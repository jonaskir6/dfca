# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import global_model as GLOBAL
import numpy as np

from util import *

# %%
torch.cuda.empty_cache()

with open("config.json", "r") as read_file:
    config = json.load(read_file)

res_final = []

start_time = time.time()
config['data_seed'] = 12
config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = GLOBAL.TrainCIFARCluster(config, device)
exp.setup()
res = exp.run()
res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
del exp
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 400, 'm_test': 80, 'p': 2, 'n': 250, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.2, 'num_epochs': 300, 'batch_size': 50, 'tau': 5, 'lr': 0.1, 'data_seed': 12, 'train_seed': 12, 'project_dir': 'output'}
# Using device: cuda
# num_data: 50000
# Files already downloaded and verified
# num_data: 10000
# Files already downloaded and verified
# Epoch -1 tr: l 2.315 a 0.099 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  4.709sec
# Epoch -1 tst: l 2.311 a 0.106 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.159sec
# Epoch 0 tr: l 1.970 a 0.279 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.100000 6.165sec(train) 4.380sec(infer)
# Epoch 0 tst: l 1.891 a 0.330 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.187sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 1 tr: l 1.846 a 0.326 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.099950 6.104sec(train) 4.429sec(infer)
# Epoch 1 tst: l 1.714 a 0.382 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.154sec
# Epoch 2 tr: l 1.799 a 0.349 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.099900 6.122sec(train) 4.422sec(infer)
# Epoch 2 tst: l 1.646 a 0.408 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.161sec
# Epoch 3 tr: l 1.767 a 0.367 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.099850 6.193sec(train) 4.407sec(infer)
# Epoch 3 tst: l 1.596 a 0.427 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.160sec
# Epoch 4 tr: l 1.735 a 0.379 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.099800 6.092sec(train) 4.448sec(infer)
# Epoch 4 tst: l 1.563 a 0.439 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.136sec
# Epoch 5 tr: l 1.722 a 0.389 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.099750 6.081sec(train) 4.458sec(infer)
# Epoch 5 tst: l 1.540 a 0.451 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.201sec
# Epoch 6 tr: l 1.688 a 0.395 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.099700 6.090sec(train) 4.487sec(infer)
# Epoch 6 tst: l 1.513 a 0.460 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.183sec
# Epoch 7 tr: l 1.663 a 0.414 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.099651 6.438sec(train) 4.494sec(infer)
# Epoch 7 tst: l 1.490 a 0.471 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.177sec
# Epoch 8 tr: l 1.647 a 0.420 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.099601 6.175sec(train) 4.408sec(infer)
# Epoch 8 tst: l 1.479 a 0.476 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.155sec
# Epoch 9 tr: l 1.645 a 0.419 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.099551 6.116sec(train) 4.455sec(infer)
# Epoch 9 tst: l 1.453 a 0.487 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.154sec
# Epoch 10 tr: l 1.612 a 0.435 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.099501 6.138sec(train) 4.425sec(infer)
# Epoch 10 tst: l 1.432 a 0.494 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.148sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 11 tr: l 1.604 a 0.439 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.099451 6.180sec(train) 4.447sec(infer)
# Epoch 11 tst: l 1.421 a 0.497 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.184sec
# Epoch 12 tr: l 1.589 a 0.451 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.099402 6.289sec(train) 4.511sec(infer)
# Epoch 12 tst: l 1.411 a 0.503 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.216sec
# Epoch 13 tr: l 1.553 a 0.456 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.099352 6.205sec(train) 4.516sec(infer)
# Epoch 13 tst: l 1.389 a 0.509 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.200sec
# Epoch 14 tr: l 1.549 a 0.458 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.099302 6.253sec(train) 4.518sec(infer)
# Epoch 14 tst: l 1.381 a 0.511 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.228sec
# Epoch 15 tr: l 1.544 a 0.458 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(33), np.int64(47)]  lr 0.099253 6.238sec(train) 4.603sec(infer)
# Epoch 15 tst: l 1.372 a 0.516 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.209sec
# Epoch 16 tr: l 1.519 a 0.470 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.099203 6.301sec(train) 4.577sec(infer)
# Epoch 16 tst: l 1.359 a 0.522 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.118sec
# Epoch 17 tr: l 1.507 a 0.472 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.099153 6.252sec(train) 4.395sec(infer)
# Epoch 17 tst: l 1.352 a 0.525 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.145sec
# Epoch 18 tr: l 1.511 a 0.469 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.099104 6.068sec(train) 4.390sec(infer)
# Epoch 18 tst: l 1.343 a 0.527 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.211sec
# Epoch 19 tr: l 1.491 a 0.479 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.099054 6.152sec(train) 4.417sec(infer)
# Epoch 19 tst: l 1.330 a 0.532 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.107sec
# Epoch 20 tr: l 1.481 a 0.481 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.099005 6.110sec(train) 4.380sec(infer)
# Epoch 20 tst: l 1.323 a 0.537 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 21 tr: l 1.472 a 0.483 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.098955 6.185sec(train) 4.576sec(infer)
# Epoch 21 tst: l 1.314 a 0.542 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# Epoch 22 tr: l 1.466 a 0.484 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.098906 6.316sec(train) 4.489sec(infer)
# Epoch 22 tst: l 1.310 a 0.543 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.154sec
# Epoch 23 tr: l 1.451 a 0.493 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.098856 6.248sec(train) 4.506sec(infer)
# Epoch 23 tst: l 1.298 a 0.547 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.170sec
# Epoch 24 tr: l 1.453 a 0.493 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.098807 6.227sec(train) 4.492sec(infer)
# Epoch 24 tst: l 1.293 a 0.551 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.181sec
# Epoch 25 tr: l 1.457 a 0.489 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.098757 6.289sec(train) 4.522sec(infer)
# Epoch 25 tst: l 1.287 a 0.551 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.163sec
# Epoch 26 tr: l 1.415 a 0.511 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.098708 6.282sec(train) 4.478sec(infer)
# Epoch 26 tst: l 1.273 a 0.556 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.158sec
# Epoch 27 tr: l 1.423 a 0.504 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.098659 6.228sec(train) 4.528sec(infer)
# Epoch 27 tst: l 1.271 a 0.556 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.200sec
# Epoch 28 tr: l 1.419 a 0.506 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.098609 6.220sec(train) 4.502sec(infer)
# Epoch 28 tst: l 1.267 a 0.558 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# Epoch 29 tr: l 1.395 a 0.514 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.098560 6.225sec(train) 4.493sec(infer)
# Epoch 29 tst: l 1.257 a 0.563 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.167sec
# Epoch 30 tr: l 1.402 a 0.513 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.098511 6.256sec(train) 4.462sec(infer)
# Epoch 30 tst: l 1.250 a 0.563 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.141sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 31 tr: l 1.396 a 0.515 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.098462 6.277sec(train) 4.513sec(infer)
# Epoch 31 tst: l 1.246 a 0.567 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.209sec
# Epoch 32 tr: l 1.386 a 0.521 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.098412 6.194sec(train) 4.517sec(infer)
# Epoch 32 tst: l 1.238 a 0.568 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.179sec
# Epoch 33 tr: l 1.386 a 0.515 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.098363 6.302sec(train) 4.476sec(infer)
# Epoch 33 tst: l 1.235 a 0.572 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.158sec
# Epoch 34 tr: l 1.385 a 0.519 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.098314 6.357sec(train) 4.498sec(infer)
# Epoch 34 tst: l 1.228 a 0.575 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.156sec
# Epoch 35 tr: l 1.373 a 0.522 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.098265 6.216sec(train) 4.575sec(infer)
# Epoch 35 tst: l 1.226 a 0.574 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.162sec
# Epoch 36 tr: l 1.371 a 0.523 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.098216 6.277sec(train) 4.523sec(infer)
# Epoch 36 tst: l 1.222 a 0.576 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.186sec
# Epoch 37 tr: l 1.360 a 0.525 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.098167 6.236sec(train) 4.493sec(infer)
# Epoch 37 tst: l 1.216 a 0.579 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.328sec
# Epoch 38 tr: l 1.353 a 0.532 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.098117 6.230sec(train) 4.490sec(infer)
# Epoch 38 tst: l 1.212 a 0.580 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.146sec
# Epoch 39 tr: l 1.362 a 0.530 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.098068 6.252sec(train) 4.501sec(infer)
# Epoch 39 tst: l 1.212 a 0.581 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.180sec
# Epoch 40 tr: l 1.365 a 0.530 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.098019 6.310sec(train) 4.396sec(infer)
# Epoch 40 tst: l 1.204 a 0.584 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.143sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 41 tr: l 1.340 a 0.536 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.097970 6.340sec(train) 4.434sec(infer)
# Epoch 41 tst: l 1.196 a 0.586 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.127sec
# Epoch 42 tr: l 1.346 a 0.533 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.097921 6.183sec(train) 4.516sec(infer)
# Epoch 42 tst: l 1.189 a 0.590 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.220sec
# Epoch 43 tr: l 1.340 a 0.536 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.097872 6.133sec(train) 4.416sec(infer)
# Epoch 43 tst: l 1.181 a 0.591 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.129sec
# Epoch 44 tr: l 1.315 a 0.542 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.097823 6.112sec(train) 4.436sec(infer)
# Epoch 44 tst: l 1.180 a 0.593 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.167sec
# Epoch 45 tr: l 1.322 a 0.543 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097775 6.079sec(train) 4.544sec(infer)
# Epoch 45 tst: l 1.178 a 0.593 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.183sec
# Epoch 46 tr: l 1.322 a 0.545 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.097726 6.127sec(train) 4.425sec(infer)
# Epoch 46 tst: l 1.170 a 0.595 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.139sec
# Epoch 47 tr: l 1.310 a 0.548 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.097677 6.186sec(train) 4.419sec(infer)
# Epoch 47 tst: l 1.168 a 0.596 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.136sec
# Epoch 48 tr: l 1.318 a 0.547 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.097628 6.174sec(train) 4.437sec(infer)
# Epoch 48 tst: l 1.167 a 0.598 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.148sec
# Epoch 49 tr: l 1.300 a 0.550 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.097579 6.158sec(train) 4.529sec(infer)
# Epoch 49 tst: l 1.158 a 0.599 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.146sec
# Epoch 50 tr: l 1.303 a 0.550 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(48), np.int64(32)]  lr 0.097530 6.351sec(train) 4.417sec(infer)
# Epoch 50 tst: l 1.154 a 0.601 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.141sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 51 tr: l 1.302 a 0.546 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097482 6.236sec(train) 4.424sec(infer)
# Epoch 51 tst: l 1.152 a 0.602 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.162sec
# Epoch 52 tr: l 1.299 a 0.551 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.097433 6.180sec(train) 4.505sec(infer)
# Epoch 52 tst: l 1.146 a 0.604 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.167sec
# Epoch 53 tr: l 1.307 a 0.553 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.097384 6.249sec(train) 4.580sec(infer)
# Epoch 53 tst: l 1.146 a 0.603 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.198sec
# Epoch 54 tr: l 1.299 a 0.549 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097335 6.267sec(train) 4.485sec(infer)
# Epoch 54 tst: l 1.140 a 0.605 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.199sec
# Epoch 55 tr: l 1.278 a 0.561 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.097287 6.294sec(train) 4.491sec(infer)
# Epoch 55 tst: l 1.136 a 0.608 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.220sec
# Epoch 56 tr: l 1.281 a 0.556 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.097238 6.201sec(train) 4.490sec(infer)
# Epoch 56 tst: l 1.135 a 0.608 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.159sec
# Epoch 57 tr: l 1.288 a 0.555 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097190 6.169sec(train) 4.398sec(infer)
# Epoch 57 tst: l 1.132 a 0.609 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.169sec
# Epoch 58 tr: l 1.275 a 0.560 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.097141 6.191sec(train) 4.516sec(infer)
# Epoch 58 tst: l 1.127 a 0.610 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.148sec
# Epoch 59 tr: l 1.267 a 0.562 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097092 6.279sec(train) 4.488sec(infer)
# Epoch 59 tst: l 1.124 a 0.611 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.133sec
# Epoch 60 tr: l 1.261 a 0.562 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.097044 6.245sec(train) 4.484sec(infer)
# Epoch 60 tst: l 1.121 a 0.612 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.188sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 61 tr: l 1.253 a 0.566 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.096995 6.256sec(train) 4.450sec(infer)
# Epoch 61 tst: l 1.120 a 0.612 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.180sec
# Epoch 62 tr: l 1.251 a 0.566 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.096947 6.157sec(train) 4.428sec(infer)
# Epoch 62 tst: l 1.120 a 0.614 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.126sec
# Epoch 63 tr: l 1.260 a 0.565 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.096898 6.150sec(train) 4.456sec(infer)
# Epoch 63 tst: l 1.112 a 0.616 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.131sec
# Epoch 64 tr: l 1.236 a 0.574 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.096850 6.258sec(train) 4.482sec(infer)
# Epoch 64 tst: l 1.109 a 0.618 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.192sec
# Epoch 65 tr: l 1.263 a 0.568 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.096801 6.246sec(train) 4.486sec(infer)
# Epoch 65 tst: l 1.107 a 0.619 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.188sec
# Epoch 66 tr: l 1.239 a 0.571 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.096753 6.228sec(train) 4.475sec(infer)
# Epoch 66 tst: l 1.104 a 0.619 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.173sec
# Epoch 67 tr: l 1.244 a 0.572 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.096705 6.343sec(train) 4.520sec(infer)
# Epoch 67 tst: l 1.102 a 0.620 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.145sec
# Epoch 68 tr: l 1.241 a 0.572 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.096656 6.142sec(train) 4.390sec(infer)
# Epoch 68 tst: l 1.101 a 0.622 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.165sec
# Epoch 69 tr: l 1.238 a 0.574 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.096608 6.076sec(train) 4.430sec(infer)
# Epoch 69 tst: l 1.095 a 0.624 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.164sec
# Epoch 70 tr: l 1.224 a 0.571 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.096560 6.223sec(train) 4.471sec(infer)
# Epoch 70 tst: l 1.092 a 0.624 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.192sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 71 tr: l 1.229 a 0.573 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.096511 6.289sec(train) 4.495sec(infer)
# Epoch 71 tst: l 1.091 a 0.625 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.196sec
# Epoch 72 tr: l 1.227 a 0.578 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.096463 6.273sec(train) 4.530sec(infer)
# Epoch 72 tst: l 1.087 a 0.627 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.185sec
# Epoch 73 tr: l 1.214 a 0.580 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(52), np.int64(28)]  lr 0.096415 6.292sec(train) 4.566sec(infer)
# Epoch 73 tst: l 1.086 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.199sec
# Epoch 74 tr: l 1.210 a 0.581 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(30), np.int64(50)]  lr 0.096367 6.242sec(train) 4.489sec(infer)
# Epoch 74 tst: l 1.087 a 0.627 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.161sec
# Epoch 75 tr: l 1.224 a 0.577 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.096319 6.366sec(train) 4.547sec(infer)
# Epoch 75 tst: l 1.081 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.240sec
# Epoch 76 tr: l 1.203 a 0.585 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.096270 7.886sec(train) 4.487sec(infer)
# Epoch 76 tst: l 1.079 a 0.629 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.191sec
# Epoch 77 tr: l 1.195 a 0.588 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.096222 6.277sec(train) 4.526sec(infer)
# Epoch 77 tst: l 1.079 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.181sec
# Epoch 78 tr: l 1.208 a 0.587 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.096174 6.258sec(train) 4.519sec(infer)
# Epoch 78 tst: l 1.078 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.154sec
# Epoch 79 tr: l 1.206 a 0.586 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.096126 6.232sec(train) 4.458sec(infer)
# Epoch 79 tst: l 1.073 a 0.630 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.166sec
# Epoch 80 tr: l 1.210 a 0.585 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.096078 6.216sec(train) 4.408sec(infer)
# Epoch 80 tst: l 1.070 a 0.633 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.164sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 81 tr: l 1.212 a 0.584 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.096030 6.162sec(train) 4.507sec(infer)
# Epoch 81 tst: l 1.067 a 0.634 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.184sec
# Epoch 82 tr: l 1.202 a 0.585 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.095982 6.319sec(train) 4.489sec(infer)
# Epoch 82 tst: l 1.063 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.160sec
# Epoch 83 tr: l 1.190 a 0.592 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.095934 6.267sec(train) 4.453sec(infer)
# Epoch 83 tst: l 1.061 a 0.634 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.195sec
# Epoch 84 tr: l 1.170 a 0.594 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.095886 6.280sec(train) 4.505sec(infer)
# Epoch 84 tst: l 1.060 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.199sec
# Epoch 85 tr: l 1.183 a 0.595 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.095838 6.193sec(train) 4.408sec(infer)
# Epoch 85 tst: l 1.058 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.132sec
# Epoch 86 tr: l 1.183 a 0.592 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.095790 6.126sec(train) 4.403sec(infer)
# Epoch 86 tst: l 1.055 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.145sec
# Epoch 87 tr: l 1.175 a 0.591 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.095742 6.597sec(train) 4.871sec(infer)
# Epoch 87 tst: l 1.050 a 0.639 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.202sec
# Epoch 88 tr: l 1.182 a 0.591 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.095694 6.559sec(train) 4.719sec(infer)
# Epoch 88 tst: l 1.049 a 0.639 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.193sec
# Epoch 89 tr: l 1.164 a 0.597 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.095646 6.242sec(train) 4.506sec(infer)
# Epoch 89 tst: l 1.045 a 0.639 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.324sec
# Epoch 90 tr: l 1.179 a 0.591 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.095599 6.395sec(train) 4.775sec(infer)
# Epoch 90 tst: l 1.046 a 0.640 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.267sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 91 tr: l 1.172 a 0.596 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.095551 6.641sec(train) 4.643sec(infer)
# Epoch 91 tst: l 1.045 a 0.641 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.188sec
# Epoch 92 tr: l 1.168 a 0.594 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.095503 6.514sec(train) 4.607sec(infer)
# Epoch 92 tst: l 1.045 a 0.642 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.239sec
# Epoch 93 tr: l 1.182 a 0.592 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.095455 6.367sec(train) 4.462sec(infer)
# Epoch 93 tst: l 1.042 a 0.644 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.128sec
# Epoch 94 tr: l 1.164 a 0.599 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.095408 6.096sec(train) 4.391sec(infer)
# Epoch 94 tst: l 1.039 a 0.644 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.145sec
# Epoch 95 tr: l 1.166 a 0.599 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.095360 6.174sec(train) 4.465sec(infer)
# Epoch 95 tst: l 1.038 a 0.644 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.169sec
# Epoch 96 tr: l 1.171 a 0.597 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.095312 6.253sec(train) 4.516sec(infer)
# Epoch 96 tst: l 1.037 a 0.644 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.222sec
# Epoch 97 tr: l 1.165 a 0.598 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(49), np.int64(31)]  lr 0.095265 6.157sec(train) 4.412sec(infer)
# Epoch 97 tst: l 1.038 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.166sec
# Epoch 98 tr: l 1.154 a 0.599 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.095217 6.181sec(train) 4.417sec(infer)
# Epoch 98 tst: l 1.036 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.151sec
# Epoch 99 tr: l 1.151 a 0.604 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.095169 6.155sec(train) 4.491sec(infer)
# Epoch 99 tst: l 1.031 a 0.647 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.168sec
# Epoch 100 tr: l 1.149 a 0.606 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.095122 6.328sec(train) 4.532sec(infer)
# Epoch 100 tst: l 1.030 a 0.648 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.175sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 101 tr: l 1.154 a 0.603 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.095074 6.320sec(train) 4.509sec(infer)
# Epoch 101 tst: l 1.028 a 0.648 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.181sec
# Epoch 102 tr: l 1.152 a 0.604 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.095027 6.198sec(train) 4.441sec(infer)
# Epoch 102 tst: l 1.024 a 0.649 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.152sec
# Epoch 103 tr: l 1.146 a 0.603 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.094979 6.141sec(train) 4.418sec(infer)
# Epoch 103 tst: l 1.023 a 0.650 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.132sec
# Epoch 104 tr: l 1.146 a 0.610 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.094932 6.137sec(train) 4.489sec(infer)
# Epoch 104 tst: l 1.024 a 0.650 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.193sec
# Epoch 105 tr: l 1.154 a 0.605 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.094884 6.228sec(train) 4.603sec(infer)
# Epoch 105 tst: l 1.019 a 0.654 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.184sec
# Epoch 106 tr: l 1.150 a 0.604 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.094837 6.269sec(train) 4.451sec(infer)
# Epoch 106 tst: l 1.017 a 0.651 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.219sec
# Epoch 107 tr: l 1.148 a 0.606 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.094789 6.220sec(train) 4.518sec(infer)
# Epoch 107 tst: l 1.017 a 0.653 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.210sec
# Epoch 108 tr: l 1.141 a 0.607 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.094742 6.172sec(train) 4.506sec(infer)
# Epoch 108 tst: l 1.016 a 0.653 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.177sec
# Epoch 109 tr: l 1.153 a 0.604 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(30), np.int64(50)]  lr 0.094695 6.210sec(train) 4.465sec(infer)
# Epoch 109 tst: l 1.013 a 0.655 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.149sec
# Epoch 110 tr: l 1.123 a 0.617 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(33), np.int64(47)]  lr 0.094647 6.195sec(train) 4.444sec(infer)
# Epoch 110 tst: l 1.013 a 0.655 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.217sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 111 tr: l 1.133 a 0.610 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.094600 6.231sec(train) 4.477sec(infer)
# Epoch 111 tst: l 1.010 a 0.656 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.190sec
# Epoch 112 tr: l 1.130 a 0.610 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.094553 6.362sec(train) 4.492sec(infer)
# Epoch 112 tst: l 1.008 a 0.657 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.227sec
# Epoch 113 tr: l 1.123 a 0.616 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.094505 6.222sec(train) 4.477sec(infer)
# Epoch 113 tst: l 1.009 a 0.657 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.223sec
# Epoch 114 tr: l 1.137 a 0.608 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.094458 6.217sec(train) 4.482sec(infer)
# Epoch 114 tst: l 1.007 a 0.657 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.182sec
# Epoch 115 tr: l 1.119 a 0.618 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.094411 6.218sec(train) 4.456sec(infer)
# Epoch 115 tst: l 1.004 a 0.659 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.210sec
# Epoch 116 tr: l 1.126 a 0.612 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.094364 6.241sec(train) 4.513sec(infer)
# Epoch 116 tst: l 1.004 a 0.659 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.170sec
# Epoch 117 tr: l 1.116 a 0.620 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.094316 6.244sec(train) 4.525sec(infer)
# Epoch 117 tst: l 1.003 a 0.658 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.172sec
# Epoch 118 tr: l 1.125 a 0.613 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.094269 6.309sec(train) 4.502sec(infer)
# Epoch 118 tst: l 1.000 a 0.661 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.182sec
# Epoch 119 tr: l 1.131 a 0.609 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.094222 6.219sec(train) 4.405sec(infer)
# Epoch 119 tst: l 0.998 a 0.661 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.149sec
# Epoch 120 tr: l 1.103 a 0.620 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.094175 6.107sec(train) 4.414sec(infer)
# Epoch 120 tst: l 0.993 a 0.662 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.159sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 121 tr: l 1.125 a 0.613 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.094128 6.113sec(train) 4.534sec(infer)
# Epoch 121 tst: l 0.998 a 0.660 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.193sec
# Epoch 122 tr: l 1.121 a 0.616 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.094081 6.103sec(train) 4.391sec(infer)
# Epoch 122 tst: l 0.996 a 0.662 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.162sec
# Epoch 123 tr: l 1.099 a 0.625 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.094034 6.092sec(train) 4.448sec(infer)
# Epoch 123 tst: l 0.994 a 0.661 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.176sec
# Epoch 124 tr: l 1.109 a 0.620 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.093987 6.120sec(train) 4.543sec(infer)
# Epoch 124 tst: l 0.995 a 0.662 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.212sec
# Epoch 125 tr: l 1.125 a 0.618 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.093940 6.218sec(train) 4.492sec(infer)
# Epoch 125 tst: l 0.992 a 0.664 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.200sec
# Epoch 126 tr: l 1.125 a 0.615 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.093893 6.259sec(train) 4.457sec(infer)
# Epoch 126 tst: l 0.988 a 0.664 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.172sec
# Epoch 127 tr: l 1.088 a 0.624 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.093846 6.358sec(train) 4.532sec(infer)
# Epoch 127 tst: l 0.986 a 0.665 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.252sec
# Epoch 128 tr: l 1.093 a 0.627 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.093799 6.250sec(train) 4.525sec(infer)
# Epoch 128 tst: l 0.987 a 0.664 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.152sec
# Epoch 129 tr: l 1.086 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.093752 6.274sec(train) 4.487sec(infer)
# Epoch 129 tst: l 0.985 a 0.666 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.160sec
# Epoch 130 tr: l 1.102 a 0.620 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.093705 6.251sec(train) 4.475sec(infer)
# Epoch 130 tst: l 0.986 a 0.665 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.170sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 131 tr: l 1.085 a 0.625 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.093658 6.222sec(train) 4.489sec(infer)
# Epoch 131 tst: l 0.981 a 0.667 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.213sec
# Epoch 132 tr: l 1.104 a 0.619 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.093612 6.201sec(train) 4.474sec(infer)
# Epoch 132 tst: l 0.980 a 0.666 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.216sec
# Epoch 133 tr: l 1.095 a 0.627 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.093565 6.278sec(train) 4.570sec(infer)
# Epoch 133 tst: l 0.977 a 0.668 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.208sec
# Epoch 134 tr: l 1.100 a 0.625 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.093518 6.245sec(train) 4.476sec(infer)
# Epoch 134 tst: l 0.978 a 0.667 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.218sec
# Epoch 135 tr: l 1.093 a 0.621 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.093471 6.318sec(train) 4.481sec(infer)
# Epoch 135 tst: l 0.975 a 0.668 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.208sec
# Epoch 136 tr: l 1.084 a 0.624 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.093424 6.242sec(train) 4.484sec(infer)
# Epoch 136 tst: l 0.976 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.219sec
# Epoch 137 tr: l 1.078 a 0.627 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.093378 6.263sec(train) 4.500sec(infer)
# Epoch 137 tst: l 0.971 a 0.670 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.174sec
# Epoch 138 tr: l 1.090 a 0.624 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.093331 6.220sec(train) 4.473sec(infer)
# Epoch 138 tst: l 0.972 a 0.668 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.177sec
# Epoch 139 tr: l 1.080 a 0.626 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.093284 6.179sec(train) 4.475sec(infer)
# Epoch 139 tst: l 0.967 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.169sec
# Epoch 140 tr: l 1.084 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.093238 6.226sec(train) 4.379sec(infer)
# Epoch 140 tst: l 0.967 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.122sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 141 tr: l 1.076 a 0.629 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.093191 6.206sec(train) 4.469sec(infer)
# Epoch 141 tst: l 0.967 a 0.670 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.185sec
# Epoch 142 tr: l 1.066 a 0.634 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.093145 6.212sec(train) 4.503sec(infer)
# Epoch 142 tst: l 0.969 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.199sec
# Epoch 143 tr: l 1.078 a 0.632 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.093098 6.220sec(train) 4.512sec(infer)
# Epoch 143 tst: l 0.968 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.188sec
# Epoch 144 tr: l 1.096 a 0.621 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.093051 6.360sec(train) 4.453sec(infer)
# Epoch 144 tst: l 0.965 a 0.671 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.185sec
# Epoch 145 tr: l 1.087 a 0.628 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.093005 6.191sec(train) 4.501sec(infer)
# Epoch 145 tst: l 0.965 a 0.670 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.211sec
# Epoch 146 tr: l 1.075 a 0.633 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.092958 6.224sec(train) 4.492sec(infer)
# Epoch 146 tst: l 0.961 a 0.672 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.211sec
# Epoch 147 tr: l 1.073 a 0.629 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.092912 6.368sec(train) 4.509sec(infer)
# Epoch 147 tst: l 0.960 a 0.672 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.209sec
# Epoch 148 tr: l 1.084 a 0.630 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(48), np.int64(32)]  lr 0.092865 6.316sec(train) 4.378sec(infer)
# Epoch 148 tst: l 0.959 a 0.672 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.128sec
# Epoch 149 tr: l 1.056 a 0.639 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.092819 6.186sec(train) 4.480sec(infer)
# Epoch 149 tst: l 0.962 a 0.673 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.147sec
# Epoch 150 tr: l 1.066 a 0.636 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.092773 6.145sec(train) 4.511sec(infer)
# Epoch 150 tst: l 0.960 a 0.672 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.164sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 151 tr: l 1.069 a 0.634 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.092726 6.176sec(train) 4.471sec(infer)
# Epoch 151 tst: l 0.955 a 0.673 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.160sec
# Epoch 152 tr: l 1.060 a 0.637 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.092680 6.398sec(train) 4.458sec(infer)
# Epoch 152 tst: l 0.955 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.186sec
# Epoch 153 tr: l 1.062 a 0.636 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.092634 6.224sec(train) 4.456sec(infer)
# Epoch 153 tst: l 0.954 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.173sec
# Epoch 154 tr: l 1.064 a 0.632 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.092587 6.204sec(train) 4.453sec(infer)
# Epoch 154 tst: l 0.951 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.191sec
# Epoch 155 tr: l 1.075 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.092541 6.230sec(train) 4.443sec(infer)
# Epoch 155 tst: l 0.954 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# Epoch 156 tr: l 1.068 a 0.636 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.092495 6.155sec(train) 4.468sec(infer)
# Epoch 156 tst: l 0.950 a 0.676 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# Epoch 157 tr: l 1.064 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.092448 6.243sec(train) 4.449sec(infer)
# Epoch 157 tst: l 0.949 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.146sec
# Epoch 158 tr: l 1.052 a 0.637 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.092402 6.198sec(train) 4.509sec(infer)
# Epoch 158 tst: l 0.948 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.166sec
# Epoch 159 tr: l 1.061 a 0.635 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.092356 6.204sec(train) 4.442sec(infer)
# Epoch 159 tst: l 0.948 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.173sec
# Epoch 160 tr: l 1.054 a 0.642 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.092310 6.210sec(train) 4.445sec(infer)
# Epoch 160 tst: l 0.947 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.162sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 161 tr: l 1.041 a 0.644 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.092264 6.392sec(train) 4.606sec(infer)
# Epoch 161 tst: l 0.947 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.184sec
# Epoch 162 tr: l 1.055 a 0.638 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.092218 6.148sec(train) 4.957sec(infer)
# Epoch 162 tst: l 0.950 a 0.676 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.332sec
# Epoch 163 tr: l 1.060 a 0.640 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.092171 6.507sec(train) 4.552sec(infer)
# Epoch 163 tst: l 0.948 a 0.676 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.143sec
# Epoch 164 tr: l 1.057 a 0.636 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.092125 6.369sec(train) 4.663sec(infer)
# Epoch 164 tst: l 0.946 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.182sec
# Epoch 165 tr: l 1.027 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.092079 6.376sec(train) 4.510sec(infer)
# Epoch 165 tst: l 0.943 a 0.679 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.139sec
# Epoch 166 tr: l 1.035 a 0.647 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.092033 6.436sec(train) 4.553sec(infer)
# Epoch 166 tst: l 0.945 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.127sec
# Epoch 167 tr: l 1.047 a 0.640 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.091987 6.509sec(train) 4.559sec(infer)
# Epoch 167 tst: l 0.945 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.150sec
# Epoch 168 tr: l 1.039 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.091941 6.782sec(train) 4.646sec(infer)
# Epoch 168 tst: l 0.942 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.318sec
# Epoch 169 tr: l 1.039 a 0.647 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.091895 6.858sec(train) 5.060sec(infer)
# Epoch 169 tst: l 0.939 a 0.679 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.095sec
# Epoch 170 tr: l 1.043 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.091849 6.370sec(train) 4.489sec(infer)
# Epoch 170 tst: l 0.940 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.235sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 171 tr: l 1.030 a 0.648 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.091803 6.396sec(train) 4.701sec(infer)
# Epoch 171 tst: l 0.939 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.066sec
# Epoch 172 tr: l 1.047 a 0.639 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.091757 6.223sec(train) 4.521sec(infer)
# Epoch 172 tst: l 0.940 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.157sec
# Epoch 173 tr: l 1.044 a 0.643 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(33), np.int64(47)]  lr 0.091712 6.238sec(train) 4.485sec(infer)
# Epoch 173 tst: l 0.938 a 0.681 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.136sec
# Epoch 174 tr: l 1.040 a 0.643 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.091666 6.233sec(train) 4.465sec(infer)
# Epoch 174 tst: l 0.933 a 0.682 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.133sec
# Epoch 175 tr: l 1.034 a 0.645 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.091620 6.200sec(train) 4.491sec(infer)
# Epoch 175 tst: l 0.933 a 0.682 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.169sec
# Epoch 176 tr: l 1.039 a 0.642 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.091574 6.258sec(train) 4.538sec(infer)
# Epoch 176 tst: l 0.930 a 0.684 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.131sec
# Epoch 177 tr: l 1.029 a 0.648 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(50), np.int64(30)]  lr 0.091528 6.268sec(train) 4.479sec(infer)
# Epoch 177 tst: l 0.929 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.165sec
# Epoch 178 tr: l 1.031 a 0.646 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(31), np.int64(49)]  lr 0.091483 6.334sec(train) 4.528sec(infer)
# Epoch 178 tst: l 0.930 a 0.684 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# Epoch 179 tr: l 1.024 a 0.647 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.091437 6.254sec(train) 4.468sec(infer)
# Epoch 179 tst: l 0.928 a 0.682 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.144sec
# Epoch 180 tr: l 1.023 a 0.650 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.091391 6.179sec(train) 4.669sec(infer)
# Epoch 180 tst: l 0.928 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.153sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# ...
# Epoch 242 tr: l 0.967 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.088601 7.013sec(train) 5.242sec(infer)
# Epoch 242 tst: l 0.882 a 0.702 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.533sec
# Epoch 243 tr: l 0.975 a 0.665 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.088556 7.265sec(train) 5.496sec(infer)
# Epoch 243 tst: l 0.879 a 0.701 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.521sec
# Epoch 244 tr: l 0.958 a 0.673 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.088512 6.984sec(train) 4.929sec(infer)
# Epoch 244 tst: l 0.878 a 0.702 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.310sec
# Epoch 245 tr: l 0.953 a 0.673 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.088468 6.587sec(train) 4.879sec(infer)
# Epoch 245 tst: l 0.878 a 0.703 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.344sec
# Epoch 246 tr: l 0.955 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.088424 6.714sec(train) 5.087sec(infer)
# Epoch 246 tst: l 0.876 a 0.704 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.455sec
# Epoch 247 tr: l 0.942 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.088379 6.924sec(train) 4.965sec(infer)
# Epoch 247 tst: l 0.877 a 0.703 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.469sec
# Epoch 248 tr: l 0.963 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.088335 7.258sec(train) 4.885sec(infer)
# Epoch 248 tst: l 0.877 a 0.704 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.480sec
# Epoch 249 tr: l 0.955 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.088291 6.656sec(train) 4.956sec(infer)
# Epoch 249 tst: l 0.876 a 0.703 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.994sec
# Epoch 250 tr: l 0.951 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.088247 7.812sec(train) 5.326sec(infer)
# Epoch 250 tst: l 0.875 a 0.702 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.412sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 251 tr: l 0.951 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(47), np.int64(33)]  lr 0.088203 7.217sec(train) 5.165sec(infer)
# Epoch 251 tst: l 0.874 a 0.703 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.527sec
# Epoch 252 tr: l 0.962 a 0.669 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.088159 7.848sec(train) 5.095sec(infer)
# Epoch 252 tst: l 0.876 a 0.702 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.555sec
# Epoch 253 tr: l 0.944 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.088115 6.385sec(train) 4.370sec(infer)
# Epoch 253 tst: l 0.873 a 0.703 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.044sec
# Epoch 254 tr: l 0.953 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.088071 6.343sec(train) 4.530sec(infer)
# Epoch 254 tst: l 0.873 a 0.705 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.140sec
# Epoch 255 tr: l 0.955 a 0.676 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(48), np.int64(32)]  lr 0.088027 6.428sec(train) 4.465sec(infer)
# Epoch 255 tst: l 0.873 a 0.706 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.063sec
# Epoch 256 tr: l 0.941 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087983 6.562sec(train) 5.061sec(infer)
# Epoch 256 tst: l 0.874 a 0.704 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.681sec
# Epoch 257 tr: l 0.956 a 0.672 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(51), np.int64(29)]  lr 0.087939 7.082sec(train) 4.667sec(infer)
# Epoch 257 tst: l 0.871 a 0.707 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.092sec
# Epoch 258 tr: l 0.950 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087895 6.257sec(train) 4.371sec(infer)
# Epoch 258 tst: l 0.871 a 0.706 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.055sec
# Epoch 259 tr: l 0.955 a 0.671 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.087851 6.189sec(train) 4.455sec(infer)
# Epoch 259 tst: l 0.873 a 0.705 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.079sec
# Epoch 260 tr: l 0.950 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.087807 6.227sec(train) 4.399sec(infer)
# Epoch 260 tst: l 0.872 a 0.704 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.250sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 261 tr: l 0.963 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.087763 6.211sec(train) 4.421sec(infer)
# Epoch 261 tst: l 0.871 a 0.705 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.055sec
# Epoch 262 tr: l 0.938 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087719 6.178sec(train) 4.507sec(infer)
# Epoch 262 tst: l 0.867 a 0.706 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.157sec
# Epoch 263 tr: l 0.931 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087675 6.569sec(train) 4.471sec(infer)
# Epoch 263 tst: l 0.869 a 0.708 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.042sec
# Epoch 264 tr: l 0.946 a 0.673 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.087631 6.155sec(train) 4.395sec(infer)
# Epoch 264 tst: l 0.868 a 0.708 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.067sec
# Epoch 265 tr: l 0.939 a 0.679 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.087587 6.147sec(train) 4.413sec(infer)
# Epoch 265 tst: l 0.867 a 0.708 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.126sec
# Epoch 266 tr: l 0.930 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(35), np.int64(45)]  lr 0.087544 7.568sec(train) 5.266sec(infer)
# Epoch 266 tst: l 0.866 a 0.707 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.534sec
# Epoch 267 tr: l 0.927 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.087500 7.135sec(train) 5.021sec(infer)
# Epoch 267 tst: l 0.867 a 0.707 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.272sec
# Epoch 268 tr: l 0.929 a 0.674 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.087456 6.654sec(train) 4.841sec(infer)
# Epoch 268 tst: l 0.867 a 0.709 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.240sec
# Epoch 269 tr: l 0.936 a 0.677 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.087412 6.608sec(train) 4.818sec(infer)
# Epoch 269 tst: l 0.866 a 0.708 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.280sec
# Epoch 270 tr: l 0.943 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087369 6.682sec(train) 4.854sec(infer)
# Epoch 270 tst: l 0.864 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.280sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 271 tr: l 0.937 a 0.681 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.087325 6.921sec(train) 4.929sec(infer)
# Epoch 271 tst: l 0.863 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.276sec
# Epoch 272 tr: l 0.935 a 0.682 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(46), np.int64(34)]  lr 0.087281 6.783sec(train) 4.990sec(infer)
# Epoch 272 tst: l 0.865 a 0.708 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.354sec
# Epoch 273 tr: l 0.937 a 0.681 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.087238 6.810sec(train) 5.120sec(infer)
# Epoch 273 tst: l 0.863 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.328sec
# Epoch 274 tr: l 0.925 a 0.687 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(45), np.int64(35)]  lr 0.087194 6.830sec(train) 4.955sec(infer)
# Epoch 274 tst: l 0.863 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.321sec
# Epoch 275 tr: l 0.937 a 0.679 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.087150 7.199sec(train) 4.862sec(infer)
# Epoch 275 tst: l 0.865 a 0.707 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.305sec
# Epoch 276 tr: l 0.922 a 0.681 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.087107 6.652sec(train) 4.857sec(infer)
# Epoch 276 tst: l 0.862 a 0.709 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.285sec
# Epoch 277 tr: l 0.940 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(33), np.int64(47)]  lr 0.087063 6.708sec(train) 4.932sec(infer)
# Epoch 277 tst: l 0.864 a 0.707 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.285sec
# Epoch 278 tr: l 0.938 a 0.680 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.087020 6.878sec(train) 4.926sec(infer)
# Epoch 278 tst: l 0.864 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.490sec
# Epoch 279 tr: l 0.948 a 0.675 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.086976 6.900sec(train) 4.947sec(infer)
# Epoch 279 tst: l 0.858 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.421sec
# Epoch 280 tr: l 0.947 a 0.678 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.086933 6.844sec(train) 4.888sec(infer)
# Epoch 280 tst: l 0.861 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.379sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 281 tr: l 0.921 a 0.688 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(34), np.int64(46)]  lr 0.086889 6.740sec(train) 4.907sec(infer)
# Epoch 281 tst: l 0.860 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.417sec
# Epoch 282 tr: l 0.917 a 0.689 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.086846 6.709sec(train) 4.878sec(infer)
# Epoch 282 tst: l 0.862 a 0.709 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.346sec
# Epoch 283 tr: l 0.931 a 0.682 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(37), np.int64(43)]  lr 0.086802 6.684sec(train) 4.953sec(infer)
# Epoch 283 tst: l 0.862 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.351sec
# Epoch 284 tr: l 0.924 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.086759 6.650sec(train) 5.072sec(infer)
# Epoch 284 tst: l 0.861 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.342sec
# Epoch 285 tr: l 0.914 a 0.688 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.086716 6.831sec(train) 4.931sec(infer)
# Epoch 285 tst: l 0.858 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.341sec
# Epoch 286 tr: l 0.912 a 0.686 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.086672 6.708sec(train) 4.862sec(infer)
# Epoch 286 tst: l 0.859 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.351sec
# Epoch 287 tr: l 0.934 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(43), np.int64(37)]  lr 0.086629 6.773sec(train) 4.905sec(infer)
# Epoch 287 tst: l 0.857 a 0.710 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.344sec
# Epoch 288 tr: l 0.928 a 0.685 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(36), np.int64(44)]  lr 0.086586 6.908sec(train) 4.854sec(infer)
# Epoch 288 tst: l 0.857 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.341sec
# Epoch 289 tr: l 0.930 a 0.684 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  lr 0.086542 6.729sec(train) 4.888sec(infer)
# Epoch 289 tst: l 0.855 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.359sec
# Epoch 290 tr: l 0.916 a 0.687 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.086499 6.775sec(train) 5.009sec(infer)
# Epoch 290 tst: l 0.851 a 0.712 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.334sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 291 tr: l 0.929 a 0.683 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(33), np.int64(47)]  lr 0.086456 6.716sec(train) 4.863sec(infer)
# Epoch 291 tst: l 0.852 a 0.711 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.361sec
# Epoch 292 tr: l 0.920 a 0.684 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(32), np.int64(48)]  lr 0.086413 6.646sec(train) 4.850sec(infer)
# Epoch 292 tst: l 0.853 a 0.712 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.286sec
# Epoch 293 tr: l 0.919 a 0.687 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.086369 6.755sec(train) 4.846sec(infer)
# Epoch 293 tst: l 0.853 a 0.712 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.365sec
# Epoch 294 tr: l 0.903 a 0.691 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(41), np.int64(39)]  lr 0.086326 6.685sec(train) 4.897sec(infer)
# Epoch 294 tst: l 0.851 a 0.712 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.312sec
# Epoch 295 tr: l 0.905 a 0.690 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.086283 9.233sec(train) 4.887sec(infer)
# Epoch 295 tst: l 0.851 a 0.712 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.357sec
# Epoch 296 tr: l 0.922 a 0.684 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(44), np.int64(36)]  lr 0.086240 6.651sec(train) 4.897sec(infer)
# Epoch 296 tst: l 0.852 a 0.714 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.337sec
# Epoch 297 tr: l 0.917 a 0.687 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(42), np.int64(38)]  lr 0.086197 6.868sec(train) 4.919sec(infer)
# Epoch 297 tst: l 0.851 a 0.713 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.280sec
# Epoch 298 tr: l 0.920 a 0.687 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(39), np.int64(41)]  lr 0.086154 6.645sec(train) 4.850sec(infer)
# Epoch 298 tst: l 0.849 a 0.714 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.325sec
# Epoch 299 tr: l 0.917 a 0.689 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(38), np.int64(42)]  lr 0.086111 6.683sec(train) 4.889sec(infer)
# Epoch 299 tst: l 0.849 a 0.713 clct[np.int64(80), np.int64(0)] clct_ans[np.int64(40), np.int64(40)]  2.325sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 19
#      17 exp.setup()
#      18 res = exp.run()
# ---> 19 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#      20 del exp
#      21 duration = (time.time() - start_time)
#
# Cell In[2], line 19, in <listcomp>(.0)
#      17 exp.setup()
#      18 res = exp.run()
# ---> 19 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#      20 del exp
#      21 duration = (time.time() - start_time)
#
# KeyError: 'cl_acc'
