# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import ifca as IFCA

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
rc = ipp.Cluster(n=3).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]

# %%
learning_rates = [0.25]

dfca_gi = []
ifca = []
dfca_li = []

# %%
# %%px --targets all
#
# import sys
# import os
# import random
# sys.path.append(os.getcwd())
#
# random.seed(42)
# seeds = random.sample(range(10000), 5)
# learning_rates = [0.25]
#
# dfca_gi = []
# ifca = []
# dfca_li = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-GI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainCIFARCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_gi.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the dfca-li experiments

# %%
# %%px --target 1 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_li.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-LI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainCIFARCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_li.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the ifca experiment

# %%
# %%px --target 2 --noblock
# import ifca as IFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------IFCA, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = IFCA.TrainCIFARCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ifca.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# DFCA-GI Experiment Outputs

# %%
rc.wait_interactive()
_.display_outputs()

dfca_gi = rc[0].pull('dfca_gi', block=True)
dfca_li = rc[1].pull('dfca_li', block=True)
dfca_li = rc[2].pull('ifca', block=True)
# Out:
# unknown:   0%|          | 0/3 [00:00<?, ?tasks/s]
# ---------------------------------IFCA, lr: 0.25, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.3, 'h1': 128, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda:3
# num_data: 50000
# num_data: 10000
# finding good initializer from train data
# Epoch -1 tr: l 2.302 a 0.115 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(30), np.int64(30)]  14.871sec
# found good initializer
# Epoch -1 tr: l 2.302 a 0.120 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(31), np.int64(29)]  12.722sec
# Epoch -1 tst: l 2.302 a 0.122 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.088sec
# Epoch 0 tr: l 2.187 a 0.216 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.250000 41.848sec(train) 12.501sec(infer)
# Epoch 0 tst: l 2.183 a 0.225 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.130sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 2.116 a 0.249 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.249975 29.057sec(train) 12.522sec(infer)
# Epoch 1 tst: l 2.106 a 0.259 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.142sec
# Epoch 2 tr: l 2.055 a 0.290 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249950 29.044sec(train) 12.514sec(infer)
# Epoch 2 tst: l 2.038 a 0.309 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.140sec
# Epoch 3 tr: l 1.974 a 0.313 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(39), np.int64(21)]  lr 0.249925 29.030sec(train) 12.538sec(infer)
# Epoch 3 tst: l 1.953 a 0.332 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.151sec
# Epoch 4 tr: l 1.898 a 0.334 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.249900 29.164sec(train) 12.478sec(infer)
# Epoch 4 tst: l 1.873 a 0.347 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# Epoch 5 tr: l 1.879 a 0.349 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.249875 28.681sec(train) 12.538sec(infer)
# Epoch 5 tst: l 1.845 a 0.370 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.160sec
# Epoch 6 tr: l 1.821 a 0.354 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.249850 28.992sec(train) 12.497sec(infer)
# Epoch 6 tst: l 1.773 a 0.385 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 7 tr: l 1.809 a 0.364 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(23), np.int64(37)]  lr 0.249825 29.011sec(train) 12.471sec(infer)
# Epoch 7 tst: l 1.762 a 0.392 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.188sec
# Epoch 8 tr: l 1.753 a 0.376 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.249800 28.968sec(train) 12.472sec(infer)
# Epoch 8 tst: l 1.699 a 0.400 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.151sec
# Epoch 9 tr: l 1.725 a 0.392 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249775 25.013sec(train) 12.524sec(infer)
# Epoch 9 tst: l 1.664 a 0.421 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# Epoch 10 tr: l 1.691 a 0.402 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.249750 28.966sec(train) 12.516sec(infer)
# Epoch 10 tst: l 1.627 a 0.431 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.143sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 1.700 a 0.409 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.249725 29.146sec(train) 12.466sec(infer)
# Epoch 11 tst: l 1.626 a 0.444 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.161sec
# Epoch 12 tr: l 1.671 a 0.411 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.249700 28.963sec(train) 12.450sec(infer)
# Epoch 12 tst: l 1.602 a 0.449 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 13 tr: l 1.634 a 0.417 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.249675 28.917sec(train) 12.475sec(infer)
# Epoch 13 tst: l 1.558 a 0.454 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 14 tr: l 1.611 a 0.431 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249650 28.972sec(train) 12.456sec(infer)
# Epoch 14 tst: l 1.542 a 0.463 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.146sec
# Epoch 15 tr: l 1.583 a 0.440 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249625 28.947sec(train) 12.471sec(infer)
# Epoch 15 tst: l 1.514 a 0.473 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.112sec
# Epoch 16 tr: l 1.578 a 0.445 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249600 28.970sec(train) 12.490sec(infer)
# Epoch 16 tst: l 1.501 a 0.478 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.121sec
# Epoch 17 tr: l 1.566 a 0.447 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.249575 28.917sec(train) 12.469sec(infer)
# Epoch 17 tst: l 1.481 a 0.484 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# Epoch 18 tr: l 1.527 a 0.461 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.249550 29.112sec(train) 12.433sec(infer)
# Epoch 18 tst: l 1.450 a 0.491 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.115sec
# Epoch 19 tr: l 1.524 a 0.461 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.249525 28.227sec(train) 12.469sec(infer)
# Epoch 19 tst: l 1.438 a 0.499 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.145sec
# Epoch 20 tr: l 1.509 a 0.471 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.249500 28.939sec(train) 12.475sec(infer)
# Epoch 20 tst: l 1.432 a 0.502 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 1.505 a 0.470 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249476 28.968sec(train) 12.456sec(infer)
# Epoch 21 tst: l 1.425 a 0.505 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.097sec
# Epoch 22 tr: l 1.492 a 0.477 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249451 28.914sec(train) 12.532sec(infer)
# Epoch 22 tst: l 1.423 a 0.506 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.168sec
# Epoch 23 tr: l 1.492 a 0.479 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249426 29.007sec(train) 12.499sec(infer)
# Epoch 23 tst: l 1.410 a 0.510 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.169sec
# Epoch 24 tr: l 1.481 a 0.482 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(37), np.int64(23)]  lr 0.249401 28.962sec(train) 12.512sec(infer)
# Epoch 24 tst: l 1.418 a 0.513 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.141sec
# Epoch 25 tr: l 1.472 a 0.486 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249376 29.132sec(train) 12.457sec(infer)
# Epoch 25 tst: l 1.393 a 0.513 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.111sec
# Epoch 26 tr: l 1.484 a 0.484 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.249351 28.976sec(train) 12.479sec(infer)
# Epoch 26 tst: l 1.415 a 0.509 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 27 tr: l 1.453 a 0.490 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249326 28.946sec(train) 12.469sec(infer)
# Epoch 27 tst: l 1.375 a 0.521 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.206sec
# Epoch 28 tr: l 1.458 a 0.491 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.249301 28.963sec(train) 12.457sec(infer)
# Epoch 28 tst: l 1.391 a 0.516 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 29 tr: l 1.446 a 0.494 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249276 28.896sec(train) 12.470sec(infer)
# Epoch 29 tst: l 1.369 a 0.522 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.130sec
# Epoch 30 tr: l 1.443 a 0.493 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.249251 28.940sec(train) 12.525sec(infer)
# Epoch 30 tst: l 1.371 a 0.522 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.175sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 1.421 a 0.504 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(36), np.int64(24)]  lr 0.249226 28.974sec(train) 12.513sec(infer)
# Epoch 31 tst: l 1.353 a 0.529 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.148sec
# Epoch 32 tr: l 1.425 a 0.506 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.249201 29.140sec(train) 12.438sec(infer)
# Epoch 32 tst: l 1.365 a 0.525 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.130sec
# Epoch 33 tr: l 1.423 a 0.500 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.249176 28.992sec(train) 12.486sec(infer)
# Epoch 33 tst: l 1.351 a 0.529 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.113sec
# Epoch 34 tr: l 1.421 a 0.505 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.249151 28.956sec(train) 12.561sec(infer)
# Epoch 34 tst: l 1.352 a 0.530 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.264sec
# Epoch 35 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249126 28.985sec(train) 12.435sec(infer)
# Epoch 35 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.134sec
# Epoch 36 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.249102 28.964sec(train) 12.525sec(infer)
# Epoch 36 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.131sec
# Epoch 37 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.249077 28.948sec(train) 12.469sec(infer)
# Epoch 37 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.160sec
# Epoch 38 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.249052 28.972sec(train) 12.484sec(infer)
# Epoch 38 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.141sec
# Epoch 39 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.249027 29.169sec(train) 12.457sec(infer)
# Epoch 39 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 40 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.249002 29.005sec(train) 12.467sec(infer)
# Epoch 40 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 41 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.248977 28.909sec(train) 12.630sec(infer)
# Epoch 41 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.164sec
# Epoch 42 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.248952 28.887sec(train) 12.537sec(infer)
# Epoch 42 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# Epoch 43 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.248927 28.669sec(train) 12.577sec(infer)
# Epoch 43 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.137sec
# Epoch 44 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.248902 28.569sec(train) 12.545sec(infer)
# Epoch 44 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.160sec
# Epoch 45 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.248877 27.682sec(train) 12.550sec(infer)
# Epoch 45 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.167sec
# Epoch 46 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.248853 29.070sec(train) 12.504sec(infer)
# Epoch 46 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.183sec
# Epoch 47 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(23), np.int64(37)]  lr 0.248828 28.384sec(train) 12.559sec(infer)
# Epoch 47 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.158sec
# Epoch 48 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.248803 28.390sec(train) 12.511sec(infer)
# Epoch 48 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.142sec
# Epoch 49 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.248778 28.697sec(train) 12.533sec(infer)
# Epoch 49 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.111sec
# Epoch 50 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.248753 28.342sec(train) 12.502sec(infer)
# Epoch 50 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.157sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 51 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.248728 27.696sec(train) 12.481sec(infer)
# Epoch 51 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# Epoch 52 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.248703 27.927sec(train) 12.499sec(infer)
# Epoch 52 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.304sec
# Epoch 53 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.248678 28.300sec(train) 12.499sec(infer)
# Epoch 53 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.140sec
# Epoch 54 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.248654 27.686sec(train) 12.430sec(infer)
# Epoch 54 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.180sec
# Epoch 55 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.248629 29.189sec(train) 12.621sec(infer)
# Epoch 55 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 56 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.248604 29.039sec(train) 12.961sec(infer)
# Epoch 56 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.205sec
# Epoch 57 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.248579 27.947sec(train) 12.548sec(infer)
# Epoch 57 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 58 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.248554 27.195sec(train) 12.536sec(infer)
# Epoch 58 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 59 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.248529 28.300sec(train) 12.715sec(infer)
# Epoch 59 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.151sec
# Epoch 60 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.248504 28.574sec(train) 12.466sec(infer)
# Epoch 60 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.157sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 61 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.248480 28.843sec(train) 12.511sec(infer)
# Epoch 61 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# Epoch 62 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.248455 27.892sec(train) 12.473sec(infer)
# Epoch 62 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.141sec
# Epoch 63 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(36), np.int64(24)]  lr 0.248430 27.052sec(train) 12.456sec(infer)
# Epoch 63 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.130sec
# Epoch 64 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.248405 28.667sec(train) 12.473sec(infer)
# Epoch 64 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 65 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.248380 28.040sec(train) 12.447sec(infer)
# Epoch 65 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.143sec
# Epoch 66 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.248355 27.431sec(train) 12.673sec(infer)
# Epoch 66 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.140sec
# Epoch 67 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.248331 28.415sec(train) 12.489sec(infer)
# Epoch 67 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.164sec
# Epoch 68 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.248306 22.958sec(train) 12.451sec(infer)
# Epoch 68 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.112sec
# Epoch 69 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.248281 25.594sec(train) 12.466sec(infer)
# Epoch 69 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# Epoch 70 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.248256 28.380sec(train) 12.439sec(infer)
# Epoch 70 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 71 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.248231 27.966sec(train) 12.491sec(infer)
# Epoch 71 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 72 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.248206 27.835sec(train) 12.483sec(infer)
# Epoch 72 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.145sec
# Epoch 73 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(36), np.int64(24)]  lr 0.248182 27.642sec(train) 12.442sec(infer)
# Epoch 73 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# Epoch 74 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.248157 28.114sec(train) 12.460sec(infer)
# Epoch 74 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 75 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.248132 27.138sec(train) 12.494sec(infer)
# Epoch 75 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.143sec
# Epoch 76 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.248107 28.209sec(train) 12.412sec(infer)
# Epoch 76 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.190sec
# Epoch 77 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.248082 28.021sec(train) 12.435sec(infer)
# Epoch 77 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.109sec
# Epoch 78 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.248057 28.033sec(train) 12.457sec(infer)
# Epoch 78 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.147sec
# Epoch 79 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.248033 27.568sec(train) 12.461sec(infer)
# Epoch 79 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.131sec
# Epoch 80 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.248008 28.711sec(train) 12.482sec(infer)
# Epoch 80 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 81 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247983 28.757sec(train) 12.425sec(infer)
# Epoch 81 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.134sec
# Epoch 82 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247958 29.019sec(train) 12.479sec(infer)
# Epoch 82 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.111sec
# Epoch 83 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247933 28.940sec(train) 12.463sec(infer)
# Epoch 83 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.095sec
# Epoch 84 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247909 28.892sec(train) 12.442sec(infer)
# Epoch 84 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 85 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247884 28.963sec(train) 12.446sec(infer)
# Epoch 85 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.117sec
# Epoch 86 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247859 28.985sec(train) 12.497sec(infer)
# Epoch 86 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.123sec
# Epoch 87 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.247834 29.127sec(train) 12.471sec(infer)
# Epoch 87 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.153sec
# Epoch 88 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247810 28.920sec(train) 12.432sec(infer)
# Epoch 88 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 89 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247785 28.933sec(train) 12.434sec(infer)
# Epoch 89 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.099sec
# Epoch 90 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.247760 29.006sec(train) 12.479sec(infer)
# Epoch 90 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.110sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 91 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247735 28.982sec(train) 12.441sec(infer)
# Epoch 91 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.114sec
# Epoch 92 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247710 28.937sec(train) 12.465sec(infer)
# Epoch 92 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.131sec
# Epoch 93 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247686 28.876sec(train) 12.454sec(infer)
# Epoch 93 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.137sec
# Epoch 94 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247661 29.157sec(train) 12.423sec(infer)
# Epoch 94 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.101sec
# Epoch 95 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247636 28.917sec(train) 12.460sec(infer)
# Epoch 95 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.108sec
# Epoch 96 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247611 28.953sec(train) 12.474sec(infer)
# Epoch 96 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.159sec
# Epoch 97 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247587 28.981sec(train) 12.484sec(infer)
# Epoch 97 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 98 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247562 28.980sec(train) 12.455sec(infer)
# Epoch 98 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 99 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.247537 28.958sec(train) 12.499sec(infer)
# Epoch 99 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 100 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247512 28.969sec(train) 12.452sec(infer)
# Epoch 100 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 101 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247488 29.180sec(train) 12.449sec(infer)
# Epoch 101 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.103sec
# Epoch 102 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.247463 28.957sec(train) 12.445sec(infer)
# Epoch 102 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.147sec
# Epoch 103 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.247438 28.915sec(train) 12.454sec(infer)
# Epoch 103 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 104 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247413 28.965sec(train) 12.483sec(infer)
# Epoch 104 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 105 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.247389 28.877sec(train) 12.453sec(infer)
# Epoch 105 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.125sec
# Epoch 106 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247364 27.908sec(train) 12.458sec(infer)
# Epoch 106 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.165sec
# Epoch 107 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247339 27.964sec(train) 12.508sec(infer)
# Epoch 107 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.117sec
# Epoch 108 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247314 27.964sec(train) 12.418sec(infer)
# Epoch 108 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.105sec
# Epoch 109 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247290 22.820sec(train) 12.451sec(infer)
# Epoch 109 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 110 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247265 28.114sec(train) 12.500sec(infer)
# Epoch 110 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 111 tr: l nan a 0.096 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(38), np.int64(22)]  lr 0.247240 27.898sec(train) 12.439sec(infer)
# Epoch 111 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# Epoch 112 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.247215 27.912sec(train) 12.451sec(infer)
# Epoch 112 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.123sec
# Epoch 113 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.247191 27.877sec(train) 12.491sec(infer)
# Epoch 113 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.156sec
# Epoch 114 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247166 27.650sec(train) 12.453sec(infer)
# Epoch 114 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.106sec
# Epoch 115 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.247141 29.057sec(train) 12.450sec(infer)
# Epoch 115 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 116 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.247117 28.271sec(train) 12.517sec(infer)
# Epoch 116 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.138sec
# Epoch 117 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.247092 28.435sec(train) 12.463sec(infer)
# Epoch 117 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 118 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247067 28.930sec(train) 12.406sec(infer)
# Epoch 118 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# Epoch 119 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.247042 28.953sec(train) 12.409sec(infer)
# Epoch 119 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.153sec
# Epoch 120 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.247018 28.915sec(train) 12.463sec(infer)
# Epoch 120 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.098sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 121 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246993 28.828sec(train) 12.468sec(infer)
# Epoch 121 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 122 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.246968 29.179sec(train) 12.424sec(infer)
# Epoch 122 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.110sec
# Epoch 123 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.246944 28.908sec(train) 12.465sec(infer)
# Epoch 123 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 124 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.246919 28.950sec(train) 12.454sec(infer)
# Epoch 124 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.137sec
# Epoch 125 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(23), np.int64(37)]  lr 0.246894 29.004sec(train) 12.397sec(infer)
# Epoch 125 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.104sec
# Epoch 126 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.246870 28.938sec(train) 12.428sec(infer)
# Epoch 126 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.109sec
# Epoch 127 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.246845 28.948sec(train) 12.467sec(infer)
# Epoch 127 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# Epoch 128 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.246820 28.970sec(train) 12.463sec(infer)
# Epoch 128 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 129 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.246796 29.156sec(train) 12.425sec(infer)
# Epoch 129 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 130 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246771 28.947sec(train) 12.465sec(infer)
# Epoch 130 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l nan a 0.104 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.246746 28.921sec(train) 12.444sec(infer)
# Epoch 131 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.209sec
# Epoch 132 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246722 28.973sec(train) 12.441sec(infer)
# Epoch 132 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.100sec
# Epoch 133 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246697 28.938sec(train) 12.451sec(infer)
# Epoch 133 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# Epoch 134 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.246672 28.845sec(train) 12.435sec(infer)
# Epoch 134 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.117sec
# Epoch 135 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.246648 27.479sec(train) 12.491sec(infer)
# Epoch 135 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 136 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.246623 28.214sec(train) 12.466sec(infer)
# Epoch 136 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.120sec
# Epoch 137 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.246598 28.083sec(train) 12.451sec(infer)
# Epoch 137 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.130sec
# Epoch 138 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.246574 27.230sec(train) 12.482sec(infer)
# Epoch 138 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 139 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.246549 28.293sec(train) 12.456sec(infer)
# Epoch 139 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.134sec
# Epoch 140 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.246524 28.101sec(train) 12.446sec(infer)
# Epoch 140 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.246500 27.250sec(train) 12.517sec(infer)
# Epoch 141 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.169sec
# Epoch 142 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(23), np.int64(37)]  lr 0.246475 28.685sec(train) 12.409sec(infer)
# Epoch 142 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 143 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.246450 29.096sec(train) 12.420sec(infer)
# Epoch 143 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.141sec
# Epoch 144 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.246426 28.974sec(train) 12.479sec(infer)
# Epoch 144 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# Epoch 145 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.246401 28.953sec(train) 12.404sec(infer)
# Epoch 145 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 146 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.246376 28.970sec(train) 12.466sec(infer)
# Epoch 146 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.124sec
# Epoch 147 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.246352 28.921sec(train) 12.494sec(infer)
# Epoch 147 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.147sec
# Epoch 148 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.246327 28.971sec(train) 12.447sec(infer)
# Epoch 148 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.172sec
# Epoch 149 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.246302 28.916sec(train) 12.413sec(infer)
# Epoch 149 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.320sec
# Epoch 150 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246278 28.988sec(train) 12.440sec(infer)
# Epoch 150 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.246253 28.963sec(train) 12.440sec(infer)
# Epoch 151 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.143sec
# Epoch 152 tr: l nan a 0.096 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.246229 28.911sec(train) 12.463sec(infer)
# Epoch 152 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.134sec
# Epoch 153 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.246204 28.967sec(train) 12.436sec(infer)
# Epoch 153 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 154 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.246179 28.953sec(train) 12.459sec(infer)
# Epoch 154 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.137sec
# Epoch 155 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.246155 28.925sec(train) 12.459sec(infer)
# Epoch 155 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.134sec
# Epoch 156 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.246130 28.965sec(train) 12.711sec(infer)
# Epoch 156 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.117sec
# Epoch 157 tr: l nan a 0.104 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.246105 28.956sec(train) 12.479sec(infer)
# Epoch 157 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# Epoch 158 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.246081 28.967sec(train) 12.492sec(infer)
# Epoch 158 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.131sec
# Epoch 159 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.246056 28.988sec(train) 12.504sec(infer)
# Epoch 159 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# Epoch 160 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.246032 28.932sec(train) 12.455sec(infer)
# Epoch 160 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.149sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.246007 28.744sec(train) 12.476sec(infer)
# Epoch 161 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.139sec
# Epoch 162 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.245982 29.005sec(train) 12.500sec(infer)
# Epoch 162 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 163 tr: l nan a 0.095 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.245958 28.960sec(train) 12.658sec(infer)
# Epoch 163 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.137sec
# Epoch 164 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.245933 28.940sec(train) 12.449sec(infer)
# Epoch 164 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.145sec
# Epoch 165 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.245909 28.969sec(train) 12.462sec(infer)
# Epoch 165 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 166 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.245884 28.960sec(train) 12.496sec(infer)
# Epoch 166 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# Epoch 167 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.245859 29.024sec(train) 12.453sec(infer)
# Epoch 167 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.143sec
# Epoch 168 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.245835 28.913sec(train) 12.483sec(infer)
# Epoch 168 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 169 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.245810 28.947sec(train) 12.481sec(infer)
# Epoch 169 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# Epoch 170 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(23), np.int64(37)]  lr 0.245786 29.115sec(train) 12.444sec(infer)
# Epoch 170 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.142sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 171 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(38), np.int64(22)]  lr 0.245761 28.763sec(train) 12.441sec(infer)
# Epoch 171 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.111sec
# Epoch 172 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.245737 28.909sec(train) 12.496sec(infer)
# Epoch 172 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 173 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.245712 28.979sec(train) 12.483sec(infer)
# Epoch 173 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.128sec
# Epoch 174 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(37), np.int64(23)]  lr 0.245687 28.971sec(train) 12.429sec(infer)
# Epoch 174 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.180sec
# Epoch 175 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.245663 28.959sec(train) 12.452sec(infer)
# Epoch 175 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.126sec
# Epoch 176 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.245638 29.022sec(train) 12.462sec(infer)
# Epoch 176 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.139sec
# Epoch 177 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.245614 29.179sec(train) 12.431sec(infer)
# Epoch 177 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.125sec
# Epoch 178 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.245589 28.971sec(train) 12.464sec(infer)
# Epoch 178 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 179 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.245565 28.983sec(train) 12.489sec(infer)
# Epoch 179 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.156sec
# ...
# Epoch 539 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 540 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023686 28.951sec(train) 12.647sec(infer)
# Epoch 540 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.136sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 541 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023683 28.990sec(train) 12.426sec(infer)
# Epoch 541 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.120sec
# Epoch 542 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(38), np.int64(22)]  lr 0.023681 28.830sec(train) 12.391sec(infer)
# Epoch 542 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 543 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023679 28.943sec(train) 12.378sec(infer)
# Epoch 543 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.097sec
# Epoch 544 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023676 28.982sec(train) 12.601sec(infer)
# Epoch 544 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.101sec
# Epoch 545 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023674 27.608sec(train) 12.429sec(infer)
# Epoch 545 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.113sec
# Epoch 546 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(36), np.int64(24)]  lr 0.023672 27.471sec(train) 12.426sec(infer)
# Epoch 546 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 547 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023669 27.603sec(train) 12.460sec(infer)
# Epoch 547 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.115sec
# Epoch 548 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023667 27.118sec(train) 12.374sec(infer)
# Epoch 548 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 549 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.023664 28.525sec(train) 12.403sec(infer)
# Epoch 549 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.114sec
# Epoch 550 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.023662 27.864sec(train) 12.428sec(infer)
# Epoch 550 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.103sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 551 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023660 27.566sec(train) 12.504sec(infer)
# Epoch 551 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 552 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023657 28.972sec(train) 12.444sec(infer)
# Epoch 552 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.125sec
# Epoch 553 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023655 28.971sec(train) 12.442sec(infer)
# Epoch 553 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 554 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.023653 27.964sec(train) 12.687sec(infer)
# Epoch 554 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 555 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.023650 29.000sec(train) 12.417sec(infer)
# Epoch 555 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.107sec
# Epoch 556 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(33), np.int64(27)]  lr 0.023648 28.944sec(train) 12.483sec(infer)
# Epoch 556 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.108sec
# Epoch 557 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023646 28.402sec(train) 12.463sec(infer)
# Epoch 557 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# Epoch 558 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.023643 27.617sec(train) 12.495sec(infer)
# Epoch 558 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 559 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(24), np.int64(36)]  lr 0.023641 28.407sec(train) 12.456sec(infer)
# Epoch 559 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 560 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(36), np.int64(24)]  lr 0.023638 28.768sec(train) 12.428sec(infer)
# Epoch 560 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.099sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 561 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.023636 28.191sec(train) 12.417sec(infer)
# Epoch 561 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.095sec
# Epoch 562 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.023634 27.930sec(train) 12.456sec(infer)
# Epoch 562 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.125sec
# Epoch 563 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023631 27.686sec(train) 12.462sec(infer)
# Epoch 563 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.118sec
# Epoch 564 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.023629 28.262sec(train) 12.451sec(infer)
# Epoch 564 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.112sec
# Epoch 565 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.023627 28.230sec(train) 12.413sec(infer)
# Epoch 565 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.094sec
# Epoch 566 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.023624 26.901sec(train) 12.480sec(infer)
# Epoch 566 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 567 tr: l nan a 0.096 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(27), np.int64(33)]  lr 0.023622 28.818sec(train) 12.518sec(infer)
# Epoch 567 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.121sec
# Epoch 568 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.023620 28.064sec(train) 12.487sec(infer)
# Epoch 568 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 569 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023617 27.750sec(train) 12.484sec(infer)
# Epoch 569 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.123sec
# Epoch 570 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023615 27.830sec(train) 12.450sec(infer)
# Epoch 570 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.110sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 571 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023612 27.998sec(train) 12.406sec(infer)
# Epoch 571 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.107sec
# Epoch 572 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.023610 28.095sec(train) 12.437sec(infer)
# Epoch 572 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.102sec
# Epoch 573 tr: l nan a 0.103 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023608 27.855sec(train) 12.425sec(infer)
# Epoch 573 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.117sec
# Epoch 574 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.023605 27.463sec(train) 12.468sec(infer)
# Epoch 574 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.140sec
# Epoch 575 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.023603 27.643sec(train) 12.497sec(infer)
# Epoch 575 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.115sec
# Epoch 576 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.023601 27.734sec(train) 12.377sec(infer)
# Epoch 576 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.210sec
# Epoch 577 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.023598 27.475sec(train) 12.424sec(infer)
# Epoch 577 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.094sec
# Epoch 578 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.023596 28.238sec(train) 12.464sec(infer)
# Epoch 578 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.129sec
# Epoch 579 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(26), np.int64(34)]  lr 0.023594 27.942sec(train) 12.418sec(infer)
# Epoch 579 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 580 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(35), np.int64(25)]  lr 0.023591 28.378sec(train) 12.456sec(infer)
# Epoch 580 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.115sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 581 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.023589 28.286sec(train) 12.463sec(infer)
# Epoch 581 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.133sec
# Epoch 582 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023586 28.385sec(train) 12.415sec(infer)
# Epoch 582 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.104sec
# Epoch 583 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.023584 28.455sec(train) 12.455sec(infer)
# Epoch 583 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.101sec
# Epoch 584 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023582 28.276sec(train) 12.469sec(infer)
# Epoch 584 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.105sec
# Epoch 585 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(28), np.int64(32)]  lr 0.023579 28.293sec(train) 12.429sec(infer)
# Epoch 585 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.121sec
# Epoch 586 tr: l nan a 0.102 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023577 28.092sec(train) 12.490sec(infer)
# Epoch 586 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.122sec
# Epoch 587 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023575 28.054sec(train) 12.425sec(infer)
# Epoch 587 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.148sec
# Epoch 588 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023572 27.964sec(train) 12.426sec(infer)
# Epoch 588 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.125sec
# Epoch 589 tr: l nan a 0.097 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023570 28.907sec(train) 12.632sec(infer)
# Epoch 589 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.155sec
# Epoch 590 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.023568 28.888sec(train) 12.447sec(infer)
# Epoch 590 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 591 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.023565 28.911sec(train) 12.481sec(infer)
# Epoch 591 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.121sec
# Epoch 592 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(30), np.int64(30)]  lr 0.023563 28.942sec(train) 12.465sec(infer)
# Epoch 592 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.119sec
# Epoch 593 tr: l nan a 0.099 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(29), np.int64(31)]  lr 0.023561 28.928sec(train) 12.448sec(infer)
# Epoch 593 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.162sec
# Epoch 594 tr: l nan a 0.100 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(25), np.int64(35)]  lr 0.023558 28.959sec(train) 12.440sec(infer)
# Epoch 594 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.099sec
# Epoch 595 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(31), np.int64(29)]  lr 0.023556 28.941sec(train) 12.441sec(infer)
# Epoch 595 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.132sec
# Epoch 596 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023553 29.089sec(train) 12.446sec(infer)
# Epoch 596 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.116sec
# Epoch 597 tr: l nan a 0.101 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023551 28.974sec(train) 12.468sec(infer)
# Epoch 597 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 598 tr: l nan a 0.104 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(32), np.int64(28)]  lr 0.023549 27.185sec(train) 12.469sec(infer)
# Epoch 598 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.127sec
# Epoch 599 tr: l nan a 0.098 clct[np.int64(60), np.int64(0)] clct_ans[np.int64(34), np.int64(26)]  lr 0.023546 28.946sec(train) 12.503sec(infer)
# Epoch 599 tst: l nan a 0.100 clct[np.int64(40), np.int64(0)] clct_ans[np.int64(20), np.int64(20)]  3.149sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# 100%|██████████| 170M/170M [00:07<00:00, 22.3MB/s]

# %% [markdown]
# IFCA Experiment Outputs

# %%
__.display_outputs()
# Out:
# ---------------------------------DFCA-LI, lr: 0.25, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': False, 'local_model_init': True, 'participation_rate': 0.3, 'h1': 128, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_li'}
# Using device: cuda:3
# num_data: 50000
# num_data: 10000
# finding good initializer from train data
# Epoch -1 tr: l 2.303 a 0.102 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.517  13.552sec
# found good initializer
# Epoch -1 tr: l 2.302 a 0.104 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.517  13.115sec
# Epoch -1 tst: l 2.302 a 0.112 clct[np.int64(16), np.int64(24)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.718sec
# Epoch 0 tr: l 2.293 a 0.115 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.600  lr 0.250000 31.833sec(train) 13.136sec(infer)
# Epoch 0 tst: l 2.299 a 0.119 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.629sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 1 tr: l 2.281 a 0.121 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.550  lr 0.249975 30.661sec(train) 13.061sec(infer)
# Epoch 1 tst: l 2.296 a 0.120 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.663sec
# Epoch 2 tr: l 2.276 a 0.129 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.550  lr 0.249950 30.901sec(train) 12.977sec(infer)
# Epoch 2 tst: l 2.288 a 0.122 clct[np.int64(18), np.int64(22)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.629sec
# Epoch 3 tr: l 2.284 a 0.127 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(39), np.int64(21)] cl_acc0.517  lr 0.249925 30.838sec(train) 12.883sec(infer)
# Epoch 3 tst: l 2.294 a 0.119 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.554sec
# Epoch 4 tr: l 2.263 a 0.141 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.517  lr 0.249900 30.517sec(train) 12.848sec(infer)
# Epoch 4 tst: l 2.285 a 0.125 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.485sec
# Epoch 5 tr: l 2.274 a 0.131 clct[np.int64(23), np.int64(37)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.550  lr 0.249875 30.512sec(train) 12.799sec(infer)
# Epoch 5 tst: l 2.283 a 0.129 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.469sec
# Epoch 6 tr: l 2.259 a 0.142 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.517  lr 0.249850 30.454sec(train) 12.787sec(infer)
# Epoch 6 tst: l 2.275 a 0.130 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.477sec
# Epoch 7 tr: l 2.267 a 0.134 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(23), np.int64(37)] cl_acc0.567  lr 0.249825 30.717sec(train) 12.766sec(infer)
# Epoch 7 tst: l 2.275 a 0.127 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.494sec
# Epoch 8 tr: l 2.258 a 0.138 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.567  lr 0.249800 30.378sec(train) 12.772sec(infer)
# Epoch 8 tst: l 2.270 a 0.130 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.447sec
# Epoch 9 tr: l 2.264 a 0.138 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.600  lr 0.249775 30.957sec(train) 12.817sec(infer)
# Epoch 9 tst: l 2.266 a 0.130 clct[np.int64(13), np.int64(27)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.510sec
# Epoch 10 tr: l 2.266 a 0.133 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.500  lr 0.249750 31.485sec(train) 12.779sec(infer)
# Epoch 10 tst: l 2.263 a 0.131 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.497sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 11 tr: l 2.272 a 0.134 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.533  lr 0.249725 31.358sec(train) 12.828sec(infer)
# Epoch 11 tst: l 2.272 a 0.130 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.505sec
# Epoch 12 tr: l 2.263 a 0.140 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.600  lr 0.249700 31.530sec(train) 12.961sec(infer)
# Epoch 12 tst: l 2.267 a 0.131 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.522sec
# Epoch 13 tr: l 2.249 a 0.145 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.517  lr 0.249675 31.538sec(train) 12.837sec(infer)
# Epoch 13 tst: l 2.246 a 0.138 clct[np.int64(18), np.int64(22)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.500sec
# Epoch 14 tr: l 2.223 a 0.157 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.517  lr 0.249650 31.592sec(train) 12.865sec(infer)
# Epoch 14 tst: l 2.234 a 0.146 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.499sec
# Epoch 15 tr: l 2.221 a 0.155 clct[np.int64(17), np.int64(43)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.600  lr 0.249625 31.518sec(train) 12.833sec(infer)
# Epoch 15 tst: l 2.233 a 0.147 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.488sec
# Epoch 16 tr: l 2.212 a 0.163 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.533  lr 0.249600 31.632sec(train) 12.850sec(infer)
# Epoch 16 tst: l 2.228 a 0.150 clct[np.int64(18), np.int64(22)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.450sec
# Epoch 17 tr: l 2.196 a 0.162 clct[np.int64(20), np.int64(40)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.517  lr 0.249575 31.563sec(train) 12.814sec(infer)
# Epoch 17 tst: l 2.216 a 0.154 clct[np.int64(14), np.int64(26)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.732sec
# Epoch 18 tr: l 2.189 a 0.167 clct[np.int64(21), np.int64(39)] clct_ans[np.int64(26), np.int64(34)] cl_acc0.583  lr 0.249550 27.981sec(train) 12.904sec(infer)
# Epoch 18 tst: l 2.205 a 0.159 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.532sec
# Epoch 19 tr: l 2.172 a 0.172 clct[np.int64(21), np.int64(39)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.567  lr 0.249525 25.382sec(train) 12.852sec(infer)
# Epoch 19 tst: l 2.178 a 0.166 clct[np.int64(12), np.int64(28)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.484sec
# Epoch 20 tr: l 2.127 a 0.188 clct[np.int64(19), np.int64(41)] clct_ans[np.int64(26), np.int64(34)] cl_acc0.550  lr 0.249500 25.911sec(train) 12.811sec(infer)
# Epoch 20 tst: l 2.146 a 0.174 clct[np.int64(10), np.int64(30)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.472sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 21 tr: l 2.111 a 0.190 clct[np.int64(16), np.int64(44)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.500  lr 0.249476 31.571sec(train) 12.789sec(infer)
# Epoch 21 tst: l 2.129 a 0.183 clct[np.int64(9), np.int64(31)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.501sec
# Epoch 22 tr: l 2.114 a 0.188 clct[np.int64(13), np.int64(47)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.517  lr 0.249451 31.641sec(train) 12.818sec(infer)
# Epoch 22 tst: l 2.117 a 0.186 clct[np.int64(8), np.int64(32)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.470sec
# Epoch 23 tr: l 2.059 a 0.203 clct[np.int64(14), np.int64(46)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.533  lr 0.249426 31.568sec(train) 12.789sec(infer)
# Epoch 23 tst: l 2.078 a 0.195 clct[np.int64(6), np.int64(34)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.500  9.478sec
# Epoch 24 tr: l 2.054 a 0.204 clct[np.int64(7), np.int64(53)] clct_ans[np.int64(37), np.int64(23)] cl_acc0.633  lr 0.249401 26.946sec(train) 12.785sec(infer)
# Epoch 24 tst: l 2.054 a 0.202 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.508sec
# Epoch 25 tr: l 2.046 a 0.205 clct[np.int64(8), np.int64(52)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.583  lr 0.249376 25.631sec(train) 12.934sec(infer)
# Epoch 25 tst: l 2.053 a 0.204 clct[np.int64(3), np.int64(37)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.564sec
# Epoch 26 tr: l 2.050 a 0.202 clct[np.int64(10), np.int64(50)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.550  lr 0.249351 25.809sec(train) 12.822sec(infer)
# Epoch 26 tst: l 2.050 a 0.204 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.551sec
# Epoch 27 tr: l 2.036 a 0.211 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.500  lr 0.249326 25.710sec(train) 12.784sec(infer)
# Epoch 27 tst: l 2.043 a 0.208 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.500  9.458sec
# Epoch 28 tr: l 2.024 a 0.217 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.650  lr 0.249301 31.712sec(train) 12.849sec(infer)
# Epoch 28 tst: l 2.017 a 0.217 clct[np.int64(1), np.int64(39)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.503sec
# Epoch 29 tr: l 1.995 a 0.219 clct[np.int64(8), np.int64(52)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.500  lr 0.249276 31.524sec(train) 12.756sec(infer)
# Epoch 29 tst: l 2.008 a 0.214 clct[np.int64(1), np.int64(39)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.480sec
# Epoch 30 tr: l 2.008 a 0.219 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.517  lr 0.249251 31.373sec(train) 12.786sec(infer)
# Epoch 30 tst: l 2.006 a 0.213 clct[np.int64(3), np.int64(37)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.487sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 31 tr: l 2.004 a 0.211 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(36), np.int64(24)] cl_acc0.667  lr 0.249226 31.201sec(train) 12.857sec(infer)
# Epoch 31 tst: l 2.006 a 0.210 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.500sec
# Epoch 32 tr: l 2.009 a 0.213 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(33), np.int64(27)] cl_acc0.600  lr 0.249201 30.244sec(train) 12.775sec(infer)
# Epoch 32 tst: l 2.007 a 0.210 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.465sec
# Epoch 33 tr: l 1.995 a 0.218 clct[np.int64(5), np.int64(55)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.583  lr 0.249176 30.235sec(train) 12.774sec(infer)
# Epoch 33 tst: l 2.004 a 0.213 clct[np.int64(3), np.int64(37)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.463sec
# Epoch 34 tr: l 2.003 a 0.218 clct[np.int64(5), np.int64(55)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.583  lr 0.249151 30.220sec(train) 12.745sec(infer)
# Epoch 34 tst: l 1.998 a 0.217 clct[np.int64(3), np.int64(37)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.470sec
# Epoch 35 tr: l 1.993 a 0.218 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.517  lr 0.249126 30.334sec(train) 12.753sec(infer)
# Epoch 35 tst: l 1.995 a 0.217 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.466sec
# Epoch 36 tr: l 1.990 a 0.221 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.550  lr 0.249102 30.327sec(train) 12.741sec(infer)
# Epoch 36 tst: l 1.997 a 0.216 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.549sec
# Epoch 37 tr: l 1.989 a 0.224 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.550  lr 0.249077 30.457sec(train) 12.746sec(infer)
# Epoch 37 tst: l 1.993 a 0.216 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.490sec
# Epoch 38 tr: l 1.991 a 0.221 clct[np.int64(1), np.int64(59)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.517  lr 0.249052 29.270sec(train) 12.817sec(infer)
# Epoch 38 tst: l 1.992 a 0.220 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.525  9.702sec
# Epoch 39 tr: l 1.989 a 0.216 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.533  lr 0.249027 31.481sec(train) 12.751sec(infer)
# Epoch 39 tst: l 1.990 a 0.221 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.485sec
# Epoch 40 tr: l 1.981 a 0.225 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(26), np.int64(34)] cl_acc0.500  lr 0.249002 31.503sec(train) 12.783sec(infer)
# Epoch 40 tst: l 1.990 a 0.222 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.496sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 41 tr: l 1.973 a 0.229 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.517  lr 0.248977 31.252sec(train) 12.769sec(infer)
# Epoch 41 tst: l 1.984 a 0.226 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.550  9.581sec
# Epoch 42 tr: l 1.980 a 0.225 clct[np.int64(7), np.int64(53)] clct_ans[np.int64(25), np.int64(35)] cl_acc0.533  lr 0.248952 31.443sec(train) 12.793sec(infer)
# Epoch 42 tst: l 1.987 a 0.222 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.526sec
# Epoch 43 tr: l 1.975 a 0.232 clct[np.int64(1), np.int64(59)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.533  lr 0.248927 31.592sec(train) 12.789sec(infer)
# Epoch 43 tst: l 1.982 a 0.224 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.599sec
# Epoch 44 tr: l 1.974 a 0.228 clct[np.int64(7), np.int64(53)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.600  lr 0.248902 30.450sec(train) 12.976sec(infer)
# Epoch 44 tst: l 1.976 a 0.229 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.559sec
# Epoch 45 tr: l 1.961 a 0.237 clct[np.int64(2), np.int64(58)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.500  lr 0.248877 31.592sec(train) 12.792sec(infer)
# Epoch 45 tst: l 1.966 a 0.233 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.462sec
# Epoch 46 tr: l 1.949 a 0.239 clct[np.int64(8), np.int64(52)] clct_ans[np.int64(33), np.int64(27)] cl_acc0.650  lr 0.248853 31.507sec(train) 12.811sec(infer)
# Epoch 46 tst: l 1.963 a 0.234 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.451sec
# Epoch 47 tr: l 1.957 a 0.237 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(23), np.int64(37)] cl_acc0.583  lr 0.248828 31.045sec(train) 12.869sec(infer)
# Epoch 47 tst: l 1.962 a 0.234 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.547sec
# Epoch 48 tr: l 1.951 a 0.241 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.600  lr 0.248803 30.276sec(train) 12.797sec(infer)
# Epoch 48 tst: l 1.965 a 0.233 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.538sec
# Epoch 49 tr: l 1.948 a 0.238 clct[np.int64(1), np.int64(59)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.517  lr 0.248778 31.734sec(train) 12.827sec(infer)
# Epoch 49 tst: l 1.964 a 0.234 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.596sec
# Epoch 50 tr: l 1.941 a 0.245 clct[np.int64(4), np.int64(56)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.567  lr 0.248753 30.507sec(train) 12.971sec(infer)
# Epoch 50 tst: l 1.957 a 0.237 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.460sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 51 tr: l 1.940 a 0.247 clct[np.int64(1), np.int64(59)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.533  lr 0.248728 30.400sec(train) 12.810sec(infer)
# Epoch 51 tst: l 1.954 a 0.238 clct[np.int64(3), np.int64(37)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  9.511sec
# Epoch 52 tr: l 1.943 a 0.242 clct[np.int64(6), np.int64(54)] clct_ans[np.int64(25), np.int64(35)] cl_acc0.517  lr 0.248703 30.456sec(train) 12.843sec(infer)
# Epoch 52 tst: l 1.944 a 0.240 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.488sec
# Epoch 53 tr: l 1.922 a 0.256 clct[np.int64(5), np.int64(55)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.600  lr 0.248678 30.342sec(train) 12.796sec(infer)
# Epoch 53 tst: l 1.927 a 0.246 clct[np.int64(4), np.int64(36)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.463sec
# Epoch 54 tr: l 1.911 a 0.258 clct[np.int64(3), np.int64(57)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.550  lr 0.248654 30.443sec(train) 12.861sec(infer)
# Epoch 54 tst: l 1.921 a 0.250 clct[np.int64(8), np.int64(32)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.700  9.487sec
# Epoch 55 tr: l 1.910 a 0.262 clct[np.int64(5), np.int64(55)] clct_ans[np.int64(33), np.int64(27)] cl_acc0.633  lr 0.248629 30.251sec(train) 12.771sec(infer)
# Epoch 55 tst: l 1.920 a 0.251 clct[np.int64(6), np.int64(34)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.650  9.432sec
# Epoch 56 tr: l 1.906 a 0.259 clct[np.int64(7), np.int64(53)] clct_ans[np.int64(26), np.int64(34)] cl_acc0.550  lr 0.248604 29.883sec(train) 12.873sec(infer)
# Epoch 56 tst: l 1.908 a 0.257 clct[np.int64(7), np.int64(33)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.675  9.572sec
# Epoch 57 tr: l 1.905 a 0.262 clct[np.int64(5), np.int64(55)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.650  lr 0.248579 31.578sec(train) 12.819sec(infer)
# Epoch 57 tst: l 1.901 a 0.264 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.510sec
# Epoch 58 tr: l 1.896 a 0.268 clct[np.int64(10), np.int64(50)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.667  lr 0.248554 31.209sec(train) 12.787sec(infer)
# Epoch 58 tst: l 1.890 a 0.269 clct[np.int64(5), np.int64(35)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.625  9.395sec
# Epoch 59 tr: l 1.893 a 0.270 clct[np.int64(11), np.int64(49)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.683  lr 0.248529 31.507sec(train) 12.824sec(infer)
# Epoch 59 tst: l 1.892 a 0.266 clct[np.int64(8), np.int64(32)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.700  9.607sec
# Epoch 60 tr: l 1.890 a 0.272 clct[np.int64(11), np.int64(49)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.667  lr 0.248504 31.586sec(train) 12.810sec(infer)
# Epoch 60 tst: l 1.884 a 0.272 clct[np.int64(10), np.int64(30)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.750  9.528sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 61 tr: l 1.889 a 0.270 clct[np.int64(10), np.int64(50)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.667  lr 0.248480 31.496sec(train) 12.797sec(infer)
# Epoch 61 tst: l 1.875 a 0.277 clct[np.int64(11), np.int64(29)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.775  9.471sec
# Epoch 62 tr: l 1.883 a 0.276 clct[np.int64(12), np.int64(48)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.783  lr 0.248455 30.712sec(train) 12.773sec(infer)
# Epoch 62 tst: l 1.865 a 0.280 clct[np.int64(10), np.int64(30)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.750  9.469sec
# Epoch 63 tr: l 1.864 a 0.282 clct[np.int64(13), np.int64(47)] clct_ans[np.int64(36), np.int64(24)] cl_acc0.817  lr 0.248430 29.657sec(train) 12.864sec(infer)
# Epoch 63 tst: l 1.851 a 0.288 clct[np.int64(12), np.int64(28)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.800  9.417sec
# Epoch 64 tr: l 1.862 a 0.281 clct[np.int64(13), np.int64(47)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.700  lr 0.248405 31.490sec(train) 12.826sec(infer)
# Epoch 64 tst: l 1.838 a 0.293 clct[np.int64(14), np.int64(26)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.850  9.440sec
# Epoch 65 tr: l 1.860 a 0.283 clct[np.int64(14), np.int64(46)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.717  lr 0.248380 31.409sec(train) 12.827sec(infer)
# Epoch 65 tst: l 1.832 a 0.295 clct[np.int64(16), np.int64(24)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.900  9.493sec
# Epoch 66 tr: l 1.841 a 0.292 clct[np.int64(16), np.int64(44)] clct_ans[np.int64(33), np.int64(27)] cl_acc0.817  lr 0.248355 31.505sec(train) 12.839sec(infer)
# Epoch 66 tst: l 1.832 a 0.298 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.875  9.549sec
# Epoch 67 tr: l 1.830 a 0.300 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.817  lr 0.248331 31.498sec(train) 12.832sec(infer)
# Epoch 67 tst: l 1.816 a 0.302 clct[np.int64(14), np.int64(26)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.850  9.412sec
# Epoch 68 tr: l 1.839 a 0.296 clct[np.int64(19), np.int64(41)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.817  lr 0.248306 31.448sec(train) 12.889sec(infer)
# Epoch 68 tst: l 1.806 a 0.308 clct[np.int64(13), np.int64(27)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.825  9.397sec
# Epoch 69 tr: l 1.825 a 0.297 clct[np.int64(18), np.int64(42)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.883  lr 0.248281 31.494sec(train) 12.794sec(infer)
# Epoch 69 tst: l 1.803 a 0.308 clct[np.int64(16), np.int64(24)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.900  9.508sec
# Epoch 70 tr: l 1.804 a 0.315 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(24), np.int64(36)] cl_acc0.850  lr 0.248256 30.989sec(train) 13.088sec(infer)
# Epoch 70 tst: l 1.792 a 0.312 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.925  9.584sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 71 tr: l 1.809 a 0.315 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.867  lr 0.248231 31.508sec(train) 12.822sec(infer)
# Epoch 71 tst: l 1.787 a 0.314 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.500sec
# Epoch 72 tr: l 1.787 a 0.318 clct[np.int64(20), np.int64(40)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.917  lr 0.248206 31.539sec(train) 12.774sec(infer)
# Epoch 72 tst: l 1.781 a 0.320 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.433sec
# Epoch 73 tr: l 1.789 a 0.324 clct[np.int64(19), np.int64(41)] clct_ans[np.int64(36), np.int64(24)] cl_acc0.917  lr 0.248182 31.592sec(train) 12.828sec(infer)
# Epoch 73 tst: l 1.775 a 0.325 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.454sec
# Epoch 74 tr: l 1.774 a 0.330 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.933  lr 0.248157 31.531sec(train) 12.704sec(infer)
# Epoch 74 tst: l 1.755 a 0.336 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 75 tr: l 1.771 a 0.329 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.883  lr 0.248132 31.487sec(train) 12.826sec(infer)
# Epoch 75 tst: l 1.746 a 0.338 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.566sec
# Epoch 76 tr: l 1.759 a 0.334 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.967  lr 0.248107 31.559sec(train) 12.711sec(infer)
# Epoch 76 tst: l 1.745 a 0.340 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.532sec
# Epoch 77 tr: l 1.739 a 0.348 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.983  lr 0.248082 31.563sec(train) 12.763sec(infer)
# Epoch 77 tst: l 1.736 a 0.344 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.395sec
# Epoch 78 tr: l 1.744 a 0.346 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.967  lr 0.248057 31.542sec(train) 12.867sec(infer)
# Epoch 78 tst: l 1.732 a 0.345 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.469sec
# Epoch 79 tr: l 1.735 a 0.345 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248033 31.580sec(train) 12.743sec(infer)
# Epoch 79 tst: l 1.723 a 0.351 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 80 tr: l 1.742 a 0.343 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.248008 31.583sec(train) 12.796sec(infer)
# Epoch 80 tst: l 1.719 a 0.353 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.715sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 81 tr: l 1.725 a 0.355 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.950  lr 0.247983 31.529sec(train) 12.770sec(infer)
# Epoch 81 tst: l 1.713 a 0.355 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.506sec
# Epoch 82 tr: l 1.714 a 0.360 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247958 31.533sec(train) 12.846sec(infer)
# Epoch 82 tst: l 1.708 a 0.358 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.553sec
# Epoch 83 tr: l 1.712 a 0.355 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247933 31.568sec(train) 12.740sec(infer)
# Epoch 83 tst: l 1.703 a 0.359 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.503sec
# Epoch 84 tr: l 1.700 a 0.361 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(33), np.int64(27)] cl_acc0.983  lr 0.247909 31.358sec(train) 12.795sec(infer)
# Epoch 84 tst: l 1.692 a 0.367 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.507sec
# Epoch 85 tr: l 1.705 a 0.363 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.983  lr 0.247884 30.603sec(train) 12.880sec(infer)
# Epoch 85 tst: l 1.674 a 0.375 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.508sec
# Epoch 86 tr: l 1.692 a 0.368 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.983  lr 0.247859 22.353sec(train) 12.832sec(infer)
# Epoch 86 tst: l 1.667 a 0.378 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.482sec
# Epoch 87 tr: l 1.691 a 0.371 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.247834 31.570sec(train) 12.808sec(infer)
# Epoch 87 tst: l 1.670 a 0.377 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.537sec
# Epoch 88 tr: l 1.682 a 0.376 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247810 31.497sec(train) 12.742sec(infer)
# Epoch 88 tst: l 1.653 a 0.385 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.550sec
# Epoch 89 tr: l 1.667 a 0.382 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.983  lr 0.247785 30.526sec(train) 12.761sec(infer)
# Epoch 89 tst: l 1.649 a 0.387 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.536sec
# Epoch 90 tr: l 1.641 a 0.394 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(24), np.int64(36)] cl_acc0.983  lr 0.247760 30.446sec(train) 12.774sec(infer)
# Epoch 90 tst: l 1.637 a 0.394 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.544sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 91 tr: l 1.648 a 0.388 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247735 30.168sec(train) 12.982sec(infer)
# Epoch 91 tst: l 1.646 a 0.393 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.532sec
# Epoch 92 tr: l 1.650 a 0.389 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247710 25.395sec(train) 12.809sec(infer)
# Epoch 92 tst: l 1.628 a 0.401 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.460sec
# Epoch 93 tr: l 1.637 a 0.396 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.967  lr 0.247686 22.426sec(train) 12.761sec(infer)
# Epoch 93 tst: l 1.615 a 0.407 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.398sec
# Epoch 94 tr: l 1.636 a 0.397 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247661 22.360sec(train) 12.800sec(infer)
# Epoch 94 tst: l 1.600 a 0.415 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.413sec
# Epoch 95 tr: l 1.630 a 0.400 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247636 22.395sec(train) 12.836sec(infer)
# Epoch 95 tst: l 1.592 a 0.420 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.559sec
# Epoch 96 tr: l 1.624 a 0.404 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247611 22.383sec(train) 12.804sec(infer)
# Epoch 96 tst: l 1.587 a 0.422 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 97 tr: l 1.608 a 0.410 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247587 22.371sec(train) 12.814sec(infer)
# Epoch 97 tst: l 1.587 a 0.423 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.528sec
# Epoch 98 tr: l 1.598 a 0.414 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247562 22.458sec(train) 12.785sec(infer)
# Epoch 98 tst: l 1.590 a 0.423 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.524sec
# Epoch 99 tr: l 1.576 a 0.424 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.247537 22.444sec(train) 12.732sec(infer)
# Epoch 99 tst: l 1.587 a 0.422 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 100 tr: l 1.601 a 0.418 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247512 30.993sec(train) 12.757sec(infer)
# Epoch 100 tst: l 1.583 a 0.425 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.456sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 101 tr: l 1.570 a 0.430 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247488 31.490sec(train) 12.754sec(infer)
# Epoch 101 tst: l 1.576 a 0.427 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.728sec
# Epoch 102 tr: l 1.589 a 0.423 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.247463 31.535sec(train) 12.797sec(infer)
# Epoch 102 tst: l 1.593 a 0.421 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.519sec
# Epoch 103 tr: l 1.549 a 0.436 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.247438 30.982sec(train) 12.840sec(infer)
# Epoch 103 tst: l 1.583 a 0.429 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.455sec
# Epoch 104 tr: l 1.563 a 0.431 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247413 30.108sec(train) 12.803sec(infer)
# Epoch 104 tst: l 1.595 a 0.428 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.416sec
# Epoch 105 tr: l 1.550 a 0.436 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.983  lr 0.247389 30.380sec(train) 12.956sec(infer)
# Epoch 105 tst: l 1.587 a 0.431 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 106 tr: l 1.574 a 0.436 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247364 30.556sec(train) 12.864sec(infer)
# Epoch 106 tst: l 1.569 a 0.437 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.508sec
# Epoch 107 tr: l 1.536 a 0.448 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247339 31.601sec(train) 12.838sec(infer)
# Epoch 107 tst: l 1.567 a 0.437 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.494sec
# Epoch 108 tr: l 1.549 a 0.442 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247314 31.594sec(train) 12.819sec(infer)
# Epoch 108 tst: l 1.554 a 0.441 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.466sec
# Epoch 109 tr: l 1.536 a 0.450 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247290 31.464sec(train) 12.791sec(infer)
# Epoch 109 tst: l 1.551 a 0.444 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.452sec
# Epoch 110 tr: l 1.522 a 0.453 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247265 31.469sec(train) 12.753sec(infer)
# Epoch 110 tst: l 1.540 a 0.449 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.531sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 111 tr: l 1.537 a 0.447 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.247240 31.617sec(train) 12.749sec(infer)
# Epoch 111 tst: l 1.522 a 0.457 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.486sec
# Epoch 112 tr: l 1.529 a 0.454 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247215 30.831sec(train) 13.114sec(infer)
# Epoch 112 tst: l 1.527 a 0.456 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.594sec
# Epoch 113 tr: l 1.497 a 0.468 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247191 30.064sec(train) 12.860sec(infer)
# Epoch 113 tst: l 1.528 a 0.457 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.595sec
# Epoch 114 tr: l 1.500 a 0.466 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247166 31.497sec(train) 12.814sec(infer)
# Epoch 114 tst: l 1.512 a 0.461 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.554sec
# Epoch 115 tr: l 1.495 a 0.465 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.247141 31.625sec(train) 12.790sec(infer)
# Epoch 115 tst: l 1.515 a 0.464 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.539sec
# Epoch 116 tr: l 1.501 a 0.468 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247117 31.609sec(train) 12.845sec(infer)
# Epoch 116 tst: l 1.512 a 0.465 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.511sec
# Epoch 117 tr: l 1.498 a 0.470 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.983  lr 0.247092 31.054sec(train) 12.840sec(infer)
# Epoch 117 tst: l 1.504 a 0.469 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.492sec
# Epoch 118 tr: l 1.492 a 0.473 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247067 31.471sec(train) 12.861sec(infer)
# Epoch 118 tst: l 1.501 a 0.471 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.534sec
# Epoch 119 tr: l 1.485 a 0.475 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247042 30.591sec(train) 12.861sec(infer)
# Epoch 119 tst: l 1.502 a 0.472 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.571sec
# Epoch 120 tr: l 1.496 a 0.475 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247018 31.448sec(train) 12.804sec(infer)
# Epoch 120 tst: l 1.510 a 0.470 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.487sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 121 tr: l 1.459 a 0.490 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246993 31.447sec(train) 12.820sec(infer)
# Epoch 121 tst: l 1.518 a 0.471 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.537sec
# Epoch 122 tr: l 1.467 a 0.487 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246968 31.527sec(train) 12.783sec(infer)
# Epoch 122 tst: l 1.521 a 0.473 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.488sec
# Epoch 123 tr: l 1.495 a 0.482 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.983  lr 0.246944 31.743sec(train) 12.798sec(infer)
# Epoch 123 tst: l 1.504 a 0.481 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.564sec
# Epoch 124 tr: l 1.441 a 0.495 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.246919 31.597sec(train) 12.845sec(infer)
# Epoch 124 tst: l 1.496 a 0.484 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.660sec
# Epoch 125 tr: l 1.421 a 0.503 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.246894 28.210sec(train) 12.853sec(infer)
# Epoch 125 tst: l 1.483 a 0.489 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.675sec
# Epoch 126 tr: l 1.454 a 0.498 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.983  lr 0.246870 29.819sec(train) 12.876sec(infer)
# Epoch 126 tst: l 1.484 a 0.490 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.525sec
# Epoch 127 tr: l 1.437 a 0.502 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246845 29.619sec(train) 12.794sec(infer)
# Epoch 127 tst: l 1.507 a 0.487 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.507sec
# Epoch 128 tr: l 1.457 a 0.497 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(24), np.int64(36)] cl_acc0.983  lr 0.246820 30.208sec(train) 12.819sec(infer)
# Epoch 128 tst: l 1.510 a 0.489 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.515sec
# Epoch 129 tr: l 1.410 a 0.516 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246796 30.453sec(train) 12.822sec(infer)
# Epoch 129 tst: l 1.493 a 0.490 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.548sec
# Epoch 130 tr: l 1.461 a 0.504 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.983  lr 0.246771 30.527sec(train) 12.792sec(infer)
# Epoch 130 tst: l 1.494 a 0.493 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.532sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 131 tr: l 1.411 a 0.514 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246746 31.422sec(train) 12.827sec(infer)
# Epoch 131 tst: l 1.486 a 0.497 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.517sec
# Epoch 132 tr: l 1.401 a 0.518 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246722 31.446sec(train) 12.743sec(infer)
# Epoch 132 tst: l 1.480 a 0.500 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.466sec
# Epoch 133 tr: l 1.428 a 0.517 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246697 30.891sec(train) 13.008sec(infer)
# Epoch 133 tst: l 1.498 a 0.498 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.498sec
# Epoch 134 tr: l 1.365 a 0.536 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246672 30.472sec(train) 12.790sec(infer)
# Epoch 134 tst: l 1.502 a 0.499 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.495sec
# Epoch 135 tr: l 1.400 a 0.529 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.246648 30.482sec(train) 12.824sec(infer)
# Epoch 135 tst: l 1.499 a 0.501 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.534sec
# Epoch 136 tr: l 1.443 a 0.517 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.246623 30.385sec(train) 12.859sec(infer)
# Epoch 136 tst: l 1.486 a 0.504 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.504sec
# Epoch 137 tr: l 1.357 a 0.543 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246598 30.371sec(train) 12.771sec(infer)
# Epoch 137 tst: l 1.469 a 0.508 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.516sec
# Epoch 138 tr: l 1.381 a 0.535 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246574 30.624sec(train) 12.855sec(infer)
# Epoch 138 tst: l 1.475 a 0.510 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.491sec
# Epoch 139 tr: l 1.392 a 0.530 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246549 30.560sec(train) 12.845sec(infer)
# Epoch 139 tst: l 1.473 a 0.511 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.538sec
# Epoch 140 tr: l 1.361 a 0.541 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246524 30.547sec(train) 12.788sec(infer)
# Epoch 140 tst: l 1.469 a 0.512 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.505sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 141 tr: l 1.355 a 0.541 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246500 30.475sec(train) 12.767sec(infer)
# Epoch 141 tst: l 1.453 a 0.518 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# Epoch 142 tr: l 1.343 a 0.554 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.246475 30.372sec(train) 12.799sec(infer)
# Epoch 142 tst: l 1.460 a 0.518 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.511sec
# Epoch 143 tr: l 1.354 a 0.547 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246450 30.594sec(train) 12.784sec(infer)
# Epoch 143 tst: l 1.441 a 0.522 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.482sec
# Epoch 144 tr: l 1.358 a 0.552 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246426 30.639sec(train) 12.763sec(infer)
# Epoch 144 tst: l 1.444 a 0.523 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.503sec
# Epoch 145 tr: l 1.347 a 0.546 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246401 30.069sec(train) 12.767sec(infer)
# Epoch 145 tst: l 1.435 a 0.525 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 146 tr: l 1.312 a 0.561 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246376 28.773sec(train) 12.825sec(infer)
# Epoch 146 tst: l 1.440 a 0.526 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.490sec
# Epoch 147 tr: l 1.348 a 0.557 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.246352 30.846sec(train) 12.802sec(infer)
# Epoch 147 tst: l 1.441 a 0.526 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.481sec
# Epoch 148 tr: l 1.285 a 0.572 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246327 31.552sec(train) 12.850sec(infer)
# Epoch 148 tst: l 1.450 a 0.526 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 149 tr: l 1.342 a 0.553 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246302 30.950sec(train) 12.795sec(infer)
# Epoch 149 tst: l 1.452 a 0.529 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.457sec
# Epoch 150 tr: l 1.311 a 0.563 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246278 31.528sec(train) 12.867sec(infer)
# Epoch 150 tst: l 1.437 a 0.533 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.534sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 151 tr: l 1.298 a 0.570 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246253 31.532sec(train) 12.822sec(infer)
# Epoch 151 tst: l 1.440 a 0.535 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.681sec
# Epoch 152 tr: l 1.337 a 0.559 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246229 29.687sec(train) 12.849sec(infer)
# Epoch 152 tst: l 1.426 a 0.539 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.453sec
# Epoch 153 tr: l 1.308 a 0.565 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.983  lr 0.246204 31.570sec(train) 12.799sec(infer)
# Epoch 153 tst: l 1.450 a 0.536 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.472sec
# Epoch 154 tr: l 1.292 a 0.573 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246179 31.580sec(train) 12.796sec(infer)
# Epoch 154 tst: l 1.448 a 0.537 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.672sec
# Epoch 155 tr: l 1.288 a 0.578 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246155 31.614sec(train) 12.811sec(infer)
# Epoch 155 tst: l 1.427 a 0.542 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.493sec
# Epoch 156 tr: l 1.323 a 0.569 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246130 31.572sec(train) 12.797sec(infer)
# Epoch 156 tst: l 1.425 a 0.541 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.484sec
# Epoch 157 tr: l 1.287 a 0.578 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246105 31.526sec(train) 12.820sec(infer)
# Epoch 157 tst: l 1.421 a 0.544 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.629sec
# Epoch 158 tr: l 1.295 a 0.572 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246081 30.557sec(train) 12.830sec(infer)
# Epoch 158 tst: l 1.393 a 0.551 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.478sec
# Epoch 159 tr: l 1.251 a 0.586 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246056 30.518sec(train) 12.802sec(infer)
# Epoch 159 tst: l 1.394 a 0.551 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.522sec
# Epoch 160 tr: l 1.275 a 0.575 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246032 30.466sec(train) 12.782sec(infer)
# Epoch 160 tst: l 1.391 a 0.552 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.476sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 161 tr: l 1.296 a 0.575 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246007 30.853sec(train) 12.934sec(infer)
# Epoch 161 tst: l 1.401 a 0.552 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.508sec
# ...
# Epoch 546 tr: l 0.792 a 0.739 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023672 24.013sec(train) 13.236sec(infer)
# Epoch 546 tst: l 0.930 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.684sec
# Epoch 547 tr: l 0.785 a 0.738 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023669 22.869sec(train) 12.680sec(infer)
# Epoch 547 tst: l 0.929 a 0.708 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.549sec
# Epoch 548 tr: l 0.772 a 0.742 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023667 22.761sec(train) 12.664sec(infer)
# Epoch 548 tst: l 0.932 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.507sec
# Epoch 549 tr: l 0.817 a 0.728 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023664 22.892sec(train) 12.680sec(infer)
# Epoch 549 tst: l 0.934 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.408sec
# Epoch 550 tr: l 0.791 a 0.737 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023662 22.457sec(train) 12.713sec(infer)
# Epoch 550 tst: l 0.943 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.421sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 551 tr: l 0.774 a 0.741 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023660 22.361sec(train) 12.742sec(infer)
# Epoch 551 tst: l 0.933 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.464sec
# Epoch 552 tr: l 0.791 a 0.739 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023657 25.070sec(train) 12.770sec(infer)
# Epoch 552 tst: l 0.940 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.499sec
# Epoch 553 tr: l 0.764 a 0.748 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023655 30.741sec(train) 12.676sec(infer)
# Epoch 553 tst: l 0.935 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.493sec
# Epoch 554 tr: l 0.804 a 0.734 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023653 26.503sec(train) 12.699sec(infer)
# Epoch 554 tst: l 0.931 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.502sec
# Epoch 555 tr: l 0.780 a 0.742 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023650 30.656sec(train) 12.698sec(infer)
# Epoch 555 tst: l 0.930 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.453sec
# Epoch 556 tr: l 0.797 a 0.733 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023648 29.753sec(train) 12.728sec(infer)
# Epoch 556 tst: l 0.925 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.626sec
# Epoch 557 tr: l 0.786 a 0.738 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023646 26.891sec(train) 12.921sec(infer)
# Epoch 557 tst: l 0.922 a 0.708 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.742sec
# Epoch 558 tr: l 0.807 a 0.732 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.023643 27.994sec(train) 12.815sec(infer)
# Epoch 558 tst: l 0.930 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.729sec
# Epoch 559 tr: l 0.779 a 0.743 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023641 29.069sec(train) 12.940sec(infer)
# Epoch 559 tst: l 0.929 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.653sec
# Epoch 560 tr: l 0.798 a 0.735 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023638 27.446sec(train) 12.789sec(infer)
# Epoch 560 tst: l 0.923 a 0.708 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.842sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 561 tr: l 0.789 a 0.738 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023636 26.644sec(train) 12.980sec(infer)
# Epoch 561 tst: l 0.923 a 0.708 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.869sec
# Epoch 562 tr: l 0.807 a 0.731 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023634 28.289sec(train) 12.967sec(infer)
# Epoch 562 tst: l 0.928 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.905sec
# Epoch 563 tr: l 0.777 a 0.745 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023631 27.781sec(train) 12.854sec(infer)
# Epoch 563 tst: l 0.932 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.544sec
# Epoch 564 tr: l 0.775 a 0.744 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.023629 26.685sec(train) 12.757sec(infer)
# Epoch 564 tst: l 0.924 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.662sec
# Epoch 565 tr: l 0.789 a 0.738 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023627 26.012sec(train) 12.903sec(infer)
# Epoch 565 tst: l 0.920 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.621sec
# Epoch 566 tr: l 0.772 a 0.744 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023624 26.994sec(train) 12.875sec(infer)
# Epoch 566 tst: l 0.927 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.567sec
# Epoch 567 tr: l 0.779 a 0.741 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023622 25.831sec(train) 12.764sec(infer)
# Epoch 567 tst: l 0.931 a 0.703 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.661sec
# Epoch 568 tr: l 0.795 a 0.737 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023620 26.650sec(train) 12.827sec(infer)
# Epoch 568 tst: l 0.927 a 0.703 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.568sec
# Epoch 569 tr: l 0.768 a 0.745 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023617 26.513sec(train) 12.788sec(infer)
# Epoch 569 tst: l 0.934 a 0.703 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.576sec
# Epoch 570 tr: l 0.789 a 0.737 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023615 27.661sec(train) 12.901sec(infer)
# Epoch 570 tst: l 0.933 a 0.702 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.833sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 571 tr: l 0.794 a 0.738 clct[np.int64(35), np.int64(25)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.023612 28.903sec(train) 12.964sec(infer)
# Epoch 571 tst: l 0.933 a 0.702 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.731sec
# Epoch 572 tr: l 0.812 a 0.733 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023610 26.515sec(train) 12.840sec(infer)
# Epoch 572 tst: l 0.926 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.739sec
# Epoch 573 tr: l 0.788 a 0.738 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.023608 28.395sec(train) 12.985sec(infer)
# Epoch 573 tst: l 0.927 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.937sec
# Epoch 574 tr: l 0.810 a 0.729 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023605 28.823sec(train) 12.849sec(infer)
# Epoch 574 tst: l 0.920 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.711sec
# Epoch 575 tr: l 0.806 a 0.734 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023603 27.421sec(train) 12.842sec(infer)
# Epoch 575 tst: l 0.932 a 0.704 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.715sec
# Epoch 576 tr: l 0.767 a 0.743 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023601 28.207sec(train) 12.985sec(infer)
# Epoch 576 tst: l 0.935 a 0.703 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.766sec
# Epoch 577 tr: l 0.795 a 0.733 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023598 27.252sec(train) 12.834sec(infer)
# Epoch 577 tst: l 0.930 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.677sec
# Epoch 578 tr: l 0.770 a 0.742 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023596 27.469sec(train) 12.767sec(infer)
# Epoch 578 tst: l 0.925 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.699sec
# Epoch 579 tr: l 0.786 a 0.740 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023594 28.091sec(train) 12.768sec(infer)
# Epoch 579 tst: l 0.923 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.622sec
# Epoch 580 tr: l 0.787 a 0.736 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023591 27.150sec(train) 12.900sec(infer)
# Epoch 580 tst: l 0.929 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.776sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 581 tr: l 0.781 a 0.739 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023589 27.694sec(train) 12.678sec(infer)
# Epoch 581 tst: l 0.938 a 0.703 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.422sec
# Epoch 582 tr: l 0.773 a 0.742 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023586 25.156sec(train) 12.791sec(infer)
# Epoch 582 tst: l 0.938 a 0.702 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.717sec
# Epoch 583 tr: l 0.770 a 0.743 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.023584 28.143sec(train) 12.676sec(infer)
# Epoch 583 tst: l 0.929 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.464sec
# Epoch 584 tr: l 0.766 a 0.744 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023582 28.232sec(train) 12.902sec(infer)
# Epoch 584 tst: l 0.935 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.413sec
# Epoch 585 tr: l 0.761 a 0.750 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.023579 27.794sec(train) 12.697sec(infer)
# Epoch 585 tst: l 0.924 a 0.708 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.502sec
# Epoch 586 tr: l 0.769 a 0.745 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023577 27.360sec(train) 12.849sec(infer)
# Epoch 586 tst: l 0.920 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  10.140sec
# Epoch 587 tr: l 0.818 a 0.729 clct[np.int64(35), np.int64(25)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.023575 28.070sec(train) 13.098sec(infer)
# Epoch 587 tst: l 0.914 a 0.709 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.550sec
# Epoch 588 tr: l 0.759 a 0.746 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023572 28.305sec(train) 12.908sec(infer)
# Epoch 588 tst: l 0.924 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.691sec
# Epoch 589 tr: l 0.771 a 0.742 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023570 27.475sec(train) 12.714sec(infer)
# Epoch 589 tst: l 0.924 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.536sec
# Epoch 590 tr: l 0.796 a 0.737 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023568 26.669sec(train) 12.905sec(infer)
# Epoch 590 tst: l 0.923 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.556sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 591 tr: l 0.777 a 0.741 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023565 27.705sec(train) 12.735sec(infer)
# Epoch 591 tst: l 0.921 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.567sec
# Epoch 592 tr: l 0.765 a 0.745 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023563 28.051sec(train) 13.110sec(infer)
# Epoch 592 tst: l 0.918 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.653sec
# Epoch 593 tr: l 0.796 a 0.735 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023561 29.400sec(train) 12.694sec(infer)
# Epoch 593 tst: l 0.925 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.554sec
# Epoch 594 tr: l 0.758 a 0.748 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023558 27.779sec(train) 12.988sec(infer)
# Epoch 594 tst: l 0.929 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.740sec
# Epoch 595 tr: l 0.760 a 0.748 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023556 27.599sec(train) 12.975sec(infer)
# Epoch 595 tst: l 0.927 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.551sec
# Epoch 596 tr: l 0.774 a 0.739 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023553 27.152sec(train) 12.707sec(infer)
# Epoch 596 tst: l 0.928 a 0.705 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.516sec
# Epoch 597 tr: l 0.755 a 0.751 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023551 27.160sec(train) 12.690sec(infer)
# Epoch 597 tst: l 0.928 a 0.706 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.453sec
# Epoch 598 tr: l 0.784 a 0.738 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023549 26.469sec(train) 12.815sec(infer)
# Epoch 598 tst: l 0.926 a 0.707 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.533sec
# Epoch 599 tr: l 0.801 a 0.734 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023546 27.292sec(train) 12.761sec(infer)
# Epoch 599 tst: l 0.918 a 0.709 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.465sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# ---train cluster Ended in 8.79 hour (31636.884 sec)
# 100%|██████████| 170M/170M [00:07<00:00, 22.3MB/s]

# %%
___.display_outputs()
# Out:
# ---------------------------------DFCA-GI, lr: 0.25, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.3, 'h1': 128, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda:3
# num_data: 50000
# num_data: 10000
# finding good initializer from train data
# Epoch -1 tr: l 2.302 a 0.108 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.733  12.835sec
# found good initializer
# Epoch -1 tr: l 2.302 a 0.103 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.700  12.617sec
# Epoch -1 tst: l 2.302 a 0.108 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.369sec
# Epoch 0 tr: l 2.263 a 0.134 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.783  lr 0.250000 31.445sec(train) 12.587sec(infer)
# Epoch 0 tst: l 2.257 a 0.146 clct[np.int64(24), np.int64(16)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.600  9.398sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 2.205 a 0.176 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.750  lr 0.249975 30.089sec(train) 12.647sec(infer)
# Epoch 1 tst: l 2.225 a 0.171 clct[np.int64(25), np.int64(15)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.675  9.419sec
# Epoch 2 tr: l 2.163 a 0.190 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.750  lr 0.249950 30.228sec(train) 12.616sec(infer)
# Epoch 2 tst: l 2.162 a 0.207 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.825  9.459sec
# Epoch 3 tr: l 2.140 a 0.214 clct[np.int64(17), np.int64(43)] clct_ans[np.int64(39), np.int64(21)] cl_acc0.667  lr 0.249925 30.241sec(train) 12.584sec(infer)
# Epoch 3 tst: l 2.130 a 0.222 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.825  9.404sec
# Epoch 4 tr: l 2.099 a 0.234 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.800  lr 0.249900 29.941sec(train) 12.624sec(infer)
# Epoch 4 tst: l 2.102 a 0.241 clct[np.int64(16), np.int64(24)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.750  9.400sec
# Epoch 5 tr: l 2.065 a 0.256 clct[np.int64(21), np.int64(39)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.850  lr 0.249875 30.229sec(train) 12.586sec(infer)
# Epoch 5 tst: l 2.076 a 0.258 clct[np.int64(17), np.int64(23)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.775  9.397sec
# Epoch 6 tr: l 2.036 a 0.256 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(28), np.int64(32)] cl_acc0.850  lr 0.249850 30.027sec(train) 12.582sec(infer)
# Epoch 6 tst: l 2.030 a 0.271 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.875  9.479sec
# Epoch 7 tr: l 1.995 a 0.279 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(23), np.int64(37)] cl_acc0.917  lr 0.249825 30.455sec(train) 12.855sec(infer)
# Epoch 7 tst: l 2.005 a 0.286 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.950  9.485sec
# Epoch 8 tr: l 1.989 a 0.274 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.900  lr 0.249800 30.415sec(train) 12.589sec(infer)
# Epoch 8 tst: l 1.985 a 0.296 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.950  9.433sec
# Epoch 9 tr: l 1.956 a 0.304 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.983  lr 0.249775 30.239sec(train) 12.625sec(infer)
# Epoch 9 tst: l 1.966 a 0.305 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.451sec
# Epoch 10 tr: l 1.920 a 0.310 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(27), np.int64(33)] cl_acc0.900  lr 0.249750 30.248sec(train) 12.571sec(infer)
# Epoch 10 tst: l 1.937 a 0.311 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.406sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 1.931 a 0.309 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.933  lr 0.249725 30.178sec(train) 12.555sec(infer)
# Epoch 11 tst: l 1.924 a 0.319 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.441sec
# Epoch 12 tr: l 1.855 a 0.339 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(32), np.int64(28)] cl_acc0.967  lr 0.249700 30.157sec(train) 12.594sec(infer)
# Epoch 12 tst: l 1.886 a 0.333 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.459sec
# Epoch 13 tr: l 1.846 a 0.346 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc0.967  lr 0.249675 30.262sec(train) 12.617sec(infer)
# Epoch 13 tst: l 1.832 a 0.347 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.445sec
# Epoch 14 tr: l 1.820 a 0.347 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.967  lr 0.249650 29.996sec(train) 12.564sec(infer)
# Epoch 14 tst: l 1.811 a 0.354 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.457sec
# Epoch 15 tr: l 1.795 a 0.364 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.983  lr 0.249625 29.983sec(train) 12.523sec(infer)
# Epoch 15 tst: l 1.813 a 0.356 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.425sec
# Epoch 16 tr: l 1.783 a 0.361 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.967  lr 0.249600 29.938sec(train) 12.561sec(infer)
# Epoch 16 tst: l 1.798 a 0.358 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.480sec
# Epoch 17 tr: l 1.795 a 0.361 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.249575 30.216sec(train) 12.551sec(infer)
# Epoch 17 tst: l 1.766 a 0.375 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.463sec
# Epoch 18 tr: l 1.757 a 0.370 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.249550 30.336sec(train) 12.533sec(infer)
# Epoch 18 tst: l 1.744 a 0.382 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.432sec
# Epoch 19 tr: l 1.738 a 0.376 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(31), np.int64(29)] cl_acc0.983  lr 0.249525 30.256sec(train) 12.679sec(infer)
# Epoch 19 tst: l 1.715 a 0.393 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 20 tr: l 1.716 a 0.386 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.249500 30.020sec(train) 12.553sec(infer)
# Epoch 20 tst: l 1.715 a 0.392 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.457sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 1.694 a 0.391 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.983  lr 0.249476 29.950sec(train) 12.540sec(infer)
# Epoch 21 tst: l 1.691 a 0.400 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.400sec
# Epoch 22 tr: l 1.694 a 0.393 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.249451 29.987sec(train) 12.528sec(infer)
# Epoch 22 tst: l 1.691 a 0.399 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.409sec
# Epoch 23 tr: l 1.641 a 0.412 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.249426 29.927sec(train) 12.543sec(infer)
# Epoch 23 tst: l 1.656 a 0.407 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.471sec
# Epoch 24 tr: l 1.645 a 0.411 clct[np.int64(23), np.int64(37)] clct_ans[np.int64(37), np.int64(23)] cl_acc1.000  lr 0.249401 29.993sec(train) 12.555sec(infer)
# Epoch 24 tst: l 1.660 a 0.409 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.437sec
# Epoch 25 tr: l 1.614 a 0.425 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(29), np.int64(31)] cl_acc0.983  lr 0.249376 29.925sec(train) 12.527sec(infer)
# Epoch 25 tst: l 1.651 a 0.412 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.415sec
# Epoch 26 tr: l 1.639 a 0.417 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.249351 30.077sec(train) 12.563sec(infer)
# Epoch 26 tst: l 1.630 a 0.419 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.472sec
# Epoch 27 tr: l 1.601 a 0.423 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.249326 30.041sec(train) 12.508sec(infer)
# Epoch 27 tst: l 1.625 a 0.419 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.370sec
# Epoch 28 tr: l 1.579 a 0.436 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.249301 29.912sec(train) 12.735sec(infer)
# Epoch 28 tst: l 1.601 a 0.430 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.446sec
# Epoch 29 tr: l 1.577 a 0.436 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(30), np.int64(30)] cl_acc0.983  lr 0.249276 30.170sec(train) 12.588sec(infer)
# Epoch 29 tst: l 1.605 a 0.433 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.517sec
# Epoch 30 tr: l 1.560 a 0.444 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.249251 30.019sec(train) 12.573sec(infer)
# Epoch 30 tst: l 1.612 a 0.434 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.449sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 1.563 a 0.444 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(36), np.int64(24)] cl_acc1.000  lr 0.249226 30.021sec(train) 12.586sec(infer)
# Epoch 31 tst: l 1.616 a 0.434 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.452sec
# Epoch 32 tr: l 1.540 a 0.455 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.249201 30.064sec(train) 12.545sec(infer)
# Epoch 32 tst: l 1.584 a 0.442 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.414sec
# Epoch 33 tr: l 1.519 a 0.466 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.249176 30.174sec(train) 12.566sec(infer)
# Epoch 33 tst: l 1.594 a 0.441 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.425sec
# Epoch 34 tr: l 1.535 a 0.461 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.249151 30.159sec(train) 12.506sec(infer)
# Epoch 34 tst: l 1.593 a 0.445 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.444sec
# Epoch 35 tr: l 1.500 a 0.469 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.249126 30.415sec(train) 12.612sec(infer)
# Epoch 35 tst: l 1.579 a 0.451 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.517sec
# Epoch 36 tr: l 1.491 a 0.474 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.249102 30.782sec(train) 12.587sec(infer)
# Epoch 36 tst: l 1.567 a 0.454 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.439sec
# Epoch 37 tr: l 1.500 a 0.475 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.249077 30.601sec(train) 12.579sec(infer)
# Epoch 37 tst: l 1.565 a 0.457 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.431sec
# Epoch 38 tr: l 1.501 a 0.472 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.249052 30.606sec(train) 12.594sec(infer)
# Epoch 38 tst: l 1.535 a 0.466 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.448sec
# Epoch 39 tr: l 1.464 a 0.487 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.249027 30.732sec(train) 12.560sec(infer)
# Epoch 39 tst: l 1.538 a 0.466 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.438sec
# Epoch 40 tr: l 1.468 a 0.490 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.249002 30.770sec(train) 12.519sec(infer)
# Epoch 40 tst: l 1.546 a 0.470 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.434sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 41 tr: l 1.439 a 0.500 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.248977 30.378sec(train) 12.514sec(infer)
# Epoch 41 tst: l 1.539 a 0.474 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.422sec
# Epoch 42 tr: l 1.459 a 0.494 clct[np.int64(35), np.int64(25)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.248952 29.858sec(train) 12.537sec(infer)
# Epoch 42 tst: l 1.512 a 0.481 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.465sec
# Epoch 43 tr: l 1.446 a 0.509 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.248927 30.037sec(train) 12.499sec(infer)
# Epoch 43 tst: l 1.525 a 0.480 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.387sec
# Epoch 44 tr: l 1.415 a 0.519 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.248902 30.512sec(train) 12.503sec(infer)
# Epoch 44 tst: l 1.513 a 0.484 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.413sec
# Epoch 45 tr: l 1.415 a 0.511 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.248877 30.876sec(train) 12.560sec(infer)
# Epoch 45 tst: l 1.485 a 0.494 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.475sec
# Epoch 46 tr: l 1.392 a 0.522 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.248853 30.678sec(train) 12.553sec(infer)
# Epoch 46 tst: l 1.487 a 0.496 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.455sec
# Epoch 47 tr: l 1.396 a 0.522 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.248828 29.708sec(train) 12.564sec(infer)
# Epoch 47 tst: l 1.490 a 0.498 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.418sec
# Epoch 48 tr: l 1.411 a 0.521 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(34), np.int64(26)] cl_acc0.967  lr 0.248803 29.789sec(train) 12.626sec(infer)
# Epoch 48 tst: l 1.488 a 0.500 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.418sec
# Epoch 49 tr: l 1.371 a 0.530 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.248778 31.237sec(train) 13.520sec(infer)
# Epoch 49 tst: l 1.459 a 0.508 clct[np.int64(21), np.int64(19)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  9.701sec
# Epoch 50 tr: l 1.354 a 0.539 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.248753 31.440sec(train) 12.989sec(infer)
# Epoch 50 tst: l 1.488 a 0.506 clct[np.int64(22), np.int64(18)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.950  9.654sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 51 tr: l 1.330 a 0.547 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.248728 31.032sec(train) 12.826sec(infer)
# Epoch 51 tst: l 1.479 a 0.511 clct[np.int64(22), np.int64(18)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.950  9.514sec
# Epoch 52 tr: l 1.343 a 0.547 clct[np.int64(35), np.int64(25)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.248703 30.269sec(train) 12.713sec(infer)
# Epoch 52 tst: l 1.477 a 0.515 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 53 tr: l 1.302 a 0.562 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.248678 29.994sec(train) 12.661sec(infer)
# Epoch 53 tst: l 1.461 a 0.521 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.445sec
# Epoch 54 tr: l 1.310 a 0.560 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.248654 29.531sec(train) 12.610sec(infer)
# Epoch 54 tst: l 1.480 a 0.516 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.504sec
# Epoch 55 tr: l 1.260 a 0.574 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.248629 30.617sec(train) 12.633sec(infer)
# Epoch 55 tst: l 1.485 a 0.517 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.462sec
# Epoch 56 tr: l 1.279 a 0.571 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.248604 31.077sec(train) 12.623sec(infer)
# Epoch 56 tst: l 1.473 a 0.521 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.528sec
# Epoch 57 tr: l 1.279 a 0.569 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.248579 30.733sec(train) 12.735sec(infer)
# Epoch 57 tst: l 1.461 a 0.524 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.512sec
# Epoch 58 tr: l 1.265 a 0.578 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.248554 30.597sec(train) 12.656sec(infer)
# Epoch 58 tst: l 1.432 a 0.531 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.473sec
# Epoch 59 tr: l 1.258 a 0.581 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.248529 30.512sec(train) 12.599sec(infer)
# Epoch 59 tst: l 1.444 a 0.527 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.493sec
# Epoch 60 tr: l 1.271 a 0.580 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248504 30.643sec(train) 12.656sec(infer)
# Epoch 60 tst: l 1.448 a 0.529 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.492sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 61 tr: l 1.288 a 0.569 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.248480 30.034sec(train) 12.633sec(infer)
# Epoch 61 tst: l 1.445 a 0.530 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.448sec
# Epoch 62 tr: l 1.246 a 0.588 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.248455 30.569sec(train) 12.614sec(infer)
# Epoch 62 tst: l 1.453 a 0.531 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.471sec
# Epoch 63 tr: l 1.271 a 0.575 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(36), np.int64(24)] cl_acc1.000  lr 0.248430 30.395sec(train) 12.565sec(infer)
# Epoch 63 tst: l 1.420 a 0.538 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.619sec
# Epoch 64 tr: l 1.256 a 0.581 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248405 31.086sec(train) 12.650sec(infer)
# Epoch 64 tst: l 1.386 a 0.546 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.542sec
# Epoch 65 tr: l 1.238 a 0.585 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248380 31.281sec(train) 12.608sec(infer)
# Epoch 65 tst: l 1.391 a 0.546 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# Epoch 66 tr: l 1.231 a 0.591 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.248355 31.213sec(train) 12.643sec(infer)
# Epoch 66 tst: l 1.400 a 0.545 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.501sec
# Epoch 67 tr: l 1.203 a 0.596 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.248331 31.126sec(train) 12.692sec(infer)
# Epoch 67 tst: l 1.384 a 0.548 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.541sec
# Epoch 68 tr: l 1.218 a 0.593 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.248306 31.069sec(train) 12.625sec(infer)
# Epoch 68 tst: l 1.391 a 0.548 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 69 tr: l 1.254 a 0.581 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.248281 31.170sec(train) 12.698sec(infer)
# Epoch 69 tst: l 1.392 a 0.548 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.536sec
# Epoch 70 tr: l 1.211 a 0.592 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.248256 30.876sec(train) 12.636sec(infer)
# Epoch 70 tst: l 1.376 a 0.553 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.805sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 71 tr: l 1.249 a 0.583 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.248231 30.604sec(train) 12.650sec(infer)
# Epoch 71 tst: l 1.377 a 0.553 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.558sec
# Epoch 72 tr: l 1.201 a 0.599 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.248206 30.504sec(train) 12.613sec(infer)
# Epoch 72 tst: l 1.378 a 0.554 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.479sec
# Epoch 73 tr: l 1.184 a 0.604 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(36), np.int64(24)] cl_acc1.000  lr 0.248182 30.369sec(train) 12.636sec(infer)
# Epoch 73 tst: l 1.363 a 0.559 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# Epoch 74 tr: l 1.185 a 0.608 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.248157 30.490sec(train) 12.660sec(infer)
# Epoch 74 tst: l 1.364 a 0.558 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.513sec
# Epoch 75 tr: l 1.182 a 0.605 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.248132 29.491sec(train) 12.588sec(infer)
# Epoch 75 tst: l 1.377 a 0.556 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.537sec
# Epoch 76 tr: l 1.192 a 0.600 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.248107 30.243sec(train) 12.834sec(infer)
# Epoch 76 tst: l 1.358 a 0.560 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.516sec
# Epoch 77 tr: l 1.205 a 0.595 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248082 30.446sec(train) 12.720sec(infer)
# Epoch 77 tst: l 1.365 a 0.559 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.542sec
# Epoch 78 tr: l 1.174 a 0.614 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.248057 30.477sec(train) 12.747sec(infer)
# Epoch 78 tst: l 1.367 a 0.560 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.432sec
# Epoch 79 tr: l 1.168 a 0.610 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.248033 30.344sec(train) 12.741sec(infer)
# Epoch 79 tst: l 1.365 a 0.561 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.385sec
# Epoch 80 tr: l 1.147 a 0.619 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.248008 30.547sec(train) 12.603sec(infer)
# Epoch 80 tst: l 1.357 a 0.563 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 81 tr: l 1.175 a 0.606 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247983 30.666sec(train) 12.604sec(infer)
# Epoch 81 tst: l 1.339 a 0.567 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.478sec
# Epoch 82 tr: l 1.194 a 0.604 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247958 30.348sec(train) 12.555sec(infer)
# Epoch 82 tst: l 1.351 a 0.563 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.464sec
# Epoch 83 tr: l 1.150 a 0.617 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247933 30.399sec(train) 12.723sec(infer)
# Epoch 83 tst: l 1.345 a 0.564 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.476sec
# Epoch 84 tr: l 1.170 a 0.608 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247909 30.517sec(train) 12.650sec(infer)
# Epoch 84 tst: l 1.338 a 0.566 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.367sec
# Epoch 85 tr: l 1.161 a 0.619 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247884 29.822sec(train) 12.631sec(infer)
# Epoch 85 tst: l 1.351 a 0.567 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.416sec
# Epoch 86 tr: l 1.147 a 0.621 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247859 30.586sec(train) 12.711sec(infer)
# Epoch 86 tst: l 1.323 a 0.570 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.480sec
# Epoch 87 tr: l 1.125 a 0.627 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.247834 30.508sec(train) 12.631sec(infer)
# Epoch 87 tst: l 1.322 a 0.571 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.423sec
# Epoch 88 tr: l 1.117 a 0.626 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247810 30.410sec(train) 12.619sec(infer)
# Epoch 88 tst: l 1.332 a 0.571 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.491sec
# Epoch 89 tr: l 1.136 a 0.630 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247785 30.742sec(train) 12.590sec(infer)
# Epoch 89 tst: l 1.332 a 0.572 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.363sec
# Epoch 90 tr: l 1.144 a 0.619 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.247760 31.183sec(train) 12.617sec(infer)
# Epoch 90 tst: l 1.315 a 0.575 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.368sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 91 tr: l 1.107 a 0.630 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247735 30.935sec(train) 12.587sec(infer)
# Epoch 91 tst: l 1.306 a 0.577 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.679sec
# Epoch 92 tr: l 1.152 a 0.613 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247710 30.971sec(train) 12.570sec(infer)
# Epoch 92 tst: l 1.305 a 0.577 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.461sec
# Epoch 93 tr: l 1.126 a 0.622 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247686 29.463sec(train) 12.632sec(infer)
# Epoch 93 tst: l 1.303 a 0.577 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.383sec
# Epoch 94 tr: l 1.122 a 0.626 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247661 31.260sec(train) 12.593sec(infer)
# Epoch 94 tst: l 1.307 a 0.576 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.438sec
# Epoch 95 tr: l 1.123 a 0.624 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247636 31.033sec(train) 12.621sec(infer)
# Epoch 95 tst: l 1.295 a 0.578 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.456sec
# Epoch 96 tr: l 1.146 a 0.618 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247611 31.113sec(train) 12.601sec(infer)
# Epoch 96 tst: l 1.279 a 0.581 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.448sec
# Epoch 97 tr: l 1.152 a 0.617 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247587 31.164sec(train) 12.596sec(infer)
# Epoch 97 tst: l 1.280 a 0.581 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.419sec
# Epoch 98 tr: l 1.123 a 0.625 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247562 31.116sec(train) 12.623sec(infer)
# Epoch 98 tst: l 1.284 a 0.582 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.437sec
# Epoch 99 tr: l 1.106 a 0.634 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.247537 30.656sec(train) 12.658sec(infer)
# Epoch 99 tst: l 1.282 a 0.582 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.660sec
# Epoch 100 tr: l 1.129 a 0.626 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247512 30.378sec(train) 12.615sec(infer)
# Epoch 100 tst: l 1.298 a 0.581 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.451sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 101 tr: l 1.100 a 0.631 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247488 30.903sec(train) 12.599sec(infer)
# Epoch 101 tst: l 1.302 a 0.578 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.472sec
# Epoch 102 tr: l 1.099 a 0.637 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.247463 31.444sec(train) 12.641sec(infer)
# Epoch 102 tst: l 1.301 a 0.579 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# Epoch 103 tr: l 1.079 a 0.634 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.247438 31.151sec(train) 12.608sec(infer)
# Epoch 103 tst: l 1.309 a 0.580 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.413sec
# Epoch 104 tr: l 1.114 a 0.626 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247413 31.251sec(train) 12.559sec(infer)
# Epoch 104 tst: l 1.319 a 0.579 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.465sec
# Epoch 105 tr: l 1.118 a 0.626 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.247389 30.402sec(train) 12.591sec(infer)
# Epoch 105 tst: l 1.296 a 0.583 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.481sec
# Epoch 106 tr: l 1.084 a 0.644 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247364 29.938sec(train) 12.772sec(infer)
# Epoch 106 tst: l 1.289 a 0.584 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.555sec
# Epoch 107 tr: l 1.081 a 0.638 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247339 29.014sec(train) 12.661sec(infer)
# Epoch 107 tst: l 1.269 a 0.585 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.473sec
# Epoch 108 tr: l 1.069 a 0.645 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247314 30.485sec(train) 12.638sec(infer)
# Epoch 108 tst: l 1.297 a 0.582 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.439sec
# Epoch 109 tr: l 1.131 a 0.626 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247290 30.576sec(train) 12.627sec(infer)
# Epoch 109 tst: l 1.276 a 0.586 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.371sec
# Epoch 110 tr: l 1.057 a 0.649 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247265 30.420sec(train) 12.614sec(infer)
# Epoch 110 tst: l 1.280 a 0.588 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.410sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 111 tr: l 1.078 a 0.642 clct[np.int64(22), np.int64(38)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.247240 30.496sec(train) 12.564sec(infer)
# Epoch 111 tst: l 1.266 a 0.590 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.507sec
# Epoch 112 tr: l 1.088 a 0.637 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.247215 30.664sec(train) 12.844sec(infer)
# Epoch 112 tst: l 1.274 a 0.588 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.774sec
# Epoch 113 tr: l 1.071 a 0.647 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.247191 30.471sec(train) 12.899sec(infer)
# Epoch 113 tst: l 1.276 a 0.588 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.628sec
# Epoch 114 tr: l 1.058 a 0.645 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247166 25.591sec(train) 12.644sec(infer)
# Epoch 114 tst: l 1.259 a 0.591 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.456sec
# Epoch 115 tr: l 1.072 a 0.645 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.247141 31.025sec(train) 12.704sec(infer)
# Epoch 115 tst: l 1.267 a 0.589 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.360sec
# Epoch 116 tr: l 1.060 a 0.644 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.247117 31.248sec(train) 12.624sec(infer)
# Epoch 116 tst: l 1.247 a 0.594 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.475sec
# Epoch 117 tr: l 1.064 a 0.647 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.247092 31.145sec(train) 12.623sec(infer)
# Epoch 117 tst: l 1.243 a 0.597 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.454sec
# Epoch 118 tr: l 1.082 a 0.638 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247067 31.158sec(train) 12.597sec(infer)
# Epoch 118 tst: l 1.245 a 0.594 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.464sec
# Epoch 119 tr: l 1.062 a 0.647 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.247042 28.681sec(train) 12.652sec(infer)
# Epoch 119 tst: l 1.259 a 0.593 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.388sec
# Epoch 120 tr: l 1.077 a 0.642 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.247018 31.164sec(train) 12.587sec(infer)
# Epoch 120 tst: l 1.242 a 0.595 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.403sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 121 tr: l 1.057 a 0.645 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246993 31.103sec(train) 12.621sec(infer)
# Epoch 121 tst: l 1.241 a 0.595 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.426sec
# Epoch 122 tr: l 1.072 a 0.645 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246968 31.126sec(train) 12.646sec(infer)
# Epoch 122 tst: l 1.232 a 0.599 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.457sec
# Epoch 123 tr: l 1.061 a 0.646 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246944 31.373sec(train) 12.630sec(infer)
# Epoch 123 tst: l 1.211 a 0.601 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.486sec
# Epoch 124 tr: l 1.075 a 0.640 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.246919 31.147sec(train) 12.608sec(infer)
# Epoch 124 tst: l 1.223 a 0.599 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.447sec
# Epoch 125 tr: l 1.049 a 0.645 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.246894 29.866sec(train) 12.554sec(infer)
# Epoch 125 tst: l 1.239 a 0.597 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.420sec
# Epoch 126 tr: l 1.081 a 0.641 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246870 27.076sec(train) 12.728sec(infer)
# Epoch 126 tst: l 1.228 a 0.600 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.726sec
# Epoch 127 tr: l 1.044 a 0.648 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246845 29.846sec(train) 12.800sec(infer)
# Epoch 127 tst: l 1.221 a 0.601 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.574sec
# Epoch 128 tr: l 1.046 a 0.645 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.246820 31.235sec(train) 12.665sec(infer)
# Epoch 128 tst: l 1.210 a 0.602 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.472sec
# Epoch 129 tr: l 1.014 a 0.660 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246796 31.237sec(train) 12.658sec(infer)
# Epoch 129 tst: l 1.204 a 0.603 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.493sec
# Epoch 130 tr: l 1.064 a 0.641 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246771 30.943sec(train) 12.702sec(infer)
# Epoch 130 tst: l 1.190 a 0.607 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.419sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l 1.064 a 0.645 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246746 30.558sec(train) 12.672sec(infer)
# Epoch 131 tst: l 1.210 a 0.604 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.435sec
# Epoch 132 tr: l 1.054 a 0.648 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246722 30.535sec(train) 12.630sec(infer)
# Epoch 132 tst: l 1.209 a 0.604 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.447sec
# Epoch 133 tr: l 1.067 a 0.642 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246697 30.406sec(train) 12.673sec(infer)
# Epoch 133 tst: l 1.210 a 0.603 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.691sec
# Epoch 134 tr: l 1.033 a 0.655 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246672 31.228sec(train) 12.628sec(infer)
# Epoch 134 tst: l 1.216 a 0.603 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.476sec
# Epoch 135 tr: l 1.049 a 0.650 clct[np.int64(36), np.int64(24)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.246648 31.175sec(train) 12.622sec(infer)
# Epoch 135 tst: l 1.227 a 0.602 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.481sec
# Epoch 136 tr: l 1.065 a 0.645 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.246623 28.617sec(train) 12.626sec(infer)
# Epoch 136 tst: l 1.236 a 0.600 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.547sec
# Epoch 137 tr: l 1.046 a 0.648 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246598 31.219sec(train) 12.602sec(infer)
# Epoch 137 tst: l 1.229 a 0.601 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.523sec
# Epoch 138 tr: l 1.042 a 0.651 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246574 31.193sec(train) 12.649sec(infer)
# Epoch 138 tst: l 1.215 a 0.603 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.508sec
# Epoch 139 tr: l 1.025 a 0.655 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246549 31.127sec(train) 12.613sec(infer)
# Epoch 139 tst: l 1.216 a 0.605 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.438sec
# Epoch 140 tr: l 1.047 a 0.646 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246524 31.106sec(train) 12.636sec(infer)
# Epoch 140 tst: l 1.204 a 0.606 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.468sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l 1.066 a 0.643 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246500 31.175sec(train) 12.635sec(infer)
# Epoch 141 tst: l 1.203 a 0.606 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.469sec
# Epoch 142 tr: l 1.015 a 0.659 clct[np.int64(37), np.int64(23)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.246475 31.040sec(train) 12.588sec(infer)
# Epoch 142 tst: l 1.199 a 0.608 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.481sec
# Epoch 143 tr: l 1.035 a 0.647 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246450 31.109sec(train) 12.687sec(infer)
# Epoch 143 tst: l 1.193 a 0.608 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.482sec
# Epoch 144 tr: l 1.064 a 0.644 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246426 31.202sec(train) 12.805sec(infer)
# Epoch 144 tst: l 1.192 a 0.609 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.464sec
# Epoch 145 tr: l 1.020 a 0.662 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246401 31.061sec(train) 12.636sec(infer)
# Epoch 145 tst: l 1.188 a 0.610 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.422sec
# Epoch 146 tr: l 1.000 a 0.664 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246376 31.206sec(train) 12.766sec(infer)
# Epoch 146 tst: l 1.193 a 0.609 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.496sec
# Epoch 147 tr: l 1.021 a 0.658 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.246352 30.636sec(train) 12.724sec(infer)
# Epoch 147 tst: l 1.193 a 0.608 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.421sec
# Epoch 148 tr: l 1.045 a 0.651 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246327 30.625sec(train) 12.685sec(infer)
# Epoch 148 tst: l 1.185 a 0.610 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.466sec
# Epoch 149 tr: l 1.032 a 0.652 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246302 30.468sec(train) 12.605sec(infer)
# Epoch 149 tst: l 1.186 a 0.611 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.446sec
# Epoch 150 tr: l 1.041 a 0.649 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246278 30.732sec(train) 12.600sec(infer)
# Epoch 150 tst: l 1.187 a 0.613 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.461sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l 0.982 a 0.673 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.246253 30.562sec(train) 12.666sec(infer)
# Epoch 151 tst: l 1.188 a 0.613 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.399sec
# Epoch 152 tr: l 1.017 a 0.658 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246229 30.976sec(train) 12.712sec(infer)
# Epoch 152 tst: l 1.189 a 0.614 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.521sec
# Epoch 153 tr: l 1.012 a 0.659 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.246204 31.237sec(train) 12.669sec(infer)
# Epoch 153 tst: l 1.211 a 0.610 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.458sec
# Epoch 154 tr: l 1.030 a 0.655 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246179 31.084sec(train) 12.643sec(infer)
# Epoch 154 tst: l 1.201 a 0.613 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.640sec
# Epoch 155 tr: l 0.993 a 0.666 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.246155 31.220sec(train) 12.633sec(infer)
# Epoch 155 tst: l 1.187 a 0.615 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.477sec
# Epoch 156 tr: l 1.009 a 0.662 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.246130 31.333sec(train) 12.603sec(infer)
# Epoch 156 tst: l 1.181 a 0.617 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.460sec
# Epoch 157 tr: l 0.992 a 0.665 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.246105 31.233sec(train) 12.641sec(infer)
# Epoch 157 tst: l 1.181 a 0.616 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.474sec
# Epoch 158 tr: l 1.022 a 0.658 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.246081 31.210sec(train) 12.656sec(infer)
# Epoch 158 tst: l 1.180 a 0.616 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.448sec
# Epoch 159 tr: l 1.026 a 0.655 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.246056 31.100sec(train) 12.625sec(infer)
# Epoch 159 tst: l 1.188 a 0.614 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.442sec
# Epoch 160 tr: l 1.030 a 0.655 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.246032 31.118sec(train) 12.599sec(infer)
# Epoch 160 tst: l 1.193 a 0.612 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.449sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l 0.992 a 0.668 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.246007 30.920sec(train) 12.652sec(infer)
# ...
# Epoch 546 tr: l 0.763 a 0.746 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023672 30.542sec(train) 12.525sec(infer)
# Epoch 546 tst: l 0.911 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.383sec
# Epoch 547 tr: l 0.738 a 0.752 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023669 30.500sec(train) 12.479sec(infer)
# Epoch 547 tst: l 0.914 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.473sec
# Epoch 548 tr: l 0.727 a 0.756 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023667 30.637sec(train) 12.534sec(infer)
# Epoch 548 tst: l 0.916 a 0.710 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.616sec
# Epoch 549 tr: l 0.760 a 0.746 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023664 30.479sec(train) 12.477sec(infer)
# Epoch 549 tst: l 0.908 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.484sec
# Epoch 550 tr: l 0.741 a 0.751 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023662 31.013sec(train) 12.526sec(infer)
# Epoch 550 tst: l 0.906 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.445sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 551 tr: l 0.739 a 0.751 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023660 30.565sec(train) 12.580sec(infer)
# Epoch 551 tst: l 0.909 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.498sec
# Epoch 552 tr: l 0.764 a 0.743 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023657 30.121sec(train) 12.558sec(infer)
# Epoch 552 tst: l 0.915 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.497sec
# Epoch 553 tr: l 0.741 a 0.752 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023655 30.613sec(train) 12.526sec(infer)
# Epoch 553 tst: l 0.908 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.420sec
# Epoch 554 tr: l 0.749 a 0.748 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023653 30.755sec(train) 12.614sec(infer)
# Epoch 554 tst: l 0.905 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.454sec
# Epoch 555 tr: l 0.765 a 0.743 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023650 30.543sec(train) 12.514sec(infer)
# Epoch 555 tst: l 0.910 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.415sec
# Epoch 556 tr: l 0.765 a 0.745 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023648 25.179sec(train) 12.489sec(infer)
# Epoch 556 tst: l 0.909 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.616sec
# Epoch 557 tr: l 0.744 a 0.749 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023646 30.212sec(train) 12.485sec(infer)
# Epoch 557 tst: l 0.904 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.491sec
# Epoch 558 tr: l 0.769 a 0.743 clct[np.int64(23), np.int64(37)] clct_ans[np.int64(23), np.int64(37)] cl_acc1.000  lr 0.023643 30.348sec(train) 12.488sec(infer)
# Epoch 558 tst: l 0.906 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.488sec
# Epoch 559 tr: l 0.747 a 0.750 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023641 30.145sec(train) 12.491sec(infer)
# Epoch 559 tst: l 0.901 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.578sec
# Epoch 560 tr: l 0.760 a 0.746 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023638 24.668sec(train) 12.484sec(infer)
# Epoch 560 tst: l 0.901 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.674sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 561 tr: l 0.786 a 0.736 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023636 25.791sec(train) 12.536sec(infer)
# Epoch 561 tst: l 0.900 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.502sec
# Epoch 562 tr: l 0.769 a 0.743 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023634 30.210sec(train) 13.565sec(infer)
# Epoch 562 tst: l 0.901 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  10.516sec
# Epoch 563 tr: l 0.758 a 0.744 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023631 31.024sec(train) 14.979sec(infer)
# Epoch 563 tst: l 0.895 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  11.292sec
# Epoch 564 tr: l 0.767 a 0.745 clct[np.int64(38), np.int64(22)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.023629 31.841sec(train) 14.618sec(infer)
# Epoch 564 tst: l 0.898 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  11.038sec
# Epoch 565 tr: l 0.758 a 0.747 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023627 30.477sec(train) 14.274sec(infer)
# Epoch 565 tst: l 0.900 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  10.632sec
# Epoch 566 tr: l 0.743 a 0.750 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023624 32.018sec(train) 13.457sec(infer)
# Epoch 566 tst: l 0.902 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  10.125sec
# Epoch 567 tr: l 0.757 a 0.745 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023622 30.774sec(train) 12.717sec(infer)
# Epoch 567 tst: l 0.897 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.533sec
# Epoch 568 tr: l 0.748 a 0.751 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023620 30.503sec(train) 12.590sec(infer)
# Epoch 568 tst: l 0.896 a 0.715 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.450sec
# Epoch 569 tr: l 0.753 a 0.748 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023617 30.608sec(train) 12.526sec(infer)
# Epoch 569 tst: l 0.899 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.388sec
# Epoch 570 tr: l 0.777 a 0.740 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023615 30.682sec(train) 12.501sec(infer)
# Epoch 570 tst: l 0.903 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.566sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 571 tr: l 0.743 a 0.752 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.023612 30.725sec(train) 12.771sec(infer)
# Epoch 571 tst: l 0.901 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.547sec
# Epoch 572 tr: l 0.740 a 0.750 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023610 30.241sec(train) 12.553sec(infer)
# Epoch 572 tst: l 0.899 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.479sec
# Epoch 573 tr: l 0.738 a 0.750 clct[np.int64(38), np.int64(22)] clct_ans[np.int64(38), np.int64(22)] cl_acc1.000  lr 0.023608 30.636sec(train) 12.549sec(infer)
# Epoch 573 tst: l 0.897 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.647sec
# Epoch 574 tr: l 0.729 a 0.755 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023605 29.957sec(train) 12.524sec(infer)
# Epoch 574 tst: l 0.893 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.501sec
# Epoch 575 tr: l 0.747 a 0.750 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023603 30.337sec(train) 12.570sec(infer)
# Epoch 575 tst: l 0.896 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.638sec
# Epoch 576 tr: l 0.739 a 0.750 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023601 28.939sec(train) 12.656sec(infer)
# Epoch 576 tst: l 0.893 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.869sec
# Epoch 577 tr: l 0.764 a 0.744 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023598 27.448sec(train) 12.687sec(infer)
# Epoch 577 tst: l 0.895 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.664sec
# Epoch 578 tr: l 0.741 a 0.749 clct[np.int64(32), np.int64(28)] clct_ans[np.int64(32), np.int64(28)] cl_acc1.000  lr 0.023596 28.699sec(train) 12.811sec(infer)
# Epoch 578 tst: l 0.895 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.633sec
# Epoch 579 tr: l 0.760 a 0.742 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023594 26.082sec(train) 12.632sec(infer)
# Epoch 579 tst: l 0.900 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.633sec
# Epoch 580 tr: l 0.739 a 0.753 clct[np.int64(29), np.int64(31)] clct_ans[np.int64(29), np.int64(31)] cl_acc1.000  lr 0.023591 28.781sec(train) 12.748sec(infer)
# Epoch 580 tst: l 0.903 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.620sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 581 tr: l 0.739 a 0.753 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023589 28.305sec(train) 12.852sec(infer)
# Epoch 581 tst: l 0.897 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.536sec
# Epoch 582 tr: l 0.751 a 0.749 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023586 28.827sec(train) 12.814sec(infer)
# Epoch 582 tst: l 0.897 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.597sec
# Epoch 583 tr: l 0.729 a 0.750 clct[np.int64(24), np.int64(36)] clct_ans[np.int64(24), np.int64(36)] cl_acc1.000  lr 0.023584 27.977sec(train) 12.823sec(infer)
# Epoch 583 tst: l 0.901 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.673sec
# Epoch 584 tr: l 0.731 a 0.755 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023582 28.727sec(train) 12.907sec(infer)
# Epoch 584 tst: l 0.903 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.688sec
# Epoch 585 tr: l 0.729 a 0.752 clct[np.int64(35), np.int64(25)] clct_ans[np.int64(35), np.int64(25)] cl_acc1.000  lr 0.023579 26.979sec(train) 12.701sec(infer)
# Epoch 585 tst: l 0.904 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.783sec
# Epoch 586 tr: l 0.736 a 0.751 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023577 27.403sec(train) 12.824sec(infer)
# Epoch 586 tst: l 0.900 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.904sec
# Epoch 587 tr: l 0.744 a 0.751 clct[np.int64(25), np.int64(35)] clct_ans[np.int64(25), np.int64(35)] cl_acc1.000  lr 0.023575 25.285sec(train) 12.660sec(infer)
# Epoch 587 tst: l 0.907 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.649sec
# Epoch 588 tr: l 0.733 a 0.753 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023572 27.860sec(train) 12.898sec(infer)
# Epoch 588 tst: l 0.907 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.699sec
# Epoch 589 tr: l 0.723 a 0.758 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023570 27.434sec(train) 12.785sec(infer)
# Epoch 589 tst: l 0.912 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.611sec
# Epoch 590 tr: l 0.753 a 0.746 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023568 29.180sec(train) 12.837sec(infer)
# Epoch 590 tst: l 0.908 a 0.712 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.622sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 591 tr: l 0.734 a 0.755 clct[np.int64(28), np.int64(32)] clct_ans[np.int64(28), np.int64(32)] cl_acc1.000  lr 0.023565 28.382sec(train) 12.688sec(infer)
# Epoch 591 tst: l 0.912 a 0.710 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.664sec
# Epoch 592 tr: l 0.729 a 0.756 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023563 28.100sec(train) 12.796sec(infer)
# Epoch 592 tst: l 0.918 a 0.709 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.667sec
# Epoch 593 tr: l 0.710 a 0.763 clct[np.int64(27), np.int64(33)] clct_ans[np.int64(27), np.int64(33)] cl_acc1.000  lr 0.023561 27.078sec(train) 12.685sec(infer)
# Epoch 593 tst: l 0.909 a 0.711 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.712sec
# Epoch 594 tr: l 0.718 a 0.757 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023558 26.688sec(train) 12.807sec(infer)
# Epoch 594 tst: l 0.899 a 0.714 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.722sec
# Epoch 595 tr: l 0.730 a 0.755 clct[np.int64(33), np.int64(27)] clct_ans[np.int64(33), np.int64(27)] cl_acc1.000  lr 0.023556 27.235sec(train) 12.761sec(infer)
# Epoch 595 tst: l 0.900 a 0.713 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.610sec
# Epoch 596 tr: l 0.760 a 0.748 clct[np.int64(30), np.int64(30)] clct_ans[np.int64(30), np.int64(30)] cl_acc1.000  lr 0.023553 25.726sec(train) 12.836sec(infer)
# Epoch 596 tst: l 0.893 a 0.716 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.678sec
# Epoch 597 tr: l 0.716 a 0.759 clct[np.int64(34), np.int64(26)] clct_ans[np.int64(34), np.int64(26)] cl_acc1.000  lr 0.023551 27.918sec(train) 12.817sec(infer)
# Epoch 597 tst: l 0.889 a 0.716 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.739sec
# Epoch 598 tr: l 0.733 a 0.755 clct[np.int64(31), np.int64(29)] clct_ans[np.int64(31), np.int64(29)] cl_acc1.000  lr 0.023549 26.910sec(train) 12.806sec(infer)
# Epoch 598 tst: l 0.893 a 0.715 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.839sec
# Epoch 599 tr: l 0.748 a 0.750 clct[np.int64(26), np.int64(34)] clct_ans[np.int64(26), np.int64(34)] cl_acc1.000  lr 0.023546 27.985sec(train) 12.755sec(infer)
# Epoch 599 tst: l 0.892 a 0.715 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  9.694sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 8.80 hour (31683.691 sec)
# 100%|██████████| 170M/170M [00:07<00:00, 22.3MB/s]

# %% [markdown]
# ## Plots

# %%
r_ifca = {}
r_dfca_gi = {}
r_dfca_li = {}

r_ifca['test_loss'] = []
r_ifca['test_acc'] = []
r_ifca['cl_acc'] = []
r_ifca['train_loss'] = []
for i in range(len(learning_rates)):
    r_ifca['test_loss'].append(ifca[i][0])
    r_ifca['test_acc'].append(ifca[i][1])
    r_ifca['cl_acc'].append(ifca[i][2])
    r_ifca['train_loss'].append(ifca[i][3])

r_dfca_li['test_loss'] = []
r_dfca_li['test_acc'] = []
r_dfca_li['cl_acc'] = []
r_dfca_li['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_li['test_loss'].append(dfca_li[i][0])
    r_dfca_li['test_acc'].append(dfca_li[i][1])
    r_dfca_li['cl_acc'].append(dfca_li[i][2])
    r_dfca_li['train_loss'].append(dfca_li[i][3])

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
r_dfca_gi['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])
    r_dfca_gi['train_loss'].append(dfca_gi[i][3])


os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['train_loss'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['train_loss'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['train_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Train Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_loss'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_loss'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_acc'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_acc'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('test accuracy', fontsize=20)
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_acc.png'))

    plt.figure(figsize=(10,7))
    plt.ylim([0, 1.1])
    plt.plot(r_ifca['cl_acc'][l][:31], label='ifca', color='xkcd:azure', marker='o')
    plt.plot(r_dfca_li['cl_acc'][l][:31], label='dfca-li', color='red', marker='o')
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green', marker='o')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('cluster acc', fontsize=20)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.savefig(os.path.join('graphs', 'cluster_acc.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 10
#       8 r_ifca['train_loss'] = []
#       9 for i in range(len(learning_rates)):
# ---> 10     r_ifca['test_loss'].append(ifca[i][0])
#      11     r_ifca['test_acc'].append(ifca[i][1])
#      12     r_ifca['cl_acc'].append(ifca[i][2])
#
# IndexError: list index out of range
