# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import ifca_pn_go as IFCA
import numpy as np

from util import *

# %%
torch.cuda.empty_cache()

with open("config.json", "r") as read_file:
    config = json.load(read_file)

res_final = []

start_time = time.time()
config['data_seed'] = 13
config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = IFCA.TrainCIFARCluster(config, device)
exp.setup()
res = exp.run()
res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
del exp
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 400, 'm_test': 80, 'p': 2, 'n': 250, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.2, 'num_epochs': 300, 'batch_size': 50, 'tau': 5, 'lr': 0.2, 'data_seed': 12, 'train_seed': 12, 'project_dir': 'output'}
# Using device: cuda
# num_data: 50000
# Files already downloaded and verified
# num_data: 10000
# Files already downloaded and verified
# finding good initializer from train data
# Epoch -1 tr: l 2.300 a 0.129 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(34), np.int64(46)]  5.083sec
# found good initializer
# Epoch -1 tr: l 2.299 a 0.131 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(35), np.int64(45)]  5.167sec
# Epoch -1 tst: l 2.299 a 0.132 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(40), np.int64(40)]  2.214sec
# Epoch 0 tr: l 1.977 a 0.297 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.200000 6.459sec(train) 4.893sec(infer)
# Epoch 0 tst: l 1.895 a 0.358 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.241sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 1 tr: l 1.788 a 0.367 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.199900 6.420sec(train) 4.754sec(infer)
# Epoch 1 tst: l 1.628 a 0.427 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.184sec
# Epoch 2 tr: l 1.725 a 0.392 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.199800 6.400sec(train) 4.761sec(infer)
# Epoch 2 tst: l 1.517 a 0.460 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.202sec
# Epoch 3 tr: l 1.666 a 0.420 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.199700 6.443sec(train) 4.861sec(infer)
# Epoch 3 tst: l 1.450 a 0.487 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.435sec
# Epoch 4 tr: l 1.631 a 0.438 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.199600 6.445sec(train) 4.806sec(infer)
# Epoch 4 tst: l 1.410 a 0.504 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.243sec
# Epoch 5 tr: l 1.612 a 0.445 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.199500 6.390sec(train) 4.757sec(infer)
# Epoch 5 tst: l 1.382 a 0.514 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.259sec
# Epoch 6 tr: l 1.542 a 0.462 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.199401 6.566sec(train) 4.709sec(infer)
# Epoch 6 tst: l 1.341 a 0.527 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.212sec
# Epoch 7 tr: l 1.533 a 0.475 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.199301 6.603sec(train) 4.792sec(infer)
# Epoch 7 tst: l 1.329 a 0.534 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.322sec
# Epoch 8 tr: l 1.519 a 0.472 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.199201 6.713sec(train) 4.894sec(infer)
# Epoch 8 tst: l 1.300 a 0.545 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.216sec
# Epoch 9 tr: l 1.490 a 0.489 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.199102 6.554sec(train) 4.986sec(infer)
# Epoch 9 tst: l 1.293 a 0.548 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.511sec
# Epoch 10 tr: l 1.461 a 0.496 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.199002 7.311sec(train) 4.857sec(infer)
# Epoch 10 tst: l 1.273 a 0.555 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.267sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 11 tr: l 1.445 a 0.505 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.198903 6.539sec(train) 4.908sec(infer)
# Epoch 11 tst: l 1.253 a 0.565 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.275sec
# Epoch 12 tr: l 1.416 a 0.513 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.198803 6.817sec(train) 4.870sec(infer)
# Epoch 12 tst: l 1.240 a 0.566 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.278sec
# Epoch 13 tr: l 1.413 a 0.515 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.198704 6.714sec(train) 4.857sec(infer)
# Epoch 13 tst: l 1.231 a 0.573 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.300sec
# Epoch 14 tr: l 1.399 a 0.516 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.198605 6.437sec(train) 4.836sec(infer)
# Epoch 14 tst: l 1.218 a 0.578 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.345sec
# Epoch 15 tr: l 1.375 a 0.530 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.198505 6.779sec(train) 4.852sec(infer)
# Epoch 15 tst: l 1.199 a 0.587 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.264sec
# Epoch 16 tr: l 1.356 a 0.533 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.198406 7.341sec(train) 5.004sec(infer)
# Epoch 16 tst: l 1.191 a 0.588 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.303sec
# Epoch 17 tr: l 1.355 a 0.535 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.198307 6.821sec(train) 5.062sec(infer)
# Epoch 17 tst: l 1.180 a 0.593 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.415sec
# Epoch 18 tr: l 1.341 a 0.542 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.198208 6.678sec(train) 4.990sec(infer)
# Epoch 18 tst: l 1.167 a 0.600 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.331sec
# Epoch 19 tr: l 1.335 a 0.538 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.198109 6.684sec(train) 4.804sec(infer)
# Epoch 19 tst: l 1.162 a 0.603 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.213sec
# Epoch 20 tr: l 1.319 a 0.544 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.198009 6.472sec(train) 4.714sec(infer)
# Epoch 20 tst: l 1.156 a 0.602 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.231sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 21 tr: l 1.310 a 0.546 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.197910 6.743sec(train) 4.744sec(infer)
# Epoch 21 tst: l 1.144 a 0.606 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.237sec
# Epoch 22 tr: l 1.285 a 0.560 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.197812 6.401sec(train) 4.830sec(infer)
# Epoch 22 tst: l 1.139 a 0.608 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.311sec
# Epoch 23 tr: l 1.300 a 0.550 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.197713 7.044sec(train) 5.272sec(infer)
# Epoch 23 tst: l 1.129 a 0.615 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.455sec
# Epoch 24 tr: l 1.297 a 0.560 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.197614 7.045sec(train) 4.763sec(infer)
# Epoch 24 tst: l 1.119 a 0.618 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.204sec
# Epoch 25 tr: l 1.262 a 0.571 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.197515 6.459sec(train) 4.723sec(infer)
# Epoch 25 tst: l 1.113 a 0.622 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.162sec
# Epoch 26 tr: l 1.254 a 0.570 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.197416 6.463sec(train) 4.750sec(infer)
# Epoch 26 tst: l 1.109 a 0.620 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.244sec
# Epoch 27 tr: l 1.260 a 0.571 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.197317 6.531sec(train) 5.053sec(infer)
# Epoch 27 tst: l 1.101 a 0.623 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.154sec
# Epoch 28 tr: l 1.251 a 0.571 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.197219 6.645sec(train) 5.387sec(infer)
# Epoch 28 tst: l 1.096 a 0.625 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.362sec
# Epoch 29 tr: l 1.240 a 0.575 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.197120 7.138sec(train) 5.265sec(infer)
# Epoch 29 tst: l 1.090 a 0.626 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.364sec
# Epoch 30 tr: l 1.245 a 0.578 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.197022 6.745sec(train) 4.855sec(infer)
# Epoch 30 tst: l 1.084 a 0.628 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.197sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 31 tr: l 1.232 a 0.581 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.196923 6.608sec(train) 5.036sec(infer)
# Epoch 31 tst: l 1.075 a 0.632 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.535sec
# Epoch 32 tr: l 1.228 a 0.576 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196825 6.898sec(train) 5.023sec(infer)
# Epoch 32 tst: l 1.065 a 0.634 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.347sec
# Epoch 33 tr: l 1.237 a 0.579 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196726 6.976sec(train) 4.885sec(infer)
# Epoch 33 tst: l 1.060 a 0.637 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.415sec
# Epoch 34 tr: l 1.208 a 0.587 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.196628 6.994sec(train) 4.947sec(infer)
# Epoch 34 tst: l 1.057 a 0.635 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.323sec
# Epoch 35 tr: l 1.216 a 0.587 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.196530 7.058sec(train) 5.069sec(infer)
# Epoch 35 tst: l 1.051 a 0.638 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.337sec
# Epoch 36 tr: l 1.192 a 0.591 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.196431 6.930sec(train) 5.157sec(infer)
# Epoch 36 tst: l 1.049 a 0.638 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.471sec
# Epoch 37 tr: l 1.196 a 0.592 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.196333 6.848sec(train) 5.174sec(infer)
# Epoch 37 tst: l 1.040 a 0.642 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.282sec
# Epoch 38 tr: l 1.182 a 0.594 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.196235 6.552sec(train) 5.028sec(infer)
# Epoch 38 tst: l 1.042 a 0.645 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.213sec
# Epoch 39 tr: l 1.195 a 0.594 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196137 6.518sec(train) 5.029sec(infer)
# Epoch 39 tst: l 1.033 a 0.649 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.314sec
# Epoch 40 tr: l 1.167 a 0.602 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.196039 6.875sec(train) 4.916sec(infer)
# Epoch 40 tst: l 1.026 a 0.651 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.365sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 41 tr: l 1.166 a 0.600 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.195941 6.859sec(train) 4.928sec(infer)
# Epoch 41 tst: l 1.019 a 0.654 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.331sec
# Epoch 42 tr: l 1.167 a 0.603 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.195843 6.928sec(train) 5.019sec(infer)
# Epoch 42 tst: l 1.015 a 0.655 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.326sec
# Epoch 43 tr: l 1.144 a 0.605 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.195745 6.563sec(train) 5.116sec(infer)
# Epoch 43 tst: l 1.009 a 0.656 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.457sec
# Epoch 44 tr: l 1.162 a 0.609 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.195647 6.816sec(train) 5.021sec(infer)
# Epoch 44 tst: l 1.009 a 0.656 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.320sec
# Epoch 45 tr: l 1.159 a 0.607 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.195549 6.767sec(train) 5.083sec(infer)
# Epoch 45 tst: l 1.002 a 0.659 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.408sec
# Epoch 46 tr: l 1.149 a 0.610 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.195451 6.766sec(train) 4.940sec(infer)
# Epoch 46 tst: l 1.001 a 0.659 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.278sec
# Epoch 47 tr: l 1.144 a 0.609 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.195354 6.732sec(train) 4.985sec(infer)
# Epoch 47 tst: l 0.996 a 0.660 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.310sec
# Epoch 48 tr: l 1.137 a 0.614 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.195256 6.813sec(train) 5.032sec(infer)
# Epoch 48 tst: l 0.992 a 0.661 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.447sec
# Epoch 49 tr: l 1.138 a 0.614 clct[np.int64(32), np.int64(48)] clct_ans[np.int64(48), np.int64(32)]  lr 0.195158 6.571sec(train) 4.797sec(infer)
# Epoch 49 tst: l 0.991 a 0.662 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.218sec
# Epoch 50 tr: l 1.124 a 0.622 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019506 6.703sec(train) 4.889sec(infer)
# Epoch 50 tst: l 0.985 a 0.666 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.252sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 51 tr: l 1.124 a 0.627 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.019496 6.547sec(train) 4.886sec(infer)
# Epoch 51 tst: l 0.985 a 0.669 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.348sec
# Epoch 52 tr: l 1.143 a 0.623 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019487 6.694sec(train) 4.831sec(infer)
# Epoch 52 tst: l 0.985 a 0.671 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.343sec
# Epoch 53 tr: l 1.128 a 0.625 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019477 6.784sec(train) 4.919sec(infer)
# Epoch 53 tst: l 0.985 a 0.673 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.353sec
# Epoch 54 tr: l 1.125 a 0.630 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019467 6.625sec(train) 4.789sec(infer)
# Epoch 54 tst: l 0.986 a 0.674 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.304sec
# Epoch 55 tr: l 1.138 a 0.624 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019457 6.453sec(train) 4.879sec(infer)
# Epoch 55 tst: l 0.987 a 0.675 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.279sec
# Epoch 56 tr: l 1.132 a 0.627 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019448 6.759sec(train) 4.959sec(infer)
# Epoch 56 tst: l 0.987 a 0.678 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.532sec
# Epoch 57 tr: l 1.135 a 0.632 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.019438 6.738sec(train) 5.028sec(infer)
# Epoch 57 tst: l 0.988 a 0.679 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.372sec
# Epoch 58 tr: l 1.118 a 0.632 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019428 6.781sec(train) 4.865sec(infer)
# Epoch 58 tst: l 0.988 a 0.680 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.371sec
# Epoch 59 tr: l 1.133 a 0.634 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019418 6.927sec(train) 5.054sec(infer)
# Epoch 59 tst: l 0.987 a 0.680 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.361sec
# Epoch 60 tr: l 1.116 a 0.633 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.019409 6.620sec(train) 4.824sec(infer)
# Epoch 60 tst: l 0.989 a 0.681 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.355sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 61 tr: l 1.113 a 0.638 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019399 6.788sec(train) 5.012sec(infer)
# Epoch 61 tst: l 0.989 a 0.682 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.360sec
# Epoch 62 tr: l 1.148 a 0.630 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019389 6.800sec(train) 5.116sec(infer)
# Epoch 62 tst: l 0.989 a 0.683 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.271sec
# Epoch 63 tr: l 1.134 a 0.634 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019380 6.593sec(train) 4.624sec(infer)
# Epoch 63 tst: l 0.990 a 0.684 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.234sec
# Epoch 64 tr: l 1.126 a 0.638 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019370 6.307sec(train) 4.605sec(infer)
# Epoch 64 tst: l 0.990 a 0.685 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.219sec
# Epoch 65 tr: l 1.109 a 0.646 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019360 6.275sec(train) 4.636sec(infer)
# Epoch 65 tst: l 0.990 a 0.685 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.192sec
# Epoch 66 tr: l 1.095 a 0.646 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019351 6.351sec(train) 4.581sec(infer)
# Epoch 66 tst: l 0.990 a 0.685 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.155sec
# Epoch 67 tr: l 1.115 a 0.640 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019341 6.389sec(train) 4.623sec(infer)
# Epoch 67 tst: l 0.990 a 0.686 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.228sec
# Epoch 68 tr: l 1.112 a 0.643 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.019331 6.260sec(train) 4.617sec(infer)
# Epoch 68 tst: l 0.989 a 0.687 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.211sec
# Epoch 69 tr: l 1.097 a 0.647 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019322 6.363sec(train) 4.674sec(infer)
# Epoch 69 tst: l 0.989 a 0.688 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.234sec
# Epoch 70 tr: l 1.121 a 0.644 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019312 6.309sec(train) 4.657sec(infer)
# Epoch 70 tst: l 0.987 a 0.689 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.201sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 71 tr: l 1.128 a 0.646 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019302 6.349sec(train) 4.715sec(infer)
# Epoch 71 tst: l 0.986 a 0.689 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.277sec
# Epoch 72 tr: l 1.117 a 0.642 clct[np.int64(28), np.int64(52)] clct_ans[np.int64(52), np.int64(28)]  lr 0.019293 7.023sec(train) 4.993sec(infer)
# Epoch 72 tst: l 0.987 a 0.690 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.322sec
# Epoch 73 tr: l 1.098 a 0.648 clct[np.int64(50), np.int64(30)] clct_ans[np.int64(30), np.int64(50)]  lr 0.019283 6.736sec(train) 4.940sec(infer)
# Epoch 73 tst: l 0.988 a 0.689 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.348sec
# Epoch 74 tr: l 1.116 a 0.651 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019273 6.870sec(train) 4.952sec(infer)
# Epoch 74 tst: l 0.985 a 0.690 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.372sec
# Epoch 75 tr: l 1.109 a 0.644 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019264 6.841sec(train) 4.934sec(infer)
# Epoch 75 tst: l 0.985 a 0.690 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.285sec
# Epoch 76 tr: l 1.092 a 0.650 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.019254 6.917sec(train) 4.783sec(infer)
# Epoch 76 tst: l 0.984 a 0.692 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.218sec
# Epoch 77 tr: l 1.105 a 0.648 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.019244 6.264sec(train) 4.609sec(infer)
# Epoch 77 tst: l 0.986 a 0.691 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.191sec
# Epoch 78 tr: l 1.110 a 0.647 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019235 6.271sec(train) 4.621sec(infer)
# Epoch 78 tst: l 0.983 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.202sec
# Epoch 79 tr: l 1.097 a 0.653 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019225 6.403sec(train) 4.693sec(infer)
# Epoch 79 tst: l 0.983 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.181sec
# Epoch 80 tr: l 1.103 a 0.650 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019216 6.258sec(train) 4.785sec(infer)
# Epoch 80 tst: l 0.981 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.309sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 81 tr: l 1.110 a 0.646 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019206 6.755sec(train) 4.808sec(infer)
# Epoch 81 tst: l 0.981 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.270sec
# Epoch 82 tr: l 1.093 a 0.653 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019196 6.569sec(train) 4.890sec(infer)
# Epoch 82 tst: l 0.980 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.303sec
# Epoch 83 tr: l 1.096 a 0.652 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.019187 6.866sec(train) 4.921sec(infer)
# Epoch 83 tst: l 0.979 a 0.694 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.476sec
# Epoch 84 tr: l 1.086 a 0.652 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.019177 6.961sec(train) 4.726sec(infer)
# Epoch 84 tst: l 0.978 a 0.694 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.334sec
# Epoch 85 tr: l 1.094 a 0.653 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019168 6.802sec(train) 4.958sec(infer)
# Epoch 85 tst: l 0.976 a 0.695 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.327sec
# Epoch 86 tr: l 1.080 a 0.654 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019158 6.739sec(train) 4.820sec(infer)
# Epoch 86 tst: l 0.974 a 0.695 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.316sec
# Epoch 87 tr: l 1.081 a 0.655 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019148 6.767sec(train) 4.660sec(infer)
# Epoch 87 tst: l 0.974 a 0.695 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.212sec
# Epoch 88 tr: l 1.089 a 0.655 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019139 6.299sec(train) 4.611sec(infer)
# Epoch 88 tst: l 0.972 a 0.696 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.237sec
# Epoch 89 tr: l 1.082 a 0.653 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019129 6.301sec(train) 4.620sec(infer)
# Epoch 89 tst: l 0.973 a 0.698 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.211sec
# Epoch 90 tr: l 1.090 a 0.652 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019120 6.471sec(train) 4.718sec(infer)
# Epoch 90 tst: l 0.973 a 0.697 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.205sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 91 tr: l 1.081 a 0.657 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.019110 6.406sec(train) 4.707sec(infer)
# Epoch 91 tst: l 0.972 a 0.697 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.226sec
# Epoch 92 tr: l 1.086 a 0.658 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.019101 6.378sec(train) 4.666sec(infer)
# Epoch 92 tst: l 0.970 a 0.698 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.177sec
# Epoch 93 tr: l 1.069 a 0.658 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019091 6.508sec(train) 4.735sec(infer)
# Epoch 93 tst: l 0.970 a 0.698 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  2.200sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      16 exp = IFCA.TrainCIFARCluster(config, device)
#      17 exp.setup()
# ---> 18 res = exp.run()
#      19 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#      20 del exp
#
# File d:\GIT Repos\decentralized-ifca\cifar\notebooks\ifca_pn_copy.py:269, in TrainCIFARCluster.run(self)
#     266 result['lr'] = lr
#     268 t0 = time.time()
# --> 269 result['train'] = self.train(lr = lr)
#     270 t1 = time.time()
#     271 train_time = t1-t0
#
# File d:\GIT Repos\decentralized-ifca\cifar\notebooks\ifca_pn_copy.py:434, in TrainCIFARCluster.train(self, lr)
#     431 for m_i in participating_nodes:
#     432     if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')
# --> 434     (X, y) = self.load_data(m_i)
#     436     ds = TensorDataset(X, y)
#     437     dl = DataLoader(ds, batch_size=batch_size, shuffle=True)
#
# File d:\GIT Repos\decentralized-ifca\cifar\notebooks\ifca_pn_copy.py:625, in TrainCIFARCluster.load_data(self, m_i, train)
#     622     raise NotImplementedError("only p=1,2,4 supported")
#     624 if train:
# --> 625     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     626 else:
#     627     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File d:\GIT Repos\decentralized-ifca\cifar\notebooks\ifca_pn_copy.py:625, in <listcomp>(.0)
#     622     raise NotImplementedError("only p=1,2,4 supported")
#     624 if train:
# --> 625     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     626 else:
#     627     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File e:\anaconda\envs\dl-new\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File e:\anaconda\envs\dl-new\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File e:\anaconda\envs\dl-new\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File e:\anaconda\envs\dl-new\lib\site-packages\torchvision\transforms\transforms.py:1268, in ColorJitter.forward(self, img)
#    1260 def forward(self, img):
#    1261     """
#    1262     Args:
#    1263         img (PIL Image or Tensor): Input image.
#    (...)
#    1266         PIL Image or Tensor: Color jittered image.
#    1267     """
# -> 1268     fn_idx, brightness_factor, contrast_factor, saturation_factor, hue_factor = self.get_params(
#    1269         self.brightness, self.contrast, self.saturation, self.hue
#    1270     )
#    1272     for fn_id in fn_idx:
#    1273         if fn_id == 0 and brightness_factor is not None:
#
# File e:\anaconda\envs\dl-new\lib\site-packages\torchvision\transforms\transforms.py:1253, in ColorJitter.get_params(brightness, contrast, saturation, hue)
#    1235 """Get the parameters for the randomized transform to be applied on image.
#    1236
#    1237 Args:
#    (...)
#    1249     along with their random order.
#    1250 """
#    1251 fn_idx = torch.randperm(4)
# -> 1253 b = None if brightness is None else float(torch.empty(1).uniform_(brightness[0], brightness[1]))
#    1254 c = None if contrast is None else float(torch.empty(1).uniform_(contrast[0], contrast[1]))
#    1255 s = None if saturation is None else float(torch.empty(1).uniform_(saturation[0], saturation[1]))
#
# KeyboardInterrupt:
