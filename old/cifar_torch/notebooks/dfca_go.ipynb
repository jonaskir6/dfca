# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca_pn_go as DFCA
import numpy as np

from util import *
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
torch.cuda.empty_cache()

with open("config.json", "r") as read_file:
    config = json.load(read_file)

res_final = []

start_time = time.time()
config['data_seed'] = 13
config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = DFCA.TrainCIFARCluster(config, device)
exp.setup()
res = exp.run()
res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
del exp
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 400, 'm_test': 80, 'p': 2, 'n': 250, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.2, 'num_epochs': 300, 'batch_size': 50, 'tau': 5, 'lr': 0.2, 'data_seed': 12, 'train_seed': 12, 'project_dir': 'output'}
# Using device: cuda
# num_data: 50000
# Files already downloaded and verified
# num_data: 10000
# Files already downloaded and verified
# finding good initializer from train data
# Epoch -1 tr: l 2.300 a 0.129 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(34), np.int64(46)]  4.987sec
# found good initializer
# Epoch -1 tr: l 2.299 a 0.131 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(35), np.int64(45)]  4.845sec
# Epoch -1 tst: l 2.299 a 0.136 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(40), np.int64(40)]  6.241sec
# Epoch 0 tr: l 2.287 a 0.372 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.200000 6.564sec(train) 4.357sec(infer)
# Epoch 0 tst: l 2.107 a 0.421 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.166sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 1 tr: l 2.225 a 0.422 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.199900 6.441sec(train) 4.415sec(infer)
# Epoch 1 tst: l 2.028 a 0.490 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.044sec
# Epoch 2 tr: l 2.177 a 0.445 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.199800 6.480sec(train) 4.415sec(infer)
# Epoch 2 tst: l 1.961 a 0.515 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.307sec
# Epoch 3 tr: l 2.170 a 0.460 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.199700 6.747sec(train) 4.509sec(infer)
# Epoch 3 tst: l 1.993 a 0.519 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.356sec
# Epoch 4 tr: l 2.163 a 0.484 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.199600 6.610sec(train) 4.411sec(infer)
# Epoch 4 tst: l 1.964 a 0.549 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.325sec
# Epoch 5 tr: l 2.067 a 0.487 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.199500 6.713sec(train) 4.395sec(infer)
# Epoch 5 tst: l 1.829 a 0.561 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.310sec
# Epoch 6 tr: l 2.044 a 0.501 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.199401 6.593sec(train) 4.351sec(infer)
# Epoch 6 tst: l 1.888 a 0.567 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.230sec
# Epoch 7 tr: l 1.994 a 0.520 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.199301 6.485sec(train) 4.362sec(infer)
# Epoch 7 tst: l 1.840 a 0.577 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.459sec
# Epoch 8 tr: l 1.923 a 0.520 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.199201 6.660sec(train) 4.530sec(infer)
# Epoch 8 tst: l 1.783 a 0.585 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.090sec
# Epoch 9 tr: l 1.931 a 0.542 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.199102 6.813sec(train) 4.349sec(infer)
# Epoch 9 tst: l 1.838 a 0.597 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.878sec
# Epoch 10 tr: l 1.891 a 0.549 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.199002 6.599sec(train) 4.315sec(infer)
# Epoch 10 tst: l 1.769 a 0.606 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.378sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 11 tr: l 1.849 a 0.539 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.198903 6.940sec(train) 4.287sec(infer)
# Epoch 11 tst: l 1.650 a 0.609 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.020sec
# Epoch 12 tr: l 1.681 a 0.560 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.198803 7.099sec(train) 4.521sec(infer)
# Epoch 12 tst: l 1.619 a 0.617 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.195sec
# Epoch 13 tr: l 1.675 a 0.566 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.198704 6.717sec(train) 4.324sec(infer)
# Epoch 13 tst: l 1.614 a 0.620 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.927sec
# Epoch 14 tr: l 1.810 a 0.563 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.198605 6.629sec(train) 4.444sec(infer)
# Epoch 14 tst: l 1.698 a 0.623 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.116sec
# Epoch 15 tr: l 1.771 a 0.579 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.198505 6.509sec(train) 4.292sec(infer)
# Epoch 15 tst: l 1.639 a 0.634 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.032sec
# Epoch 16 tr: l 1.795 a 0.577 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.198406 6.660sec(train) 4.471sec(infer)
# Epoch 16 tst: l 1.667 a 0.638 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.151sec
# Epoch 17 tr: l 1.722 a 0.582 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.198307 6.620sec(train) 4.320sec(infer)
# Epoch 17 tst: l 1.625 a 0.642 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.029sec
# Epoch 18 tr: l 1.592 a 0.603 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.198208 6.655sec(train) 4.338sec(infer)
# Epoch 18 tst: l 1.529 a 0.655 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.083sec
# Epoch 19 tr: l 1.596 a 0.588 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.198109 6.702sec(train) 4.347sec(infer)
# Epoch 19 tst: l 1.480 a 0.650 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.955sec
# Epoch 20 tr: l 1.690 a 0.599 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.198009 6.526sec(train) 4.300sec(infer)
# Epoch 20 tst: l 1.575 a 0.655 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.935sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 21 tr: l 1.617 a 0.598 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.197910 6.461sec(train) 4.315sec(infer)
# Epoch 21 tst: l 1.537 a 0.652 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.995sec
# Epoch 22 tr: l 1.571 a 0.610 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.197812 6.885sec(train) 4.476sec(infer)
# Epoch 22 tst: l 1.543 a 0.666 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.033sec
# Epoch 23 tr: l 1.561 a 0.609 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.197713 6.451sec(train) 4.399sec(infer)
# Epoch 23 tst: l 1.460 a 0.665 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.013sec
# Epoch 24 tr: l 1.629 a 0.606 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.197614 6.711sec(train) 4.508sec(infer)
# Epoch 24 tst: l 1.544 a 0.667 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.265sec
# Epoch 25 tr: l 1.552 a 0.622 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.197515 6.930sec(train) 4.521sec(infer)
# Epoch 25 tst: l 1.532 a 0.669 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.136sec
# Epoch 26 tr: l 1.526 a 0.632 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.197416 7.023sec(train) 4.569sec(infer)
# Epoch 26 tst: l 1.474 a 0.683 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.479sec
# Epoch 27 tr: l 1.558 a 0.628 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.197317 6.590sec(train) 4.409sec(infer)
# Epoch 27 tst: l 1.471 a 0.679 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.299sec
# Epoch 28 tr: l 1.583 a 0.622 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.197219 6.621sec(train) 4.453sec(infer)
# Epoch 28 tst: l 1.541 a 0.673 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.301sec
# Epoch 29 tr: l 1.486 a 0.629 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.197120 6.573sec(train) 4.440sec(infer)
# Epoch 29 tst: l 1.406 a 0.682 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.408sec
# Epoch 30 tr: l 1.493 a 0.618 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.197022 6.689sec(train) 4.433sec(infer)
# Epoch 30 tst: l 1.424 a 0.671 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.358sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 31 tr: l 1.547 a 0.640 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.196923 6.633sec(train) 4.370sec(infer)
# Epoch 31 tst: l 1.470 a 0.691 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.264sec
# Epoch 32 tr: l 1.535 a 0.638 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196825 6.482sec(train) 4.391sec(infer)
# Epoch 32 tst: l 1.489 a 0.685 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.262sec
# Epoch 33 tr: l 1.422 a 0.632 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196726 6.564sec(train) 4.345sec(infer)
# Epoch 33 tst: l 1.376 a 0.686 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.193sec
# Epoch 34 tr: l 1.486 a 0.646 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.196628 6.479sec(train) 4.405sec(infer)
# Epoch 34 tst: l 1.429 a 0.694 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.369sec
# Epoch 35 tr: l 1.360 a 0.646 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.196530 7.242sec(train) 4.850sec(infer)
# Epoch 35 tst: l 1.347 a 0.692 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.786sec
# Epoch 36 tr: l 1.456 a 0.646 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.196431 6.726sec(train) 4.457sec(infer)
# Epoch 36 tst: l 1.422 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.394sec
# Epoch 37 tr: l 1.471 a 0.648 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.196333 6.758sec(train) 4.492sec(infer)
# Epoch 37 tst: l 1.411 a 0.699 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.321sec
# Epoch 38 tr: l 1.400 a 0.646 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.196235 6.760sec(train) 4.844sec(infer)
# Epoch 38 tst: l 1.356 a 0.693 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.610sec
# Epoch 39 tr: l 1.450 a 0.640 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.196137 6.770sec(train) 4.526sec(infer)
# Epoch 39 tst: l 1.387 a 0.695 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.249sec
# Epoch 40 tr: l 1.445 a 0.652 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.196039 6.934sec(train) 4.683sec(infer)
# Epoch 40 tst: l 1.374 a 0.707 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.999sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 41 tr: l 1.440 a 0.652 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.195941 6.657sec(train) 4.475sec(infer)
# Epoch 41 tst: l 1.427 a 0.701 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.395sec
# Epoch 42 tr: l 1.418 a 0.653 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.195843 6.891sec(train) 4.530sec(infer)
# Epoch 42 tst: l 1.386 a 0.706 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.273sec
# Epoch 43 tr: l 1.403 a 0.646 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.195745 6.707sec(train) 4.422sec(infer)
# Epoch 43 tst: l 1.351 a 0.699 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.446sec
# Epoch 44 tr: l 1.402 a 0.669 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.195647 6.625sec(train) 4.500sec(infer)
# Epoch 44 tst: l 1.401 a 0.711 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.301sec
# Epoch 45 tr: l 1.378 a 0.668 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.195549 6.680sec(train) 4.477sec(infer)
# Epoch 45 tst: l 1.355 a 0.711 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.342sec
# Epoch 46 tr: l 1.380 a 0.662 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.195451 6.988sec(train) 4.404sec(infer)
# Epoch 46 tst: l 1.323 a 0.710 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.264sec
# Epoch 47 tr: l 1.445 a 0.663 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.195354 6.583sec(train) 4.443sec(infer)
# Epoch 47 tst: l 1.371 a 0.715 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.414sec
# Epoch 48 tr: l 1.338 a 0.660 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.195256 6.652sec(train) 4.490sec(infer)
# Epoch 48 tst: l 1.280 a 0.713 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.241sec
# Epoch 49 tr: l 1.434 a 0.663 clct[np.int64(32), np.int64(48)] clct_ans[np.int64(48), np.int64(32)]  lr 0.195158 7.152sec(train) 4.412sec(infer)
# Epoch 49 tst: l 1.375 a 0.721 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.005sec
# Epoch 50 tr: l 0.910 a 0.710 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019506 6.623sec(train) 4.386sec(infer)
# Epoch 50 tst: l 0.880 a 0.741 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.212sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 51 tr: l 0.876 a 0.722 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.019496 6.801sec(train) 5.234sec(infer)
# Epoch 51 tst: l 0.818 a 0.754 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  7.085sec
# Epoch 52 tr: l 0.844 a 0.723 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019487 7.723sec(train) 4.958sec(infer)
# Epoch 52 tst: l 0.798 a 0.757 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.185sec
# Epoch 53 tr: l 0.833 a 0.723 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019477 6.926sec(train) 4.403sec(infer)
# Epoch 53 tst: l 0.771 a 0.757 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.315sec
# Epoch 54 tr: l 0.813 a 0.730 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019467 6.654sec(train) 4.565sec(infer)
# Epoch 54 tst: l 0.753 a 0.763 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.376sec
# Epoch 55 tr: l 0.816 a 0.733 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019457 6.637sec(train) 4.328sec(infer)
# Epoch 55 tst: l 0.767 a 0.766 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.135sec
# Epoch 56 tr: l 0.823 a 0.731 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019448 6.495sec(train) 4.322sec(infer)
# Epoch 56 tst: l 0.750 a 0.764 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.374sec
# Epoch 57 tr: l 0.816 a 0.729 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.019438 6.792sec(train) 4.433sec(infer)
# Epoch 57 tst: l 0.744 a 0.767 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.284sec
# Epoch 58 tr: l 0.791 a 0.733 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019428 6.843sec(train) 4.410sec(infer)
# Epoch 58 tst: l 0.737 a 0.766 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.049sec
# Epoch 59 tr: l 0.796 a 0.739 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019418 6.862sec(train) 4.415sec(infer)
# Epoch 59 tst: l 0.751 a 0.765 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.165sec
# Epoch 60 tr: l 0.791 a 0.737 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.019409 6.858sec(train) 4.390sec(infer)
# Epoch 60 tst: l 0.744 a 0.768 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.206sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 61 tr: l 0.785 a 0.736 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019399 6.941sec(train) 4.557sec(infer)
# Epoch 61 tst: l 0.744 a 0.764 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.157sec
# Epoch 62 tr: l 0.775 a 0.738 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019389 6.649sec(train) 4.486sec(infer)
# Epoch 62 tst: l 0.730 a 0.772 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.187sec
# Epoch 63 tr: l 0.769 a 0.741 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019380 7.004sec(train) 4.536sec(infer)
# Epoch 63 tst: l 0.736 a 0.769 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.865sec
# Epoch 64 tr: l 0.777 a 0.747 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019370 6.604sec(train) 4.349sec(infer)
# Epoch 64 tst: l 0.732 a 0.773 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.104sec
# Epoch 65 tr: l 0.777 a 0.740 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019360 6.484sec(train) 4.317sec(infer)
# Epoch 65 tst: l 0.746 a 0.770 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.159sec
# Epoch 66 tr: l 0.760 a 0.745 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019351 6.514sec(train) 4.318sec(infer)
# Epoch 66 tst: l 0.729 a 0.773 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.165sec
# Epoch 67 tr: l 0.761 a 0.752 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019341 6.605sec(train) 4.389sec(infer)
# Epoch 67 tst: l 0.734 a 0.773 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.422sec
# Epoch 68 tr: l 0.754 a 0.746 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.019331 6.661sec(train) 4.376sec(infer)
# Epoch 68 tst: l 0.726 a 0.775 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.245sec
# Epoch 69 tr: l 0.739 a 0.755 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019322 6.541sec(train) 4.348sec(infer)
# Epoch 69 tst: l 0.706 a 0.774 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.166sec
# Epoch 70 tr: l 0.744 a 0.744 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019312 6.501sec(train) 4.337sec(infer)
# Epoch 70 tst: l 0.711 a 0.775 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.113sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 71 tr: l 0.749 a 0.750 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019302 6.561sec(train) 4.321sec(infer)
# Epoch 71 tst: l 0.718 a 0.776 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.163sec
# Epoch 72 tr: l 0.740 a 0.752 clct[np.int64(28), np.int64(52)] clct_ans[np.int64(52), np.int64(28)]  lr 0.019293 6.568sec(train) 4.320sec(infer)
# Epoch 72 tst: l 0.701 a 0.777 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.091sec
# Epoch 73 tr: l 0.739 a 0.754 clct[np.int64(50), np.int64(30)] clct_ans[np.int64(30), np.int64(50)]  lr 0.019283 6.346sec(train) 4.293sec(infer)
# Epoch 73 tst: l 0.717 a 0.776 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.294sec
# Epoch 74 tr: l 0.750 a 0.753 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019273 6.626sec(train) 4.438sec(infer)
# Epoch 74 tst: l 0.727 a 0.775 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.160sec
# Epoch 75 tr: l 0.744 a 0.752 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019264 6.717sec(train) 4.578sec(infer)
# Epoch 75 tst: l 0.714 a 0.779 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.245sec
# Epoch 76 tr: l 0.711 a 0.759 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.019254 6.588sec(train) 4.369sec(infer)
# Epoch 76 tst: l 0.704 a 0.778 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.237sec
# Epoch 77 tr: l 0.744 a 0.754 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.019244 6.574sec(train) 4.416sec(infer)
# Epoch 77 tst: l 0.706 a 0.779 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.261sec
# Epoch 78 tr: l 0.727 a 0.761 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019235 6.623sec(train) 4.438sec(infer)
# Epoch 78 tst: l 0.717 a 0.777 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.155sec
# Epoch 79 tr: l 0.742 a 0.755 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019225 6.826sec(train) 4.621sec(infer)
# Epoch 79 tst: l 0.726 a 0.777 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.240sec
# Epoch 80 tr: l 0.719 a 0.760 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019216 6.845sec(train) 4.473sec(infer)
# Epoch 80 tst: l 0.697 a 0.780 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.151sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 81 tr: l 0.737 a 0.759 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.019206 6.595sec(train) 4.538sec(infer)
# Epoch 81 tst: l 0.719 a 0.782 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.208sec
# Epoch 82 tr: l 0.741 a 0.754 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019196 6.703sec(train) 4.399sec(infer)
# Epoch 82 tst: l 0.711 a 0.780 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.237sec
# Epoch 83 tr: l 0.720 a 0.761 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.019187 6.724sec(train) 4.483sec(infer)
# Epoch 83 tst: l 0.697 a 0.782 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.191sec
# Epoch 84 tr: l 0.716 a 0.763 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.019177 6.612sec(train) 4.399sec(infer)
# Epoch 84 tst: l 0.687 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.244sec
# Epoch 85 tr: l 0.726 a 0.761 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.019168 6.527sec(train) 4.463sec(infer)
# Epoch 85 tst: l 0.720 a 0.779 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.247sec
# Epoch 86 tr: l 0.720 a 0.760 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019158 6.665sec(train) 4.400sec(infer)
# Epoch 86 tst: l 0.706 a 0.784 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.189sec
# Epoch 87 tr: l 0.735 a 0.752 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019148 6.553sec(train) 4.435sec(infer)
# Epoch 87 tst: l 0.721 a 0.775 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.311sec
# Epoch 88 tr: l 0.712 a 0.766 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019139 6.540sec(train) 4.442sec(infer)
# Epoch 88 tst: l 0.701 a 0.788 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.212sec
# Epoch 89 tr: l 0.715 a 0.763 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.019129 6.566sec(train) 4.456sec(infer)
# Epoch 89 tst: l 0.704 a 0.780 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.234sec
# Epoch 90 tr: l 0.697 a 0.766 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019120 6.534sec(train) 4.344sec(infer)
# Epoch 90 tst: l 0.683 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.272sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 91 tr: l 0.695 a 0.767 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.019110 6.754sec(train) 4.508sec(infer)
# Epoch 91 tst: l 0.692 a 0.786 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.228sec
# Epoch 92 tr: l 0.735 a 0.760 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.019101 6.538sec(train) 4.357sec(infer)
# Epoch 92 tst: l 0.706 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.194sec
# Epoch 93 tr: l 0.694 a 0.765 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.019091 6.452sec(train) 4.313sec(infer)
# Epoch 93 tst: l 0.685 a 0.780 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.138sec
# Epoch 94 tr: l 0.707 a 0.764 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.019082 6.618sec(train) 4.320sec(infer)
# Epoch 94 tst: l 0.689 a 0.784 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.202sec
# Epoch 95 tr: l 0.699 a 0.763 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.019072 6.651sec(train) 4.445sec(infer)
# Epoch 95 tst: l 0.680 a 0.788 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.860sec
# Epoch 96 tr: l 0.710 a 0.764 clct[np.int64(31), np.int64(49)] clct_ans[np.int64(49), np.int64(31)]  lr 0.019062 6.590sec(train) 4.361sec(infer)
# Epoch 96 tst: l 0.704 a 0.782 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.251sec
# Epoch 97 tr: l 0.712 a 0.766 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.019053 6.582sec(train) 4.404sec(infer)
# Epoch 97 tst: l 0.709 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.298sec
# Epoch 98 tr: l 0.690 a 0.769 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.019043 6.576sec(train) 4.332sec(infer)
# Epoch 98 tst: l 0.698 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.175sec
# Epoch 99 tr: l 0.681 a 0.769 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.019034 6.471sec(train) 4.310sec(infer)
# Epoch 99 tst: l 0.678 a 0.784 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.178sec
# Epoch 100 tr: l 0.645 a 0.781 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.001902 6.421sec(train) 4.399sec(infer)
# Epoch 100 tst: l 0.643 a 0.789 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.257sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 101 tr: l 0.644 a 0.783 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001901 6.555sec(train) 4.338sec(infer)
# Epoch 101 tst: l 0.634 a 0.792 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.127sec
# Epoch 102 tr: l 0.632 a 0.783 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.001901 6.626sec(train) 4.443sec(infer)
# Epoch 102 tst: l 0.632 a 0.794 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.408sec
# Epoch 103 tr: l 0.638 a 0.784 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.001900 6.806sec(train) 4.571sec(infer)
# Epoch 103 tst: l 0.630 a 0.794 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.980sec
# Epoch 104 tr: l 0.629 a 0.785 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001899 6.748sec(train) 4.385sec(infer)
# Epoch 104 tst: l 0.630 a 0.794 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.203sec
# Epoch 105 tr: l 0.642 a 0.780 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.001898 6.649sec(train) 4.474sec(infer)
# Epoch 105 tst: l 0.626 a 0.795 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.375sec
# Epoch 106 tr: l 0.622 a 0.786 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.001897 6.669sec(train) 4.416sec(infer)
# Epoch 106 tst: l 0.623 a 0.795 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.384sec
# Epoch 107 tr: l 0.640 a 0.781 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.001896 6.696sec(train) 4.368sec(infer)
# Epoch 107 tst: l 0.618 a 0.796 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.272sec
# Epoch 108 tr: l 0.640 a 0.782 clct[np.int64(50), np.int64(30)] clct_ans[np.int64(30), np.int64(50)]  lr 0.001895 6.642sec(train) 4.511sec(infer)
# Epoch 108 tst: l 0.622 a 0.797 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.355sec
# Epoch 109 tr: l 0.618 a 0.788 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.001894 6.576sec(train) 4.663sec(infer)
# Epoch 109 tst: l 0.618 a 0.796 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.468sec
# Epoch 110 tr: l 0.629 a 0.785 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.001893 6.604sec(train) 4.470sec(infer)
# Epoch 110 tst: l 0.620 a 0.795 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.389sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 111 tr: l 0.618 a 0.789 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.001892 6.745sec(train) 4.448sec(infer)
# Epoch 111 tst: l 0.616 a 0.797 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.487sec
# Epoch 112 tr: l 0.618 a 0.789 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001891 6.745sec(train) 4.431sec(infer)
# Epoch 112 tst: l 0.616 a 0.797 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.390sec
# Epoch 113 tr: l 0.635 a 0.783 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.001890 6.742sec(train) 4.748sec(infer)
# Epoch 113 tst: l 0.612 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.391sec
# Epoch 114 tr: l 0.614 a 0.788 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001889 6.553sec(train) 4.371sec(infer)
# Epoch 114 tst: l 0.612 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.239sec
# Epoch 115 tr: l 0.641 a 0.781 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.001888 6.695sec(train) 4.380sec(infer)
# Epoch 115 tst: l 0.614 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.236sec
# Epoch 116 tr: l 0.632 a 0.785 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.001887 6.565sec(train) 4.394sec(infer)
# Epoch 116 tst: l 0.612 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.338sec
# Epoch 117 tr: l 0.619 a 0.787 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.001886 6.631sec(train) 4.469sec(infer)
# Epoch 117 tst: l 0.616 a 0.796 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.391sec
# Epoch 118 tr: l 0.618 a 0.788 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.001885 6.673sec(train) 4.398sec(infer)
# Epoch 118 tst: l 0.612 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.276sec
# Epoch 119 tr: l 0.605 a 0.791 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.001884 6.622sec(train) 4.394sec(infer)
# Epoch 119 tst: l 0.613 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.230sec
# Epoch 120 tr: l 0.641 a 0.779 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.001884 6.445sec(train) 4.440sec(infer)
# Epoch 120 tst: l 0.611 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.428sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 121 tr: l 0.636 a 0.778 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001883 6.705sec(train) 4.444sec(infer)
# Epoch 121 tst: l 0.612 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.365sec
# Epoch 122 tr: l 0.612 a 0.791 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001882 6.499sec(train) 4.371sec(infer)
# Epoch 122 tst: l 0.607 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.264sec
# Epoch 123 tr: l 0.628 a 0.785 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.001881 6.657sec(train) 4.382sec(infer)
# Epoch 123 tst: l 0.610 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.289sec
# Epoch 124 tr: l 0.628 a 0.783 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001880 6.561sec(train) 4.377sec(infer)
# Epoch 124 tst: l 0.609 a 0.797 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.305sec
# Epoch 125 tr: l 0.639 a 0.782 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.001879 6.549sec(train) 4.401sec(infer)
# Epoch 125 tst: l 0.609 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.291sec
# Epoch 126 tr: l 0.601 a 0.794 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.001878 6.528sec(train) 4.434sec(infer)
# Epoch 126 tst: l 0.609 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.253sec
# Epoch 127 tr: l 0.617 a 0.788 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.001877 6.491sec(train) 4.478sec(infer)
# Epoch 127 tst: l 0.609 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  5.958sec
# Epoch 128 tr: l 0.616 a 0.789 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.001876 6.584sec(train) 4.366sec(infer)
# Epoch 128 tst: l 0.609 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.274sec
# Epoch 129 tr: l 0.612 a 0.792 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001875 6.550sec(train) 4.428sec(infer)
# Epoch 129 tst: l 0.610 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.541sec
# Epoch 130 tr: l 0.608 a 0.792 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.001874 6.743sec(train) 4.459sec(infer)
# Epoch 130 tst: l 0.608 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.423sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 131 tr: l 0.627 a 0.789 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.001873 6.702sec(train) 4.418sec(infer)
# Epoch 131 tst: l 0.609 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.322sec
# Epoch 132 tr: l 0.616 a 0.790 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.001872 6.608sec(train) 4.458sec(infer)
# Epoch 132 tst: l 0.607 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.355sec
# Epoch 133 tr: l 0.624 a 0.786 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001871 6.631sec(train) 4.405sec(infer)
# Epoch 133 tst: l 0.609 a 0.798 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.323sec
# Epoch 134 tr: l 0.604 a 0.795 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.001870 6.667sec(train) 4.374sec(infer)
# Epoch 134 tst: l 0.606 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.282sec
# Epoch 135 tr: l 0.617 a 0.788 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.001869 6.558sec(train) 4.371sec(infer)
# Epoch 135 tst: l 0.605 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.341sec
# Epoch 136 tr: l 0.616 a 0.789 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.001868 6.567sec(train) 4.402sec(infer)
# Epoch 136 tst: l 0.603 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.311sec
# Epoch 137 tr: l 0.627 a 0.787 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.001868 6.589sec(train) 4.375sec(infer)
# Epoch 137 tst: l 0.602 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.314sec
# Epoch 138 tr: l 0.616 a 0.787 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001867 6.533sec(train) 4.362sec(infer)
# Epoch 138 tst: l 0.603 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.263sec
# Epoch 139 tr: l 0.613 a 0.790 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001866 6.555sec(train) 4.408sec(infer)
# Epoch 139 tst: l 0.604 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.333sec
# Epoch 140 tr: l 0.607 a 0.790 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001865 6.606sec(train) 4.422sec(infer)
# Epoch 140 tst: l 0.603 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.304sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 141 tr: l 0.607 a 0.792 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.001864 6.660sec(train) 4.468sec(infer)
# Epoch 141 tst: l 0.601 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.364sec
# Epoch 142 tr: l 0.612 a 0.789 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.001863 6.575sec(train) 4.331sec(infer)
# Epoch 142 tst: l 0.607 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.211sec
# Epoch 143 tr: l 0.625 a 0.782 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.001862 6.541sec(train) 4.372sec(infer)
# Epoch 143 tst: l 0.604 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.315sec
# Epoch 144 tr: l 0.625 a 0.785 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.001861 6.643sec(train) 4.443sec(infer)
# Epoch 144 tst: l 0.603 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.367sec
# Epoch 145 tr: l 0.626 a 0.786 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001860 6.663sec(train) 4.418sec(infer)
# Epoch 145 tst: l 0.603 a 0.800 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.414sec
# Epoch 146 tr: l 0.622 a 0.787 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.001859 6.687sec(train) 4.508sec(infer)
# Epoch 146 tst: l 0.602 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.432sec
# Epoch 147 tr: l 0.630 a 0.784 clct[np.int64(32), np.int64(48)] clct_ans[np.int64(48), np.int64(32)]  lr 0.001858 6.594sec(train) 4.375sec(infer)
# Epoch 147 tst: l 0.602 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.244sec
# Epoch 148 tr: l 0.604 a 0.792 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.001857 6.538sec(train) 4.393sec(infer)
# Epoch 148 tst: l 0.601 a 0.799 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.241sec
# Epoch 149 tr: l 0.613 a 0.788 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.001856 6.576sec(train) 4.357sec(infer)
# Epoch 149 tst: l 0.601 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.247sec
# Epoch 150 tr: l 0.623 a 0.787 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.000186 6.548sec(train) 4.376sec(infer)
# Epoch 150 tst: l 0.599 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.304sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 151 tr: l 0.615 a 0.787 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000185 6.632sec(train) 4.388sec(infer)
# Epoch 151 tst: l 0.599 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.291sec
# Epoch 152 tr: l 0.608 a 0.792 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000185 6.634sec(train) 4.317sec(infer)
# Epoch 152 tst: l 0.598 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.301sec
# Epoch 153 tr: l 0.617 a 0.788 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.000185 6.551sec(train) 4.377sec(infer)
# Epoch 153 tst: l 0.598 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.263sec
# Epoch 154 tr: l 0.603 a 0.792 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.000185 6.584sec(train) 4.415sec(infer)
# Epoch 154 tst: l 0.598 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.314sec
# Epoch 155 tr: l 0.613 a 0.790 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000185 6.629sec(train) 4.446sec(infer)
# Epoch 155 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.354sec
# Epoch 156 tr: l 0.617 a 0.785 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000185 6.618sec(train) 4.347sec(infer)
# Epoch 156 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.191sec
# Epoch 157 tr: l 0.603 a 0.793 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.000185 6.547sec(train) 4.344sec(infer)
# Epoch 157 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.312sec
# Epoch 158 tr: l 0.613 a 0.787 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.000185 6.482sec(train) 4.382sec(infer)
# Epoch 158 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.265sec
# Epoch 159 tr: l 0.603 a 0.792 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000185 6.510sec(train) 4.349sec(infer)
# Epoch 159 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.298sec
# Epoch 160 tr: l 0.610 a 0.790 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.000185 6.498sec(train) 4.363sec(infer)
# Epoch 160 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.261sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 161 tr: l 0.602 a 0.792 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.000185 6.593sec(train) 4.453sec(infer)
# Epoch 161 tst: l 0.598 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.371sec
# Epoch 162 tr: l 0.616 a 0.786 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000184 6.544sec(train) 4.395sec(infer)
# Epoch 162 tst: l 0.598 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.319sec
# Epoch 163 tr: l 0.615 a 0.791 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.000184 6.643sec(train) 4.422sec(infer)
# Epoch 163 tst: l 0.598 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.335sec
# Epoch 164 tr: l 0.603 a 0.792 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000184 6.568sec(train) 4.328sec(infer)
# Epoch 164 tst: l 0.597 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.322sec
# Epoch 165 tr: l 0.595 a 0.793 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000184 6.464sec(train) 4.349sec(infer)
# Epoch 165 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.311sec
# Epoch 166 tr: l 0.604 a 0.792 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000184 6.661sec(train) 4.440sec(infer)
# Epoch 166 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.333sec
# Epoch 167 tr: l 0.605 a 0.792 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000184 6.628sec(train) 4.355sec(infer)
# Epoch 167 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.250sec
# Epoch 168 tr: l 0.607 a 0.793 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000184 6.582sec(train) 4.673sec(infer)
# Epoch 168 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.546sec
# Epoch 169 tr: l 0.607 a 0.792 clct[np.int64(45), np.int64(35)] clct_ans[np.int64(35), np.int64(45)]  lr 0.000184 6.548sec(train) 4.621sec(infer)
# Epoch 169 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.605sec
# Epoch 170 tr: l 0.617 a 0.785 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000184 6.573sec(train) 4.485sec(infer)
# Epoch 170 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.559sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 171 tr: l 0.617 a 0.791 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.000184 6.695sec(train) 4.522sec(infer)
# Epoch 171 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.709sec
# Epoch 172 tr: l 0.625 a 0.783 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.000184 6.464sec(train) 4.528sec(infer)
# Epoch 172 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.595sec
# Epoch 173 tr: l 0.601 a 0.794 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000183 6.554sec(train) 4.620sec(infer)
# Epoch 173 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.678sec
# Epoch 174 tr: l 0.608 a 0.789 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000183 6.699sec(train) 4.597sec(infer)
# Epoch 174 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.652sec
# Epoch 175 tr: l 0.631 a 0.784 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000183 6.676sec(train) 4.555sec(infer)
# Epoch 175 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.620sec
# Epoch 176 tr: l 0.606 a 0.791 clct[np.int64(30), np.int64(50)] clct_ans[np.int64(50), np.int64(30)]  lr 0.000183 6.533sec(train) 4.554sec(infer)
# Epoch 176 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.554sec
# Epoch 177 tr: l 0.610 a 0.791 clct[np.int64(49), np.int64(31)] clct_ans[np.int64(31), np.int64(49)]  lr 0.000183 6.459sec(train) 4.594sec(infer)
# Epoch 177 tst: l 0.596 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.565sec
# Epoch 178 tr: l 0.602 a 0.792 clct[np.int64(48), np.int64(32)] clct_ans[np.int64(32), np.int64(48)]  lr 0.000183 6.512sec(train) 4.647sec(infer)
# Epoch 178 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.543sec
# Epoch 179 tr: l 0.602 a 0.788 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.000183 6.432sec(train) 4.508sec(infer)
# Epoch 179 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.656sec
# Epoch 180 tr: l 0.603 a 0.797 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.000183 6.468sec(train) 4.494sec(infer)
# Epoch 180 tst: l 0.595 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.641sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 181 tr: l 0.618 a 0.788 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.000183 6.439sec(train) 4.485sec(infer)
# Epoch 181 tst: l 0.595 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.696sec
# Epoch 182 tr: l 0.604 a 0.791 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.000183 6.537sec(train) 4.551sec(infer)
# Epoch 182 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.594sec
# Epoch 183 tr: l 0.616 a 0.786 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000183 6.556sec(train) 4.493sec(infer)
# Epoch 183 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.560sec
# Epoch 184 tr: l 0.609 a 0.792 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000182 6.477sec(train) 4.518sec(infer)
# Epoch 184 tst: l 0.595 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.551sec
# Epoch 185 tr: l 0.604 a 0.792 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000182 6.528sec(train) 4.525sec(infer)
# Epoch 185 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.540sec
# Epoch 186 tr: l 0.604 a 0.794 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000182 6.434sec(train) 4.518sec(infer)
# Epoch 186 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.531sec
# Epoch 187 tr: l 0.611 a 0.793 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000182 6.461sec(train) 4.499sec(infer)
# Epoch 187 tst: l 0.597 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.537sec
# Epoch 188 tr: l 0.621 a 0.787 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000182 6.497sec(train) 4.501sec(infer)
# Epoch 188 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.550sec
# Epoch 189 tr: l 0.609 a 0.791 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000182 6.505sec(train) 4.543sec(infer)
# Epoch 189 tst: l 0.596 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.594sec
# Epoch 190 tr: l 0.609 a 0.793 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000182 6.561sec(train) 4.536sec(infer)
# Epoch 190 tst: l 0.595 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.584sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 191 tr: l 0.615 a 0.787 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000182 6.644sec(train) 4.604sec(infer)
# Epoch 191 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.695sec
# Epoch 192 tr: l 0.609 a 0.788 clct[np.int64(42), np.int64(38)] clct_ans[np.int64(38), np.int64(42)]  lr 0.000182 6.890sec(train) 4.547sec(infer)
# Epoch 192 tst: l 0.596 a 0.801 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.590sec
# Epoch 193 tr: l 0.612 a 0.790 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.000182 6.550sec(train) 4.548sec(infer)
# Epoch 193 tst: l 0.596 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.590sec
# Epoch 194 tr: l 0.604 a 0.792 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000182 6.667sec(train) 4.625sec(infer)
# Epoch 194 tst: l 0.596 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.649sec
# Epoch 195 tr: l 0.617 a 0.788 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.000181 6.644sec(train) 4.568sec(infer)
# Epoch 195 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.668sec
# Epoch 196 tr: l 0.603 a 0.794 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.000181 6.632sec(train) 4.583sec(infer)
# Epoch 196 tst: l 0.596 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.691sec
# Epoch 197 tr: l 0.597 a 0.796 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.000181 6.603sec(train) 4.606sec(infer)
# Epoch 197 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.666sec
# Epoch 198 tr: l 0.613 a 0.789 clct[np.int64(35), np.int64(45)] clct_ans[np.int64(45), np.int64(35)]  lr 0.000181 6.469sec(train) 4.531sec(infer)
# Epoch 198 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.570sec
# Epoch 199 tr: l 0.615 a 0.793 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000181 6.557sec(train) 4.528sec(infer)
# Epoch 199 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.567sec
# Epoch 200 tr: l 0.614 a 0.790 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.000018 6.564sec(train) 4.522sec(infer)
# Epoch 200 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.883sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 201 tr: l 0.618 a 0.788 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.000018 6.572sec(train) 4.514sec(infer)
# Epoch 201 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.550sec
# Epoch 202 tr: l 0.604 a 0.793 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000018 6.619sec(train) 4.634sec(infer)
# Epoch 202 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.635sec
# Epoch 203 tr: l 0.600 a 0.797 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000018 6.717sec(train) 4.654sec(infer)
# Epoch 203 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.701sec
# Epoch 204 tr: l 0.628 a 0.782 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.000018 6.628sec(train) 4.598sec(infer)
# Epoch 204 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.729sec
# Epoch 205 tr: l 0.607 a 0.793 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.562sec(train) 4.729sec(infer)
# Epoch 205 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.771sec
# Epoch 206 tr: l 0.614 a 0.788 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000018 6.567sec(train) 4.591sec(infer)
# Epoch 206 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.691sec
# Epoch 207 tr: l 0.616 a 0.789 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.000018 6.610sec(train) 4.585sec(infer)
# Epoch 207 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.660sec
# Epoch 208 tr: l 0.603 a 0.794 clct[np.int64(41), np.int64(39)] clct_ans[np.int64(39), np.int64(41)]  lr 0.000018 6.688sec(train) 4.577sec(infer)
# Epoch 208 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.719sec
# Epoch 209 tr: l 0.609 a 0.791 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.000018 6.656sec(train) 4.623sec(infer)
# Epoch 209 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.738sec
# Epoch 210 tr: l 0.607 a 0.792 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.000018 6.635sec(train) 4.522sec(infer)
# Epoch 210 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.592sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 211 tr: l 0.612 a 0.789 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.662sec(train) 4.620sec(infer)
# Epoch 211 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.631sec
# Epoch 212 tr: l 0.598 a 0.796 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.723sec(train) 4.597sec(infer)
# Epoch 212 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.531sec
# Epoch 213 tr: l 0.601 a 0.795 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.000018 6.638sec(train) 4.484sec(infer)
# Epoch 213 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.540sec
# Epoch 214 tr: l 0.604 a 0.793 clct[np.int64(33), np.int64(47)] clct_ans[np.int64(47), np.int64(33)]  lr 0.000018 6.502sec(train) 4.480sec(infer)
# Epoch 214 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.635sec
# Epoch 215 tr: l 0.600 a 0.793 clct[np.int64(44), np.int64(36)] clct_ans[np.int64(36), np.int64(44)]  lr 0.000018 6.451sec(train) 4.516sec(infer)
# Epoch 215 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.518sec
# Epoch 216 tr: l 0.615 a 0.791 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.000018 6.556sec(train) 4.577sec(infer)
# Epoch 216 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.678sec
# Epoch 217 tr: l 0.603 a 0.792 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000018 6.684sec(train) 4.563sec(infer)
# Epoch 217 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.669sec
# Epoch 218 tr: l 0.608 a 0.790 clct[np.int64(43), np.int64(37)] clct_ans[np.int64(37), np.int64(43)]  lr 0.000018 6.557sec(train) 4.608sec(infer)
# Epoch 218 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.813sec
# Epoch 219 tr: l 0.609 a 0.790 clct[np.int64(46), np.int64(34)] clct_ans[np.int64(34), np.int64(46)]  lr 0.000018 6.563sec(train) 4.525sec(infer)
# Epoch 219 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.527sec
# Epoch 220 tr: l 0.601 a 0.795 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.000018 6.578sec(train) 4.591sec(infer)
# Epoch 220 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.632sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 221 tr: l 0.608 a 0.794 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.637sec(train) 4.577sec(infer)
# Epoch 221 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.599sec
# Epoch 222 tr: l 0.609 a 0.790 clct[np.int64(39), np.int64(41)] clct_ans[np.int64(41), np.int64(39)]  lr 0.000018 6.612sec(train) 4.513sec(infer)
# Epoch 222 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.604sec
# Epoch 223 tr: l 0.600 a 0.791 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.574sec(train) 4.574sec(infer)
# Epoch 223 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.665sec
# Epoch 224 tr: l 0.605 a 0.794 clct[np.int64(34), np.int64(46)] clct_ans[np.int64(46), np.int64(34)]  lr 0.000018 6.644sec(train) 4.580sec(infer)
# Epoch 224 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.626sec
# Epoch 225 tr: l 0.611 a 0.788 clct[np.int64(32), np.int64(48)] clct_ans[np.int64(48), np.int64(32)]  lr 0.000018 6.619sec(train) 4.487sec(infer)
# Epoch 225 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.460sec
# Epoch 226 tr: l 0.607 a 0.792 clct[np.int64(47), np.int64(33)] clct_ans[np.int64(33), np.int64(47)]  lr 0.000018 6.406sec(train) 4.495sec(infer)
# Epoch 226 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.557sec
# Epoch 227 tr: l 0.607 a 0.791 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  lr 0.000018 6.499sec(train) 4.567sec(infer)
# Epoch 227 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.657sec
# Epoch 228 tr: l 0.612 a 0.788 clct[np.int64(38), np.int64(42)] clct_ans[np.int64(42), np.int64(38)]  lr 0.000018 6.628sec(train) 4.560sec(infer)
# Epoch 228 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.549sec
# Epoch 229 tr: l 0.599 a 0.791 clct[np.int64(37), np.int64(43)] clct_ans[np.int64(43), np.int64(37)]  lr 0.000018 6.681sec(train) 4.556sec(infer)
# Epoch 229 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.638sec
# Epoch 230 tr: l 0.607 a 0.791 clct[np.int64(36), np.int64(44)] clct_ans[np.int64(44), np.int64(36)]  lr 0.000018 6.593sec(train) 4.585sec(infer)
# Epoch 230 tst: l 0.595 a 0.802 clct[np.int64(40), np.int64(40)] clct_ans[np.int64(40), np.int64(40)]  6.926sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
