# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import ifca as IFCA

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
rc = ipp.Cluster(n=3).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]

# %%
learning_rates = [0.1]

dfca_li = []
dfca_gi = []
ifca = []

# %%
# %%px --targets all
#
# import sys
# import os
# import random
# sys.path.append(os.getcwd())
#
# random.seed(42)
# seeds = random.sample(range(10000), 5)
# learning_rates = [0.1]
#
# dfca_li = []
# dfca_gi = []
# ifca = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_gi.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-LI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainEMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_gi.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the dfca-li experiment

# %%
# %%px --target 1 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_li.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-LI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainEMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_li.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the ifca experiment

# %%
# %%px --target 2 --noblock
# import ifca as IFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config_ifca.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------IFCA, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = IFCA.TrainEMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ifca.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Experiment Final Results:

# %%
rc.wait_interactive()
_.display_outputs()

dfca_gi = rc[0].pull('dfca_gi', block=True)
dfca_li = rc[1].pull('dfca_li', block=True)
ifca = rc[2].pull('ifca', block=True)
# Out:
# unknown:   0%|          | 0/3 [00:00<?, ?tasks/s]
# ---------------------------------IFCA, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 3.850 a 0.024 clct[np.int64(117), np.int64(83)] cl_acc 0.575  6.467sec
# Epoch -1 tst: l 3.851 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.550  0.360sec
# Epoch 0 tr: l 3.846 a 0.026 clct[np.int64(88), np.int64(112)] cl_acc 0.610  lr 0.100000 18.262sec(train) 2.360sec(infer)
# Epoch 0 tst: l 3.847 a 0.027 clct[np.int64(20), np.int64(20)] cl_acc 0.600  0.439sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 1 tr: l 3.842 a 0.029 clct[np.int64(66), np.int64(134)] cl_acc 0.660  lr 0.100000 11.384sec(train) 3.732sec(infer)
# Epoch 1 tst: l 3.843 a 0.029 clct[np.int64(12), np.int64(28)] cl_acc 0.650  0.739sec
# Epoch 2 tr: l 3.836 a 0.040 clct[np.int64(50), np.int64(150)] cl_acc 0.690  lr 0.100000 9.112sec(train) 3.493sec(infer)
# Epoch 2 tst: l 3.838 a 0.040 clct[np.int64(11), np.int64(29)] cl_acc 0.675  0.936sec
# Epoch 3 tr: l 3.829 a 0.054 clct[np.int64(42), np.int64(158)] cl_acc 0.710  lr 0.100000 11.276sec(train) 3.164sec(infer)
# Epoch 3 tst: l 3.831 a 0.055 clct[np.int64(11), np.int64(29)] cl_acc 0.725  0.647sec
# Epoch 4 tr: l 3.819 a 0.071 clct[np.int64(42), np.int64(158)] cl_acc 0.710  lr 0.100000 12.055sec(train) 3.574sec(infer)
# Epoch 4 tst: l 3.821 a 0.073 clct[np.int64(12), np.int64(28)] cl_acc 0.750  0.714sec
# Epoch 5 tr: l 3.805 a 0.086 clct[np.int64(40), np.int64(160)] cl_acc 0.700  lr 0.100000 11.290sec(train) 4.919sec(infer)
# Epoch 5 tst: l 3.807 a 0.083 clct[np.int64(10), np.int64(30)] cl_acc 0.750  0.878sec
# Epoch 6 tr: l 3.784 a 0.094 clct[np.int64(40), np.int64(160)] cl_acc 0.700  lr 0.100000 13.032sec(train) 5.465sec(infer)
# Epoch 6 tst: l 3.786 a 0.091 clct[np.int64(10), np.int64(30)] cl_acc 0.750  1.114sec
# Epoch 7 tr: l 3.750 a 0.105 clct[np.int64(44), np.int64(156)] cl_acc 0.720  lr 0.100000 13.501sec(train) 2.462sec(infer)
# Epoch 7 tst: l 3.753 a 0.100 clct[np.int64(11), np.int64(29)] cl_acc 0.775  0.730sec
# Epoch 8 tr: l 3.695 a 0.116 clct[np.int64(61), np.int64(139)] cl_acc 0.805  lr 0.100000 11.232sec(train) 3.673sec(infer)
# Epoch 8 tst: l 3.699 a 0.114 clct[np.int64(13), np.int64(27)] cl_acc 0.825  0.660sec
# Epoch 9 tr: l 3.594 a 0.156 clct[np.int64(91), np.int64(109)] cl_acc 0.955  lr 0.100000 11.113sec(train) 3.891sec(infer)
# Epoch 9 tst: l 3.599 a 0.155 clct[np.int64(19), np.int64(21)] cl_acc 0.975  0.697sec
# Epoch 10 tr: l 3.391 a 0.242 clct[np.int64(99), np.int64(101)] cl_acc 0.995  lr 0.100000 10.296sec(train) 3.511sec(infer)
# Epoch 10 tst: l 3.399 a 0.242 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.636sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 11 tr: l 3.052 a 0.305 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.810sec(train) 3.347sec(infer)
# Epoch 11 tst: l 3.058 a 0.303 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.885sec
# Epoch 12 tr: l 3.014 a 0.284 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.577sec(train) 5.270sec(infer)
# Epoch 12 tst: l 3.027 a 0.283 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.106sec
# Epoch 13 tr: l 2.721 a 0.307 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.384sec(train) 4.119sec(infer)
# Epoch 13 tst: l 2.729 a 0.306 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.936sec
# Epoch 14 tr: l 2.502 a 0.341 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.296sec(train) 3.390sec(infer)
# Epoch 14 tst: l 2.526 a 0.340 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.612sec
# Epoch 15 tr: l 2.343 a 0.378 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.233sec(train) 3.047sec(infer)
# Epoch 15 tst: l 2.362 a 0.374 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.385sec
# Epoch 16 tr: l 2.188 a 0.423 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.280sec(train) 4.047sec(infer)
# Epoch 16 tst: l 2.207 a 0.419 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.698sec
# Epoch 17 tr: l 2.135 a 0.428 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.479sec(train) 3.516sec(infer)
# Epoch 17 tst: l 2.165 a 0.422 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.940sec
# Epoch 18 tr: l 1.985 a 0.455 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.370sec(train) 3.285sec(infer)
# Epoch 18 tst: l 2.008 a 0.459 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.843sec
# Epoch 19 tr: l 1.837 a 0.499 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.056sec(train) 3.959sec(infer)
# Epoch 19 tst: l 1.858 a 0.493 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.634sec
# Epoch 20 tr: l 1.827 a 0.490 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.845sec(train) 3.561sec(infer)
# Epoch 20 tst: l 1.867 a 0.487 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.688sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 21 tr: l 1.710 a 0.520 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.723sec(train) 3.407sec(infer)
# Epoch 21 tst: l 1.742 a 0.521 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.687sec
# Epoch 22 tr: l 1.629 a 0.540 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.006sec(train) 3.271sec(infer)
# Epoch 22 tst: l 1.672 a 0.533 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.805sec
# Epoch 23 tr: l 1.552 a 0.561 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.738sec(train) 3.412sec(infer)
# Epoch 23 tst: l 1.591 a 0.557 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.646sec
# Epoch 24 tr: l 1.514 a 0.571 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.860sec(train) 4.172sec(infer)
# Epoch 24 tst: l 1.558 a 0.570 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.904sec
# Epoch 25 tr: l 1.487 a 0.578 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.638sec(train) 5.669sec(infer)
# Epoch 25 tst: l 1.529 a 0.572 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.030sec
# Epoch 26 tr: l 1.441 a 0.581 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.330sec(train) 2.670sec(infer)
# Epoch 26 tst: l 1.486 a 0.579 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.796sec
# Epoch 27 tr: l 1.417 a 0.588 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.324sec(train) 3.639sec(infer)
# Epoch 27 tst: l 1.474 a 0.586 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.648sec
# Epoch 28 tr: l 1.358 a 0.608 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.915sec(train) 3.244sec(infer)
# Epoch 28 tst: l 1.401 a 0.604 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.915sec
# Epoch 29 tr: l 1.337 a 0.609 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.863sec(train) 3.097sec(infer)
# Epoch 29 tst: l 1.397 a 0.605 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.700sec
# Epoch 30 tr: l 1.361 a 0.601 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.399sec(train) 3.955sec(infer)
# Epoch 30 tst: l 1.418 a 0.597 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.786sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 31 tr: l 1.278 a 0.625 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.691sec(train) 6.180sec(infer)
# Epoch 31 tst: l 1.328 a 0.624 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.087sec
# Epoch 32 tr: l 1.268 a 0.626 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.993sec(train) 3.152sec(infer)
# Epoch 32 tst: l 1.328 a 0.621 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.627sec
# Epoch 33 tr: l 1.247 a 0.632 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.056sec(train) 3.394sec(infer)
# Epoch 33 tst: l 1.304 a 0.630 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.713sec
# Epoch 34 tr: l 1.215 a 0.640 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.686sec(train) 3.280sec(infer)
# Epoch 34 tst: l 1.275 a 0.639 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.652sec
# Epoch 35 tr: l 1.198 a 0.644 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.839sec(train) 3.766sec(infer)
# Epoch 35 tst: l 1.261 a 0.642 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.766sec
# Epoch 36 tr: l 1.180 a 0.650 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.891sec(train) 3.565sec(infer)
# Epoch 36 tst: l 1.242 a 0.647 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.739sec
# Epoch 37 tr: l 1.180 a 0.647 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.767sec(train) 3.729sec(infer)
# Epoch 37 tst: l 1.246 a 0.644 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.916sec
# Epoch 38 tr: l 1.139 a 0.658 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.876sec(train) 4.353sec(infer)
# Epoch 38 tst: l 1.202 a 0.655 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.610sec
# Epoch 39 tr: l 1.110 a 0.670 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.511sec(train) 3.710sec(infer)
# Epoch 39 tst: l 1.177 a 0.665 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.774sec
# Epoch 40 tr: l 1.094 a 0.671 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.483sec(train) 3.391sec(infer)
# Epoch 40 tst: l 1.157 a 0.666 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.644sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 41 tr: l 1.098 a 0.671 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.074sec(train) 2.960sec(infer)
# Epoch 41 tst: l 1.166 a 0.669 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.725sec
# Epoch 42 tr: l 1.118 a 0.660 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.347sec(train) 3.607sec(infer)
# Epoch 42 tst: l 1.189 a 0.657 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.592sec
# Epoch 43 tr: l 1.098 a 0.670 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.613sec(train) 3.941sec(infer)
# Epoch 43 tst: l 1.166 a 0.667 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.174sec
# Epoch 44 tr: l 1.079 a 0.673 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.417sec(train) 6.709sec(infer)
# Epoch 44 tst: l 1.149 a 0.669 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.089sec
# Epoch 45 tr: l 1.069 a 0.675 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.164sec(train) 2.682sec(infer)
# Epoch 45 tst: l 1.142 a 0.670 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.393sec
# Epoch 46 tr: l 1.031 a 0.690 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.896sec(train) 3.778sec(infer)
# Epoch 46 tst: l 1.099 a 0.682 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.672sec
# Epoch 47 tr: l 1.024 a 0.690 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.073sec(train) 3.181sec(infer)
# Epoch 47 tst: l 1.098 a 0.684 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.812sec
# Epoch 48 tr: l 1.007 a 0.695 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.178sec(train) 3.211sec(infer)
# Epoch 48 tst: l 1.081 a 0.690 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.795sec
# Epoch 49 tr: l 0.986 a 0.699 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.950sec(train) 3.712sec(infer)
# Epoch 49 tst: l 1.062 a 0.695 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.733sec
# Epoch 50 tr: l 0.985 a 0.698 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.286sec(train) 5.799sec(infer)
# Epoch 50 tst: l 1.060 a 0.693 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.330sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 51 tr: l 0.977 a 0.700 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.100sec(train) 3.184sec(infer)
# Epoch 51 tst: l 1.059 a 0.697 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.640sec
# Epoch 52 tr: l 0.971 a 0.700 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.128sec(train) 3.594sec(infer)
# Epoch 52 tst: l 1.044 a 0.695 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.776sec
# Epoch 53 tr: l 0.958 a 0.707 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.490sec(train) 3.462sec(infer)
# Epoch 53 tst: l 1.036 a 0.703 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.661sec
# Epoch 54 tr: l 0.951 a 0.707 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.123sec(train) 3.525sec(infer)
# Epoch 54 tst: l 1.032 a 0.701 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.702sec
# Epoch 55 tr: l 0.930 a 0.713 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.661sec(train) 3.524sec(infer)
# Epoch 55 tst: l 1.009 a 0.709 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.739sec
# Epoch 56 tr: l 0.914 a 0.717 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.663sec(train) 3.880sec(infer)
# Epoch 56 tst: l 0.995 a 0.712 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.906sec
# Epoch 57 tr: l 0.909 a 0.719 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.773sec(train) 4.582sec(infer)
# Epoch 57 tst: l 0.991 a 0.714 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.666sec
# Epoch 58 tr: l 0.891 a 0.724 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.218sec(train) 3.448sec(infer)
# Epoch 58 tst: l 0.972 a 0.719 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.710sec
# Epoch 59 tr: l 0.900 a 0.721 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.372sec(train) 3.446sec(infer)
# Epoch 59 tst: l 0.984 a 0.715 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.599sec
# Epoch 60 tr: l 0.890 a 0.725 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.003sec(train) 2.990sec(infer)
# Epoch 60 tst: l 0.973 a 0.719 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.739sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 61 tr: l 0.890 a 0.722 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.596sec(train) 3.892sec(infer)
# Epoch 61 tst: l 0.973 a 0.717 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.661sec
# Epoch 62 tr: l 0.870 a 0.729 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.414sec(train) 4.164sec(infer)
# Epoch 62 tst: l 0.957 a 0.722 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.083sec
# Epoch 63 tr: l 0.862 a 0.731 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.510sec(train) 5.566sec(infer)
# Epoch 63 tst: l 0.945 a 0.726 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.061sec
# Epoch 64 tr: l 0.852 a 0.732 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.779sec(train) 2.633sec(infer)
# Epoch 64 tst: l 0.944 a 0.724 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.387sec
# Epoch 65 tr: l 0.842 a 0.736 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.679sec(train) 4.103sec(infer)
# Epoch 65 tst: l 0.930 a 0.731 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.746sec
# Epoch 66 tr: l 0.855 a 0.729 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.525sec(train) 3.375sec(infer)
# Epoch 66 tst: l 0.945 a 0.723 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.847sec
# Epoch 67 tr: l 0.830 a 0.739 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.803sec(train) 2.657sec(infer)
# Epoch 67 tst: l 0.917 a 0.733 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.753sec
# Epoch 68 tr: l 0.838 a 0.738 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.423sec(train) 3.879sec(infer)
# Epoch 68 tst: l 0.934 a 0.732 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.733sec
# Epoch 69 tr: l 0.816 a 0.743 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.007sec(train) 5.183sec(infer)
# Epoch 69 tst: l 0.905 a 0.736 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.448sec
# Epoch 70 tr: l 0.820 a 0.743 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.207sec(train) 3.387sec(infer)
# Epoch 70 tst: l 0.916 a 0.737 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.693sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 71 tr: l 0.799 a 0.749 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.292sec(train) 2.698sec(infer)
# Epoch 71 tst: l 0.893 a 0.742 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.757sec
# Epoch 72 tr: l 0.818 a 0.743 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.681sec(train) 3.372sec(infer)
# Epoch 72 tst: l 0.912 a 0.735 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.600sec
# Epoch 73 tr: l 0.795 a 0.748 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.313sec(train) 3.521sec(infer)
# Epoch 73 tst: l 0.891 a 0.740 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.837sec
# Epoch 74 tr: l 0.784 a 0.752 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.430sec(train) 4.024sec(infer)
# Epoch 74 tst: l 0.879 a 0.744 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.770sec
# Epoch 75 tr: l 0.776 a 0.753 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.539sec(train) 4.002sec(infer)
# Epoch 75 tst: l 0.874 a 0.745 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.951sec
# Epoch 76 tr: l 0.773 a 0.754 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.906sec(train) 4.921sec(infer)
# Epoch 76 tst: l 0.870 a 0.745 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.580sec
# Epoch 77 tr: l 0.774 a 0.753 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.613sec(train) 3.316sec(infer)
# Epoch 77 tst: l 0.871 a 0.742 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.889sec
# Epoch 78 tr: l 0.768 a 0.756 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.510sec(train) 3.474sec(infer)
# Epoch 78 tst: l 0.867 a 0.748 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.638sec
# Epoch 79 tr: l 0.772 a 0.754 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.413sec(train) 3.403sec(infer)
# Epoch 79 tst: l 0.872 a 0.744 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.665sec
# Epoch 80 tr: l 0.754 a 0.760 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.572sec(train) 3.783sec(infer)
# Epoch 80 tst: l 0.852 a 0.752 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.709sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 81 tr: l 0.746 a 0.761 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.371sec(train) 3.770sec(infer)
# Epoch 81 tst: l 0.850 a 0.752 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.894sec
# Epoch 82 tr: l 0.738 a 0.763 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.052sec(train) 5.253sec(infer)
# Epoch 82 tst: l 0.835 a 0.754 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.080sec
# Epoch 83 tr: l 0.738 a 0.764 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.991sec(train) 3.519sec(infer)
# Epoch 83 tst: l 0.845 a 0.755 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.519sec
# Epoch 84 tr: l 0.728 a 0.765 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.680sec(train) 4.514sec(infer)
# Epoch 84 tst: l 0.825 a 0.756 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.715sec
# Epoch 85 tr: l 0.721 a 0.769 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.012sec(train) 3.208sec(infer)
# Epoch 85 tst: l 0.830 a 0.758 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.576sec
# Epoch 86 tr: l 0.713 a 0.769 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.636sec(train) 2.432sec(infer)
# Epoch 86 tst: l 0.814 a 0.759 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.686sec
# Epoch 87 tr: l 0.703 a 0.774 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.202sec(train) 4.225sec(infer)
# Epoch 87 tst: l 0.813 a 0.761 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.759sec
# Epoch 88 tr: l 0.700 a 0.772 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.962sec(train) 5.306sec(infer)
# Epoch 88 tst: l 0.805 a 0.761 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.658sec
# Epoch 89 tr: l 0.700 a 0.773 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.613sec(train) 3.501sec(infer)
# Epoch 89 tst: l 0.812 a 0.762 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.624sec
# Epoch 90 tr: l 0.692 a 0.776 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.006sec(train) 3.064sec(infer)
# Epoch 90 tst: l 0.798 a 0.767 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.599sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 91 tr: l 0.691 a 0.776 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.877sec(train) 3.633sec(infer)
# Epoch 91 tst: l 0.805 a 0.767 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.661sec
# Epoch 92 tr: l 0.684 a 0.779 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.589sec(train) 3.459sec(infer)
# Epoch 92 tst: l 0.791 a 0.770 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.898sec
# Epoch 93 tr: l 0.684 a 0.778 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.989sec(train) 3.060sec(infer)
# Epoch 93 tst: l 0.798 a 0.766 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.855sec
# Epoch 94 tr: l 0.678 a 0.781 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.560sec(train) 3.750sec(infer)
# Epoch 94 tst: l 0.788 a 0.769 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.717sec
# Epoch 95 tr: l 0.670 a 0.782 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.000sec(train) 5.554sec(infer)
# Epoch 95 tst: l 0.785 a 0.770 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.710sec
# Epoch 96 tr: l 0.674 a 0.781 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.269sec(train) 3.408sec(infer)
# Epoch 96 tst: l 0.784 a 0.771 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.645sec
# Epoch 97 tr: l 0.666 a 0.783 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.414sec(train) 2.810sec(infer)
# Epoch 97 tst: l 0.781 a 0.771 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.806sec
# Epoch 98 tr: l 0.669 a 0.783 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.031sec(train) 3.518sec(infer)
# Epoch 98 tst: l 0.780 a 0.772 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.620sec
# Epoch 99 tr: l 0.657 a 0.786 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.079sec(train) 3.496sec(infer)
# Epoch 99 tst: l 0.774 a 0.774 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.903sec
# Epoch 100 tr: l 0.651 a 0.789 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.587sec(train) 4.047sec(infer)
# Epoch 100 tst: l 0.765 a 0.776 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.715sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 101 tr: l 0.640 a 0.791 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.602sec(train) 6.099sec(infer)
# Epoch 101 tst: l 0.756 a 0.779 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.468sec
# Epoch 102 tr: l 0.640 a 0.790 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.608sec(train) 3.613sec(infer)
# Epoch 102 tst: l 0.759 a 0.777 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.676sec
# Epoch 103 tr: l 0.637 a 0.791 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.782sec(train) 3.231sec(infer)
# Epoch 103 tst: l 0.751 a 0.779 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.925sec
# Epoch 104 tr: l 0.640 a 0.788 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.210sec(train) 3.183sec(infer)
# Epoch 104 tst: l 0.761 a 0.777 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.622sec
# Epoch 105 tr: l 0.644 a 0.788 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.480sec(train) 3.452sec(infer)
# Epoch 105 tst: l 0.758 a 0.774 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.666sec
# Epoch 106 tr: l 0.629 a 0.792 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.687sec(train) 4.462sec(infer)
# Epoch 106 tst: l 0.749 a 0.781 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.852sec
# Epoch 107 tr: l 0.630 a 0.792 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.000sec(train) 3.700sec(infer)
# Epoch 107 tst: l 0.748 a 0.779 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.869sec
# Epoch 108 tr: l 0.617 a 0.796 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.526sec(train) 3.180sec(infer)
# Epoch 108 tst: l 0.738 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.714sec
# Epoch 109 tr: l 0.619 a 0.795 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.671sec(train) 3.407sec(infer)
# Epoch 109 tst: l 0.739 a 0.782 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.658sec
# Epoch 110 tr: l 0.610 a 0.797 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.507sec(train) 3.722sec(infer)
# Epoch 110 tst: l 0.733 a 0.787 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.809sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 111 tr: l 0.610 a 0.798 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.797sec(train) 3.417sec(infer)
# Epoch 111 tst: l 0.731 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.625sec
# Epoch 112 tr: l 0.603 a 0.800 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.163sec(train) 3.141sec(infer)
# Epoch 112 tst: l 0.726 a 0.788 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.795sec
# Epoch 113 tr: l 0.608 a 0.800 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.642sec(train) 4.106sec(infer)
# Epoch 113 tst: l 0.731 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.742sec
# Epoch 114 tr: l 0.604 a 0.799 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.613sec(train) 6.441sec(infer)
# Epoch 114 tst: l 0.729 a 0.786 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.911sec
# Epoch 115 tr: l 0.606 a 0.801 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.933sec(train) 3.448sec(infer)
# Epoch 115 tst: l 0.728 a 0.786 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.633sec
# Epoch 116 tr: l 0.601 a 0.800 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.227sec(train) 2.918sec(infer)
# Epoch 116 tst: l 0.727 a 0.786 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.634sec
# Epoch 117 tr: l 0.595 a 0.802 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.860sec(train) 3.687sec(infer)
# Epoch 117 tst: l 0.719 a 0.788 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.641sec
# Epoch 118 tr: l 0.587 a 0.804 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.247sec(train) 3.446sec(infer)
# Epoch 118 tst: l 0.716 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.829sec
# Epoch 119 tr: l 0.585 a 0.804 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.129sec(train) 4.234sec(infer)
# Epoch 119 tst: l 0.709 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.708sec
# Epoch 120 tr: l 0.580 a 0.805 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.446sec(train) 5.431sec(infer)
# Epoch 120 tst: l 0.710 a 0.791 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.044sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 121 tr: l 0.581 a 0.806 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.743sec(train) 3.829sec(infer)
# Epoch 121 tst: l 0.705 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.675sec
# Epoch 122 tr: l 0.571 a 0.808 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.810sec(train) 3.180sec(infer)
# Epoch 122 tst: l 0.703 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.780sec
# Epoch 123 tr: l 0.570 a 0.809 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.440sec(train) 2.863sec(infer)
# Epoch 123 tst: l 0.695 a 0.793 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.826sec
# Epoch 124 tr: l 0.566 a 0.810 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.198sec(train) 3.391sec(infer)
# Epoch 124 tst: l 0.700 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.631sec
# Epoch 125 tr: l 0.565 a 0.810 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.244sec(train) 4.386sec(infer)
# Epoch 125 tst: l 0.691 a 0.793 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.874sec
# Epoch 126 tr: l 0.561 a 0.811 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.579sec(train) 3.812sec(infer)
# Epoch 126 tst: l 0.694 a 0.797 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.833sec
# Epoch 127 tr: l 0.560 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.885sec(train) 3.441sec(infer)
# Epoch 127 tst: l 0.689 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.829sec
# Epoch 128 tr: l 0.556 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.583sec(train) 3.593sec(infer)
# Epoch 128 tst: l 0.688 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.613sec
# Epoch 129 tr: l 0.557 a 0.813 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.517sec(train) 3.523sec(infer)
# Epoch 129 tst: l 0.689 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.735sec
# Epoch 130 tr: l 0.553 a 0.811 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.522sec(train) 3.506sec(infer)
# Epoch 130 tst: l 0.685 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.614sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 131 tr: l 0.556 a 0.813 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.012sec(train) 3.135sec(infer)
# Epoch 131 tst: l 0.690 a 0.795 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.638sec
# Epoch 132 tr: l 0.550 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.588sec(train) 4.874sec(infer)
# Epoch 132 tst: l 0.685 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.782sec
# Epoch 133 tr: l 0.554 a 0.813 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.582sec(train) 5.415sec(infer)
# Epoch 133 tst: l 0.687 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.009sec
# Epoch 134 tr: l 0.552 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.589sec(train) 3.247sec(infer)
# Epoch 134 tst: l 0.689 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.620sec
# Epoch 135 tr: l 0.553 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.073sec(train) 3.183sec(infer)
# Epoch 135 tst: l 0.684 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.603sec
# Epoch 136 tr: l 0.543 a 0.816 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.033sec(train) 4.275sec(infer)
# Epoch 136 tst: l 0.681 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.776sec
# Epoch 137 tr: l 0.542 a 0.815 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.916sec(train) 3.217sec(infer)
# Epoch 137 tst: l 0.677 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.633sec
# Epoch 138 tr: l 0.538 a 0.818 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.243sec(train) 3.588sec(infer)
# Epoch 138 tst: l 0.675 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.923sec
# Epoch 139 tr: l 0.535 a 0.818 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.970sec(train) 5.430sec(infer)
# Epoch 139 tst: l 0.673 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.087sec
# Epoch 140 tr: l 0.534 a 0.820 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.826sec(train) 4.095sec(infer)
# Epoch 140 tst: l 0.671 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.764sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 141 tr: l 0.529 a 0.819 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.360sec(train) 3.392sec(infer)
# Epoch 141 tst: l 0.671 a 0.803 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.709sec
# Epoch 142 tr: l 0.529 a 0.821 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.679sec(train) 2.572sec(infer)
# Epoch 142 tst: l 0.666 a 0.802 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.722sec
# Epoch 143 tr: l 0.527 a 0.820 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.877sec(train) 3.535sec(infer)
# Epoch 143 tst: l 0.672 a 0.802 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.635sec
# Epoch 144 tr: l 0.526 a 0.821 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.300sec(train) 3.791sec(infer)
# Epoch 144 tst: l 0.663 a 0.802 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.033sec
# Epoch 145 tr: l 0.524 a 0.821 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.842sec(train) 5.120sec(infer)
# Epoch 145 tst: l 0.669 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.960sec
# Epoch 146 tr: l 0.520 a 0.821 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.854sec(train) 3.368sec(infer)
# Epoch 146 tst: l 0.659 a 0.802 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.624sec
# Epoch 147 tr: l 0.518 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.783sec(train) 3.655sec(infer)
# Epoch 147 tst: l 0.664 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.681sec
# Epoch 148 tr: l 0.514 a 0.822 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.994sec(train) 3.185sec(infer)
# Epoch 148 tst: l 0.656 a 0.803 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.798sec
# Epoch 149 tr: l 0.511 a 0.825 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.430sec(train) 3.226sec(infer)
# Epoch 149 tst: l 0.655 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.782sec
# Epoch 150 tr: l 0.510 a 0.824 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.604sec(train) 3.666sec(infer)
# Epoch 150 tst: l 0.654 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.753sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 151 tr: l 0.505 a 0.826 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.991sec(train) 4.442sec(infer)
# Epoch 151 tst: l 0.650 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.845sec
# Epoch 152 tr: l 0.503 a 0.826 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.842sec(train) 4.431sec(infer)
# Epoch 152 tst: l 0.648 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.821sec
# Epoch 153 tr: l 0.501 a 0.828 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.828sec(train) 2.657sec(infer)
# Epoch 153 tst: l 0.647 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.762sec
# Epoch 154 tr: l 0.500 a 0.828 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.525sec(train) 3.728sec(infer)
# Epoch 154 tst: l 0.645 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.684sec
# Epoch 155 tr: l 0.497 a 0.828 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.200sec(train) 3.801sec(infer)
# Epoch 155 tst: l 0.645 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.722sec
# Epoch 156 tr: l 0.499 a 0.828 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.322sec(train) 3.557sec(infer)
# Epoch 156 tst: l 0.645 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.643sec
# Epoch 157 tr: l 0.496 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.814sec(train) 3.575sec(infer)
# Epoch 157 tst: l 0.644 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.730sec
# Epoch 158 tr: l 0.496 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.774sec(train) 6.080sec(infer)
# Epoch 158 tst: l 0.643 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.198sec
# Epoch 159 tr: l 0.495 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.717sec(train) 3.669sec(infer)
# Epoch 159 tst: l 0.645 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.868sec
# Epoch 160 tr: l 0.493 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.297sec(train) 3.554sec(infer)
# Epoch 160 tst: l 0.640 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.636sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 161 tr: l 0.493 a 0.830 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.030sec(train) 3.099sec(infer)
# Epoch 161 tst: l 0.643 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.413sec
# Epoch 162 tr: l 0.489 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.812sec(train) 4.069sec(infer)
# Epoch 162 tst: l 0.639 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.729sec
# Epoch 163 tr: l 0.491 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.598sec(train) 3.690sec(infer)
# Epoch 163 tst: l 0.643 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.082sec
# Epoch 164 tr: l 0.489 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.878sec(train) 4.439sec(infer)
# Epoch 164 tst: l 0.642 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.862sec
# Epoch 165 tr: l 0.490 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.062sec(train) 3.934sec(infer)
# Epoch 165 tst: l 0.641 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.526sec
# Epoch 166 tr: l 0.485 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.793sec(train) 3.700sec(infer)
# Epoch 166 tst: l 0.640 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.735sec
# Epoch 167 tr: l 0.483 a 0.832 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.546sec(train) 3.380sec(infer)
# Epoch 167 tst: l 0.634 a 0.813 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.666sec
# Epoch 168 tr: l 0.480 a 0.832 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.278sec(train) 2.833sec(infer)
# Epoch 168 tst: l 0.636 a 0.812 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.734sec
# Epoch 169 tr: l 0.477 a 0.834 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.890sec(train) 3.446sec(infer)
# Epoch 169 tst: l 0.630 a 0.813 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.666sec
# Epoch 170 tr: l 0.475 a 0.835 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.710sec(train) 4.472sec(infer)
# Epoch 170 tst: l 0.632 a 0.812 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.857sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 171 tr: l 0.474 a 0.835 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.731sec(train) 5.489sec(infer)
# Epoch 171 tst: l 0.628 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.865sec
# Epoch 172 tr: l 0.472 a 0.835 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.651sec(train) 2.743sec(infer)
# Epoch 172 tst: l 0.629 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.805sec
# Epoch 173 tr: l 0.471 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.939sec(train) 3.585sec(infer)
# Epoch 173 tst: l 0.629 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.660sec
# Epoch 174 tr: l 0.470 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.706sec(train) 3.447sec(infer)
# Epoch 174 tst: l 0.626 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.917sec
# Epoch 175 tr: l 0.469 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.880sec(train) 3.103sec(infer)
# Epoch 175 tst: l 0.629 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.591sec
# Epoch 176 tr: l 0.467 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.470sec(train) 3.973sec(infer)
# Epoch 176 tst: l 0.623 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.750sec
# Epoch 177 tr: l 0.468 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.572sec(train) 6.132sec(infer)
# Epoch 177 tst: l 0.630 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.154sec
# Epoch 178 tr: l 0.466 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.834sec(train) 3.228sec(infer)
# Epoch 178 tst: l 0.624 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.915sec
# Epoch 179 tr: l 0.467 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.843sec(train) 3.044sec(infer)
# Epoch 179 tst: l 0.630 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.715sec
# Epoch 180 tr: l 0.463 a 0.838 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.764sec(train) 3.368sec(infer)
# Epoch 180 tst: l 0.621 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.639sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 181 tr: l 0.461 a 0.838 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.003sec(train) 3.559sec(infer)
# Epoch 181 tst: l 0.625 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.703sec
# Epoch 182 tr: l 0.457 a 0.840 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.968sec(train) 3.444sec(infer)
# Epoch 182 tst: l 0.616 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.657sec
# Epoch 183 tr: l 0.458 a 0.839 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.877sec(train) 4.335sec(infer)
# Epoch 183 tst: l 0.623 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.136sec
# Epoch 184 tr: l 0.454 a 0.840 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.193sec(train) 4.035sec(infer)
# Epoch 184 tst: l 0.614 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.674sec
# Epoch 185 tr: l 0.455 a 0.840 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.506sec(train) 3.981sec(infer)
# Epoch 185 tst: l 0.621 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.754sec
# Epoch 186 tr: l 0.452 a 0.841 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.103sec(train) 3.185sec(infer)
# Epoch 186 tst: l 0.613 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.624sec
# Epoch 187 tr: l 0.453 a 0.841 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.200sec(train) 3.026sec(infer)
# Epoch 187 tst: l 0.620 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.732sec
# Epoch 188 tr: l 0.448 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.724sec(train) 3.480sec(infer)
# Epoch 188 tst: l 0.611 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.702sec
# Epoch 189 tr: l 0.449 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.843sec(train) 4.472sec(infer)
# Epoch 189 tst: l 0.616 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.129sec
# Epoch 190 tr: l 0.445 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.064sec(train) 5.062sec(infer)
# Epoch 190 tst: l 0.611 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.780sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 191 tr: l 0.445 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.806sec(train) 2.452sec(infer)
# Epoch 191 tst: l 0.612 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.730sec
# Epoch 192 tr: l 0.443 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.068sec(train) 3.601sec(infer)
# Epoch 192 tst: l 0.611 a 0.822 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.696sec
# Epoch 193 tr: l 0.443 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 9.762sec(train) 3.497sec(infer)
# Epoch 193 tst: l 0.610 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.994sec
# Epoch 194 tr: l 0.443 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.796sec(train) 3.538sec(infer)
# Epoch 194 tst: l 0.614 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.679sec
# Epoch 195 tr: l 0.446 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.830sec(train) 3.643sec(infer)
# Epoch 195 tst: l 0.610 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.693sec
# Epoch 196 tr: l 0.447 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.134sec(train) 5.915sec(infer)
# Epoch 196 tst: l 0.619 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.247sec
# Epoch 197 tr: l 0.449 a 0.841 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.916sec(train) 3.119sec(infer)
# Epoch 197 tst: l 0.613 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.792sec
# Epoch 198 tr: l 0.443 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.582sec(train) 3.354sec(infer)
# Epoch 198 tst: l 0.616 a 0.822 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.778sec
# Epoch 199 tr: l 0.441 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.500sec(train) 3.220sec(infer)
# Epoch 199 tst: l 0.608 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.649sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# ---train cluster Ended in 0.93 hour (3346.612 sec)
# ---------------------------------IFCA, lr: 0.1, seed: 409---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 3.849 a 0.026 clct[np.int64(113), np.int64(87)] cl_acc 0.505  3.505sec
# Epoch -1 tst: l 3.849 a 0.027 clct[np.int64(25), np.int64(15)] cl_acc 0.575  0.707sec
# Epoch 0 tr: l 3.842 a 0.039 clct[np.int64(158), np.int64(42)] cl_acc 0.540  lr 0.100000 10.898sec(train) 3.163sec(infer)
# Epoch 0 tst: l 3.842 a 0.037 clct[np.int64(36), np.int64(4)] cl_acc 0.500  0.650sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 1 tr: l 3.831 a 0.048 clct[np.int64(185), np.int64(15)] cl_acc 0.535  lr 0.100000 11.576sec(train) 4.133sec(infer)
# Epoch 1 tst: l 3.831 a 0.046 clct[np.int64(38), np.int64(2)] cl_acc 0.500  0.829sec
# Epoch 2 tr: l 3.814 a 0.050 clct[np.int64(190), np.int64(10)] cl_acc 0.530  lr 0.100000 14.088sec(train) 5.143sec(infer)
# Epoch 2 tst: l 3.816 a 0.050 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.200sec
# Epoch 3 tr: l 3.786 a 0.062 clct[np.int64(194), np.int64(6)] cl_acc 0.510  lr 0.100000 15.032sec(train) 3.317sec(infer)
# Epoch 3 tst: l 3.793 a 0.062 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.726sec
# Epoch 4 tr: l 3.743 a 0.074 clct[np.int64(198), np.int64(2)] cl_acc 0.500  lr 0.100000 10.478sec(train) 3.245sec(infer)
# Epoch 4 tst: l 3.755 a 0.075 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.620sec
# Epoch 5 tr: l 3.672 a 0.109 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 10.895sec(train) 3.183sec(infer)
# Epoch 5 tst: l 3.692 a 0.111 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.742sec
# Epoch 6 tr: l 3.560 a 0.145 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 10.629sec(train) 3.811sec(infer)
# Epoch 6 tst: l 3.581 a 0.144 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.660sec
# Epoch 7 tr: l 3.378 a 0.180 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 11.851sec(train) 3.672sec(infer)
# Epoch 7 tst: l 3.400 a 0.179 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.854sec
# Epoch 8 tr: l 3.211 a 0.195 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 12.589sec(train) 4.564sec(infer)
# Epoch 8 tst: l 3.235 a 0.194 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.845sec
# Epoch 9 tr: l 3.164 a 0.184 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 15.993sec(train) 4.454sec(infer)
# Epoch 9 tst: l 3.186 a 0.178 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.841sec
# Epoch 10 tr: l 3.028 a 0.201 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 10.336sec(train) 3.530sec(infer)
# Epoch 10 tst: l 3.051 a 0.204 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.641sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 11 tr: l 2.974 a 0.189 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 11.804sec(train) 3.389sec(infer)
# Epoch 11 tst: l 2.998 a 0.187 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.659sec
# Epoch 12 tr: l 2.858 a 0.228 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 11.279sec(train) 3.685sec(infer)
# Epoch 12 tst: l 2.882 a 0.226 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.596sec
# ...
# Epoch 127 tr: l 0.841 a 0.715 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.354sec(train) 3.262sec(infer)
# Epoch 127 tst: l 0.936 a 0.706 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.637sec
# Epoch 128 tr: l 0.834 a 0.720 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.500sec(train) 2.848sec(infer)
# Epoch 128 tst: l 0.931 a 0.707 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.755sec
# Epoch 129 tr: l 0.830 a 0.718 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.034sec(train) 3.568sec(infer)
# Epoch 129 tst: l 0.926 a 0.708 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.584sec
# Epoch 130 tr: l 0.824 a 0.723 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.948sec(train) 3.614sec(infer)
# Epoch 130 tst: l 0.922 a 0.710 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.041sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 131 tr: l 0.823 a 0.722 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.218sec(train) 4.075sec(infer)
# Epoch 131 tst: l 0.919 a 0.710 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.724sec
# Epoch 132 tr: l 0.818 a 0.724 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.013sec(train) 4.209sec(infer)
# Epoch 132 tst: l 0.918 a 0.713 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.162sec
# Epoch 133 tr: l 0.823 a 0.721 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 16.182sec(train) 4.288sec(infer)
# Epoch 133 tst: l 0.919 a 0.709 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.573sec
# Epoch 134 tr: l 0.828 a 0.721 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.646sec(train) 3.606sec(infer)
# Epoch 134 tst: l 0.929 a 0.710 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.989sec
# Epoch 135 tr: l 0.814 a 0.724 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.572sec(train) 3.913sec(infer)
# Epoch 135 tst: l 0.910 a 0.711 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.694sec
# Epoch 136 tr: l 0.810 a 0.726 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.565sec(train) 3.140sec(infer)
# Epoch 136 tst: l 0.912 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.523sec
# Epoch 137 tr: l 0.802 a 0.728 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.889sec(train) 4.124sec(infer)
# Epoch 137 tst: l 0.899 a 0.717 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.784sec
# Epoch 138 tr: l 0.799 a 0.729 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.557sec(train) 3.669sec(infer)
# Epoch 138 tst: l 0.904 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.965sec
# Epoch 139 tr: l 0.804 a 0.727 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 17.097sec(train) 4.898sec(infer)
# Epoch 139 tst: l 0.903 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.843sec
# Epoch 140 tr: l 0.802 a 0.727 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.255sec(train) 3.186sec(infer)
# Epoch 140 tst: l 0.907 a 0.712 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.522sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 141 tr: l 0.801 a 0.727 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.432sec(train) 4.033sec(infer)
# Epoch 141 tst: l 0.901 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.722sec
# Epoch 142 tr: l 0.798 a 0.728 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.445sec(train) 3.187sec(infer)
# Epoch 142 tst: l 0.902 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.585sec
# Epoch 143 tr: l 0.799 a 0.727 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.732sec(train) 3.116sec(infer)
# Epoch 143 tst: l 0.899 a 0.714 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.807sec
# Epoch 144 tr: l 0.791 a 0.730 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.780sec(train) 4.304sec(infer)
# Epoch 144 tst: l 0.895 a 0.715 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.678sec
# Epoch 145 tr: l 0.787 a 0.730 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.250sec(train) 5.250sec(infer)
# Epoch 145 tst: l 0.889 a 0.715 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.441sec
# Epoch 146 tr: l 0.785 a 0.731 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 14.918sec(train) 3.188sec(infer)
# Epoch 146 tst: l 0.889 a 0.717 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.559sec
# Epoch 147 tr: l 0.781 a 0.732 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.462sec(train) 2.807sec(infer)
# Epoch 147 tst: l 0.883 a 0.717 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.739sec
# Epoch 148 tr: l 0.780 a 0.732 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.918sec(train) 3.799sec(infer)
# Epoch 148 tst: l 0.886 a 0.718 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.617sec
# Epoch 149 tr: l 0.779 a 0.732 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.168sec(train) 3.440sec(infer)
# Epoch 149 tst: l 0.882 a 0.717 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.935sec
# Epoch 150 tr: l 0.777 a 0.734 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.905sec(train) 3.707sec(infer)
# Epoch 150 tst: l 0.882 a 0.720 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.661sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 151 tr: l 0.771 a 0.736 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.004sec(train) 3.667sec(infer)
# Epoch 151 tst: l 0.874 a 0.720 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.650sec
# Epoch 152 tr: l 0.767 a 0.738 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 16.736sec(train) 5.206sec(infer)
# Epoch 152 tst: l 0.874 a 0.724 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.825sec
# Epoch 153 tr: l 0.762 a 0.738 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.667sec(train) 3.580sec(infer)
# Epoch 153 tst: l 0.867 a 0.722 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.937sec
# Epoch 154 tr: l 0.762 a 0.739 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.954sec(train) 3.542sec(infer)
# Epoch 154 tst: l 0.870 a 0.725 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.626sec
# Epoch 155 tr: l 0.759 a 0.739 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.056sec(train) 3.093sec(infer)
# Epoch 155 tst: l 0.864 a 0.724 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.671sec
# Epoch 156 tr: l 0.756 a 0.741 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.058sec(train) 3.771sec(infer)
# Epoch 156 tst: l 0.864 a 0.727 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.823sec
# Epoch 157 tr: l 0.756 a 0.740 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.460sec(train) 3.930sec(infer)
# Epoch 157 tst: l 0.863 a 0.726 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.807sec
# Epoch 158 tr: l 0.755 a 0.740 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 15.430sec(train) 5.754sec(infer)
# Epoch 158 tst: l 0.863 a 0.726 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.903sec
# Epoch 159 tr: l 0.755 a 0.741 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.486sec(train) 3.138sec(infer)
# Epoch 159 tst: l 0.863 a 0.727 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.655sec
# Epoch 160 tr: l 0.750 a 0.741 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.476sec(train) 4.053sec(infer)
# Epoch 160 tst: l 0.859 a 0.726 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.727sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 161 tr: l 0.754 a 0.741 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.705sec(train) 3.413sec(infer)
# Epoch 161 tst: l 0.863 a 0.727 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.639sec
# Epoch 162 tr: l 0.747 a 0.743 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.667sec(train) 2.919sec(infer)
# Epoch 162 tst: l 0.857 a 0.728 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.705sec
# Epoch 163 tr: l 0.750 a 0.743 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.670sec(train) 3.796sec(infer)
# Epoch 163 tst: l 0.859 a 0.730 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.686sec
# Epoch 164 tr: l 0.742 a 0.745 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.369sec(train) 5.330sec(infer)
# Epoch 164 tst: l 0.852 a 0.729 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.064sec
# Epoch 165 tr: l 0.742 a 0.745 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 15.528sec(train) 3.954sec(infer)
# Epoch 165 tst: l 0.853 a 0.729 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.668sec
# Epoch 166 tr: l 0.736 a 0.746 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.517sec(train) 2.918sec(infer)
# Epoch 166 tst: l 0.848 a 0.729 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.824sec
# Epoch 167 tr: l 0.736 a 0.745 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.573sec(train) 3.533sec(infer)
# Epoch 167 tst: l 0.847 a 0.731 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.562sec
# Epoch 168 tr: l 0.733 a 0.747 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.624sec(train) 3.601sec(infer)
# Epoch 168 tst: l 0.845 a 0.729 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.948sec
# Epoch 169 tr: l 0.731 a 0.746 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.537sec(train) 3.705sec(infer)
# Epoch 169 tst: l 0.843 a 0.732 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.686sec
# Epoch 170 tr: l 0.729 a 0.748 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.158sec(train) 3.968sec(infer)
# Epoch 170 tst: l 0.841 a 0.732 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.757sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 171 tr: l 0.726 a 0.748 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 17.188sec(train) 4.783sec(infer)
# Epoch 171 tst: l 0.837 a 0.734 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.749sec
# Epoch 172 tr: l 0.724 a 0.749 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.618sec(train) 3.328sec(infer)
# Epoch 172 tst: l 0.837 a 0.733 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.953sec
# Epoch 173 tr: l 0.723 a 0.748 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.837sec(train) 3.569sec(infer)
# Epoch 173 tst: l 0.835 a 0.732 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.627sec
# Epoch 174 tr: l 0.719 a 0.750 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.206sec(train) 3.358sec(infer)
# Epoch 174 tst: l 0.833 a 0.735 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.718sec
# Epoch 175 tr: l 0.720 a 0.749 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.077sec(train) 4.182sec(infer)
# Epoch 175 tst: l 0.831 a 0.734 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.740sec
# Epoch 176 tr: l 0.714 a 0.752 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.327sec(train) 3.665sec(infer)
# Epoch 176 tst: l 0.830 a 0.737 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.910sec
# Epoch 177 tr: l 0.715 a 0.750 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 14.176sec(train) 4.536sec(infer)
# Epoch 177 tst: l 0.828 a 0.736 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.982sec
# Epoch 178 tr: l 0.714 a 0.752 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 15.392sec(train) 3.221sec(infer)
# Epoch 178 tst: l 0.830 a 0.736 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.671sec
# Epoch 179 tr: l 0.713 a 0.752 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.346sec(train) 4.211sec(infer)
# Epoch 179 tst: l 0.826 a 0.736 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.790sec
# Epoch 180 tr: l 0.711 a 0.753 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.154sec(train) 3.197sec(infer)
# Epoch 180 tst: l 0.828 a 0.736 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.703sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 181 tr: l 0.709 a 0.753 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.742sec(train) 2.796sec(infer)
# Epoch 181 tst: l 0.823 a 0.736 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.708sec
# Epoch 182 tr: l 0.705 a 0.754 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.434sec(train) 3.530sec(infer)
# Epoch 182 tst: l 0.823 a 0.738 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.696sec
# Epoch 183 tr: l 0.704 a 0.754 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.446sec(train) 5.347sec(infer)
# Epoch 183 tst: l 0.820 a 0.737 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.288sec
# Epoch 184 tr: l 0.702 a 0.755 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 16.968sec(train) 3.984sec(infer)
# Epoch 184 tst: l 0.821 a 0.738 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.771sec
# Epoch 185 tr: l 0.705 a 0.754 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.808sec(train) 2.893sec(infer)
# Epoch 185 tst: l 0.819 a 0.737 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.715sec
# Epoch 186 tr: l 0.700 a 0.757 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.100sec(train) 3.347sec(infer)
# Epoch 186 tst: l 0.819 a 0.739 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.595sec
# Epoch 187 tr: l 0.701 a 0.755 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.797sec(train) 3.887sec(infer)
# Epoch 187 tst: l 0.817 a 0.740 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.775sec
# Epoch 188 tr: l 0.700 a 0.756 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.655sec(train) 3.793sec(infer)
# Epoch 188 tst: l 0.820 a 0.738 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.706sec
# Epoch 189 tr: l 0.698 a 0.756 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.589sec(train) 3.566sec(infer)
# Epoch 189 tst: l 0.816 a 0.740 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.903sec
# Epoch 190 tr: l 0.695 a 0.758 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 14.918sec(train) 5.493sec(infer)
# Epoch 190 tst: l 0.814 a 0.739 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.720sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 191 tr: l 0.691 a 0.758 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.144sec(train) 3.858sec(infer)
# Epoch 191 tst: l 0.809 a 0.742 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.714sec
# Epoch 192 tr: l 0.689 a 0.759 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.303sec(train) 3.417sec(infer)
# Epoch 192 tst: l 0.809 a 0.741 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.665sec
# Epoch 193 tr: l 0.687 a 0.759 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 12.484sec(train) 2.818sec(infer)
# Epoch 193 tst: l 0.808 a 0.742 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.724sec
# Epoch 194 tr: l 0.685 a 0.760 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.063sec(train) 3.573sec(infer)
# Epoch 194 tst: l 0.805 a 0.742 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.583sec
# Epoch 195 tr: l 0.684 a 0.760 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.973sec(train) 3.865sec(infer)
# Epoch 195 tst: l 0.805 a 0.744 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.070sec
# Epoch 196 tr: l 0.682 a 0.762 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 13.096sec(train) 5.397sec(infer)
# Epoch 196 tst: l 0.802 a 0.744 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.979sec
# Epoch 197 tr: l 0.682 a 0.761 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 16.798sec(train) 3.579sec(infer)
# Epoch 197 tst: l 0.804 a 0.744 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.735sec
# Epoch 198 tr: l 0.679 a 0.762 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 11.207sec(train) 3.589sec(infer)
# Epoch 198 tst: l 0.800 a 0.744 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.608sec
# Epoch 199 tr: l 0.682 a 0.760 clct[np.int64(197), np.int64(3)] cl_acc 0.505  lr 0.100000 10.407sec(train) 3.232sec(infer)
# Epoch 199 tst: l 0.805 a 0.743 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.940sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# ---train cluster Ended in 0.94 hour (3395.681 sec)

# %%
__.display_outputs()
# Out:
# ---------------------------------DFCA-LI, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'local_model_init': True, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_li'}
# Using device: cuda
# Epoch -1 tr: l 3.850 a 0.023 clct[np.int64(95), np.int64(105)] cl_acc 0.545  11.227sec
# Epoch -1 tst: l 3.849 a 0.026 clct[np.int64(21), np.int64(19)] cl_acc 0.525  1.320sec
# Epoch 0 tr: l 3.849 a 0.023 clct[np.int64(103), np.int64(97)] cl_acc 0.535  lr 0.100000 17.137sec(train) 4.009sec(infer)
# Epoch 0 tst: l 3.850 a 0.024 clct[np.int64(20), np.int64(20)] cl_acc 0.600  1.830sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 1 tr: l 3.850 a 0.023 clct[np.int64(101), np.int64(99)] cl_acc 0.515  lr 0.100000 14.641sec(train) 3.917sec(infer)
# Epoch 1 tst: l 3.850 a 0.024 clct[np.int64(19), np.int64(21)] cl_acc 0.575  1.219sec
# Epoch 2 tr: l 3.850 a 0.023 clct[np.int64(102), np.int64(98)] cl_acc 0.510  lr 0.100000 15.544sec(train) 3.507sec(infer)
# Epoch 2 tst: l 3.850 a 0.025 clct[np.int64(19), np.int64(21)] cl_acc 0.575  2.239sec
# Epoch 3 tr: l 3.850 a 0.023 clct[np.int64(103), np.int64(97)] cl_acc 0.515  lr 0.100000 17.075sec(train) 5.742sec(infer)
# Epoch 3 tst: l 3.850 a 0.024 clct[np.int64(20), np.int64(20)] cl_acc 0.600  2.855sec
# Epoch 4 tr: l 3.850 a 0.024 clct[np.int64(101), np.int64(99)] cl_acc 0.505  lr 0.100000 18.836sec(train) 4.046sec(infer)
# Epoch 4 tst: l 3.850 a 0.024 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.966sec
# Epoch 5 tr: l 3.850 a 0.023 clct[np.int64(101), np.int64(99)] cl_acc 0.505  lr 0.100000 15.037sec(train) 3.904sec(infer)
# Epoch 5 tst: l 3.850 a 0.024 clct[np.int64(22), np.int64(18)] cl_acc 0.650  2.206sec
# Epoch 6 tr: l 3.850 a 0.023 clct[np.int64(101), np.int64(99)] cl_acc 0.505  lr 0.100000 15.363sec(train) 4.585sec(infer)
# Epoch 6 tst: l 3.850 a 0.024 clct[np.int64(22), np.int64(18)] cl_acc 0.650  1.847sec
# Epoch 7 tr: l 3.850 a 0.023 clct[np.int64(100), np.int64(100)] cl_acc 0.500  lr 0.100000 14.044sec(train) 4.182sec(infer)
# Epoch 7 tst: l 3.850 a 0.024 clct[np.int64(24), np.int64(16)] cl_acc 0.600  1.548sec
# Epoch 8 tr: l 3.850 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.505  lr 0.100000 17.278sec(train) 6.736sec(infer)
# Epoch 8 tst: l 3.850 a 0.024 clct[np.int64(21), np.int64(19)] cl_acc 0.675  4.170sec
# Epoch 9 tr: l 3.850 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.505  lr 0.100000 17.257sec(train) 4.483sec(infer)
# Epoch 9 tst: l 3.850 a 0.024 clct[np.int64(21), np.int64(19)] cl_acc 0.675  1.748sec
# Epoch 10 tr: l 3.850 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.505  lr 0.100000 13.782sec(train) 3.639sec(infer)
# Epoch 10 tst: l 3.850 a 0.024 clct[np.int64(22), np.int64(18)] cl_acc 0.650  1.552sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 11 tr: l 3.850 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.510  lr 0.100000 15.825sec(train) 4.713sec(infer)
# Epoch 11 tst: l 3.850 a 0.024 clct[np.int64(21), np.int64(19)] cl_acc 0.675  2.082sec
# Epoch 12 tr: l 3.850 a 0.024 clct[np.int64(98), np.int64(102)] cl_acc 0.510  lr 0.100000 16.242sec(train) 5.178sec(infer)
# Epoch 12 tst: l 3.850 a 0.024 clct[np.int64(23), np.int64(17)] cl_acc 0.625  1.226sec
# Epoch 13 tr: l 3.850 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.510  lr 0.100000 20.127sec(train) 3.813sec(infer)
# Epoch 13 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.650  2.036sec
# Epoch 14 tr: l 3.850 a 0.024 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 14.818sec(train) 4.606sec(infer)
# Epoch 14 tst: l 3.850 a 0.024 clct[np.int64(23), np.int64(17)] cl_acc 0.625  2.064sec
# Epoch 15 tr: l 3.849 a 0.024 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 14.798sec(train) 4.711sec(infer)
# Epoch 15 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.625  1.320sec
# Epoch 16 tr: l 3.849 a 0.024 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 14.769sec(train) 3.664sec(infer)
# Epoch 16 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.625  2.313sec
# Epoch 17 tr: l 3.849 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 16.488sec(train) 5.613sec(infer)
# Epoch 17 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.625  3.768sec
# Epoch 18 tr: l 3.849 a 0.024 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 19.508sec(train) 4.056sec(infer)
# Epoch 18 tst: l 3.850 a 0.025 clct[np.int64(24), np.int64(16)] cl_acc 0.600  1.066sec
# Epoch 19 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 15.878sec(train) 4.351sec(infer)
# Epoch 19 tst: l 3.850 a 0.025 clct[np.int64(24), np.int64(16)] cl_acc 0.600  1.754sec
# Epoch 20 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 14.087sec(train) 4.620sec(infer)
# Epoch 20 tst: l 3.850 a 0.025 clct[np.int64(24), np.int64(16)] cl_acc 0.600  1.284sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 21 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.515  lr 0.100000 14.225sec(train) 4.043sec(infer)
# Epoch 21 tst: l 3.850 a 0.025 clct[np.int64(24), np.int64(16)] cl_acc 0.600  2.424sec
# Epoch 22 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 18.420sec(train) 7.293sec(infer)
# Epoch 22 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  3.755sec
# Epoch 23 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 14.305sec(train) 4.643sec(infer)
# Epoch 23 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  1.690sec
# Epoch 24 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 14.234sec(train) 3.304sec(infer)
# Epoch 24 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.231sec
# Epoch 25 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.515  lr 0.100000 16.460sec(train) 4.827sec(infer)
# Epoch 25 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.074sec
# Epoch 26 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.066sec(train) 4.976sec(infer)
# Epoch 26 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  1.633sec
# Epoch 27 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 20.312sec(train) 3.594sec(infer)
# Epoch 27 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.269sec
# Epoch 28 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.610sec(train) 4.910sec(infer)
# Epoch 28 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.362sec
# Epoch 29 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.341sec(train) 4.189sec(infer)
# Epoch 29 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.550  1.273sec
# Epoch 30 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.797sec(train) 4.160sec(infer)
# Epoch 30 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.498sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 31 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 16.146sec(train) 6.508sec(infer)
# Epoch 31 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  4.117sec
# Epoch 32 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 18.535sec(train) 3.466sec(infer)
# Epoch 32 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  1.012sec
# Epoch 33 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.923sec(train) 4.281sec(infer)
# Epoch 33 tst: l 3.850 a 0.025 clct[np.int64(24), np.int64(16)] cl_acc 0.550  1.870sec
# Epoch 34 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.389sec(train) 4.976sec(infer)
# Epoch 34 tst: l 3.850 a 0.025 clct[np.int64(25), np.int64(15)] cl_acc 0.575  1.113sec
# Epoch 35 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.530sec(train) 3.654sec(infer)
# Epoch 35 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.563sec
# Epoch 36 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.634sec(train) 7.568sec(infer)
# Epoch 36 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  3.661sec
# Epoch 37 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.140sec(train) 4.776sec(infer)
# Epoch 37 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  1.596sec
# Epoch 38 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.037sec(train) 3.398sec(infer)
# Epoch 38 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.244sec
# Epoch 39 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.611sec(train) 4.634sec(infer)
# Epoch 39 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.128sec
# Epoch 40 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.997sec(train) 5.126sec(infer)
# Epoch 40 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.734sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 41 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 21.789sec(train) 3.713sec(infer)
# Epoch 41 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.444sec
# Epoch 42 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.228sec(train) 4.584sec(infer)
# Epoch 42 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.045sec
# Epoch 43 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.275sec(train) 3.905sec(infer)
# Epoch 43 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.369sec
# Epoch 44 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.614sec(train) 4.457sec(infer)
# Epoch 44 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.621sec
# Epoch 45 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.986sec(train) 6.364sec(infer)
# Epoch 45 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  3.491sec
# Epoch 46 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 18.390sec(train) 2.974sec(infer)
# Epoch 46 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.308sec
# Epoch 47 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.308sec(train) 4.790sec(infer)
# Epoch 47 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.016sec
# Epoch 48 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.270sec(train) 4.252sec(infer)
# Epoch 48 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  0.991sec
# Epoch 49 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.116sec(train) 3.919sec(infer)
# Epoch 49 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.481sec
# Epoch 50 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.949sec(train) 7.863sec(infer)
# Epoch 50 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  3.443sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 51 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.641sec(train) 4.572sec(infer)
# Epoch 51 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  0.967sec
# Epoch 52 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.794sec(train) 3.784sec(infer)
# Epoch 52 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.963sec
# Epoch 53 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.498sec(train) 4.650sec(infer)
# Epoch 53 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.010sec
# Epoch 54 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.883sec(train) 4.721sec(infer)
# Epoch 54 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.007sec
# Epoch 55 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 21.571sec(train) 3.909sec(infer)
# Epoch 55 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.150sec
# Epoch 56 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.650sec(train) 4.637sec(infer)
# Epoch 56 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.759sec
# Epoch 57 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.184sec(train) 3.733sec(infer)
# Epoch 57 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.813sec
# Epoch 58 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.225sec(train) 4.980sec(infer)
# Epoch 58 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.327sec
# Epoch 59 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.262sec(train) 7.222sec(infer)
# Epoch 59 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.076sec
# Epoch 60 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 18.262sec(train) 3.315sec(infer)
# Epoch 60 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.109sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 61 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.963sec(train) 4.372sec(infer)
# Epoch 61 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.870sec
# Epoch 62 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.405sec(train) 3.675sec(infer)
# Epoch 62 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  0.990sec
# Epoch 63 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.376sec(train) 5.092sec(infer)
# Epoch 63 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.639sec
# Epoch 64 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 19.037sec(train) 7.247sec(infer)
# Epoch 64 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.279sec
# Epoch 65 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 13.908sec(train) 3.775sec(infer)
# Epoch 65 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.343sec
# Epoch 66 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.650sec(train) 4.728sec(infer)
# Epoch 66 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.049sec
# Epoch 67 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 15.520sec(train) 4.758sec(infer)
# Epoch 67 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  0.992sec
# Epoch 68 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 16.154sec(train) 3.648sec(infer)
# Epoch 68 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.512sec
# Epoch 69 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 21.839sec(train) 4.525sec(infer)
# Epoch 69 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.891sec
# Epoch 70 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.072sec(train) 4.291sec(infer)
# Epoch 70 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.072sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 71 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.426sec(train) 4.071sec(infer)
# Epoch 71 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.853sec
# Epoch 72 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.179sec(train) 5.245sec(infer)
# Epoch 72 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.158sec
# Epoch 73 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.843sec(train) 6.844sec(infer)
# Epoch 73 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.943sec
# Epoch 74 tr: l 3.848 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 18.723sec(train) 4.362sec(infer)
# Epoch 74 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.823sec
# Epoch 75 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.299sec(train) 4.412sec(infer)
# Epoch 75 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.263sec
# Epoch 76 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.373sec(train) 3.528sec(infer)
# Epoch 76 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.033sec
# Epoch 77 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 16.651sec(train) 5.311sec(infer)
# Epoch 77 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.337sec
# Epoch 78 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 18.385sec(train) 7.072sec(infer)
# Epoch 78 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.294sec
# Epoch 79 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.426sec(train) 3.500sec(infer)
# Epoch 79 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.432sec
# Epoch 80 tr: l 3.848 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 15.539sec(train) 4.710sec(infer)
# Epoch 80 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.139sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 81 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 13.883sec(train) 4.123sec(infer)
# Epoch 81 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.445sec
# Epoch 82 tr: l 3.848 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 16.813sec(train) 4.472sec(infer)
# Epoch 82 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.471sec
# Epoch 83 tr: l 3.848 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 21.584sec(train) 4.847sec(infer)
# Epoch 83 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.929sec
# Epoch 84 tr: l 3.848 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 13.933sec(train) 3.773sec(infer)
# Epoch 84 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.244sec
# Epoch 85 tr: l 3.848 a 0.023 clct[np.int64(95), np.int64(105)] cl_acc 0.505  lr 0.100000 15.431sec(train) 4.482sec(infer)
# Epoch 85 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.853sec
# Epoch 86 tr: l 3.848 a 0.023 clct[np.int64(95), np.int64(105)] cl_acc 0.505  lr 0.100000 14.828sec(train) 5.551sec(infer)
# Epoch 86 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.964sec
# Epoch 87 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.279sec(train) 5.842sec(infer)
# Epoch 87 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.727sec
# Epoch 88 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 18.617sec(train) 4.338sec(infer)
# Epoch 88 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.813sec
# Epoch 89 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.833sec(train) 4.567sec(infer)
# Epoch 89 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.071sec
# Epoch 90 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.334sec(train) 3.638sec(infer)
# Epoch 90 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.010sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 91 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.799sec(train) 5.151sec(infer)
# Epoch 91 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.451sec
# Epoch 92 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 18.200sec(train) 7.066sec(infer)
# Epoch 92 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.470sec
# Epoch 93 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.015sec(train) 3.705sec(infer)
# Epoch 93 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.033sec
# Epoch 94 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.373sec(train) 4.612sec(infer)
# Epoch 94 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  2.038sec
# Epoch 95 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 13.938sec(train) 3.777sec(infer)
# Epoch 95 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.423sec
# Epoch 96 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 18.572sec(train) 5.311sec(infer)
# Epoch 96 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  3.465sec
# Epoch 97 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 19.523sec(train) 4.458sec(infer)
# Epoch 97 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.426sec
# Epoch 98 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 13.941sec(train) 3.353sec(infer)
# Epoch 98 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.636sec
# Epoch 99 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.043sec(train) 4.933sec(infer)
# Epoch 99 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.989sec
# Epoch 100 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.368sec(train) 5.275sec(infer)
# Epoch 100 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.382sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 101 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 17.832sec(train) 5.410sec(infer)
# Epoch 101 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.042sec
# Epoch 102 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.937sec(train) 4.800sec(infer)
# Epoch 102 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.058sec
# Epoch 103 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.088sec(train) 4.088sec(infer)
# Epoch 103 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.979sec
# Epoch 104 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.202sec(train) 4.114sec(infer)
# Epoch 104 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.600  1.852sec
# Epoch 105 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.226sec(train) 5.713sec(infer)
# Epoch 105 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.448sec
# Epoch 106 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 20.262sec(train) 4.737sec(infer)
# Epoch 106 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.245sec
# Epoch 107 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.643sec(train) 4.550sec(infer)
# Epoch 107 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.840sec
# Epoch 108 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.079sec(train) 4.756sec(infer)
# Epoch 108 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.162sec
# Epoch 109 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.390sec(train) 3.640sec(infer)
# Epoch 109 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.258sec
# Epoch 110 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.454sec(train) 6.290sec(infer)
# Epoch 110 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.070sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 111 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 18.761sec(train) 4.217sec(infer)
# Epoch 111 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.964sec
# Epoch 112 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.651sec(train) 4.115sec(infer)
# Epoch 112 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.198sec
# Epoch 113 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.898sec(train) 4.608sec(infer)
# Epoch 113 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.878sec
# Epoch 114 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.237sec(train) 4.219sec(infer)
# Epoch 114 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.637sec
# Epoch 115 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 18.709sec(train) 6.625sec(infer)
# Epoch 115 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.981sec
# Epoch 116 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.113sec(train) 4.571sec(infer)
# Epoch 116 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.895sec
# Epoch 117 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 14.140sec(train) 3.626sec(infer)
# Epoch 117 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.259sec
# Epoch 118 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 15.386sec(train) 4.845sec(infer)
# Epoch 118 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.826sec
# Epoch 119 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.500  lr 0.100000 16.377sec(train) 5.355sec(infer)
# Epoch 119 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.820sec
# Epoch 120 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.865sec(train) 4.526sec(infer)
# Epoch 120 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.734sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 121 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.562sec(train) 4.697sec(infer)
# Epoch 121 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.034sec
# Epoch 122 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.144sec(train) 4.816sec(infer)
# Epoch 122 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.975sec
# Epoch 123 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.991sec(train) 3.844sec(infer)
# Epoch 123 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.187sec
# Epoch 124 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.104sec(train) 6.331sec(infer)
# Epoch 124 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.201sec
# Epoch 125 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 19.575sec(train) 4.241sec(infer)
# Epoch 125 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.071sec
# Epoch 126 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.995sec(train) 4.221sec(infer)
# Epoch 126 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.799sec
# Epoch 127 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.422sec(train) 4.461sec(infer)
# Epoch 127 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.231sec
# Epoch 128 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.015sec(train) 4.119sec(infer)
# Epoch 128 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.237sec
# Epoch 129 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.842sec(train) 6.588sec(infer)
# Epoch 129 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.258sec
# Epoch 130 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.178sec(train) 4.609sec(infer)
# Epoch 130 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.471sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 131 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 13.596sec(train) 3.486sec(infer)
# Epoch 131 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.959sec
# Epoch 132 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.061sec(train) 4.646sec(infer)
# Epoch 132 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.175sec
# Epoch 133 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.363sec(train) 5.281sec(infer)
# Epoch 133 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.629sec
# Epoch 134 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 20.314sec(train) 3.904sec(infer)
# Epoch 134 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.312sec
# Epoch 135 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.596sec(train) 4.913sec(infer)
# Epoch 135 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.018sec
# Epoch 136 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.056sec(train) 4.381sec(infer)
# Epoch 136 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.224sec
# Epoch 137 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.086sec(train) 4.114sec(infer)
# Epoch 137 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.211sec
# Epoch 138 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.826sec(train) 6.999sec(infer)
# Epoch 138 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.843sec
# Epoch 139 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.864sec(train) 3.772sec(infer)
# Epoch 139 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.972sec
# Epoch 140 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.645sec(train) 4.308sec(infer)
# Epoch 140 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.819sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 141 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.531sec(train) 4.997sec(infer)
# Epoch 141 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.427sec
# Epoch 142 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.009sec(train) 3.749sec(infer)
# Epoch 142 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.127sec
# Epoch 143 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.520sec(train) 6.574sec(infer)
# Epoch 143 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.699sec
# Epoch 144 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.322sec(train) 4.912sec(infer)
# Epoch 144 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.356sec
# Epoch 145 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.458sec(train) 3.180sec(infer)
# Epoch 145 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.366sec
# Epoch 146 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 13.900sec(train) 3.246sec(infer)
# Epoch 146 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.902sec
# Epoch 147 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.001sec(train) 5.401sec(infer)
# Epoch 147 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.251sec
# Epoch 148 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 20.375sec(train) 5.577sec(infer)
# Epoch 148 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.469sec
# Epoch 149 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.117sec(train) 3.205sec(infer)
# Epoch 149 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.282sec
# Epoch 150 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.011sec(train) 4.588sec(infer)
# Epoch 150 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.325sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 151 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.521sec(train) 4.447sec(infer)
# Epoch 151 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.759sec
# Epoch 152 tr: l 3.848 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.510  lr 0.100000 16.707sec(train) 5.312sec(infer)
# Epoch 152 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.595sec
# Epoch 153 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.334sec(train) 4.610sec(infer)
# Epoch 153 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.957sec
# Epoch 154 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.199sec(train) 4.075sec(infer)
# Epoch 154 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.538sec
# Epoch 155 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.401sec(train) 4.252sec(infer)
# Epoch 155 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.900sec
# Epoch 156 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.704sec(train) 5.341sec(infer)
# Epoch 156 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.795sec
# Epoch 157 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.321sec(train) 6.469sec(infer)
# Epoch 157 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.175sec
# Epoch 158 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.191sec(train) 4.513sec(infer)
# Epoch 158 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.794sec
# Epoch 159 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.250sec(train) 4.614sec(infer)
# Epoch 159 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.018sec
# Epoch 160 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.372sec(train) 3.540sec(infer)
# Epoch 160 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.382sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 161 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.607sec(train) 5.300sec(infer)
# Epoch 161 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.542sec
# Epoch 162 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 19.340sec(train) 5.401sec(infer)
# Epoch 162 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.288sec
# Epoch 163 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.401sec(train) 3.533sec(infer)
# Epoch 163 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.313sec
# Epoch 164 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.573sec(train) 4.930sec(infer)
# Epoch 164 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.149sec
# Epoch 165 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 13.809sec(train) 4.048sec(infer)
# Epoch 165 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.525sec
# Epoch 166 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.665sec(train) 5.980sec(infer)
# Epoch 166 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.835sec
# Epoch 167 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.660sec(train) 4.809sec(infer)
# Epoch 167 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.370sec
# Epoch 168 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.933sec(train) 3.203sec(infer)
# Epoch 168 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.435sec
# Epoch 169 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.021sec(train) 4.568sec(infer)
# Epoch 169 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.904sec
# Epoch 170 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.507sec(train) 5.608sec(infer)
# Epoch 170 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.602sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 171 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.537sec(train) 4.840sec(infer)
# Epoch 171 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.705sec
# Epoch 172 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.700sec(train) 4.549sec(infer)
# Epoch 172 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.920sec
# Epoch 173 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.447sec(train) 4.332sec(infer)
# Epoch 173 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.082sec
# Epoch 174 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.867sec(train) 3.959sec(infer)
# Epoch 174 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.992sec
# Epoch 175 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.056sec(train) 5.337sec(infer)
# Epoch 175 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.587sec
# Epoch 176 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 19.901sec(train) 4.593sec(infer)
# Epoch 176 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.224sec
# Epoch 177 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.247sec(train) 4.550sec(infer)
# Epoch 177 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.948sec
# Epoch 178 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.393sec(train) 4.569sec(infer)
# Epoch 178 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.318sec
# Epoch 179 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.105sec(train) 3.374sec(infer)
# Epoch 179 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.939sec
# Epoch 180 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.833sec(train) 6.444sec(infer)
# Epoch 180 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  4.025sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 181 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 19.163sec(train) 4.128sec(infer)
# Epoch 181 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.972sec
# Epoch 182 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.424sec(train) 3.481sec(infer)
# Epoch 182 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.990sec
# Epoch 183 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.925sec(train) 4.921sec(infer)
# Epoch 183 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.810sec
# Epoch 184 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.195sec(train) 4.801sec(infer)
# Epoch 184 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.386sec
# Epoch 185 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.595sec(train) 5.772sec(infer)
# Epoch 185 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.226sec
# Epoch 186 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.425sec(train) 4.551sec(infer)
# Epoch 186 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.158sec
# Epoch 187 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.814sec(train) 4.305sec(infer)
# Epoch 187 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.273sec
# Epoch 188 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.995sec(train) 4.081sec(infer)
# Epoch 188 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.903sec
# Epoch 189 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.746sec(train) 5.171sec(infer)
# Epoch 189 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.455sec
# Epoch 190 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 19.331sec(train) 5.877sec(infer)
# Epoch 190 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.655sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 191 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.905sec(train) 4.414sec(infer)
# Epoch 191 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.813sec
# Epoch 192 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.214sec(train) 4.616sec(infer)
# Epoch 192 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.183sec
# Epoch 193 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.231sec(train) 3.424sec(infer)
# Epoch 193 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.436sec
# Epoch 194 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 17.687sec(train) 5.618sec(infer)
# Epoch 194 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.691sec
# Epoch 195 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.882sec(train) 4.049sec(infer)
# Epoch 195 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  0.980sec
# Epoch 196 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 14.909sec(train) 3.986sec(infer)
# Epoch 196 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  2.089sec
# Epoch 197 tr: l 3.848 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 15.162sec(train) 4.867sec(infer)
# Epoch 197 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.941sec
# Epoch 198 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 13.651sec(train) 4.337sec(infer)
# Epoch 198 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  1.701sec
# Epoch 199 tr: l 3.848 a 0.024 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 16.816sec(train) 7.183sec(infer)
# Epoch 199 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.625  3.881sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# ---train cluster Ended in 1.27 hour (4573.508 sec)
# ---------------------------------DFCA-LI, lr: 0.1, seed: 409---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'local_model_init': True, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_li'}
# Using device: cuda
# Epoch -1 tr: l 3.850 a 0.022 clct[np.int64(89), np.int64(111)] cl_acc 0.525  3.364sec
# Epoch -1 tst: l 3.850 a 0.025 clct[np.int64(17), np.int64(23)] cl_acc 0.575  1.737sec
# Epoch 0 tr: l 3.849 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.505  lr 0.100000 17.504sec(train) 4.557sec(infer)
# Epoch 0 tst: l 3.850 a 0.024 clct[np.int64(17), np.int64(23)] cl_acc 0.575  2.389sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 1 tr: l 3.850 a 0.023 clct[np.int64(90), np.int64(110)] cl_acc 0.520  lr 0.100000 14.511sec(train) 4.091sec(infer)
# Epoch 1 tst: l 3.850 a 0.025 clct[np.int64(19), np.int64(21)] cl_acc 0.525  1.673sec
# Epoch 2 tr: l 3.850 a 0.023 clct[np.int64(93), np.int64(107)] cl_acc 0.505  lr 0.100000 18.056sec(train) 5.102sec(infer)
# Epoch 2 tst: l 3.850 a 0.025 clct[np.int64(22), np.int64(18)] cl_acc 0.550  3.483sec
# Epoch 3 tr: l 3.850 a 0.023 clct[np.int64(94), np.int64(106)] cl_acc 0.510  lr 0.100000 20.281sec(train) 4.677sec(infer)
# Epoch 3 tst: l 3.850 a 0.025 clct[np.int64(21), np.int64(19)] cl_acc 0.525  1.891sec
# Epoch 4 tr: l 3.850 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.510  lr 0.100000 14.113sec(train) 2.745sec(infer)
# Epoch 4 tst: l 3.850 a 0.026 clct[np.int64(22), np.int64(18)] cl_acc 0.550  1.920sec
# Epoch 5 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.500  lr 0.100000 16.240sec(train) 4.931sec(infer)
# Epoch 5 tst: l 3.850 a 0.025 clct[np.int64(23), np.int64(17)] cl_acc 0.575  2.555sec
# Epoch 6 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.500  lr 0.100000 14.530sec(train) 4.809sec(infer)
# Epoch 6 tst: l 3.850 a 0.026 clct[np.int64(21), np.int64(19)] cl_acc 0.575  1.868sec
# Epoch 7 tr: l 3.849 a 0.023 clct[np.int64(95), np.int64(105)] cl_acc 0.505  lr 0.100000 17.395sec(train) 5.925sec(infer)
# Epoch 7 tst: l 3.850 a 0.026 clct[np.int64(21), np.int64(19)] cl_acc 0.525  3.905sec
# Epoch 8 tr: l 3.849 a 0.023 clct[np.int64(96), np.int64(104)] cl_acc 0.500  lr 0.100000 15.860sec(train) 4.792sec(infer)
# Epoch 8 tst: l 3.850 a 0.026 clct[np.int64(20), np.int64(20)] cl_acc 0.550  2.428sec
# Epoch 9 tr: l 3.849 a 0.023 clct[np.int64(97), np.int64(103)] cl_acc 0.505  lr 0.100000 14.431sec(train) 4.207sec(infer)
# Epoch 9 tst: l 3.850 a 0.026 clct[np.int64(20), np.int64(20)] cl_acc 0.550  1.624sec
# Epoch 10 tr: l 3.849 a 0.023 clct[np.int64(99), np.int64(101)] cl_acc 0.515  lr 0.100000 15.651sec(train) 4.440sec(infer)
# Epoch 10 tst: l 3.850 a 0.026 clct[np.int64(20), np.int64(20)] cl_acc 0.550  1.940sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 11 tr: l 3.849 a 0.023 clct[np.int64(98), np.int64(102)] cl_acc 0.520  lr 0.100000 15.505sec(train) 5.360sec(infer)
# Epoch 11 tst: l 3.850 a 0.026 clct[np.int64(20), np.int64(20)] cl_acc 0.550  1.775sec
# Epoch 12 tr: l 3.849 a 0.023 clct[np.int64(100), np.int64(100)] cl_acc 0.520  lr 0.100000 21.065sec(train) 4.476sec(infer)
# Epoch 12 tst: l 3.850 a 0.026 clct[np.int64(20), np.int64(20)] cl_acc 0.550  1.856sec
# ...
# Epoch 128 tr: l 3.844 a 0.024 clct[np.int64(125), np.int64(75)] cl_acc 0.525  lr 0.100000 11.377sec(train) 2.958sec(infer)
# Epoch 128 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.896sec
# Epoch 129 tr: l 3.843 a 0.024 clct[np.int64(125), np.int64(75)] cl_acc 0.525  lr 0.100000 12.143sec(train) 3.396sec(infer)
# Epoch 129 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.791sec
# Epoch 130 tr: l 3.844 a 0.024 clct[np.int64(126), np.int64(74)] cl_acc 0.520  lr 0.100000 14.768sec(train) 3.461sec(infer)
# Epoch 130 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.595sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 131 tr: l 3.842 a 0.024 clct[np.int64(126), np.int64(74)] cl_acc 0.520  lr 0.100000 12.826sec(train) 2.708sec(infer)
# Epoch 131 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.746sec
# Epoch 132 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 11.378sec(train) 2.976sec(infer)
# Epoch 132 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.975sec
# Epoch 133 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 12.121sec(train) 3.037sec(infer)
# Epoch 133 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.984sec
# Epoch 134 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 12.133sec(train) 3.445sec(infer)
# Epoch 134 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.353sec
# Epoch 135 tr: l 3.845 a 0.024 clct[np.int64(128), np.int64(72)] cl_acc 0.520  lr 0.100000 14.144sec(train) 3.500sec(infer)
# Epoch 135 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.838sec
# Epoch 136 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 13.583sec(train) 2.757sec(infer)
# Epoch 136 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.760sec
# Epoch 137 tr: l 3.844 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 12.003sec(train) 2.435sec(infer)
# Epoch 137 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.702sec
# Epoch 138 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 11.770sec(train) 2.865sec(infer)
# Epoch 138 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.860sec
# Epoch 139 tr: l 3.844 a 0.024 clct[np.int64(128), np.int64(72)] cl_acc 0.520  lr 0.100000 12.824sec(train) 3.910sec(infer)
# Epoch 139 tst: l 3.850 a 0.024 clct[np.int64(28), np.int64(12)] cl_acc 0.550  1.584sec
# Epoch 140 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 15.834sec(train) 3.107sec(infer)
# Epoch 140 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.871sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 141 tr: l 3.845 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 11.431sec(train) 2.728sec(infer)
# Epoch 141 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.802sec
# Epoch 142 tr: l 3.845 a 0.024 clct[np.int64(128), np.int64(72)] cl_acc 0.520  lr 0.100000 11.531sec(train) 2.934sec(infer)
# Epoch 142 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.917sec
# Epoch 143 tr: l 3.842 a 0.024 clct[np.int64(127), np.int64(73)] cl_acc 0.515  lr 0.100000 12.137sec(train) 3.164sec(infer)
# Epoch 143 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.199sec
# Epoch 144 tr: l 3.844 a 0.024 clct[np.int64(128), np.int64(72)] cl_acc 0.510  lr 0.100000 12.564sec(train) 4.004sec(infer)
# Epoch 144 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.951sec
# Epoch 145 tr: l 3.845 a 0.024 clct[np.int64(130), np.int64(70)] cl_acc 0.510  lr 0.100000 15.633sec(train) 2.336sec(infer)
# Epoch 145 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.760sec
# Epoch 146 tr: l 3.845 a 0.024 clct[np.int64(130), np.int64(70)] cl_acc 0.510  lr 0.100000 11.861sec(train) 2.923sec(infer)
# Epoch 146 tst: l 3.850 a 0.024 clct[np.int64(28), np.int64(12)] cl_acc 0.550  0.883sec
# Epoch 147 tr: l 3.843 a 0.024 clct[np.int64(130), np.int64(70)] cl_acc 0.510  lr 0.100000 11.250sec(train) 2.758sec(infer)
# Epoch 147 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  0.803sec
# Epoch 148 tr: l 3.844 a 0.024 clct[np.int64(131), np.int64(69)] cl_acc 0.515  lr 0.100000 11.918sec(train) 3.153sec(infer)
# Epoch 148 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  1.286sec
# Epoch 149 tr: l 3.843 a 0.024 clct[np.int64(132), np.int64(68)] cl_acc 0.520  lr 0.100000 13.789sec(train) 5.092sec(infer)
# Epoch 149 tst: l 3.850 a 0.024 clct[np.int64(27), np.int64(13)] cl_acc 0.575  2.663sec
# Epoch 150 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.694sec(train) 2.739sec(infer)
# Epoch 150 tst: l 3.850 a 0.024 clct[np.int64(28), np.int64(12)] cl_acc 0.600  0.899sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 151 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.391sec(train) 2.699sec(infer)
# Epoch 151 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.705sec
# Epoch 152 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.141sec(train) 3.026sec(infer)
# Epoch 152 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.915sec
# Epoch 153 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.785sec(train) 3.207sec(infer)
# Epoch 153 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.988sec
# Epoch 154 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 17.443sec(train) 2.917sec(infer)
# Epoch 154 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  1.360sec
# Epoch 155 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.814sec(train) 2.711sec(infer)
# Epoch 155 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.772sec
# Epoch 156 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.200sec(train) 2.766sec(infer)
# Epoch 156 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.836sec
# Epoch 157 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.113sec(train) 3.430sec(infer)
# Epoch 157 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  1.434sec
# Epoch 158 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.935sec(train) 4.639sec(infer)
# Epoch 158 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  1.937sec
# Epoch 159 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 15.211sec(train) 2.275sec(infer)
# Epoch 159 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.699sec
# Epoch 160 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.221sec(train) 2.934sec(infer)
# Epoch 160 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.968sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 161 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.136sec(train) 2.789sec(infer)
# Epoch 161 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  0.788sec
# Epoch 162 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.543sec(train) 3.173sec(infer)
# Epoch 162 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.989sec
# Epoch 163 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 13.383sec(train) 4.665sec(infer)
# Epoch 163 tst: l 3.850 a 0.024 clct[np.int64(29), np.int64(11)] cl_acc 0.575  2.533sec
# Epoch 164 tr: l 3.843 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 13.030sec(train) 2.976sec(infer)
# Epoch 164 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.014sec
# Epoch 165 tr: l 3.845 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 11.251sec(train) 2.760sec(infer)
# Epoch 165 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.915sec
# Epoch 166 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 10.857sec(train) 2.907sec(infer)
# Epoch 166 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.183sec
# Epoch 167 tr: l 3.844 a 0.024 clct[np.int64(133), np.int64(67)] cl_acc 0.515  lr 0.100000 12.974sec(train) 3.412sec(infer)
# Epoch 167 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.425sec
# Epoch 168 tr: l 3.843 a 0.024 clct[np.int64(135), np.int64(65)] cl_acc 0.515  lr 0.100000 16.204sec(train) 3.342sec(infer)
# Epoch 168 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.383sec
# Epoch 169 tr: l 3.845 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 11.439sec(train) 2.751sec(infer)
# Epoch 169 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.963sec
# Epoch 170 tr: l 3.845 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 11.336sec(train) 2.943sec(infer)
# Epoch 170 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.147sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 171 tr: l 3.844 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 11.969sec(train) 3.181sec(infer)
# Epoch 171 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.381sec
# Epoch 172 tr: l 3.844 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 12.494sec(train) 3.812sec(infer)
# Epoch 172 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.860sec
# Epoch 173 tr: l 3.844 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 15.724sec(train) 2.774sec(infer)
# Epoch 173 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.705sec
# Epoch 174 tr: l 3.845 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 12.106sec(train) 2.915sec(infer)
# Epoch 174 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.749sec
# Epoch 175 tr: l 3.845 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 11.530sec(train) 2.737sec(infer)
# Epoch 175 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.798sec
# Epoch 176 tr: l 3.844 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 11.873sec(train) 3.198sec(infer)
# Epoch 176 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.245sec
# Epoch 177 tr: l 3.843 a 0.024 clct[np.int64(136), np.int64(64)] cl_acc 0.520  lr 0.100000 12.806sec(train) 4.952sec(infer)
# Epoch 177 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  2.597sec
# Epoch 178 tr: l 3.844 a 0.024 clct[np.int64(137), np.int64(63)] cl_acc 0.515  lr 0.100000 14.139sec(train) 2.726sec(infer)
# Epoch 178 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.697sec
# Epoch 179 tr: l 3.844 a 0.024 clct[np.int64(137), np.int64(63)] cl_acc 0.515  lr 0.100000 11.403sec(train) 2.746sec(infer)
# Epoch 179 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.806sec
# Epoch 180 tr: l 3.844 a 0.024 clct[np.int64(137), np.int64(63)] cl_acc 0.515  lr 0.100000 11.528sec(train) 2.918sec(infer)
# Epoch 180 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.174sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 181 tr: l 3.844 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 13.087sec(train) 3.199sec(infer)
# Epoch 181 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.060sec
# Epoch 182 tr: l 3.844 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 14.026sec(train) 4.326sec(infer)
# Epoch 182 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.692sec
# Epoch 183 tr: l 3.844 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 12.198sec(train) 2.949sec(infer)
# Epoch 183 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.074sec
# Epoch 184 tr: l 3.844 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 12.016sec(train) 2.932sec(infer)
# Epoch 184 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.893sec
# Epoch 185 tr: l 3.844 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 11.178sec(train) 2.974sec(infer)
# Epoch 185 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.811sec
# Epoch 186 tr: l 3.843 a 0.024 clct[np.int64(138), np.int64(62)] cl_acc 0.510  lr 0.100000 12.463sec(train) 3.212sec(infer)
# Epoch 186 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.502sec
# Epoch 187 tr: l 3.844 a 0.024 clct[np.int64(140), np.int64(60)] cl_acc 0.500  lr 0.100000 17.441sec(train) 3.456sec(infer)
# Epoch 187 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  0.951sec
# Epoch 188 tr: l 3.844 a 0.024 clct[np.int64(140), np.int64(60)] cl_acc 0.500  lr 0.100000 11.112sec(train) 2.706sec(infer)
# Epoch 188 tst: l 3.850 a 0.024 clct[np.int64(30), np.int64(10)] cl_acc 0.550  1.047sec
# Epoch 189 tr: l 3.844 a 0.024 clct[np.int64(140), np.int64(60)] cl_acc 0.500  lr 0.100000 11.833sec(train) 2.676sec(infer)
# Epoch 189 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.710sec
# Epoch 190 tr: l 3.844 a 0.024 clct[np.int64(140), np.int64(60)] cl_acc 0.500  lr 0.100000 11.799sec(train) 3.440sec(infer)
# Epoch 190 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  1.364sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 191 tr: l 3.843 a 0.024 clct[np.int64(141), np.int64(59)] cl_acc 0.505  lr 0.100000 13.195sec(train) 3.921sec(infer)
# Epoch 191 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  1.757sec
# Epoch 192 tr: l 3.844 a 0.024 clct[np.int64(141), np.int64(59)] cl_acc 0.505  lr 0.100000 15.850sec(train) 2.265sec(infer)
# Epoch 192 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.692sec
# Epoch 193 tr: l 3.842 a 0.024 clct[np.int64(141), np.int64(59)] cl_acc 0.505  lr 0.100000 11.103sec(train) 2.950sec(infer)
# Epoch 193 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.941sec
# Epoch 194 tr: l 3.844 a 0.024 clct[np.int64(142), np.int64(58)] cl_acc 0.510  lr 0.100000 11.955sec(train) 2.832sec(infer)
# Epoch 194 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.824sec
# Epoch 195 tr: l 3.844 a 0.024 clct[np.int64(143), np.int64(57)] cl_acc 0.505  lr 0.100000 11.895sec(train) 1.072sec(infer)
# Epoch 195 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.535sec
# Epoch 196 tr: l 3.844 a 0.024 clct[np.int64(143), np.int64(57)] cl_acc 0.505  lr 0.100000 11.347sec(train) 1.375sec(infer)
# Epoch 196 tst: l 3.850 a 0.024 clct[np.int64(32), np.int64(8)] cl_acc 0.550  0.685sec
# Epoch 197 tr: l 3.842 a 0.024 clct[np.int64(143), np.int64(57)] cl_acc 0.505  lr 0.100000 13.887sec(train) 1.130sec(infer)
# Epoch 197 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.564sec
# Epoch 198 tr: l 3.844 a 0.024 clct[np.int64(143), np.int64(57)] cl_acc 0.505  lr 0.100000 10.411sec(train) 1.055sec(infer)
# Epoch 198 tst: l 3.850 a 0.024 clct[np.int64(32), np.int64(8)] cl_acc 0.550  0.544sec
# Epoch 199 tr: l 3.844 a 0.024 clct[np.int64(144), np.int64(56)] cl_acc 0.500  lr 0.100000 10.872sec(train) 1.183sec(infer)
# Epoch 199 tst: l 3.850 a 0.024 clct[np.int64(31), np.int64(9)] cl_acc 0.575  0.584sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# ---train cluster Ended in 0.94 hour (3378.894 sec)

# %%
___.display_outputs()
# Out:
# ---------------------------------DFCA-LI, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 3.850 a 0.025 clct[np.int64(113), np.int64(87)] cl_acc 0.585  4.071sec
# Epoch -1 tst: l 3.851 a 0.026 clct[np.int64(21), np.int64(19)] cl_acc 0.675  0.720sec
# Epoch 0 tr: l 3.845 a 0.026 clct[np.int64(66), np.int64(134)] cl_acc 0.650  lr 0.100000 20.671sec(train) 4.874sec(infer)
# Epoch 0 tst: l 3.847 a 0.027 clct[np.int64(15), np.int64(25)] cl_acc 0.675  2.280sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 3.840 a 0.029 clct[np.int64(41), np.int64(159)] cl_acc 0.645  lr 0.100000 14.604sec(train) 4.177sec(infer)
# Epoch 1 tst: l 3.842 a 0.030 clct[np.int64(6), np.int64(34)] cl_acc 0.650  1.569sec
# Epoch 2 tr: l 3.833 a 0.031 clct[np.int64(29), np.int64(171)] cl_acc 0.605  lr 0.100000 15.838sec(train) 4.380sec(infer)
# Epoch 2 tst: l 3.836 a 0.038 clct[np.int64(4), np.int64(36)] cl_acc 0.600  2.483sec
# Epoch 3 tr: l 3.824 a 0.036 clct[np.int64(21), np.int64(179)] cl_acc 0.565  lr 0.100000 14.480sec(train) 5.028sec(infer)
# Epoch 3 tst: l 3.828 a 0.037 clct[np.int64(3), np.int64(37)] cl_acc 0.575  2.611sec
# Epoch 4 tr: l 3.809 a 0.043 clct[np.int64(10), np.int64(190)] cl_acc 0.520  lr 0.100000 16.065sec(train) 5.833sec(infer)
# Epoch 4 tst: l 3.816 a 0.048 clct[np.int64(2), np.int64(38)] cl_acc 0.550  2.707sec
# Epoch 5 tr: l 3.787 a 0.049 clct[np.int64(9), np.int64(191)] cl_acc 0.515  lr 0.100000 18.009sec(train) 4.631sec(infer)
# Epoch 5 tst: l 3.799 a 0.049 clct[np.int64(0), np.int64(40)] cl_acc 0.500  2.458sec
# Epoch 6 tr: l 3.763 a 0.059 clct[np.int64(8), np.int64(192)] cl_acc 0.510  lr 0.100000 14.418sec(train) 4.824sec(infer)
# Epoch 6 tst: l 3.770 a 0.058 clct[np.int64(1), np.int64(39)] cl_acc 0.525  1.686sec
# Epoch 7 tr: l 3.716 a 0.087 clct[np.int64(7), np.int64(193)] cl_acc 0.505  lr 0.100000 14.851sec(train) 3.592sec(infer)
# Epoch 7 tst: l 3.728 a 0.084 clct[np.int64(1), np.int64(39)] cl_acc 0.525  2.322sec
# Epoch 8 tr: l 3.632 a 0.137 clct[np.int64(4), np.int64(196)] cl_acc 0.510  lr 0.100000 14.682sec(train) 5.343sec(infer)
# Epoch 8 tst: l 3.653 a 0.128 clct[np.int64(0), np.int64(40)] cl_acc 0.500  2.696sec
# Epoch 9 tr: l 3.490 a 0.182 clct[np.int64(4), np.int64(196)] cl_acc 0.510  lr 0.100000 19.223sec(train) 5.876sec(infer)
# Epoch 9 tst: l 3.518 a 0.175 clct[np.int64(0), np.int64(40)] cl_acc 0.500  1.658sec
# Epoch 10 tr: l 3.269 a 0.212 clct[np.int64(4), np.int64(196)] cl_acc 0.510  lr 0.100000 15.270sec(train) 3.572sec(infer)
# Epoch 10 tst: l 3.304 a 0.198 clct[np.int64(1), np.int64(39)] cl_acc 0.525  2.332sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 3.088 a 0.224 clct[np.int64(4), np.int64(196)] cl_acc 0.510  lr 0.100000 13.997sec(train) 4.309sec(infer)
# Epoch 11 tst: l 3.131 a 0.221 clct[np.int64(0), np.int64(40)] cl_acc 0.500  2.316sec
# Epoch 12 tr: l 3.115 a 0.178 clct[np.int64(3), np.int64(197)] cl_acc 0.505  lr 0.100000 13.921sec(train) 4.086sec(infer)
# Epoch 12 tst: l 3.137 a 0.174 clct[np.int64(1), np.int64(39)] cl_acc 0.525  1.828sec
# Epoch 13 tr: l 3.057 a 0.178 clct[np.int64(9), np.int64(191)] cl_acc 0.525  lr 0.100000 18.723sec(train) 6.314sec(infer)
# Epoch 13 tst: l 3.102 a 0.171 clct[np.int64(2), np.int64(38)] cl_acc 0.550  3.905sec
# Epoch 14 tr: l 2.860 a 0.252 clct[np.int64(57), np.int64(143)] cl_acc 0.765  lr 0.100000 17.483sec(train) 4.586sec(infer)
# Epoch 14 tst: l 2.906 a 0.244 clct[np.int64(11), np.int64(29)] cl_acc 0.775  1.736sec
# Epoch 15 tr: l 2.566 a 0.348 clct[np.int64(98), np.int64(102)] cl_acc 0.990  lr 0.100000 13.709sec(train) 3.411sec(infer)
# Epoch 15 tst: l 2.609 a 0.342 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.181sec
# Epoch 16 tr: l 2.474 a 0.363 clct[np.int64(99), np.int64(101)] cl_acc 0.995  lr 0.100000 16.018sec(train) 4.593sec(infer)
# Epoch 16 tst: l 2.505 a 0.360 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.328sec
# Epoch 17 tr: l 2.410 a 0.386 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.017sec(train) 5.057sec(infer)
# Epoch 17 tst: l 2.378 a 0.391 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.825sec
# Epoch 18 tr: l 2.133 a 0.432 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.698sec(train) 5.489sec(infer)
# Epoch 18 tst: l 2.142 a 0.440 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.311sec
# Epoch 19 tr: l 1.999 a 0.465 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.473sec(train) 4.907sec(infer)
# Epoch 19 tst: l 2.034 a 0.460 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.350sec
# Epoch 20 tr: l 1.902 a 0.482 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.473sec(train) 3.955sec(infer)
# Epoch 20 tst: l 1.925 a 0.484 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.608sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 1.756 a 0.516 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.608sec(train) 4.578sec(infer)
# Epoch 21 tst: l 1.814 a 0.510 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.331sec
# Epoch 22 tr: l 1.761 a 0.501 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.631sec(train) 5.748sec(infer)
# Epoch 22 tst: l 1.803 a 0.497 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.534sec
# Epoch 23 tr: l 1.658 a 0.531 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 20.647sec(train) 3.392sec(infer)
# Epoch 23 tst: l 1.682 a 0.533 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.616sec
# Epoch 24 tr: l 1.547 a 0.563 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.515sec(train) 4.598sec(infer)
# Epoch 24 tst: l 1.593 a 0.563 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.093sec
# Epoch 25 tr: l 1.479 a 0.580 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.898sec(train) 4.957sec(infer)
# Epoch 25 tst: l 1.518 a 0.578 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.725sec
# Epoch 26 tr: l 1.480 a 0.571 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.598sec(train) 3.536sec(infer)
# Epoch 26 tst: l 1.532 a 0.569 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.702sec
# Epoch 27 tr: l 1.429 a 0.584 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.043sec(train) 7.118sec(infer)
# Epoch 27 tst: l 1.497 a 0.578 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.858sec
# Epoch 28 tr: l 1.380 a 0.597 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.431sec(train) 4.770sec(infer)
# Epoch 28 tst: l 1.449 a 0.591 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.685sec
# Epoch 29 tr: l 1.317 a 0.618 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.978sec(train) 3.191sec(infer)
# Epoch 29 tst: l 1.375 a 0.615 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.340sec
# Epoch 30 tr: l 1.275 a 0.626 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.229sec(train) 4.589sec(infer)
# Epoch 30 tst: l 1.353 a 0.618 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.180sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 1.261 a 0.630 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.496sec(train) 4.601sec(infer)
# Epoch 31 tst: l 1.354 a 0.622 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.957sec
# Epoch 32 tr: l 1.221 a 0.636 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.101sec(train) 6.150sec(infer)
# Epoch 32 tst: l 1.309 a 0.628 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.791sec
# Epoch 33 tr: l 1.226 a 0.639 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.889sec(train) 4.572sec(infer)
# Epoch 33 tst: l 1.313 a 0.631 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.339sec
# Epoch 34 tr: l 1.201 a 0.638 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.643sec(train) 3.797sec(infer)
# Epoch 34 tst: l 1.287 a 0.627 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.597sec
# Epoch 35 tr: l 1.148 a 0.654 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.823sec(train) 5.009sec(infer)
# Epoch 35 tst: l 1.238 a 0.647 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.462sec
# Epoch 36 tr: l 1.135 a 0.658 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.135sec(train) 5.313sec(infer)
# Epoch 36 tst: l 1.235 a 0.648 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.075sec
# Epoch 37 tr: l 1.142 a 0.655 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 20.464sec(train) 3.358sec(infer)
# Epoch 37 tst: l 1.245 a 0.645 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.855sec
# Epoch 38 tr: l 1.113 a 0.666 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.033sec(train) 4.963sec(infer)
# Epoch 38 tst: l 1.212 a 0.654 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.468sec
# Epoch 39 tr: l 1.083 a 0.673 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.024sec(train) 4.576sec(infer)
# Epoch 39 tst: l 1.182 a 0.662 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.687sec
# Epoch 40 tr: l 1.060 a 0.679 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.125sec(train) 3.507sec(infer)
# Epoch 40 tst: l 1.161 a 0.669 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.663sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 41 tr: l 1.058 a 0.680 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.223sec(train) 7.561sec(infer)
# Epoch 41 tst: l 1.156 a 0.670 clct[np.int64(20), np.int64(20)] cl_acc 1.000  4.213sec
# Epoch 42 tr: l 1.006 a 0.694 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.866sec(train) 4.500sec(infer)
# Epoch 42 tst: l 1.131 a 0.680 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.599sec
# Epoch 43 tr: l 1.036 a 0.683 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.281sec(train) 3.523sec(infer)
# Epoch 43 tst: l 1.131 a 0.675 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.333sec
# Epoch 44 tr: l 0.993 a 0.698 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.233sec(train) 4.684sec(infer)
# Epoch 44 tst: l 1.095 a 0.690 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.511sec
# Epoch 45 tr: l 1.003 a 0.695 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.977sec(train) 5.336sec(infer)
# Epoch 45 tst: l 1.111 a 0.685 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.841sec
# Epoch 46 tr: l 0.978 a 0.707 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.163sec(train) 5.463sec(infer)
# Epoch 46 tst: l 1.073 a 0.694 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.257sec
# Epoch 47 tr: l 0.966 a 0.707 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.276sec(train) 4.603sec(infer)
# Epoch 47 tst: l 1.067 a 0.698 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.339sec
# Epoch 48 tr: l 0.940 a 0.711 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.344sec(train) 4.033sec(infer)
# Epoch 48 tst: l 1.052 a 0.699 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.723sec
# Epoch 49 tr: l 0.927 a 0.710 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.319sec(train) 4.624sec(infer)
# Epoch 49 tst: l 1.057 a 0.697 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.302sec
# Epoch 50 tr: l 0.925 a 0.715 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.565sec(train) 5.334sec(infer)
# Epoch 50 tst: l 1.049 a 0.698 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.082sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 51 tr: l 0.884 a 0.720 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 20.349sec(train) 3.728sec(infer)
# Epoch 51 tst: l 1.020 a 0.706 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.791sec
# Epoch 52 tr: l 0.911 a 0.720 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.379sec(train) 4.559sec(infer)
# Epoch 52 tst: l 1.038 a 0.703 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.301sec
# Epoch 53 tr: l 0.897 a 0.723 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.763sec(train) 4.217sec(infer)
# Epoch 53 tst: l 1.013 a 0.709 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.615sec
# Epoch 54 tr: l 0.887 a 0.722 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.191sec(train) 4.762sec(infer)
# Epoch 54 tst: l 1.005 a 0.708 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.859sec
# Epoch 55 tr: l 0.875 a 0.730 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.417sec(train) 7.371sec(infer)
# Epoch 55 tst: l 0.992 a 0.712 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.950sec
# Epoch 56 tr: l 0.869 a 0.734 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.348sec(train) 4.027sec(infer)
# Epoch 56 tst: l 0.978 a 0.720 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.602sec
# Epoch 57 tr: l 0.837 a 0.738 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.142sec(train) 4.419sec(infer)
# Epoch 57 tst: l 0.985 a 0.718 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.467sec
# Epoch 58 tr: l 0.824 a 0.742 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.991sec(train) 4.986sec(infer)
# Epoch 58 tst: l 0.985 a 0.720 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.191sec
# Epoch 59 tr: l 0.846 a 0.736 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.517sec(train) 4.462sec(infer)
# Epoch 59 tst: l 0.985 a 0.714 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.887sec
# Epoch 60 tr: l 0.822 a 0.741 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.213sec(train) 6.120sec(infer)
# Epoch 60 tst: l 0.966 a 0.722 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.560sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 61 tr: l 0.788 a 0.750 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.910sec(train) 5.038sec(infer)
# Epoch 61 tst: l 0.932 a 0.728 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.277sec
# Epoch 62 tr: l 0.790 a 0.751 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.702sec(train) 3.219sec(infer)
# Epoch 62 tst: l 0.931 a 0.732 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.997sec
# Epoch 63 tr: l 0.783 a 0.751 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.683sec(train) 4.624sec(infer)
# Epoch 63 tst: l 0.918 a 0.734 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.416sec
# Epoch 64 tr: l 0.784 a 0.750 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.078sec(train) 5.567sec(infer)
# Epoch 64 tst: l 0.925 a 0.732 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.212sec
# Epoch 65 tr: l 0.783 a 0.752 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 21.507sec(train) 3.659sec(infer)
# Epoch 65 tst: l 0.918 a 0.733 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.306sec
# Epoch 66 tr: l 0.767 a 0.755 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.880sec(train) 4.608sec(infer)
# Epoch 66 tst: l 0.924 a 0.732 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.312sec
# Epoch 67 tr: l 0.772 a 0.756 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.669sec(train) 4.162sec(infer)
# Epoch 67 tst: l 0.915 a 0.732 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.691sec
# Epoch 68 tr: l 0.764 a 0.759 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.496sec(train) 5.254sec(infer)
# Epoch 68 tst: l 0.896 a 0.742 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.660sec
# Epoch 69 tr: l 0.771 a 0.756 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.379sec(train) 7.780sec(infer)
# Epoch 69 tst: l 0.915 a 0.738 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.400sec
# Epoch 70 tr: l 0.745 a 0.763 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.941sec(train) 3.549sec(infer)
# Epoch 70 tst: l 0.883 a 0.744 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.002sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 71 tr: l 0.748 a 0.762 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.009sec(train) 4.647sec(infer)
# Epoch 71 tst: l 0.899 a 0.739 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.295sec
# Epoch 72 tr: l 0.723 a 0.768 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.999sec(train) 4.124sec(infer)
# Epoch 72 tst: l 0.871 a 0.746 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.649sec
# Epoch 73 tr: l 0.728 a 0.771 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.992sec(train) 4.339sec(infer)
# Epoch 73 tst: l 0.855 a 0.750 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.769sec
# Epoch 74 tr: l 0.706 a 0.773 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 20.783sec(train) 5.675sec(infer)
# Epoch 74 tst: l 0.859 a 0.752 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.340sec
# Epoch 75 tr: l 0.694 a 0.776 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.596sec(train) 3.973sec(infer)
# Epoch 75 tst: l 0.843 a 0.753 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.575sec
# Epoch 76 tr: l 0.690 a 0.778 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.468sec(train) 4.330sec(infer)
# Epoch 76 tst: l 0.844 a 0.754 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.394sec
# Epoch 77 tr: l 0.706 a 0.777 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.626sec(train) 5.000sec(infer)
# Epoch 77 tst: l 0.831 a 0.758 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.383sec
# Epoch 78 tr: l 0.687 a 0.777 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.621sec(train) 3.955sec(infer)
# Epoch 78 tst: l 0.843 a 0.754 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.411sec
# Epoch 79 tr: l 0.681 a 0.778 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 21.415sec(train) 4.594sec(infer)
# Epoch 79 tst: l 0.865 a 0.748 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.240sec
# Epoch 80 tr: l 0.700 a 0.779 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.119sec(train) 4.778sec(infer)
# Epoch 80 tst: l 0.840 a 0.754 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.687sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 81 tr: l 0.681 a 0.780 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.894sec(train) 3.499sec(infer)
# Epoch 81 tst: l 0.837 a 0.755 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.181sec
# Epoch 82 tr: l 0.673 a 0.784 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.110sec(train) 5.277sec(infer)
# Epoch 82 tst: l 0.838 a 0.751 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.692sec
# Epoch 83 tr: l 0.655 a 0.785 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.729sec(train) 8.041sec(infer)
# Epoch 83 tst: l 0.808 a 0.762 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.123sec
# Epoch 84 tr: l 0.651 a 0.791 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.861sec(train) 3.489sec(infer)
# Epoch 84 tst: l 0.818 a 0.763 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.321sec
# Epoch 85 tr: l 0.650 a 0.788 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.162sec(train) 4.564sec(infer)
# Epoch 85 tst: l 0.800 a 0.765 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.322sec
# Epoch 86 tr: l 0.652 a 0.789 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.947sec(train) 3.998sec(infer)
# Epoch 86 tst: l 0.809 a 0.763 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.762sec
# Epoch 87 tr: l 0.631 a 0.793 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.985sec(train) 4.700sec(infer)
# Epoch 87 tst: l 0.797 a 0.766 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.647sec
# Epoch 88 tr: l 0.644 a 0.791 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.829sec(train) 5.646sec(infer)
# Epoch 88 tst: l 0.789 a 0.768 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.316sec
# Epoch 89 tr: l 0.652 a 0.790 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.703sec(train) 3.724sec(infer)
# Epoch 89 tst: l 0.802 a 0.765 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.617sec
# Epoch 90 tr: l 0.639 a 0.791 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.637sec(train) 4.943sec(infer)
# Epoch 90 tst: l 0.785 a 0.769 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.383sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 91 tr: l 0.624 a 0.794 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.740sec(train) 4.496sec(infer)
# Epoch 91 tst: l 0.796 a 0.766 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.852sec
# Epoch 92 tr: l 0.633 a 0.793 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.316sec(train) 3.696sec(infer)
# Epoch 92 tst: l 0.780 a 0.771 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.366sec
# Epoch 93 tr: l 0.628 a 0.797 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 20.361sec(train) 4.931sec(infer)
# Epoch 93 tst: l 0.775 a 0.771 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.483sec
# Epoch 94 tr: l 0.615 a 0.796 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.367sec(train) 4.206sec(infer)
# Epoch 94 tst: l 0.771 a 0.773 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.584sec
# Epoch 95 tr: l 0.598 a 0.801 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.367sec(train) 3.618sec(infer)
# Epoch 95 tst: l 0.771 a 0.772 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.308sec
# Epoch 96 tr: l 0.615 a 0.800 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.099sec(train) 5.735sec(infer)
# Epoch 96 tst: l 0.779 a 0.774 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.877sec
# Epoch 97 tr: l 0.601 a 0.799 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.268sec(train) 7.148sec(infer)
# Epoch 97 tst: l 0.754 a 0.777 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.562sec
# Epoch 98 tr: l 0.611 a 0.799 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.707sec(train) 4.046sec(infer)
# Epoch 98 tst: l 0.765 a 0.776 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.293sec
# Epoch 99 tr: l 0.590 a 0.803 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.551sec(train) 4.905sec(infer)
# Epoch 99 tst: l 0.771 a 0.771 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.456sec
# Epoch 100 tr: l 0.597 a 0.801 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.841sec(train) 3.580sec(infer)
# Epoch 100 tst: l 0.768 a 0.774 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.733sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 101 tr: l 0.586 a 0.805 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.471sec(train) 5.386sec(infer)
# Epoch 101 tst: l 0.743 a 0.778 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.052sec
# Epoch 102 tr: l 0.596 a 0.806 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.544sec(train) 5.254sec(infer)
# Epoch 102 tst: l 0.756 a 0.778 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.901sec
# Epoch 103 tr: l 0.574 a 0.806 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.700sec(train) 3.616sec(infer)
# Epoch 103 tst: l 0.741 a 0.779 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.981sec
# Epoch 104 tr: l 0.581 a 0.805 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.450sec(train) 4.582sec(infer)
# Epoch 104 tst: l 0.754 a 0.780 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.340sec
# Epoch 105 tr: l 0.587 a 0.808 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.768sec(train) 4.434sec(infer)
# Epoch 105 tst: l 0.767 a 0.775 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.785sec
# Epoch 106 tr: l 0.567 a 0.812 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.686sec(train) 5.209sec(infer)
# Epoch 106 tst: l 0.745 a 0.781 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.813sec
# Epoch 107 tr: l 0.562 a 0.810 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.087sec(train) 4.576sec(infer)
# Epoch 107 tst: l 0.725 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.316sec
# Epoch 108 tr: l 0.562 a 0.813 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.229sec(train) 3.761sec(infer)
# Epoch 108 tst: l 0.742 a 0.783 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.598sec
# Epoch 109 tr: l 0.566 a 0.811 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.768sec(train) 4.881sec(infer)
# Epoch 109 tst: l 0.731 a 0.782 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.468sec
# Epoch 110 tr: l 0.572 a 0.810 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.769sec(train) 5.316sec(infer)
# Epoch 110 tst: l 0.724 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.110sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 111 tr: l 0.584 a 0.810 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.739sec(train) 4.994sec(infer)
# Epoch 111 tst: l 0.721 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.284sec
# Epoch 112 tr: l 0.553 a 0.813 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.665sec(train) 4.936sec(infer)
# Epoch 112 tst: l 0.741 a 0.777 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.493sec
# Epoch 113 tr: l 0.554 a 0.817 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.330sec(train) 4.396sec(infer)
# Epoch 113 tst: l 0.717 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.612sec
# Epoch 114 tr: l 0.550 a 0.816 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.019sec(train) 3.724sec(infer)
# Epoch 114 tst: l 0.726 a 0.786 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.470sec
# Epoch 115 tr: l 0.546 a 0.814 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.877sec(train) 5.392sec(infer)
# Epoch 115 tst: l 0.723 a 0.785 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.296sec
# Epoch 116 tr: l 0.546 a 0.822 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.136sec(train) 5.545sec(infer)
# Epoch 116 tst: l 0.712 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.602sec
# Epoch 117 tr: l 0.532 a 0.819 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.980sec(train) 3.688sec(infer)
# Epoch 117 tst: l 0.708 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.288sec
# Epoch 118 tr: l 0.540 a 0.817 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.338sec(train) 4.589sec(infer)
# Epoch 118 tst: l 0.708 a 0.791 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.314sec
# Epoch 119 tr: l 0.526 a 0.821 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.967sec(train) 4.497sec(infer)
# Epoch 119 tst: l 0.714 a 0.788 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.861sec
# Epoch 120 tr: l 0.524 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.183sec(train) 5.472sec(infer)
# Epoch 120 tst: l 0.713 a 0.789 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.789sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 121 tr: l 0.532 a 0.820 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.276sec(train) 4.583sec(infer)
# Epoch 121 tst: l 0.706 a 0.790 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.265sec
# Epoch 122 tr: l 0.523 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.357sec(train) 3.862sec(infer)
# Epoch 122 tst: l 0.714 a 0.787 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.706sec
# Epoch 123 tr: l 0.519 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.297sec(train) 4.630sec(infer)
# Epoch 123 tst: l 0.706 a 0.789 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.348sec
# Epoch 124 tr: l 0.517 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.988sec(train) 5.224sec(infer)
# Epoch 124 tst: l 0.700 a 0.793 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.874sec
# Epoch 125 tr: l 0.506 a 0.827 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.646sec(train) 5.822sec(infer)
# Epoch 125 tst: l 0.696 a 0.793 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.565sec
# Epoch 126 tr: l 0.524 a 0.822 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.364sec(train) 4.607sec(infer)
# Epoch 126 tst: l 0.698 a 0.792 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.322sec
# Epoch 127 tr: l 0.520 a 0.824 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.394sec(train) 4.141sec(infer)
# Epoch 127 tst: l 0.696 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.593sec
# Epoch 128 tr: l 0.513 a 0.824 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.292sec(train) 4.282sec(infer)
# Epoch 128 tst: l 0.696 a 0.794 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.595sec
# Epoch 129 tr: l 0.502 a 0.828 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.551sec(train) 5.657sec(infer)
# Epoch 129 tst: l 0.700 a 0.797 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.212sec
# Epoch 130 tr: l 0.505 a 0.823 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.579sec(train) 4.382sec(infer)
# Epoch 130 tst: l 0.688 a 0.795 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.617sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l 0.512 a 0.826 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.970sec(train) 4.816sec(infer)
# Epoch 131 tst: l 0.697 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.209sec
# Epoch 132 tr: l 0.500 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.299sec(train) 4.954sec(infer)
# Epoch 132 tst: l 0.681 a 0.797 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.710sec
# Epoch 133 tr: l 0.503 a 0.830 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.953sec(train) 3.423sec(infer)
# Epoch 133 tst: l 0.684 a 0.799 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.332sec
# Epoch 134 tr: l 0.495 a 0.830 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.799sec(train) 6.882sec(infer)
# Epoch 134 tst: l 0.683 a 0.799 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.887sec
# Epoch 135 tr: l 0.488 a 0.831 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.962sec(train) 4.965sec(infer)
# Epoch 135 tst: l 0.680 a 0.800 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.885sec
# Epoch 136 tr: l 0.505 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.579sec(train) 3.182sec(infer)
# Epoch 136 tst: l 0.699 a 0.796 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.055sec
# Epoch 137 tr: l 0.504 a 0.829 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.060sec(train) 4.613sec(infer)
# Epoch 137 tst: l 0.683 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.330sec
# Epoch 138 tr: l 0.496 a 0.830 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.728sec(train) 5.353sec(infer)
# Epoch 138 tst: l 0.681 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.979sec
# Epoch 139 tr: l 0.478 a 0.834 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.759sec(train) 4.601sec(infer)
# Epoch 139 tst: l 0.672 a 0.799 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.552sec
# Epoch 140 tr: l 0.485 a 0.832 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.086sec(train) 4.574sec(infer)
# Epoch 140 tst: l 0.673 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.193sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l 0.484 a 0.833 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.432sec(train) 4.163sec(infer)
# Epoch 141 tst: l 0.676 a 0.798 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.688sec
# Epoch 142 tr: l 0.496 a 0.835 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.504sec(train) 4.521sec(infer)
# Epoch 142 tst: l 0.671 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.474sec
# Epoch 143 tr: l 0.473 a 0.835 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.967sec(train) 5.710sec(infer)
# Epoch 143 tst: l 0.664 a 0.800 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.965sec
# Epoch 144 tr: l 0.474 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.211sec(train) 4.161sec(infer)
# Epoch 144 tst: l 0.678 a 0.800 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.575sec
# Epoch 145 tr: l 0.477 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.205sec(train) 4.918sec(infer)
# Epoch 145 tst: l 0.667 a 0.801 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.479sec
# Epoch 146 tr: l 0.484 a 0.838 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.242sec(train) 4.322sec(infer)
# Epoch 146 tst: l 0.665 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.113sec
# Epoch 147 tr: l 0.479 a 0.834 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.719sec(train) 4.966sec(infer)
# Epoch 147 tst: l 0.663 a 0.799 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.988sec
# Epoch 148 tr: l 0.473 a 0.834 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.891sec(train) 5.233sec(infer)
# Epoch 148 tst: l 0.661 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.490sec
# Epoch 149 tr: l 0.462 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.259sec(train) 4.530sec(infer)
# Epoch 149 tst: l 0.657 a 0.803 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.275sec
# Epoch 150 tr: l 0.485 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.572sec(train) 4.433sec(infer)
# Epoch 150 tst: l 0.661 a 0.805 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.546sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l 0.472 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.731sec(train) 3.976sec(infer)
# Epoch 151 tst: l 0.658 a 0.803 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.477sec
# Epoch 152 tr: l 0.468 a 0.836 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.197sec(train) 5.302sec(infer)
# Epoch 152 tst: l 0.654 a 0.806 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.736sec
# Epoch 153 tr: l 0.461 a 0.838 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.505sec(train) 6.142sec(infer)
# Epoch 153 tst: l 0.661 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.012sec
# Epoch 154 tr: l 0.460 a 0.840 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.112sec(train) 3.875sec(infer)
# Epoch 154 tst: l 0.660 a 0.803 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.455sec
# Epoch 155 tr: l 0.460 a 0.839 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.342sec(train) 4.838sec(infer)
# Epoch 155 tst: l 0.661 a 0.805 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.344sec
# Epoch 156 tr: l 0.461 a 0.839 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.672sec(train) 3.788sec(infer)
# Epoch 156 tst: l 0.651 a 0.806 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.653sec
# Epoch 157 tr: l 0.440 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.326sec(train) 4.738sec(infer)
# Epoch 157 tst: l 0.650 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.042sec
# Epoch 158 tr: l 0.450 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.512sec(train) 5.489sec(infer)
# Epoch 158 tst: l 0.654 a 0.806 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.490sec
# Epoch 159 tr: l 0.460 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.647sec(train) 3.646sec(infer)
# Epoch 159 tst: l 0.660 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.600sec
# Epoch 160 tr: l 0.451 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.804sec(train) 4.559sec(infer)
# Epoch 160 tst: l 0.654 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.324sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l 0.437 a 0.846 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.777sec(train) 5.363sec(infer)
# Epoch 161 tst: l 0.642 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.961sec
# Epoch 162 tr: l 0.454 a 0.841 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.057sec(train) 4.415sec(infer)
# Epoch 162 tst: l 0.647 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.540sec
# Epoch 163 tr: l 0.446 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.278sec(train) 4.559sec(infer)
# Epoch 163 tst: l 0.656 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.319sec
# Epoch 164 tr: l 0.452 a 0.840 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.250sec(train) 4.712sec(infer)
# Epoch 164 tst: l 0.654 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.718sec
# Epoch 165 tr: l 0.441 a 0.841 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.374sec(train) 3.598sec(infer)
# Epoch 165 tst: l 0.642 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.304sec
# Epoch 166 tr: l 0.444 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.391sec(train) 5.285sec(infer)
# Epoch 166 tst: l 0.642 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.779sec
# Epoch 167 tr: l 0.448 a 0.846 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.997sec(train) 6.673sec(infer)
# Epoch 167 tst: l 0.646 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.174sec
# Epoch 168 tr: l 0.435 a 0.848 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.478sec(train) 3.947sec(infer)
# Epoch 168 tst: l 0.647 a 0.809 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.277sec
# Epoch 169 tr: l 0.442 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.727sec(train) 4.600sec(infer)
# Epoch 169 tst: l 0.639 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.057sec
# Epoch 170 tr: l 0.430 a 0.847 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.754sec(train) 3.341sec(infer)
# Epoch 170 tst: l 0.646 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.976sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 171 tr: l 0.436 a 0.846 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.313sec(train) 6.102sec(infer)
# Epoch 171 tst: l 0.640 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.180sec
# Epoch 172 tr: l 0.435 a 0.846 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.548sec(train) 5.245sec(infer)
# Epoch 172 tst: l 0.658 a 0.805 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.898sec
# Epoch 173 tr: l 0.441 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.271sec(train) 3.171sec(infer)
# Epoch 173 tst: l 0.639 a 0.812 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.146sec
# Epoch 174 tr: l 0.436 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.570sec(train) 4.868sec(infer)
# Epoch 174 tst: l 0.638 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.537sec
# Epoch 175 tr: l 0.435 a 0.847 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.963sec(train) 4.465sec(infer)
# Epoch 175 tst: l 0.644 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.751sec
# Epoch 176 tr: l 0.427 a 0.849 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.749sec(train) 4.763sec(infer)
# Epoch 176 tst: l 0.645 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  3.892sec
# Epoch 177 tr: l 0.419 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.526sec(train) 4.880sec(infer)
# Epoch 177 tst: l 0.641 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.516sec
# Epoch 178 tr: l 0.422 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.038sec(train) 4.121sec(infer)
# Epoch 178 tst: l 0.638 a 0.812 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.601sec
# Epoch 179 tr: l 0.423 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.372sec(train) 4.205sec(infer)
# Epoch 179 tst: l 0.632 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.310sec
# Epoch 180 tr: l 0.429 a 0.849 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.760sec(train) 5.327sec(infer)
# Epoch 180 tst: l 0.635 a 0.813 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.584sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 181 tr: l 0.425 a 0.848 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 18.165sec(train) 6.620sec(infer)
# Epoch 181 tst: l 0.632 a 0.812 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.006sec
# Epoch 182 tr: l 0.419 a 0.849 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.911sec(train) 4.567sec(infer)
# Epoch 182 tst: l 0.628 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.273sec
# Epoch 183 tr: l 0.404 a 0.856 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.013sec(train) 4.620sec(infer)
# Epoch 183 tst: l 0.626 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.668sec
# Epoch 184 tr: l 0.420 a 0.850 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.233sec(train) 3.420sec(infer)
# Epoch 184 tst: l 0.706 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.370sec
# Epoch 185 tr: l 0.408 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.038sec(train) 5.286sec(infer)
# Epoch 185 tst: l 0.629 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.912sec
# Epoch 186 tr: l 0.408 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.105sec(train) 4.815sec(infer)
# Epoch 186 tst: l 0.625 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.694sec
# Epoch 187 tr: l 0.420 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.448sec(train) 3.408sec(infer)
# Epoch 187 tst: l 0.627 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.451sec
# Epoch 188 tr: l 0.411 a 0.852 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.350sec(train) 4.559sec(infer)
# Epoch 188 tst: l 0.626 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.366sec
# Epoch 189 tr: l 0.407 a 0.856 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.406sec(train) 4.293sec(infer)
# Epoch 189 tst: l 0.624 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.845sec
# Epoch 190 tr: l 0.409 a 0.853 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.588sec(train) 4.680sec(infer)
# Epoch 190 tst: l 0.628 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  4.024sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 191 tr: l 0.410 a 0.854 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 19.265sec(train) 4.775sec(infer)
# Epoch 191 tst: l 0.621 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.320sec
# Epoch 192 tr: l 0.442 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.784sec(train) 3.633sec(infer)
# Epoch 192 tst: l 0.624 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.611sec
# Epoch 193 tr: l 0.412 a 0.853 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.206sec(train) 4.596sec(infer)
# Epoch 193 tst: l 0.621 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.321sec
# Epoch 194 tr: l 0.403 a 0.857 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.323sec(train) 5.756sec(infer)
# Epoch 194 tst: l 0.620 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.346sec
# Epoch 195 tr: l 0.392 a 0.857 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.125sec(train) 6.229sec(infer)
# Epoch 195 tst: l 0.624 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.479sec
# Epoch 196 tr: l 0.408 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.677sec(train) 4.563sec(infer)
# Epoch 196 tst: l 0.622 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.323sec
# Epoch 197 tr: l 0.418 a 0.850 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.801sec(train) 4.618sec(infer)
# Epoch 197 tst: l 0.620 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.716sec
# Epoch 198 tr: l 0.407 a 0.856 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.613sec(train) 3.798sec(infer)
# Epoch 198 tst: l 0.622 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.292sec
# Epoch 199 tr: l 0.390 a 0.861 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.651sec(train) 5.277sec(infer)
# Epoch 199 tst: l 0.621 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.697sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 1.27 hour (4557.267 sec)
# ---------------------------------DFCA-LI, lr: 0.1, seed: 409---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 200, 'batch_size': 100, 'tau': 5, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 3.850 a 0.019 clct[np.int64(85), np.int64(115)] cl_acc 0.545  2.939sec
# Epoch -1 tst: l 3.851 a 0.022 clct[np.int64(22), np.int64(18)] cl_acc 0.650  2.794sec
# Epoch 0 tr: l 3.841 a 0.029 clct[np.int64(182), np.int64(18)] cl_acc 0.560  lr 0.100000 19.042sec(train) 3.068sec(infer)
# Epoch 0 tst: l 3.843 a 0.030 clct[np.int64(38), np.int64(2)] cl_acc 0.550  1.589sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 3.829 a 0.047 clct[np.int64(190), np.int64(10)] cl_acc 0.540  lr 0.100000 15.485sec(train) 2.638sec(infer)
# Epoch 1 tst: l 3.831 a 0.043 clct[np.int64(40), np.int64(0)] cl_acc 0.500  0.963sec
# Epoch 2 tr: l 3.810 a 0.052 clct[np.int64(194), np.int64(6)] cl_acc 0.530  lr 0.100000 15.603sec(train) 4.244sec(infer)
# Epoch 2 tst: l 3.816 a 0.049 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.815sec
# Epoch 3 tr: l 3.784 a 0.071 clct[np.int64(195), np.int64(5)] cl_acc 0.525  lr 0.100000 14.557sec(train) 5.701sec(infer)
# Epoch 3 tst: l 3.791 a 0.068 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.757sec
# Epoch 4 tr: l 3.740 a 0.087 clct[np.int64(195), np.int64(5)] cl_acc 0.525  lr 0.100000 18.550sec(train) 5.861sec(infer)
# Epoch 4 tst: l 3.751 a 0.086 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.067sec
# Epoch 5 tr: l 3.665 a 0.118 clct[np.int64(195), np.int64(5)] cl_acc 0.525  lr 0.100000 15.744sec(train) 4.593sec(infer)
# Epoch 5 tst: l 3.682 a 0.114 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.015sec
# Epoch 6 tr: l 3.543 a 0.143 clct[np.int64(195), np.int64(5)] cl_acc 0.525  lr 0.100000 14.872sec(train) 4.425sec(infer)
# Epoch 6 tst: l 3.561 a 0.141 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.248sec
# Epoch 7 tr: l 3.354 a 0.177 clct[np.int64(198), np.int64(2)] cl_acc 0.510  lr 0.100000 15.474sec(train) 3.936sec(infer)
# Epoch 7 tst: l 3.373 a 0.172 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.487sec
# Epoch 8 tr: l 3.232 a 0.187 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 15.749sec(train) 5.326sec(infer)
# Epoch 8 tst: l 3.244 a 0.183 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.975sec
# Epoch 9 tr: l 3.113 a 0.190 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 19.678sec(train) 4.119sec(infer)
# Epoch 9 tst: l 3.141 a 0.185 clct[np.int64(40), np.int64(0)] cl_acc 0.500  1.615sec
# Epoch 10 tr: l 3.040 a 0.206 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 15.238sec(train) 4.046sec(infer)
# Epoch 10 tst: l 3.066 a 0.198 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.452sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 3.013 a 0.197 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 14.359sec(train) 4.656sec(infer)
# Epoch 11 tst: l 3.035 a 0.193 clct[np.int64(40), np.int64(0)] cl_acc 0.500  2.331sec
# Epoch 12 tr: l 2.848 a 0.220 clct[np.int64(199), np.int64(1)] cl_acc 0.505  lr 0.100000 13.977sec(train) 3.784sec(infer)
# ...
# Epoch 128 tst: l 0.700 a 0.779 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.472sec
# Epoch 129 tr: l 0.484 a 0.833 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.917sec(train) 3.624sec(infer)
# Epoch 129 tst: l 0.622 a 0.807 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.868sec
# Epoch 130 tr: l 0.477 a 0.837 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.630sec(train) 3.788sec(infer)
# Epoch 130 tst: l 0.608 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.930sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l 0.459 a 0.838 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.470sec(train) 2.714sec(infer)
# Epoch 131 tst: l 0.603 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.211sec
# Epoch 132 tr: l 0.446 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.829sec(train) 2.733sec(infer)
# Epoch 132 tst: l 0.598 a 0.813 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.198sec
# Epoch 133 tr: l 0.479 a 0.833 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.517sec(train) 3.160sec(infer)
# Epoch 133 tst: l 0.627 a 0.804 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.568sec
# Epoch 134 tr: l 0.452 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.016sec(train) 3.991sec(infer)
# Epoch 134 tst: l 0.605 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.853sec
# Epoch 135 tr: l 0.448 a 0.842 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.018sec(train) 3.333sec(infer)
# Epoch 135 tst: l 0.599 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.342sec
# Epoch 136 tr: l 0.484 a 0.843 clct[np.int64(101), np.int64(99)] cl_acc 0.995  lr 0.100000 10.971sec(train) 2.730sec(infer)
# Epoch 136 tst: l 0.607 a 0.808 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.313sec
# Epoch 137 tr: l 0.438 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.431sec(train) 2.889sec(infer)
# Epoch 137 tst: l 0.595 a 0.810 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.408sec
# Epoch 138 tr: l 0.439 a 0.843 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.759sec(train) 3.075sec(infer)
# Epoch 138 tst: l 0.602 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.501sec
# Epoch 139 tr: l 0.436 a 0.845 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.528sec(train) 3.662sec(infer)
# Epoch 139 tst: l 0.592 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.956sec
# Epoch 140 tr: l 0.435 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.321sec(train) 2.886sec(infer)
# Epoch 140 tst: l 0.599 a 0.813 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.467sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l 0.429 a 0.846 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.450sec(train) 2.683sec(infer)
# Epoch 141 tst: l 0.593 a 0.811 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.348sec
# Epoch 142 tr: l 0.435 a 0.844 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.137sec(train) 2.710sec(infer)
# Epoch 142 tst: l 0.595 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.362sec
# Epoch 143 tr: l 0.429 a 0.848 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.539sec(train) 3.426sec(infer)
# Epoch 143 tst: l 0.592 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.741sec
# Epoch 144 tr: l 0.426 a 0.849 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.345sec(train) 4.836sec(infer)
# Epoch 144 tst: l 0.590 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.385sec
# Epoch 145 tr: l 0.426 a 0.847 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.195sec(train) 2.744sec(infer)
# Epoch 145 tst: l 0.586 a 0.817 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.040sec
# Epoch 146 tr: l 0.413 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.571sec(train) 2.918sec(infer)
# Epoch 146 tst: l 0.592 a 0.815 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.385sec
# Epoch 147 tr: l 0.421 a 0.850 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.530sec(train) 3.111sec(infer)
# Epoch 147 tst: l 0.588 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.460sec
# Epoch 148 tr: l 0.412 a 0.850 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.680sec(train) 3.136sec(infer)
# Epoch 148 tst: l 0.584 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.585sec
# Epoch 149 tr: l 0.421 a 0.849 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.762sec(train) 4.263sec(infer)
# Epoch 149 tst: l 0.584 a 0.816 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.782sec
# Epoch 150 tr: l 0.425 a 0.848 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.494sec(train) 2.919sec(infer)
# Epoch 150 tst: l 0.577 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.458sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l 0.420 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.309sec(train) 2.689sec(infer)
# Epoch 151 tst: l 0.593 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.345sec
# Epoch 152 tr: l 0.416 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.135sec(train) 3.101sec(infer)
# Epoch 152 tst: l 0.577 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.428sec
# Epoch 153 tr: l 0.438 a 0.853 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.193sec(train) 3.561sec(infer)
# Epoch 153 tst: l 0.575 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.925sec
# Epoch 154 tr: l 0.407 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.422sec(train) 2.743sec(infer)
# Epoch 154 tst: l 0.571 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.995sec
# Epoch 155 tr: l 0.395 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.472sec(train) 2.707sec(infer)
# Epoch 155 tst: l 0.575 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.335sec
# Epoch 156 tr: l 0.400 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.632sec(train) 2.734sec(infer)
# Epoch 156 tst: l 0.574 a 0.818 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.357sec
# Epoch 157 tr: l 0.409 a 0.853 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.545sec(train) 3.150sec(infer)
# Epoch 157 tst: l 0.570 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.574sec
# Epoch 158 tr: l 0.411 a 0.851 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.343sec(train) 5.201sec(infer)
# Epoch 158 tst: l 0.576 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.648sec
# Epoch 159 tr: l 0.400 a 0.853 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.200sec(train) 2.758sec(infer)
# Epoch 159 tst: l 0.573 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.107sec
# Epoch 160 tr: l 0.390 a 0.856 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.726sec(train) 2.682sec(infer)
# Epoch 160 tst: l 0.568 a 0.821 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.334sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l 0.398 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.154sec(train) 2.964sec(infer)
# Epoch 161 tst: l 0.569 a 0.823 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.380sec
# Epoch 162 tr: l 0.405 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.822sec(train) 3.420sec(infer)
# Epoch 162 tst: l 0.568 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.585sec
# Epoch 163 tr: l 0.391 a 0.857 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.383sec(train) 4.242sec(infer)
# Epoch 163 tst: l 0.564 a 0.823 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.695sec
# Epoch 164 tr: l 0.402 a 0.855 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.769sec(train) 2.681sec(infer)
# Epoch 164 tst: l 0.564 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.348sec
# Epoch 165 tr: l 0.392 a 0.858 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.309sec(train) 2.906sec(infer)
# Epoch 165 tst: l 0.572 a 0.820 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.453sec
# Epoch 166 tr: l 0.379 a 0.861 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.258sec(train) 3.170sec(infer)
# Epoch 166 tst: l 0.562 a 0.822 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.556sec
# Epoch 167 tr: l 0.379 a 0.860 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.984sec(train) 3.360sec(infer)
# Epoch 167 tst: l 0.563 a 0.823 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.976sec
# Epoch 168 tr: l 0.393 a 0.857 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 17.065sec(train) 2.945sec(infer)
# Epoch 168 tst: l 0.559 a 0.825 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.139sec
# Epoch 169 tr: l 0.427 a 0.859 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.644sec(train) 2.729sec(infer)
# Epoch 169 tst: l 0.559 a 0.824 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.108sec
# Epoch 170 tr: l 0.389 a 0.858 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.606sec(train) 2.726sec(infer)
# Epoch 170 tst: l 0.563 a 0.822 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.247sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 171 tr: l 0.394 a 0.857 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.358sec(train) 3.307sec(infer)
# Epoch 171 tst: l 0.576 a 0.819 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.694sec
# Epoch 172 tr: l 0.387 a 0.858 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.951sec(train) 4.969sec(infer)
# Epoch 172 tst: l 0.559 a 0.825 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.352sec
# Epoch 173 tr: l 0.375 a 0.862 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 14.002sec(train) 2.749sec(infer)
# Epoch 173 tst: l 0.614 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.786sec
# Epoch 174 tr: l 0.376 a 0.861 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.914sec(train) 2.873sec(infer)
# Epoch 174 tst: l 0.550 a 0.825 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.165sec
# Epoch 175 tr: l 0.392 a 0.856 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.082sec(train) 2.986sec(infer)
# Epoch 175 tst: l 0.625 a 0.814 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.166sec
# Epoch 176 tr: l 0.378 a 0.860 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.179sec(train) 3.194sec(infer)
# Epoch 176 tst: l 0.552 a 0.825 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.389sec
# Epoch 177 tr: l 0.368 a 0.864 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.259sec(train) 4.538sec(infer)
# Epoch 177 tst: l 0.554 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.740sec
# Epoch 178 tr: l 0.371 a 0.863 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.224sec(train) 2.931sec(infer)
# Epoch 178 tst: l 0.549 a 0.825 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.478sec
# Epoch 179 tr: l 0.370 a 0.863 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.781sec(train) 2.738sec(infer)
# Epoch 179 tst: l 0.551 a 0.828 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.343sec
# Epoch 180 tr: l 0.371 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.276sec(train) 3.003sec(infer)
# Epoch 180 tst: l 0.547 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.209sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 181 tr: l 0.381 a 0.860 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.388sec(train) 3.411sec(infer)
# Epoch 181 tst: l 0.556 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.833sec
# Epoch 182 tr: l 0.365 a 0.868 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 16.173sec(train) 3.458sec(infer)
# Epoch 182 tst: l 0.549 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.416sec
# Epoch 183 tr: l 0.370 a 0.863 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.107sec(train) 2.753sec(infer)
# Epoch 183 tst: l 0.545 a 0.829 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.121sec
# Epoch 184 tr: l 0.366 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.059sec(train) 2.946sec(infer)
# Epoch 184 tst: l 0.542 a 0.827 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.244sec
# Epoch 185 tr: l 0.369 a 0.864 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.388sec(train) 3.422sec(infer)
# Epoch 185 tst: l 0.549 a 0.828 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.714sec
# Epoch 186 tr: l 0.375 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.493sec(train) 3.772sec(infer)
# Epoch 186 tst: l 0.549 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.269sec
# Epoch 187 tr: l 0.361 a 0.868 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.256sec(train) 2.748sec(infer)
# Epoch 187 tst: l 0.548 a 0.829 clct[np.int64(20), np.int64(20)] cl_acc 1.000  0.888sec
# Epoch 188 tr: l 0.367 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.409sec(train) 2.917sec(infer)
# Epoch 188 tst: l 0.547 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.261sec
# Epoch 189 tr: l 0.353 a 0.867 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.115sec(train) 2.709sec(infer)
# Epoch 189 tst: l 0.544 a 0.829 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.349sec
# Epoch 190 tr: l 0.357 a 0.868 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.634sec(train) 3.157sec(infer)
# Epoch 190 tst: l 0.544 a 0.828 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.407sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 191 tr: l 0.365 a 0.864 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.835sec(train) 4.816sec(infer)
# Epoch 191 tst: l 0.556 a 0.827 clct[np.int64(20), np.int64(20)] cl_acc 1.000  2.658sec
# Epoch 192 tr: l 0.362 a 0.866 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 15.097sec(train) 2.726sec(infer)
# Epoch 192 tst: l 0.543 a 0.828 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.026sec
# Epoch 193 tr: l 0.386 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.616sec(train) 2.717sec(infer)
# Epoch 193 tst: l 0.538 a 0.831 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.188sec
# Epoch 194 tr: l 0.349 a 0.870 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 10.883sec(train) 3.006sec(infer)
# Epoch 194 tst: l 0.546 a 0.826 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.587sec
# Epoch 195 tr: l 0.360 a 0.864 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.438sec(train) 3.376sec(infer)
# Epoch 195 tst: l 0.535 a 0.832 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.590sec
# Epoch 196 tr: l 0.360 a 0.867 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 13.963sec(train) 4.364sec(infer)
# Epoch 196 tst: l 0.539 a 0.829 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.722sec
# Epoch 197 tr: l 0.356 a 0.866 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 12.196sec(train) 2.713sec(infer)
# Epoch 197 tst: l 0.538 a 0.830 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.464sec
# Epoch 198 tr: l 0.342 a 0.873 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.151sec(train) 2.914sec(infer)
# Epoch 198 tst: l 0.537 a 0.829 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.457sec
# Epoch 199 tr: l 0.359 a 0.865 clct[np.int64(100), np.int64(100)] cl_acc 1.000  lr 0.100000 11.441sec(train) 2.975sec(infer)
# Epoch 199 tst: l 0.542 a 0.830 clct[np.int64(20), np.int64(20)] cl_acc 1.000  1.421sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.94 hour (3379.538 sec)

# %%
r_ifca = {}
r_dfca_gi = {}
r_dfca_li = {}

r_ifca['test_loss'] = []
r_ifca['test_acc'] = []
r_ifca['cl_acc'] = []
for i in range(len(learning_rates)):
    r_ifca['test_loss'].append(ifca[i][0])
    r_ifca['test_acc'].append(ifca[i][1])
    r_ifca['cl_acc'].append(ifca[i][2])

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])

r_dfca_li['test_loss'] = []
r_dfca_li['test_acc'] = []
r_dfca_li['cl_acc'] = []
for i in range(len(learning_rates)):
    r_dfca_li['test_loss'].append(dfca_li[i][0])
    r_dfca_li['test_acc'].append(dfca_li[i][1])
    r_dfca_li['cl_acc'].append(dfca_li[i][2])

print(r_ifca)

os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_loss'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_loss'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_acc'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_acc'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('test accuracy', fontsize=20)
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_acc.png'))

    plt.figure(figsize=(10,7))
    plt.ylim([0, 1.1])
    plt.plot(r_ifca['cl_acc'][l][:31], label='ifca', color='xkcd:azure', marker='o')
    plt.plot(r_dfca_li['cl_acc'][l][:31], label='dfca-li', color='red', marker='o')
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green', marker='o')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('cluster acc', fontsize=20)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.savefig(os.path.join('graphs', 'cluster_acc.png'))
# Out:
# {'test_loss': [[3.8501142430305486, 3.8450124049186707, 3.83865029335022, 3.83034286737442, 3.8183295154571533, 3.7998185443878176, 3.769897887706757, 3.719760762453079, 3.634900890588761, 3.51773999094963, 3.3694716000556943, 3.228031848669052, 3.043555643558502, 2.9168420219421387, 2.7416764080524447, 2.6209776735305788, 2.5072056943178174, 2.3586073088645936, 2.3081514585018157, 2.2146940368413923, 2.1105817520618437, 2.0738935124874116, 1.9995841658115387, 1.9473332434892654, 1.888746688365936, 1.8635006457567216, 1.808535893559456, 1.780926320552826, 1.76195770919323, 1.6926221883296964, 1.6642405313253401, 1.686596909761429, 1.605388897061348, 1.5897278380393982, 1.5643046993017198, 1.5296978807449342, 1.5278112906217576, 1.4810332122445105, 1.4717206233739852, 1.4580785113573076, 1.4214485093951226, 1.393085477948189, 1.3997874316573142, 1.3727668394148347, 1.373532734811306, 1.3440902307629585, 1.3162448263168334, 1.3062603691220285, 1.2894230157136917, 1.284917750954628, 1.2590370744466781, 1.2456112343072892, 1.236003254354, 1.222681320309639, 1.2073323380947112, 1.1947591820359231, 1.1730096389353275, 1.1723314750194551, 1.150773509144783, 1.1472472453117368, 1.1318076345324517, 1.1260869506001474, 1.1128368777036666, 1.10571396201849, 1.0833558422327043, 1.081027618646622, 1.0630231511592865, 1.0697375801205635, 1.0562271469831466, 1.0499496123194696, 1.0371503469347954, 1.0280735525488853, 1.0169115722179414, 1.0145574322342872, 1.001505680978298, 0.9987504145503043, 0.983018071949482, 0.9833243647217749, 0.9684162333607673, 0.9700331881642341, 0.9634639838337898, 0.9549122485518456, 0.9492802393436431, 0.9384343734383584, 0.934963404685259, 0.9265712150931357, 0.9200092530250549, 0.9139997947216034, 0.9065285587310793, 0.9051875956356525, 0.8966330954432487, 0.8961542655527591, 0.8939085942506789, 0.8828206749260424, 0.8778771683573723, 0.875026557892561, 0.8709631031751632, 0.8693241196870805, 0.8609257416427137, 0.8574187318980693, 0.8540016253292559, 0.8526559042930604, 0.8473796047270298, 0.8453443351387978, 0.8393973582983015, 0.8355482506752014, 0.8368541313707828, 0.8261002241075038, 0.8246909695863724, 0.8166805497556926, 0.8179302108287813, 0.8158221589773893, 0.8113813753426076, 0.8092431062459946, 0.8057476998865605, 0.8045182515680789, 0.7967158789932729, 0.7960772880911827, 0.7892592933773994, 0.7892847043275834, 0.7838232161104679, 0.7830447989702225, 0.7788589053601027, 0.7773403009772301, 0.7733255161345005, 0.7734676891565323, 0.7695152104645968, 0.7683446981012821, 0.7624225462228059, 0.7617212136089802, 0.7573149447888136, 0.756590622663498, 0.7547965345531702, 0.7542051427811384, 0.7538445840775966, 0.754211513325572, 0.7493351578712464, 0.7465020007640123, 0.7429505716264247, 0.7416304436326027, 0.7414970014244318, 0.740400063470006, 0.7379664205759763, 0.7369432733207941, 0.734690240956843, 0.7317897902429104, 0.7292535697668792, 0.7272705663740635, 0.7250410022586584, 0.7233476734161377, 0.7211740563064815, 0.7201571782678365, 0.7167768136411905, 0.7160683985427022, 0.716068813726306, 0.7143944627046586, 0.71182187192142, 0.7109588503465056, 0.7083809521049261, 0.7077067644149065, 0.7074290478602052, 0.7052542939782142, 0.704063040614128, 0.7009777179360389, 0.7012373100593686, 0.7003722016513347, 0.6984922774136068, 0.6984727025404573, 0.6969652369990944, 0.6966093938052654, 0.6935591575875879, 0.69265017721802, 0.6904847413673997, 0.6900254502147436, 0.6889879936538637, 0.6873686161637306, 0.6864163825474678, 0.6844608796387911, 0.6859118447639048, 0.6833458248898386, 0.6836952416226267, 0.6806230929121375, 0.6808599353767931, 0.6775013019517064, 0.6780463168025017, 0.6758417665958405, 0.6763893162831663, 0.6740503350272775, 0.6755390353873373, 0.6729767189919948, 0.6714913908764719, 0.6697419256903231, 0.6686711175739766, 0.6682246839441358, 0.6665510672330855, 0.6666153341345489, 0.6648193764314055, 0.6652481723949313, 0.6651911108568311, 0.6650069388560951, 0.6651169027201831]], 'test_ ...
