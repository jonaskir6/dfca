# %%
import argparse
import json
import os
import time
import itertools
import pickle
import copy
import random
import math

import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset, TensorDataset


import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config.json

# %%
LR_DECAY = False
def get_config():

    # read config json and update the sysarg
    with open("config.json", "r") as read_file:
        config = json.load(read_file)

    if config["config_override"] == "":
        del config['config_override']
    else:
        print(config['config_override'])
        config_override = json.loads(config['config_override'])
        del config['config_override']
        config.update(config_override)

    return config

# %% [markdown]
# Class SimpleLinear with simple MLP for MNIST Classification

# %%
class SimpleLinear(torch.nn.Module):

    def __init__(self, h1=2048):
        super().__init__()
        self.fc1 = torch.nn.Linear(28*28, h1)
        self.fc2 = torch.nn.Linear(h1, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        # x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

    # def weight(self):
    #     return self.linear1.weight

# %% [markdown]
# Class TrainMNISTCluster with all the methods needed to run the experiments

# %%
class TrainMNISTCluster(object):
    def __init__(self, config, device):
        self.config = config
        self.device = device

        assert self.config['m'] % self.config['p'] == 0

    def setup(self):

        os.makedirs(self.config['project_dir'], exist_ok = True)

        self.result_fname = os.path.join(self.config['project_dir'], 'results.pickle')
        self.checkpoint_fname = os.path.join(self.config['project_dir'], 'checkpoint.pt')

        self.setup_datasets()
        self.setup_models()

        self.epoch = None
        self.lr = None


    def setup_datasets(self):

        np.random.seed(self.config['data_seed'])

        # generate indices for each dataset
        # also write cluster info

        MNIST_TRAINSET_DATA_SIZE = 60000
        MNIST_TESTSET_DATA_SIZE = 10000

        np.random.seed(self.config['data_seed'])

        cfg = self.config

        self.dataset = {}

        if cfg['uneven'] == True:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        else:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        # import ipdb; ipdb.set_trace()


    def _setup_dataset_random_n(self, num_data, p, m, n, random = True):

        print("m:",m)
        print("p:",p)
        print("num_data:",num_data)

        dataset = {}

        cfg = self.config

        data_indices = []
        cluster_assign = []

        m_per_cluster = m // p

        for p_i in range(p):

            ll = list(np.random.permutation(num_data))

            ll2 = chunkify_uneven(ll, m_per_cluster) # splits ll into m lists
            data_indices += ll2

            cluster_assign += [p_i for _ in range(m_per_cluster)]

        data_indices = np.array(data_indices, dtype=object)
        cluster_assign = np.array(cluster_assign)
        assert data_indices.shape[0] == cluster_assign.shape[0]
        assert data_indices.shape[0] == m


        return data_indices, cluster_assign


    def _load_MNIST(self, train=True):
        transforms = torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               # torchvision.transforms.Normalize(
                               #   (0.1307,), (0.3081,))
                             ])
        if train:
            mnist_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms)
        else:
            mnist_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms)

        dl = DataLoader(mnist_dataset)

        X = dl.dataset.data # (60000,28, 28)
        y = dl.dataset.targets #(60000)

        # normalize to have 0 ~ 1 range in each pixel

        X = X / 255.0
        X = X.to(self.device)
        y = y.to(self.device)

        return X, y


    # Need p models for each client

    def setup_models(self):
        np.random.seed(self.config['train_seed'])
        torch.manual_seed(self.config['train_seed'])

        p = self.config['p']

        self.models = [[SimpleLinear(h1 = self.config['h1']).to(self.device) for p_i in range(p)] for m_i in range(m)] # p models with p different params of dimension(1,d) for each client m_i

        self.criterion = torch.nn.CrossEntropyLoss()

        # import ipdb; ipdb.set_trace()


    def run(self):
        num_epochs = self.config['num_epochs']
        lr = self.config['lr']

        results = []

        # epoch -1
        self.epoch = -1

        result = {}
        result['epoch'] = -1

        t0 = time.time()
        res = self.test(train=True)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['train'] = res

        self.print_epoch_stats(res)

        t0 = time.time()
        res = self.test(train=False)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['test'] = res
        self.print_epoch_stats(res)
        results.append(result)

        # this will be used in next epoch
        cluster_assign = result['train']['cluster_assign']

        for epoch in range(num_epochs):
            self.epoch = epoch

            result = {}
            result['epoch'] = epoch

            lr = self.lr_schedule(epoch)
            result['lr'] = lr

            t0 = time.time()
            result['train'] = self.train(cluster_assign, lr = lr)
            t1 = time.time()
            train_time = t1-t0

            t0 = time.time()
            res = self.test(train=True)
            t1 = time.time()
            res['infer_time'] = t1-t0
            res['train_time'] = train_time
            res['lr'] = lr
            result['train'] = res

            self.print_epoch_stats(res)

            t0 = time.time()
            res = self.test(train=False)
            t1 = time.time()
            res['infer_time'] = t1-t0
            result['test'] = res
            self.print_epoch_stats(res)

            results.append(result)

            # this will be used in next epoch's gradient update
            cluster_assign = result['train']['cluster_assign']

            if epoch % 10 == 0 or epoch == num_epochs - 1 :
                with open(self.result_fname, 'wb') as outfile:
                    pickle.dump(results, outfile)
                    print(f'result written at {self.result_fname}')
#                self.save_checkpoint()
                print(f'checkpoint written at {self.checkpoint_fname}')

        plt.figure(figsize=(10,5))
        plt.plot([r['train']['loss'] for r in results], label='train')
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.title('Training Loss per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'train_loss.png'))
        # import ipdb; ipdb.set_trace()

        plt.figure(figsize=(10,5))
        plt.plot([r['test']['acc'] for r in results], label='train')
        plt.xlabel('epoch')
        plt.ylabel('test accuracy')
        plt.title('Test Accuracy per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'test_acc.png'))


    def lr_schedule(self, epoch):
        if self.lr is None:
            self.lr = self.config['lr']

        if epoch % 50 == 0 and epoch != 0 and LR_DECAY:
            self.lr = self.lr * 0.1

        return self.lr


    def cluster_assignment(self, m_i):
        


    def print_epoch_stats(self, res):
        if res['is_train']:
            data_str = 'tr'
        else:
            data_str = 'tst'

        if 'train_time' in res:
            time_str = f"{res['train_time']:.3f}sec(train) {res['infer_time']:.3f}sec(infer)"
        else:
            time_str = f"{res['infer_time']:.3f}sec"

        if 'lr' in res:
            lr_str = f" lr {res['lr']:4f}"
        else:
            lr_str = ""

        str0 = f"Epoch {self.epoch} {data_str}: l {res['loss']:.3f} a {res['acc']:.3f} clct{res['cl_ct']}{lr_str} {time_str}"

        print(str0)

    def train(self, cluster_assign, lr):
        VERBOSE = 0

        cfg = self.config
        m = cfg['m']
        p = cfg['p']
        tau = cfg['tau']

        # run local update
        t0 = time.time()


        for m_i in range(m):
            if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')

            (X, y) = self.load_data(m_i)

            p_i = cluster_assign[m_i]
            model = self.models[m_i][p_i]

            # LOCAL UPDATE PER MACHINE tau times
            for step_i in range(tau):

                y_logit = model(X)
                loss = self.criterion(y_logit, y)

                model.zero_grad()
                loss.backward()
                self.local_param_update(model, lr)

            model.zero_grad()


        t02 = time.time()
        # print(f'running single ..took {t02-t01:.3f}sec')


        t1 = time.time()
        if VERBOSE: print(f'local update {t1-t0:.3f}sec')

        # apply gradient update
        t0 = time.time()

        # NEEDS TO BE DECENTRALIZED
        self.dec_param_update()
        t1 = time.time()

        if VERBOSE: print(f'global update {t1-t0:.3f}sec')

    def check_local_model_loss(self, local_models):
        # for debugging
        m = self.config['m']

        losses = []
        for m_i in range(m):
            (X, y) = self.load_data(m_i)
            y_logit = local_models[m_i](X)
            loss = self.criterion(y_logit, y)

            losses.append(loss.item())

        return np.array(losses)


    def get_inference_stats(self, train = True):
        cfg = self.config
        if train:
            m = cfg['m']
            dataset = self.dataset['train']
        else:
            m = cfg['m_test']
            dataset = self.dataset['test']

        p = cfg['p']


        num_data = 0
        losses = {}
        corrects = {}
        for m_i in range(m):
            (X, y) = self.load_data(m_i, train=train) # load batch data rotated

            for p_i in range(p):
                y_logit = self.models[m_i][p_i](X)
                loss = self.criterion(y_logit, y) # loss of
                n_correct = self.n_correct(y_logit, y)

                # if torch.isnan(loss):
                #     print("nan loss: ", dataset['data_indices'][m_i])

                losses[(m_i,p_i)] = loss.item()
                corrects[(m_i,p_i)] = n_correct

            num_data += X.shape[0]

        # calculate loss and cluster the machines
        cluster_assign = []
        for m_i in range(m):
            machine_losses = [ losses[(m_i,p_i)] for p_i in range(p) ]
            min_p_i = np.argmin(machine_losses)
            cluster_assign.append(min_p_i)

        # calculate optimal model's loss, acc over all models
        min_corrects = []
        min_losses = []
        for m_i, p_i in enumerate(cluster_assign):

            min_loss = losses[(m_i,p_i)]
            min_losses.append(min_loss)

            min_correct = corrects[(m_i,p_i)]
            min_corrects.append(min_correct)

        # print("losses: ", min_losses)
        loss = np.mean(min_losses)
        acc = np.sum(min_corrects) / num_data


        # check cluster assignment acc
        cl_acc = np.mean(np.array(cluster_assign) == np.array(dataset['cluster_assign']))
        cl_ct = [np.sum(np.array(cluster_assign) == p_i ) for p_i in range(p)]

        res = {} # results
        # res['losses'] = losses
        # res['corrects'] = corrects
        res['cluster_assign'] = cluster_assign
        res['num_data'] = num_data
        res['loss'] = loss
        res['acc'] = acc
        res['cl_acc'] = cl_acc
        res['cl_ct'] = cl_ct
        res['is_train'] = train

        # import ipdb; ipdb.set_trace()

        return res

    def n_correct(self, y_logit, y):
        _, predicted = torch.max(y_logit.data, 1)
        correct = (predicted == y).sum().item()

        return correct

    # TODO Does every Cluster get 4 clients with the same data, but rotated differently?

    def load_data(self, m_i, train=True):
        # this part is very fast since its just rearranging models
        cfg = self.config

        if train:
            dataset = self.dataset['train']
        else:
            dataset = self.dataset['test']

        indices = dataset['data_indices'][m_i]
        p_i = dataset['cluster_assign'][m_i]

        X_batch = dataset['X'][indices]
        y_batch = dataset['y'][indices]

        # k : how many times rotate 90 degree
        # k =1 : 90 , k=2 180, k=3 270

        if cfg['p'] == 4:
            k = p_i
        elif cfg['p'] == 2:
            k = (p_i % 2) * 2
        elif cfg['p'] == 1:
            k = 0
        else:
            raise NotImplementedError("only p=1,2,4 supported")

        X_batch2 = torch.rot90(X_batch, k=int(k), dims = (1,2))
        X_batch3 = X_batch2.reshape(-1, 28 * 28)

        # import ipdb; ipdb.set_trace()

        return X_batch3, y_batch


    def local_param_update(self, model, lr):

        # gradient update manually

        for name, param in model.named_parameters():
            if param.requires_grad:
                param.data -= lr * param.grad

        model.zero_grad()

        # import ipdb; ipdb.set_trace() # we need to check the output of name, check if duplicate exists


    def dec_param_update(self):

        num_clients = self.config['m']

        if num_clients <= 4:
            return

        max_e = 50
        if num_clients <= max_e:
            e = num_clients - 1
        else:
            e = min(max_e, int(np.log(num_clients) * 20))

        if e >= num_clients:
            e = num_clients - 1

        client_indices = list(range(num_clients))

        for m_i in range(num_clients):
            selected_clients = random.sample([i for i in client_indices if i != m_i], e)
            m_i_cluster = self.config['cluster_assign'][m_i]
            for m_j in selected_clients:
                m_j_cluster = self.config['cluster_assign'][m_j]

                m_j_params = dict(self.models[m_j][m_j_cluster].named_parameters())

                for name, param in self.models[m_i][m_i_cluster].named_parameters():
                    m_i_param = param.data.clone()
                    m_j_param = m_j_params[name].data.clone()
                    param.data = (m_i_param + m_j_param) / 2                    

        # import ipdb; ipdb.set_trace()


    def test(self, train=False):
        return self.get_inference_stats(train=train)

    def save_checkpoint(self):
        models_to_save = [model.state_dict() for model in self.models]
        torch.save({'models':models_to_save}, self.checkpoint_fname)

# %% [markdown]
# Running the Experiment

# %%
start_time = time.time()
config = get_config()

config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = TrainMNISTCluster(config, device)
exp.setup()
exp.run()
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 10, 'train_seed': 10, 'project_dir': 'output'}
# Using device: cuda
# m: 1200
# p: 4
# num_data: 60000
# len:  60000
# len:  60000
# len:  60000
# len:  60000
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.1MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 499kB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.58MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 14.2MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# m: 200
# p: 4
# num_data: 10000
# len:  10000
# len:  10000
# len:  10000
# len:  10000
# Epoch -1 tr: l 2.294 a 0.113 clct[346, 317, 154, 383] 2.701sec
# Epoch -1 tst: l 2.292 a 0.114 clct[53, 69, 22, 56] 0.422sec
# Epoch 0 tr: l 2.160 a 0.429 clct[300, 498, 100, 302] lr 0.100000 27.873sec(train) 1.898sec(infer)
# Epoch 0 tst: l 2.158 a 0.434 clct[49, 88, 13, 50] 0.332sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 1 tr: l 1.942 a 0.533 clct[301, 337, 259, 303] lr 0.100000 28.303sec(train) 1.910sec(infer)
# Epoch 1 tst: l 1.940 a 0.539 clct[49, 57, 42, 52] 0.331sec
# Epoch 2 tr: l 1.598 a 0.699 clct[301, 299, 300, 300] lr 0.100000 27.804sec(train) 1.915sec(infer)
# Epoch 2 tst: l 1.590 a 0.707 clct[50, 50, 50, 50] 0.338sec
# Epoch 3 tr: l 1.287 a 0.742 clct[300, 300, 300, 300] lr 0.100000 26.979sec(train) 1.909sec(infer)
# Epoch 3 tst: l 1.277 a 0.751 clct[50, 50, 50, 50] 0.321sec
# Epoch 4 tr: l 1.052 a 0.779 clct[300, 300, 300, 300] lr 0.100000 27.018sec(train) 2.258sec(infer)
# Epoch 4 tst: l 1.039 a 0.789 clct[50, 50, 50, 50] 0.503sec
# Epoch 5 tr: l 0.896 a 0.799 clct[300, 300, 300, 300] lr 0.100000 27.523sec(train) 1.928sec(infer)
# Epoch 5 tst: l 0.883 a 0.808 clct[50, 50, 50, 50] 0.330sec
# Epoch 6 tr: l 0.816 a 0.784 clct[300, 300, 300, 300] lr 0.100000 27.210sec(train) 1.934sec(infer)
# Epoch 6 tst: l 0.804 a 0.790 clct[50, 50, 50, 50] 0.329sec
# Epoch 7 tr: l 0.724 a 0.824 clct[300, 300, 300, 300] lr 0.100000 27.258sec(train) 2.456sec(infer)
# Epoch 7 tst: l 0.711 a 0.834 clct[50, 50, 50, 50] 0.340sec
# Epoch 8 tr: l 0.648 a 0.845 clct[300, 300, 300, 300] lr 0.100000 26.910sec(train) 1.905sec(infer)
# Epoch 8 tst: l 0.636 a 0.854 clct[50, 50, 50, 50] 0.318sec
# Epoch 9 tr: l 0.597 a 0.854 clct[300, 300, 300, 300] lr 0.100000 27.152sec(train) 1.917sec(infer)
# Epoch 9 tst: l 0.588 a 0.862 clct[50, 50, 50, 50] 0.315sec
# Epoch 10 tr: l 0.565 a 0.857 clct[300, 300, 300, 300] lr 0.100000 27.460sec(train) 2.306sec(infer)
# Epoch 10 tst: l 0.557 a 0.865 clct[50, 50, 50, 50] 0.343sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 11 tr: l 0.537 a 0.862 clct[300, 300, 300, 300] lr 0.100000 27.105sec(train) 1.916sec(infer)
# Epoch 11 tst: l 0.528 a 0.869 clct[50, 50, 50, 50] 0.331sec
# Epoch 12 tr: l 0.527 a 0.857 clct[300, 300, 300, 300] lr 0.100000 26.898sec(train) 1.905sec(infer)
# Epoch 12 tst: l 0.517 a 0.865 clct[50, 50, 50, 50] 0.333sec
# Epoch 13 tr: l 0.499 a 0.866 clct[300, 300, 300, 300] lr 0.100000 28.177sec(train) 1.907sec(infer)
# Epoch 13 tst: l 0.491 a 0.871 clct[50, 50, 50, 50] 0.340sec
# Epoch 14 tr: l 0.479 a 0.870 clct[300, 300, 300, 300] lr 0.100000 26.982sec(train) 1.938sec(infer)
# Epoch 14 tst: l 0.473 a 0.877 clct[50, 50, 50, 50] 0.325sec
# Epoch 15 tr: l 0.459 a 0.874 clct[300, 300, 300, 300] lr 0.100000 27.163sec(train) 2.264sec(infer)
# Epoch 15 tst: l 0.454 a 0.881 clct[50, 50, 50, 50] 0.504sec
# Epoch 16 tr: l 0.445 a 0.878 clct[300, 300, 300, 300] lr 0.100000 27.326sec(train) 1.933sec(infer)
# Epoch 16 tst: l 0.440 a 0.883 clct[50, 50, 50, 50] 0.326sec
# Epoch 17 tr: l 0.440 a 0.876 clct[300, 300, 300, 300] lr 0.100000 27.262sec(train) 1.929sec(infer)
# Epoch 17 tst: l 0.434 a 0.882 clct[50, 50, 50, 50] 0.327sec
# Epoch 18 tr: l 0.431 a 0.877 clct[300, 300, 300, 300] lr 0.100000 26.989sec(train) 2.594sec(infer)
# Epoch 18 tst: l 0.427 a 0.884 clct[50, 50, 50, 50] 0.336sec
# Epoch 19 tr: l 0.421 a 0.881 clct[300, 300, 300, 300] lr 0.100000 27.160sec(train) 1.935sec(infer)
# Epoch 19 tst: l 0.418 a 0.887 clct[50, 50, 50, 50] 0.345sec
# Epoch 20 tr: l 0.412 a 0.882 clct[300, 300, 300, 300] lr 0.100000 27.080sec(train) 1.914sec(infer)
# Epoch 20 tst: l 0.407 a 0.888 clct[50, 50, 50, 50] 0.329sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 21 tr: l 0.405 a 0.885 clct[300, 300, 300, 300] lr 0.100000 27.791sec(train) 2.074sec(infer)
# Epoch 21 tst: l 0.403 a 0.890 clct[50, 50, 50, 50] 0.334sec
# Epoch 22 tr: l 0.399 a 0.887 clct[300, 300, 300, 300] lr 0.100000 27.221sec(train) 1.899sec(infer)
# Epoch 22 tst: l 0.396 a 0.892 clct[50, 50, 50, 50] 0.320sec
# Epoch 23 tr: l 0.391 a 0.889 clct[300, 300, 300, 300] lr 0.100000 27.102sec(train) 2.030sec(infer)
# Epoch 23 tst: l 0.388 a 0.894 clct[50, 50, 50, 50] 0.451sec
# Epoch 24 tr: l 0.386 a 0.890 clct[300, 300, 300, 300] lr 0.100000 27.655sec(train) 1.905sec(infer)
# Epoch 24 tst: l 0.382 a 0.895 clct[50, 50, 50, 50] 0.340sec
# Epoch 25 tr: l 0.382 a 0.890 clct[300, 300, 300, 300] lr 0.100000 27.133sec(train) 1.926sec(infer)
# Epoch 25 tst: l 0.380 a 0.895 clct[50, 50, 50, 50] 0.327sec
# Epoch 26 tr: l 0.381 a 0.888 clct[300, 300, 300, 300] lr 0.100000 27.123sec(train) 2.368sec(infer)
# Epoch 26 tst: l 0.378 a 0.894 clct[50, 50, 50, 50] 0.496sec
# Epoch 27 tr: l 0.379 a 0.890 clct[300, 300, 300, 300] lr 0.100000 27.512sec(train) 1.907sec(infer)
# Epoch 27 tst: l 0.375 a 0.895 clct[50, 50, 50, 50] 0.327sec
# Epoch 28 tr: l 0.372 a 0.891 clct[300, 300, 300, 300] lr 0.100000 26.881sec(train) 1.916sec(infer)
# Epoch 28 tst: l 0.370 a 0.896 clct[50, 50, 50, 50] 0.337sec
# Epoch 29 tr: l 0.366 a 0.892 clct[300, 300, 300, 300] lr 0.100000 27.527sec(train) 2.461sec(infer)
# Epoch 29 tst: l 0.364 a 0.899 clct[50, 50, 50, 50] 0.319sec
# Epoch 30 tr: l 0.367 a 0.893 clct[300, 300, 300, 300] lr 0.100000 27.215sec(train) 1.908sec(infer)
# Epoch 30 tst: l 0.364 a 0.897 clct[50, 50, 50, 50] 0.336sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 31 tr: l 0.357 a 0.895 clct[300, 300, 300, 300] lr 0.100000 27.045sec(train) 1.900sec(infer)
# Epoch 31 tst: l 0.353 a 0.901 clct[50, 50, 50, 50] 0.327sec
# Epoch 32 tr: l 0.355 a 0.896 clct[300, 300, 300, 300] lr 0.100000 27.932sec(train) 1.889sec(infer)
# Epoch 32 tst: l 0.351 a 0.901 clct[50, 50, 50, 50] 0.333sec
# Epoch 33 tr: l 0.353 a 0.896 clct[300, 300, 300, 300] lr 0.100000 27.219sec(train) 1.901sec(infer)
# Epoch 33 tst: l 0.349 a 0.902 clct[50, 50, 50, 50] 0.317sec
# Epoch 34 tr: l 0.349 a 0.898 clct[300, 300, 300, 300] lr 0.100000 27.022sec(train) 2.320sec(infer)
# Epoch 34 tst: l 0.345 a 0.903 clct[50, 50, 50, 50] 0.474sec
# Epoch 35 tr: l 0.344 a 0.899 clct[300, 300, 300, 300] lr 0.100000 27.348sec(train) 1.922sec(infer)
# Epoch 35 tst: l 0.342 a 0.904 clct[50, 50, 50, 50] 0.342sec
# Epoch 36 tr: l 0.341 a 0.899 clct[300, 300, 300, 300] lr 0.100000 27.006sec(train) 1.902sec(infer)
# Epoch 36 tst: l 0.340 a 0.904 clct[50, 50, 50, 50] 0.320sec
# Epoch 37 tr: l 0.339 a 0.900 clct[300, 300, 300, 300] lr 0.100000 27.792sec(train) 2.444sec(infer)
# Epoch 37 tst: l 0.336 a 0.906 clct[50, 50, 50, 50] 0.335sec
# Epoch 38 tr: l 0.336 a 0.901 clct[300, 300, 300, 300] lr 0.100000 27.178sec(train) 1.900sec(infer)
# Epoch 38 tst: l 0.335 a 0.906 clct[50, 50, 50, 50] 0.328sec
# Epoch 39 tr: l 0.335 a 0.901 clct[300, 300, 300, 300] lr 0.100000 26.930sec(train) 1.930sec(infer)
# Epoch 39 tst: l 0.332 a 0.907 clct[50, 50, 50, 50] 0.391sec
# Epoch 40 tr: l 0.335 a 0.901 clct[300, 300, 300, 300] lr 0.100000 27.734sec(train) 1.910sec(infer)
# Epoch 40 tst: l 0.334 a 0.906 clct[50, 50, 50, 50] 0.330sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 41 tr: l 0.339 a 0.899 clct[300, 300, 300, 300] lr 0.100000 27.178sec(train) 1.967sec(infer)
# Epoch 41 tst: l 0.339 a 0.903 clct[50, 50, 50, 50] 0.338sec
# Epoch 42 tr: l 0.329 a 0.903 clct[300, 300, 300, 300] lr 0.100000 26.992sec(train) 2.463sec(infer)
# Epoch 42 tst: l 0.327 a 0.907 clct[50, 50, 50, 50] 0.492sec
# Epoch 43 tr: l 0.332 a 0.901 clct[300, 300, 300, 300] lr 0.100000 26.932sec(train) 1.931sec(infer)
# Epoch 43 tst: l 0.331 a 0.905 clct[50, 50, 50, 50] 0.325sec
# Epoch 44 tr: l 0.330 a 0.902 clct[300, 300, 300, 300] lr 0.100000 26.904sec(train) 1.910sec(infer)
# Epoch 44 tst: l 0.329 a 0.907 clct[50, 50, 50, 50] 0.314sec
# Epoch 45 tr: l 0.324 a 0.904 clct[300, 300, 300, 300] lr 0.100000 27.257sec(train) 2.476sec(infer)
# Epoch 45 tst: l 0.323 a 0.909 clct[50, 50, 50, 50] 0.353sec
# Epoch 46 tr: l 0.325 a 0.903 clct[300, 300, 300, 300] lr 0.100000 27.137sec(train) 1.910sec(infer)
# Epoch 46 tst: l 0.326 a 0.909 clct[50, 50, 50, 50] 0.343sec
# Epoch 47 tr: l 0.323 a 0.904 clct[300, 300, 300, 300] lr 0.100000 26.853sec(train) 1.924sec(infer)
# Epoch 47 tst: l 0.324 a 0.909 clct[50, 50, 50, 50] 0.338sec
# Epoch 48 tr: l 0.332 a 0.900 clct[300, 300, 300, 300] lr 0.100000 28.114sec(train) 1.923sec(infer)
# Epoch 48 tst: l 0.334 a 0.905 clct[50, 50, 50, 50] 0.316sec
# Epoch 49 tr: l 0.321 a 0.905 clct[300, 300, 300, 300] lr 0.100000 26.989sec(train) 1.922sec(infer)
# Epoch 49 tst: l 0.321 a 0.910 clct[50, 50, 50, 50] 0.323sec
# Epoch 50 tr: l 0.326 a 0.901 clct[300, 300, 300, 300] lr 0.100000 27.182sec(train) 2.102sec(infer)
# Epoch 50 tst: l 0.328 a 0.906 clct[50, 50, 50, 50] 0.419sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 51 tr: l 0.315 a 0.906 clct[300, 300, 300, 300] lr 0.100000 27.502sec(train) 1.941sec(infer)
# Epoch 51 tst: l 0.315 a 0.910 clct[50, 50, 50, 50] 0.317sec
# Epoch 52 tr: l 0.316 a 0.905 clct[300, 300, 300, 300] lr 0.100000 26.804sec(train) 1.943sec(infer)
# Epoch 52 tst: l 0.316 a 0.909 clct[50, 50, 50, 50] 0.316sec
# Epoch 53 tr: l 0.311 a 0.907 clct[300, 300, 300, 300] lr 0.100000 26.991sec(train) 2.635sec(infer)
# Epoch 53 tst: l 0.311 a 0.912 clct[50, 50, 50, 50] 0.329sec
# Epoch 54 tr: l 0.311 a 0.907 clct[300, 300, 300, 300] lr 0.100000 26.964sec(train) 1.908sec(infer)
# Epoch 54 tst: l 0.313 a 0.911 clct[50, 50, 50, 50] 0.330sec
# Epoch 55 tr: l 0.309 a 0.907 clct[300, 300, 300, 300] lr 0.100000 27.025sec(train) 1.921sec(infer)
# Epoch 55 tst: l 0.309 a 0.912 clct[50, 50, 50, 50] 0.324sec
# Epoch 56 tr: l 0.307 a 0.908 clct[300, 300, 300, 300] lr 0.100000 27.441sec(train) 2.215sec(infer)
# Epoch 56 tst: l 0.308 a 0.912 clct[50, 50, 50, 50] 0.324sec
# Epoch 57 tr: l 0.307 a 0.908 clct[300, 300, 300, 300] lr 0.100000 27.014sec(train) 1.912sec(infer)
# Epoch 57 tst: l 0.307 a 0.913 clct[50, 50, 50, 50] 0.328sec
# Epoch 58 tr: l 0.311 a 0.907 clct[300, 300, 300, 300] lr 0.100000 26.949sec(train) 2.107sec(infer)
# Epoch 58 tst: l 0.314 a 0.911 clct[50, 50, 50, 50] 0.397sec
# Epoch 59 tr: l 0.302 a 0.910 clct[300, 300, 300, 300] lr 0.100000 27.819sec(train) 1.913sec(infer)
# Epoch 59 tst: l 0.305 a 0.914 clct[50, 50, 50, 50] 0.322sec
# Epoch 60 tr: l 0.301 a 0.910 clct[300, 300, 300, 300] lr 0.100000 27.210sec(train) 1.901sec(infer)
# Epoch 60 tst: l 0.306 a 0.913 clct[50, 50, 50, 50] 0.327sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 61 tr: l 0.306 a 0.909 clct[300, 300, 300, 300] lr 0.100000 26.780sec(train) 2.308sec(infer)
# Epoch 61 tst: l 0.313 a 0.913 clct[50, 50, 50, 50] 0.502sec
# Epoch 62 tr: l 0.301 a 0.911 clct[300, 300, 300, 300] lr 0.100000 27.428sec(train) 1.926sec(infer)
# Epoch 62 tst: l 0.305 a 0.915 clct[50, 50, 50, 50] 0.323sec
# Epoch 63 tr: l 0.298 a 0.911 clct[300, 300, 300, 300] lr 0.100000 26.889sec(train) 1.908sec(infer)
# Epoch 63 tst: l 0.299 a 0.915 clct[50, 50, 50, 50] 0.327sec
# Epoch 64 tr: l 0.297 a 0.911 clct[300, 300, 300, 300] lr 0.100000 27.114sec(train) 2.595sec(infer)
# Epoch 64 tst: l 0.299 a 0.915 clct[50, 50, 50, 50] 0.348sec
# Epoch 65 tr: l 0.295 a 0.913 clct[300, 300, 300, 300] lr 0.100000 26.790sec(train) 1.902sec(infer)
# Epoch 65 tst: l 0.297 a 0.916 clct[50, 50, 50, 50] 0.335sec
# Epoch 66 tr: l 0.294 a 0.912 clct[300, 300, 300, 300] lr 0.100000 27.246sec(train) 1.903sec(infer)
# Epoch 66 tst: l 0.296 a 0.916 clct[50, 50, 50, 50] 0.316sec
# Epoch 67 tr: l 0.294 a 0.913 clct[300, 300, 300, 300] lr 0.100000 27.792sec(train) 1.939sec(infer)
# Epoch 67 tst: l 0.298 a 0.916 clct[50, 50, 50, 50] 0.339sec
# Epoch 68 tr: l 0.291 a 0.913 clct[300, 300, 300, 300] lr 0.100000 26.981sec(train) 1.890sec(infer)
# Epoch 68 tst: l 0.294 a 0.917 clct[50, 50, 50, 50] 0.323sec
# Epoch 69 tr: l 0.290 a 0.913 clct[300, 300, 300, 300] lr 0.100000 27.106sec(train) 2.026sec(infer)
# Epoch 69 tst: l 0.294 a 0.916 clct[50, 50, 50, 50] 0.433sec
# Epoch 70 tr: l 0.290 a 0.914 clct[300, 300, 300, 300] lr 0.100000 27.597sec(train) 1.893sec(infer)
# Epoch 70 tst: l 0.294 a 0.918 clct[50, 50, 50, 50] 0.334sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 71 tr: l 0.287 a 0.914 clct[300, 300, 300, 300] lr 0.100000 26.767sec(train) 1.911sec(infer)
# Epoch 71 tst: l 0.290 a 0.918 clct[50, 50, 50, 50] 0.317sec
# Epoch 72 tr: l 0.286 a 0.915 clct[300, 300, 300, 300] lr 0.100000 27.105sec(train) 2.631sec(infer)
# Epoch 72 tst: l 0.289 a 0.918 clct[50, 50, 50, 50] 0.325sec
# Epoch 73 tr: l 0.285 a 0.915 clct[300, 300, 300, 300] lr 0.100000 26.912sec(train) 1.920sec(infer)
# Epoch 73 tst: l 0.291 a 0.918 clct[50, 50, 50, 50] 0.343sec
# Epoch 74 tr: l 0.283 a 0.916 clct[300, 300, 300, 300] lr 0.100000 26.919sec(train) 1.905sec(infer)
# Epoch 74 tst: l 0.286 a 0.919 clct[50, 50, 50, 50] 0.318sec
# Epoch 75 tr: l 0.284 a 0.915 clct[300, 300, 300, 300] lr 0.100000 27.408sec(train) 2.342sec(infer)
# Epoch 75 tst: l 0.288 a 0.918 clct[50, 50, 50, 50] 0.326sec
# Epoch 76 tr: l 0.281 a 0.917 clct[300, 300, 300, 300] lr 0.100000 26.951sec(train) 1.927sec(infer)
# Epoch 76 tst: l 0.285 a 0.920 clct[50, 50, 50, 50] 0.322sec
# Epoch 77 tr: l 0.279 a 0.918 clct[300, 300, 300, 300] lr 0.100000 26.962sec(train) 1.881sec(infer)
# Epoch 77 tst: l 0.282 a 0.922 clct[50, 50, 50, 50] 0.344sec
# Epoch 78 tr: l 0.281 a 0.917 clct[300, 300, 300, 300] lr 0.100000 27.605sec(train) 1.991sec(infer)
# Epoch 78 tst: l 0.284 a 0.920 clct[50, 50, 50, 50] 0.332sec
# Epoch 79 tr: l 0.279 a 0.917 clct[300, 300, 300, 300] lr 0.100000 26.917sec(train) 1.946sec(infer)
# Epoch 79 tst: l 0.283 a 0.920 clct[50, 50, 50, 50] 0.319sec
# Epoch 80 tr: l 0.280 a 0.916 clct[300, 300, 300, 300] lr 0.100000 27.061sec(train) 1.916sec(infer)
# Epoch 80 tst: l 0.285 a 0.920 clct[50, 50, 50, 50] 0.451sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 81 tr: l 0.276 a 0.918 clct[300, 300, 300, 300] lr 0.100000 27.778sec(train) 1.912sec(infer)
# Epoch 81 tst: l 0.282 a 0.922 clct[50, 50, 50, 50] 0.319sec
# Epoch 82 tr: l 0.315 a 0.903 clct[300, 300, 300, 300] lr 0.100000 27.130sec(train) 1.888sec(infer)
# Epoch 82 tst: l 0.328 a 0.905 clct[50, 50, 50, 50] 0.332sec
# Epoch 83 tr: l 0.273 a 0.919 clct[300, 300, 300, 300] lr 0.100000 26.858sec(train) 2.246sec(infer)
# Epoch 83 tst: l 0.280 a 0.922 clct[50, 50, 50, 50] 0.485sec
# Epoch 84 tr: l 0.271 a 0.919 clct[300, 300, 300, 300] lr 0.100000 27.276sec(train) 1.940sec(infer)
# Epoch 84 tst: l 0.276 a 0.922 clct[50, 50, 50, 50] 0.316sec
# Epoch 85 tr: l 0.271 a 0.919 clct[300, 300, 300, 300] lr 0.100000 27.054sec(train) 1.908sec(infer)
# Epoch 85 tst: l 0.276 a 0.922 clct[50, 50, 50, 50] 0.341sec
# Epoch 86 tr: l 0.271 a 0.918 clct[300, 300, 300, 300] lr 0.100000 27.535sec(train) 2.179sec(infer)
# Epoch 86 tst: l 0.277 a 0.922 clct[50, 50, 50, 50] 0.329sec
# Epoch 87 tr: l 0.272 a 0.919 clct[300, 300, 300, 300] lr 0.100000 26.865sec(train) 1.905sec(infer)
# Epoch 87 tst: l 0.278 a 0.921 clct[50, 50, 50, 50] 0.327sec
# Epoch 88 tr: l 0.272 a 0.918 clct[300, 300, 300, 300] lr 0.100000 26.893sec(train) 1.929sec(infer)
# Epoch 88 tst: l 0.277 a 0.922 clct[50, 50, 50, 50] 0.326sec
# Epoch 89 tr: l 0.268 a 0.920 clct[300, 300, 300, 300] lr 0.100000 28.063sec(train) 1.932sec(infer)
# Epoch 89 tst: l 0.275 a 0.922 clct[50, 50, 50, 50] 0.322sec
# Epoch 90 tr: l 0.267 a 0.921 clct[300, 300, 300, 300] lr 0.100000 27.574sec(train) 1.920sec(infer)
# Epoch 90 tst: l 0.273 a 0.923 clct[50, 50, 50, 50] 0.316sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 91 tr: l 0.267 a 0.920 clct[300, 300, 300, 300] lr 0.100000 26.995sec(train) 2.317sec(infer)
# Epoch 91 tst: l 0.274 a 0.922 clct[50, 50, 50, 50] 0.501sec
# Epoch 92 tr: l 0.264 a 0.921 clct[300, 300, 300, 300] lr 0.100000 27.316sec(train) 1.909sec(infer)
# Epoch 92 tst: l 0.274 a 0.923 clct[50, 50, 50, 50] 0.335sec
# Epoch 93 tr: l 0.263 a 0.922 clct[300, 300, 300, 300] lr 0.100000 27.207sec(train) 1.903sec(infer)
# Epoch 93 tst: l 0.271 a 0.924 clct[50, 50, 50, 50] 0.320sec
# Epoch 94 tr: l 0.266 a 0.920 clct[300, 300, 300, 300] lr 0.100000 27.169sec(train) 2.475sec(infer)
# Epoch 94 tst: l 0.275 a 0.923 clct[50, 50, 50, 50] 0.330sec
# Epoch 95 tr: l 0.273 a 0.917 clct[300, 300, 300, 300] lr 0.100000 27.139sec(train) 1.897sec(infer)
# Epoch 95 tst: l 0.282 a 0.920 clct[50, 50, 50, 50] 0.322sec
# Epoch 96 tr: l 0.260 a 0.923 clct[300, 300, 300, 300] lr 0.100000 26.890sec(train) 1.933sec(infer)
# Epoch 96 tst: l 0.268 a 0.925 clct[50, 50, 50, 50] 0.318sec
# Epoch 97 tr: l 0.264 a 0.921 clct[300, 300, 300, 300] lr 0.100000 27.926sec(train) 1.998sec(infer)
# Epoch 97 tst: l 0.272 a 0.925 clct[50, 50, 50, 50] 0.343sec
# Epoch 98 tr: l 0.267 a 0.920 clct[300, 300, 300, 300] lr 0.100000 26.883sec(train) 1.906sec(infer)
# Epoch 98 tst: l 0.276 a 0.923 clct[50, 50, 50, 50] 0.326sec
# Epoch 99 tr: l 0.264 a 0.921 clct[300, 300, 300, 300] lr 0.100000 27.153sec(train) 2.015sec(infer)
# Epoch 99 tst: l 0.274 a 0.922 clct[50, 50, 50, 50] 0.452sec
# Epoch 100 tr: l 0.264 a 0.922 clct[300, 300, 300, 300] lr 0.100000 27.709sec(train) 1.932sec(infer)
# Epoch 100 tst: l 0.273 a 0.924 clct[50, 50, 50, 50] 0.316sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 101 tr: l 0.260 a 0.922 clct[300, 300, 300, 300] lr 0.100000 26.982sec(train) 1.907sec(infer)
# Epoch 101 tst: l 0.270 a 0.924 clct[50, 50, 50, 50] 0.334sec
# Epoch 102 tr: l 0.254 a 0.924 clct[300, 300, 300, 300] lr 0.100000 26.964sec(train) 2.522sec(infer)
# Epoch 102 tst: l 0.263 a 0.927 clct[50, 50, 50, 50] 0.494sec
# Epoch 103 tr: l 0.264 a 0.921 clct[300, 300, 300, 300] lr 0.100000 27.303sec(train) 1.921sec(infer)
# Epoch 103 tst: l 0.272 a 0.923 clct[50, 50, 50, 50] 0.316sec
# Epoch 104 tr: l 0.256 a 0.924 clct[300, 300, 300, 300] lr 0.100000 26.860sec(train) 1.916sec(infer)
# Epoch 104 tst: l 0.264 a 0.926 clct[50, 50, 50, 50] 0.332sec
# Epoch 105 tr: l 0.256 a 0.923 clct[300, 300, 300, 300] lr 0.100000 27.286sec(train) 2.486sec(infer)
# Epoch 105 tst: l 0.266 a 0.926 clct[50, 50, 50, 50] 0.325sec
# Epoch 106 tr: l 0.254 a 0.923 clct[300, 300, 300, 300] lr 0.100000 26.942sec(train) 1.957sec(infer)
# Epoch 106 tst: l 0.264 a 0.926 clct[50, 50, 50, 50] 0.361sec
# Epoch 107 tr: l 0.251 a 0.925 clct[300, 300, 300, 300] lr 0.100000 27.131sec(train) 1.937sec(infer)
# Epoch 107 tst: l 0.261 a 0.927 clct[50, 50, 50, 50] 0.322sec
# Epoch 108 tr: l 0.252 a 0.925 clct[300, 300, 300, 300] lr 0.100000 27.533sec(train) 2.219sec(infer)
# Epoch 108 tst: l 0.261 a 0.926 clct[50, 50, 50, 50] 0.310sec
# Epoch 109 tr: l 0.252 a 0.924 clct[300, 300, 300, 300] lr 0.100000 26.897sec(train) 1.901sec(infer)
# Epoch 109 tst: l 0.264 a 0.926 clct[50, 50, 50, 50] 0.363sec
# Epoch 110 tr: l 0.251 a 0.924 clct[300, 300, 300, 300] lr 0.100000 27.023sec(train) 2.066sec(infer)
# Epoch 110 tst: l 0.262 a 0.926 clct[50, 50, 50, 50] 0.432sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 111 tr: l 0.247 a 0.926 clct[300, 300, 300, 300] lr 0.100000 27.809sec(train) 1.927sec(infer)
# Epoch 111 tst: l 0.257 a 0.928 clct[50, 50, 50, 50] 0.324sec
# Epoch 112 tr: l 0.248 a 0.926 clct[300, 300, 300, 300] lr 0.100000 27.153sec(train) 1.917sec(infer)
# Epoch 112 tst: l 0.257 a 0.928 clct[50, 50, 50, 50] 0.345sec
# Epoch 113 tr: l 0.248 a 0.926 clct[300, 300, 300, 300] lr 0.100000 26.989sec(train) 2.574sec(infer)
# Epoch 113 tst: l 0.258 a 0.927 clct[50, 50, 50, 50] 0.384sec
# Epoch 114 tr: l 0.251 a 0.924 clct[300, 300, 300, 300] lr 0.100000 27.141sec(train) 1.922sec(infer)
# Epoch 114 tst: l 0.260 a 0.927 clct[50, 50, 50, 50] 0.312sec
# Epoch 115 tr: l 0.246 a 0.927 clct[300, 300, 300, 300] lr 0.100000 26.937sec(train) 1.906sec(infer)
# Epoch 115 tst: l 0.257 a 0.928 clct[50, 50, 50, 50] 0.335sec
# Epoch 116 tr: l 0.246 a 0.926 clct[300, 300, 300, 300] lr 0.100000 27.301sec(train) 2.498sec(infer)
# Epoch 116 tst: l 0.254 a 0.928 clct[50, 50, 50, 50] 0.335sec
# Epoch 117 tr: l 0.246 a 0.927 clct[300, 300, 300, 300] lr 0.100000 27.178sec(train) 1.902sec(infer)
# Epoch 117 tst: l 0.257 a 0.927 clct[50, 50, 50, 50] 0.323sec
# Epoch 118 tr: l 0.244 a 0.927 clct[300, 300, 300, 300] lr 0.100000 27.077sec(train) 1.888sec(infer)
# Epoch 118 tst: l 0.255 a 0.928 clct[50, 50, 50, 50] 0.367sec
# Epoch 119 tr: l 0.242 a 0.927 clct[300, 300, 300, 300] lr 0.100000 27.533sec(train) 2.219sec(infer)
# Epoch 119 tst: l 0.253 a 0.928 clct[50, 50, 50, 50] 0.328sec
# Epoch 120 tr: l 0.241 a 0.928 clct[300, 300, 300, 300] lr 0.100000 26.869sec(train) 1.915sec(infer)
# Epoch 120 tst: l 0.252 a 0.928 clct[50, 50, 50, 50] 0.334sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 121 tr: l 0.240 a 0.928 clct[300, 300, 300, 300] lr 0.100000 27.203sec(train) 1.985sec(infer)
# Epoch 121 tst: l 0.251 a 0.929 clct[50, 50, 50, 50] 0.448sec
# Epoch 122 tr: l 0.243 a 0.927 clct[300, 300, 300, 300] lr 0.100000 27.882sec(train) 1.897sec(infer)
# Epoch 122 tst: l 0.253 a 0.928 clct[50, 50, 50, 50] 0.331sec
# Epoch 123 tr: l 0.240 a 0.928 clct[300, 300, 300, 300] lr 0.100000 26.748sec(train) 1.893sec(infer)
# Epoch 123 tst: l 0.250 a 0.929 clct[50, 50, 50, 50] 0.342sec
# Epoch 124 tr: l 0.245 a 0.926 clct[300, 300, 300, 300] lr 0.100000 26.873sec(train) 2.286sec(infer)
# Epoch 124 tst: l 0.257 a 0.926 clct[50, 50, 50, 50] 0.492sec
# Epoch 125 tr: l 0.240 a 0.927 clct[300, 300, 300, 300] lr 0.100000 27.570sec(train) 1.918sec(infer)
# Epoch 125 tst: l 0.251 a 0.929 clct[50, 50, 50, 50] 0.324sec
# Epoch 126 tr: l 0.238 a 0.929 clct[300, 300, 300, 300] lr 0.100000 26.992sec(train) 1.891sec(infer)
# Epoch 126 tst: l 0.246 a 0.930 clct[50, 50, 50, 50] 0.326sec
# Epoch 127 tr: l 0.236 a 0.929 clct[300, 300, 300, 300] lr 0.100000 27.584sec(train) 2.443sec(infer)
# Epoch 127 tst: l 0.246 a 0.930 clct[50, 50, 50, 50] 0.319sec
# Epoch 128 tr: l 0.241 a 0.927 clct[300, 300, 300, 300] lr 0.100000 26.961sec(train) 1.905sec(infer)
# Epoch 128 tst: l 0.250 a 0.927 clct[50, 50, 50, 50] 0.329sec
# Epoch 129 tr: l 0.236 a 0.930 clct[300, 300, 300, 300] lr 0.100000 27.161sec(train) 1.900sec(infer)
# Epoch 129 tst: l 0.247 a 0.931 clct[50, 50, 50, 50] 0.315sec
# Epoch 130 tr: l 0.233 a 0.931 clct[300, 300, 300, 300] lr 0.100000 27.594sec(train) 2.321sec(infer)
# Epoch 130 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] 0.327sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 131 tr: l 0.234 a 0.930 clct[300, 300, 300, 300] lr 0.100000 26.722sec(train) 1.905sec(infer)
# Epoch 131 tst: l 0.246 a 0.930 clct[50, 50, 50, 50] 0.322sec
# Epoch 132 tr: l 0.232 a 0.931 clct[300, 300, 300, 300] lr 0.100000 27.314sec(train) 2.147sec(infer)
# Epoch 132 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] 0.431sec
# Epoch 133 tr: l 0.231 a 0.932 clct[300, 300, 300, 300] lr 0.100000 27.479sec(train) 1.906sec(infer)
# Epoch 133 tst: l 0.241 a 0.932 clct[50, 50, 50, 50] 0.328sec
# Epoch 134 tr: l 0.232 a 0.931 clct[300, 300, 300, 300] lr 0.100000 26.829sec(train) 1.892sec(infer)
# Epoch 134 tst: l 0.242 a 0.932 clct[50, 50, 50, 50] 0.317sec
# Epoch 135 tr: l 0.229 a 0.932 clct[300, 300, 300, 300] lr 0.100000 26.905sec(train) 2.578sec(infer)
# Epoch 135 tst: l 0.240 a 0.933 clct[50, 50, 50, 50] 0.424sec
# Epoch 136 tr: l 0.231 a 0.931 clct[300, 300, 300, 300] lr 0.100000 27.170sec(train) 1.926sec(infer)
# Epoch 136 tst: l 0.244 a 0.931 clct[50, 50, 50, 50] 0.331sec
# Epoch 137 tr: l 0.229 a 0.931 clct[300, 300, 300, 300] lr 0.100000 27.002sec(train) 1.910sec(infer)
# Epoch 137 tst: l 0.240 a 0.931 clct[50, 50, 50, 50] 0.320sec
# Epoch 138 tr: l 0.229 a 0.931 clct[300, 300, 300, 300] lr 0.100000 27.034sec(train) 2.548sec(infer)
# Epoch 138 tst: l 0.241 a 0.931 clct[50, 50, 50, 50] 0.326sec
# Epoch 139 tr: l 0.226 a 0.933 clct[300, 300, 300, 300] lr 0.100000 27.146sec(train) 1.906sec(infer)
# Epoch 139 tst: l 0.237 a 0.933 clct[50, 50, 50, 50] 0.328sec
# Epoch 140 tr: l 0.228 a 0.932 clct[300, 300, 300, 300] lr 0.100000 26.839sec(train) 1.928sec(infer)
# Epoch 140 tst: l 0.239 a 0.932 clct[50, 50, 50, 50] 0.319sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 141 tr: l 0.226 a 0.932 clct[300, 300, 300, 300] lr 0.100000 27.556sec(train) 2.288sec(infer)
# Epoch 141 tst: l 0.237 a 0.933 clct[50, 50, 50, 50] 0.334sec
# Epoch 142 tr: l 0.227 a 0.931 clct[300, 300, 300, 300] lr 0.100000 26.868sec(train) 1.905sec(infer)
# Epoch 142 tst: l 0.237 a 0.932 clct[50, 50, 50, 50] 0.329sec
# Epoch 143 tr: l 0.224 a 0.933 clct[300, 300, 300, 300] lr 0.100000 27.118sec(train) 1.887sec(infer)
# Epoch 143 tst: l 0.235 a 0.933 clct[50, 50, 50, 50] 0.322sec
# Epoch 144 tr: l 0.230 a 0.930 clct[300, 300, 300, 300] lr 0.100000 27.901sec(train) 2.021sec(infer)
# Epoch 144 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] 0.331sec
# Epoch 145 tr: l 0.223 a 0.933 clct[300, 300, 300, 300] lr 0.100000 26.954sec(train) 1.904sec(infer)
# Epoch 145 tst: l 0.235 a 0.933 clct[50, 50, 50, 50] 0.325sec
# Epoch 146 tr: l 0.375 a 0.894 clct[300, 300, 300, 300] lr 0.100000 26.851sec(train) 1.911sec(infer)
# Epoch 146 tst: l 0.403 a 0.893 clct[50, 50, 50, 50] 0.323sec
# Epoch 147 tr: l 0.230 a 0.931 clct[300, 300, 300, 300] lr 0.100000 28.090sec(train) 1.899sec(infer)
# Epoch 147 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] 0.316sec
# Epoch 148 tr: l 0.222 a 0.933 clct[300, 300, 300, 300] lr 0.100000 26.915sec(train) 1.892sec(infer)
# Epoch 148 tst: l 0.237 a 0.933 clct[50, 50, 50, 50] 0.325sec
# Epoch 149 tr: l 0.221 a 0.933 clct[300, 300, 300, 300] lr 0.100000 27.090sec(train) 2.102sec(infer)
# Epoch 149 tst: l 0.234 a 0.933 clct[50, 50, 50, 50] 0.419sec
# Epoch 150 tr: l 0.221 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.650sec(train) 1.895sec(infer)
# Epoch 150 tst: l 0.234 a 0.933 clct[50, 50, 50, 50] 0.324sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 151 tr: l 0.220 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.052sec(train) 1.905sec(infer)
# Epoch 151 tst: l 0.232 a 0.933 clct[50, 50, 50, 50] 0.320sec
# Epoch 152 tr: l 0.219 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.057sec(train) 2.682sec(infer)
# Epoch 152 tst: l 0.233 a 0.934 clct[50, 50, 50, 50] 0.330sec
# Epoch 153 tr: l 0.219 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.210sec(train) 1.904sec(infer)
# Epoch 153 tst: l 0.230 a 0.935 clct[50, 50, 50, 50] 0.335sec
# Epoch 154 tr: l 0.220 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.018sec(train) 1.903sec(infer)
# Epoch 154 tst: l 0.232 a 0.935 clct[50, 50, 50, 50] 0.323sec
# Epoch 155 tr: l 0.222 a 0.934 clct[300, 300, 300, 300] lr 0.100000 27.765sec(train) 2.121sec(infer)
# Epoch 155 tst: l 0.235 a 0.933 clct[50, 50, 50, 50] 0.318sec
# Epoch 156 tr: l 0.215 a 0.935 clct[300, 300, 300, 300] lr 0.100000 27.055sec(train) 1.938sec(infer)
# Epoch 156 tst: l 0.227 a 0.935 clct[50, 50, 50, 50] 0.331sec
# Epoch 157 tr: l 0.216 a 0.935 clct[300, 300, 300, 300] lr 0.100000 27.367sec(train) 2.053sec(infer)
# Epoch 157 tst: l 0.230 a 0.934 clct[50, 50, 50, 50] 0.475sec
# Epoch 158 tr: l 0.215 a 0.936 clct[300, 300, 300, 300] lr 0.100000 28.347sec(train) 1.941sec(infer)
# Epoch 158 tst: l 0.228 a 0.935 clct[50, 50, 50, 50] 0.338sec
# Epoch 159 tr: l 0.213 a 0.936 clct[300, 300, 300, 300] lr 0.100000 27.295sec(train) 1.898sec(infer)
# Epoch 159 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] 0.325sec
# Epoch 160 tr: l 0.215 a 0.935 clct[300, 300, 300, 300] lr 0.100000 26.912sec(train) 2.505sec(infer)
# Epoch 160 tst: l 0.229 a 0.934 clct[50, 50, 50, 50] 0.485sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 161 tr: l 0.213 a 0.936 clct[300, 300, 300, 300] lr 0.100000 26.968sec(train) 1.908sec(infer)
# Epoch 161 tst: l 0.227 a 0.935 clct[50, 50, 50, 50] 0.322sec
# Epoch 162 tr: l 0.212 a 0.937 clct[300, 300, 300, 300] lr 0.100000 27.048sec(train) 1.899sec(infer)
# Epoch 162 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] 0.346sec
# Epoch 163 tr: l 0.213 a 0.936 clct[300, 300, 300, 300] lr 0.100000 27.498sec(train) 2.379sec(infer)
# Epoch 163 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] 0.316sec
# Epoch 164 tr: l 0.210 a 0.937 clct[300, 300, 300, 300] lr 0.100000 26.934sec(train) 1.887sec(infer)
# Epoch 164 tst: l 0.223 a 0.936 clct[50, 50, 50, 50] 0.319sec
# Epoch 165 tr: l 0.213 a 0.936 clct[300, 300, 300, 300] lr 0.100000 26.973sec(train) 1.893sec(infer)
# Epoch 165 tst: l 0.227 a 0.935 clct[50, 50, 50, 50] 0.330sec
# Epoch 166 tr: l 0.209 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.749sec(train) 2.136sec(infer)
# Epoch 166 tst: l 0.223 a 0.936 clct[50, 50, 50, 50] 0.327sec
# Epoch 167 tr: l 0.209 a 0.937 clct[300, 300, 300, 300] lr 0.100000 27.011sec(train) 1.929sec(infer)
# Epoch 167 tst: l 0.223 a 0.936 clct[50, 50, 50, 50] 0.330sec
# Epoch 168 tr: l 0.211 a 0.936 clct[300, 300, 300, 300] lr 0.100000 27.039sec(train) 1.920sec(infer)
# Epoch 168 tst: l 0.225 a 0.936 clct[50, 50, 50, 50] 0.431sec
# Epoch 169 tr: l 0.210 a 0.936 clct[300, 300, 300, 300] lr 0.100000 27.742sec(train) 1.932sec(infer)
# Epoch 169 tst: l 0.226 a 0.935 clct[50, 50, 50, 50] 0.320sec
# Epoch 170 tr: l 0.210 a 0.937 clct[300, 300, 300, 300] lr 0.100000 27.107sec(train) 1.909sec(infer)
# Epoch 170 tst: l 0.223 a 0.936 clct[50, 50, 50, 50] 0.331sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 171 tr: l 0.207 a 0.938 clct[300, 300, 300, 300] lr 0.100000 26.924sec(train) 2.324sec(infer)
# Epoch 171 tst: l 0.220 a 0.937 clct[50, 50, 50, 50] 0.497sec
# Epoch 172 tr: l 0.207 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.347sec(train) 1.898sec(infer)
# Epoch 172 tst: l 0.219 a 0.937 clct[50, 50, 50, 50] 0.353sec
# Epoch 173 tr: l 0.207 a 0.937 clct[300, 300, 300, 300] lr 0.100000 26.920sec(train) 1.913sec(infer)
# Epoch 173 tst: l 0.221 a 0.937 clct[50, 50, 50, 50] 0.341sec
# Epoch 174 tr: l 0.208 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.153sec(train) 2.568sec(infer)
# Epoch 174 tst: l 0.220 a 0.937 clct[50, 50, 50, 50] 0.326sec
# Epoch 175 tr: l 0.205 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.172sec(train) 1.876sec(infer)
# Epoch 175 tst: l 0.218 a 0.938 clct[50, 50, 50, 50] 0.326sec
# Epoch 176 tr: l 0.205 a 0.938 clct[300, 300, 300, 300] lr 0.100000 26.909sec(train) 1.925sec(infer)
# Epoch 176 tst: l 0.216 a 0.938 clct[50, 50, 50, 50] 0.330sec
# Epoch 177 tr: l 0.204 a 0.939 clct[300, 300, 300, 300] lr 0.100000 27.346sec(train) 2.488sec(infer)
# Epoch 177 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] 0.326sec
# Epoch 178 tr: l 0.203 a 0.939 clct[300, 300, 300, 300] lr 0.100000 26.900sec(train) 1.883sec(infer)
# Epoch 178 tst: l 0.216 a 0.938 clct[50, 50, 50, 50] 0.340sec
# Epoch 179 tr: l 0.203 a 0.939 clct[300, 300, 300, 300] lr 0.100000 27.027sec(train) 1.910sec(infer)
# Epoch 179 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] 0.324sec
# Epoch 180 tr: l 0.203 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.311sec(train) 2.203sec(infer)
# Epoch 180 tst: l 0.218 a 0.937 clct[50, 50, 50, 50] 0.345sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 181 tr: l 0.201 a 0.939 clct[300, 300, 300, 300] lr 0.100000 27.061sec(train) 1.890sec(infer)
# Epoch 181 tst: l 0.216 a 0.938 clct[50, 50, 50, 50] 0.351sec
# Epoch 182 tr: l 0.205 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.049sec(train) 1.894sec(infer)
# Epoch 182 tst: l 0.219 a 0.937 clct[50, 50, 50, 50] 0.479sec
# Epoch 183 tr: l 0.200 a 0.940 clct[300, 300, 300, 300] lr 0.100000 27.586sec(train) 1.900sec(infer)
# Epoch 183 tst: l 0.213 a 0.939 clct[50, 50, 50, 50] 0.346sec
# Epoch 184 tr: l 0.204 a 0.938 clct[300, 300, 300, 300] lr 0.100000 27.290sec(train) 1.893sec(infer)
# Epoch 184 tst: l 0.221 a 0.936 clct[50, 50, 50, 50] 0.317sec
# Epoch 185 tr: l 0.200 a 0.940 clct[300, 300, 300, 300] lr 0.100000 26.905sec(train) 2.178sec(infer)
# Epoch 185 tst: l 0.215 a 0.939 clct[50, 50, 50, 50] 0.462sec
# Epoch 186 tr: l 0.199 a 0.940 clct[300, 300, 300, 300] lr 0.100000 27.494sec(train) 1.881sec(infer)
# Epoch 186 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] 0.334sec
# Epoch 187 tr: l 0.197 a 0.941 clct[300, 300, 300, 300] lr 0.100000 26.994sec(train) 1.900sec(infer)
# Epoch 187 tst: l 0.211 a 0.939 clct[50, 50, 50, 50] 0.339sec
# Epoch 188 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.052sec(train) 2.746sec(infer)
# Epoch 188 tst: l 0.211 a 0.940 clct[50, 50, 50, 50] 0.323sec
# Epoch 189 tr: l 0.199 a 0.940 clct[300, 300, 300, 300] lr 0.100000 26.996sec(train) 1.879sec(infer)
# Epoch 189 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] 0.326sec
# Epoch 190 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.188sec(train) 1.918sec(infer)
# Epoch 190 tst: l 0.212 a 0.940 clct[50, 50, 50, 50] 0.330sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 191 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.310sec(train) 2.399sec(infer)
# Epoch 191 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.331sec
# Epoch 192 tr: l 0.198 a 0.940 clct[300, 300, 300, 300] lr 0.100000 27.163sec(train) 1.901sec(infer)
# Epoch 192 tst: l 0.211 a 0.938 clct[50, 50, 50, 50] 0.337sec
# Epoch 193 tr: l 0.194 a 0.941 clct[300, 300, 300, 300] lr 0.100000 26.976sec(train) 1.901sec(infer)
# Epoch 193 tst: l 0.208 a 0.940 clct[50, 50, 50, 50] 0.332sec
# Epoch 194 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.692sec(train) 1.999sec(infer)
# Epoch 194 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.321sec
# Epoch 195 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 26.984sec(train) 1.916sec(infer)
# Epoch 195 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.333sec
# Epoch 196 tr: l 0.193 a 0.942 clct[300, 300, 300, 300] lr 0.100000 27.045sec(train) 2.082sec(infer)
# Epoch 196 tst: l 0.208 a 0.940 clct[50, 50, 50, 50] 0.449sec
# Epoch 197 tr: l 0.195 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.569sec(train) 1.905sec(infer)
# Epoch 197 tst: l 0.209 a 0.939 clct[50, 50, 50, 50] 0.333sec
# Epoch 198 tr: l 0.191 a 0.942 clct[300, 300, 300, 300] lr 0.100000 27.157sec(train) 1.892sec(infer)
# Epoch 198 tst: l 0.204 a 0.941 clct[50, 50, 50, 50] 0.326sec
# Epoch 199 tr: l 0.192 a 0.942 clct[300, 300, 300, 300] lr 0.100000 26.871sec(train) 2.258sec(infer)
# Epoch 199 tst: l 0.207 a 0.941 clct[50, 50, 50, 50] 0.484sec
# Epoch 200 tr: l 0.191 a 0.943 clct[300, 300, 300, 300] lr 0.100000 27.450sec(train) 2.055sec(infer)
# Epoch 200 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] 0.326sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 201 tr: l 0.192 a 0.942 clct[300, 300, 300, 300] lr 0.100000 26.723sec(train) 1.921sec(infer)
# Epoch 201 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] 0.325sec
# Epoch 202 tr: l 0.190 a 0.943 clct[300, 300, 300, 300] lr 0.100000 27.204sec(train) 2.415sec(infer)
# Epoch 202 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] 0.350sec
# Epoch 203 tr: l 0.191 a 0.942 clct[300, 300, 300, 300] lr 0.100000 26.981sec(train) 1.878sec(infer)
# Epoch 203 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] 0.328sec
# Epoch 204 tr: l 0.192 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.002sec(train) 1.876sec(infer)
# Epoch 204 tst: l 0.207 a 0.940 clct[50, 50, 50, 50] 0.317sec
# Epoch 205 tr: l 0.189 a 0.943 clct[300, 300, 300, 300] lr 0.100000 27.531sec(train) 2.320sec(infer)
# Epoch 205 tst: l 0.204 a 0.941 clct[50, 50, 50, 50] 0.329sec
# Epoch 206 tr: l 0.189 a 0.943 clct[300, 300, 300, 300] lr 0.100000 26.905sec(train) 1.889sec(infer)
# Epoch 206 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] 0.326sec
# Epoch 207 tr: l 0.190 a 0.942 clct[300, 300, 300, 300] lr 0.100000 27.041sec(train) 1.902sec(infer)
# Epoch 207 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.324sec
# Epoch 208 tr: l 0.191 a 0.941 clct[300, 300, 300, 300] lr 0.100000 27.753sec(train) 1.915sec(infer)
# Epoch 208 tst: l 0.209 a 0.940 clct[50, 50, 50, 50] 0.331sec
# Epoch 209 tr: l 0.190 a 0.942 clct[300, 300, 300, 300] lr 0.100000 27.091sec(train) 1.906sec(infer)
# Epoch 209 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] 0.318sec
# Epoch 210 tr: l 0.188 a 0.943 clct[300, 300, 300, 300] lr 0.100000 26.920sec(train) 2.018sec(infer)
# Epoch 210 tst: l 0.203 a 0.942 clct[50, 50, 50, 50] 0.433sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 211 tr: l 0.186 a 0.944 clct[300, 300, 300, 300] lr 0.100000 27.296sec(train) 1.883sec(infer)
# Epoch 211 tst: l 0.202 a 0.942 clct[50, 50, 50, 50] 0.330sec
# Epoch 212 tr: l 0.186 a 0.944 clct[300, 300, 300, 300] lr 0.100000 26.853sec(train) 1.860sec(infer)
# Epoch 212 tst: l 0.202 a 0.942 clct[50, 50, 50, 50] 0.315sec
# Epoch 213 tr: l 0.183 a 0.945 clct[300, 300, 300, 300] lr 0.100000 26.954sec(train) 2.567sec(infer)
# Epoch 213 tst: l 0.200 a 0.943 clct[50, 50, 50, 50] 0.423sec
# Epoch 214 tr: l 0.184 a 0.944 clct[300, 300, 300, 300] lr 0.100000 27.004sec(train) 1.875sec(infer)
# Epoch 214 tst: l 0.200 a 0.943 clct[50, 50, 50, 50] 0.326sec
# Epoch 215 tr: l 0.183 a 0.945 clct[300, 300, 300, 300] lr 0.100000 26.905sec(train) 1.903sec(infer)
# Epoch 215 tst: l 0.198 a 0.943 clct[50, 50, 50, 50] 0.313sec
# Epoch 216 tr: l 0.184 a 0.944 clct[300, 300, 300, 300] lr 0.100000 27.495sec(train) 2.356sec(infer)
# Epoch 216 tst: l 0.201 a 0.942 clct[50, 50, 50, 50] 0.329sec
# Epoch 217 tr: l 0.183 a 0.944 clct[300, 300, 300, 300] lr 0.100000 27.058sec(train) 1.900sec(infer)
# Epoch 217 tst: l 0.200 a 0.943 clct[50, 50, 50, 50] 0.323sec
# Epoch 218 tr: l 0.184 a 0.943 clct[300, 300, 300, 300] lr 0.100000 27.042sec(train) 1.920sec(infer)
# Epoch 218 tst: l 0.199 a 0.942 clct[50, 50, 50, 50] 0.315sec
# Epoch 219 tr: l 0.185 a 0.944 clct[300, 300, 300, 300] lr 0.100000 27.441sec(train) 2.040sec(infer)
# Epoch 219 tst: l 0.200 a 0.942 clct[50, 50, 50, 50] 0.325sec
# Epoch 220 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] lr 0.100000 26.794sec(train) 1.872sec(infer)
# Epoch 220 tst: l 0.198 a 0.943 clct[50, 50, 50, 50] 0.317sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 221 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] lr 0.100000 27.034sec(train) 2.119sec(infer)
# Epoch 221 tst: l 0.198 a 0.944 clct[50, 50, 50, 50] 0.430sec
# Epoch 222 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.487sec(train) 1.895sec(infer)
# Epoch 222 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.343sec
# Epoch 223 tr: l 0.180 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.003sec(train) 1.892sec(infer)
# Epoch 223 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.315sec
# Epoch 224 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 26.815sec(train) 2.317sec(infer)
# Epoch 224 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.490sec
# Epoch 225 tr: l 0.179 a 0.945 clct[300, 300, 300, 300] lr 0.100000 27.251sec(train) 1.921sec(infer)
# Epoch 225 tst: l 0.198 a 0.944 clct[50, 50, 50, 50] 0.328sec
# Epoch 226 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 26.986sec(train) 1.915sec(infer)
# Epoch 226 tst: l 0.195 a 0.945 clct[50, 50, 50, 50] 0.325sec
# Epoch 227 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.092sec(train) 2.501sec(infer)
# Epoch 227 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.354sec
# Epoch 228 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 26.902sec(train) 1.916sec(infer)
# Epoch 228 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.321sec
# Epoch 229 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.018sec(train) 1.879sec(infer)
# Epoch 229 tst: l 0.195 a 0.945 clct[50, 50, 50, 50] 0.342sec
# Epoch 230 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.763sec(train) 1.943sec(infer)
# Epoch 230 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.326sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 231 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.014sec(train) 1.904sec(infer)
# Epoch 231 tst: l 0.195 a 0.943 clct[50, 50, 50, 50] 0.326sec
# Epoch 232 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] lr 0.100000 26.870sec(train) 2.391sec(infer)
# Epoch 232 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.478sec
# Epoch 233 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.468sec(train) 1.883sec(infer)
# Epoch 233 tst: l 0.195 a 0.944 clct[50, 50, 50, 50] 0.329sec
# Epoch 234 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 26.893sec(train) 1.890sec(infer)
# Epoch 234 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.324sec
# Epoch 235 tr: l 0.173 a 0.948 clct[300, 300, 300, 300] lr 0.100000 27.241sec(train) 2.453sec(infer)
# Epoch 235 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.321sec
# Epoch 236 tr: l 0.175 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.957sec(train) 1.887sec(infer)
# Epoch 236 tst: l 0.193 a 0.945 clct[50, 50, 50, 50] 0.334sec
# Epoch 237 tr: l 0.176 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.294sec(train) 1.902sec(infer)
# Epoch 237 tst: l 0.194 a 0.945 clct[50, 50, 50, 50] 0.319sec
# Epoch 238 tr: l 0.176 a 0.946 clct[300, 300, 300, 300] lr 0.100000 27.588sec(train) 1.912sec(infer)
# Epoch 238 tst: l 0.193 a 0.945 clct[50, 50, 50, 50] 0.328sec
# Epoch 239 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.971sec(train) 1.899sec(infer)
# Epoch 239 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.330sec
# Epoch 240 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.938sec(train) 1.934sec(infer)
# Epoch 240 tst: l 0.189 a 0.945 clct[50, 50, 50, 50] 0.463sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 241 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 27.354sec(train) 1.875sec(infer)
# Epoch 241 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.324sec
# Epoch 242 tr: l 0.172 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.874sec(train) 1.914sec(infer)
# Epoch 242 tst: l 0.189 a 0.945 clct[50, 50, 50, 50] 0.320sec
# Epoch 243 tr: l 0.174 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.947sec(train) 2.643sec(infer)
# Epoch 243 tst: l 0.190 a 0.945 clct[50, 50, 50, 50] 0.336sec
# Epoch 244 tr: l 0.172 a 0.948 clct[300, 300, 300, 300] lr 0.100000 27.203sec(train) 1.910sec(infer)
# Epoch 244 tst: l 0.191 a 0.946 clct[50, 50, 50, 50] 0.332sec
# Epoch 245 tr: l 0.170 a 0.948 clct[300, 300, 300, 300] lr 0.100000 27.076sec(train) 1.925sec(infer)
# Epoch 245 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.328sec
# Epoch 246 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 27.078sec(train) 2.367sec(infer)
# Epoch 246 tst: l 0.193 a 0.945 clct[50, 50, 50, 50] 0.322sec
# Epoch 247 tr: l 0.169 a 0.948 clct[300, 300, 300, 300] lr 0.100000 27.353sec(train) 1.904sec(infer)
# Epoch 247 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.326sec
# Epoch 248 tr: l 0.172 a 0.948 clct[300, 300, 300, 300] lr 0.100000 26.811sec(train) 1.887sec(infer)
# Epoch 248 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.321sec
# Epoch 249 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 27.823sec(train) 1.942sec(infer)
# Epoch 249 tst: l 0.187 a 0.947 clct[50, 50, 50, 50] 0.321sec
# Epoch 250 tr: l 0.169 a 0.949 clct[300, 300, 300, 300] lr 0.100000 26.982sec(train) 1.874sec(infer)
# Epoch 250 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.339sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 251 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 26.957sec(train) 2.274sec(infer)
# Epoch 251 tst: l 0.186 a 0.946 clct[50, 50, 50, 50] 0.484sec
# Epoch 252 tr: l 0.167 a 0.949 clct[300, 300, 300, 300] lr 0.100000 27.495sec(train) 1.880sec(infer)
# Epoch 252 tst: l 0.185 a 0.947 clct[50, 50, 50, 50] 0.331sec
# Epoch 253 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 26.732sec(train) 1.897sec(infer)
# Epoch 253 tst: l 0.186 a 0.947 clct[50, 50, 50, 50] 0.329sec
# Epoch 254 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 26.879sec(train) 2.460sec(infer)
# Epoch 254 tst: l 0.187 a 0.946 clct[50, 50, 50, 50] 0.462sec
# Epoch 255 tr: l 0.166 a 0.949 clct[300, 300, 300, 300] lr 0.100000 27.008sec(train) 1.875sec(infer)
# Epoch 255 tst: l 0.185 a 0.948 clct[50, 50, 50, 50] 0.343sec
# Epoch 256 tr: l 0.167 a 0.949 clct[300, 300, 300, 300] lr 0.100000 27.020sec(train) 1.894sec(infer)
# Epoch 256 tst: l 0.187 a 0.946 clct[50, 50, 50, 50] 0.318sec
# Epoch 257 tr: l 0.171 a 0.947 clct[300, 300, 300, 300] lr 0.100000 26.705sec(train) 2.577sec(infer)
# Epoch 257 tst: l 0.189 a 0.945 clct[50, 50, 50, 50] 0.324sec
# Epoch 258 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 26.967sec(train) 1.870sec(infer)
# Epoch 258 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.324sec
# Epoch 259 tr: l 0.164 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.964sec(train) 1.889sec(infer)
# Epoch 259 tst: l 0.183 a 0.948 clct[50, 50, 50, 50] 0.331sec
# Epoch 260 tr: l 0.167 a 0.949 clct[300, 300, 300, 300] lr 0.100000 27.141sec(train) 2.347sec(infer)
# Epoch 260 tst: l 0.187 a 0.946 clct[50, 50, 50, 50] 0.337sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 261 tr: l 0.164 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.787sec(train) 1.901sec(infer)
# Epoch 261 tst: l 0.184 a 0.947 clct[50, 50, 50, 50] 0.330sec
# Epoch 262 tr: l 0.164 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.982sec(train) 2.048sec(infer)
# Epoch 262 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.430sec
# Epoch 263 tr: l 0.163 a 0.950 clct[300, 300, 300, 300] lr 0.100000 27.655sec(train) 1.902sec(infer)
# Epoch 263 tst: l 0.183 a 0.948 clct[50, 50, 50, 50] 0.334sec
# Epoch 264 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.727sec(train) 1.896sec(infer)
# Epoch 264 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.333sec
# Epoch 265 tr: l 0.191 a 0.940 clct[300, 300, 300, 300] lr 0.100000 27.157sec(train) 2.198sec(infer)
# Epoch 265 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] 0.493sec
# Epoch 266 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 27.424sec(train) 1.926sec(infer)
# Epoch 266 tst: l 0.180 a 0.949 clct[50, 50, 50, 50] 0.329sec
# Epoch 267 tr: l 0.161 a 0.951 clct[300, 300, 300, 300] lr 0.100000 26.852sec(train) 1.888sec(infer)
# Epoch 267 tst: l 0.181 a 0.949 clct[50, 50, 50, 50] 0.321sec
# Epoch 268 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.983sec(train) 2.811sec(infer)
# Epoch 268 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.339sec
# Epoch 269 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 26.911sec(train) 1.891sec(infer)
# Epoch 269 tst: l 0.182 a 0.947 clct[50, 50, 50, 50] 0.330sec
# Epoch 270 tr: l 0.159 a 0.951 clct[300, 300, 300, 300] lr 0.100000 27.034sec(train) 1.894sec(infer)
# Epoch 270 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.322sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 271 tr: l 0.159 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.409sec(train) 1.921sec(infer)
# Epoch 271 tst: l 0.176 a 0.949 clct[50, 50, 50, 50] 0.324sec
# Epoch 272 tr: l 0.161 a 0.951 clct[300, 300, 300, 300] lr 0.100000 27.020sec(train) 1.887sec(infer)
# Epoch 272 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.339sec
# Epoch 273 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 26.864sec(train) 1.904sec(infer)
# Epoch 273 tst: l 0.177 a 0.950 clct[50, 50, 50, 50] 0.423sec
# Epoch 274 tr: l 0.159 a 0.951 clct[300, 300, 300, 300] lr 0.100000 27.478sec(train) 1.869sec(infer)
# Epoch 274 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.335sec
# Epoch 275 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 26.937sec(train) 1.888sec(infer)
# Epoch 275 tst: l 0.180 a 0.948 clct[50, 50, 50, 50] 0.326sec
# Epoch 276 tr: l 0.157 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.012sec(train) 2.046sec(infer)
# Epoch 276 tst: l 0.176 a 0.950 clct[50, 50, 50, 50] 0.444sec
# Epoch 277 tr: l 0.157 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.490sec(train) 1.911sec(infer)
# Epoch 277 tst: l 0.177 a 0.950 clct[50, 50, 50, 50] 0.320sec
# Epoch 278 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 26.853sec(train) 1.902sec(infer)
# Epoch 278 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.325sec
# Epoch 279 tr: l 0.161 a 0.950 clct[300, 300, 300, 300] lr 0.100000 27.245sec(train) 2.526sec(infer)
# Epoch 279 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.435sec
# Epoch 280 tr: l 0.159 a 0.950 clct[300, 300, 300, 300] lr 0.100000 27.049sec(train) 1.891sec(infer)
# Epoch 280 tst: l 0.179 a 0.948 clct[50, 50, 50, 50] 0.329sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 281 tr: l 0.159 a 0.951 clct[300, 300, 300, 300] lr 0.100000 26.767sec(train) 1.875sec(infer)
# Epoch 281 tst: l 0.179 a 0.949 clct[50, 50, 50, 50] 0.319sec
# Epoch 282 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.358sec(train) 2.105sec(infer)
# Epoch 282 tst: l 0.176 a 0.949 clct[50, 50, 50, 50] 0.323sec
# Epoch 283 tr: l 0.155 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.018sec(train) 1.897sec(infer)
# Epoch 283 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.318sec
# Epoch 284 tr: l 0.155 a 0.952 clct[300, 300, 300, 300] lr 0.100000 26.854sec(train) 1.914sec(infer)
# Epoch 284 tst: l 0.176 a 0.950 clct[50, 50, 50, 50] 0.322sec
# Epoch 285 tr: l 0.157 a 0.951 clct[300, 300, 300, 300] lr 0.100000 27.931sec(train) 1.921sec(infer)
# Epoch 285 tst: l 0.180 a 0.949 clct[50, 50, 50, 50] 0.318sec
# Epoch 286 tr: l 0.154 a 0.952 clct[300, 300, 300, 300] lr 0.100000 26.806sec(train) 1.895sec(infer)
# Epoch 286 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.349sec
# Epoch 287 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.190sec(train) 1.960sec(infer)
# Epoch 287 tst: l 0.176 a 0.950 clct[50, 50, 50, 50] 0.436sec
# Epoch 288 tr: l 0.155 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.751sec(train) 1.889sec(infer)
# Epoch 288 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.316sec
# Epoch 289 tr: l 0.154 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.280sec(train) 1.867sec(infer)
# Epoch 289 tst: l 0.173 a 0.949 clct[50, 50, 50, 50] 0.320sec
# Epoch 290 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 26.788sec(train) 2.201sec(infer)
# Epoch 290 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.471sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# Epoch 291 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 27.098sec(train) 1.907sec(infer)
# Epoch 291 tst: l 0.172 a 0.950 clct[50, 50, 50, 50] 0.318sec
# Epoch 292 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 26.801sec(train) 1.896sec(infer)
# Epoch 292 tst: l 0.172 a 0.950 clct[50, 50, 50, 50] 0.330sec
# Epoch 293 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 27.082sec(train) 2.517sec(infer)
# Epoch 293 tst: l 0.172 a 0.951 clct[50, 50, 50, 50] 0.332sec
# Epoch 294 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 26.732sec(train) 1.883sec(infer)
# Epoch 294 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.335sec
# Epoch 295 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 27.010sec(train) 1.912sec(infer)
# Epoch 295 tst: l 0.172 a 0.951 clct[50, 50, 50, 50] 0.319sec
# Epoch 296 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 27.319sec(train) 2.349sec(infer)
# Epoch 296 tst: l 0.177 a 0.949 clct[50, 50, 50, 50] 0.323sec
# Epoch 297 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 26.908sec(train) 1.895sec(infer)
# Epoch 297 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.320sec
# Epoch 298 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 27.040sec(train) 1.889sec(infer)
# Epoch 298 tst: l 0.172 a 0.951 clct[50, 50, 50, 50] 0.315sec
# Epoch 299 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 27.707sec(train) 1.929sec(infer)
# Epoch 299 tst: l 0.172 a 0.951 clct[50, 50, 50, 50] 0.318sec
# result written at output/results.pickle
# checkpoint written at output/checkpoint.pt
# ---train cluster Ended in 2.47 hour (8891.528 sec)
