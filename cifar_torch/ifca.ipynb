# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import ifca as IFCA
import numpy as np

from util import *

# %%
torch.cuda.empty_cache()

with open("config.json", "r") as read_file:
    config = json.load(read_file)

res_final = []

start_time = time.time()
config['data_seed'] = 13
config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = IFCA.TrainCIFARCluster(config, device)
exp.setup()
res = exp.run()
res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
del exp
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.8, 'h1': 128, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 13, 'train_seed': 13, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda:3
# num_data: 50000
# num_data: 10000
# finding good initializer from train data
# Epoch -1 tr: l 2.304 a 0.099 clct[np.int64(95), np.int64(65)] clct_ans[np.int64(82), np.int64(78)]  34.208sec
# found good initializer
# Epoch -1 tr: l 2.304 a 0.098 clct[np.int64(90), np.int64(70)] clct_ans[np.int64(82), np.int64(78)]  33.853sec
# Epoch -1 tst: l 2.304 a 0.100 clct[np.int64(22), np.int64(18)] clct_ans[np.int64(20), np.int64(20)]  3.172sec
# Epoch 0 tr: l 2.235 a 0.187 clct[np.int64(103), np.int64(57)] clct_ans[np.int64(78), np.int64(82)]  lr 0.250000 88.933sec(train) 34.050sec(infer)
# Epoch 0 tst: l 2.232 a 0.198 clct[np.int64(28), np.int64(12)] clct_ans[np.int64(20), np.int64(20)]  3.146sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 2.087 a 0.267 clct[np.int64(86), np.int64(74)] clct_ans[np.int64(74), np.int64(86)]  lr 0.249975 70.867sec(train) 33.963sec(infer)
# Epoch 1 tst: l 2.076 a 0.285 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.180sec
# Epoch 2 tr: l 1.945 a 0.318 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249950 70.207sec(train) 33.929sec(infer)
# Epoch 2 tst: l 1.918 a 0.339 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.330sec
# Epoch 3 tr: l 1.851 a 0.344 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(79), np.int64(81)]  lr 0.249925 70.031sec(train) 33.656sec(infer)
# Epoch 3 tst: l 1.806 a 0.374 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.299sec
# Epoch 4 tr: l 1.789 a 0.366 clct[np.int64(82), np.int64(78)] clct_ans[np.int64(78), np.int64(82)]  lr 0.249900 70.673sec(train) 34.107sec(infer)
# Epoch 4 tst: l 1.735 a 0.400 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.257sec
# Epoch 5 tr: l 1.722 a 0.386 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(82), np.int64(78)]  lr 0.249875 67.626sec(train) 33.729sec(infer)
# Epoch 5 tst: l 1.658 a 0.421 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.186sec
# Epoch 6 tr: l 1.685 a 0.399 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249850 67.727sec(train) 33.594sec(infer)
# Epoch 6 tst: l 1.614 a 0.436 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.155sec
# Epoch 7 tr: l 1.636 a 0.417 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249825 67.724sec(train) 33.568sec(infer)
# Epoch 7 tst: l 1.559 a 0.451 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.190sec
# Epoch 8 tr: l 1.592 a 0.431 clct[np.int64(76), np.int64(84)] clct_ans[np.int64(84), np.int64(76)]  lr 0.249800 73.206sec(train) 33.726sec(infer)
# Epoch 8 tst: l 1.512 a 0.467 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.174sec
# Epoch 9 tr: l 1.550 a 0.450 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(83), np.int64(77)]  lr 0.249775 68.827sec(train) 33.569sec(infer)
# Epoch 9 tst: l 1.467 a 0.485 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.230sec
# Epoch 10 tr: l 1.523 a 0.459 clct[np.int64(75), np.int64(85)] clct_ans[np.int64(85), np.int64(75)]  lr 0.249750 70.200sec(train) 33.877sec(infer)
# Epoch 10 tst: l 1.434 a 0.495 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.160sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 1.490 a 0.472 clct[np.int64(84), np.int64(76)] clct_ans[np.int64(76), np.int64(84)]  lr 0.249725 69.196sec(train) 33.836sec(infer)
# Epoch 11 tst: l 1.402 a 0.514 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.180sec
# Epoch 12 tr: l 1.467 a 0.479 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(83), np.int64(77)]  lr 0.249700 72.134sec(train) 33.780sec(infer)
# Epoch 12 tst: l 1.373 a 0.521 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.186sec
# Epoch 13 tr: l 1.434 a 0.494 clct[np.int64(84), np.int64(76)] clct_ans[np.int64(76), np.int64(84)]  lr 0.249675 70.942sec(train) 33.697sec(infer)
# Epoch 13 tst: l 1.346 a 0.538 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.153sec
# Epoch 14 tr: l 1.408 a 0.506 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249650 69.659sec(train) 33.471sec(infer)
# Epoch 14 tst: l 1.321 a 0.545 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.156sec
# Epoch 15 tr: l 1.394 a 0.514 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249625 69.551sec(train) 33.834sec(infer)
# Epoch 15 tst: l 1.301 a 0.552 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.172sec
# Epoch 16 tr: l 1.377 a 0.525 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249600 70.441sec(train) 33.685sec(infer)
# Epoch 16 tst: l 1.288 a 0.558 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.265sec
# Epoch 17 tr: l 1.366 a 0.531 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)]  lr 0.249575 69.507sec(train) 33.649sec(infer)
# Epoch 17 tst: l 1.274 a 0.567 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.154sec
# Epoch 18 tr: l 1.347 a 0.538 clct[np.int64(75), np.int64(85)] clct_ans[np.int64(85), np.int64(75)]  lr 0.249550 69.473sec(train) 34.122sec(infer)
# Epoch 18 tst: l 1.261 a 0.573 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.167sec
# Epoch 19 tr: l 1.338 a 0.543 clct[np.int64(79), np.int64(81)] clct_ans[np.int64(81), np.int64(79)]  lr 0.249525 68.565sec(train) 34.086sec(infer)
# Epoch 19 tst: l 1.247 a 0.578 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.185sec
# Epoch 20 tr: l 1.318 a 0.550 clct[np.int64(82), np.int64(78)] clct_ans[np.int64(78), np.int64(82)]  lr 0.249500 69.467sec(train) 33.771sec(infer)
# Epoch 20 tst: l 1.233 a 0.585 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.222sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 1.308 a 0.549 clct[np.int64(85), np.int64(75)] clct_ans[np.int64(75), np.int64(85)]  lr 0.249476 69.098sec(train) 34.001sec(infer)
# Epoch 21 tst: l 1.218 a 0.589 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.175sec
# Epoch 22 tr: l 1.296 a 0.555 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(79), np.int64(81)]  lr 0.249451 70.235sec(train) 33.649sec(infer)
# Epoch 22 tst: l 1.205 a 0.595 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.165sec
# Epoch 23 tr: l 1.276 a 0.563 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(82), np.int64(78)]  lr 0.249426 66.865sec(train) 34.043sec(infer)
# Epoch 23 tst: l 1.191 a 0.598 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.176sec
# Epoch 24 tr: l 1.277 a 0.565 clct[np.int64(79), np.int64(81)] clct_ans[np.int64(81), np.int64(79)]  lr 0.249401 70.690sec(train) 34.259sec(infer)
# Epoch 24 tst: l 1.179 a 0.603 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.172sec
# Epoch 25 tr: l 1.256 a 0.569 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249376 71.314sec(train) 33.747sec(infer)
# Epoch 25 tst: l 1.168 a 0.604 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.200sec
# Epoch 26 tr: l 1.247 a 0.575 clct[np.int64(75), np.int64(85)] clct_ans[np.int64(85), np.int64(75)]  lr 0.249351 68.833sec(train) 33.790sec(infer)
# Epoch 26 tst: l 1.160 a 0.609 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.173sec
# Epoch 27 tr: l 1.240 a 0.575 clct[np.int64(82), np.int64(78)] clct_ans[np.int64(78), np.int64(82)]  lr 0.249326 69.803sec(train) 34.141sec(infer)
# Epoch 27 tst: l 1.150 a 0.611 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.201sec
# Epoch 28 tr: l 1.235 a 0.576 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249301 69.566sec(train) 33.754sec(infer)
# Epoch 28 tst: l 1.143 a 0.615 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.286sec
# Epoch 29 tr: l 1.221 a 0.583 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)]  lr 0.249276 69.969sec(train) 33.677sec(infer)
# Epoch 29 tst: l 1.133 a 0.618 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.164sec
# Epoch 30 tr: l 1.208 a 0.585 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)]  lr 0.249251 69.617sec(train) 34.232sec(infer)
# Epoch 30 tst: l 1.123 a 0.621 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.170sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 1.204 a 0.588 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(77), np.int64(83)]  lr 0.249226 69.591sec(train) 33.854sec(infer)
# Epoch 31 tst: l 1.118 a 0.623 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.181sec
# Epoch 32 tr: l 1.199 a 0.589 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)]  lr 0.249201 70.720sec(train) 34.014sec(infer)
# Epoch 32 tst: l 1.110 a 0.626 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.272sec
# Epoch 33 tr: l 1.190 a 0.592 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(82), np.int64(78)]  lr 0.249176 72.392sec(train) 34.292sec(infer)
# Epoch 33 tst: l 1.101 a 0.628 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.189sec
# Epoch 34 tr: l 1.181 a 0.596 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(83), np.int64(77)]  lr 0.249151 68.950sec(train) 33.640sec(infer)
# Epoch 34 tst: l 1.095 a 0.629 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.178sec
# Epoch 35 tr: l 1.178 a 0.598 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(79), np.int64(81)]  lr 0.249126 69.366sec(train) 33.873sec(infer)
# Epoch 35 tst: l 1.091 a 0.631 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.123sec
# Epoch 36 tr: l 1.175 a 0.597 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(82), np.int64(78)]  lr 0.249102 67.205sec(train) 33.674sec(infer)
# Epoch 36 tst: l 1.082 a 0.633 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)]  3.144sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      16 exp = IFCA.TrainCIFARCluster(config, device)
#      17 exp.setup()
# ---> 18 res = exp.run()
#      19 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#      20 del exp
#
# File ~/repos/dfca/cifar_torch/ifca.py:276, in TrainCIFARCluster.run(self)
#     273 result['lr'] = lr
#     275 t0 = time.time()
# --> 276 result['train'] = self.train(lr = lr)
#     277 t1 = time.time()
#     278 train_time = t1-t0
#
# File ~/repos/dfca/cifar_torch/ifca.py:441, in TrainCIFARCluster.train(self, lr)
#     438 for m_i in participating_nodes:
#     439     if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')
# --> 441     (X, y) = self.load_data(m_i)
#     443     ds = TensorDataset(X, y)
#     444     dl = DataLoader(ds, batch_size=batch_size, shuffle=True)
#
# File ~/repos/dfca/cifar_torch/ifca.py:633, in TrainCIFARCluster.load_data(self, m_i, train)
#     630     raise NotImplementedError("only p=1,2,4 supported")
#     632 if train:
# --> 633     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     634 else:
#     635     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File ~/repos/dfca/cifar_torch/ifca.py:633, in <listcomp>(.0)
#     630     raise NotImplementedError("only p=1,2,4 supported")
#     632 if train:
# --> 633     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     634 else:
#     635     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/transforms.py:660, in RandomCrop.forward(self, img)
#     657     self.fill = fill
#     658     self.padding_mode = padding_mode
# --> 660 def forward(self, img):
#     661     """
#     662     Args:
#     663         img (PIL Image or Tensor): Image to be cropped.
#    (...)    666         PIL Image or Tensor: Cropped image.
#     667     """
#     668     if self.padding is not None:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
