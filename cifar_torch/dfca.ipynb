# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import numpy as np

from util import *

# %%
torch.cuda.empty_cache()

with open("config.json", "r") as read_file:
    config = json.load(read_file)

res_final = []

start_time = time.time()
config['data_seed'] = 13
config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = DFCA.TrainCIFARCluster(config, device)
exp.setup()
res = exp.run()
res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
del exp
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'uneven': False, 'local_model_init': False, 'participation_rate': 0.8, 'h1': 128, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 13, 'train_seed': 13, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda:3
# num_data: 50000
# num_data: 10000
# finding good initializer from train data
# Epoch -1 tr: l 2.301 a 0.106 clct[np.int64(71), np.int64(89)] clct_ans[np.int64(82), np.int64(78)] cl_acc0.544  35.878sec
# found good initializer
# Epoch -1 tr: l 2.301 a 0.106 clct[np.int64(69), np.int64(91)] clct_ans[np.int64(82), np.int64(78)] cl_acc0.531  34.063sec
# Epoch -1 tst: l 2.301 a 0.109 clct[np.int64(15), np.int64(25)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  3.256sec
# Epoch 0 tr: l 2.223 a 0.180 clct[np.int64(109), np.int64(51)] clct_ans[np.int64(78), np.int64(82)] cl_acc0.544  lr 0.250000 75.719sec(train) 34.063sec(infer)
# Epoch 0 tst: l 2.227 a 0.183 clct[np.int64(29), np.int64(11)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.575  3.283sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 2.123 a 0.244 clct[np.int64(97), np.int64(63)] clct_ans[np.int64(74), np.int64(86)] cl_acc0.606  lr 0.249875 72.340sec(train) 34.588sec(infer)
# Epoch 1 tst: l 2.137 a 0.235 clct[np.int64(26), np.int64(14)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.500  3.199sec
# Epoch 2 tr: l 2.054 a 0.282 clct[np.int64(95), np.int64(65)] clct_ans[np.int64(77), np.int64(83)] cl_acc0.725  lr 0.249750 73.764sec(train) 34.226sec(infer)
# Epoch 2 tst: l 2.053 a 0.281 clct[np.int64(26), np.int64(14)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.700  3.214sec
# Epoch 3 tr: l 1.965 a 0.316 clct[np.int64(89), np.int64(71)] clct_ans[np.int64(79), np.int64(81)] cl_acc0.900  lr 0.249625 73.940sec(train) 34.097sec(infer)
# Epoch 3 tst: l 1.973 a 0.323 clct[np.int64(23), np.int64(17)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.875  3.326sec
# Epoch 4 tr: l 1.869 a 0.340 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(78), np.int64(82)] cl_acc0.969  lr 0.249500 72.106sec(train) 34.074sec(infer)
# Epoch 4 tst: l 1.851 a 0.357 clct[np.int64(22), np.int64(18)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.950  3.205sec
# Epoch 5 tr: l 1.773 a 0.368 clct[np.int64(82), np.int64(78)] clct_ans[np.int64(82), np.int64(78)] cl_acc0.988  lr 0.249376 71.965sec(train) 33.899sec(infer)
# Epoch 5 tst: l 1.750 a 0.387 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.264sec
# Epoch 6 tr: l 1.709 a 0.389 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.249251 73.961sec(train) 34.237sec(infer)
# Epoch 6 tst: l 1.685 a 0.406 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.227sec
# Epoch 7 tr: l 1.647 a 0.409 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.249126 74.410sec(train) 34.334sec(infer)
# Epoch 7 tst: l 1.609 a 0.429 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.204sec
# Epoch 8 tr: l 1.615 a 0.425 clct[np.int64(84), np.int64(76)] clct_ans[np.int64(84), np.int64(76)] cl_acc1.000  lr 0.249002 73.438sec(train) 34.207sec(infer)
# Epoch 8 tst: l 1.569 a 0.448 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.253sec
# Epoch 9 tr: l 1.570 a 0.442 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(83), np.int64(77)] cl_acc1.000  lr 0.248877 72.716sec(train) 34.111sec(infer)
# Epoch 9 tst: l 1.537 a 0.455 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  3.228sec
# Epoch 10 tr: l 1.540 a 0.456 clct[np.int64(85), np.int64(75)] clct_ans[np.int64(85), np.int64(75)] cl_acc1.000  lr 0.248753 73.646sec(train) 34.078sec(infer)
# Epoch 10 tst: l 1.510 a 0.468 clct[np.int64(19), np.int64(21)] clct_ans[np.int64(20), np.int64(20)] cl_acc0.975  3.240sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 1.491 a 0.476 clct[np.int64(76), np.int64(84)] clct_ans[np.int64(76), np.int64(84)] cl_acc1.000  lr 0.248628 71.936sec(train) 33.955sec(infer)
# Epoch 11 tst: l 1.463 a 0.489 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.223sec
# Epoch 12 tr: l 1.454 a 0.492 clct[np.int64(83), np.int64(77)] clct_ans[np.int64(83), np.int64(77)] cl_acc1.000  lr 0.248504 71.472sec(train) 34.173sec(infer)
# Epoch 12 tst: l 1.440 a 0.503 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.215sec
# Epoch 13 tr: l 1.442 a 0.506 clct[np.int64(76), np.int64(84)] clct_ans[np.int64(76), np.int64(84)] cl_acc1.000  lr 0.248380 71.896sec(train) 34.048sec(infer)
# Epoch 13 tst: l 1.403 a 0.516 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.236sec
# Epoch 14 tr: l 1.414 a 0.520 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.248256 73.365sec(train) 34.613sec(infer)
# Epoch 14 tst: l 1.415 a 0.523 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.415sec
# Epoch 15 tr: l 1.411 a 0.526 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(77), np.int64(83)] cl_acc0.994  lr 0.248132 72.089sec(train) 34.541sec(infer)
# Epoch 15 tst: l 1.415 a 0.527 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.245sec
# Epoch 16 tr: l 1.388 a 0.538 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.248007 70.298sec(train) 33.950sec(infer)
# Epoch 16 tst: l 1.391 a 0.535 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.238sec
# Epoch 17 tr: l 1.359 a 0.544 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)] cl_acc1.000  lr 0.247883 72.767sec(train) 34.252sec(infer)
# Epoch 17 tst: l 1.389 a 0.541 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.259sec
# Epoch 18 tr: l 1.347 a 0.547 clct[np.int64(85), np.int64(75)] clct_ans[np.int64(85), np.int64(75)] cl_acc1.000  lr 0.247760 71.342sec(train) 34.223sec(infer)
# Epoch 18 tst: l 1.353 a 0.548 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.278sec
# Epoch 19 tr: l 1.340 a 0.549 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(81), np.int64(79)] cl_acc1.000  lr 0.247636 72.894sec(train) 34.336sec(infer)
# Epoch 19 tst: l 1.344 a 0.548 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.238sec
# Epoch 20 tr: l 1.318 a 0.561 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(78), np.int64(82)] cl_acc1.000  lr 0.247512 72.385sec(train) 34.207sec(infer)
# Epoch 20 tst: l 1.329 a 0.556 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.215sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 1.318 a 0.560 clct[np.int64(75), np.int64(85)] clct_ans[np.int64(75), np.int64(85)] cl_acc1.000  lr 0.247388 70.703sec(train) 34.168sec(infer)
# Epoch 21 tst: l 1.320 a 0.562 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.228sec
# Epoch 22 tr: l 1.283 a 0.570 clct[np.int64(79), np.int64(81)] clct_ans[np.int64(79), np.int64(81)] cl_acc1.000  lr 0.247264 70.695sec(train) 34.402sec(infer)
# Epoch 22 tst: l 1.307 a 0.563 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.229sec
# Epoch 23 tr: l 1.273 a 0.572 clct[np.int64(82), np.int64(78)] clct_ans[np.int64(82), np.int64(78)] cl_acc1.000  lr 0.247141 72.335sec(train) 34.337sec(infer)
# Epoch 23 tst: l 1.303 a 0.569 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.252sec
# Epoch 24 tr: l 1.278 a 0.572 clct[np.int64(81), np.int64(79)] clct_ans[np.int64(81), np.int64(79)] cl_acc1.000  lr 0.247017 70.774sec(train) 34.097sec(infer)
# Epoch 24 tst: l 1.295 a 0.574 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.194sec
# Epoch 25 tr: l 1.255 a 0.579 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.246894 70.984sec(train) 34.102sec(infer)
# Epoch 25 tst: l 1.273 a 0.576 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.233sec
# Epoch 26 tr: l 1.256 a 0.580 clct[np.int64(85), np.int64(75)] clct_ans[np.int64(85), np.int64(75)] cl_acc1.000  lr 0.246770 71.182sec(train) 34.496sec(infer)
# Epoch 26 tst: l 1.268 a 0.576 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.265sec
# Epoch 27 tr: l 1.253 a 0.582 clct[np.int64(78), np.int64(82)] clct_ans[np.int64(78), np.int64(82)] cl_acc1.000  lr 0.246647 69.234sec(train) 34.327sec(infer)
# Epoch 27 tst: l 1.268 a 0.577 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.240sec
# Epoch 28 tr: l 1.229 a 0.588 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.246524 74.626sec(train) 34.112sec(infer)
# Epoch 28 tst: l 1.318 a 0.572 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.242sec
# Epoch 29 tr: l 1.229 a 0.589 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)] cl_acc1.000  lr 0.246400 73.000sec(train) 34.296sec(infer)
# Epoch 29 tst: l 1.277 a 0.576 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.267sec
# Epoch 30 tr: l 1.213 a 0.596 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)] cl_acc1.000  lr 0.246277 72.482sec(train) 34.122sec(infer)
# Epoch 30 tst: l 1.273 a 0.583 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.242sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 1.219 a 0.591 clct[np.int64(77), np.int64(83)] clct_ans[np.int64(77), np.int64(83)] cl_acc1.000  lr 0.246154 72.341sec(train) 33.921sec(infer)
# Epoch 31 tst: l 1.240 a 0.588 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.228sec
# Epoch 32 tr: l 1.208 a 0.595 clct[np.int64(80), np.int64(80)] clct_ans[np.int64(80), np.int64(80)] cl_acc1.000  lr 0.246031 74.041sec(train) 34.003sec(infer)
# Epoch 32 tst: l 1.225 a 0.589 clct[np.int64(20), np.int64(20)] clct_ans[np.int64(20), np.int64(20)] cl_acc1.000  3.557sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      16 exp = DFCA.TrainCIFARCluster(config, device)
#      17 exp.setup()
# ---> 18 res = exp.run()
#      19 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res]])
#      20 del exp
#
# File ~/repos/dfca/cifar_torch/dfca.py:287, in TrainCIFARCluster.run(self)
#     284 result['lr'] = lr
#     286 t0 = time.time()
# --> 287 result['train'] = self.train(lr = lr)
#     288 t1 = time.time()
#     289 train_time = t1-t0
#
# File ~/repos/dfca/cifar_torch/dfca.py:451, in TrainCIFARCluster.train(self, lr)
#     448 for m_i in participating_nodes:
#     449     if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')
# --> 451     (X, y) = self.load_data(m_i)
#     453     ds = TensorDataset(X, y)
#     454     dl = DataLoader(ds, batch_size=batch_size, shuffle=True)
#
# File ~/repos/dfca/cifar_torch/dfca.py:656, in TrainCIFARCluster.load_data(self, m_i, train)
#     653     raise NotImplementedError("only p=1,2,4 supported")
#     655 if train:
# --> 656     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     657 else:
#     658     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File ~/repos/dfca/cifar_torch/dfca.py:656, in <listcomp>(.0)
#     653     raise NotImplementedError("only p=1,2,4 supported")
#     655 if train:
# --> 656     X_batch2 = [self.train_transform(img) for img in X_batch]  # Now tensors
#     657 else:
#     658     X_batch2 = [self.test_transform(img) for img in X_batch]  # Now tensors
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/transforms.py:1276, in ColorJitter.forward(self, img)
#    1274     img = F.adjust_brightness(img, brightness_factor)
#    1275 elif fn_id == 1 and contrast_factor is not None:
# -> 1276     img = F.adjust_contrast(img, contrast_factor)
#    1277 elif fn_id == 2 and saturation_factor is not None:
#    1278     img = F.adjust_saturation(img, saturation_factor)
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/functional.py:907, in adjust_contrast(img, contrast_factor)
#     905     _log_api_usage_once(adjust_contrast)
#     906 if not isinstance(img, torch.Tensor):
# --> 907     return F_pil.adjust_contrast(img, contrast_factor)
#     909 return F_t.adjust_contrast(img, contrast_factor)
#
# File ~/local/python-3.11/lib/python3.11/site-packages/torchvision/transforms/_functional_pil.py:83, in adjust_contrast(img, contrast_factor)
#      80     raise TypeError(f"img should be PIL Image. Got {type(img)}")
#      82 enhancer = ImageEnhance.Contrast(img)
# ---> 83 img = enhancer.enhance(contrast_factor)
#      84 return img
#
# File ~/local/python-3.11/lib/python3.11/site-packages/PIL/ImageEnhance.py:40, in _Enhance.enhance(self, factor)
#      29 def enhance(self, factor: float) -> Image.Image:
#      30     """
#      31     Returns an enhanced image.
#      32
#    (...)     38     :rtype: :py:class:`~PIL.Image.Image`
#      39     """
# ---> 40     return Image.blend(self.degenerate, self.image, factor)
#
# File ~/local/python-3.11/lib/python3.11/site-packages/PIL/Image.py:3578, in blend(im1, im2, alpha)
#    3576 im1.load()
#    3577 im2.load()
# -> 3578 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# File ~/local/python-3.11/lib/python3.11/site-packages/PIL/Image.py:589, in Image._new(self, im)
#     587 def _new(self, im: core.ImagingCore) -> Image:
#     588     new = Image()
# --> 589     new.im = im
#     590     new._mode = im.mode
#     591     new._size = im.size
#
# File ~/local/python-3.11/lib/python3.11/site-packages/PIL/Image.py:567, in Image.im(self, im)
#     564     assert self._im is not None
#     565     return self._im
# --> 567 @im.setter
#     568 def im(self, im: core.ImagingCore) -> None:
#     569     self._im = im
#     571 @property
#     572 def width(self) -> int:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
