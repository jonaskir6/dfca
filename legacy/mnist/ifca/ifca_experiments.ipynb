# %%
import argparse
import json
import os
import time
import itertools
import pickle
import copy
import random
import math

import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset, TensorDataset


import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config.json

# %%
LR_DECAY = False
def get_config():

    # read config json and update the sysarg
    with open("config.json", "r") as read_file:
        config = json.load(read_file)

    if config["config_override"] == "":
        del config['config_override']
    else:
        print(config['config_override'])
        config_override = json.loads(config['config_override'])
        del config['config_override']
        config.update(config_override)

    return config

# %% [markdown]
# Class SimpleLinear with simple MLP for MNIST Classification

# %%
class SimpleLinear(torch.nn.Module):

    def __init__(self, h1=2048):
        super().__init__()
        self.fc1 = torch.nn.Linear(28*28, h1)
        self.fc2 = torch.nn.Linear(h1, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        # x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

    # def weight(self):
    #     return self.linear1.weight

# %% [markdown]
# Class TrainMNISTCluster with all the methods needed to run the experiments

# %%
class TrainMNISTCluster(object):
    def __init__(self, config, device):
        self.config = config
        self.device = device

        assert self.config['m'] % self.config['p'] == 0

    def setup(self):

        os.makedirs(self.config['project_dir'], exist_ok = True)

        self.result_fname = os.path.join(self.config['project_dir'], 'results.pickle')
        self.checkpoint_fname = os.path.join(self.config['project_dir'], 'checkpoint.pt')

        self.setup_datasets()
        self.setup_models()

        self.epoch = None
        self.lr = None


    def setup_datasets(self):

        np.random.seed(self.config['data_seed'])

        # generate indices for each dataset
        # also write cluster info

        MNIST_TRAINSET_DATA_SIZE = 60000
        MNIST_TESTSET_DATA_SIZE = 10000

        np.random.seed(self.config['data_seed'])

        cfg = self.config

        self.dataset = {}

        if cfg['uneven'] == True:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        else:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        # import ipdb; ipdb.set_trace()

    def _setup_dataset(self, num_data, p, m, n, random = True):

        print("m:",m)
        print("p:",p)
        print("n:",n)
        print("num_data:",num_data)
        assert (m // p) * n == num_data

        dataset = {}

        cfg = self.config

        data_indices = []
        cluster_assign = []

        m_per_cluster = m // p

        for p_i in range(p):

            if random:
                ll = list(np.random.permutation(num_data))
            else:
                ll = list(range(num_data))

            ll2 = chunkify(ll, m_per_cluster) # splits ll into m lists with size n
            data_indices += ll2

            cluster_assign += [p_i for _ in range(m_per_cluster)]

        print(type(data_indices))
        data_indices = np.array(data_indices)
        cluster_assign = np.array(cluster_assign)
        assert data_indices.shape[0] == cluster_assign.shape[0]
        assert data_indices.shape[0] == m


        return data_indices, cluster_assign


    def _setup_dataset_random_n(self, num_data, p, m, n, random = True):

        print("m:",m)
        print("p:",p)
        print("num_data:",num_data)

        dataset = {}

        cfg = self.config

        data_indices = []
        cluster_assign = []

        m_per_cluster = m // p

        for p_i in range(p):

            ll = list(np.random.permutation(num_data))

            ll2 = chunkify_uneven(ll, m_per_cluster) # splits ll into m lists
            data_indices += ll2

            cluster_assign += [p_i for _ in range(m_per_cluster)]

        data_indices = np.array(data_indices, dtype=object)
        cluster_assign = np.array(cluster_assign)
        assert data_indices.shape[0] == cluster_assign.shape[0]
        assert data_indices.shape[0] == m


        return data_indices, cluster_assign


    def _load_MNIST(self, train=True):
        transforms = torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               # torchvision.transforms.Normalize(
                               #   (0.1307,), (0.3081,))
                             ])
        if train:
            mnist_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms)
        else:
            mnist_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms)

        dl = DataLoader(mnist_dataset)

        X = dl.dataset.data # (60000,28, 28)
        y = dl.dataset.targets #(60000)

        # normalize to have 0 ~ 1 range in each pixel

        X = X / 255.0
        X = X.to(self.device)
        y = y.to(self.device)

        return X, y


    # Need p models for each client

    def setup_models(self):
        np.random.seed(self.config['train_seed'])
        torch.manual_seed(self.config['train_seed'])

        p = self.config['p']

        self.models = [ SimpleLinear(h1 = self.config['h1']).to(self.device) for p_i in range(p)] # p models with p different params of dimension(1,d)

        self.criterion = torch.nn.CrossEntropyLoss()

        # import ipdb; ipdb.set_trace()


    def run(self):
        num_epochs = self.config['num_epochs']
        lr = self.config['lr']

        results = []

        # epoch -1
        self.epoch = -1

        result = {}
        result['epoch'] = -1

        t0 = time.time()
        res = self.test(train=True)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['train'] = res

        self.print_epoch_stats(res)

        t0 = time.time()
        res = self.test(train=False)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['test'] = res
        self.print_epoch_stats(res)
        results.append(result)

        # this will be used in next epoch
        cluster_assign = result['train']['cluster_assign']

        for epoch in range(num_epochs):
            self.epoch = epoch

            result = {}
            result['epoch'] = epoch

            lr = self.lr_schedule(epoch)
            result['lr'] = lr

            t0 = time.time()
            result['train'] = self.train(cluster_assign, lr = lr)
            t1 = time.time()
            train_time = t1-t0

            t0 = time.time()
            res = self.test(train=True)
            t1 = time.time()
            res['infer_time'] = t1-t0
            res['train_time'] = train_time
            res['lr'] = lr
            result['train'] = res

            self.print_epoch_stats(res)

            t0 = time.time()
            res = self.test(train=False)
            t1 = time.time()
            res['infer_time'] = t1-t0
            result['test'] = res
            self.print_epoch_stats(res)

            results.append(result)

            # this will be used in next epoch's gradient update
            cluster_assign = result['train']['cluster_assign']

            if epoch % 10 == 0 or epoch == num_epochs - 1 :
                with open(self.result_fname, 'wb') as outfile:
                    pickle.dump(results, outfile)
                    print(f'result written at {self.result_fname}')
                self.save_checkpoint()
                print(f'checkpoint written at {self.checkpoint_fname}')

        plt.figure(figsize=(10,5))
        plt.plot([r['train']['loss'] for r in results], label='train loss')
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.title('Training Loss per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'train_loss.png'))
        # import ipdb; ipdb.set_trace()

        plt.figure(figsize=(10,5))
        plt.plot([r['test']['acc'] for r in results], label='test acc')
        plt.xlabel('epoch')
        plt.ylabel('test accuracy')
        plt.title('Test Accuracy per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'test_acc.png'))

    def lr_schedule(self, epoch):
        if self.lr is None:
            self.lr = self.config['lr']

        if epoch % 50 == 0 and epoch != 0 and LR_DECAY:
            self.lr = self.lr * 0.1

        return self.lr


    def print_epoch_stats(self, res):
        if res['is_train']:
            data_str = 'tr'
        else:
            data_str = 'tst'

        if 'train_time' in res:
            time_str = f"{res['train_time']:.3f}sec(train) {res['infer_time']:.3f}sec(infer)"
        else:
            time_str = f"{res['infer_time']:.3f}sec"

        if 'lr' in res:
            lr_str = f" lr {res['lr']:4f}"
        else:
            lr_str = ""

        str0 = f"Epoch {self.epoch} {data_str}: l {res['loss']:.3f} a {res['acc']:.3f} clct{res['cl_ct']}{lr_str} {time_str}"

        print(str0)

    def train(self, cluster_assign, lr):
        VERBOSE = 0

        cfg = self.config
        m = cfg['m']
        p = cfg['p']
        tau = cfg['tau']

        # run local update
        t0 = time.time()


        updated_models = []
        for m_i in range(m):
            if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')

            (X, y) = self.load_data(m_i)

            p_i = cluster_assign[m_i]
            model = copy.deepcopy(self.models[p_i])

            # LOCAL UPDATE PER MACHINE tau times
            for step_i in range(tau):

                y_logit = model(X)
                loss = self.criterion(y_logit, y)

                model.zero_grad()
                loss.backward()
                self.local_param_update(model, lr)

            model.zero_grad()

            updated_models.append(model)

        t02 = time.time()
        # print(f'running single ..took {t02-t01:.3f}sec')


        t1 = time.time()
        if VERBOSE: print(f'local update {t1-t0:.3f}sec')

        # apply gradient update
        t0 = time.time()

        # CLUSTER MACHINES INTO p_i's
        local_models = [[] for p_i in range(p)]
        for m_i in range(m):
            p_i = cluster_assign[m_i]
            local_models[p_i].append(updated_models[m_i])

        # NEEDS TO BE DECENTRALIZED
        for p_i, models in enumerate(local_models):
            if len(models) > 0:
                # self.dec_param_update(models, self.models[p_i])
                self.global_param_update(models, self.models[p_i])
        t1 = time.time()

        if VERBOSE: print(f'global update {t1-t0:.3f}sec')

    def check_local_model_loss(self, local_models):
        # for debugging
        m = self.config['m']

        losses = []
        for m_i in range(m):
            (X, y) = self.load_data(m_i)
            y_logit = local_models[m_i](X)
            loss = self.criterion(y_logit, y)

            losses.append(loss.item())

        return np.array(losses)


    def get_inference_stats(self, train = True):
        cfg = self.config
        if train:
            m = cfg['m']
            dataset = self.dataset['train']
        else:
            m = cfg['m_test']
            dataset = self.dataset['test']

        p = cfg['p']


        num_data = 0
        losses = {}
        corrects = {}
        for m_i in range(m):
            (X, y) = self.load_data(m_i, train=train) # load batch data rotated

            for p_i in range(p):
                y_logit = self.models[p_i](X)
                loss = self.criterion(y_logit, y) # loss of
                n_correct = self.n_correct(y_logit, y)

                # if torch.isnan(loss):
                #     print("nan loss: ", dataset['data_indices'][m_i])

                losses[(m_i,p_i)] = loss.item()
                corrects[(m_i,p_i)] = n_correct

            num_data += X.shape[0]

        # calculate loss and cluster the machines
        cluster_assign = []
        for m_i in range(m):
            machine_losses = [ losses[(m_i,p_i)] for p_i in range(p) ]
            min_p_i = np.argmin(machine_losses)
            cluster_assign.append(min_p_i)

        # calculate optimal model's loss, acc over all models
        min_corrects = []
        min_losses = []
        for m_i, p_i in enumerate(cluster_assign):

            min_loss = losses[(m_i,p_i)]
            min_losses.append(min_loss)

            min_correct = corrects[(m_i,p_i)]
            min_corrects.append(min_correct)

        # print("losses: ", min_losses)
        loss = np.mean(min_losses)
        acc = np.sum(min_corrects) / num_data


        # check cluster assignment acc
        cl_acc = np.mean(np.array(cluster_assign) == np.array(dataset['cluster_assign']))
        cl_ct = [np.sum(np.array(cluster_assign) == p_i ) for p_i in range(p)]

        res = {} # results
        # res['losses'] = losses
        # res['corrects'] = corrects
        res['cluster_assign'] = cluster_assign
        res['num_data'] = num_data
        res['loss'] = loss
        res['acc'] = acc
        res['cl_acc'] = cl_acc
        res['cl_ct'] = cl_ct
        res['is_train'] = train

        # import ipdb; ipdb.set_trace()

        return res

    def n_correct(self, y_logit, y):
        _, predicted = torch.max(y_logit.data, 1)
        correct = (predicted == y).sum().item()

        return correct

    # TODO Does every Cluster get 4 clients with the same data, but rotated differently?

    def load_data(self, m_i, train=True):
        # this part is very fast since its just rearranging models
        cfg = self.config

        if train:
            dataset = self.dataset['train']
        else:
            dataset = self.dataset['test']

        indices = dataset['data_indices'][m_i]
        p_i = dataset['cluster_assign'][m_i]

        X_batch = dataset['X'][indices]
        y_batch = dataset['y'][indices]

        # k : how many times rotate 90 degree
        # k =1 : 90 , k=2 180, k=3 270

        if cfg['p'] == 4:
            k = p_i
        elif cfg['p'] == 2:
            k = (p_i % 2) * 2
        elif cfg['p'] == 1:
            k = 0
        else:
            raise NotImplementedError("only p=1,2,4 supported")

        X_batch2 = torch.rot90(X_batch, k=int(k), dims = (1,2))
        X_batch3 = X_batch2.reshape(-1, 28 * 28)

        # import ipdb; ipdb.set_trace()

        return X_batch3, y_batch


    def local_param_update(self, model, lr):

        # gradient update manually

        for name, param in model.named_parameters():
            if param.requires_grad:
                param.data -= lr * param.grad

        model.zero_grad()

        # import ipdb; ipdb.set_trace() # we need to check the output of name, check if duplicate exists


    def global_param_update(self, local_models, global_model):

        # average of each weight

        weights = {}

        for m_i, local_model in enumerate(local_models):
            for name, param in local_model.named_parameters():
                if name not in weights:
                    weights[name] = torch.zeros_like(param.data)

                weights[name] += param.data

        for name, param in global_model.named_parameters():
            weights[name] /= len(local_models)
            param.data = weights[name]

        # import ipdb; ipdb.set_trace()


    def dec_param_update(self, local_models, global_model):

        num_clients = len(local_models)

        if num_clients == 0:
            return

        if num_clients == 1:
            bc_client = dict(local_models[0].named_parameters())
            for name, param in global_model.named_parameters():
                param.data = bc_client[name].data.clone()
            return

        max_e = 100
        if num_clients <= max_e:
            e = num_clients - 1
        else:
            e = min(max_e, int(np.log(num_clients) * 10))

        if e >= num_clients:
            e = num_clients - 1

        client_indices = list(range(num_clients))

        for m_i, local_model in enumerate(local_models):
            selected_clients = random.sample([i for i in client_indices if i != m_i], e)

            for m_j in selected_clients:

                m_j_params = dict(local_models[m_j].named_parameters())

                for name, param in local_model.named_parameters():
                    m_i_param = param.data.clone()
                    m_j_param = m_j_params[name].data.clone()
                    param.data = (m_i_param + m_j_param) / 2

        bc_client = random.choice(client_indices)
        bc_client_params = dict(local_models[bc_client].named_parameters())
        for name, param in global_model.named_parameters():
            param.data = bc_client_params[name].data.clone()

        # import ipdb; ipdb.set_trace()


    def test(self, train=False):
        return self.get_inference_stats(train=train)

    def save_checkpoint(self):
        models_to_save = [model.state_dict() for model in self.models]
        torch.save({'models':models_to_save}, self.checkpoint_fname)

# %% [markdown]
# Running the Experiment

# %%
start_time = time.time()
config = get_config()

config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = TrainMNISTCluster(config, device)
exp.setup()
exp.run()
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 10, 'train_seed': 10, 'project_dir': 'output'}
# Using device: cuda
# m: 1200
# p: 4
# num_data: 60000
# len:  60000
# len:  60000
# len:  60000
# len:  60000
# m: 200
# p: 4
# num_data: 10000
# len:  10000
# len:  10000
# len:  10000
# len:  10000
# Epoch -1 tr: l 2.294 a 0.113 clct[346, 317, 154, 383] 1.614sec
# Epoch -1 tst: l 2.292 a 0.114 clct[53, 69, 22, 56] 0.247sec
# Epoch 0 tr: l 2.170 a 0.391 clct[304, 413, 175, 308] lr 0.100000 4.617sec(train) 1.522sec(infer)
# Epoch 0 tst: l 2.168 a 0.394 clct[49, 73, 25, 53] 0.245sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 1 tr: l 1.909 a 0.643 clct[302, 297, 301, 300] lr 0.100000 4.657sec(train) 1.444sec(infer)
# Epoch 1 tst: l 1.905 a 0.650 clct[50, 51, 49, 50] 0.245sec
# Epoch 2 tr: l 1.566 a 0.737 clct[300, 300, 300, 300] lr 0.100000 4.522sec(train) 1.483sec(infer)
# Epoch 2 tst: l 1.559 a 0.747 clct[50, 50, 50, 50] 0.247sec
# Epoch 3 tr: l 1.256 a 0.777 clct[300, 300, 300, 300] lr 0.100000 4.416sec(train) 1.473sec(infer)
# Epoch 3 tst: l 1.245 a 0.788 clct[50, 50, 50, 50] 0.248sec
# Epoch 4 tr: l 1.027 a 0.805 clct[300, 300, 300, 300] lr 0.100000 4.847sec(train) 1.504sec(infer)
# Epoch 4 tst: l 1.016 a 0.814 clct[50, 50, 50, 50] 0.248sec
# Epoch 5 tr: l 0.871 a 0.824 clct[300, 300, 300, 300] lr 0.100000 4.725sec(train) 1.472sec(infer)
# Epoch 5 tst: l 0.860 a 0.832 clct[50, 50, 50, 50] 0.245sec
# Epoch 6 tr: l 0.764 a 0.836 clct[300, 300, 300, 300] lr 0.100000 4.421sec(train) 1.434sec(infer)
# Epoch 6 tst: l 0.753 a 0.844 clct[50, 50, 50, 50] 0.238sec
# Epoch 7 tr: l 0.687 a 0.845 clct[300, 300, 300, 300] lr 0.100000 4.421sec(train) 1.535sec(infer)
# Epoch 7 tst: l 0.677 a 0.853 clct[50, 50, 50, 50] 0.248sec
# Epoch 8 tr: l 0.630 a 0.852 clct[300, 300, 300, 300] lr 0.100000 5.158sec(train) 1.491sec(infer)
# Epoch 8 tst: l 0.620 a 0.861 clct[50, 50, 50, 50] 0.254sec
# Epoch 9 tr: l 0.587 a 0.858 clct[300, 300, 300, 300] lr 0.100000 4.775sec(train) 1.467sec(infer)
# Epoch 9 tst: l 0.577 a 0.866 clct[50, 50, 50, 50] 0.234sec
# Epoch 10 tr: l 0.552 a 0.863 clct[300, 300, 300, 300] lr 0.100000 4.645sec(train) 1.411sec(infer)
# Epoch 10 tst: l 0.543 a 0.870 clct[50, 50, 50, 50] 0.236sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 11 tr: l 0.524 a 0.867 clct[300, 300, 300, 300] lr 0.100000 4.655sec(train) 1.431sec(infer)
# Epoch 11 tst: l 0.516 a 0.875 clct[50, 50, 50, 50] 0.239sec
# Epoch 12 tr: l 0.501 a 0.871 clct[300, 300, 300, 300] lr 0.100000 4.759sec(train) 1.424sec(infer)
# Epoch 12 tst: l 0.493 a 0.879 clct[50, 50, 50, 50] 0.239sec
# Epoch 13 tr: l 0.482 a 0.874 clct[300, 300, 300, 300] lr 0.100000 4.589sec(train) 1.426sec(infer)
# Epoch 13 tst: l 0.474 a 0.882 clct[50, 50, 50, 50] 0.253sec
# Epoch 14 tr: l 0.465 a 0.877 clct[300, 300, 300, 300] lr 0.100000 4.545sec(train) 1.445sec(infer)
# Epoch 14 tst: l 0.458 a 0.884 clct[50, 50, 50, 50] 0.240sec
# Epoch 15 tr: l 0.451 a 0.879 clct[300, 300, 300, 300] lr 0.100000 5.059sec(train) 1.454sec(infer)
# Epoch 15 tst: l 0.444 a 0.886 clct[50, 50, 50, 50] 0.239sec
# Epoch 16 tr: l 0.439 a 0.881 clct[300, 300, 300, 300] lr 0.100000 4.655sec(train) 1.493sec(infer)
# Epoch 16 tst: l 0.432 a 0.888 clct[50, 50, 50, 50] 0.253sec
# Epoch 17 tr: l 0.428 a 0.883 clct[300, 300, 300, 300] lr 0.100000 4.624sec(train) 1.504sec(infer)
# Epoch 17 tst: l 0.421 a 0.889 clct[50, 50, 50, 50] 0.250sec
# Epoch 18 tr: l 0.418 a 0.885 clct[300, 300, 300, 300] lr 0.100000 4.630sec(train) 1.475sec(infer)
# Epoch 18 tst: l 0.412 a 0.891 clct[50, 50, 50, 50] 0.244sec
# Epoch 19 tr: l 0.410 a 0.886 clct[300, 300, 300, 300] lr 0.100000 4.571sec(train) 1.591sec(infer)
# Epoch 19 tst: l 0.404 a 0.892 clct[50, 50, 50, 50] 0.253sec
# Epoch 20 tr: l 0.402 a 0.888 clct[300, 300, 300, 300] lr 0.100000 4.732sec(train) 1.491sec(infer)
# Epoch 20 tst: l 0.397 a 0.894 clct[50, 50, 50, 50] 0.247sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 21 tr: l 0.395 a 0.889 clct[300, 300, 300, 300] lr 0.100000 4.908sec(train) 1.472sec(infer)
# Epoch 21 tst: l 0.390 a 0.895 clct[50, 50, 50, 50] 0.248sec
# Epoch 22 tr: l 0.389 a 0.890 clct[300, 300, 300, 300] lr 0.100000 4.552sec(train) 1.504sec(infer)
# Epoch 22 tst: l 0.384 a 0.897 clct[50, 50, 50, 50] 0.260sec
# Epoch 23 tr: l 0.383 a 0.891 clct[300, 300, 300, 300] lr 0.100000 4.731sec(train) 1.496sec(infer)
# Epoch 23 tst: l 0.378 a 0.898 clct[50, 50, 50, 50] 0.254sec
# Epoch 24 tr: l 0.378 a 0.892 clct[300, 300, 300, 300] lr 0.100000 4.711sec(train) 1.468sec(infer)
# Epoch 24 tst: l 0.373 a 0.899 clct[50, 50, 50, 50] 0.245sec
# Epoch 25 tr: l 0.373 a 0.893 clct[300, 300, 300, 300] lr 0.100000 4.619sec(train) 1.492sec(infer)
# Epoch 25 tst: l 0.369 a 0.899 clct[50, 50, 50, 50] 0.248sec
# Epoch 26 tr: l 0.368 a 0.894 clct[300, 300, 300, 300] lr 0.100000 4.771sec(train) 1.453sec(infer)
# Epoch 26 tst: l 0.364 a 0.900 clct[50, 50, 50, 50] 0.245sec
# Epoch 27 tr: l 0.364 a 0.895 clct[300, 300, 300, 300] lr 0.100000 4.682sec(train) 1.534sec(infer)
# Epoch 27 tst: l 0.360 a 0.901 clct[50, 50, 50, 50] 0.268sec
# Epoch 28 tr: l 0.360 a 0.896 clct[300, 300, 300, 300] lr 0.100000 4.686sec(train) 1.467sec(infer)
# Epoch 28 tst: l 0.357 a 0.901 clct[50, 50, 50, 50] 0.248sec
# Epoch 29 tr: l 0.356 a 0.897 clct[300, 300, 300, 300] lr 0.100000 4.601sec(train) 1.471sec(infer)
# Epoch 29 tst: l 0.353 a 0.902 clct[50, 50, 50, 50] 0.241sec
# Epoch 30 tr: l 0.353 a 0.898 clct[300, 300, 300, 300] lr 0.100000 4.628sec(train) 1.525sec(infer)
# Epoch 30 tst: l 0.350 a 0.903 clct[50, 50, 50, 50] 0.235sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 31 tr: l 0.350 a 0.898 clct[300, 300, 300, 300] lr 0.100000 6.913sec(train) 2.673sec(infer)
# Epoch 31 tst: l 0.347 a 0.904 clct[50, 50, 50, 50] 0.409sec
# Epoch 32 tr: l 0.346 a 0.899 clct[300, 300, 300, 300] lr 0.100000 9.535sec(train) 2.546sec(infer)
# Epoch 32 tst: l 0.344 a 0.904 clct[50, 50, 50, 50] 0.431sec
# Epoch 33 tr: l 0.343 a 0.900 clct[300, 300, 300, 300] lr 0.100000 9.582sec(train) 2.674sec(infer)
# Epoch 33 tst: l 0.341 a 0.905 clct[50, 50, 50, 50] 0.495sec
# Epoch 34 tr: l 0.341 a 0.900 clct[300, 300, 300, 300] lr 0.100000 9.881sec(train) 2.762sec(infer)
# Epoch 34 tst: l 0.338 a 0.905 clct[50, 50, 50, 50] 0.449sec
# Epoch 35 tr: l 0.338 a 0.901 clct[300, 300, 300, 300] lr 0.100000 9.704sec(train) 2.731sec(infer)
# Epoch 35 tst: l 0.336 a 0.906 clct[50, 50, 50, 50] 0.468sec
# Epoch 36 tr: l 0.335 a 0.901 clct[300, 300, 300, 300] lr 0.100000 10.107sec(train) 2.711sec(infer)
# Epoch 36 tst: l 0.333 a 0.907 clct[50, 50, 50, 50] 0.464sec
# Epoch 37 tr: l 0.333 a 0.902 clct[300, 300, 300, 300] lr 0.100000 10.086sec(train) 2.916sec(infer)
# Epoch 37 tst: l 0.331 a 0.907 clct[50, 50, 50, 50] 0.505sec
# Epoch 38 tr: l 0.330 a 0.903 clct[300, 300, 300, 300] lr 0.100000 10.296sec(train) 2.637sec(infer)
# Epoch 38 tst: l 0.329 a 0.907 clct[50, 50, 50, 50] 0.429sec
# Epoch 39 tr: l 0.328 a 0.903 clct[300, 300, 300, 300] lr 0.100000 9.973sec(train) 2.590sec(infer)
# Epoch 39 tst: l 0.327 a 0.908 clct[50, 50, 50, 50] 0.454sec
# Epoch 40 tr: l 0.326 a 0.904 clct[300, 300, 300, 300] lr 0.100000 9.486sec(train) 2.602sec(infer)
# Epoch 40 tst: l 0.325 a 0.908 clct[50, 50, 50, 50] 0.443sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 41 tr: l 0.324 a 0.904 clct[300, 300, 300, 300] lr 0.100000 9.347sec(train) 2.604sec(infer)
# Epoch 41 tst: l 0.323 a 0.909 clct[50, 50, 50, 50] 0.440sec
# Epoch 42 tr: l 0.322 a 0.905 clct[300, 300, 300, 300] lr 0.100000 9.275sec(train) 2.637sec(infer)
# Epoch 42 tst: l 0.321 a 0.909 clct[50, 50, 50, 50] 0.439sec
# Epoch 43 tr: l 0.320 a 0.905 clct[300, 300, 300, 300] lr 0.100000 9.726sec(train) 2.584sec(infer)
# Epoch 43 tst: l 0.319 a 0.910 clct[50, 50, 50, 50] 0.435sec
# Epoch 44 tr: l 0.318 a 0.906 clct[300, 300, 300, 300] lr 0.100000 9.410sec(train) 2.580sec(infer)
# Epoch 44 tst: l 0.318 a 0.911 clct[50, 50, 50, 50] 0.427sec
# Epoch 45 tr: l 0.316 a 0.906 clct[300, 300, 300, 300] lr 0.100000 9.442sec(train) 2.631sec(infer)
# Epoch 45 tst: l 0.316 a 0.911 clct[50, 50, 50, 50] 0.443sec
# Epoch 46 tr: l 0.314 a 0.907 clct[300, 300, 300, 300] lr 0.100000 8.156sec(train) 1.445sec(infer)
# Epoch 46 tst: l 0.314 a 0.911 clct[50, 50, 50, 50] 0.247sec
# Epoch 47 tr: l 0.312 a 0.907 clct[300, 300, 300, 300] lr 0.100000 5.245sec(train) 1.617sec(infer)
# Epoch 47 tst: l 0.313 a 0.912 clct[50, 50, 50, 50] 0.277sec
# Epoch 48 tr: l 0.311 a 0.908 clct[300, 300, 300, 300] lr 0.100000 5.284sec(train) 2.598sec(infer)
# Epoch 48 tst: l 0.311 a 0.912 clct[50, 50, 50, 50] 0.452sec
# Epoch 49 tr: l 0.309 a 0.908 clct[300, 300, 300, 300] lr 0.100000 9.892sec(train) 2.548sec(infer)
# Epoch 49 tst: l 0.310 a 0.913 clct[50, 50, 50, 50] 0.440sec
# Epoch 50 tr: l 0.307 a 0.909 clct[300, 300, 300, 300] lr 0.100000 9.489sec(train) 2.792sec(infer)
# Epoch 50 tst: l 0.308 a 0.913 clct[50, 50, 50, 50] 0.447sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 51 tr: l 0.306 a 0.909 clct[300, 300, 300, 300] lr 0.100000 9.001sec(train) 1.452sec(infer)
# Epoch 51 tst: l 0.307 a 0.914 clct[50, 50, 50, 50] 0.240sec
# Epoch 52 tr: l 0.304 a 0.910 clct[300, 300, 300, 300] lr 0.100000 4.937sec(train) 1.456sec(infer)
# Epoch 52 tst: l 0.305 a 0.914 clct[50, 50, 50, 50] 0.242sec
# Epoch 53 tr: l 0.303 a 0.910 clct[300, 300, 300, 300] lr 0.100000 4.532sec(train) 1.442sec(infer)
# Epoch 53 tst: l 0.304 a 0.914 clct[50, 50, 50, 50] 0.266sec
# Epoch 54 tr: l 0.301 a 0.910 clct[300, 300, 300, 300] lr 0.100000 5.193sec(train) 1.526sec(infer)
# Epoch 54 tst: l 0.303 a 0.915 clct[50, 50, 50, 50] 0.256sec
# Epoch 55 tr: l 0.300 a 0.911 clct[300, 300, 300, 300] lr 0.100000 8.658sec(train) 2.696sec(infer)
# Epoch 55 tst: l 0.301 a 0.915 clct[50, 50, 50, 50] 0.460sec
# Epoch 56 tr: l 0.298 a 0.911 clct[300, 300, 300, 300] lr 0.100000 9.652sec(train) 2.718sec(infer)
# Epoch 56 tst: l 0.300 a 0.916 clct[50, 50, 50, 50] 0.433sec
# Epoch 57 tr: l 0.297 a 0.912 clct[300, 300, 300, 300] lr 0.100000 9.690sec(train) 2.652sec(infer)
# Epoch 57 tst: l 0.299 a 0.916 clct[50, 50, 50, 50] 0.462sec
# Epoch 58 tr: l 0.295 a 0.912 clct[300, 300, 300, 300] lr 0.100000 9.706sec(train) 2.830sec(infer)
# Epoch 58 tst: l 0.298 a 0.917 clct[50, 50, 50, 50] 0.424sec
# Epoch 59 tr: l 0.294 a 0.912 clct[300, 300, 300, 300] lr 0.100000 9.169sec(train) 2.579sec(infer)
# Epoch 59 tst: l 0.296 a 0.917 clct[50, 50, 50, 50] 0.438sec
# Epoch 60 tr: l 0.293 a 0.913 clct[300, 300, 300, 300] lr 0.100000 9.271sec(train) 2.591sec(infer)
# Epoch 60 tst: l 0.295 a 0.917 clct[50, 50, 50, 50] 0.432sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 61 tr: l 0.291 a 0.913 clct[300, 300, 300, 300] lr 0.100000 9.246sec(train) 2.607sec(infer)
# Epoch 61 tst: l 0.294 a 0.918 clct[50, 50, 50, 50] 0.438sec
# Epoch 62 tr: l 0.290 a 0.914 clct[300, 300, 300, 300] lr 0.100000 9.161sec(train) 2.579sec(infer)
# Epoch 62 tst: l 0.293 a 0.918 clct[50, 50, 50, 50] 0.436sec
# Epoch 63 tr: l 0.289 a 0.914 clct[300, 300, 300, 300] lr 0.100000 9.258sec(train) 2.595sec(infer)
# Epoch 63 tst: l 0.292 a 0.918 clct[50, 50, 50, 50] 0.437sec
# Epoch 64 tr: l 0.287 a 0.914 clct[300, 300, 300, 300] lr 0.100000 9.225sec(train) 2.590sec(infer)
# Epoch 64 tst: l 0.291 a 0.918 clct[50, 50, 50, 50] 0.433sec
# Epoch 65 tr: l 0.286 a 0.915 clct[300, 300, 300, 300] lr 0.100000 9.294sec(train) 2.567sec(infer)
# Epoch 65 tst: l 0.290 a 0.919 clct[50, 50, 50, 50] 0.436sec
# Epoch 66 tr: l 0.285 a 0.915 clct[300, 300, 300, 300] lr 0.100000 9.611sec(train) 2.584sec(infer)
# Epoch 66 tst: l 0.289 a 0.919 clct[50, 50, 50, 50] 0.441sec
# Epoch 67 tr: l 0.284 a 0.915 clct[300, 300, 300, 300] lr 0.100000 9.152sec(train) 2.620sec(infer)
# Epoch 67 tst: l 0.288 a 0.920 clct[50, 50, 50, 50] 0.439sec
# Epoch 68 tr: l 0.282 a 0.916 clct[300, 300, 300, 300] lr 0.100000 9.308sec(train) 2.587sec(infer)
# Epoch 68 tst: l 0.287 a 0.920 clct[50, 50, 50, 50] 0.435sec
# Epoch 69 tr: l 0.281 a 0.916 clct[300, 300, 300, 300] lr 0.100000 9.315sec(train) 2.636sec(infer)
# Epoch 69 tst: l 0.285 a 0.920 clct[50, 50, 50, 50] 0.441sec
# Epoch 70 tr: l 0.280 a 0.917 clct[300, 300, 300, 300] lr 0.100000 9.199sec(train) 2.597sec(infer)
# Epoch 70 tst: l 0.284 a 0.921 clct[50, 50, 50, 50] 0.444sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 71 tr: l 0.279 a 0.917 clct[300, 300, 300, 300] lr 0.100000 9.472sec(train) 2.637sec(infer)
# Epoch 71 tst: l 0.283 a 0.921 clct[50, 50, 50, 50] 0.453sec
# Epoch 72 tr: l 0.278 a 0.917 clct[300, 300, 300, 300] lr 0.100000 6.163sec(train) 1.501sec(infer)
# Epoch 72 tst: l 0.282 a 0.921 clct[50, 50, 50, 50] 0.245sec
# Epoch 73 tr: l 0.277 a 0.918 clct[300, 300, 300, 300] lr 0.100000 4.698sec(train) 1.440sec(infer)
# Epoch 73 tst: l 0.281 a 0.921 clct[50, 50, 50, 50] 0.241sec
# Epoch 74 tr: l 0.275 a 0.918 clct[300, 300, 300, 300] lr 0.100000 4.616sec(train) 1.442sec(infer)
# Epoch 74 tst: l 0.281 a 0.922 clct[50, 50, 50, 50] 0.240sec
# Epoch 75 tr: l 0.274 a 0.918 clct[300, 300, 300, 300] lr 0.100000 4.829sec(train) 1.683sec(infer)
# Epoch 75 tst: l 0.280 a 0.922 clct[50, 50, 50, 50] 0.257sec
# Epoch 76 tr: l 0.273 a 0.919 clct[300, 300, 300, 300] lr 0.100000 7.384sec(train) 2.606sec(infer)
# Epoch 76 tst: l 0.279 a 0.922 clct[50, 50, 50, 50] 0.442sec
# Epoch 77 tr: l 0.272 a 0.919 clct[300, 300, 300, 300] lr 0.100000 10.564sec(train) 2.858sec(infer)
# Epoch 77 tst: l 0.278 a 0.922 clct[50, 50, 50, 50] 0.454sec
# Epoch 78 tr: l 0.271 a 0.919 clct[300, 300, 300, 300] lr 0.100000 9.821sec(train) 2.786sec(infer)
# Epoch 78 tst: l 0.277 a 0.923 clct[50, 50, 50, 50] 0.486sec
# Epoch 79 tr: l 0.270 a 0.920 clct[300, 300, 300, 300] lr 0.100000 10.199sec(train) 2.698sec(infer)
# Epoch 79 tst: l 0.276 a 0.923 clct[50, 50, 50, 50] 0.449sec
# Epoch 80 tr: l 0.269 a 0.920 clct[300, 300, 300, 300] lr 0.100000 9.660sec(train) 2.737sec(infer)
# Epoch 80 tst: l 0.275 a 0.924 clct[50, 50, 50, 50] 0.460sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 81 tr: l 0.268 a 0.920 clct[300, 300, 300, 300] lr 0.100000 9.776sec(train) 2.788sec(infer)
# Epoch 81 tst: l 0.274 a 0.924 clct[50, 50, 50, 50] 0.480sec
# Epoch 82 tr: l 0.267 a 0.921 clct[300, 300, 300, 300] lr 0.100000 9.889sec(train) 2.664sec(infer)
# Epoch 82 tst: l 0.273 a 0.924 clct[50, 50, 50, 50] 0.458sec
# Epoch 83 tr: l 0.266 a 0.921 clct[300, 300, 300, 300] lr 0.100000 9.674sec(train) 2.703sec(infer)
# Epoch 83 tst: l 0.272 a 0.924 clct[50, 50, 50, 50] 0.452sec
# Epoch 84 tr: l 0.265 a 0.921 clct[300, 300, 300, 300] lr 0.100000 9.716sec(train) 2.757sec(infer)
# Epoch 84 tst: l 0.271 a 0.925 clct[50, 50, 50, 50] 0.459sec
# Epoch 85 tr: l 0.264 a 0.922 clct[300, 300, 300, 300] lr 0.100000 9.755sec(train) 2.685sec(infer)
# Epoch 85 tst: l 0.270 a 0.925 clct[50, 50, 50, 50] 0.452sec
# Epoch 86 tr: l 0.263 a 0.922 clct[300, 300, 300, 300] lr 0.100000 9.649sec(train) 2.695sec(infer)
# Epoch 86 tst: l 0.269 a 0.925 clct[50, 50, 50, 50] 0.457sec
# Epoch 87 tr: l 0.262 a 0.922 clct[300, 300, 300, 300] lr 0.100000 9.817sec(train) 2.567sec(infer)
# Epoch 87 tst: l 0.269 a 0.925 clct[50, 50, 50, 50] 0.443sec
# Epoch 88 tr: l 0.261 a 0.923 clct[300, 300, 300, 300] lr 0.100000 9.882sec(train) 2.673sec(infer)
# Epoch 88 tst: l 0.268 a 0.926 clct[50, 50, 50, 50] 0.465sec
# Epoch 89 tr: l 0.260 a 0.923 clct[300, 300, 300, 300] lr 0.100000 9.709sec(train) 2.713sec(infer)
# Epoch 89 tst: l 0.267 a 0.926 clct[50, 50, 50, 50] 0.467sec
# Epoch 90 tr: l 0.259 a 0.923 clct[300, 300, 300, 300] lr 0.100000 10.081sec(train) 2.904sec(infer)
# Epoch 90 tst: l 0.266 a 0.926 clct[50, 50, 50, 50] 0.444sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 91 tr: l 0.258 a 0.923 clct[300, 300, 300, 300] lr 0.100000 10.167sec(train) 3.441sec(infer)
# Epoch 91 tst: l 0.265 a 0.926 clct[50, 50, 50, 50] 0.608sec
# Epoch 92 tr: l 0.257 a 0.923 clct[300, 300, 300, 300] lr 0.100000 12.204sec(train) 3.175sec(infer)
# Epoch 92 tst: l 0.264 a 0.927 clct[50, 50, 50, 50] 0.576sec
# Epoch 93 tr: l 0.256 a 0.924 clct[300, 300, 300, 300] lr 0.100000 12.791sec(train) 2.816sec(infer)
# Epoch 93 tst: l 0.264 a 0.927 clct[50, 50, 50, 50] 0.497sec
# Epoch 94 tr: l 0.255 a 0.924 clct[300, 300, 300, 300] lr 0.100000 12.414sec(train) 3.094sec(infer)
# Epoch 94 tst: l 0.263 a 0.927 clct[50, 50, 50, 50] 0.499sec
# Epoch 95 tr: l 0.254 a 0.924 clct[300, 300, 300, 300] lr 0.100000 10.992sec(train) 3.158sec(infer)
# Epoch 95 tst: l 0.262 a 0.927 clct[50, 50, 50, 50] 0.519sec
# Epoch 96 tr: l 0.253 a 0.925 clct[300, 300, 300, 300] lr 0.100000 12.170sec(train) 2.709sec(infer)
# Epoch 96 tst: l 0.261 a 0.928 clct[50, 50, 50, 50] 0.554sec
# Epoch 97 tr: l 0.252 a 0.925 clct[300, 300, 300, 300] lr 0.100000 11.171sec(train) 3.214sec(infer)
# Epoch 97 tst: l 0.260 a 0.928 clct[50, 50, 50, 50] 0.482sec
# Epoch 98 tr: l 0.251 a 0.925 clct[300, 300, 300, 300] lr 0.100000 12.045sec(train) 3.096sec(infer)
# Epoch 98 tst: l 0.260 a 0.928 clct[50, 50, 50, 50] 0.525sec
# Epoch 99 tr: l 0.250 a 0.925 clct[300, 300, 300, 300] lr 0.100000 12.181sec(train) 3.292sec(infer)
# Epoch 99 tst: l 0.259 a 0.928 clct[50, 50, 50, 50] 0.550sec
# Epoch 100 tr: l 0.249 a 0.926 clct[300, 300, 300, 300] lr 0.100000 12.005sec(train) 3.283sec(infer)
# Epoch 100 tst: l 0.258 a 0.928 clct[50, 50, 50, 50] 0.539sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 101 tr: l 0.249 a 0.926 clct[300, 300, 300, 300] lr 0.100000 11.977sec(train) 2.725sec(infer)
# Epoch 101 tst: l 0.257 a 0.929 clct[50, 50, 50, 50] 0.456sec
# Epoch 102 tr: l 0.248 a 0.926 clct[300, 300, 300, 300] lr 0.100000 9.802sec(train) 2.701sec(infer)
# Epoch 102 tst: l 0.256 a 0.929 clct[50, 50, 50, 50] 0.525sec
# Epoch 103 tr: l 0.247 a 0.926 clct[300, 300, 300, 300] lr 0.100000 13.061sec(train) 3.461sec(infer)
# Epoch 103 tst: l 0.256 a 0.929 clct[50, 50, 50, 50] 0.552sec
# Epoch 104 tr: l 0.246 a 0.927 clct[300, 300, 300, 300] lr 0.100000 12.888sec(train) 2.713sec(infer)
# Epoch 104 tst: l 0.255 a 0.929 clct[50, 50, 50, 50] 0.461sec
# Epoch 105 tr: l 0.245 a 0.927 clct[300, 300, 300, 300] lr 0.100000 10.522sec(train) 2.766sec(infer)
# Epoch 105 tst: l 0.254 a 0.929 clct[50, 50, 50, 50] 0.426sec
# Epoch 106 tr: l 0.244 a 0.927 clct[300, 300, 300, 300] lr 0.100000 10.028sec(train) 2.709sec(infer)
# Epoch 106 tst: l 0.253 a 0.929 clct[50, 50, 50, 50] 0.475sec
# Epoch 107 tr: l 0.243 a 0.927 clct[300, 300, 300, 300] lr 0.100000 10.050sec(train) 2.559sec(infer)
# Epoch 107 tst: l 0.253 a 0.930 clct[50, 50, 50, 50] 0.438sec
# Epoch 108 tr: l 0.242 a 0.928 clct[300, 300, 300, 300] lr 0.100000 9.948sec(train) 1.827sec(infer)
# Epoch 108 tst: l 0.252 a 0.930 clct[50, 50, 50, 50] 0.240sec
# Epoch 109 tr: l 0.242 a 0.928 clct[300, 300, 300, 300] lr 0.100000 4.874sec(train) 1.477sec(infer)
# Epoch 109 tst: l 0.251 a 0.930 clct[50, 50, 50, 50] 0.245sec
# Epoch 110 tr: l 0.241 a 0.928 clct[300, 300, 300, 300] lr 0.100000 4.561sec(train) 1.458sec(infer)
# Epoch 110 tst: l 0.250 a 0.930 clct[50, 50, 50, 50] 0.244sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 111 tr: l 0.240 a 0.928 clct[300, 300, 300, 300] lr 0.100000 8.636sec(train) 2.775sec(infer)
# Epoch 111 tst: l 0.250 a 0.930 clct[50, 50, 50, 50] 0.436sec
# Epoch 112 tr: l 0.239 a 0.929 clct[300, 300, 300, 300] lr 0.100000 9.371sec(train) 2.675sec(infer)
# Epoch 112 tst: l 0.249 a 0.931 clct[50, 50, 50, 50] 0.449sec
# Epoch 113 tr: l 0.238 a 0.929 clct[300, 300, 300, 300] lr 0.100000 9.563sec(train) 2.628sec(infer)
# Epoch 113 tst: l 0.248 a 0.931 clct[50, 50, 50, 50] 0.467sec
# Epoch 114 tr: l 0.237 a 0.929 clct[300, 300, 300, 300] lr 0.100000 9.496sec(train) 2.678sec(infer)
# Epoch 114 tst: l 0.248 a 0.931 clct[50, 50, 50, 50] 0.461sec
# Epoch 115 tr: l 0.237 a 0.929 clct[300, 300, 300, 300] lr 0.100000 9.449sec(train) 2.646sec(infer)
# Epoch 115 tst: l 0.247 a 0.931 clct[50, 50, 50, 50] 0.425sec
# Epoch 116 tr: l 0.236 a 0.930 clct[300, 300, 300, 300] lr 0.100000 9.510sec(train) 2.622sec(infer)
# Epoch 116 tst: l 0.246 a 0.931 clct[50, 50, 50, 50] 0.446sec
# Epoch 117 tr: l 0.235 a 0.930 clct[300, 300, 300, 300] lr 0.100000 9.637sec(train) 2.675sec(infer)
# Epoch 117 tst: l 0.245 a 0.932 clct[50, 50, 50, 50] 0.431sec
# Epoch 118 tr: l 0.234 a 0.930 clct[300, 300, 300, 300] lr 0.100000 9.738sec(train) 2.748sec(infer)
# Epoch 118 tst: l 0.245 a 0.932 clct[50, 50, 50, 50] 0.457sec
# Epoch 119 tr: l 0.233 a 0.930 clct[300, 300, 300, 300] lr 0.100000 9.700sec(train) 2.691sec(infer)
# Epoch 119 tst: l 0.244 a 0.932 clct[50, 50, 50, 50] 0.447sec
# Epoch 120 tr: l 0.233 a 0.931 clct[300, 300, 300, 300] lr 0.100000 9.518sec(train) 2.650sec(infer)
# Epoch 120 tst: l 0.243 a 0.932 clct[50, 50, 50, 50] 0.449sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 121 tr: l 0.232 a 0.931 clct[300, 300, 300, 300] lr 0.100000 9.725sec(train) 2.623sec(infer)
# Epoch 121 tst: l 0.243 a 0.932 clct[50, 50, 50, 50] 0.450sec
# Epoch 122 tr: l 0.231 a 0.931 clct[300, 300, 300, 300] lr 0.100000 9.465sec(train) 2.645sec(infer)
# Epoch 122 tst: l 0.242 a 0.932 clct[50, 50, 50, 50] 0.445sec
# Epoch 123 tr: l 0.230 a 0.931 clct[300, 300, 300, 300] lr 0.100000 9.562sec(train) 2.638sec(infer)
# Epoch 123 tst: l 0.241 a 0.933 clct[50, 50, 50, 50] 0.446sec
# Epoch 124 tr: l 0.230 a 0.932 clct[300, 300, 300, 300] lr 0.100000 9.369sec(train) 2.659sec(infer)
# Epoch 124 tst: l 0.241 a 0.933 clct[50, 50, 50, 50] 0.448sec
# Epoch 125 tr: l 0.229 a 0.932 clct[300, 300, 300, 300] lr 0.100000 9.658sec(train) 2.632sec(infer)
# Epoch 125 tst: l 0.240 a 0.933 clct[50, 50, 50, 50] 0.450sec
# Epoch 126 tr: l 0.228 a 0.932 clct[300, 300, 300, 300] lr 0.100000 9.566sec(train) 2.628sec(infer)
# Epoch 126 tst: l 0.239 a 0.933 clct[50, 50, 50, 50] 0.451sec
# Epoch 127 tr: l 0.227 a 0.932 clct[300, 300, 300, 300] lr 0.100000 9.657sec(train) 2.755sec(infer)
# Epoch 127 tst: l 0.239 a 0.933 clct[50, 50, 50, 50] 0.366sec
# Epoch 128 tr: l 0.227 a 0.933 clct[300, 300, 300, 300] lr 0.100000 4.690sec(train) 1.719sec(infer)
# Epoch 128 tst: l 0.238 a 0.933 clct[50, 50, 50, 50] 0.267sec
# Epoch 129 tr: l 0.226 a 0.933 clct[300, 300, 300, 300] lr 0.100000 6.591sec(train) 2.685sec(infer)
# Epoch 129 tst: l 0.237 a 0.934 clct[50, 50, 50, 50] 0.448sec
# Epoch 130 tr: l 0.225 a 0.933 clct[300, 300, 300, 300] lr 0.100000 9.586sec(train) 2.669sec(infer)
# Epoch 130 tst: l 0.237 a 0.934 clct[50, 50, 50, 50] 0.460sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 131 tr: l 0.224 a 0.933 clct[300, 300, 300, 300] lr 0.100000 9.688sec(train) 2.636sec(infer)
# Epoch 131 tst: l 0.236 a 0.934 clct[50, 50, 50, 50] 0.448sec
# Epoch 132 tr: l 0.224 a 0.933 clct[300, 300, 300, 300] lr 0.100000 9.710sec(train) 2.699sec(infer)
# Epoch 132 tst: l 0.236 a 0.934 clct[50, 50, 50, 50] 0.456sec
# Epoch 133 tr: l 0.223 a 0.934 clct[300, 300, 300, 300] lr 0.100000 9.555sec(train) 2.747sec(infer)
# Epoch 133 tst: l 0.235 a 0.934 clct[50, 50, 50, 50] 0.442sec
# Epoch 134 tr: l 0.222 a 0.934 clct[300, 300, 300, 300] lr 0.100000 9.749sec(train) 2.688sec(infer)
# Epoch 134 tst: l 0.234 a 0.934 clct[50, 50, 50, 50] 0.453sec
# Epoch 135 tr: l 0.221 a 0.934 clct[300, 300, 300, 300] lr 0.100000 10.151sec(train) 2.664sec(infer)
# Epoch 135 tst: l 0.234 a 0.935 clct[50, 50, 50, 50] 0.448sec
# Epoch 136 tr: l 0.221 a 0.934 clct[300, 300, 300, 300] lr 0.100000 10.083sec(train) 2.796sec(infer)
# Epoch 136 tst: l 0.233 a 0.935 clct[50, 50, 50, 50] 0.457sec
# Epoch 137 tr: l 0.220 a 0.935 clct[300, 300, 300, 300] lr 0.100000 9.711sec(train) 4.113sec(infer)
# Epoch 137 tst: l 0.232 a 0.935 clct[50, 50, 50, 50] 0.469sec
# Epoch 138 tr: l 0.219 a 0.935 clct[300, 300, 300, 300] lr 0.100000 9.567sec(train) 2.669sec(infer)
# Epoch 138 tst: l 0.232 a 0.935 clct[50, 50, 50, 50] 0.450sec
# Epoch 139 tr: l 0.219 a 0.935 clct[300, 300, 300, 300] lr 0.100000 10.066sec(train) 2.812sec(infer)
# Epoch 139 tst: l 0.231 a 0.935 clct[50, 50, 50, 50] 0.428sec
# Epoch 140 tr: l 0.218 a 0.935 clct[300, 300, 300, 300] lr 0.100000 10.006sec(train) 2.880sec(infer)
# Epoch 140 tst: l 0.231 a 0.935 clct[50, 50, 50, 50] 0.444sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 141 tr: l 0.217 a 0.935 clct[300, 300, 300, 300] lr 0.100000 9.526sec(train) 2.632sec(infer)
# Epoch 141 tst: l 0.230 a 0.935 clct[50, 50, 50, 50] 0.445sec
# Epoch 142 tr: l 0.217 a 0.936 clct[300, 300, 300, 300] lr 0.100000 10.438sec(train) 2.741sec(infer)
# Epoch 142 tst: l 0.229 a 0.936 clct[50, 50, 50, 50] 0.467sec
# Epoch 143 tr: l 0.216 a 0.936 clct[300, 300, 300, 300] lr 0.100000 10.227sec(train) 2.749sec(infer)
# Epoch 143 tst: l 0.229 a 0.936 clct[50, 50, 50, 50] 0.444sec
# Epoch 144 tr: l 0.215 a 0.936 clct[300, 300, 300, 300] lr 0.100000 9.837sec(train) 2.762sec(infer)
# Epoch 144 tst: l 0.228 a 0.936 clct[50, 50, 50, 50] 0.431sec
# Epoch 145 tr: l 0.215 a 0.936 clct[300, 300, 300, 300] lr 0.100000 9.952sec(train) 2.623sec(infer)
# Epoch 145 tst: l 0.228 a 0.936 clct[50, 50, 50, 50] 0.443sec
# Epoch 146 tr: l 0.214 a 0.936 clct[300, 300, 300, 300] lr 0.100000 9.671sec(train) 2.646sec(infer)
# Epoch 146 tst: l 0.227 a 0.936 clct[50, 50, 50, 50] 0.453sec
# Epoch 147 tr: l 0.213 a 0.937 clct[300, 300, 300, 300] lr 0.100000 9.580sec(train) 2.667sec(infer)
# Epoch 147 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] 0.460sec
# Epoch 148 tr: l 0.213 a 0.937 clct[300, 300, 300, 300] lr 0.100000 8.498sec(train) 1.490sec(infer)
# Epoch 148 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] 0.244sec
# Epoch 149 tr: l 0.212 a 0.937 clct[300, 300, 300, 300] lr 0.100000 4.576sec(train) 1.451sec(infer)
# Epoch 149 tst: l 0.225 a 0.937 clct[50, 50, 50, 50] 0.242sec
# Epoch 150 tr: l 0.211 a 0.937 clct[300, 300, 300, 300] lr 0.100000 4.609sec(train) 1.439sec(infer)
# Epoch 150 tst: l 0.225 a 0.937 clct[50, 50, 50, 50] 0.243sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 151 tr: l 0.211 a 0.937 clct[300, 300, 300, 300] lr 0.100000 4.759sec(train) 1.516sec(infer)
# Epoch 151 tst: l 0.224 a 0.937 clct[50, 50, 50, 50] 0.249sec
# Epoch 152 tr: l 0.210 a 0.937 clct[300, 300, 300, 300] lr 0.100000 5.074sec(train) 1.536sec(infer)
# Epoch 152 tst: l 0.223 a 0.937 clct[50, 50, 50, 50] 0.256sec
# Epoch 153 tr: l 0.209 a 0.938 clct[300, 300, 300, 300] lr 0.100000 8.721sec(train) 2.647sec(infer)
# Epoch 153 tst: l 0.223 a 0.937 clct[50, 50, 50, 50] 0.477sec
# Epoch 154 tr: l 0.209 a 0.938 clct[300, 300, 300, 300] lr 0.100000 10.032sec(train) 2.710sec(infer)
# Epoch 154 tst: l 0.222 a 0.937 clct[50, 50, 50, 50] 0.473sec
# Epoch 155 tr: l 0.208 a 0.938 clct[300, 300, 300, 300] lr 0.100000 10.059sec(train) 2.749sec(infer)
# Epoch 155 tst: l 0.222 a 0.938 clct[50, 50, 50, 50] 0.465sec
# Epoch 156 tr: l 0.207 a 0.938 clct[300, 300, 300, 300] lr 0.100000 10.082sec(train) 2.655sec(infer)
# Epoch 156 tst: l 0.221 a 0.938 clct[50, 50, 50, 50] 0.475sec
# Epoch 157 tr: l 0.207 a 0.938 clct[300, 300, 300, 300] lr 0.100000 9.954sec(train) 2.601sec(infer)
# Epoch 157 tst: l 0.221 a 0.938 clct[50, 50, 50, 50] 0.445sec
# Epoch 158 tr: l 0.206 a 0.939 clct[300, 300, 300, 300] lr 0.100000 9.457sec(train) 2.626sec(infer)
# Epoch 158 tst: l 0.220 a 0.938 clct[50, 50, 50, 50] 0.440sec
# Epoch 159 tr: l 0.206 a 0.939 clct[300, 300, 300, 300] lr 0.100000 9.595sec(train) 2.668sec(infer)
# Epoch 159 tst: l 0.220 a 0.938 clct[50, 50, 50, 50] 0.446sec
# Epoch 160 tr: l 0.205 a 0.939 clct[300, 300, 300, 300] lr 0.100000 9.752sec(train) 2.712sec(infer)
# Epoch 160 tst: l 0.219 a 0.938 clct[50, 50, 50, 50] 0.465sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 161 tr: l 0.204 a 0.939 clct[300, 300, 300, 300] lr 0.100000 9.761sec(train) 2.649sec(infer)
# Epoch 161 tst: l 0.218 a 0.939 clct[50, 50, 50, 50] 0.446sec
# Epoch 162 tr: l 0.204 a 0.939 clct[300, 300, 300, 300] lr 0.100000 9.674sec(train) 2.718sec(infer)
# Epoch 162 tst: l 0.218 a 0.939 clct[50, 50, 50, 50] 0.403sec
# Epoch 163 tr: l 0.203 a 0.939 clct[300, 300, 300, 300] lr 0.100000 5.530sec(train) 1.415sec(infer)
# Epoch 163 tst: l 0.217 a 0.939 clct[50, 50, 50, 50] 0.238sec
# Epoch 164 tr: l 0.202 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.334sec(train) 1.415sec(infer)
# Epoch 164 tst: l 0.217 a 0.939 clct[50, 50, 50, 50] 0.237sec
# Epoch 165 tr: l 0.202 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.410sec(train) 1.416sec(infer)
# Epoch 165 tst: l 0.216 a 0.939 clct[50, 50, 50, 50] 0.236sec
# Epoch 166 tr: l 0.201 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.380sec(train) 1.435sec(infer)
# Epoch 166 tst: l 0.216 a 0.939 clct[50, 50, 50, 50] 0.237sec
# Epoch 167 tr: l 0.201 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.378sec(train) 1.409sec(infer)
# Epoch 167 tst: l 0.215 a 0.939 clct[50, 50, 50, 50] 0.236sec
# Epoch 168 tr: l 0.200 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.415sec(train) 1.418sec(infer)
# Epoch 168 tst: l 0.215 a 0.939 clct[50, 50, 50, 50] 0.238sec
# Epoch 169 tr: l 0.200 a 0.940 clct[300, 300, 300, 300] lr 0.100000 4.415sec(train) 1.416sec(infer)
# Epoch 169 tst: l 0.214 a 0.939 clct[50, 50, 50, 50] 0.237sec
# Epoch 170 tr: l 0.199 a 0.941 clct[300, 300, 300, 300] lr 0.100000 4.363sec(train) 1.434sec(infer)
# Epoch 170 tst: l 0.214 a 0.939 clct[50, 50, 50, 50] 0.241sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 171 tr: l 0.198 a 0.941 clct[300, 300, 300, 300] lr 0.100000 4.587sec(train) 1.565sec(infer)
# Epoch 171 tst: l 0.213 a 0.940 clct[50, 50, 50, 50] 0.263sec
# Epoch 172 tr: l 0.198 a 0.941 clct[300, 300, 300, 300] lr 0.100000 5.165sec(train) 1.483sec(infer)
# Epoch 172 tst: l 0.213 a 0.940 clct[50, 50, 50, 50] 0.253sec
# Epoch 173 tr: l 0.197 a 0.941 clct[300, 300, 300, 300] lr 0.100000 5.192sec(train) 1.743sec(infer)
# Epoch 173 tst: l 0.212 a 0.940 clct[50, 50, 50, 50] 0.264sec
# Epoch 174 tr: l 0.197 a 0.941 clct[300, 300, 300, 300] lr 0.100000 5.096sec(train) 1.808sec(infer)
# Epoch 174 tst: l 0.212 a 0.940 clct[50, 50, 50, 50] 0.435sec
# Epoch 175 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 9.594sec(train) 2.822sec(infer)
# Epoch 175 tst: l 0.211 a 0.940 clct[50, 50, 50, 50] 0.451sec
# Epoch 176 tr: l 0.196 a 0.941 clct[300, 300, 300, 300] lr 0.100000 9.582sec(train) 2.675sec(infer)
# Epoch 176 tst: l 0.211 a 0.940 clct[50, 50, 50, 50] 0.438sec
# Epoch 177 tr: l 0.195 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.638sec(train) 2.657sec(infer)
# Epoch 177 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.447sec
# Epoch 178 tr: l 0.194 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.484sec(train) 2.637sec(infer)
# Epoch 178 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] 0.450sec
# Epoch 179 tr: l 0.194 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.625sec(train) 2.652sec(infer)
# Epoch 179 tst: l 0.209 a 0.940 clct[50, 50, 50, 50] 0.451sec
# Epoch 180 tr: l 0.193 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.620sec(train) 2.667sec(infer)
# Epoch 180 tst: l 0.209 a 0.940 clct[50, 50, 50, 50] 0.454sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 181 tr: l 0.193 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.643sec(train) 2.675sec(infer)
# Epoch 181 tst: l 0.208 a 0.941 clct[50, 50, 50, 50] 0.445sec
# Epoch 182 tr: l 0.192 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.439sec(train) 2.659sec(infer)
# Epoch 182 tst: l 0.208 a 0.941 clct[50, 50, 50, 50] 0.455sec
# Epoch 183 tr: l 0.192 a 0.942 clct[300, 300, 300, 300] lr 0.100000 9.618sec(train) 2.668sec(infer)
# Epoch 183 tst: l 0.207 a 0.941 clct[50, 50, 50, 50] 0.442sec
# Epoch 184 tr: l 0.191 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.579sec(train) 2.605sec(infer)
# Epoch 184 tst: l 0.207 a 0.941 clct[50, 50, 50, 50] 0.445sec
# Epoch 185 tr: l 0.191 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.609sec(train) 2.638sec(infer)
# Epoch 185 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] 0.447sec
# Epoch 186 tr: l 0.190 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.642sec(train) 2.668sec(infer)
# Epoch 186 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] 0.447sec
# Epoch 187 tr: l 0.190 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.702sec(train) 2.657sec(infer)
# Epoch 187 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] 0.458sec
# Epoch 188 tr: l 0.189 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.527sec(train) 2.815sec(infer)
# Epoch 188 tst: l 0.205 a 0.942 clct[50, 50, 50, 50] 0.510sec
# Epoch 189 tr: l 0.189 a 0.943 clct[300, 300, 300, 300] lr 0.100000 10.089sec(train) 2.573sec(infer)
# Epoch 189 tst: l 0.204 a 0.942 clct[50, 50, 50, 50] 0.421sec
# Epoch 190 tr: l 0.188 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.485sec(train) 2.717sec(infer)
# Epoch 190 tst: l 0.204 a 0.942 clct[50, 50, 50, 50] 0.454sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 191 tr: l 0.187 a 0.943 clct[300, 300, 300, 300] lr 0.100000 9.898sec(train) 2.629sec(infer)
# Epoch 191 tst: l 0.203 a 0.942 clct[50, 50, 50, 50] 0.444sec
# Epoch 192 tr: l 0.187 a 0.944 clct[300, 300, 300, 300] lr 0.100000 10.727sec(train) 2.753sec(infer)
# Epoch 192 tst: l 0.203 a 0.942 clct[50, 50, 50, 50] 0.491sec
# Epoch 193 tr: l 0.186 a 0.944 clct[300, 300, 300, 300] lr 0.100000 9.559sec(train) 2.566sec(infer)
# Epoch 193 tst: l 0.203 a 0.942 clct[50, 50, 50, 50] 0.439sec
# Epoch 194 tr: l 0.186 a 0.944 clct[300, 300, 300, 300] lr 0.100000 9.465sec(train) 2.692sec(infer)
# Epoch 194 tst: l 0.202 a 0.942 clct[50, 50, 50, 50] 0.427sec
# Epoch 195 tr: l 0.185 a 0.944 clct[300, 300, 300, 300] lr 0.100000 9.365sec(train) 2.576sec(infer)
# Epoch 195 tst: l 0.202 a 0.942 clct[50, 50, 50, 50] 0.426sec
# Epoch 196 tr: l 0.185 a 0.944 clct[300, 300, 300, 300] lr 0.100000 9.534sec(train) 2.640sec(infer)
# Epoch 196 tst: l 0.201 a 0.943 clct[50, 50, 50, 50] 0.440sec
# Epoch 197 tr: l 0.184 a 0.944 clct[300, 300, 300, 300] lr 0.100000 9.546sec(train) 2.619sec(infer)
# Epoch 197 tst: l 0.201 a 0.943 clct[50, 50, 50, 50] 0.480sec
# Epoch 198 tr: l 0.184 a 0.945 clct[300, 300, 300, 300] lr 0.100000 7.593sec(train) 1.452sec(infer)
# Epoch 198 tst: l 0.200 a 0.943 clct[50, 50, 50, 50] 0.239sec
# Epoch 199 tr: l 0.183 a 0.945 clct[300, 300, 300, 300] lr 0.100000 4.723sec(train) 1.492sec(infer)
# Epoch 199 tst: l 0.200 a 0.943 clct[50, 50, 50, 50] 0.287sec
# Epoch 200 tr: l 0.183 a 0.945 clct[300, 300, 300, 300] lr 0.100000 5.159sec(train) 2.462sec(infer)
# Epoch 200 tst: l 0.199 a 0.943 clct[50, 50, 50, 50] 0.429sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 201 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] lr 0.100000 9.449sec(train) 2.796sec(infer)
# Epoch 201 tst: l 0.199 a 0.943 clct[50, 50, 50, 50] 0.432sec
# Epoch 202 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] lr 0.100000 9.503sec(train) 2.562sec(infer)
# Epoch 202 tst: l 0.199 a 0.943 clct[50, 50, 50, 50] 0.481sec
# Epoch 203 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] lr 0.100000 9.389sec(train) 2.633sec(infer)
# Epoch 203 tst: l 0.198 a 0.943 clct[50, 50, 50, 50] 0.439sec
# Epoch 204 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] lr 0.100000 9.467sec(train) 2.615sec(infer)
# Epoch 204 tst: l 0.198 a 0.944 clct[50, 50, 50, 50] 0.423sec
# Epoch 205 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] lr 0.100000 9.626sec(train) 1.663sec(infer)
# Epoch 205 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.257sec
# Epoch 206 tr: l 0.180 a 0.945 clct[300, 300, 300, 300] lr 0.100000 4.637sec(train) 1.426sec(infer)
# Epoch 206 tst: l 0.197 a 0.944 clct[50, 50, 50, 50] 0.239sec
# Epoch 207 tr: l 0.180 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.507sec(train) 1.465sec(infer)
# Epoch 207 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.239sec
# Epoch 208 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.588sec(train) 1.479sec(infer)
# Epoch 208 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.239sec
# Epoch 209 tr: l 0.179 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.896sec(train) 1.475sec(infer)
# Epoch 209 tst: l 0.196 a 0.944 clct[50, 50, 50, 50] 0.246sec
# Epoch 210 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.608sec(train) 1.479sec(infer)
# Epoch 210 tst: l 0.195 a 0.944 clct[50, 50, 50, 50] 0.245sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 211 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.891sec(train) 1.472sec(infer)
# Epoch 211 tst: l 0.195 a 0.944 clct[50, 50, 50, 50] 0.237sec
# Epoch 212 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.867sec(train) 1.454sec(infer)
# Epoch 212 tst: l 0.194 a 0.944 clct[50, 50, 50, 50] 0.238sec
# Epoch 213 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.326sec(train) 1.416sec(infer)
# Epoch 213 tst: l 0.194 a 0.944 clct[50, 50, 50, 50] 0.247sec
# Epoch 214 tr: l 0.176 a 0.946 clct[300, 300, 300, 300] lr 0.100000 4.369sec(train) 1.420sec(infer)
# Epoch 214 tst: l 0.193 a 0.944 clct[50, 50, 50, 50] 0.242sec
# Epoch 215 tr: l 0.176 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.850sec(train) 1.504sec(infer)
# Epoch 215 tst: l 0.193 a 0.945 clct[50, 50, 50, 50] 0.240sec
# Epoch 216 tr: l 0.175 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.764sec(train) 1.475sec(infer)
# Epoch 216 tst: l 0.193 a 0.945 clct[50, 50, 50, 50] 0.244sec
# Epoch 217 tr: l 0.175 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.673sec(train) 1.477sec(infer)
# Epoch 217 tst: l 0.192 a 0.945 clct[50, 50, 50, 50] 0.251sec
# Epoch 218 tr: l 0.174 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.480sec(train) 1.443sec(infer)
# Epoch 218 tst: l 0.192 a 0.945 clct[50, 50, 50, 50] 0.253sec
# Epoch 219 tr: l 0.174 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.378sec(train) 1.445sec(infer)
# Epoch 219 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.237sec
# Epoch 220 tr: l 0.174 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.451sec(train) 1.470sec(infer)
# Epoch 220 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.239sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 221 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.399sec(train) 1.465sec(infer)
# Epoch 221 tst: l 0.191 a 0.945 clct[50, 50, 50, 50] 0.237sec
# Epoch 222 tr: l 0.173 a 0.947 clct[300, 300, 300, 300] lr 0.100000 4.704sec(train) 1.498sec(infer)
# Epoch 222 tst: l 0.190 a 0.945 clct[50, 50, 50, 50] 0.257sec
# Epoch 223 tr: l 0.172 a 0.948 clct[300, 300, 300, 300] lr 0.100000 6.385sec(train) 2.572sec(infer)
# Epoch 223 tst: l 0.190 a 0.946 clct[50, 50, 50, 50] 0.560sec
# Epoch 224 tr: l 0.172 a 0.948 clct[300, 300, 300, 300] lr 0.100000 10.077sec(train) 2.784sec(infer)
# Epoch 224 tst: l 0.190 a 0.946 clct[50, 50, 50, 50] 0.436sec
# Epoch 225 tr: l 0.171 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.189sec(train) 2.556sec(infer)
# Epoch 225 tst: l 0.189 a 0.946 clct[50, 50, 50, 50] 0.428sec
# Epoch 226 tr: l 0.171 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.448sec(train) 2.549sec(infer)
# Epoch 226 tst: l 0.189 a 0.946 clct[50, 50, 50, 50] 0.428sec
# Epoch 227 tr: l 0.170 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.368sec(train) 2.552sec(infer)
# Epoch 227 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.446sec
# Epoch 228 tr: l 0.170 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.254sec(train) 2.564sec(infer)
# Epoch 228 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.421sec
# Epoch 229 tr: l 0.170 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.360sec(train) 2.561sec(infer)
# Epoch 229 tst: l 0.188 a 0.946 clct[50, 50, 50, 50] 0.427sec
# Epoch 230 tr: l 0.169 a 0.948 clct[300, 300, 300, 300] lr 0.100000 9.230sec(train) 2.505sec(infer)
# Epoch 230 tst: l 0.187 a 0.946 clct[50, 50, 50, 50] 0.419sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 231 tr: l 0.169 a 0.949 clct[300, 300, 300, 300] lr 0.100000 9.374sec(train) 2.590sec(infer)
# Epoch 231 tst: l 0.187 a 0.946 clct[50, 50, 50, 50] 0.442sec
# Epoch 232 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 9.286sec(train) 2.677sec(infer)
# Epoch 232 tst: l 0.186 a 0.947 clct[50, 50, 50, 50] 0.426sec
# Epoch 233 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 6.191sec(train) 1.551sec(infer)
# Epoch 233 tst: l 0.186 a 0.947 clct[50, 50, 50, 50] 0.256sec
# Epoch 234 tr: l 0.168 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.669sec(train) 1.447sec(infer)
# Epoch 234 tst: l 0.186 a 0.947 clct[50, 50, 50, 50] 0.239sec
# Epoch 235 tr: l 0.167 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.579sec(train) 1.440sec(infer)
# Epoch 235 tst: l 0.185 a 0.947 clct[50, 50, 50, 50] 0.238sec
# Epoch 236 tr: l 0.167 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.633sec(train) 1.474sec(infer)
# Epoch 236 tst: l 0.185 a 0.947 clct[50, 50, 50, 50] 0.259sec
# Epoch 237 tr: l 0.166 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.868sec(train) 1.542sec(infer)
# Epoch 237 tst: l 0.185 a 0.947 clct[50, 50, 50, 50] 0.264sec
# Epoch 238 tr: l 0.166 a 0.949 clct[300, 300, 300, 300] lr 0.100000 5.233sec(train) 1.517sec(infer)
# Epoch 238 tst: l 0.184 a 0.947 clct[50, 50, 50, 50] 0.253sec
# Epoch 239 tr: l 0.165 a 0.949 clct[300, 300, 300, 300] lr 0.100000 5.085sec(train) 1.616sec(infer)
# Epoch 239 tst: l 0.184 a 0.947 clct[50, 50, 50, 50] 0.268sec
# Epoch 240 tr: l 0.165 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.730sec(train) 1.484sec(infer)
# Epoch 240 tst: l 0.184 a 0.947 clct[50, 50, 50, 50] 0.243sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 241 tr: l 0.165 a 0.949 clct[300, 300, 300, 300] lr 0.100000 4.708sec(train) 1.495sec(infer)
# Epoch 241 tst: l 0.183 a 0.948 clct[50, 50, 50, 50] 0.250sec
# Epoch 242 tr: l 0.164 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.916sec(train) 1.494sec(infer)
# Epoch 242 tst: l 0.183 a 0.948 clct[50, 50, 50, 50] 0.246sec
# Epoch 243 tr: l 0.164 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.602sec(train) 1.459sec(infer)
# Epoch 243 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.245sec
# Epoch 244 tr: l 0.163 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.672sec(train) 1.468sec(infer)
# Epoch 244 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.244sec
# Epoch 245 tr: l 0.163 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.570sec(train) 1.470sec(infer)
# Epoch 245 tst: l 0.182 a 0.948 clct[50, 50, 50, 50] 0.243sec
# Epoch 246 tr: l 0.163 a 0.950 clct[300, 300, 300, 300] lr 0.100000 5.066sec(train) 1.569sec(infer)
# Epoch 246 tst: l 0.181 a 0.948 clct[50, 50, 50, 50] 0.244sec
# Epoch 247 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 5.150sec(train) 1.566sec(infer)
# Epoch 247 tst: l 0.181 a 0.948 clct[50, 50, 50, 50] 0.267sec
# Epoch 248 tr: l 0.162 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.744sec(train) 1.502sec(infer)
# Epoch 248 tst: l 0.181 a 0.948 clct[50, 50, 50, 50] 0.244sec
# Epoch 249 tr: l 0.161 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.707sec(train) 1.492sec(infer)
# Epoch 249 tst: l 0.180 a 0.948 clct[50, 50, 50, 50] 0.259sec
# Epoch 250 tr: l 0.161 a 0.950 clct[300, 300, 300, 300] lr 0.100000 4.865sec(train) 1.460sec(infer)
# Epoch 250 tst: l 0.180 a 0.949 clct[50, 50, 50, 50] 0.245sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 251 tr: l 0.161 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.821sec(train) 1.482sec(infer)
# Epoch 251 tst: l 0.180 a 0.949 clct[50, 50, 50, 50] 0.259sec
# Epoch 252 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.726sec(train) 1.486sec(infer)
# Epoch 252 tst: l 0.179 a 0.949 clct[50, 50, 50, 50] 0.244sec
# Epoch 253 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.720sec(train) 1.454sec(infer)
# Epoch 253 tst: l 0.179 a 0.949 clct[50, 50, 50, 50] 0.246sec
# Epoch 254 tr: l 0.160 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.840sec(train) 1.496sec(infer)
# Epoch 254 tst: l 0.179 a 0.949 clct[50, 50, 50, 50] 0.243sec
# Epoch 255 tr: l 0.159 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.691sec(train) 1.454sec(infer)
# Epoch 255 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.244sec
# Epoch 256 tr: l 0.159 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.926sec(train) 1.450sec(infer)
# Epoch 256 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.245sec
# Epoch 257 tr: l 0.158 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.522sec(train) 1.458sec(infer)
# Epoch 257 tst: l 0.178 a 0.949 clct[50, 50, 50, 50] 0.245sec
# Epoch 258 tr: l 0.158 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.657sec(train) 1.473sec(infer)
# Epoch 258 tst: l 0.177 a 0.949 clct[50, 50, 50, 50] 0.247sec
# Epoch 259 tr: l 0.158 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.539sec(train) 1.499sec(infer)
# Epoch 259 tst: l 0.177 a 0.949 clct[50, 50, 50, 50] 0.244sec
# Epoch 260 tr: l 0.157 a 0.951 clct[300, 300, 300, 300] lr 0.100000 4.667sec(train) 1.466sec(infer)
# Epoch 260 tst: l 0.177 a 0.949 clct[50, 50, 50, 50] 0.244sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 261 tr: l 0.157 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.663sec(train) 1.485sec(infer)
# Epoch 261 tst: l 0.176 a 0.949 clct[50, 50, 50, 50] 0.247sec
# Epoch 262 tr: l 0.157 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.859sec(train) 1.527sec(infer)
# Epoch 262 tst: l 0.176 a 0.949 clct[50, 50, 50, 50] 0.249sec
# Epoch 263 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.625sec(train) 1.485sec(infer)
# Epoch 263 tst: l 0.176 a 0.949 clct[50, 50, 50, 50] 0.251sec
# Epoch 264 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.649sec(train) 1.480sec(infer)
# Epoch 264 tst: l 0.175 a 0.949 clct[50, 50, 50, 50] 0.272sec
# Epoch 265 tr: l 0.156 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.632sec(train) 1.514sec(infer)
# Epoch 265 tst: l 0.175 a 0.949 clct[50, 50, 50, 50] 0.246sec
# Epoch 266 tr: l 0.155 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.936sec(train) 1.600sec(infer)
# Epoch 266 tst: l 0.175 a 0.949 clct[50, 50, 50, 50] 0.274sec
# Epoch 267 tr: l 0.155 a 0.952 clct[300, 300, 300, 300] lr 0.100000 5.566sec(train) 2.488sec(infer)
# Epoch 267 tst: l 0.175 a 0.950 clct[50, 50, 50, 50] 0.388sec
# Epoch 268 tr: l 0.154 a 0.952 clct[300, 300, 300, 300] lr 0.100000 9.322sec(train) 2.646sec(infer)
# Epoch 268 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.466sec
# Epoch 269 tr: l 0.154 a 0.952 clct[300, 300, 300, 300] lr 0.100000 9.153sec(train) 2.365sec(infer)
# Epoch 269 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.259sec
# Epoch 270 tr: l 0.154 a 0.952 clct[300, 300, 300, 300] lr 0.100000 5.036sec(train) 1.479sec(infer)
# Epoch 270 tst: l 0.174 a 0.950 clct[50, 50, 50, 50] 0.246sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 271 tr: l 0.153 a 0.952 clct[300, 300, 300, 300] lr 0.100000 4.606sec(train) 1.508sec(infer)
# Epoch 271 tst: l 0.173 a 0.950 clct[50, 50, 50, 50] 0.248sec
# Epoch 272 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.824sec(train) 1.506sec(infer)
# Epoch 272 tst: l 0.173 a 0.950 clct[50, 50, 50, 50] 0.284sec
# Epoch 273 tr: l 0.153 a 0.953 clct[300, 300, 300, 300] lr 0.100000 5.029sec(train) 1.488sec(infer)
# Epoch 273 tst: l 0.173 a 0.950 clct[50, 50, 50, 50] 0.255sec
# Epoch 274 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.654sec(train) 1.477sec(infer)
# Epoch 274 tst: l 0.172 a 0.950 clct[50, 50, 50, 50] 0.246sec
# Epoch 275 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.660sec(train) 1.460sec(infer)
# Epoch 275 tst: l 0.172 a 0.950 clct[50, 50, 50, 50] 0.245sec
# Epoch 276 tr: l 0.152 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.700sec(train) 1.457sec(infer)
# Epoch 276 tst: l 0.172 a 0.950 clct[50, 50, 50, 50] 0.244sec
# Epoch 277 tr: l 0.151 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.536sec(train) 1.458sec(infer)
# Epoch 277 tst: l 0.171 a 0.950 clct[50, 50, 50, 50] 0.245sec
# Epoch 278 tr: l 0.151 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.663sec(train) 1.488sec(infer)
# Epoch 278 tst: l 0.171 a 0.950 clct[50, 50, 50, 50] 0.295sec
# Epoch 279 tr: l 0.151 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.905sec(train) 1.514sec(infer)
# Epoch 279 tst: l 0.171 a 0.951 clct[50, 50, 50, 50] 0.246sec
# Epoch 280 tr: l 0.150 a 0.953 clct[300, 300, 300, 300] lr 0.100000 4.676sec(train) 1.471sec(infer)
# Epoch 280 tst: l 0.171 a 0.951 clct[50, 50, 50, 50] 0.243sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 281 tr: l 0.150 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.584sec(train) 1.460sec(infer)
# Epoch 281 tst: l 0.170 a 0.951 clct[50, 50, 50, 50] 0.245sec
# Epoch 282 tr: l 0.150 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.610sec(train) 1.468sec(infer)
# Epoch 282 tst: l 0.170 a 0.951 clct[50, 50, 50, 50] 0.244sec
# Epoch 283 tr: l 0.149 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.557sec(train) 1.465sec(infer)
# Epoch 283 tst: l 0.170 a 0.951 clct[50, 50, 50, 50] 0.245sec
# Epoch 284 tr: l 0.149 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.643sec(train) 1.455sec(infer)
# Epoch 284 tst: l 0.169 a 0.951 clct[50, 50, 50, 50] 0.242sec
# Epoch 285 tr: l 0.149 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.651sec(train) 1.457sec(infer)
# Epoch 285 tst: l 0.169 a 0.951 clct[50, 50, 50, 50] 0.249sec
# Epoch 286 tr: l 0.148 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.617sec(train) 1.471sec(infer)
# Epoch 286 tst: l 0.169 a 0.951 clct[50, 50, 50, 50] 0.249sec
# Epoch 287 tr: l 0.148 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.569sec(train) 1.451sec(infer)
# Epoch 287 tst: l 0.168 a 0.951 clct[50, 50, 50, 50] 0.242sec
# Epoch 288 tr: l 0.148 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.655sec(train) 1.458sec(infer)
# Epoch 288 tst: l 0.168 a 0.951 clct[50, 50, 50, 50] 0.243sec
# Epoch 289 tr: l 0.147 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.565sec(train) 1.468sec(infer)
# Epoch 289 tst: l 0.168 a 0.951 clct[50, 50, 50, 50] 0.244sec
# Epoch 290 tr: l 0.147 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.625sec(train) 1.475sec(infer)
# Epoch 290 tst: l 0.168 a 0.951 clct[50, 50, 50, 50] 0.245sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 291 tr: l 0.147 a 0.954 clct[300, 300, 300, 300] lr 0.100000 4.643sec(train) 1.462sec(infer)
# Epoch 291 tst: l 0.167 a 0.951 clct[50, 50, 50, 50] 0.245sec
# Epoch 292 tr: l 0.146 a 0.955 clct[300, 300, 300, 300] lr 0.100000 4.688sec(train) 1.466sec(infer)
# Epoch 292 tst: l 0.167 a 0.952 clct[50, 50, 50, 50] 0.242sec
# Epoch 293 tr: l 0.146 a 0.955 clct[300, 300, 300, 300] lr 0.100000 4.639sec(train) 1.510sec(infer)
# Epoch 293 tst: l 0.167 a 0.952 clct[50, 50, 50, 50] 0.248sec
# Epoch 294 tr: l 0.146 a 0.955 clct[300, 300, 300, 300] lr 0.100000 4.978sec(train) 1.612sec(infer)
# Epoch 294 tst: l 0.166 a 0.952 clct[50, 50, 50, 50] 0.255sec
# Epoch 295 tr: l 0.145 a 0.955 clct[300, 300, 300, 300] lr 0.100000 5.049sec(train) 1.563sec(infer)
# Epoch 295 tst: l 0.166 a 0.952 clct[50, 50, 50, 50] 0.242sec
# Epoch 296 tr: l 0.145 a 0.955 clct[300, 300, 300, 300] lr 0.100000 5.030sec(train) 1.480sec(infer)
# Epoch 296 tst: l 0.166 a 0.952 clct[50, 50, 50, 50] 0.241sec
# Epoch 297 tr: l 0.145 a 0.955 clct[300, 300, 300, 300] lr 0.100000 5.091sec(train) 1.436sec(infer)
# Epoch 297 tst: l 0.166 a 0.952 clct[50, 50, 50, 50] 0.248sec
# Epoch 298 tr: l 0.144 a 0.955 clct[300, 300, 300, 300] lr 0.100000 4.617sec(train) 1.432sec(infer)
# Epoch 298 tst: l 0.165 a 0.952 clct[50, 50, 50, 50] 0.261sec
# Epoch 299 tr: l 0.144 a 0.955 clct[300, 300, 300, 300] lr 0.100000 4.532sec(train) 1.433sec(infer)
# Epoch 299 tst: l 0.165 a 0.952 clct[50, 50, 50, 50] 0.245sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# ---train cluster Ended in 0.82 hour (2959.727 sec)
