# %%
import argparse
import json
import os
import time
import itertools
import pickle
import copy
import random
import math

import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset, TensorDataset
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import confusion_matrix

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config.json

# %%
LR_DECAY = False
def get_config():

    # read config json and update the sysarg
    with open("config.json", "r") as read_file:
        config = json.load(read_file)

    if config["config_override"] == "":
        del config['config_override']
    else:
        print(config['config_override'])
        config_override = json.loads(config['config_override'])
        del config['config_override']
        config.update(config_override)

    return config

# %% [markdown]
# Class SimpleLinear with simple MLP for MNIST Classification

# %%
class SimpleLinear(torch.nn.Module):

    def __init__(self, h1=2048):
        super().__init__()
        self.fc1 = torch.nn.Linear(28*28, h1)
        self.fc2 = torch.nn.Linear(h1, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        # x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

    # def weight(self):
    #     return self.linear1.weight

# %% [markdown]
# Class TrainMNISTCluster with all the methods needed to run the experiments

# %%
class TrainMNISTCluster(object):
    def __init__(self, config, device):
        self.config = config
        self.device = device

        assert self.config['m'] % self.config['p'] == 0

    def setup(self):

        os.makedirs(self.config['project_dir'], exist_ok = True)

        self.result_fname = os.path.join(self.config['project_dir'], 'results.pickle')
        self.checkpoint_fname = os.path.join(self.config['project_dir'], 'checkpoint.pt')

        self.setup_datasets()
        self.setup_models()

        self.epoch = None
        self.lr = None
        #self.cluster_switch = None


    def setup_datasets(self):

        np.random.seed(self.config['data_seed'])

        # generate indices for each dataset
        # also write cluster info

        MNIST_TRAINSET_DATA_SIZE = 60000
        MNIST_TESTSET_DATA_SIZE = 10000

        np.random.seed(self.config['data_seed'])

        cfg = self.config

        self.dataset = {}

        if cfg['uneven'] == True:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset_random_n(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        else:
            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TRAINSET_DATA_SIZE, cfg['p'], cfg['m'], cfg['n'])
            (X, y) = self._load_MNIST(train=True)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['train'] = dataset

            dataset = {}
            dataset['data_indices'], dataset['cluster_assign'] = \
                self._setup_dataset(MNIST_TESTSET_DATA_SIZE, cfg['p'], cfg['m_test'], cfg['n'], random=True)
            (X, y) = self._load_MNIST(train=False)
            dataset['X'] = X
            dataset['y'] = y
            self.dataset['test'] = dataset

        # import ipdb; ipdb.set_trace()


    def _setup_dataset_random_n(self, num_data, p, m, n, random = True):

        print("m:",m)
        print("p:",p)
        print("num_data:",num_data)

        dataset = {}

        cfg = self.config

        data_indices = []
        cluster_assign = []

        m_per_cluster = m // p

        for p_i in range(p):

            ll = list(np.random.permutation(num_data))

            ll2 = chunkify_uneven(ll, m_per_cluster) # splits ll into m lists
            data_indices += ll2

            cluster_assign += [p_i for _ in range(m_per_cluster)]

        data_indices = np.array(data_indices, dtype=object)
        cluster_assign = np.array(cluster_assign)
        assert data_indices.shape[0] == cluster_assign.shape[0]
        assert data_indices.shape[0] == m


        return data_indices, cluster_assign


    def _load_MNIST(self, train=True):
        transforms = torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               # torchvision.transforms.Normalize(
                               #   (0.1307,), (0.3081,))
                             ])
        if train:
            mnist_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms)
        else:
            mnist_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms)

        dl = DataLoader(mnist_dataset)

        X = dl.dataset.data # (60000,28, 28)
        y = dl.dataset.targets #(60000)

        # normalize to have 0 ~ 1 range in each pixel

        X = X / 255.0
        X = X.to(self.device)
        y = y.to(self.device)

        return X, y


    # Need p models for each client

    def setup_models(self):
        np.random.seed(self.config['train_seed'])
        torch.manual_seed(self.config['train_seed'])

        p = self.config['p']
        m = self.config['m']

        self.models = [[SimpleLinear(h1 = self.config['h1']).to(self.device) for p_i in range(p)] for m_i in range(m)] # p models with p different params of dimension(1,d) for each client m_i

        self.criterion = torch.nn.CrossEntropyLoss()

        # import ipdb; ipdb.set_trace()


    def run(self):
        num_epochs = self.config['num_epochs']
        lr = self.config['lr']

        #self.cluster_switch = [[0 for _ in range(self.config['p'])] for m_i in range(self.config['m'])] 

        results = []

        # epoch -1
        self.epoch = -1

        result = {}
        result['epoch'] = -1

        t0 = time.time()
        res = self.test(train=True)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['train'] = res

        self.print_epoch_stats(res)

        t0 = time.time()
        res = self.test(train=False)
        t1 = time.time()
        res['infer_time'] = t1-t0
        result['test'] = res
        self.print_epoch_stats(res)
        results.append(result)

        # this will be used in next epoch
        cluster_assign = result['train']['cluster_assign']

        for epoch in range(num_epochs):
            self.epoch = epoch

            result = {}
            result['epoch'] = epoch

            lr = self.lr_schedule(epoch)
            result['lr'] = lr

            t0 = time.time()
            result['train'] = self.train(cluster_assign, lr = lr)
            t1 = time.time()
            train_time = t1-t0

            t0 = time.time()
            res = self.test(train=True)
            t1 = time.time()
            res['infer_time'] = t1-t0
            res['train_time'] = train_time
            res['lr'] = lr
            result['train'] = res

            self.print_epoch_stats(res)

            t0 = time.time()
            res = self.test(train=False)
            t1 = time.time()
            res['infer_time'] = t1-t0
            result['test'] = res
            self.print_epoch_stats(res)

            results.append(result)

            # this will be used in next epoch's gradient update
            cluster_assign = result['train']['cluster_assign']

            if epoch % 10 == 0 or epoch == num_epochs - 1 :
                with open(self.result_fname, 'wb') as outfile:
                    pickle.dump(results, outfile)
                    print(f'result written at {self.result_fname}')
#                self.save_checkpoint()
                print(f'checkpoint written at {self.checkpoint_fname}')
            
            if epoch % 10 == 0:
                self.test_all(train=False)



        plt.figure(figsize=(10,5))
        plt.plot([r['train']['loss'] for r in results], label='train')
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.title('Training Loss per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'train_loss.png'))
        # import ipdb; ipdb.set_trace()

        plt.figure(figsize=(10,5))
        plt.plot([r['test']['acc'] for r in results], label='test')
        plt.xlabel('epoch')
        plt.ylabel('test accuracy')
        plt.title('Test Accuracy per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'test_acc.png'))

        plt.figure(figsize=(10,5))
        plt.plot([r['train']['cl_acc'] for r in results], label='train')
        plt.xlabel('epoch')
        plt.ylabel('cluster acc')
        plt.title('Cluster Accuracy per Epoch')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.config['project_dir'], 'cluster_acc.png'))



    def lr_schedule(self, epoch):
        if self.lr is None:
            self.lr = self.config['lr']

        if epoch % 50 == 0 and epoch != 0 and LR_DECAY:
            self.lr = self.lr * 0.1

        return self.lr        


    def print_epoch_stats(self, res):
        if res['is_train']:
            data_str = 'tr'
        else:
            data_str = 'tst'

        if 'train_time' in res:
            time_str = f"{res['train_time']:.3f}sec(train) {res['infer_time']:.3f}sec(infer)"
        else:
            time_str = f"{res['infer_time']:.3f}sec"

        if 'lr' in res:
            lr_str = f" lr {res['lr']:4f}"
        else:
            lr_str = ""

        str0 = f"Epoch {self.epoch} {data_str}: l {res['loss']:.3f} a {res['acc']:.3f} clct{res['cl_ct']} cl_acc {res['cl_acc']:.3f} {lr_str} {time_str}"

        print(str0)

    def train(self, cluster_assign, lr):
        VERBOSE = 0

        cfg = self.config
        m = cfg['m']
        p = cfg['p']
        tau = cfg['tau']

        # run local update
        t0 = time.time()


        for m_i in range(m):
            if VERBOSE and m_i % 100 == 0: print(f'm {m_i}/{m} processing \r', end ='')

            (X, y) = self.load_data(m_i)

            p_i = cluster_assign[m_i]
            model = self.models[m_i][p_i]

            # LOCAL UPDATE PER MACHINE tau times
            for step_i in range(tau):

                y_logit = model(X)
                loss = self.criterion(y_logit, y)

                model.zero_grad()
                loss.backward()
                self.local_param_update(model, lr)

            model.zero_grad()


        t02 = time.time()
        # print(f'running single ..took {t02-t01:.3f}sec')


        t1 = time.time()
        if VERBOSE: print(f'local update {t1-t0:.3f}sec')

        # apply gradient update
        t0 = time.time()

        # NEEDS TO BE DECENTRALIZED
        self.dec_param_update(cluster_assign)
        t1 = time.time()

        if VERBOSE: print(f'global update {t1-t0:.3f}sec')

    def check_local_model_loss(self, local_models):
        # for debugging
        m = self.config['m']

        losses = []
        for m_i in range(m):
            (X, y) = self.load_data(m_i)
            y_logit = local_models[m_i](X)
            loss = self.criterion(y_logit, y)

            losses.append(loss.item())

        return np.array(losses)
    
    def get_cluster_accuracy(self, actual, pred):
        
        cm = confusion_matrix(actual, pred)

        row_ind, col_ind = linear_sum_assignment(-cm)
        matching = dict(zip(col_ind, row_ind))

        remapped_preds = [matching[p] for p in pred]

        cl_acc = np.mean(np.array(remapped_preds) == np.array(actual))

        return cl_acc


    def get_inference_stats(self, train = True):
        cfg = self.config
        if train:
            m = cfg['m']
            dataset = self.dataset['train']
        else:
            m = cfg['m_test']
            dataset = self.dataset['test']

        p = cfg['p']


        num_data = 0
        losses = {}
        corrects = {}
        for m_i in range(m):
            (X, y) = self.load_data(m_i, train=train) # load batch data rotated

            for p_i in range(p):
                y_logit = self.models[m_i][p_i](X)
                loss = self.criterion(y_logit, y) # loss of
                n_correct = self.n_correct(y_logit, y)

                # if torch.isnan(loss):
                #     print("nan loss: ", dataset['data_indices'][m_i])

                losses[(m_i,p_i)] = loss.item()
                corrects[(m_i,p_i)] = n_correct

            num_data += X.shape[0]

        # calculate loss and cluster the machines
        cluster_assign = []
        for m_i in range(m):
            machine_losses = [ losses[(m_i,p_i)] for p_i in range(p) ]
            #print("Machine Losses:", machine_losses)
            min_p_i = np.argmin(machine_losses)
            cluster_assign.append(min_p_i)

        # calculate optimal model's loss, acc over all models
        min_corrects = []
        min_losses = []
        for m_i, p_i in enumerate(cluster_assign):

            min_loss = losses[(m_i,p_i)]
            min_losses.append(min_loss)

            min_correct = corrects[(m_i,p_i)]
            min_corrects.append(min_correct)

        # print("losses: ", min_losses)

        if train:
            loss = np.mean(min_losses)
            acc = np.sum(min_corrects) / num_data

        else:
            loss, acc = self.test_all()


        # check cluster assignment acc
        cl_acc = self.get_cluster_accuracy(dataset['cluster_assign'], cluster_assign)
        cl_ct = [np.sum(np.array(cluster_assign) == p_i ) for p_i in range(p)]

        # improved cluster assignment acc (model 2 can work better on clients with p=3)
        

        res = {} # results
        # res['losses'] = losses
        # res['corrects'] = corrects
        res['cluster_assign'] = cluster_assign
        res['num_data'] = num_data
        res['loss'] = loss
        res['acc'] = acc
        res['cl_acc'] = cl_acc
        res['cl_ct'] = cl_ct
        res['is_train'] = train

        # import ipdb; ipdb.set_trace()

        return res

    def n_correct(self, y_logit, y):
        _, predicted = torch.max(y_logit.data, 1)
        correct = (predicted == y).sum().item()

        return correct

    # TODO Does every Cluster get 4 clients with the same data, but rotated differently?

    def load_data(self, m_i, train=True):
        # this part is very fast since its just rearranging models
        cfg = self.config

        if train:
            dataset = self.dataset['train']
        else:
            dataset = self.dataset['test']

        indices = dataset['data_indices'][m_i]
        p_i = dataset['cluster_assign'][m_i]

        X_batch = dataset['X'][indices]
        y_batch = dataset['y'][indices]

        # k : how many times rotate 90 degree
        # k =1 : 90 , k=2 180, k=3 270

        if cfg['p'] == 4:
            k = p_i
        elif cfg['p'] == 2:
            k = (p_i % 2) * 2
        elif cfg['p'] == 1:
            k = 0
        else:
            raise NotImplementedError("only p=1,2,4 supported")

        X_batch2 = torch.rot90(X_batch, k=int(k), dims = (1,2))
        X_batch3 = X_batch2.reshape(-1, 28 * 28)

        # import ipdb; ipdb.set_trace()

        return X_batch3, y_batch


    def local_param_update(self, model, lr):

        # gradient update manually

        for name, param in model.named_parameters():
            if param.requires_grad:
                param.data -= lr * param.grad

        model.zero_grad()

        # import ipdb; ipdb.set_trace() # we need to check the output of name, check if duplicate exists


    def dec_param_update(self, cluster_assign):

        num_clients = self.config['m']

        if num_clients <= 4:
            return

        max_e = 100
        if num_clients <= max_e:
            e = num_clients - 1
        else:
            e = min(max_e, int(np.log(num_clients) * 20))

        if e >= num_clients:
            e = num_clients - 1

        client_indices = list(range(num_clients)) 

        for m_i in range(num_clients):

            counts = {i: 0 for i in range(self.config['p'])}
            for value in cluster_assign:
                counts[value] += 1

            num_cluster_i = counts[cluster_assign[m_i]]
            num_cluster_rest = num_clients - num_cluster_i

            threshold_j = min(num_cluster_rest, 100)
            threshold_i = min(num_cluster_i, 100)

            # threshold_j = min(num_cluster_rest, int(np.floor(e/2)))
            # threshold_i = min(num_cluster_i, int(np.floor(e/2))) - 1

            selected_clients = random.sample([i for i in client_indices if i != m_i], torch.randint(1, min(threshold_i,threshold_j), (1,)))
            # selected_clients += random.sample([i for i in client_indices if i != m_i and cluster_assign[m_i] == cluster_assign[i]], threshold_i)
            m_i_cluster = cluster_assign[m_i]
            for m_j in selected_clients:
                m_j_cluster = cluster_assign[m_j]

                m_j_params = dict(self.models[m_j][m_j_cluster].named_parameters())

                if m_i_cluster == m_j_cluster:
                    for name, param in self.models[m_i][m_i_cluster].named_parameters():
                        m_i_param = param.data.clone()
                        m_j_param = m_j_params[name].data.clone()
                        alpha = 0.5
                        param.data = (m_i_param + m_j_param) / 2     

                else:
                    for name, param in self.models[m_i][m_j_cluster].named_parameters():
                        m_i_param = param.data.clone()
                        m_j_param = m_j_params[name].data.clone()
                        alpha = 0.4
                        param.data = alpha * m_i_param + (1 - alpha) * m_j_param

        # import ipdb; ipdb.set_trace()


    def test(self, train=False):
        return self.get_inference_stats(train=train)

    def load_test_data(self, m_i, train=False):
        cfg = self.config

        p = cfg['p']

        if train:
            dataset = self.dataset['train']
        else:
            dataset = self.dataset['test']

        indices = dataset['data_indices'][m_i]
        p_i = dataset['cluster_assign'][m_i]

        X_batch = dataset['X'][indices]
        y_batch = dataset['y'][indices]

        data = []

        for p_j in range(p):
            X_batch2 = torch.rot90(X_batch, k=int(p_j), dims = (1,2))
            X_batch3 = X_batch2.reshape(-1, 28 * 28)
            data.append(X_batch3)

        return data, y_batch

    def test_all(self, train=False):
        cfg = self.config
        m = cfg['m_test']
        dataset = self.dataset['test']

        p = cfg['p']

        num_data = 0
        losses = []
        corrects = []
        for m_i in range(m):
            
            (data, y) = self.load_test_data(m_i, train=train)

            for p_i in range(p):
                X = data[p_i]
                loss_m_i = []
                correct_m_i = []
                for model in range(p):
                    y_logit = self.models[m_i][model](X)
                    loss_m_i.append(self.criterion(y_logit, y))
                    correct_m_i.append(self.n_correct(y_logit, y))

                loss = np.min([l.item() for l in loss_m_i])
                n_correct = np.max(correct_m_i)

                # if torch.isnan(loss):
                #     print("nan loss: ", dataset['data_indices'][m_i])

                losses.append(loss)
                corrects.append(n_correct)

                num_data += X.shape[0]

        loss = np.mean(losses)
        acc = np.sum(corrects) / num_data

        # print(f"Average loss over all clients and models: {loss:.3f}")
        # print(f"Average accuracy over all clients and models: {acc:.3f}")    

        return loss, acc



    def save_checkpoint(self):
        models_to_save = [model.state_dict() for model in self.models]
        torch.save({'models':models_to_save}, self.checkpoint_fname)

# %% [markdown]
# Running the Experiment

# %%
start_time = time.time()
config = get_config()

config['train_seed'] = config['data_seed']

print("config:",config)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

exp = TrainMNISTCluster(config, device)
exp.setup()
exp.run()
duration = (time.time() - start_time)
print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
# Out:
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 10, 'train_seed': 10, 'project_dir': 'output'}
# Using device: cuda
# m: 1200
# p: 4
# num_data: 60000
# len:  60000
# len:  60000
# len:  60000
# len:  60000
# m: 200
# p: 4
# num_data: 10000
# len:  10000
# len:  10000
# len:  10000
# len:  10000
# Epoch -1 tr: l 2.295 a 0.117 clct[324, 294, 290, 292] cl_acc 0.279  2.092sec
# Epoch -1 tst: l 2.294 a 0.136 clct[54, 46, 47, 53] cl_acc 0.335  1.199sec
# Epoch 0 tr: l 2.247 a 0.284 clct[280, 339, 273, 308] cl_acc 0.301  lr 0.100000 11.348sec(train) 1.431sec(infer)
# Epoch 0 tst: l 2.243 a 0.303 clct[47, 50, 52, 51] cl_acc 0.315  1.118sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 1 tr: l 2.250 a 0.268 clct[291, 309, 287, 313] cl_acc 0.302  lr 0.100000 10.816sec(train) 1.458sec(infer)
# Epoch 1 tst: l 2.243 a 0.298 clct[44, 47, 48, 61] cl_acc 0.365  1.105sec
# Epoch 2 tr: l 2.256 a 0.215 clct[314, 318, 298, 270] cl_acc 0.325  lr 0.100000 10.957sec(train) 1.475sec(infer)
# Epoch 2 tst: l 2.246 a 0.257 clct[45, 51, 49, 55] cl_acc 0.355  1.114sec
# Epoch 3 tr: l 2.246 a 0.181 clct[334, 289, 311, 266] cl_acc 0.319  lr 0.100000 11.654sec(train) 1.440sec(infer)
# Epoch 3 tst: l 2.246 a 0.223 clct[58, 45, 53, 44] cl_acc 0.330  1.128sec
# Epoch 4 tr: l 2.228 a 0.172 clct[334, 302, 327, 237] cl_acc 0.347  lr 0.100000 11.265sec(train) 1.578sec(infer)
# Epoch 4 tst: l 2.230 a 0.217 clct[45, 68, 56, 31] cl_acc 0.365  1.157sec
# Epoch 5 tr: l 2.187 a 0.220 clct[300, 271, 372, 257] cl_acc 0.467  lr 0.100000 11.419sec(train) 1.442sec(infer)
# Epoch 5 tst: l 2.194 a 0.239 clct[48, 49, 62, 41] cl_acc 0.405  1.137sec
# Epoch 6 tr: l 2.113 a 0.315 clct[271, 207, 424, 298] cl_acc 0.608  lr 0.100000 11.323sec(train) 1.510sec(infer)
# Epoch 6 tst: l 2.127 a 0.308 clct[42, 44, 66, 48] cl_acc 0.545  1.245sec
# Epoch 7 tr: l 1.997 a 0.409 clct[316, 205, 381, 298] cl_acc 0.752  lr 0.100000 11.863sec(train) 1.460sec(infer)
# Epoch 7 tst: l 2.016 a 0.386 clct[39, 44, 76, 41] cl_acc 0.655  1.148sec
# Epoch 8 tr: l 1.836 a 0.486 clct[331, 253, 316, 300] cl_acc 0.933  lr 0.100000 11.587sec(train) 1.435sec(infer)
# Epoch 8 tst: l 1.858 a 0.461 clct[49, 42, 59, 50] cl_acc 0.885  1.106sec
# Epoch 9 tr: l 1.637 a 0.543 clct[302, 297, 301, 300] cl_acc 0.989  lr 0.100000 11.415sec(train) 1.464sec(infer)
# Epoch 9 tst: l 1.661 a 0.520 clct[48, 49, 53, 50] cl_acc 0.965  1.163sec
# Epoch 10 tr: l 1.453 a 0.592 clct[299, 300, 301, 300] cl_acc 0.998  lr 0.100000 11.525sec(train) 1.731sec(infer)
# Epoch 10 tst: l 1.474 a 0.573 clct[50, 50, 50, 50] cl_acc 1.000  1.272sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 11 tr: l 1.288 a 0.640 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.233sec(train) 1.690sec(infer)
# Epoch 11 tst: l 1.310 a 0.621 clct[50, 50, 50, 50] cl_acc 1.000  1.257sec
# Epoch 12 tr: l 1.148 a 0.682 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.091sec(train) 1.528sec(infer)
# Epoch 12 tst: l 1.171 a 0.669 clct[50, 50, 50, 50] cl_acc 1.000  1.306sec
# Epoch 13 tr: l 1.033 a 0.714 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.440sec(train) 1.467sec(infer)
# Epoch 13 tst: l 1.055 a 0.701 clct[50, 50, 50, 50] cl_acc 1.000  1.142sec
# Epoch 14 tr: l 0.935 a 0.744 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.238sec(train) 1.512sec(infer)
# Epoch 14 tst: l 0.952 a 0.737 clct[50, 50, 50, 50] cl_acc 1.000  1.141sec
# Epoch 15 tr: l 0.852 a 0.768 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.382sec(train) 1.501sec(infer)
# Epoch 15 tst: l 0.872 a 0.757 clct[50, 50, 50, 50] cl_acc 1.000  1.175sec
# Epoch 16 tr: l 0.784 a 0.784 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.109sec(train) 1.460sec(infer)
# Epoch 16 tst: l 0.802 a 0.776 clct[50, 50, 50, 50] cl_acc 1.000  1.166sec
# Epoch 17 tr: l 0.733 a 0.798 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.048sec(train) 1.452sec(infer)
# Epoch 17 tst: l 0.747 a 0.794 clct[50, 50, 50, 50] cl_acc 1.000  1.131sec
# Epoch 18 tr: l 0.688 a 0.809 clct[301, 299, 300, 300] cl_acc 0.999  lr 0.100000 11.440sec(train) 1.464sec(infer)
# Epoch 18 tst: l 0.698 a 0.807 clct[50, 50, 50, 50] cl_acc 1.000  1.154sec
# Epoch 19 tr: l 0.648 a 0.818 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.327sec(train) 1.464sec(infer)
# Epoch 19 tst: l 0.664 a 0.816 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 20 tr: l 0.615 a 0.828 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.158sec(train) 1.453sec(infer)
# Epoch 20 tst: l 0.632 a 0.825 clct[50, 50, 50, 50] cl_acc 1.000  1.133sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 21 tr: l 0.588 a 0.835 clct[301, 299, 300, 300] cl_acc 0.999  lr 0.100000 11.182sec(train) 1.450sec(infer)
# Epoch 21 tst: l 0.603 a 0.833 clct[50, 50, 50, 50] cl_acc 1.000  1.128sec
# Epoch 22 tr: l 0.567 a 0.841 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.411sec(train) 1.487sec(infer)
# Epoch 22 tst: l 0.583 a 0.837 clct[50, 50, 50, 50] cl_acc 1.000  1.151sec
# Epoch 23 tr: l 0.546 a 0.846 clct[301, 299, 300, 300] cl_acc 0.999  lr 0.100000 12.039sec(train) 1.952sec(infer)
# Epoch 23 tst: l 0.562 a 0.842 clct[50, 50, 50, 50] cl_acc 1.000  1.434sec
# Epoch 24 tr: l 0.528 a 0.852 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.181sec(train) 1.466sec(infer)
# Epoch 24 tst: l 0.543 a 0.848 clct[50, 50, 50, 50] cl_acc 1.000  1.144sec
# Epoch 25 tr: l 0.509 a 0.857 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.861sec(train) 1.466sec(infer)
# Epoch 25 tst: l 0.523 a 0.855 clct[50, 50, 50, 50] cl_acc 1.000  1.167sec
# Epoch 26 tr: l 0.496 a 0.859 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.907sec(train) 1.604sec(infer)
# Epoch 26 tst: l 0.509 a 0.860 clct[50, 50, 50, 50] cl_acc 1.000  1.202sec
# Epoch 27 tr: l 0.480 a 0.864 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.786sec(train) 1.645sec(infer)
# Epoch 27 tst: l 0.495 a 0.864 clct[50, 50, 50, 50] cl_acc 1.000  1.230sec
# Epoch 28 tr: l 0.472 a 0.865 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.674sec(train) 1.548sec(infer)
# Epoch 28 tst: l 0.484 a 0.864 clct[50, 50, 50, 50] cl_acc 1.000  1.169sec
# Epoch 29 tr: l 0.463 a 0.869 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.803sec(train) 1.488sec(infer)
# Epoch 29 tst: l 0.473 a 0.869 clct[50, 50, 50, 50] cl_acc 1.000  1.149sec
# Epoch 30 tr: l 0.450 a 0.871 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.703sec(train) 1.498sec(infer)
# Epoch 30 tst: l 0.464 a 0.870 clct[50, 50, 50, 50] cl_acc 1.000  1.146sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 31 tr: l 0.441 a 0.875 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.554sec(train) 1.578sec(infer)
# Epoch 31 tst: l 0.455 a 0.874 clct[50, 50, 50, 50] cl_acc 1.000  1.183sec
# Epoch 32 tr: l 0.432 a 0.876 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.670sec(train) 1.491sec(infer)
# Epoch 32 tst: l 0.444 a 0.877 clct[50, 50, 50, 50] cl_acc 1.000  1.151sec
# Epoch 33 tr: l 0.426 a 0.878 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.656sec(train) 1.475sec(infer)
# Epoch 33 tst: l 0.437 a 0.879 clct[50, 50, 50, 50] cl_acc 1.000  1.222sec
# Epoch 34 tr: l 0.420 a 0.880 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.336sec(train) 1.576sec(infer)
# Epoch 34 tst: l 0.430 a 0.880 clct[50, 50, 50, 50] cl_acc 1.000  1.134sec
# Epoch 35 tr: l 0.414 a 0.882 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.505sec(train) 1.532sec(infer)
# Epoch 35 tst: l 0.423 a 0.883 clct[50, 50, 50, 50] cl_acc 1.000  1.158sec
# Epoch 36 tr: l 0.406 a 0.883 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.231sec(train) 1.450sec(infer)
# Epoch 36 tst: l 0.420 a 0.882 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 37 tr: l 0.401 a 0.884 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.308sec(train) 1.479sec(infer)
# Epoch 37 tst: l 0.413 a 0.885 clct[50, 50, 50, 50] cl_acc 1.000  1.161sec
# Epoch 38 tr: l 0.394 a 0.886 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.383sec(train) 1.544sec(infer)
# Epoch 38 tst: l 0.409 a 0.886 clct[50, 50, 50, 50] cl_acc 1.000  1.170sec
# Epoch 39 tr: l 0.388 a 0.886 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.789sec(train) 1.472sec(infer)
# Epoch 39 tst: l 0.405 a 0.887 clct[50, 50, 50, 50] cl_acc 1.000  1.282sec
# Epoch 40 tr: l 0.385 a 0.888 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.249sec(train) 1.481sec(infer)
# Epoch 40 tst: l 0.398 a 0.889 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 41 tr: l 0.382 a 0.889 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.451sec(train) 1.548sec(infer)
# Epoch 41 tst: l 0.396 a 0.890 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 42 tr: l 0.375 a 0.891 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.513sec(train) 1.464sec(infer)
# Epoch 42 tst: l 0.390 a 0.891 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 43 tr: l 0.372 a 0.891 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.334sec(train) 1.439sec(infer)
# Epoch 43 tst: l 0.386 a 0.892 clct[50, 50, 50, 50] cl_acc 1.000  1.138sec
# Epoch 44 tr: l 0.370 a 0.892 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.537sec(train) 1.463sec(infer)
# Epoch 44 tst: l 0.381 a 0.893 clct[50, 50, 50, 50] cl_acc 1.000  1.138sec
# Epoch 45 tr: l 0.368 a 0.892 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.309sec(train) 1.466sec(infer)
# Epoch 45 tst: l 0.380 a 0.893 clct[50, 50, 50, 50] cl_acc 1.000  1.145sec
# Epoch 46 tr: l 0.365 a 0.893 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.446sec(train) 1.537sec(infer)
# Epoch 46 tst: l 0.376 a 0.894 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 47 tr: l 0.360 a 0.894 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.807sec(train) 1.481sec(infer)
# Epoch 47 tst: l 0.373 a 0.895 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 48 tr: l 0.356 a 0.895 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.223sec(train) 1.498sec(infer)
# Epoch 48 tst: l 0.369 a 0.896 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 49 tr: l 0.355 a 0.896 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.283sec(train) 1.494sec(infer)
# Epoch 49 tst: l 0.367 a 0.896 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 50 tr: l 0.350 a 0.897 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.990sec(train) 1.783sec(infer)
# Epoch 50 tst: l 0.365 a 0.897 clct[50, 50, 50, 50] cl_acc 1.000  1.300sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 51 tr: l 0.350 a 0.896 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.618sec(train) 1.541sec(infer)
# Epoch 51 tst: l 0.364 a 0.897 clct[50, 50, 50, 50] cl_acc 1.000  1.172sec
# Epoch 52 tr: l 0.347 a 0.897 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.467sec(train) 1.485sec(infer)
# Epoch 52 tst: l 0.362 a 0.897 clct[50, 50, 50, 50] cl_acc 1.000  1.211sec
# Epoch 53 tr: l 0.345 a 0.898 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.073sec(train) 1.563sec(infer)
# Epoch 53 tst: l 0.359 a 0.898 clct[50, 50, 50, 50] cl_acc 1.000  1.228sec
# Epoch 54 tr: l 0.345 a 0.898 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.843sec(train) 1.831sec(infer)
# Epoch 54 tst: l 0.356 a 0.900 clct[50, 50, 50, 50] cl_acc 1.000  1.366sec
# Epoch 55 tr: l 0.341 a 0.899 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.808sec(train) 1.603sec(infer)
# Epoch 55 tst: l 0.354 a 0.900 clct[50, 50, 50, 50] cl_acc 1.000  1.258sec
# Epoch 56 tr: l 0.338 a 0.900 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.915sec(train) 1.611sec(infer)
# Epoch 56 tst: l 0.350 a 0.900 clct[50, 50, 50, 50] cl_acc 1.000  1.219sec
# Epoch 57 tr: l 0.335 a 0.901 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.013sec(train) 1.481sec(infer)
# Epoch 57 tst: l 0.350 a 0.901 clct[50, 50, 50, 50] cl_acc 1.000  1.207sec
# Epoch 58 tr: l 0.335 a 0.900 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.879sec(train) 1.514sec(infer)
# Epoch 58 tst: l 0.348 a 0.902 clct[50, 50, 50, 50] cl_acc 1.000  1.187sec
# Epoch 59 tr: l 0.331 a 0.902 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.835sec(train) 1.512sec(infer)
# Epoch 59 tst: l 0.346 a 0.901 clct[50, 50, 50, 50] cl_acc 1.000  1.228sec
# Epoch 60 tr: l 0.332 a 0.902 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.044sec(train) 1.626sec(infer)
# Epoch 60 tst: l 0.344 a 0.902 clct[50, 50, 50, 50] cl_acc 1.000  1.246sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 61 tr: l 0.328 a 0.902 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.720sec(train) 1.545sec(infer)
# Epoch 61 tst: l 0.343 a 0.902 clct[50, 50, 50, 50] cl_acc 1.000  1.261sec
# Epoch 62 tr: l 0.328 a 0.903 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.011sec(train) 1.478sec(infer)
# Epoch 62 tst: l 0.342 a 0.903 clct[50, 50, 50, 50] cl_acc 1.000  1.196sec
# Epoch 63 tr: l 0.327 a 0.903 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.560sec(train) 1.464sec(infer)
# Epoch 63 tst: l 0.339 a 0.903 clct[50, 50, 50, 50] cl_acc 1.000  1.266sec
# Epoch 64 tr: l 0.323 a 0.904 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.031sec(train) 1.473sec(infer)
# Epoch 64 tst: l 0.340 a 0.903 clct[50, 50, 50, 50] cl_acc 1.000  1.173sec
# Epoch 65 tr: l 0.322 a 0.904 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.575sec(train) 1.471sec(infer)
# Epoch 65 tst: l 0.336 a 0.904 clct[50, 50, 50, 50] cl_acc 1.000  1.168sec
# Epoch 66 tr: l 0.321 a 0.904 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.289sec(train) 1.455sec(infer)
# Epoch 66 tst: l 0.337 a 0.904 clct[50, 50, 50, 50] cl_acc 1.000  1.156sec
# Epoch 67 tr: l 0.320 a 0.905 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.493sec(train) 1.454sec(infer)
# Epoch 67 tst: l 0.334 a 0.905 clct[50, 50, 50, 50] cl_acc 1.000  1.256sec
# Epoch 68 tr: l 0.319 a 0.905 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.902sec(train) 1.507sec(infer)
# Epoch 68 tst: l 0.332 a 0.906 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 69 tr: l 0.315 a 0.906 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.431sec(train) 1.435sec(infer)
# Epoch 69 tst: l 0.330 a 0.906 clct[50, 50, 50, 50] cl_acc 1.000  1.138sec
# Epoch 70 tr: l 0.314 a 0.906 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.613sec(train) 1.459sec(infer)
# Epoch 70 tst: l 0.329 a 0.906 clct[50, 50, 50, 50] cl_acc 1.000  1.140sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 71 tr: l 0.314 a 0.906 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.423sec(train) 1.489sec(infer)
# Epoch 71 tst: l 0.331 a 0.907 clct[50, 50, 50, 50] cl_acc 1.000  1.143sec
# Epoch 72 tr: l 0.310 a 0.907 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.612sec(train) 1.474sec(infer)
# Epoch 72 tst: l 0.329 a 0.906 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# Epoch 73 tr: l 0.310 a 0.907 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.260sec(train) 1.504sec(infer)
# Epoch 73 tst: l 0.327 a 0.907 clct[50, 50, 50, 50] cl_acc 1.000  1.248sec
# Epoch 74 tr: l 0.308 a 0.908 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.079sec(train) 1.543sec(infer)
# Epoch 74 tst: l 0.326 a 0.907 clct[50, 50, 50, 50] cl_acc 1.000  1.193sec
# Epoch 75 tr: l 0.308 a 0.908 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.369sec(train) 1.602sec(infer)
# Epoch 75 tst: l 0.324 a 0.909 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 76 tr: l 0.307 a 0.908 clct[301, 300, 299, 300] cl_acc 0.999  lr 0.100000 11.879sec(train) 1.679sec(infer)
# Epoch 76 tst: l 0.324 a 0.908 clct[50, 50, 50, 50] cl_acc 1.000  1.366sec
# Epoch 77 tr: l 0.306 a 0.908 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.232sec(train) 1.598sec(infer)
# Epoch 77 tst: l 0.322 a 0.909 clct[50, 50, 50, 50] cl_acc 1.000  1.250sec
# Epoch 78 tr: l 0.307 a 0.908 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.945sec(train) 1.555sec(infer)
# Epoch 78 tst: l 0.324 a 0.907 clct[50, 50, 50, 50] cl_acc 1.000  1.179sec
# Epoch 79 tr: l 0.303 a 0.909 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.205sec(train) 1.500sec(infer)
# Epoch 79 tst: l 0.322 a 0.909 clct[50, 50, 50, 50] cl_acc 1.000  1.162sec
# Epoch 80 tr: l 0.303 a 0.909 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.091sec(train) 1.528sec(infer)
# Epoch 80 tst: l 0.317 a 0.909 clct[50, 50, 50, 50] cl_acc 1.000  1.154sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 81 tr: l 0.303 a 0.909 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.666sec(train) 1.487sec(infer)
# Epoch 81 tst: l 0.318 a 0.910 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 82 tr: l 0.302 a 0.910 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.299sec(train) 1.467sec(infer)
# Epoch 82 tst: l 0.318 a 0.909 clct[50, 50, 50, 50] cl_acc 1.000  1.153sec
# Epoch 83 tr: l 0.301 a 0.910 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.723sec(train) 1.507sec(infer)
# Epoch 83 tst: l 0.316 a 0.910 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 84 tr: l 0.296 a 0.911 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.196sec(train) 1.453sec(infer)
# Epoch 84 tst: l 0.314 a 0.911 clct[50, 50, 50, 50] cl_acc 1.000  1.131sec
# Epoch 85 tr: l 0.298 a 0.911 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.863sec(train) 1.477sec(infer)
# Epoch 85 tst: l 0.314 a 0.911 clct[50, 50, 50, 50] cl_acc 1.000  1.164sec
# Epoch 86 tr: l 0.297 a 0.911 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.250sec(train) 1.454sec(infer)
# Epoch 86 tst: l 0.314 a 0.911 clct[50, 50, 50, 50] cl_acc 1.000  1.155sec
# Epoch 87 tr: l 0.297 a 0.911 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.497sec(train) 1.490sec(infer)
# Epoch 87 tst: l 0.312 a 0.911 clct[50, 50, 50, 50] cl_acc 1.000  1.148sec
# Epoch 88 tr: l 0.295 a 0.912 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.862sec(train) 1.569sec(infer)
# Epoch 88 tst: l 0.312 a 0.912 clct[50, 50, 50, 50] cl_acc 1.000  1.217sec
# Epoch 89 tr: l 0.294 a 0.912 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.556sec(train) 1.495sec(infer)
# Epoch 89 tst: l 0.313 a 0.911 clct[50, 50, 50, 50] cl_acc 1.000  1.172sec
# Epoch 90 tr: l 0.292 a 0.912 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.704sec(train) 1.601sec(infer)
# Epoch 90 tst: l 0.310 a 0.912 clct[50, 50, 50, 50] cl_acc 1.000  1.228sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 91 tr: l 0.291 a 0.913 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.395sec(train) 1.493sec(infer)
# Epoch 91 tst: l 0.309 a 0.912 clct[50, 50, 50, 50] cl_acc 1.000  1.156sec
# Epoch 92 tr: l 0.288 a 0.913 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.122sec(train) 1.481sec(infer)
# Epoch 92 tst: l 0.308 a 0.913 clct[50, 50, 50, 50] cl_acc 1.000  1.232sec
# Epoch 93 tr: l 0.290 a 0.913 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.107sec(train) 1.462sec(infer)
# Epoch 93 tst: l 0.307 a 0.913 clct[50, 50, 50, 50] cl_acc 1.000  1.143sec
# Epoch 94 tr: l 0.288 a 0.914 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.567sec(train) 1.547sec(infer)
# Epoch 94 tst: l 0.306 a 0.914 clct[50, 50, 50, 50] cl_acc 1.000  1.156sec
# Epoch 95 tr: l 0.289 a 0.913 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.684sec(train) 1.479sec(infer)
# Epoch 95 tst: l 0.306 a 0.913 clct[50, 50, 50, 50] cl_acc 1.000  1.155sec
# Epoch 96 tr: l 0.288 a 0.914 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.475sec(train) 1.617sec(infer)
# Epoch 96 tst: l 0.309 a 0.912 clct[50, 50, 50, 50] cl_acc 1.000  1.226sec
# Epoch 97 tr: l 0.286 a 0.914 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.621sec(train) 1.495sec(infer)
# Epoch 97 tst: l 0.304 a 0.914 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 98 tr: l 0.286 a 0.914 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.999sec(train) 1.600sec(infer)
# Epoch 98 tst: l 0.305 a 0.914 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 99 tr: l 0.283 a 0.915 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.867sec(train) 1.596sec(infer)
# Epoch 99 tst: l 0.302 a 0.914 clct[50, 50, 50, 50] cl_acc 1.000  1.190sec
# Epoch 100 tr: l 0.284 a 0.914 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.714sec(train) 1.504sec(infer)
# Epoch 100 tst: l 0.300 a 0.915 clct[50, 50, 50, 50] cl_acc 1.000  1.155sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 101 tr: l 0.281 a 0.915 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.784sec(train) 1.546sec(infer)
# Epoch 101 tst: l 0.305 a 0.914 clct[50, 50, 50, 50] cl_acc 1.000  1.148sec
# Epoch 102 tr: l 0.282 a 0.916 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.306sec(train) 1.538sec(infer)
# Epoch 102 tst: l 0.302 a 0.915 clct[50, 50, 50, 50] cl_acc 1.000  1.140sec
# Epoch 103 tr: l 0.281 a 0.916 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.347sec(train) 1.487sec(infer)
# Epoch 103 tst: l 0.299 a 0.916 clct[50, 50, 50, 50] cl_acc 1.000  1.182sec
# Epoch 104 tr: l 0.280 a 0.916 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.957sec(train) 1.503sec(infer)
# Epoch 104 tst: l 0.300 a 0.915 clct[50, 50, 50, 50] cl_acc 1.000  1.231sec
# Epoch 105 tr: l 0.279 a 0.916 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.053sec(train) 1.551sec(infer)
# Epoch 105 tst: l 0.297 a 0.916 clct[50, 50, 50, 50] cl_acc 1.000  1.285sec
# Epoch 106 tr: l 0.278 a 0.916 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.829sec(train) 1.532sec(infer)
# Epoch 106 tst: l 0.297 a 0.916 clct[50, 50, 50, 50] cl_acc 1.000  1.170sec
# Epoch 107 tr: l 0.277 a 0.917 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.130sec(train) 1.618sec(infer)
# Epoch 107 tst: l 0.296 a 0.916 clct[50, 50, 50, 50] cl_acc 1.000  1.265sec
# Epoch 108 tr: l 0.279 a 0.917 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.751sec(train) 1.526sec(infer)
# Epoch 108 tst: l 0.294 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 109 tr: l 0.277 a 0.917 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.541sec(train) 1.532sec(infer)
# Epoch 109 tst: l 0.296 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.189sec
# Epoch 110 tr: l 0.274 a 0.917 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.789sec(train) 1.589sec(infer)
# Epoch 110 tst: l 0.296 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.145sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 111 tr: l 0.272 a 0.918 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.201sec(train) 1.603sec(infer)
# Epoch 111 tst: l 0.294 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.187sec
# Epoch 112 tr: l 0.275 a 0.917 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.176sec(train) 1.610sec(infer)
# Epoch 112 tst: l 0.293 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.273sec
# Epoch 113 tr: l 0.273 a 0.918 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.374sec(train) 1.445sec(infer)
# Epoch 113 tst: l 0.294 a 0.917 clct[50, 50, 50, 50] cl_acc 1.000  1.154sec
# Epoch 114 tr: l 0.270 a 0.918 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.607sec(train) 1.629sec(infer)
# Epoch 114 tst: l 0.291 a 0.918 clct[50, 50, 50, 50] cl_acc 1.000  1.239sec
# Epoch 115 tr: l 0.271 a 0.919 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 13.398sec(train) 1.491sec(infer)
# Epoch 115 tst: l 0.291 a 0.918 clct[50, 50, 50, 50] cl_acc 1.000  1.241sec
# Epoch 116 tr: l 0.269 a 0.919 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.523sec(train) 1.654sec(infer)
# Epoch 116 tst: l 0.290 a 0.918 clct[50, 50, 50, 50] cl_acc 1.000  1.212sec
# Epoch 117 tr: l 0.269 a 0.919 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.964sec(train) 1.811sec(infer)
# Epoch 117 tst: l 0.290 a 0.918 clct[50, 50, 50, 50] cl_acc 1.000  1.161sec
# Epoch 118 tr: l 0.268 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.732sec(train) 1.481sec(infer)
# Epoch 118 tst: l 0.288 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.179sec
# Epoch 119 tr: l 0.269 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.813sec(train) 1.456sec(infer)
# Epoch 119 tst: l 0.292 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 120 tr: l 0.267 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.244sec(train) 1.467sec(infer)
# Epoch 120 tst: l 0.287 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 121 tr: l 0.266 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.555sec(train) 1.492sec(infer)
# Epoch 121 tst: l 0.291 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.153sec
# Epoch 122 tr: l 0.270 a 0.919 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.466sec(train) 1.472sec(infer)
# Epoch 122 tst: l 0.289 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 123 tr: l 0.264 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.152sec(train) 1.475sec(infer)
# Epoch 123 tst: l 0.286 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.168sec
# Epoch 124 tr: l 0.263 a 0.921 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.435sec(train) 1.546sec(infer)
# Epoch 124 tst: l 0.285 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.162sec
# Epoch 125 tr: l 0.264 a 0.921 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.323sec(train) 1.480sec(infer)
# Epoch 125 tst: l 0.285 a 0.919 clct[50, 50, 50, 50] cl_acc 1.000  1.145sec
# Epoch 126 tr: l 0.263 a 0.921 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.415sec(train) 1.452sec(infer)
# Epoch 126 tst: l 0.284 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 127 tr: l 0.264 a 0.920 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.237sec(train) 1.589sec(infer)
# Epoch 127 tst: l 0.283 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 128 tr: l 0.262 a 0.921 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.018sec(train) 1.641sec(infer)
# Epoch 128 tst: l 0.285 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.143sec
# Epoch 129 tr: l 0.261 a 0.921 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.313sec(train) 1.458sec(infer)
# Epoch 129 tst: l 0.283 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.203sec
# Epoch 130 tr: l 0.261 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.958sec(train) 1.515sec(infer)
# Epoch 130 tst: l 0.281 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.214sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 131 tr: l 0.259 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.707sec(train) 1.456sec(infer)
# Epoch 131 tst: l 0.281 a 0.920 clct[50, 50, 50, 50] cl_acc 1.000  1.144sec
# Epoch 132 tr: l 0.260 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.403sec(train) 1.457sec(infer)
# Epoch 132 tst: l 0.283 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.217sec
# Epoch 133 tr: l 0.261 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.845sec(train) 1.505sec(infer)
# Epoch 133 tst: l 0.280 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.268sec
# Epoch 134 tr: l 0.259 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.622sec(train) 1.514sec(infer)
# Epoch 134 tst: l 0.281 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.184sec
# Epoch 135 tr: l 0.256 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.620sec(train) 1.543sec(infer)
# Epoch 135 tst: l 0.278 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.188sec
# Epoch 136 tr: l 0.259 a 0.922 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.194sec(train) 1.560sec(infer)
# Epoch 136 tst: l 0.279 a 0.922 clct[50, 50, 50, 50] cl_acc 1.000  1.198sec
# Epoch 137 tr: l 0.252 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.424sec(train) 1.517sec(infer)
# Epoch 137 tst: l 0.278 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# Epoch 138 tr: l 0.254 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.316sec(train) 1.506sec(infer)
# Epoch 138 tst: l 0.279 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.155sec
# Epoch 139 tr: l 0.254 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.446sec(train) 1.514sec(infer)
# Epoch 139 tst: l 0.278 a 0.922 clct[50, 50, 50, 50] cl_acc 1.000  1.157sec
# Epoch 140 tr: l 0.255 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.473sec(train) 1.548sec(infer)
# Epoch 140 tst: l 0.280 a 0.921 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 141 tr: l 0.254 a 0.924 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.755sec(train) 1.517sec(infer)
# Epoch 141 tst: l 0.275 a 0.922 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 142 tr: l 0.251 a 0.923 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.399sec(train) 1.521sec(infer)
# Epoch 142 tst: l 0.275 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.192sec
# Epoch 143 tr: l 0.252 a 0.924 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.478sec(train) 1.507sec(infer)
# Epoch 143 tst: l 0.274 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.199sec
# Epoch 144 tr: l 0.249 a 0.925 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.629sec(train) 1.512sec(infer)
# Epoch 144 tst: l 0.273 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 145 tr: l 0.251 a 0.924 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.400sec(train) 1.570sec(infer)
# Epoch 145 tst: l 0.274 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# Epoch 146 tr: l 0.250 a 0.924 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.395sec(train) 1.508sec(infer)
# Epoch 146 tst: l 0.273 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.172sec
# Epoch 147 tr: l 0.249 a 0.924 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.584sec(train) 1.601sec(infer)
# Epoch 147 tst: l 0.272 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.512sec
# Epoch 148 tr: l 0.250 a 0.925 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.989sec(train) 1.867sec(infer)
# Epoch 148 tst: l 0.270 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.263sec
# Epoch 149 tr: l 0.246 a 0.925 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.728sec(train) 1.534sec(infer)
# Epoch 149 tst: l 0.276 a 0.922 clct[50, 50, 50, 50] cl_acc 1.000  1.293sec
# Epoch 150 tr: l 0.246 a 0.925 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.244sec(train) 1.506sec(infer)
# Epoch 150 tst: l 0.271 a 0.923 clct[50, 50, 50, 50] cl_acc 1.000  1.182sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 151 tr: l 0.247 a 0.925 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.715sec(train) 1.532sec(infer)
# Epoch 151 tst: l 0.270 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.175sec
# Epoch 152 tr: l 0.244 a 0.926 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.974sec(train) 1.517sec(infer)
# Epoch 152 tst: l 0.267 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.186sec
# Epoch 153 tr: l 0.246 a 0.926 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.338sec(train) 1.501sec(infer)
# Epoch 153 tst: l 0.269 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 154 tr: l 0.245 a 0.926 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.575sec(train) 1.590sec(infer)
# Epoch 154 tst: l 0.268 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.193sec
# Epoch 155 tr: l 0.244 a 0.926 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.590sec(train) 1.712sec(infer)
# Epoch 155 tst: l 0.268 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.231sec
# Epoch 156 tr: l 0.243 a 0.927 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.825sec(train) 1.545sec(infer)
# Epoch 156 tst: l 0.267 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.170sec
# Epoch 157 tr: l 0.243 a 0.926 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.966sec(train) 1.559sec(infer)
# Epoch 157 tst: l 0.265 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 158 tr: l 0.242 a 0.927 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.446sec(train) 1.516sec(infer)
# Epoch 158 tst: l 0.266 a 0.924 clct[50, 50, 50, 50] cl_acc 1.000  1.167sec
# Epoch 159 tr: l 0.243 a 0.927 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.668sec(train) 1.518sec(infer)
# Epoch 159 tst: l 0.265 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.209sec
# Epoch 160 tr: l 0.240 a 0.928 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.385sec(train) 1.494sec(infer)
# Epoch 160 tst: l 0.266 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.147sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 161 tr: l 0.239 a 0.927 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.322sec(train) 1.474sec(infer)
# Epoch 161 tst: l 0.266 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.146sec
# Epoch 162 tr: l 0.238 a 0.928 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.416sec(train) 1.501sec(infer)
# Epoch 162 tst: l 0.265 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.197sec
# Epoch 163 tr: l 0.241 a 0.927 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.336sec(train) 1.498sec(infer)
# Epoch 163 tst: l 0.263 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.160sec
# Epoch 164 tr: l 0.240 a 0.928 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.562sec(train) 1.508sec(infer)
# Epoch 164 tst: l 0.262 a 0.925 clct[50, 50, 50, 50] cl_acc 1.000  1.166sec
# Epoch 165 tr: l 0.237 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.496sec(train) 1.491sec(infer)
# Epoch 165 tst: l 0.262 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.168sec
# Epoch 166 tr: l 0.237 a 0.928 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.717sec(train) 1.553sec(infer)
# Epoch 166 tst: l 0.260 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.209sec
# Epoch 167 tr: l 0.237 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.589sec(train) 1.531sec(infer)
# Epoch 167 tst: l 0.263 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.183sec
# Epoch 168 tr: l 0.235 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.721sec(train) 1.528sec(infer)
# Epoch 168 tst: l 0.260 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 169 tr: l 0.235 a 0.928 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.765sec(train) 1.525sec(infer)
# Epoch 169 tst: l 0.261 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.162sec
# Epoch 170 tr: l 0.234 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.765sec(train) 1.518sec(infer)
# Epoch 170 tst: l 0.259 a 0.926 clct[50, 50, 50, 50] cl_acc 1.000  1.157sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 171 tr: l 0.234 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.385sec(train) 1.545sec(infer)
# Epoch 171 tst: l 0.260 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.178sec
# Epoch 172 tr: l 0.235 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.634sec(train) 1.522sec(infer)
# Epoch 172 tst: l 0.257 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.240sec
# Epoch 173 tr: l 0.234 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.729sec(train) 1.570sec(infer)
# Epoch 173 tst: l 0.258 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.271sec
# Epoch 174 tr: l 0.234 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.365sec(train) 1.502sec(infer)
# Epoch 174 tst: l 0.258 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.208sec
# Epoch 175 tr: l 0.234 a 0.929 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.882sec(train) 1.491sec(infer)
# Epoch 175 tst: l 0.257 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.130sec
# Epoch 176 tr: l 0.231 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.540sec(train) 1.522sec(infer)
# Epoch 176 tst: l 0.258 a 0.927 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 177 tr: l 0.228 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.164sec(train) 1.477sec(infer)
# Epoch 177 tst: l 0.256 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.131sec
# Epoch 178 tr: l 0.231 a 0.930 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.488sec(train) 1.488sec(infer)
# Epoch 178 tst: l 0.255 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.202sec
# Epoch 179 tr: l 0.230 a 0.930 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.449sec(train) 1.484sec(infer)
# Epoch 179 tst: l 0.256 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.153sec
# Epoch 180 tr: l 0.230 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.372sec(train) 1.499sec(infer)
# Epoch 180 tst: l 0.253 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.166sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 181 tr: l 0.227 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.672sec(train) 1.513sec(infer)
# Epoch 181 tst: l 0.253 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.201sec
# Epoch 182 tr: l 0.229 a 0.930 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.777sec(train) 1.515sec(infer)
# Epoch 182 tst: l 0.252 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.167sec
# Epoch 183 tr: l 0.226 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.678sec(train) 1.489sec(infer)
# Epoch 183 tst: l 0.252 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.205sec
# Epoch 184 tr: l 0.227 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.284sec(train) 1.525sec(infer)
# Epoch 184 tst: l 0.256 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.148sec
# Epoch 185 tr: l 0.229 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.345sec(train) 1.487sec(infer)
# Epoch 185 tst: l 0.252 a 0.928 clct[50, 50, 50, 50] cl_acc 1.000  1.147sec
# Epoch 186 tr: l 0.228 a 0.931 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.229sec(train) 1.472sec(infer)
# Epoch 186 tst: l 0.251 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.143sec
# Epoch 187 tr: l 0.226 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.352sec(train) 1.482sec(infer)
# Epoch 187 tst: l 0.250 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.136sec
# Epoch 188 tr: l 0.225 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.073sec(train) 1.487sec(infer)
# Epoch 188 tst: l 0.249 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.144sec
# Epoch 189 tr: l 0.225 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.277sec(train) 1.576sec(infer)
# Epoch 189 tst: l 0.250 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.258sec
# Epoch 190 tr: l 0.223 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.533sec(train) 1.563sec(infer)
# Epoch 190 tst: l 0.249 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 191 tr: l 0.223 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.222sec(train) 1.483sec(infer)
# Epoch 191 tst: l 0.249 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.148sec
# Epoch 192 tr: l 0.224 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.244sec(train) 1.489sec(infer)
# Epoch 192 tst: l 0.249 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.164sec
# Epoch 193 tr: l 0.223 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.310sec(train) 1.557sec(infer)
# Epoch 193 tst: l 0.246 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.154sec
# Epoch 194 tr: l 0.222 a 0.932 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.345sec(train) 1.487sec(infer)
# Epoch 194 tst: l 0.248 a 0.929 clct[50, 50, 50, 50] cl_acc 1.000  1.141sec
# Epoch 195 tr: l 0.221 a 0.933 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.146sec(train) 1.492sec(infer)
# Epoch 195 tst: l 0.247 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 196 tr: l 0.223 a 0.933 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.389sec(train) 1.483sec(infer)
# Epoch 196 tst: l 0.247 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.141sec
# Epoch 197 tr: l 0.221 a 0.933 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.169sec(train) 1.547sec(infer)
# Epoch 197 tst: l 0.246 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.148sec
# Epoch 198 tr: l 0.220 a 0.933 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.005sec(train) 1.470sec(infer)
# Epoch 198 tst: l 0.245 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.143sec
# Epoch 199 tr: l 0.219 a 0.934 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.242sec(train) 1.530sec(infer)
# Epoch 199 tst: l 0.247 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.225sec
# Epoch 200 tr: l 0.220 a 0.933 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.206sec(train) 1.490sec(infer)
# Epoch 200 tst: l 0.247 a 0.930 clct[50, 50, 50, 50] cl_acc 1.000  1.154sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 201 tr: l 0.217 a 0.934 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.248sec(train) 1.471sec(infer)
# Epoch 201 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.134sec
# Epoch 202 tr: l 0.217 a 0.934 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.471sec(train) 1.476sec(infer)
# Epoch 202 tst: l 0.242 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 203 tr: l 0.215 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.306sec(train) 1.476sec(infer)
# Epoch 203 tst: l 0.243 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.138sec
# Epoch 204 tr: l 0.214 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.533sec(train) 1.575sec(infer)
# Epoch 204 tst: l 0.244 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.352sec
# Epoch 205 tr: l 0.214 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.035sec(train) 1.505sec(infer)
# Epoch 205 tst: l 0.240 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.164sec
# Epoch 206 tr: l 0.216 a 0.934 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.708sec(train) 1.506sec(infer)
# Epoch 206 tst: l 0.244 a 0.931 clct[50, 50, 50, 50] cl_acc 1.000  1.223sec
# Epoch 207 tr: l 0.215 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.421sec(train) 1.626sec(infer)
# Epoch 207 tst: l 0.243 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.267sec
# Epoch 208 tr: l 0.215 a 0.934 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.905sec(train) 1.639sec(infer)
# Epoch 208 tst: l 0.239 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.251sec
# Epoch 209 tr: l 0.215 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.917sec(train) 1.484sec(infer)
# Epoch 209 tst: l 0.241 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 210 tr: l 0.213 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.656sec(train) 1.528sec(infer)
# Epoch 210 tst: l 0.237 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.183sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 211 tr: l 0.214 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.802sec(train) 1.485sec(infer)
# Epoch 211 tst: l 0.237 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.177sec
# Epoch 212 tr: l 0.213 a 0.935 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.637sec(train) 1.484sec(infer)
# Epoch 212 tst: l 0.237 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.160sec
# Epoch 213 tr: l 0.210 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.806sec(train) 1.651sec(infer)
# Epoch 213 tst: l 0.240 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.270sec
# Epoch 214 tr: l 0.211 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.120sec(train) 1.627sec(infer)
# Epoch 214 tst: l 0.237 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.284sec
# Epoch 215 tr: l 0.210 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.910sec(train) 1.492sec(infer)
# Epoch 215 tst: l 0.237 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.220sec
# Epoch 216 tr: l 0.210 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.641sec(train) 1.537sec(infer)
# Epoch 216 tst: l 0.236 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.231sec
# Epoch 217 tr: l 0.209 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.883sec(train) 1.512sec(infer)
# Epoch 217 tst: l 0.234 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.181sec
# Epoch 218 tr: l 0.210 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.852sec(train) 1.598sec(infer)
# Epoch 218 tst: l 0.238 a 0.932 clct[50, 50, 50, 50] cl_acc 1.000  1.188sec
# Epoch 219 tr: l 0.209 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.650sec(train) 1.536sec(infer)
# Epoch 219 tst: l 0.234 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.279sec
# Epoch 220 tr: l 0.209 a 0.936 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.853sec(train) 1.611sec(infer)
# Epoch 220 tst: l 0.235 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.177sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 221 tr: l 0.206 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.811sec(train) 1.606sec(infer)
# Epoch 221 tst: l 0.234 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 222 tr: l 0.208 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.686sec(train) 1.504sec(infer)
# Epoch 222 tst: l 0.235 a 0.933 clct[50, 50, 50, 50] cl_acc 1.000  1.188sec
# Epoch 223 tr: l 0.204 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.076sec(train) 1.496sec(infer)
# Epoch 223 tst: l 0.236 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.162sec
# Epoch 224 tr: l 0.206 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.157sec(train) 1.506sec(infer)
# Epoch 224 tst: l 0.233 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.157sec
# Epoch 225 tr: l 0.205 a 0.937 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.618sec(train) 1.612sec(infer)
# Epoch 225 tst: l 0.232 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.172sec
# Epoch 226 tr: l 0.205 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.759sec(train) 1.497sec(infer)
# Epoch 226 tst: l 0.232 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.146sec
# Epoch 227 tr: l 0.204 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.370sec(train) 1.494sec(infer)
# Epoch 227 tst: l 0.232 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 228 tr: l 0.204 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.373sec(train) 1.475sec(infer)
# Epoch 228 tst: l 0.230 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.182sec
# Epoch 229 tr: l 0.204 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.758sec(train) 1.489sec(infer)
# Epoch 229 tst: l 0.232 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 230 tr: l 0.203 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.682sec(train) 1.533sec(infer)
# Epoch 230 tst: l 0.230 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.193sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 231 tr: l 0.204 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.780sec(train) 1.551sec(infer)
# Epoch 231 tst: l 0.229 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# Epoch 232 tr: l 0.201 a 0.939 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.567sec(train) 1.499sec(infer)
# Epoch 232 tst: l 0.230 a 0.934 clct[50, 50, 50, 50] cl_acc 1.000  1.147sec
# Epoch 233 tr: l 0.200 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.439sec(train) 1.552sec(infer)
# Epoch 233 tst: l 0.229 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.202sec
# Epoch 234 tr: l 0.201 a 0.939 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.549sec(train) 1.600sec(infer)
# Epoch 234 tst: l 0.228 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.195sec
# Epoch 235 tr: l 0.203 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.511sec(train) 1.490sec(infer)
# Epoch 235 tst: l 0.229 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.135sec
# Epoch 236 tr: l 0.203 a 0.938 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.319sec(train) 1.503sec(infer)
# Epoch 236 tst: l 0.225 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.168sec
# Epoch 237 tr: l 0.201 a 0.939 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.719sec(train) 1.524sec(infer)
# Epoch 237 tst: l 0.227 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.205sec
# Epoch 238 tr: l 0.200 a 0.939 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.511sec(train) 1.512sec(infer)
# Epoch 238 tst: l 0.225 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.184sec
# Epoch 239 tr: l 0.198 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.311sec(train) 1.493sec(infer)
# Epoch 239 tst: l 0.226 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 240 tr: l 0.199 a 0.939 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.603sec(train) 1.488sec(infer)
# Epoch 240 tst: l 0.226 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.147sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 241 tr: l 0.198 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.876sec(train) 1.579sec(infer)
# Epoch 241 tst: l 0.228 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.267sec
# Epoch 242 tr: l 0.198 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.507sec(train) 1.516sec(infer)
# Epoch 242 tst: l 0.226 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.155sec
# Epoch 243 tr: l 0.197 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.508sec(train) 1.632sec(infer)
# Epoch 243 tst: l 0.224 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.192sec
# Epoch 244 tr: l 0.197 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.657sec(train) 1.513sec(infer)
# Epoch 244 tst: l 0.227 a 0.935 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 245 tr: l 0.196 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.469sec(train) 1.488sec(infer)
# Epoch 245 tst: l 0.224 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.174sec
# Epoch 246 tr: l 0.198 a 0.940 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.424sec(train) 1.505sec(infer)
# Epoch 246 tst: l 0.224 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.210sec
# Epoch 247 tr: l 0.194 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.606sec(train) 1.485sec(infer)
# Epoch 247 tst: l 0.222 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 248 tr: l 0.194 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.192sec(train) 1.605sec(infer)
# Epoch 248 tst: l 0.223 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.224sec
# Epoch 249 tr: l 0.194 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.949sec(train) 1.632sec(infer)
# Epoch 249 tst: l 0.222 a 0.936 clct[50, 50, 50, 50] cl_acc 1.000  1.198sec
# Epoch 250 tr: l 0.195 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.118sec(train) 1.504sec(infer)
# Epoch 250 tst: l 0.222 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.156sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 251 tr: l 0.193 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.593sec(train) 1.485sec(infer)
# Epoch 251 tst: l 0.221 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.202sec
# Epoch 252 tr: l 0.195 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.956sec(train) 1.545sec(infer)
# Epoch 252 tst: l 0.220 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.190sec
# Epoch 253 tr: l 0.192 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.744sec(train) 1.573sec(infer)
# Epoch 253 tst: l 0.219 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.170sec
# Epoch 254 tr: l 0.191 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.301sec(train) 1.496sec(infer)
# Epoch 254 tst: l 0.220 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.173sec
# Epoch 255 tr: l 0.193 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.336sec(train) 1.492sec(infer)
# Epoch 255 tst: l 0.220 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.207sec
# Epoch 256 tr: l 0.191 a 0.941 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.171sec(train) 1.496sec(infer)
# Epoch 256 tst: l 0.219 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.161sec
# Epoch 257 tr: l 0.191 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.018sec(train) 1.516sec(infer)
# Epoch 257 tst: l 0.218 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.191sec
# Epoch 258 tr: l 0.190 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.803sec(train) 1.503sec(infer)
# Epoch 258 tst: l 0.219 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.158sec
# Epoch 259 tr: l 0.189 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.583sec(train) 1.538sec(infer)
# Epoch 259 tst: l 0.218 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.169sec
# Epoch 260 tr: l 0.189 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.076sec(train) 1.482sec(infer)
# Epoch 260 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.151sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 261 tr: l 0.190 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.286sec(train) 1.509sec(infer)
# Epoch 261 tst: l 0.216 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.205sec
# Epoch 262 tr: l 0.190 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.745sec(train) 1.508sec(infer)
# Epoch 262 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.161sec
# Epoch 263 tr: l 0.191 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.543sec(train) 1.511sec(infer)
# Epoch 263 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.180sec
# Epoch 264 tr: l 0.188 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.606sec(train) 1.579sec(infer)
# Epoch 264 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.245sec
# Epoch 265 tr: l 0.187 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.437sec(train) 1.511sec(infer)
# Epoch 265 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 266 tr: l 0.186 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.558sec(train) 1.538sec(infer)
# Epoch 266 tst: l 0.217 a 0.937 clct[50, 50, 50, 50] cl_acc 1.000  1.194sec
# Epoch 267 tr: l 0.189 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.582sec(train) 1.500sec(infer)
# Epoch 267 tst: l 0.217 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.157sec
# Epoch 268 tr: l 0.188 a 0.942 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.762sec(train) 1.498sec(infer)
# Epoch 268 tst: l 0.215 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.182sec
# Epoch 269 tr: l 0.186 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.309sec(train) 1.543sec(infer)
# Epoch 269 tst: l 0.213 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.275sec
# Epoch 270 tr: l 0.185 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.522sec(train) 1.480sec(infer)
# Epoch 270 tst: l 0.213 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.147sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 271 tr: l 0.186 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.564sec(train) 1.520sec(infer)
# Epoch 271 tst: l 0.213 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.181sec
# Epoch 272 tr: l 0.184 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.574sec(train) 1.622sec(infer)
# Epoch 272 tst: l 0.212 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.168sec
# Epoch 273 tr: l 0.185 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.631sec(train) 1.624sec(infer)
# Epoch 273 tst: l 0.213 a 0.938 clct[50, 50, 50, 50] cl_acc 1.000  1.198sec
# Epoch 274 tr: l 0.182 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.655sec(train) 1.493sec(infer)
# Epoch 274 tst: l 0.212 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 275 tr: l 0.184 a 0.943 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.631sec(train) 1.528sec(infer)
# Epoch 275 tst: l 0.210 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.204sec
# Epoch 276 tr: l 0.183 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.669sec(train) 1.557sec(infer)
# Epoch 276 tst: l 0.210 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.165sec
# Epoch 277 tr: l 0.182 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.010sec(train) 1.592sec(infer)
# Epoch 277 tst: l 0.211 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.218sec
# Epoch 278 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 12.038sec(train) 1.506sec(infer)
# Epoch 278 tst: l 0.210 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.163sec
# Epoch 279 tr: l 0.182 a 0.944 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.810sec(train) 1.515sec(infer)
# Epoch 279 tst: l 0.212 a 0.939 clct[50, 50, 50, 50] cl_acc 1.000  1.208sec
# Epoch 280 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.507sec(train) 1.492sec(infer)
# Epoch 280 tst: l 0.209 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.131sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 281 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.236sec(train) 1.490sec(infer)
# Epoch 281 tst: l 0.211 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.149sec
# Epoch 282 tr: l 0.180 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.272sec(train) 1.499sec(infer)
# Epoch 282 tst: l 0.211 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.284sec
# Epoch 283 tr: l 0.181 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.373sec(train) 1.492sec(infer)
# Epoch 283 tst: l 0.208 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.144sec
# Epoch 284 tr: l 0.182 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.388sec(train) 1.485sec(infer)
# Epoch 284 tst: l 0.208 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.161sec
# Epoch 285 tr: l 0.180 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.351sec(train) 1.500sec(infer)
# Epoch 285 tst: l 0.207 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.159sec
# Epoch 286 tr: l 0.179 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.170sec(train) 1.485sec(infer)
# Epoch 286 tst: l 0.210 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.149sec
# Epoch 287 tr: l 0.180 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.066sec(train) 1.488sec(infer)
# Epoch 287 tst: l 0.208 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.149sec
# Epoch 288 tr: l 0.178 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.184sec(train) 1.478sec(infer)
# Epoch 288 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.153sec
# Epoch 289 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.363sec(train) 1.481sec(infer)
# Epoch 289 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 290 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.164sec(train) 1.475sec(infer)
# Epoch 290 tst: l 0.207 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.146sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# Epoch 291 tr: l 0.178 a 0.945 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.325sec(train) 1.478sec(infer)
# Epoch 291 tst: l 0.206 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.144sec
# Epoch 292 tr: l 0.176 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.181sec(train) 1.491sec(infer)
# Epoch 292 tst: l 0.206 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.149sec
# Epoch 293 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.391sec(train) 1.483sec(infer)
# Epoch 293 tst: l 0.207 a 0.940 clct[50, 50, 50, 50] cl_acc 1.000  1.150sec
# Epoch 294 tr: l 0.178 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.357sec(train) 1.489sec(infer)
# Epoch 294 tst: l 0.204 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.152sec
# Epoch 295 tr: l 0.177 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.393sec(train) 1.536sec(infer)
# Epoch 295 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.192sec
# Epoch 296 tr: l 0.175 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.532sec(train) 1.509sec(infer)
# Epoch 296 tst: l 0.203 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.190sec
# Epoch 297 tr: l 0.175 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.823sec(train) 1.570sec(infer)
# Epoch 297 tst: l 0.203 a 0.942 clct[50, 50, 50, 50] cl_acc 1.000  1.171sec
# Epoch 298 tr: l 0.174 a 0.946 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.298sec(train) 1.477sec(infer)
# Epoch 298 tst: l 0.205 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.133sec
# Epoch 299 tr: l 0.174 a 0.947 clct[300, 300, 300, 300] cl_acc 1.000  lr 0.100000 11.424sec(train) 1.492sec(infer)
# Epoch 299 tst: l 0.204 a 0.941 clct[50, 50, 50, 50] cl_acc 1.000  1.166sec
# result written at output\results.pickle
# checkpoint written at output\checkpoint.pt
# ---train cluster Ended in 1.21 hour (4342.774 sec)
