# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import ifca as IFCA

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
rc = ipp.Cluster(n=2).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/2 [00:00<?, ?engine/s]

# %%
seeds = [1111,1222,1333,1444,1555]
learning_rates = [0.1]

dfca_gi = []
ifca = []

# %%
# %%px --targets all
#
# import sys
# import os
# sys.path.append(os.getcwd())
#
# seeds = [1111,1222,1333,1444,1555]
# learning_rates = [0.1]
#
# dfca_gi = []
# ifca = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_gi.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-GI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_gi.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the ifca experiment

# %%
# %%px --target 1 --noblock
# import ifca as IFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config_ifca.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------IFCA, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = IFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ifca.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# DFCA-GI Experiment Outputs

# %%
rc.wait_interactive()
_.display_outputs()

dfca_gi = rc[0].pull('dfca_gi', block=True)
ifca = rc[1].pull('ifca', block=True)
# Out:
# unknown:   0%|          | 0/2 [00:00<?, ?tasks/s]
# Output for 1:
# 2025-06-01 21:35:09.148 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-06-01 21:35:09.148 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-06-01 21:35:09.150 [IPEngine] Registering with controller at tcp://127.0.0.1:44479
# 2025-06-01 21:35:09.153 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:60071', 'tcp://127.0.0.1:48105', 'tcp://127.0.0.1:52121']
# 2025-06-01 21:35:09.153 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60071
# 2025-06-01 21:35:09.153 [IPEngine.1] Connecting shell to tcp://127.0.0.1:48105
# 2025-06-01 21:35:09.153 [IPEngine.1] Connecting shell to tcp://127.0.0.1:52121
# 2025-06-01 21:35:09.153 [IPEngine.1] Starting nanny
# 2025-06-01 21:35:09.590 [KernelNanny.1] Starting kernel nanny for engine 1, pid=85604, nanny pid=85623
# 2025-06-01 21:35:09.590 [KernelNanny.1] Nanny watching parent pid 85604.
# 2025-06-01 21:35:09.662 [IPEngine.1] Loading IPython extension: storemagic
# 2025-06-01 21:35:09.664 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-06-01 21:35:09.668 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-06-01 21:35:09.668 [IPEngine.1] Completed registration with id 1
# 2025-06-01 21:35:14.377 [IPEngine.1] Handling execute_request: 2b7ce729-947bb9eb05ec77f4f84f8145_85303_2
# 2025-06-01 21:35:14.396 [IPEngine.1] Handling execute_request: 2b7ce729-947bb9eb05ec77f4f84f8145_85303_4
# 2025-06-02 15:07:21.577 [KernelNanny.1] Pipe closed, parent 85604 has status: zombie
# 2025-06-02 15:07:21.577 [KernelNanny.1] Notifying Hub that our parent has shut down
# ---------------------------------IFCA, lr: 0.1, seed: 1111---------------------------------
# config: {'m': 4800, 'm_test': 800, 'p': 4, 'n': 50, 'uneven': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1111, 'train_seed': 1111, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch -1 tr: l 2.286 a 0.145 clct[349, 936, 497, 3018] cl_acc 0.351  8.839sec
# Epoch -1 tst: l 2.285 a 0.148 clct[61, 147, 84, 508] cl_acc 0.336  1.266sec
# Epoch 0 tr: l 2.186 a 0.236 clct[587, 819, 1041, 2353] cl_acc 0.609  lr 0.100000 51.301sec(train) 10.245sec(infer)
# Epoch 0 tst: l 2.182 a 0.239 clct[109, 144, 181, 366] cl_acc 0.620  1.952sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 1 tr: l 1.979 a 0.431 clct[1164, 1096, 1209, 1331] cl_acc 0.927  lr 0.100000 41.661sec(train) 11.782sec(infer)
# Epoch 1 tst: l 1.970 a 0.436 clct[205, 181, 201, 213] cl_acc 0.930  1.977sec
# Epoch 2 tr: l 1.647 a 0.702 clct[1198, 1194, 1205, 1203] cl_acc 0.994  lr 0.100000 42.289sec(train) 11.777sec(infer)
# Epoch 2 tst: l 1.630 a 0.710 clct[202, 201, 201, 196] cl_acc 0.994  1.996sec
# Epoch 3 tr: l 1.330 a 0.764 clct[1199, 1201, 1202, 1198] cl_acc 0.997  lr 0.100000 41.971sec(train) 11.840sec(infer)
# Epoch 3 tst: l 1.307 a 0.773 clct[199, 201, 201, 199] cl_acc 0.998  1.980sec
# Epoch 4 tr: l 1.091 a 0.794 clct[1198, 1203, 1200, 1199] cl_acc 0.999  lr 0.100000 41.526sec(train) 11.779sec(infer)
# Epoch 4 tst: l 1.064 a 0.803 clct[199, 201, 201, 199] cl_acc 0.998  1.974sec
# Epoch 5 tr: l 0.924 a 0.814 clct[1198, 1203, 1200, 1199] cl_acc 0.999  lr 0.100000 42.013sec(train) 11.109sec(infer)
# Epoch 5 tst: l 0.896 a 0.822 clct[199, 201, 201, 199] cl_acc 0.998  1.837sec
# Epoch 6 tr: l 0.807 a 0.828 clct[1198, 1203, 1200, 1199] cl_acc 0.999  lr 0.100000 42.272sec(train) 10.649sec(infer)
# Epoch 6 tst: l 0.779 a 0.834 clct[199, 201, 201, 199] cl_acc 0.998  2.097sec
# Epoch 7 tr: l 0.724 a 0.837 clct[1197, 1203, 1201, 1199] cl_acc 0.999  lr 0.100000 40.677sec(train) 12.243sec(infer)
# Epoch 7 tst: l 0.695 a 0.845 clct[199, 202, 201, 198] cl_acc 0.996  1.991sec
# Epoch 8 tr: l 0.662 a 0.845 clct[1197, 1203, 1201, 1199] cl_acc 0.999  lr 0.100000 40.495sec(train) 12.073sec(infer)
# Epoch 8 tst: l 0.633 a 0.853 clct[199, 202, 201, 198] cl_acc 0.996  1.946sec
# Epoch 9 tr: l 0.615 a 0.851 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.130sec(train) 11.790sec(infer)
# Epoch 9 tst: l 0.586 a 0.859 clct[199, 202, 201, 198] cl_acc 0.996  1.974sec
# Epoch 10 tr: l 0.577 a 0.856 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.627sec(train) 11.749sec(infer)
# Epoch 10 tst: l 0.549 a 0.864 clct[199, 202, 201, 198] cl_acc 0.996  1.959sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 11 tr: l 0.547 a 0.860 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.065sec(train) 10.942sec(infer)
# Epoch 11 tst: l 0.519 a 0.869 clct[199, 202, 201, 198] cl_acc 0.996  1.853sec
# Epoch 12 tr: l 0.523 a 0.864 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.968sec(train) 11.517sec(infer)
# Epoch 12 tst: l 0.494 a 0.872 clct[199, 202, 201, 198] cl_acc 0.996  1.999sec
# Epoch 13 tr: l 0.502 a 0.867 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.776sec(train) 11.726sec(infer)
# Epoch 13 tst: l 0.474 a 0.875 clct[199, 202, 201, 198] cl_acc 0.996  1.966sec
# Epoch 14 tr: l 0.485 a 0.870 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.985sec(train) 11.694sec(infer)
# Epoch 14 tst: l 0.457 a 0.878 clct[199, 202, 201, 198] cl_acc 0.996  1.969sec
# Epoch 15 tr: l 0.470 a 0.872 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.798sec(train) 11.678sec(infer)
# Epoch 15 tst: l 0.442 a 0.880 clct[199, 202, 201, 198] cl_acc 0.996  2.016sec
# Epoch 16 tr: l 0.457 a 0.874 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.478sec(train) 12.001sec(infer)
# Epoch 16 tst: l 0.429 a 0.882 clct[199, 202, 201, 198] cl_acc 0.996  1.944sec
# Epoch 17 tr: l 0.445 a 0.876 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.550sec(train) 11.373sec(infer)
# Epoch 17 tst: l 0.418 a 0.884 clct[199, 202, 201, 198] cl_acc 0.996  1.851sec
# Epoch 18 tr: l 0.436 a 0.878 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.420sec(train) 12.065sec(infer)
# Epoch 18 tst: l 0.408 a 0.886 clct[199, 202, 201, 198] cl_acc 0.996  1.964sec
# Epoch 19 tr: l 0.427 a 0.880 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.781sec(train) 11.781sec(infer)
# Epoch 19 tst: l 0.400 a 0.887 clct[199, 202, 201, 198] cl_acc 0.996  1.978sec
# Epoch 20 tr: l 0.419 a 0.881 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.799sec(train) 11.691sec(infer)
# Epoch 20 tst: l 0.392 a 0.889 clct[199, 202, 201, 198] cl_acc 0.996  1.915sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 21 tr: l 0.412 a 0.882 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.100sec(train) 11.634sec(infer)
# Epoch 21 tst: l 0.385 a 0.890 clct[199, 202, 201, 198] cl_acc 0.996  1.940sec
# Epoch 22 tr: l 0.405 a 0.884 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.900sec(train) 11.871sec(infer)
# Epoch 22 tst: l 0.379 a 0.891 clct[199, 202, 201, 198] cl_acc 0.996  1.990sec
# Epoch 23 tr: l 0.399 a 0.885 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.542sec(train) 11.173sec(infer)
# Epoch 23 tst: l 0.373 a 0.893 clct[199, 202, 201, 198] cl_acc 0.996  1.866sec
# Epoch 24 tr: l 0.394 a 0.886 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.782sec(train) 11.690sec(infer)
# Epoch 24 tst: l 0.368 a 0.893 clct[199, 202, 201, 198] cl_acc 0.996  1.950sec
# Epoch 25 tr: l 0.389 a 0.887 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.847sec(train) 11.817sec(infer)
# Epoch 25 tst: l 0.363 a 0.894 clct[199, 202, 201, 198] cl_acc 0.996  2.097sec
# Epoch 26 tr: l 0.385 a 0.888 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.512sec(train) 12.095sec(infer)
# Epoch 26 tst: l 0.359 a 0.895 clct[199, 202, 201, 198] cl_acc 0.996  1.978sec
# Epoch 27 tr: l 0.381 a 0.889 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.526sec(train) 12.050sec(infer)
# Epoch 27 tst: l 0.354 a 0.896 clct[199, 202, 201, 198] cl_acc 0.996  1.930sec
# Epoch 28 tr: l 0.377 a 0.890 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.666sec(train) 11.870sec(infer)
# Epoch 28 tst: l 0.351 a 0.897 clct[199, 202, 201, 198] cl_acc 0.996  1.976sec
# Epoch 29 tr: l 0.373 a 0.891 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.727sec(train) 11.207sec(infer)
# Epoch 29 tst: l 0.347 a 0.897 clct[199, 202, 201, 198] cl_acc 0.996  1.883sec
# Epoch 30 tr: l 0.370 a 0.891 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.623sec(train) 11.691sec(infer)
# Epoch 30 tst: l 0.344 a 0.898 clct[199, 202, 201, 198] cl_acc 0.996  1.977sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 31 tr: l 0.366 a 0.892 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.757sec(train) 11.744sec(infer)
# Epoch 31 tst: l 0.341 a 0.899 clct[199, 202, 201, 198] cl_acc 0.996  1.971sec
# Epoch 32 tr: l 0.363 a 0.893 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.336sec(train) 11.709sec(infer)
# Epoch 32 tst: l 0.338 a 0.899 clct[199, 202, 201, 198] cl_acc 0.996  1.971sec
# Epoch 33 tr: l 0.361 a 0.893 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.007sec(train) 11.814sec(infer)
# Epoch 33 tst: l 0.335 a 0.900 clct[199, 202, 201, 198] cl_acc 0.996  1.956sec
# Epoch 34 tr: l 0.358 a 0.894 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.004sec(train) 11.860sec(infer)
# Epoch 34 tst: l 0.333 a 0.900 clct[199, 202, 201, 198] cl_acc 0.996  1.993sec
# Epoch 35 tr: l 0.355 a 0.895 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.656sec(train) 11.253sec(infer)
# Epoch 35 tst: l 0.331 a 0.901 clct[199, 202, 201, 198] cl_acc 0.996  1.860sec
# Epoch 36 tr: l 0.353 a 0.895 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.514sec(train) 12.109sec(infer)
# Epoch 36 tst: l 0.328 a 0.901 clct[199, 202, 201, 198] cl_acc 0.996  1.988sec
# Epoch 37 tr: l 0.351 a 0.896 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.622sec(train) 12.128sec(infer)
# Epoch 37 tst: l 0.326 a 0.902 clct[199, 202, 201, 198] cl_acc 0.996  1.971sec
# Epoch 38 tr: l 0.349 a 0.896 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.277sec(train) 11.762sec(infer)
# Epoch 38 tst: l 0.324 a 0.902 clct[199, 202, 201, 198] cl_acc 0.996  1.957sec
# Epoch 39 tr: l 0.346 a 0.897 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.326sec(train) 11.644sec(infer)
# Epoch 39 tst: l 0.322 a 0.903 clct[199, 202, 201, 198] cl_acc 0.996  1.969sec
# Epoch 40 tr: l 0.344 a 0.897 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.424sec(train) 11.724sec(infer)
# Epoch 40 tst: l 0.320 a 0.903 clct[199, 202, 201, 198] cl_acc 0.996  1.968sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 41 tr: l 0.342 a 0.898 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.204sec(train) 11.220sec(infer)
# Epoch 41 tst: l 0.318 a 0.903 clct[199, 202, 201, 198] cl_acc 0.996  1.871sec
# Epoch 42 tr: l 0.341 a 0.898 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.682sec(train) 11.739sec(infer)
# Epoch 42 tst: l 0.317 a 0.904 clct[199, 202, 201, 198] cl_acc 0.996  1.905sec
# Epoch 43 tr: l 0.339 a 0.899 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.816sec(train) 11.804sec(infer)
# Epoch 43 tst: l 0.315 a 0.904 clct[199, 202, 201, 198] cl_acc 0.996  1.989sec
# Epoch 44 tr: l 0.337 a 0.899 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.032sec(train) 11.795sec(infer)
# Epoch 44 tst: l 0.314 a 0.905 clct[199, 202, 201, 198] cl_acc 0.996  1.963sec
# Epoch 45 tr: l 0.335 a 0.900 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.398sec(train) 11.723sec(infer)
# Epoch 45 tst: l 0.312 a 0.905 clct[199, 202, 201, 198] cl_acc 0.996  2.036sec
# Epoch 46 tr: l 0.334 a 0.900 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.185sec(train) 12.097sec(infer)
# Epoch 46 tst: l 0.311 a 0.905 clct[199, 202, 201, 198] cl_acc 0.996  2.068sec
# Epoch 47 tr: l 0.332 a 0.901 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.096sec(train) 11.140sec(infer)
# Epoch 47 tst: l 0.309 a 0.906 clct[199, 202, 201, 198] cl_acc 0.996  1.871sec
# Epoch 48 tr: l 0.331 a 0.901 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.150sec(train) 12.122sec(infer)
# Epoch 48 tst: l 0.308 a 0.906 clct[199, 202, 201, 198] cl_acc 0.996  1.966sec
# Epoch 49 tr: l 0.329 a 0.902 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.010sec(train) 11.723sec(infer)
# Epoch 49 tst: l 0.307 a 0.906 clct[199, 202, 201, 198] cl_acc 0.996  1.932sec
# Epoch 50 tr: l 0.328 a 0.902 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.587sec(train) 11.746sec(infer)
# Epoch 50 tst: l 0.305 a 0.907 clct[199, 202, 201, 198] cl_acc 0.996  1.977sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 51 tr: l 0.327 a 0.902 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.919sec(train) 11.842sec(infer)
# Epoch 51 tst: l 0.304 a 0.907 clct[199, 202, 201, 198] cl_acc 0.996  1.989sec
# Epoch 52 tr: l 0.325 a 0.903 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.175sec(train) 11.826sec(infer)
# Epoch 52 tst: l 0.303 a 0.908 clct[199, 202, 201, 198] cl_acc 0.996  1.967sec
# Epoch 53 tr: l 0.324 a 0.903 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.817sec(train) 11.266sec(infer)
# Epoch 53 tst: l 0.302 a 0.908 clct[199, 202, 201, 198] cl_acc 0.996  1.884sec
# Epoch 54 tr: l 0.323 a 0.904 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.813sec(train) 11.795sec(infer)
# Epoch 54 tst: l 0.301 a 0.908 clct[199, 202, 201, 198] cl_acc 0.996  1.919sec
# Epoch 55 tr: l 0.322 a 0.904 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.774sec(train) 11.792sec(infer)
# Epoch 55 tst: l 0.299 a 0.909 clct[199, 202, 201, 198] cl_acc 0.996  1.911sec
# Epoch 56 tr: l 0.320 a 0.904 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.099sec(train) 11.940sec(infer)
# Epoch 56 tst: l 0.298 a 0.909 clct[199, 202, 201, 198] cl_acc 0.996  2.077sec
# Epoch 57 tr: l 0.319 a 0.905 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.519sec(train) 12.125sec(infer)
# Epoch 57 tst: l 0.297 a 0.909 clct[199, 202, 201, 198] cl_acc 0.996  1.977sec
# Epoch 58 tr: l 0.318 a 0.905 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.273sec(train) 12.287sec(infer)
# Epoch 58 tst: l 0.296 a 0.910 clct[199, 202, 201, 198] cl_acc 0.996  1.997sec
# Epoch 59 tr: l 0.317 a 0.905 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.026sec(train) 11.207sec(infer)
# Epoch 59 tst: l 0.295 a 0.910 clct[199, 202, 201, 198] cl_acc 0.996  1.873sec
# Epoch 60 tr: l 0.316 a 0.905 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.949sec(train) 11.744sec(infer)
# Epoch 60 tst: l 0.294 a 0.910 clct[199, 202, 201, 198] cl_acc 0.996  1.985sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 61 tr: l 0.315 a 0.906 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.862sec(train) 11.764sec(infer)
# Epoch 61 tst: l 0.293 a 0.910 clct[199, 202, 201, 198] cl_acc 0.996  1.970sec
# Epoch 62 tr: l 0.314 a 0.906 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.003sec(train) 11.792sec(infer)
# Epoch 62 tst: l 0.293 a 0.911 clct[199, 202, 201, 198] cl_acc 0.996  1.979sec
# Epoch 63 tr: l 0.313 a 0.906 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.793sec(train) 11.840sec(infer)
# Epoch 63 tst: l 0.292 a 0.911 clct[199, 202, 201, 198] cl_acc 0.996  1.946sec
# Epoch 64 tr: l 0.312 a 0.907 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.869sec(train) 11.488sec(infer)
# Epoch 64 tst: l 0.291 a 0.911 clct[199, 202, 201, 198] cl_acc 0.996  1.820sec
# Epoch 65 tr: l 0.311 a 0.907 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.473sec(train) 10.351sec(infer)
# Epoch 65 tst: l 0.290 a 0.912 clct[199, 202, 201, 198] cl_acc 0.996  1.894sec
# Epoch 66 tr: l 0.310 a 0.907 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.855sec(train) 11.773sec(infer)
# Epoch 66 tst: l 0.289 a 0.912 clct[199, 202, 201, 198] cl_acc 0.996  2.055sec
# Epoch 67 tr: l 0.309 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 41.808sec(train) 12.279sec(infer)
# Epoch 67 tst: l 0.288 a 0.912 clct[199, 202, 201, 198] cl_acc 0.996  1.983sec
# Epoch 68 tr: l 0.308 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.827sec(train) 12.230sec(infer)
# Epoch 68 tst: l 0.287 a 0.913 clct[199, 202, 201, 198] cl_acc 0.996  2.004sec
# Epoch 69 tr: l 0.307 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 40.829sec(train) 11.988sec(infer)
# Epoch 69 tst: l 0.287 a 0.913 clct[199, 202, 201, 198] cl_acc 0.996  1.964sec
# Epoch 70 tr: l 0.306 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.363sec(train) 10.891sec(infer)
# Epoch 70 tst: l 0.286 a 0.913 clct[199, 202, 201, 198] cl_acc 0.996  1.850sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 71 tr: l 0.305 a 0.909 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 42.002sec(train) 11.188sec(infer)
# Epoch 71 tst: l 0.285 a 0.914 clct[199, 202, 201, 198] cl_acc 0.996  1.968sec
# Epoch 72 tr: l 0.304 a 0.909 clct[1196, 1202, 1202, 1200] cl_acc 0.999  lr 0.100000 41.711sec(train) 11.758sec(infer)
# Epoch 72 tst: l 0.284 a 0.914 clct[199, 202, 201, 198] cl_acc 0.996  1.937sec
# Epoch 73 tr: l 0.303 a 0.909 clct[1196, 1202, 1202, 1200] cl_acc 0.999  lr 0.100000 41.886sec(train) 11.995sec(infer)
# Epoch 73 tst: l 0.284 a 0.914 clct[199, 202, 201, 198] cl_acc 0.996  1.971sec
# Epoch 74 tr: l 0.302 a 0.910 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.584sec(train) 11.787sec(infer)
# Epoch 74 tst: l 0.283 a 0.915 clct[199, 202, 201, 198] cl_acc 0.996  1.981sec
# Epoch 75 tr: l 0.301 a 0.910 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.399sec(train) 11.854sec(infer)
# Epoch 75 tst: l 0.282 a 0.915 clct[199, 202, 201, 198] cl_acc 0.996  2.023sec
# Epoch 76 tr: l 0.301 a 0.910 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.376sec(train) 11.345sec(infer)
# Epoch 76 tst: l 0.281 a 0.915 clct[199, 202, 201, 198] cl_acc 0.996  1.826sec
# Epoch 77 tr: l 0.300 a 0.910 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.218sec(train) 12.232sec(infer)
# Epoch 77 tst: l 0.281 a 0.916 clct[199, 202, 201, 198] cl_acc 0.996  1.978sec
# Epoch 78 tr: l 0.299 a 0.911 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.009sec(train) 12.275sec(infer)
# Epoch 78 tst: l 0.280 a 0.916 clct[199, 202, 201, 198] cl_acc 0.996  1.975sec
# Epoch 79 tr: l 0.298 a 0.911 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.267sec(train) 11.956sec(infer)
# Epoch 79 tst: l 0.279 a 0.916 clct[199, 202, 201, 198] cl_acc 0.996  2.008sec
# Epoch 80 tr: l 0.297 a 0.911 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.355sec(train) 11.822sec(infer)
# Epoch 80 tst: l 0.279 a 0.916 clct[199, 202, 201, 198] cl_acc 0.996  1.995sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 81 tr: l 0.297 a 0.911 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.763sec(train) 11.951sec(infer)
# Epoch 81 tst: l 0.278 a 0.916 clct[199, 202, 201, 198] cl_acc 0.996  2.000sec
# Epoch 82 tr: l 0.296 a 0.912 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.769sec(train) 11.254sec(infer)
# Epoch 82 tst: l 0.277 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  1.881sec
# Epoch 83 tr: l 0.295 a 0.912 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.964sec(train) 11.718sec(infer)
# Epoch 83 tst: l 0.277 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  1.967sec
# Epoch 84 tr: l 0.294 a 0.912 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.176sec(train) 11.717sec(infer)
# Epoch 84 tst: l 0.276 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  1.934sec
# Epoch 85 tr: l 0.293 a 0.912 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.755sec(train) 11.886sec(infer)
# Epoch 85 tst: l 0.275 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  1.968sec
# Epoch 86 tr: l 0.293 a 0.913 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.181sec(train) 11.788sec(infer)
# Epoch 86 tst: l 0.275 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  1.959sec
# Epoch 87 tr: l 0.292 a 0.913 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.194sec(train) 11.952sec(infer)
# Epoch 87 tst: l 0.274 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  2.044sec
# Epoch 88 tr: l 0.291 a 0.913 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.290sec(train) 11.252sec(infer)
# Epoch 88 tst: l 0.273 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  1.826sec
# Epoch 89 tr: l 0.290 a 0.913 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 39.748sec(train) 12.082sec(infer)
# Epoch 89 tst: l 0.273 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  1.983sec
# Epoch 90 tr: l 0.290 a 0.913 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 39.432sec(train) 12.059sec(infer)
# Epoch 90 tst: l 0.272 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  1.984sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 91 tr: l 0.289 a 0.914 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.670sec(train) 11.815sec(infer)
# Epoch 91 tst: l 0.272 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  1.954sec
# Epoch 92 tr: l 0.288 a 0.914 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.137sec(train) 11.768sec(infer)
# Epoch 92 tst: l 0.271 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  1.992sec
# Epoch 93 tr: l 0.288 a 0.914 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.196sec(train) 11.549sec(infer)
# Epoch 93 tst: l 0.270 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  1.823sec
# Epoch 94 tr: l 0.287 a 0.914 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.364sec(train) 11.042sec(infer)
# Epoch 94 tst: l 0.270 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  0.997sec
# Epoch 95 tr: l 0.286 a 0.915 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 40.873sec(train) 11.856sec(infer)
# Epoch 95 tst: l 0.269 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  1.945sec
# Epoch 96 tr: l 0.286 a 0.915 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 41.271sec(train) 11.694sec(infer)
# Epoch 96 tst: l 0.269 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  1.990sec
# Epoch 97 tr: l 0.285 a 0.915 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.012sec(train) 11.709sec(infer)
# Epoch 97 tst: l 0.268 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  1.949sec
# Epoch 98 tr: l 0.284 a 0.915 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.377sec(train) 11.785sec(infer)
# Epoch 98 tst: l 0.268 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  1.967sec
# Epoch 99 tr: l 0.284 a 0.915 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.818sec(train) 10.961sec(infer)
# Epoch 99 tst: l 0.267 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  1.879sec
# Epoch 100 tr: l 0.283 a 0.916 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.135sec(train) 12.036sec(infer)
# Epoch 100 tst: l 0.266 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  2.030sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 101 tr: l 0.282 a 0.916 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.914sec(train) 12.319sec(infer)
# Epoch 101 tst: l 0.266 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.943sec
# Epoch 102 tr: l 0.282 a 0.916 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.296sec(train) 12.075sec(infer)
# Epoch 102 tst: l 0.265 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.952sec
# Epoch 103 tr: l 0.281 a 0.916 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.798sec(train) 11.843sec(infer)
# Epoch 103 tst: l 0.265 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.950sec
# Epoch 104 tr: l 0.280 a 0.916 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.411sec(train) 11.949sec(infer)
# Epoch 104 tst: l 0.264 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.979sec
# Epoch 105 tr: l 0.280 a 0.917 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.897sec(train) 11.170sec(infer)
# Epoch 105 tst: l 0.264 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.872sec
# Epoch 106 tr: l 0.279 a 0.917 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.971sec(train) 11.653sec(infer)
# Epoch 106 tst: l 0.263 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.946sec
# Epoch 107 tr: l 0.278 a 0.917 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.222sec(train) 11.793sec(infer)
# Epoch 107 tst: l 0.263 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  1.933sec
# Epoch 108 tr: l 0.278 a 0.917 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.511sec(train) 11.759sec(infer)
# Epoch 108 tst: l 0.262 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.886sec
# Epoch 109 tr: l 0.277 a 0.917 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.122sec(train) 11.697sec(infer)
# Epoch 109 tst: l 0.262 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.934sec
# Epoch 110 tr: l 0.277 a 0.918 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.094sec(train) 11.733sec(infer)
# Epoch 110 tst: l 0.261 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.970sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 111 tr: l 0.276 a 0.918 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.102sec(train) 11.289sec(infer)
# Epoch 111 tst: l 0.261 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.830sec
# Epoch 112 tr: l 0.275 a 0.918 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.721sec(train) 12.074sec(infer)
# Epoch 112 tst: l 0.260 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  2.067sec
# Epoch 113 tr: l 0.275 a 0.918 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.447sec(train) 12.276sec(infer)
# Epoch 113 tst: l 0.260 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.960sec
# Epoch 114 tr: l 0.274 a 0.918 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.765sec(train) 12.257sec(infer)
# Epoch 114 tst: l 0.259 a 0.922 clct[200, 200, 202, 198] cl_acc 0.996  1.975sec
# Epoch 115 tr: l 0.273 a 0.919 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.373sec(train) 11.845sec(infer)
# Epoch 115 tst: l 0.259 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.970sec
# Epoch 116 tr: l 0.273 a 0.919 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.062sec(train) 11.861sec(infer)
# Epoch 116 tst: l 0.258 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.938sec
# Epoch 117 tr: l 0.272 a 0.919 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.342sec(train) 11.277sec(infer)
# Epoch 117 tst: l 0.258 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.876sec
# Epoch 118 tr: l 0.272 a 0.919 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.622sec(train) 11.847sec(infer)
# Epoch 118 tst: l 0.257 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.968sec
# Epoch 119 tr: l 0.271 a 0.919 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.108sec(train) 11.715sec(infer)
# Epoch 119 tst: l 0.257 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.941sec
# Epoch 120 tr: l 0.271 a 0.920 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.311sec(train) 11.903sec(infer)
# Epoch 120 tst: l 0.256 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.936sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 121 tr: l 0.270 a 0.920 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.343sec(train) 11.747sec(infer)
# Epoch 121 tst: l 0.256 a 0.923 clct[200, 200, 202, 198] cl_acc 0.996  1.980sec
# Epoch 122 tr: l 0.269 a 0.920 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.913sec(train) 11.917sec(infer)
# Epoch 122 tst: l 0.255 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.958sec
# Epoch 123 tr: l 0.269 a 0.920 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.727sec(train) 11.217sec(infer)
# Epoch 123 tst: l 0.255 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.841sec
# Epoch 124 tr: l 0.268 a 0.920 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.818sec(train) 12.181sec(infer)
# Epoch 124 tst: l 0.254 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.932sec
# Epoch 125 tr: l 0.268 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.771sec(train) 12.104sec(infer)
# Epoch 125 tst: l 0.254 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.990sec
# Epoch 126 tr: l 0.267 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.002sec(train) 11.892sec(infer)
# Epoch 126 tst: l 0.253 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  2.004sec
# Epoch 127 tr: l 0.267 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.159sec(train) 11.822sec(infer)
# Epoch 127 tst: l 0.253 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.954sec
# Epoch 128 tr: l 0.266 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.059sec(train) 11.427sec(infer)
# Epoch 128 tst: l 0.252 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  1.815sec
# Epoch 129 tr: l 0.265 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.248sec(train) 10.284sec(infer)
# Epoch 129 tst: l 0.252 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  1.940sec
# Epoch 130 tr: l 0.265 a 0.921 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.025sec(train) 11.941sec(infer)
# Epoch 130 tst: l 0.251 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  1.967sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 131 tr: l 0.264 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.017sec(train) 11.780sec(infer)
# Epoch 131 tst: l 0.251 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  1.955sec
# Epoch 132 tr: l 0.264 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.216sec(train) 11.800sec(infer)
# Epoch 132 tst: l 0.250 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  1.926sec
# Epoch 133 tr: l 0.263 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.108sec(train) 11.814sec(infer)
# Epoch 133 tst: l 0.250 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  2.008sec
# Epoch 134 tr: l 0.263 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.122sec(train) 10.913sec(infer)
# Epoch 134 tst: l 0.250 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  1.992sec
# Epoch 135 tr: l 0.262 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.604sec(train) 10.854sec(infer)
# Epoch 135 tst: l 0.249 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  2.125sec
# Epoch 136 tr: l 0.262 a 0.922 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.101sec(train) 12.354sec(infer)
# Epoch 136 tst: l 0.249 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.957sec
# Epoch 137 tr: l 0.261 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.728sec(train) 12.212sec(infer)
# Epoch 137 tst: l 0.248 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.996sec
# Epoch 138 tr: l 0.261 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.351sec(train) 11.814sec(infer)
# Epoch 138 tst: l 0.248 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.980sec
# Epoch 139 tr: l 0.260 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.412sec(train) 11.841sec(infer)
# Epoch 139 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.948sec
# Epoch 140 tr: l 0.260 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.757sec(train) 11.203sec(infer)
# Epoch 140 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.883sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 141 tr: l 0.259 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.910sec(train) 11.755sec(infer)
# Epoch 141 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.929sec
# Epoch 142 tr: l 0.259 a 0.923 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.141sec(train) 11.660sec(infer)
# Epoch 142 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.945sec
# Epoch 143 tr: l 0.258 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.986sec(train) 11.779sec(infer)
# Epoch 143 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  1.993sec
# Epoch 144 tr: l 0.258 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.922sec(train) 11.727sec(infer)
# Epoch 144 tst: l 0.245 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.982sec
# Epoch 145 tr: l 0.257 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.210sec(train) 11.913sec(infer)
# Epoch 145 tst: l 0.245 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.993sec
# Epoch 146 tr: l 0.256 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.116sec(train) 11.272sec(infer)
# Epoch 146 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.914sec
# Epoch 147 tr: l 0.256 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.076sec(train) 11.867sec(infer)
# Epoch 147 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  2.117sec
# Epoch 148 tr: l 0.255 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.813sec(train) 12.320sec(infer)
# Epoch 148 tst: l 0.243 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.947sec
# Epoch 149 tr: l 0.255 a 0.924 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.630sec(train) 12.170sec(infer)
# Epoch 149 tst: l 0.243 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.911sec
# Epoch 150 tr: l 0.254 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.370sec(train) 12.185sec(infer)
# Epoch 150 tst: l 0.243 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.949sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 151 tr: l 0.254 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.871sec(train) 11.886sec(infer)
# Epoch 151 tst: l 0.242 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.923sec
# Epoch 152 tr: l 0.253 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.158sec(train) 11.261sec(infer)
# Epoch 152 tst: l 0.242 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  1.871sec
# Epoch 153 tr: l 0.253 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.219sec(train) 11.888sec(infer)
# Epoch 153 tst: l 0.241 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.937sec
# Epoch 154 tr: l 0.253 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.040sec(train) 11.763sec(infer)
# Epoch 154 tst: l 0.241 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.971sec
# Epoch 155 tr: l 0.252 a 0.925 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.151sec(train) 11.799sec(infer)
# Epoch 155 tst: l 0.241 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.958sec
# Epoch 156 tr: l 0.252 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.903sec(train) 11.642sec(infer)
# Epoch 156 tst: l 0.240 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.966sec
# Epoch 157 tr: l 0.251 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.625sec(train) 11.791sec(infer)
# Epoch 157 tst: l 0.240 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.943sec
# Epoch 158 tr: l 0.251 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.226sec(train) 11.254sec(infer)
# Epoch 158 tst: l 0.239 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.883sec
# Epoch 159 tr: l 0.250 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.930sec(train) 11.719sec(infer)
# Epoch 159 tst: l 0.239 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.985sec
# Epoch 160 tr: l 0.250 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.607sec(train) 12.002sec(infer)
# Epoch 160 tst: l 0.239 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  2.123sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 161 tr: l 0.249 a 0.926 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.359sec(train) 12.262sec(infer)
# Epoch 161 tst: l 0.238 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  2.031sec
# Epoch 162 tr: l 0.249 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.860sec(train) 12.276sec(infer)
# Epoch 162 tst: l 0.238 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.961sec
# Epoch 163 tr: l 0.248 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.582sec(train) 12.162sec(infer)
# Epoch 163 tst: l 0.237 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  1.816sec
# Epoch 164 tr: l 0.248 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.620sec(train) 11.244sec(infer)
# Epoch 164 tst: l 0.237 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.876sec
# Epoch 165 tr: l 0.247 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.632sec(train) 11.939sec(infer)
# Epoch 165 tst: l 0.237 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.980sec
# Epoch 166 tr: l 0.247 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.914sec(train) 11.797sec(infer)
# Epoch 166 tst: l 0.236 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.989sec
# Epoch 167 tr: l 0.246 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.083sec(train) 11.907sec(infer)
# Epoch 167 tst: l 0.236 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.966sec
# Epoch 168 tr: l 0.246 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.936sec(train) 11.883sec(infer)
# Epoch 168 tst: l 0.235 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.986sec
# Epoch 169 tr: l 0.245 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.936sec(train) 11.207sec(infer)
# Epoch 169 tst: l 0.235 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.813sec
# Epoch 170 tr: l 0.245 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.078sec(train) 10.201sec(infer)
# Epoch 170 tst: l 0.235 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.976sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 171 tr: l 0.244 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.313sec(train) 11.974sec(infer)
# Epoch 171 tst: l 0.234 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.972sec
# Epoch 172 tr: l 0.244 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.138sec(train) 11.806sec(infer)
# Epoch 172 tst: l 0.234 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  1.962sec
# Epoch 173 tr: l 0.244 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.972sec(train) 11.999sec(infer)
# Epoch 173 tst: l 0.234 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  2.101sec
# Epoch 174 tr: l 0.243 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.575sec(train) 12.166sec(infer)
# Epoch 174 tst: l 0.233 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  2.065sec
# Epoch 175 tr: l 0.243 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.662sec(train) 11.379sec(infer)
# Epoch 175 tst: l 0.233 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.851sec
# Epoch 176 tr: l 0.242 a 0.928 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.405sec(train) 12.209sec(infer)
# Epoch 176 tst: l 0.232 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.969sec
# Epoch 177 tr: l 0.242 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 39.419sec(train) 12.152sec(infer)
# Epoch 177 tst: l 0.232 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.960sec
# Epoch 178 tr: l 0.241 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.132sec(train) 11.897sec(infer)
# Epoch 178 tst: l 0.232 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.974sec
# Epoch 179 tr: l 0.241 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.616sec(train) 11.892sec(infer)
# Epoch 179 tst: l 0.231 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.864sec
# Epoch 180 tr: l 0.240 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.837sec(train) 11.772sec(infer)
# Epoch 180 tst: l 0.231 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.896sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 181 tr: l 0.240 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.852sec(train) 10.864sec(infer)
# Epoch 181 tst: l 0.231 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.889sec
# Epoch 182 tr: l 0.240 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.000sec(train) 11.784sec(infer)
# Epoch 182 tst: l 0.230 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  1.988sec
# Epoch 183 tr: l 0.239 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.247sec(train) 11.837sec(infer)
# Epoch 183 tst: l 0.230 a 0.930 clct[200, 200, 201, 199] cl_acc 0.998  2.007sec
# Epoch 184 tr: l 0.239 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.768sec(train) 11.633sec(infer)
# Epoch 184 tst: l 0.229 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.954sec
# Epoch 185 tr: l 0.238 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.312sec(train) 11.853sec(infer)
# Epoch 185 tst: l 0.229 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.988sec
# Epoch 186 tr: l 0.238 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.243sec(train) 11.940sec(infer)
# Epoch 186 tst: l 0.229 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.988sec
# Epoch 187 tr: l 0.237 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.980sec(train) 11.263sec(infer)
# Epoch 187 tst: l 0.228 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.926sec
# Epoch 188 tr: l 0.237 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 41.532sec(train) 11.978sec(infer)
# Epoch 188 tst: l 0.228 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  2.124sec
# Epoch 189 tr: l 0.237 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 40.054sec(train) 12.306sec(infer)
# Epoch 189 tst: l 0.228 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.985sec
# Epoch 190 tr: l 0.236 a 0.930 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 39.431sec(train) 12.115sec(infer)
# Epoch 190 tst: l 0.227 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.962sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 191 tr: l 0.236 a 0.930 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 39.386sec(train) 12.150sec(infer)
# Epoch 191 tst: l 0.227 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.978sec
# Epoch 192 tr: l 0.235 a 0.930 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.793sec(train) 11.898sec(infer)
# Epoch 192 tst: l 0.227 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.981sec
# Epoch 193 tr: l 0.235 a 0.930 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.724sec(train) 11.271sec(infer)
# Epoch 193 tst: l 0.226 a 0.931 clct[200, 200, 201, 199] cl_acc 0.998  1.878sec
# Epoch 194 tr: l 0.234 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.097sec(train) 11.769sec(infer)
# Epoch 194 tst: l 0.226 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.975sec
# Epoch 195 tr: l 0.234 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.819sec(train) 11.780sec(infer)
# Epoch 195 tst: l 0.226 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.931sec
# Epoch 196 tr: l 0.234 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.901sec(train) 11.788sec(infer)
# Epoch 196 tst: l 0.225 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  2.012sec
# Epoch 197 tr: l 0.233 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.223sec(train) 11.859sec(infer)
# Epoch 197 tst: l 0.225 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.959sec
# Epoch 198 tr: l 0.233 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.150sec(train) 11.585sec(infer)
# Epoch 198 tst: l 0.225 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.824sec
# Epoch 199 tr: l 0.232 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.276sec(train) 11.022sec(infer)
# Epoch 199 tst: l 0.224 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.025sec
# Epoch 200 tr: l 0.232 a 0.931 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.890sec(train) 11.710sec(infer)
# Epoch 200 tst: l 0.224 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.971sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 201 tr: l 0.232 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.447sec(train) 12.045sec(infer)
# Epoch 201 tst: l 0.224 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  2.117sec
# Epoch 202 tr: l 0.231 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.045sec(train) 12.165sec(infer)
# Epoch 202 tst: l 0.223 a 0.932 clct[200, 200, 201, 199] cl_acc 0.998  1.966sec
# Epoch 203 tr: l 0.231 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 39.569sec(train) 12.306sec(infer)
# Epoch 203 tst: l 0.223 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.972sec
# Epoch 204 tr: l 0.230 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 39.764sec(train) 11.370sec(infer)
# Epoch 204 tst: l 0.223 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.788sec
# Epoch 205 tr: l 0.230 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.014sec(train) 10.386sec(infer)
# Epoch 205 tst: l 0.222 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.931sec
# Epoch 206 tr: l 0.230 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.937sec(train) 11.717sec(infer)
# Epoch 206 tst: l 0.222 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.943sec
# Epoch 207 tr: l 0.229 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.194sec(train) 11.713sec(infer)
# Epoch 207 tst: l 0.222 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  2.011sec
# Epoch 208 tr: l 0.229 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.955sec(train) 11.792sec(infer)
# Epoch 208 tst: l 0.221 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.958sec
# Epoch 209 tr: l 0.228 a 0.932 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.236sec(train) 11.897sec(infer)
# Epoch 209 tst: l 0.221 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  2.034sec
# Epoch 210 tr: l 0.228 a 0.933 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.239sec(train) 11.002sec(infer)
# Epoch 210 tst: l 0.221 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.878sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 211 tr: l 0.228 a 0.933 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.915sec(train) 11.914sec(infer)
# Epoch 211 tst: l 0.220 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  1.973sec
# Epoch 212 tr: l 0.227 a 0.933 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 40.999sec(train) 11.736sec(infer)
# Epoch 212 tst: l 0.220 a 0.933 clct[200, 200, 201, 199] cl_acc 0.998  2.007sec
# Epoch 213 tr: l 0.227 a 0.933 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 41.007sec(train) 11.807sec(infer)
# ...
# Epoch 193 tst: l 0.285 a 0.916 clct[199, 202, 399, 0] cl_acc 0.749  1.977sec
# Epoch 194 tr: l 0.291 a 0.914 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.708sec(train) 12.048sec(infer)
# Epoch 194 tst: l 0.285 a 0.916 clct[199, 202, 399, 0] cl_acc 0.749  2.020sec
# Epoch 195 tr: l 0.290 a 0.914 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.502sec(train) 11.868sec(infer)
# Epoch 195 tst: l 0.284 a 0.916 clct[199, 202, 399, 0] cl_acc 0.749  1.984sec
# Epoch 196 tr: l 0.290 a 0.914 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.972sec(train) 11.717sec(infer)
# Epoch 196 tst: l 0.283 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  1.971sec
# Epoch 197 tr: l 0.289 a 0.914 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.814sec(train) 11.951sec(infer)
# Epoch 197 tst: l 0.283 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  2.001sec
# Epoch 198 tr: l 0.288 a 0.914 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.757sec(train) 11.280sec(infer)
# Epoch 198 tst: l 0.282 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  1.882sec
# Epoch 199 tr: l 0.288 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.579sec(train) 11.662sec(infer)
# Epoch 199 tst: l 0.282 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  1.982sec
# Epoch 200 tr: l 0.287 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 41.126sec(train) 11.679sec(infer)
# Epoch 200 tst: l 0.281 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  1.972sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 201 tr: l 0.286 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.913sec(train) 11.746sec(infer)
# Epoch 201 tst: l 0.280 a 0.917 clct[199, 202, 399, 0] cl_acc 0.749  2.013sec
# Epoch 202 tr: l 0.286 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.907sec(train) 11.869sec(infer)
# Epoch 202 tst: l 0.280 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.993sec
# Epoch 203 tr: l 0.285 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 41.047sec(train) 11.425sec(infer)
# Epoch 203 tst: l 0.279 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.961sec
# Epoch 204 tr: l 0.284 a 0.915 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 44.303sec(train) 10.314sec(infer)
# Epoch 204 tst: l 0.279 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.930sec
# Epoch 205 tr: l 0.284 a 0.916 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.950sec(train) 11.764sec(infer)
# Epoch 205 tst: l 0.278 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.929sec
# Epoch 206 tr: l 0.283 a 0.916 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.616sec(train) 11.790sec(infer)
# Epoch 206 tst: l 0.278 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.966sec
# Epoch 207 tr: l 0.282 a 0.916 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.849sec(train) 11.786sec(infer)
# Epoch 207 tst: l 0.277 a 0.918 clct[199, 202, 399, 0] cl_acc 0.749  1.993sec
# Epoch 208 tr: l 0.282 a 0.916 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.578sec(train) 11.752sec(infer)
# Epoch 208 tst: l 0.276 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  1.989sec
# Epoch 209 tr: l 0.281 a 0.916 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.851sec(train) 11.100sec(infer)
# Epoch 209 tst: l 0.276 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  1.903sec
# Epoch 210 tr: l 0.280 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.670sec(train) 10.342sec(infer)
# Epoch 210 tst: l 0.275 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  2.024sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 211 tr: l 0.280 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.762sec(train) 12.194sec(infer)
# Epoch 211 tst: l 0.275 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  1.921sec
# Epoch 212 tr: l 0.279 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.673sec(train) 12.224sec(infer)
# Epoch 212 tst: l 0.274 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  1.976sec
# Epoch 213 tr: l 0.279 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.370sec(train) 12.023sec(infer)
# Epoch 213 tst: l 0.274 a 0.919 clct[199, 202, 399, 0] cl_acc 0.749  1.965sec
# Epoch 214 tr: l 0.278 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.159sec(train) 11.923sec(infer)
# Epoch 214 tst: l 0.273 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.990sec
# Epoch 215 tr: l 0.277 a 0.917 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.375sec(train) 10.898sec(infer)
# Epoch 215 tst: l 0.272 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.786sec
# Epoch 216 tr: l 0.277 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.454sec(train) 10.313sec(infer)
# Epoch 216 tst: l 0.272 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.967sec
# Epoch 217 tr: l 0.276 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.778sec(train) 11.759sec(infer)
# Epoch 217 tst: l 0.271 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.952sec
# Epoch 218 tr: l 0.276 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.860sec(train) 11.793sec(infer)
# Epoch 218 tst: l 0.271 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.929sec
# Epoch 219 tr: l 0.275 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.603sec(train) 11.790sec(infer)
# Epoch 219 tst: l 0.270 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.985sec
# Epoch 220 tr: l 0.274 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.713sec(train) 11.869sec(infer)
# Epoch 220 tst: l 0.270 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.983sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 221 tr: l 0.274 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.813sec(train) 10.913sec(infer)
# Epoch 221 tst: l 0.269 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.851sec
# Epoch 222 tr: l 0.273 a 0.918 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.642sec(train) 11.564sec(infer)
# Epoch 222 tst: l 0.269 a 0.920 clct[199, 202, 399, 0] cl_acc 0.749  1.948sec
# Epoch 223 tr: l 0.273 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.630sec(train) 11.866sec(infer)
# Epoch 223 tst: l 0.268 a 0.921 clct[199, 202, 399, 0] cl_acc 0.749  2.095sec
# Epoch 224 tr: l 0.272 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 41.068sec(train) 12.003sec(infer)
# Epoch 224 tst: l 0.268 a 0.921 clct[199, 202, 399, 0] cl_acc 0.749  2.092sec
# Epoch 225 tr: l 0.271 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.994sec(train) 12.197sec(infer)
# Epoch 225 tst: l 0.267 a 0.921 clct[199, 202, 399, 0] cl_acc 0.749  1.931sec
# Epoch 226 tr: l 0.271 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.672sec(train) 12.310sec(infer)
# Epoch 226 tst: l 0.267 a 0.921 clct[199, 202, 399, 0] cl_acc 0.749  1.992sec
# Epoch 227 tr: l 0.270 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.221sec(train) 11.465sec(infer)
# Epoch 227 tst: l 0.266 a 0.921 clct[199, 202, 399, 0] cl_acc 0.749  1.875sec
# Epoch 228 tr: l 0.270 a 0.919 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.169sec(train) 11.770sec(infer)
# Epoch 228 tst: l 0.266 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  1.930sec
# Epoch 229 tr: l 0.269 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.841sec(train) 11.642sec(infer)
# Epoch 229 tst: l 0.265 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  1.902sec
# Epoch 230 tr: l 0.269 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.566sec(train) 11.759sec(infer)
# Epoch 230 tst: l 0.265 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  1.963sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 231 tr: l 0.268 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.551sec(train) 11.921sec(infer)
# Epoch 231 tst: l 0.264 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  1.993sec
# Epoch 232 tr: l 0.268 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.697sec(train) 11.891sec(infer)
# Epoch 232 tst: l 0.264 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  2.018sec
# Epoch 233 tr: l 0.267 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.666sec(train) 11.283sec(infer)
# Epoch 233 tst: l 0.263 a 0.922 clct[199, 202, 399, 0] cl_acc 0.749  1.890sec
# Epoch 234 tr: l 0.266 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.274sec(train) 11.783sec(infer)
# Epoch 234 tst: l 0.263 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.970sec
# Epoch 235 tr: l 0.266 a 0.920 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.895sec(train) 11.919sec(infer)
# Epoch 235 tst: l 0.262 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.976sec
# Epoch 236 tr: l 0.265 a 0.921 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.630sec(train) 11.820sec(infer)
# Epoch 236 tst: l 0.262 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  2.115sec
# Epoch 237 tr: l 0.265 a 0.921 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 40.923sec(train) 12.094sec(infer)
# Epoch 237 tst: l 0.261 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  2.095sec
# Epoch 238 tr: l 0.264 a 0.921 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.553sec(train) 12.264sec(infer)
# Epoch 238 tst: l 0.261 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.811sec
# Epoch 239 tr: l 0.264 a 0.921 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.593sec(train) 11.151sec(infer)
# Epoch 239 tst: l 0.260 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.878sec
# Epoch 240 tr: l 0.263 a 0.921 clct[1202, 1199, 2377, 22] cl_acc 0.750  lr 0.100000 39.324sec(train) 11.856sec(infer)
# Epoch 240 tst: l 0.260 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  2.007sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 241 tr: l 0.263 a 0.921 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.086sec(train) 11.810sec(infer)
# Epoch 241 tst: l 0.259 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.921sec
# Epoch 242 tr: l 0.262 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.744sec(train) 11.722sec(infer)
# Epoch 242 tst: l 0.259 a 0.923 clct[199, 202, 399, 0] cl_acc 0.749  1.958sec
# Epoch 243 tr: l 0.262 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.911sec(train) 11.731sec(infer)
# Epoch 243 tst: l 0.258 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.953sec
# Epoch 244 tr: l 0.261 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.947sec(train) 10.864sec(infer)
# Epoch 244 tst: l 0.258 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.845sec
# Epoch 245 tr: l 0.261 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.820sec(train) 10.587sec(infer)
# Epoch 245 tst: l 0.258 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.924sec
# Epoch 246 tr: l 0.260 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.672sec(train) 11.906sec(infer)
# Epoch 246 tst: l 0.257 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.932sec
# Epoch 247 tr: l 0.260 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.339sec(train) 11.795sec(infer)
# Epoch 247 tst: l 0.257 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.954sec
# Epoch 248 tr: l 0.259 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.439sec(train) 11.805sec(infer)
# Epoch 248 tst: l 0.256 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  1.980sec
# Epoch 249 tr: l 0.259 a 0.922 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.370sec(train) 12.007sec(infer)
# Epoch 249 tst: l 0.256 a 0.924 clct[199, 202, 399, 0] cl_acc 0.749  2.089sec
# Epoch 250 tr: l 0.258 a 0.923 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.139sec(train) 11.239sec(infer)
# Epoch 250 tst: l 0.255 a 0.925 clct[199, 202, 399, 0] cl_acc 0.749  1.847sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 251 tr: l 0.258 a 0.923 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 39.368sec(train) 12.115sec(infer)
# Epoch 251 tst: l 0.255 a 0.925 clct[199, 202, 399, 0] cl_acc 0.749  1.974sec
# Epoch 252 tr: l 0.257 a 0.923 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 40.598sec(train) 11.845sec(infer)
# Epoch 252 tst: l 0.254 a 0.925 clct[199, 202, 399, 0] cl_acc 0.749  1.937sec
# Epoch 253 tr: l 0.257 a 0.923 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.561sec(train) 11.707sec(infer)
# Epoch 253 tst: l 0.254 a 0.925 clct[199, 202, 399, 0] cl_acc 0.749  1.959sec
# Epoch 254 tr: l 0.256 a 0.923 clct[1202, 1199, 2376, 23] cl_acc 0.750  lr 0.100000 41.444sec(train) 11.762sec(infer)
# Epoch 254 tst: l 0.254 a 0.925 clct[199, 202, 399, 0] cl_acc 0.749  1.926sec
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 9.41MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 263kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.33MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.15MB/s]
# Output for 0:
# 2025-06-01 21:35:09.053 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-06-01 21:35:09.053 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-06-01 21:35:09.055 [IPEngine] Registering with controller at tcp://127.0.0.1:44479
# 2025-06-01 21:35:09.059 [IPEngine.0] Shell_addrs: ['tcp://127.0.0.1:60071', 'tcp://127.0.0.1:48105', 'tcp://127.0.0.1:55847']
# 2025-06-01 21:35:09.059 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60071
# 2025-06-01 21:35:09.059 [IPEngine.0] Connecting shell to tcp://127.0.0.1:48105
# 2025-06-01 21:35:09.059 [IPEngine.0] Connecting shell to tcp://127.0.0.1:55847
# 2025-06-01 21:35:09.059 [IPEngine.0] Starting nanny
# 2025-06-01 21:35:09.487 [KernelNanny.0] Starting kernel nanny for engine 0, pid=85601, nanny pid=85619
# 2025-06-01 21:35:09.487 [KernelNanny.0] Nanny watching parent pid 85601.
# 2025-06-01 21:35:09.559 [IPEngine.0] Loading IPython extension: storemagic
# 2025-06-01 21:35:09.561 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-06-01 21:35:09.563 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-06-01 21:35:09.564 [IPEngine.0] Completed registration with id 0
# 2025-06-01 21:35:14.376 [IPEngine.0] Handling execute_request: 2b7ce729-947bb9eb05ec77f4f84f8145_85303_1
# 2025-06-01 21:35:14.388 [IPEngine.0] Handling execute_request: 2b7ce729-947bb9eb05ec77f4f84f8145_85303_3
# 2025-06-02 15:07:21.781 [KernelNanny.0] Pipe closed, parent 85601 has status: zombie
# 2025-06-02 15:07:21.782 [KernelNanny.0] Notifying Hub that our parent has shut down
# engine set stopped 1748806508: {'engines': {'1': {'exit_code': <Negsignal.SIGKILL: -9>, 'pid': 85604, 'identifier': '1'}, '0': {'exit_code': <Negsignal.SIGKILL: -9>, 'pid': 85601, 'identifier': '0'}}, 'exit_code': <Negsignal.SIGKILL: -9>}
# ---------------------------------------------------------------------------
# NoEnginesRegistered                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 rc.wait_interactive()
#       2 _.display_outputs()
# ----> 4 dfca_gi = rc[0].pull('dfca_gi', block=True)
#       5 ifca = rc[1].pull('ifca', block=True)
#
# File ~/.local/lib/python3.11/site-packages/ipyparallel/client/client.py:1336, in Client.__getitem__(self, key)
#    1334     raise TypeError(f"key by int/slice/iterable of ints only, not {type(key)}")
#    1335 else:
# -> 1336     return self.direct_view(key)
#
# File ~/.local/lib/python3.11/site-packages/ipyparallel/client/client.py:2075, in Client.direct_view(self, targets, **kwargs)
#    2073 # allow 'all' to be lazily evaluated at each execution
#    2074 if targets != 'all':
# -> 2075     targets = self._build_targets(targets)[1]
#    2076 if single:
#    2077     targets = targets[0]
#
# File ~/.local/lib/python3.11/site-packages/ipyparallel/client/client.py:699, in Client._build_targets(self, targets)
#     696 if not self._ids:
#     697     # flush notification socket if no engines yet, just in case
#     698     if not self.ids:
# --> 699         raise error.NoEnginesRegistered(
#     700             "Can't build targets without any engines"
#     701         )
#     703 if targets is None:
#     704     targets = self._ids
#
# NoEnginesRegistered: This operation requires engines. Try client.wait_for_engines(n) to wait for engines to register.

# %% [markdown]
# IFCA Experiment Outputs

# %%
__.display_outputs()
# Out:
# ---------------------------------DFCA-GI, lr: 0.1, seed: 1111---------------------------------
# config: {'m': 4800, 'm_test': 800, 'p': 4, 'n': 50, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1111, 'train_seed': 1111, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch -1 tr: l 2.286 a 0.145 clct[349, 936, 497, 3018] cl_acc 0.351  9.785sec
# Epoch -1 tst: l 2.285 a 0.171 clct[61, 147, 84, 508] cl_acc 0.336  6.985sec
# Epoch 0 tr: l 2.163 a 0.245 clct[678, 849, 984, 2289] cl_acc 0.606  lr 0.100000 312.810sec(train) 10.937sec(infer)
# Epoch 0 tst: l 2.181 a 0.254 clct[116, 150, 172, 362] cl_acc 0.629  7.985sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.945 a 0.455 clct[1134, 1110, 1186, 1370] cl_acc 0.910  lr 0.100000 304.489sec(train) 11.104sec(infer)
# Epoch 1 tst: l 1.973 a 0.442 clct[199, 182, 194, 225] cl_acc 0.922  7.634sec
# Epoch 2 tr: l 1.585 a 0.715 clct[1193, 1188, 1209, 1210] cl_acc 0.985  lr 0.100000 311.619sec(train) 11.364sec(infer)
# Epoch 2 tst: l 1.647 a 0.689 clct[199, 197, 197, 207] cl_acc 0.981  7.923sec
# Epoch 3 tr: l 1.253 a 0.782 clct[1194, 1201, 1203, 1202] cl_acc 0.995  lr 0.100000 304.029sec(train) 11.341sec(infer)
# Epoch 3 tst: l 1.334 a 0.757 clct[199, 201, 200, 200] cl_acc 0.995  7.710sec
# Epoch 4 tr: l 1.023 a 0.813 clct[1196, 1202, 1202, 1200] cl_acc 0.998  lr 0.100000 311.260sec(train) 11.238sec(infer)
# Epoch 4 tst: l 1.095 a 0.788 clct[199, 201, 201, 199] cl_acc 0.998  7.762sec
# Epoch 5 tr: l 0.860 a 0.833 clct[1197, 1203, 1201, 1199] cl_acc 0.998  lr 0.100000 308.981sec(train) 11.086sec(infer)
# Epoch 5 tst: l 0.924 a 0.808 clct[199, 201, 200, 200] cl_acc 0.996  7.862sec
# Epoch 6 tr: l 0.754 a 0.846 clct[1197, 1204, 1200, 1199] cl_acc 0.999  lr 0.100000 307.593sec(train) 11.233sec(infer)
# Epoch 6 tst: l 0.807 a 0.823 clct[199, 201, 201, 199] cl_acc 0.998  7.797sec
# Epoch 7 tr: l 0.668 a 0.857 clct[1197, 1204, 1201, 1198] cl_acc 0.999  lr 0.100000 313.394sec(train) 11.312sec(infer)
# Epoch 7 tst: l 0.718 a 0.835 clct[199, 201, 201, 199] cl_acc 0.998  7.888sec
# Epoch 8 tr: l 0.612 a 0.863 clct[1197, 1203, 1201, 1199] cl_acc 0.999  lr 0.100000 307.192sec(train) 11.215sec(infer)
# Epoch 8 tst: l 0.656 a 0.843 clct[199, 202, 201, 198] cl_acc 0.996  7.647sec
# Epoch 9 tr: l 0.569 a 0.868 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 306.857sec(train) 11.081sec(infer)
# Epoch 9 tst: l 0.606 a 0.851 clct[199, 202, 201, 198] cl_acc 0.996  7.788sec
# Epoch 10 tr: l 0.528 a 0.874 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.671sec(train) 11.011sec(infer)
# Epoch 10 tst: l 0.569 a 0.857 clct[199, 200, 201, 200] cl_acc 0.996  8.054sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.502 a 0.876 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.182sec(train) 10.943sec(infer)
# Epoch 11 tst: l 0.536 a 0.862 clct[199, 202, 201, 198] cl_acc 0.996  7.124sec
# Epoch 12 tr: l 0.479 a 0.880 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.020sec(train) 11.276sec(infer)
# Epoch 12 tst: l 0.510 a 0.866 clct[199, 202, 201, 198] cl_acc 0.996  7.787sec
# Epoch 13 tr: l 0.456 a 0.884 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 295.255sec(train) 11.313sec(infer)
# Epoch 13 tst: l 0.488 a 0.870 clct[199, 203, 200, 198] cl_acc 0.996  7.790sec
# Epoch 14 tr: l 0.441 a 0.886 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 304.687sec(train) 11.298sec(infer)
# Epoch 14 tst: l 0.472 a 0.873 clct[199, 202, 200, 199] cl_acc 0.998  7.829sec
# Epoch 15 tr: l 0.428 a 0.888 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.743sec(train) 11.075sec(infer)
# Epoch 15 tst: l 0.458 a 0.874 clct[199, 202, 201, 198] cl_acc 0.996  7.676sec
# Epoch 16 tr: l 0.411 a 0.892 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 293.971sec(train) 11.110sec(infer)
# Epoch 16 tst: l 0.443 a 0.877 clct[199, 202, 201, 198] cl_acc 0.996  7.592sec
# Epoch 17 tr: l 0.402 a 0.891 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.746sec(train) 11.180sec(infer)
# Epoch 17 tst: l 0.431 a 0.879 clct[199, 202, 201, 198] cl_acc 0.996  7.647sec
# Epoch 18 tr: l 0.392 a 0.895 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 305.593sec(train) 11.064sec(infer)
# Epoch 18 tst: l 0.420 a 0.881 clct[199, 202, 201, 198] cl_acc 0.996  7.787sec
# Epoch 19 tr: l 0.380 a 0.897 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 296.086sec(train) 11.324sec(infer)
# Epoch 19 tst: l 0.411 a 0.883 clct[199, 203, 200, 198] cl_acc 0.996  7.986sec
# Epoch 20 tr: l 0.376 a 0.897 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 296.698sec(train) 11.100sec(infer)
# Epoch 20 tst: l 0.404 a 0.884 clct[199, 203, 200, 198] cl_acc 0.995  7.828sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.368 a 0.898 clct[1197, 1202, 1201, 1200] cl_acc 0.999  lr 0.100000 299.855sec(train) 11.015sec(infer)
# Epoch 21 tst: l 0.396 a 0.886 clct[199, 202, 201, 198] cl_acc 0.996  7.681sec
# Epoch 22 tr: l 0.361 a 0.899 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.126sec(train) 10.968sec(infer)
# Epoch 22 tst: l 0.392 a 0.886 clct[199, 202, 201, 198] cl_acc 0.996  8.067sec
# Epoch 23 tr: l 0.357 a 0.900 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 291.827sec(train) 10.967sec(infer)
# Epoch 23 tst: l 0.383 a 0.889 clct[199, 203, 200, 198] cl_acc 0.995  7.724sec
# Epoch 24 tr: l 0.350 a 0.902 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 302.249sec(train) 11.104sec(infer)
# Epoch 24 tst: l 0.378 a 0.890 clct[199, 202, 201, 198] cl_acc 0.996  7.806sec
# Epoch 25 tr: l 0.348 a 0.901 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.254sec(train) 11.318sec(infer)
# Epoch 25 tst: l 0.375 a 0.890 clct[199, 202, 201, 198] cl_acc 0.996  7.669sec
# Epoch 26 tr: l 0.341 a 0.903 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.316sec(train) 11.150sec(infer)
# Epoch 26 tst: l 0.369 a 0.891 clct[199, 202, 201, 198] cl_acc 0.996  7.908sec
# Epoch 27 tr: l 0.339 a 0.903 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 306.046sec(train) 10.958sec(infer)
# Epoch 27 tst: l 0.365 a 0.892 clct[199, 203, 200, 198] cl_acc 0.995  7.834sec
# Epoch 28 tr: l 0.334 a 0.904 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 300.749sec(train) 10.944sec(infer)
# Epoch 28 tst: l 0.360 a 0.893 clct[199, 202, 201, 198] cl_acc 0.996  7.695sec
# Epoch 29 tr: l 0.329 a 0.906 clct[1196, 1202, 1201, 1201] cl_acc 0.999  lr 0.100000 299.706sec(train) 10.893sec(infer)
# Epoch 29 tst: l 0.358 a 0.893 clct[199, 202, 201, 198] cl_acc 0.996  8.135sec
# Epoch 30 tr: l 0.327 a 0.906 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 298.621sec(train) 11.265sec(infer)
# Epoch 30 tst: l 0.354 a 0.895 clct[199, 202, 201, 198] cl_acc 0.996  7.706sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 0.320 a 0.907 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.726sec(train) 11.095sec(infer)
# Epoch 31 tst: l 0.351 a 0.895 clct[199, 202, 201, 198] cl_acc 0.996  7.816sec
# Epoch 32 tr: l 0.321 a 0.907 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 295.230sec(train) 11.133sec(infer)
# Epoch 32 tst: l 0.349 a 0.896 clct[199, 202, 201, 198] cl_acc 0.996  7.742sec
# Epoch 33 tr: l 0.321 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 302.257sec(train) 11.105sec(infer)
# Epoch 33 tst: l 0.346 a 0.896 clct[199, 202, 201, 198] cl_acc 0.996  8.032sec
# Epoch 34 tr: l 0.319 a 0.908 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 300.670sec(train) 11.269sec(infer)
# Epoch 34 tst: l 0.345 a 0.896 clct[198, 203, 201, 198] cl_acc 0.994  7.761sec
# Epoch 35 tr: l 0.313 a 0.909 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 298.552sec(train) 11.205sec(infer)
# Epoch 35 tst: l 0.341 a 0.897 clct[199, 202, 201, 198] cl_acc 0.996  7.563sec
# Epoch 36 tr: l 0.312 a 0.910 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.468sec(train) 11.308sec(infer)
# Epoch 36 tst: l 0.338 a 0.898 clct[199, 202, 201, 198] cl_acc 0.996  7.946sec
# Epoch 37 tr: l 0.307 a 0.910 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 298.301sec(train) 11.096sec(infer)
# Epoch 37 tst: l 0.336 a 0.899 clct[199, 202, 201, 198] cl_acc 0.996  7.837sec
# Epoch 38 tr: l 0.306 a 0.912 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.028sec(train) 11.137sec(infer)
# Epoch 38 tst: l 0.334 a 0.899 clct[199, 203, 200, 198] cl_acc 0.996  7.841sec
# Epoch 39 tr: l 0.305 a 0.911 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 295.625sec(train) 11.018sec(infer)
# Epoch 39 tst: l 0.333 a 0.899 clct[199, 202, 201, 198] cl_acc 0.996  7.695sec
# Epoch 40 tr: l 0.307 a 0.911 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.197sec(train) 11.186sec(infer)
# Epoch 40 tst: l 0.331 a 0.900 clct[199, 202, 201, 198] cl_acc 0.996  7.905sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 41 tr: l 0.304 a 0.912 clct[1196, 1202, 1201, 1201] cl_acc 0.999  lr 0.100000 295.210sec(train) 11.233sec(infer)
# Epoch 41 tst: l 0.329 a 0.900 clct[199, 202, 201, 198] cl_acc 0.996  7.582sec
# Epoch 42 tr: l 0.302 a 0.911 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.038sec(train) 11.090sec(infer)
# Epoch 42 tst: l 0.326 a 0.901 clct[199, 202, 201, 198] cl_acc 0.996  7.828sec
# Epoch 43 tr: l 0.300 a 0.913 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.951sec(train) 11.336sec(infer)
# Epoch 43 tst: l 0.326 a 0.901 clct[199, 202, 201, 198] cl_acc 0.996  7.793sec
# Epoch 44 tr: l 0.297 a 0.912 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 305.362sec(train) 11.298sec(infer)
# Epoch 44 tst: l 0.323 a 0.901 clct[199, 202, 201, 198] cl_acc 0.996  7.675sec
# Epoch 45 tr: l 0.298 a 0.914 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.276sec(train) 11.209sec(infer)
# Epoch 45 tst: l 0.321 a 0.902 clct[199, 202, 201, 198] cl_acc 0.996  7.655sec
# Epoch 46 tr: l 0.295 a 0.914 clct[1196, 1202, 1201, 1201] cl_acc 0.999  lr 0.100000 300.714sec(train) 10.980sec(infer)
# Epoch 46 tst: l 0.319 a 0.902 clct[199, 203, 200, 198] cl_acc 0.996  7.984sec
# Epoch 47 tr: l 0.296 a 0.914 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 296.497sec(train) 10.960sec(infer)
# Epoch 47 tst: l 0.319 a 0.903 clct[199, 202, 201, 198] cl_acc 0.996  7.549sec
# Epoch 48 tr: l 0.288 a 0.916 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.990sec(train) 11.096sec(infer)
# Epoch 48 tst: l 0.317 a 0.903 clct[199, 202, 201, 198] cl_acc 0.996  7.830sec
# Epoch 49 tr: l 0.287 a 0.916 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.773sec(train) 11.327sec(infer)
# Epoch 49 tst: l 0.317 a 0.904 clct[199, 201, 201, 199] cl_acc 0.998  7.654sec
# Epoch 50 tr: l 0.292 a 0.915 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 304.469sec(train) 11.371sec(infer)
# Epoch 50 tst: l 0.315 a 0.904 clct[199, 202, 201, 198] cl_acc 0.996  7.689sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 51 tr: l 0.287 a 0.916 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 295.388sec(train) 11.133sec(infer)
# Epoch 51 tst: l 0.315 a 0.904 clct[200, 201, 201, 198] cl_acc 0.998  7.798sec
# Epoch 52 tr: l 0.284 a 0.917 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.544sec(train) 11.316sec(infer)
# Epoch 52 tst: l 0.313 a 0.905 clct[200, 201, 201, 198] cl_acc 0.998  7.632sec
# Epoch 53 tr: l 0.283 a 0.916 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 302.174sec(train) 11.067sec(infer)
# Epoch 53 tst: l 0.310 a 0.905 clct[200, 201, 201, 198] cl_acc 0.998  8.041sec
# Epoch 54 tr: l 0.283 a 0.917 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.403sec(train) 11.197sec(infer)
# Epoch 54 tst: l 0.309 a 0.906 clct[199, 202, 201, 198] cl_acc 0.996  7.833sec
# Epoch 55 tr: l 0.285 a 0.917 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 303.969sec(train) 11.190sec(infer)
# Epoch 55 tst: l 0.309 a 0.906 clct[199, 203, 200, 198] cl_acc 0.996  7.834sec
# Epoch 56 tr: l 0.281 a 0.917 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.357sec(train) 10.952sec(infer)
# Epoch 56 tst: l 0.308 a 0.906 clct[199, 201, 202, 198] cl_acc 0.995  7.551sec
# Epoch 57 tr: l 0.278 a 0.918 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.063sec(train) 11.497sec(infer)
# Epoch 57 tst: l 0.308 a 0.906 clct[201, 200, 201, 198] cl_acc 0.995  7.542sec
# Epoch 58 tr: l 0.280 a 0.918 clct[1196, 1202, 1201, 1201] cl_acc 0.999  lr 0.100000 303.819sec(train) 11.049sec(infer)
# Epoch 58 tst: l 0.305 a 0.907 clct[199, 203, 200, 198] cl_acc 0.996  7.605sec
# Epoch 59 tr: l 0.277 a 0.919 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.490sec(train) 11.294sec(infer)
# Epoch 59 tst: l 0.304 a 0.907 clct[199, 201, 202, 198] cl_acc 0.995  7.811sec
# Epoch 60 tr: l 0.277 a 0.918 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.610sec(train) 11.133sec(infer)
# Epoch 60 tst: l 0.304 a 0.907 clct[199, 201, 202, 198] cl_acc 0.995  8.031sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 61 tr: l 0.275 a 0.919 clct[1197, 1202, 1201, 1200] cl_acc 0.999  lr 0.100000 299.367sec(train) 11.018sec(infer)
# Epoch 61 tst: l 0.303 a 0.907 clct[199, 202, 201, 198] cl_acc 0.996  7.833sec
# Epoch 62 tr: l 0.272 a 0.920 clct[1196, 1202, 1201, 1201] cl_acc 0.999  lr 0.100000 306.139sec(train) 10.934sec(infer)
# Epoch 62 tst: l 0.301 a 0.909 clct[199, 201, 202, 198] cl_acc 0.995  7.791sec
# Epoch 63 tr: l 0.276 a 0.920 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.589sec(train) 11.423sec(infer)
# Epoch 63 tst: l 0.301 a 0.909 clct[199, 201, 202, 198] cl_acc 0.995  7.653sec
# Epoch 64 tr: l 0.273 a 0.920 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 298.578sec(train) 11.213sec(infer)
# Epoch 64 tst: l 0.301 a 0.909 clct[199, 201, 202, 198] cl_acc 0.995  7.546sec
# Epoch 65 tr: l 0.273 a 0.920 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 294.108sec(train) 11.275sec(infer)
# Epoch 65 tst: l 0.300 a 0.909 clct[199, 201, 202, 198] cl_acc 0.995  7.832sec
# Epoch 66 tr: l 0.272 a 0.920 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 297.241sec(train) 11.165sec(infer)
# Epoch 66 tst: l 0.299 a 0.910 clct[199, 201, 202, 198] cl_acc 0.995  7.666sec
# Epoch 67 tr: l 0.272 a 0.920 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 299.683sec(train) 11.097sec(infer)
# Epoch 67 tst: l 0.297 a 0.910 clct[199, 202, 201, 198] cl_acc 0.996  7.821sec
# Epoch 68 tr: l 0.270 a 0.921 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 305.518sec(train) 11.113sec(infer)
# Epoch 68 tst: l 0.297 a 0.909 clct[199, 201, 202, 198] cl_acc 0.995  7.788sec
# Epoch 69 tr: l 0.268 a 0.922 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 301.225sec(train) 10.969sec(infer)
# Epoch 69 tst: l 0.297 a 0.910 clct[199, 201, 202, 198] cl_acc 0.995  7.792sec
# Epoch 70 tr: l 0.268 a 0.922 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 296.425sec(train) 10.943sec(infer)
# Epoch 70 tst: l 0.294 a 0.911 clct[199, 201, 202, 198] cl_acc 0.995  7.639sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 71 tr: l 0.268 a 0.922 clct[1197, 1203, 1201, 1199] cl_acc 0.999  lr 0.100000 300.830sec(train) 10.964sec(infer)
# Epoch 71 tst: l 0.295 a 0.910 clct[200, 200, 202, 198] cl_acc 0.996  7.559sec
# Epoch 72 tr: l 0.265 a 0.921 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 298.434sec(train) 11.356sec(infer)
# Epoch 72 tst: l 0.296 a 0.910 clct[200, 200, 202, 198] cl_acc 0.996  7.660sec
# Epoch 73 tr: l 0.265 a 0.922 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 296.845sec(train) 11.325sec(infer)
# Epoch 73 tst: l 0.293 a 0.911 clct[199, 201, 202, 198] cl_acc 0.995  7.819sec
# Epoch 74 tr: l 0.267 a 0.922 clct[1196, 1203, 1201, 1200] cl_acc 0.999  lr 0.100000 304.456sec(train) 11.319sec(infer)
# Epoch 74 tst: l 0.292 a 0.911 clct[199, 202, 201, 198] cl_acc 0.996  7.660sec
# Epoch 75 tr: l 0.266 a 0.922 clct[1196, 1202, 1202, 1200] cl_acc 0.999  lr 0.100000 298.942sec(train) 11.116sec(infer)
# Epoch 75 tst: l 0.292 a 0.912 clct[199, 202, 201, 198] cl_acc 0.995  7.884sec
# Epoch 76 tr: l 0.265 a 0.922 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 301.673sec(train) 11.182sec(infer)
# Epoch 76 tst: l 0.291 a 0.912 clct[199, 201, 202, 198] cl_acc 0.995  7.821sec
# Epoch 77 tr: l 0.262 a 0.923 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 308.425sec(train) 10.977sec(infer)
# Epoch 77 tst: l 0.291 a 0.912 clct[199, 201, 202, 198] cl_acc 0.995  7.913sec
# Epoch 78 tr: l 0.263 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 301.996sec(train) 11.053sec(infer)
# Epoch 78 tst: l 0.289 a 0.913 clct[199, 201, 202, 198] cl_acc 0.995  7.693sec
# Epoch 79 tr: l 0.261 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.541sec(train) 11.243sec(infer)
# Epoch 79 tst: l 0.289 a 0.913 clct[199, 201, 202, 198] cl_acc 0.995  7.552sec
# Epoch 80 tr: l 0.262 a 0.923 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 303.447sec(train) 11.400sec(infer)
# Epoch 80 tst: l 0.288 a 0.913 clct[199, 201, 202, 198] cl_acc 0.995  7.560sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 81 tr: l 0.259 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 298.622sec(train) 11.075sec(infer)
# Epoch 81 tst: l 0.288 a 0.913 clct[199, 201, 202, 198] cl_acc 0.995  7.834sec
# Epoch 82 tr: l 0.256 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.627sec(train) 11.291sec(infer)
# Epoch 82 tst: l 0.286 a 0.914 clct[199, 201, 202, 198] cl_acc 0.995  7.679sec
# Epoch 83 tr: l 0.259 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 300.267sec(train) 8.880sec(infer)
# Epoch 83 tst: l 0.286 a 0.914 clct[199, 201, 202, 198] cl_acc 0.995  7.891sec
# Epoch 84 tr: l 0.259 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 295.269sec(train) 11.154sec(infer)
# Epoch 84 tst: l 0.285 a 0.914 clct[199, 201, 202, 198] cl_acc 0.995  7.719sec
# Epoch 85 tr: l 0.256 a 0.925 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.711sec(train) 11.072sec(infer)
# Epoch 85 tst: l 0.285 a 0.914 clct[199, 201, 202, 198] cl_acc 0.995  7.584sec
# Epoch 86 tr: l 0.254 a 0.925 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.446sec(train) 11.335sec(infer)
# Epoch 86 tst: l 0.285 a 0.914 clct[200, 201, 201, 198] cl_acc 0.996  8.080sec
# Epoch 87 tr: l 0.255 a 0.924 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 296.095sec(train) 11.205sec(infer)
# Epoch 87 tst: l 0.285 a 0.915 clct[199, 202, 201, 198] cl_acc 0.996  7.784sec
# Epoch 88 tr: l 0.256 a 0.925 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.330sec(train) 11.322sec(infer)
# Epoch 88 tst: l 0.282 a 0.915 clct[199, 201, 202, 198] cl_acc 0.995  7.628sec
# Epoch 89 tr: l 0.254 a 0.926 clct[1198, 1202, 1202, 1198] cl_acc 0.999  lr 0.100000 296.634sec(train) 10.892sec(infer)
# Epoch 89 tst: l 0.283 a 0.915 clct[199, 201, 202, 198] cl_acc 0.995  7.612sec
# Epoch 90 tr: l 0.252 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 298.446sec(train) 11.149sec(infer)
# Epoch 90 tst: l 0.282 a 0.915 clct[199, 201, 202, 198] cl_acc 0.995  7.670sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 91 tr: l 0.253 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 292.047sec(train) 11.140sec(infer)
# Epoch 91 tst: l 0.282 a 0.916 clct[199, 201, 202, 198] cl_acc 0.995  7.852sec
# Epoch 92 tr: l 0.252 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 302.955sec(train) 11.321sec(infer)
# Epoch 92 tst: l 0.281 a 0.916 clct[199, 201, 202, 198] cl_acc 0.995  7.664sec
# Epoch 93 tr: l 0.252 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 301.961sec(train) 11.272sec(infer)
# Epoch 93 tst: l 0.280 a 0.916 clct[199, 201, 202, 198] cl_acc 0.995  7.651sec
# Epoch 94 tr: l 0.251 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.185sec(train) 10.945sec(infer)
# Epoch 94 tst: l 0.280 a 0.916 clct[199, 201, 202, 198] cl_acc 0.995  7.688sec
# Epoch 95 tr: l 0.250 a 0.926 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 298.736sec(train) 11.032sec(infer)
# Epoch 95 tst: l 0.280 a 0.916 clct[199, 201, 202, 198] cl_acc 0.995  7.009sec
# Epoch 96 tr: l 0.249 a 0.927 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 293.859sec(train) 11.055sec(infer)
# Epoch 96 tst: l 0.279 a 0.916 clct[200, 200, 202, 198] cl_acc 0.996  8.069sec
# Epoch 97 tr: l 0.251 a 0.927 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.692sec(train) 11.040sec(infer)
# Epoch 97 tst: l 0.279 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  7.823sec
# Epoch 98 tr: l 0.250 a 0.927 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.907sec(train) 11.351sec(infer)
# Epoch 98 tst: l 0.277 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  7.664sec
# Epoch 99 tr: l 0.251 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 302.257sec(train) 11.092sec(infer)
# Epoch 99 tst: l 0.278 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  7.790sec
# Epoch 100 tr: l 0.247 a 0.927 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.592sec(train) 10.903sec(infer)
# Epoch 100 tst: l 0.276 a 0.917 clct[200, 200, 202, 198] cl_acc 0.996  7.835sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 101 tr: l 0.246 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 293.716sec(train) 11.051sec(infer)
# Epoch 101 tst: l 0.275 a 0.917 clct[199, 201, 202, 198] cl_acc 0.995  7.621sec
# Epoch 102 tr: l 0.250 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 301.916sec(train) 11.241sec(infer)
# Epoch 102 tst: l 0.275 a 0.918 clct[199, 201, 202, 198] cl_acc 0.995  7.634sec
# Epoch 103 tr: l 0.244 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 301.160sec(train) 11.343sec(infer)
# Epoch 103 tst: l 0.275 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  7.671sec
# Epoch 104 tr: l 0.246 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 300.925sec(train) 11.087sec(infer)
# Epoch 104 tst: l 0.275 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  8.011sec
# Epoch 105 tr: l 0.244 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.004sec(train) 11.386sec(infer)
# Epoch 105 tst: l 0.273 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  7.758sec
# Epoch 106 tr: l 0.245 a 0.927 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 297.640sec(train) 11.100sec(infer)
# Epoch 106 tst: l 0.272 a 0.918 clct[199, 201, 202, 198] cl_acc 0.995  7.546sec
# Epoch 107 tr: l 0.244 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 300.051sec(train) 11.317sec(infer)
# Epoch 107 tst: l 0.273 a 0.918 clct[200, 200, 202, 198] cl_acc 0.996  8.024sec
# Epoch 108 tr: l 0.244 a 0.929 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 297.911sec(train) 11.352sec(infer)
# Epoch 108 tst: l 0.273 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.846sec
# Epoch 109 tr: l 0.243 a 0.928 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 308.633sec(train) 11.045sec(infer)
# Epoch 109 tst: l 0.271 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.829sec
# Epoch 110 tr: l 0.242 a 0.929 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.853sec(train) 11.233sec(infer)
# Epoch 110 tst: l 0.272 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.646sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 111 tr: l 0.238 a 0.930 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 294.078sec(train) 11.339sec(infer)
# Epoch 111 tst: l 0.271 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.634sec
# Epoch 112 tr: l 0.241 a 0.929 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 299.786sec(train) 11.141sec(infer)
# Epoch 112 tst: l 0.270 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.902sec
# Epoch 113 tr: l 0.240 a 0.929 clct[1197, 1202, 1202, 1199] cl_acc 0.999  lr 0.100000 302.540sec(train) 11.298sec(infer)
# Epoch 113 tst: l 0.270 a 0.919 clct[200, 200, 202, 198] cl_acc 0.996  7.689sec
# Epoch 114 tr: l 0.240 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 300.018sec(train) 10.878sec(infer)
# Epoch 114 tst: l 0.269 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.676sec
# Epoch 115 tr: l 0.242 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 307.705sec(train) 11.422sec(infer)
# Epoch 115 tst: l 0.268 a 0.920 clct[200, 201, 201, 198] cl_acc 0.998  7.842sec
# Epoch 116 tr: l 0.241 a 0.929 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.818sec(train) 10.941sec(infer)
# Epoch 116 tst: l 0.268 a 0.920 clct[199, 201, 202, 198] cl_acc 0.995  7.533sec
# Epoch 117 tr: l 0.240 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.227sec(train) 10.988sec(infer)
# Epoch 117 tst: l 0.267 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.603sec
# Epoch 118 tr: l 0.239 a 0.930 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 304.968sec(train) 11.241sec(infer)
# Epoch 118 tst: l 0.268 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.530sec
# Epoch 119 tr: l 0.237 a 0.931 clct[1198, 1200, 1202, 1200] cl_acc 0.999  lr 0.100000 296.906sec(train) 11.096sec(infer)
# Epoch 119 tst: l 0.268 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.824sec
# Epoch 120 tr: l 0.234 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.088sec(train) 11.083sec(infer)
# Epoch 120 tst: l 0.268 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.962sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 121 tr: l 0.236 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 292.045sec(train) 11.186sec(infer)
# Epoch 121 tst: l 0.267 a 0.920 clct[200, 200, 202, 198] cl_acc 0.996  7.839sec
# Epoch 122 tr: l 0.236 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.865sec(train) 11.023sec(infer)
# Epoch 122 tst: l 0.265 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  7.666sec
# Epoch 123 tr: l 0.234 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 296.544sec(train) 10.847sec(infer)
# Epoch 123 tst: l 0.265 a 0.921 clct[200, 200, 202, 198] cl_acc 0.996  7.525sec
# Epoch 124 tr: l 0.238 a 0.931 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 302.613sec(train) 11.229sec(infer)
# Epoch 124 tst: l 0.265 a 0.921 clct[199, 201, 202, 198] cl_acc 0.995  7.552sec
# Epoch 125 tr: l 0.237 a 0.931 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 306.586sec(train) 11.052sec(infer)
# Epoch 125 tst: l 0.264 a 0.921 clct[199, 201, 201, 199] cl_acc 0.996  7.839sec
# Epoch 126 tr: l 0.233 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 301.937sec(train) 11.050sec(infer)
# Epoch 126 tst: l 0.264 a 0.921 clct[200, 200, 201, 199] cl_acc 0.998  7.813sec
# Epoch 127 tr: l 0.233 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 298.904sec(train) 11.332sec(infer)
# Epoch 127 tst: l 0.264 a 0.922 clct[199, 201, 201, 199] cl_acc 0.996  7.871sec
# Epoch 128 tr: l 0.234 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 300.718sec(train) 11.044sec(infer)
# Epoch 128 tst: l 0.263 a 0.922 clct[199, 201, 201, 199] cl_acc 0.996  7.675sec
# Epoch 129 tr: l 0.234 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 304.362sec(train) 10.983sec(infer)
# Epoch 129 tst: l 0.263 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  7.664sec
# Epoch 130 tr: l 0.232 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 297.946sec(train) 11.142sec(infer)
# Epoch 130 tst: l 0.262 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  7.600sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l 0.236 a 0.931 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 302.655sec(train) 11.576sec(infer)
# Epoch 131 tst: l 0.262 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  7.529sec
# Epoch 132 tr: l 0.233 a 0.932 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 301.551sec(train) 11.364sec(infer)
# Epoch 132 tst: l 0.260 a 0.922 clct[199, 201, 201, 199] cl_acc 0.996  7.808sec
# Epoch 133 tr: l 0.230 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 291.575sec(train) 11.207sec(infer)
# Epoch 133 tst: l 0.261 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  7.660sec
# Epoch 134 tr: l 0.230 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 300.628sec(train) 11.073sec(infer)
# Epoch 134 tst: l 0.260 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  7.840sec
# Epoch 135 tr: l 0.228 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 297.120sec(train) 11.019sec(infer)
# Epoch 135 tst: l 0.260 a 0.922 clct[200, 200, 201, 199] cl_acc 0.998  8.050sec
# Epoch 136 tr: l 0.230 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 301.785sec(train) 10.440sec(infer)
# Epoch 136 tst: l 0.260 a 0.923 clct[200, 201, 200, 199] cl_acc 0.996  6.381sec
# Epoch 137 tr: l 0.227 a 0.934 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 297.262sec(train) 11.290sec(infer)
# Epoch 137 tst: l 0.259 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.536sec
# Epoch 138 tr: l 0.229 a 0.934 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 298.013sec(train) 11.067sec(infer)
# Epoch 138 tst: l 0.259 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.920sec
# Epoch 139 tr: l 0.228 a 0.934 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.766sec(train) 11.162sec(infer)
# Epoch 139 tst: l 0.258 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.703sec
# Epoch 140 tr: l 0.228 a 0.933 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.318sec(train) 11.086sec(infer)
# Epoch 140 tst: l 0.258 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.845sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l 0.226 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 291.575sec(train) 10.883sec(infer)
# Epoch 141 tst: l 0.259 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.903sec
# Epoch 142 tr: l 0.229 a 0.933 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.342sec(train) 10.999sec(infer)
# Epoch 142 tst: l 0.256 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.527sec
# Epoch 143 tr: l 0.223 a 0.934 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 297.391sec(train) 11.100sec(infer)
# Epoch 143 tst: l 0.256 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.815sec
# Epoch 144 tr: l 0.224 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 293.946sec(train) 11.332sec(infer)
# Epoch 144 tst: l 0.257 a 0.923 clct[200, 200, 201, 199] cl_acc 0.998  7.841sec
# Epoch 145 tr: l 0.227 a 0.934 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 301.693sec(train) 11.327sec(infer)
# Epoch 145 tst: l 0.256 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.741sec
# Epoch 146 tr: l 0.224 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 296.635sec(train) 11.028sec(infer)
# Epoch 146 tst: l 0.256 a 0.924 clct[200, 200, 202, 198] cl_acc 0.996  7.826sec
# Epoch 147 tr: l 0.227 a 0.934 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.729sec(train) 10.877sec(infer)
# Epoch 147 tst: l 0.255 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.773sec
# Epoch 148 tr: l 0.227 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 299.183sec(train) 11.144sec(infer)
# Epoch 148 tst: l 0.255 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  8.097sec
# Epoch 149 tr: l 0.223 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 294.862sec(train) 11.117sec(infer)
# Epoch 149 tst: l 0.254 a 0.924 clct[200, 199, 201, 200] cl_acc 0.999  7.759sec
# Epoch 150 tr: l 0.222 a 0.936 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 299.875sec(train) 11.345sec(infer)
# Epoch 150 tst: l 0.253 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.633sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l 0.222 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 302.295sec(train) 11.123sec(infer)
# Epoch 151 tst: l 0.254 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.936sec
# Epoch 152 tr: l 0.221 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 304.564sec(train) 11.122sec(infer)
# Epoch 152 tst: l 0.253 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.819sec
# Epoch 153 tr: l 0.220 a 0.936 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 294.146sec(train) 10.890sec(infer)
# Epoch 153 tst: l 0.254 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  5.022sec
# Epoch 154 tr: l 0.222 a 0.935 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 301.023sec(train) 11.102sec(infer)
# Epoch 154 tst: l 0.253 a 0.924 clct[200, 200, 201, 199] cl_acc 0.998  7.814sec
# Epoch 155 tr: l 0.222 a 0.935 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 303.491sec(train) 11.086sec(infer)
# Epoch 155 tst: l 0.252 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.847sec
# Epoch 156 tr: l 0.221 a 0.936 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 306.742sec(train) 11.415sec(infer)
# Epoch 156 tst: l 0.251 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.857sec
# Epoch 157 tr: l 0.220 a 0.936 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 299.214sec(train) 11.107sec(infer)
# Epoch 157 tst: l 0.251 a 0.925 clct[199, 201, 201, 199] cl_acc 0.996  7.853sec
# Epoch 158 tr: l 0.220 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 304.176sec(train) 11.301sec(infer)
# Epoch 158 tst: l 0.251 a 0.925 clct[200, 201, 200, 199] cl_acc 0.999  7.678sec
# Epoch 159 tr: l 0.219 a 0.936 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 287.970sec(train) 11.063sec(infer)
# Epoch 159 tst: l 0.250 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  8.126sec
# Epoch 160 tr: l 0.220 a 0.936 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 296.333sec(train) 11.241sec(infer)
# Epoch 160 tst: l 0.251 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.640sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l 0.215 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 292.161sec(train) 11.308sec(infer)
# Epoch 161 tst: l 0.250 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.655sec
# Epoch 162 tr: l 0.219 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.587sec(train) 11.196sec(infer)
# Epoch 162 tst: l 0.249 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.662sec
# Epoch 163 tr: l 0.217 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.283sec(train) 11.302sec(infer)
# Epoch 163 tst: l 0.249 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.831sec
# Epoch 164 tr: l 0.218 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 295.790sec(train) 10.903sec(infer)
# Epoch 164 tst: l 0.249 a 0.925 clct[200, 200, 201, 199] cl_acc 0.998  7.720sec
# Epoch 165 tr: l 0.216 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 302.991sec(train) 11.051sec(infer)
# Epoch 165 tst: l 0.248 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.514sec
# Epoch 166 tr: l 0.219 a 0.936 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 299.254sec(train) 10.922sec(infer)
# Epoch 166 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.617sec
# Epoch 167 tr: l 0.218 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 303.150sec(train) 11.322sec(infer)
# Epoch 167 tst: l 0.248 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.590sec
# Epoch 168 tr: l 0.216 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.154sec(train) 11.065sec(infer)
# Epoch 168 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.978sec
# Epoch 169 tr: l 0.214 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.323sec(train) 11.064sec(infer)
# Epoch 169 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.838sec
# Epoch 170 tr: l 0.214 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 299.204sec(train) 11.070sec(infer)
# Epoch 170 tst: l 0.247 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.840sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 171 tr: l 0.214 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 297.165sec(train) 10.965sec(infer)
# Epoch 171 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.712sec
# Epoch 172 tr: l 0.215 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.664sec(train) 11.118sec(infer)
# Epoch 172 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.575sec
# Epoch 173 tr: l 0.216 a 0.937 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 295.495sec(train) 11.052sec(infer)
# Epoch 173 tst: l 0.246 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.827sec
# Epoch 174 tr: l 0.216 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 304.600sec(train) 11.075sec(infer)
# Epoch 174 tst: l 0.245 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.998sec
# Epoch 175 tr: l 0.213 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.000sec(train) 11.290sec(infer)
# Epoch 175 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.646sec
# Epoch 176 tr: l 0.212 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.299sec(train) 11.116sec(infer)
# Epoch 176 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.678sec
# Epoch 177 tr: l 0.212 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 297.494sec(train) 10.966sec(infer)
# Epoch 177 tst: l 0.245 a 0.926 clct[200, 200, 201, 199] cl_acc 0.998  7.692sec
# Epoch 178 tr: l 0.211 a 0.939 clct[1197, 1201, 1202, 1200] cl_acc 0.999  lr 0.100000 298.884sec(train) 11.306sec(infer)
# Epoch 178 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.556sec
# Epoch 179 tr: l 0.215 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 300.297sec(train) 11.067sec(infer)
# Epoch 179 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.824sec
# Epoch 180 tr: l 0.212 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.818sec(train) 11.057sec(infer)
# Epoch 180 tst: l 0.244 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.836sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 181 tr: l 0.213 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 296.478sec(train) 11.372sec(infer)
# Epoch 181 tst: l 0.243 a 0.927 clct[200, 200, 202, 198] cl_acc 0.996  7.700sec
# Epoch 182 tr: l 0.212 a 0.938 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 296.934sec(train) 10.962sec(infer)
# Epoch 182 tst: l 0.242 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  7.827sec
# Epoch 183 tr: l 0.208 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 296.392sec(train) 11.066sec(infer)
# Epoch 183 tst: l 0.242 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.545sec
# Epoch 184 tr: l 0.211 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 301.077sec(train) 11.344sec(infer)
# Epoch 184 tst: l 0.241 a 0.927 clct[200, 200, 201, 199] cl_acc 0.998  7.707sec
# Epoch 185 tr: l 0.210 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 299.792sec(train) 11.011sec(infer)
# Epoch 185 tst: l 0.241 a 0.928 clct[200, 201, 201, 198] cl_acc 0.998  7.840sec
# Epoch 186 tr: l 0.211 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 302.578sec(train) 11.324sec(infer)
# Epoch 186 tst: l 0.241 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  7.594sec
# Epoch 187 tr: l 0.209 a 0.940 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 296.933sec(train) 11.102sec(infer)
# Epoch 187 tst: l 0.241 a 0.928 clct[200, 201, 200, 199] cl_acc 0.999  7.820sec
# Epoch 188 tr: l 0.210 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 301.034sec(train) 11.196sec(infer)
# Epoch 188 tst: l 0.240 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  8.044sec
# Epoch 189 tr: l 0.209 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 306.955sec(train) 11.026sec(infer)
# Epoch 189 tst: l 0.240 a 0.928 clct[200, 201, 200, 199] cl_acc 0.999  7.866sec
# Epoch 190 tr: l 0.209 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 302.527sec(train) 10.890sec(infer)
# Epoch 190 tst: l 0.239 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  7.598sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 191 tr: l 0.212 a 0.939 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 301.073sec(train) 11.052sec(infer)
# Epoch 191 tst: l 0.240 a 0.928 clct[200, 200, 201, 199] cl_acc 0.998  7.568sec
# Epoch 192 tr: l 0.207 a 0.940 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 294.826sec(train) 11.323sec(infer)
# Epoch 192 tst: l 0.238 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  8.172sec
# Epoch 193 tr: l 0.206 a 0.940 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 290.264sec(train) 11.163sec(infer)
# Epoch 193 tst: l 0.238 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  7.879sec
# Epoch 194 tr: l 0.204 a 0.941 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.196sec(train) 11.008sec(infer)
# Epoch 194 tst: l 0.238 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  7.816sec
# Epoch 195 tr: l 0.203 a 0.941 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 295.490sec(train) 10.961sec(infer)
# Epoch 195 tst: l 0.238 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  7.651sec
# Epoch 196 tr: l 0.206 a 0.940 clct[1197, 1200, 1202, 1201] cl_acc 0.999  lr 0.100000 298.320sec(train) 11.315sec(infer)
# Epoch 196 tst: l 0.238 a 0.929 clct[200, 200, 201, 199] cl_acc 0.998  7.740sec
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 9.03MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 241kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.36MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.70MB/s]

# %% [markdown]
# IFCA Experiment Outputs

# %% [markdown]
# ## Plots

# %%
r_ifca = {}
r_dfca_gi = {}

r_ifca['test_loss'] = []
r_ifca['test_acc'] = []
r_ifca['cl_acc'] = []
r_ifca['train_loss'] = []
for i in range(len(learning_rates)):
    r_ifca['test_loss'].append(ifca[i][0])
    r_ifca['test_acc'].append(ifca[i][1])
    r_ifca['cl_acc'].append(ifca[i][2])
    r_ifca['train_loss'].append(ifca[i][3])

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
r_dfca_gi['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])
    r_dfca_gi['train_loss'].append(dfca_gi[i][3])



os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['train_loss'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['train_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Train Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_loss'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_test_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_acc'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('test accuracy')
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_test_acc.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['cl_acc'][l][:31], label='ifca', color='blue')
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('cluster acc')
    plt.title(f'Cluster Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_cluster_acc.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 9
#       7 r_ifca['train_loss'] = []
#       8 for i in range(len(learning_rates)):
# ----> 9     r_ifca['test_loss'].append(ifca[i][0])
#      10     r_ifca['test_acc'].append(ifca[i][1])
#      11     r_ifca['cl_acc'].append(ifca[i][2])
#
# IndexError: list index out of range
