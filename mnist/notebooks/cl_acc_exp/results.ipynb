# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_fixed.json

# %%
rc = ipp.Cluster(n=3).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]

# %%
learning_rates = [0.1]

ten = []
twentyfive = []
fifty = []

# %%
# %%px --targets all
#
# import sys
# import os
# import random
# sys.path.append(os.getcwd())
#
# random.seed(42)
# seeds = random.sample(range(10000), 5)
# learning_rates = [0.1]
#
# ten = []
# twentyfive = []
# fifty = []

# %% [markdown]
# Running with adaptive lambda

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 10
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ten.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running with fixed lambda

# %%
# %%px --target 1 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 25
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     twentyfive.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %%
# %%px --target 2 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 50
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     fifty.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# ### Outputs

# %%
rc.wait_interactive()
_.display_outputs()

ten = rc[0].pull('ten', block=True)
twentyfive = rc[1].pull('twentyfive', block=True)
fifty = rc[2].pull('fifty', block=True)
# Out:
# unknown:   0%|          | 0/3 [00:00<?, ?tasks/s]
# ---------------------------------R:50, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  4.536sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  3.407sec
# Epoch 0 tr: l 2.132 a 0.326 clct[np.int64(627), np.int64(234), np.int64(215), np.int64(124)] cl_acc 0.423  lr 0.100000 25.511sec(train) 4.427sec(infer)
# Epoch 0 tst: l 2.188 a 0.291 clct[np.int64(102), np.int64(44), np.int64(36), np.int64(18)] cl_acc 0.460  3.035sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.949 a 0.501 clct[np.int64(323), np.int64(376), np.int64(269), np.int64(232)] cl_acc 0.665  lr 0.100000 24.195sec(train) 4.570sec(infer)
# Epoch 1 tst: l 2.025 a 0.451 clct[np.int64(60), np.int64(59), np.int64(48), np.int64(33)] cl_acc 0.655  3.104sec
# Epoch 2 tr: l 1.688 a 0.644 clct[np.int64(254), np.int64(375), np.int64(279), np.int64(292)] cl_acc 0.862  lr 0.100000 24.026sec(train) 4.476sec(infer)
# Epoch 2 tst: l 1.770 a 0.603 clct[np.int64(36), np.int64(70), np.int64(47), np.int64(47)] cl_acc 0.860  3.013sec
# Epoch 3 tr: l 1.394 a 0.738 clct[np.int64(301), np.int64(308), np.int64(292), np.int64(299)] cl_acc 0.968  lr 0.100000 23.780sec(train) 4.466sec(infer)
# Epoch 3 tst: l 1.453 a 0.712 clct[np.int64(52), np.int64(51), np.int64(47), np.int64(50)] cl_acc 0.980  3.198sec
# Epoch 4 tr: l 1.114 a 0.788 clct[np.int64(301), np.int64(301), np.int64(296), np.int64(302)] cl_acc 0.994  lr 0.100000 23.313sec(train) 4.472sec(infer)
# Epoch 4 tst: l 1.170 a 0.772 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.332sec
# Epoch 5 tr: l 0.920 a 0.816 clct[np.int64(300), np.int64(301), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 24.498sec(train) 4.586sec(infer)
# Epoch 5 tst: l 0.964 a 0.803 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.017sec
# Epoch 6 tr: l 0.787 a 0.835 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 22.188sec(train) 4.421sec(infer)
# Epoch 6 tst: l 0.825 a 0.822 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.068sec
# Epoch 7 tr: l 0.699 a 0.847 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 24.471sec(train) 4.547sec(infer)
# Epoch 7 tst: l 0.726 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.037sec
# Epoch 8 tr: l 0.630 a 0.857 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.349sec(train) 4.446sec(infer)
# Epoch 8 tst: l 0.655 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.987sec
# Epoch 9 tr: l 0.576 a 0.865 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.685sec(train) 4.476sec(infer)
# Epoch 9 tst: l 0.603 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.209sec
# Epoch 10 tr: l 0.535 a 0.870 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.877sec(train) 4.563sec(infer)
# Epoch 10 tst: l 0.560 a 0.862 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.956sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.504 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.862sec(train) 4.470sec(infer)
# Epoch 11 tst: l 0.528 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.258sec
# Epoch 12 tr: l 0.478 a 0.879 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.795sec(train) 4.672sec(infer)
# Epoch 12 tst: l 0.500 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.215sec
# Epoch 13 tr: l 0.458 a 0.882 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.464sec(train) 4.954sec(infer)
# Epoch 13 tst: l 0.479 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.087sec
# Epoch 14 tr: l 0.439 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.175sec(train) 4.678sec(infer)
# Epoch 14 tst: l 0.460 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.974sec
# Epoch 15 tr: l 0.428 a 0.887 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.160sec(train) 4.391sec(infer)
# Epoch 15 tst: l 0.446 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.099sec
# Epoch 16 tr: l 0.411 a 0.890 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.366sec(train) 4.501sec(infer)
# Epoch 16 tst: l 0.431 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.056sec
# Epoch 17 tr: l 0.402 a 0.892 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.742sec(train) 4.452sec(infer)
# Epoch 17 tst: l 0.419 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.993sec
# Epoch 18 tr: l 0.389 a 0.894 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.566sec(train) 4.448sec(infer)
# Epoch 18 tst: l 0.408 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.014sec
# Epoch 19 tr: l 0.378 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.316sec(train) 4.717sec(infer)
# Epoch 19 tst: l 0.400 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.956sec
# Epoch 20 tr: l 0.369 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.184sec(train) 4.434sec(infer)
# Epoch 20 tst: l 0.392 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.087sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.365 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.766sec(train) 4.505sec(infer)
# Epoch 21 tst: l 0.386 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.057sec
# Epoch 22 tr: l 0.355 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.139sec(train) 4.508sec(infer)
# Epoch 22 tst: l 0.378 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.092sec
# Epoch 23 tr: l 0.352 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.319sec(train) 4.533sec(infer)
# Epoch 23 tst: l 0.372 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.365sec
# Epoch 24 tr: l 0.348 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.034sec(train) 4.963sec(infer)
# Epoch 24 tst: l 0.366 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.918sec
# Epoch 25 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.956sec(train) 4.420sec(infer)
# Epoch 25 tst: l 0.361 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.158sec
# Epoch 26 tr: l 0.339 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.070sec(train) 4.202sec(infer)
# Epoch 26 tst: l 0.356 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.894sec
# Epoch 27 tr: l 0.331 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.358sec(train) 4.683sec(infer)
# Epoch 27 tst: l 0.352 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.019sec
# Epoch 28 tr: l 0.327 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.849sec(train) 4.395sec(infer)
# Epoch 28 tst: l 0.349 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.036sec
# Epoch 29 tr: l 0.322 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.076sec(train) 4.561sec(infer)
# Epoch 29 tst: l 0.345 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.078sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.26 hour (943.041 sec)
# ---------------------------------R:50, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  4.624sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  3.004sec
# Epoch 0 tr: l 2.125 a 0.416 clct[np.int64(343), np.int64(47), np.int64(452), np.int64(358)] cl_acc 0.688  lr 0.100000 22.083sec(train) 4.496sec(infer)
# Epoch 0 tst: l 2.179 a 0.366 clct[np.int64(57), np.int64(7), np.int64(84), np.int64(52)] cl_acc 0.680  3.068sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.904 a 0.586 clct[np.int64(317), np.int64(77), np.int64(482), np.int64(324)] cl_acc 0.728  lr 0.100000 23.221sec(train) 4.538sec(infer)
# Epoch 1 tst: l 1.981 a 0.539 clct[np.int64(52), np.int64(11), np.int64(87), np.int64(50)] cl_acc 0.730  3.493sec
# Epoch 2 tr: l 1.633 a 0.662 clct[np.int64(302), np.int64(117), np.int64(479), np.int64(302)] cl_acc 0.740  lr 0.100000 23.837sec(train) 4.980sec(infer)
# Epoch 2 tst: l 1.721 a 0.631 clct[np.int64(51), np.int64(20), np.int64(79), np.int64(50)] cl_acc 0.750  3.097sec
# Epoch 3 tr: l 1.395 a 0.702 clct[np.int64(301), np.int64(147), np.int64(453), np.int64(299)] cl_acc 0.759  lr 0.100000 24.056sec(train) 4.358sec(infer)
# Epoch 3 tst: l 1.464 a 0.681 clct[np.int64(50), np.int64(26), np.int64(74), np.int64(50)] cl_acc 0.780  3.036sec
# Epoch 4 tr: l 1.183 a 0.741 clct[np.int64(300), np.int64(195), np.int64(406), np.int64(299)] cl_acc 0.810  lr 0.100000 23.195sec(train) 4.552sec(infer)
# Epoch 4 tst: l 1.247 a 0.724 clct[np.int64(50), np.int64(30), np.int64(70), np.int64(50)] cl_acc 0.790  3.111sec
# Epoch 5 tr: l 1.037 a 0.768 clct[np.int64(301), np.int64(256), np.int64(344), np.int64(299)] cl_acc 0.921  lr 0.100000 22.409sec(train) 4.613sec(infer)
# Epoch 5 tst: l 1.093 a 0.750 clct[np.int64(50), np.int64(39), np.int64(61), np.int64(50)] cl_acc 0.895  3.101sec
# Epoch 6 tr: l 0.888 a 0.803 clct[np.int64(301), np.int64(289), np.int64(311), np.int64(299)] cl_acc 0.983  lr 0.100000 22.532sec(train) 4.602sec(infer)
# Epoch 6 tst: l 0.934 a 0.791 clct[np.int64(50), np.int64(49), np.int64(51), np.int64(50)] cl_acc 0.985  3.107sec
# Epoch 7 tr: l 0.767 a 0.828 clct[np.int64(301), np.int64(295), np.int64(304), np.int64(300)] cl_acc 0.993  lr 0.100000 22.720sec(train) 4.649sec(infer)
# Epoch 7 tst: l 0.806 a 0.817 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.957sec
# Epoch 8 tr: l 0.679 a 0.843 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.998  lr 0.100000 24.729sec(train) 4.739sec(infer)
# Epoch 8 tst: l 0.708 a 0.837 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.131sec
# Epoch 9 tr: l 0.618 a 0.854 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.279sec(train) 4.648sec(infer)
# Epoch 9 tst: l 0.643 a 0.848 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.020sec
# Epoch 10 tr: l 0.565 a 0.863 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.406sec(train) 4.473sec(infer)
# Epoch 10 tst: l 0.594 a 0.857 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.104sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.529 a 0.869 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.362sec(train) 4.516sec(infer)
# Epoch 11 tst: l 0.556 a 0.863 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.201sec
# Epoch 12 tr: l 0.497 a 0.873 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 22.272sec(train) 4.671sec(infer)
# Epoch 12 tst: l 0.524 a 0.869 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.009sec
# Epoch 13 tr: l 0.473 a 0.878 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 24.031sec(train) 4.507sec(infer)
# Epoch 13 tst: l 0.501 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.115sec
# Epoch 14 tr: l 0.455 a 0.882 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 22.425sec(train) 4.522sec(infer)
# Epoch 14 tst: l 0.478 a 0.877 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.054sec
# Epoch 15 tr: l 0.434 a 0.884 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.676sec(train) 4.530sec(infer)
# Epoch 15 tst: l 0.460 a 0.880 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.264sec
# Epoch 16 tr: l 0.418 a 0.887 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 22.302sec(train) 5.063sec(infer)
# Epoch 16 tst: l 0.445 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.006sec
# Epoch 17 tr: l 0.405 a 0.891 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 21.557sec(train) 4.819sec(infer)
# Epoch 17 tst: l 0.433 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.003sec
# Epoch 18 tr: l 0.392 a 0.893 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 19.525sec(train) 4.530sec(infer)
# Epoch 18 tst: l 0.422 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.356sec
# Epoch 19 tr: l 0.384 a 0.893 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.105sec(train) 7.073sec(infer)
# Epoch 19 tst: l 0.413 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.941sec
# Epoch 20 tr: l 0.375 a 0.896 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.767sec(train) 9.667sec(infer)
# Epoch 20 tst: l 0.404 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.651sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.369 a 0.897 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 25.889sec(train) 9.515sec(infer)
# Epoch 21 tst: l 0.396 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  7.039sec
# Epoch 22 tr: l 0.362 a 0.899 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 25.803sec(train) 10.214sec(infer)
# Epoch 22 tst: l 0.387 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  7.568sec
# Epoch 23 tr: l 0.355 a 0.899 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 24.821sec(train) 9.724sec(infer)
# Epoch 23 tst: l 0.381 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  7.170sec
# Epoch 24 tr: l 0.348 a 0.901 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 23.909sec(train) 11.204sec(infer)
# Epoch 24 tst: l 0.376 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  19.951sec
# Epoch 25 tr: l 0.343 a 0.901 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 31.158sec(train) 43.224sec(infer)
# Epoch 25 tst: l 0.372 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.507sec
# Epoch 26 tr: l 0.338 a 0.904 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.344sec(train) 45.317sec(infer)
# Epoch 26 tst: l 0.367 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.888sec
# Epoch 27 tr: l 0.332 a 0.904 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 31.776sec(train) 42.216sec(infer)
# Epoch 27 tst: l 0.362 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.212sec
# Epoch 28 tr: l 0.330 a 0.905 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.697sec(train) 41.579sec(infer)
# Epoch 28 tst: l 0.359 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.676sec
# Epoch 29 tr: l 0.327 a 0.905 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 31.176sec(train) 46.141sec(infer)
# Epoch 29 tst: l 0.353 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.909sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.38 hour (1380.452 sec)
# ---------------------------------R:50, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  43.753sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  31.116sec
# Epoch 0 tr: l 2.123 a 0.422 clct[np.int64(331), np.int64(386), np.int64(340), np.int64(143)] cl_acc 0.727  lr 0.100000 29.922sec(train) 45.808sec(infer)
# Epoch 0 tst: l 2.175 a 0.372 clct[np.int64(52), np.int64(61), np.int64(60), np.int64(27)] cl_acc 0.760  29.016sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.894 a 0.618 clct[np.int64(306), np.int64(310), np.int64(301), np.int64(283)] cl_acc 0.912  lr 0.100000 30.407sec(train) 44.491sec(infer)
# Epoch 1 tst: l 1.960 a 0.583 clct[np.int64(52), np.int64(54), np.int64(48), np.int64(46)] cl_acc 0.950  30.791sec
# Epoch 2 tr: l 1.574 a 0.728 clct[np.int64(304), np.int64(296), np.int64(301), np.int64(299)] cl_acc 0.978  lr 0.100000 30.710sec(train) 44.731sec(infer)
# Epoch 2 tst: l 1.659 a 0.693 clct[np.int64(51), np.int64(49), np.int64(48), np.int64(52)] cl_acc 0.985  30.586sec
# Epoch 3 tr: l 1.264 a 0.779 clct[np.int64(300), np.int64(298), np.int64(300), np.int64(302)] cl_acc 0.993  lr 0.100000 31.501sec(train) 42.470sec(infer)
# Epoch 3 tst: l 1.329 a 0.765 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.424sec
# Epoch 4 tr: l 1.014 a 0.814 clct[np.int64(300), np.int64(299), np.int64(301), np.int64(300)] cl_acc 0.997  lr 0.100000 30.737sec(train) 46.045sec(infer)
# Epoch 4 tst: l 1.091 a 0.796 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.742sec
# Epoch 5 tr: l 0.854 a 0.832 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.996sec(train) 43.644sec(infer)
# Epoch 5 tst: l 0.913 a 0.820 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.862sec
# Epoch 6 tr: l 0.737 a 0.846 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.182sec(train) 44.607sec(infer)
# Epoch 6 tst: l 0.793 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.501sec
# Epoch 7 tr: l 0.656 a 0.857 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.864sec(train) 46.113sec(infer)
# Epoch 7 tst: l 0.710 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.896sec
# Epoch 8 tr: l 0.604 a 0.862 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.894sec(train) 44.005sec(infer)
# Epoch 8 tst: l 0.646 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.145sec
# Epoch 9 tr: l 0.558 a 0.869 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.384sec(train) 43.626sec(infer)
# Epoch 9 tst: l 0.598 a 0.862 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.569sec
# Epoch 10 tr: l 0.519 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 32.007sec(train) 46.389sec(infer)
# Epoch 10 tst: l 0.562 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.064sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.492 a 0.878 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.562sec(train) 43.576sec(infer)
# Epoch 11 tst: l 0.532 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.845sec
# Epoch 12 tr: l 0.471 a 0.881 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.853sec(train) 45.569sec(infer)
# Epoch 12 tst: l 0.509 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.319sec
# Epoch 13 tr: l 0.443 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.103sec(train) 45.514sec(infer)
# Epoch 13 tst: l 0.489 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.737sec
# Epoch 14 tr: l 0.429 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.177sec(train) 45.474sec(infer)
# Epoch 14 tst: l 0.472 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.385sec
# Epoch 15 tr: l 0.419 a 0.889 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.930sec(train) 42.577sec(infer)
# Epoch 15 tst: l 0.457 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.745sec
# Epoch 16 tr: l 0.405 a 0.891 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 32.302sec(train) 46.908sec(infer)
# Epoch 16 tst: l 0.446 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.366sec
# Epoch 17 tr: l 0.397 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.050sec(train) 44.264sec(infer)
# Epoch 17 tst: l 0.434 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.854sec
# Epoch 18 tr: l 0.385 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.800sec(train) 43.777sec(infer)
# Epoch 18 tst: l 0.425 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.313sec
# Epoch 19 tr: l 0.376 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.849sec(train) 46.044sec(infer)
# Epoch 19 tst: l 0.416 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.874sec
# Epoch 20 tr: l 0.371 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.353sec(train) 47.541sec(infer)
# Epoch 20 tst: l 0.408 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.094sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.362 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.605sec(train) 44.185sec(infer)
# Epoch 21 tst: l 0.402 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.367sec
# Epoch 22 tr: l 0.354 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 33.904sec(train) 47.169sec(infer)
# Epoch 22 tst: l 0.396 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.742sec
# Epoch 23 tr: l 0.347 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.013sec(train) 45.170sec(infer)
# Epoch 23 tst: l 0.391 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.528sec
# Epoch 24 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 32.131sec(train) 46.601sec(infer)
# Epoch 24 tst: l 0.386 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.219sec
# Epoch 25 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.564sec(train) 44.797sec(infer)
# Epoch 25 tst: l 0.381 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.274sec
# Epoch 26 tr: l 0.331 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.894sec(train) 45.997sec(infer)
# Epoch 26 tst: l 0.375 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.460sec
# Epoch 27 tr: l 0.327 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.506sec(train) 42.439sec(infer)
# Epoch 27 tst: l 0.371 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.382sec
# Epoch 28 tr: l 0.324 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.319sec(train) 44.889sec(infer)
# Epoch 28 tst: l 0.368 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.281sec
# Epoch 29 tr: l 0.321 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.157sec(train) 44.504sec(infer)
# Epoch 29 tst: l 0.364 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.866sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.90 hour (3248.116 sec)
# ---------------------------------R:50, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  45.707sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  32.116sec
# Epoch 0 tr: l 2.141 a 0.318 clct[np.int64(69), np.int64(500), np.int64(292), np.int64(339)] cl_acc 0.450  lr 0.100000 29.937sec(train) 46.290sec(infer)
# Epoch 0 tst: l 2.192 a 0.290 clct[np.int64(16), np.int64(84), np.int64(52), np.int64(48)] cl_acc 0.460  28.016sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.971 a 0.504 clct[np.int64(98), np.int64(526), np.int64(228), np.int64(348)] cl_acc 0.483  lr 0.100000 30.304sec(train) 45.317sec(infer)
# Epoch 1 tst: l 2.043 a 0.453 clct[np.int64(18), np.int64(89), np.int64(32), np.int64(61)] cl_acc 0.505  33.574sec
# Epoch 2 tr: l 1.758 a 0.628 clct[np.int64(135), np.int64(547), np.int64(206), np.int64(312)] cl_acc 0.538  lr 0.100000 30.494sec(train) 44.373sec(infer)
# Epoch 2 tst: l 1.838 a 0.592 clct[np.int64(22), np.int64(95), np.int64(26), np.int64(57)] cl_acc 0.600  28.895sec
# Epoch 3 tr: l 1.512 a 0.699 clct[np.int64(211), np.int64(575), np.int64(117), np.int64(297)] cl_acc 0.646  lr 0.100000 31.594sec(train) 44.349sec(infer)
# Epoch 3 tst: l 1.594 a 0.668 clct[np.int64(42), np.int64(95), np.int64(14), np.int64(49)] cl_acc 0.680  32.749sec
# Epoch 4 tr: l 1.276 a 0.748 clct[np.int64(218), np.int64(592), np.int64(95), np.int64(295)] cl_acc 0.677  lr 0.100000 31.346sec(train) 46.054sec(infer)
# Epoch 4 tst: l 1.354 a 0.721 clct[np.int64(40), np.int64(99), np.int64(12), np.int64(49)] cl_acc 0.690  31.544sec
# Epoch 5 tr: l 1.084 a 0.773 clct[np.int64(247), np.int64(596), np.int64(58), np.int64(299)] cl_acc 0.707  lr 0.100000 31.144sec(train) 47.115sec(infer)
# Epoch 5 tst: l 1.163 a 0.747 clct[np.int64(44), np.int64(100), np.int64(6), np.int64(50)] cl_acc 0.720  32.139sec
# Epoch 6 tr: l 0.949 a 0.789 clct[np.int64(250), np.int64(597), np.int64(54), np.int64(299)] cl_acc 0.708  lr 0.100000 30.714sec(train) 44.817sec(infer)
# Epoch 6 tst: l 1.022 a 0.767 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  31.710sec
# Epoch 7 tr: l 0.855 a 0.800 clct[np.int64(261), np.int64(598), np.int64(42), np.int64(299)] cl_acc 0.718  lr 0.100000 29.123sec(train) 50.640sec(infer)
# Epoch 7 tst: l 0.922 a 0.779 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  32.710sec
# Epoch 8 tr: l 0.776 a 0.810 clct[np.int64(270), np.int64(598), np.int64(33), np.int64(299)] cl_acc 0.726  lr 0.100000 29.829sec(train) 47.131sec(infer)
# Epoch 8 tst: l 0.846 a 0.789 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  28.665sec
# Epoch 9 tr: l 0.736 a 0.812 clct[np.int64(273), np.int64(598), np.int64(29), np.int64(300)] cl_acc 0.729  lr 0.100000 30.063sec(train) 48.324sec(infer)
# Epoch 9 tst: l 0.792 a 0.796 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  31.789sec
# Epoch 10 tr: l 0.695 a 0.818 clct[np.int64(273), np.int64(598), np.int64(29), np.int64(300)] cl_acc 0.729  lr 0.100000 31.032sec(train) 48.339sec(infer)
# Epoch 10 tst: l 0.743 a 0.803 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  27.128sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.651 a 0.826 clct[np.int64(275), np.int64(598), np.int64(27), np.int64(300)] cl_acc 0.731  lr 0.100000 30.902sec(train) 51.297sec(infer)
# Epoch 11 tst: l 0.711 a 0.808 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  30.166sec
# Epoch 12 tr: l 0.630 a 0.827 clct[np.int64(277), np.int64(598), np.int64(25), np.int64(300)] cl_acc 0.733  lr 0.100000 31.600sec(train) 46.738sec(infer)
# Epoch 12 tst: l 0.682 a 0.814 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  26.877sec
# Epoch 13 tr: l 0.602 a 0.833 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 30.364sec(train) 48.729sec(infer)
# Epoch 13 tst: l 0.660 a 0.816 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  29.197sec
# Epoch 14 tr: l 0.594 a 0.833 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 29.990sec(train) 46.072sec(infer)
# Epoch 14 tst: l 0.639 a 0.820 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  29.752sec
# Epoch 15 tr: l 0.569 a 0.840 clct[np.int64(279), np.int64(598), np.int64(23), np.int64(300)] cl_acc 0.734  lr 0.100000 29.562sec(train) 45.975sec(infer)
# Epoch 15 tst: l 0.625 a 0.822 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  29.746sec
# Epoch 16 tr: l 0.557 a 0.841 clct[np.int64(279), np.int64(598), np.int64(23), np.int64(300)] cl_acc 0.734  lr 0.100000 32.354sec(train) 46.959sec(infer)
# Epoch 16 tst: l 0.605 a 0.826 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  27.700sec
# Epoch 17 tr: l 0.547 a 0.844 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 30.127sec(train) 45.675sec(infer)
# Epoch 17 tst: l 0.594 a 0.828 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  27.325sec
# Epoch 18 tr: l 0.537 a 0.845 clct[np.int64(279), np.int64(599), np.int64(22), np.int64(300)] cl_acc 0.733  lr 0.100000 31.705sec(train) 44.401sec(infer)
# Epoch 18 tst: l 0.580 a 0.832 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  29.886sec
# Epoch 19 tr: l 0.521 a 0.848 clct[np.int64(280), np.int64(599), np.int64(21), np.int64(300)] cl_acc 0.734  lr 0.100000 30.159sec(train) 45.069sec(infer)
# Epoch 19 tst: l 0.569 a 0.833 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  31.663sec
# Epoch 20 tr: l 0.510 a 0.850 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 31.509sec(train) 46.766sec(infer)
# Epoch 20 tst: l 0.560 a 0.836 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  30.394sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.501 a 0.853 clct[np.int64(282), np.int64(599), np.int64(19), np.int64(300)] cl_acc 0.736  lr 0.100000 29.932sec(train) 42.614sec(infer)
# Epoch 21 tst: l 0.553 a 0.838 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  32.550sec
# Epoch 22 tr: l 0.496 a 0.853 clct[np.int64(282), np.int64(599), np.int64(19), np.int64(300)] cl_acc 0.736  lr 0.100000 30.592sec(train) 47.072sec(infer)
# Epoch 22 tst: l 0.543 a 0.840 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  29.452sec
# Epoch 23 tr: l 0.489 a 0.856 clct[np.int64(280), np.int64(599), np.int64(21), np.int64(300)] cl_acc 0.734  lr 0.100000 29.838sec(train) 47.063sec(infer)
# Epoch 23 tst: l 0.538 a 0.842 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  32.563sec
# Epoch 24 tr: l 0.488 a 0.854 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 29.971sec(train) 45.629sec(infer)
# Epoch 24 tst: l 0.533 a 0.842 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  31.843sec
# Epoch 25 tr: l 0.481 a 0.857 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 29.435sec(train) 46.430sec(infer)
# Epoch 25 tst: l 0.524 a 0.844 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  30.635sec
# Epoch 26 tr: l 0.479 a 0.856 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 31.608sec(train) 48.396sec(infer)
# Epoch 26 tst: l 0.518 a 0.847 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  29.565sec
# Epoch 27 tr: l 0.475 a 0.857 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 30.212sec(train) 46.665sec(infer)
# Epoch 27 tst: l 0.512 a 0.848 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  31.254sec
# Epoch 28 tr: l 0.463 a 0.862 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 31.464sec(train) 45.700sec(infer)
# Epoch 28 tst: l 0.509 a 0.848 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  28.305sec
# Epoch 29 tr: l 0.451 a 0.863 clct[np.int64(281), np.int64(600), np.int64(19), np.int64(300)] cl_acc 0.734  lr 0.100000 30.327sec(train) 46.289sec(infer)
# Epoch 29 tst: l 0.503 a 0.850 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  31.440sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.92 hour (3303.185 sec)
# ---------------------------------R:50, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  46.818sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  32.793sec
# Epoch 0 tr: l 2.130 a 0.400 clct[np.int64(160), np.int64(234), np.int64(204), np.int64(602)] cl_acc 0.393  lr 0.100000 29.456sec(train) 44.578sec(infer)
# Epoch 0 tst: l 2.184 a 0.361 clct[np.int64(31), np.int64(39), np.int64(33), np.int64(97)] cl_acc 0.445  30.906sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.953 a 0.530 clct[np.int64(207), np.int64(249), np.int64(212), np.int64(532)] cl_acc 0.455  lr 0.100000 30.581sec(train) 51.009sec(infer)
# Epoch 1 tst: l 2.026 a 0.490 clct[np.int64(34), np.int64(47), np.int64(34), np.int64(85)] cl_acc 0.465  30.290sec
# Epoch 2 tr: l 1.749 a 0.613 clct[np.int64(180), np.int64(305), np.int64(239), np.int64(476)] cl_acc 0.560  lr 0.100000 29.518sec(train) 42.882sec(infer)
# Epoch 2 tst: l 1.825 a 0.580 clct[np.int64(30), np.int64(44), np.int64(44), np.int64(82)] cl_acc 0.580  33.664sec
# Epoch 3 tr: l 1.521 a 0.682 clct[np.int64(100), np.int64(382), np.int64(267), np.int64(451)] cl_acc 0.651  lr 0.100000 30.915sec(train) 47.213sec(infer)
# Epoch 3 tst: l 1.593 a 0.654 clct[np.int64(16), np.int64(58), np.int64(47), np.int64(79)] cl_acc 0.665  30.420sec
# Epoch 4 tr: l 1.309 a 0.723 clct[np.int64(81), np.int64(458), np.int64(273), np.int64(388)] cl_acc 0.685  lr 0.100000 30.028sec(train) 44.971sec(infer)
# Epoch 4 tst: l 1.379 a 0.702 clct[np.int64(12), np.int64(74), np.int64(50), np.int64(64)] cl_acc 0.720  29.540sec
# Epoch 5 tr: l 1.129 a 0.756 clct[np.int64(100), np.int64(484), np.int64(284), np.int64(332)] cl_acc 0.769  lr 0.100000 30.476sec(train) 47.786sec(infer)
# Epoch 5 tst: l 1.198 a 0.732 clct[np.int64(16), np.int64(81), np.int64(49), np.int64(54)] cl_acc 0.805  32.166sec
# Epoch 6 tr: l 0.978 a 0.782 clct[np.int64(200), np.int64(399), np.int64(291), np.int64(310)] cl_acc 0.888  lr 0.100000 29.695sec(train) 43.701sec(infer)
# Epoch 6 tst: l 1.042 a 0.760 clct[np.int64(34), np.int64(64), np.int64(50), np.int64(52)] cl_acc 0.915  28.256sec
# Epoch 7 tr: l 0.832 a 0.813 clct[np.int64(295), np.int64(306), np.int64(296), np.int64(303)] cl_acc 0.986  lr 0.100000 30.698sec(train) 49.647sec(infer)
# Epoch 7 tst: l 0.887 a 0.796 clct[np.int64(47), np.int64(52), np.int64(50), np.int64(51)] cl_acc 0.985  29.691sec
# Epoch 8 tr: l 0.721 a 0.834 clct[np.int64(299), np.int64(301), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 30.805sec(train) 44.751sec(infer)
# Epoch 8 tst: l 0.772 a 0.822 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  29.333sec
# Epoch 9 tr: l 0.650 a 0.847 clct[np.int64(298), np.int64(301), np.int64(300), np.int64(301)] cl_acc 0.998  lr 0.100000 31.555sec(train) 46.399sec(infer)
# Epoch 9 tst: l 0.692 a 0.837 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  29.718sec
# Epoch 10 tr: l 0.589 a 0.858 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 31.906sec(train) 44.833sec(infer)
# Epoch 10 tst: l 0.633 a 0.848 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.597sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.544 a 0.866 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.496sec(train) 48.203sec(infer)
# Epoch 11 tst: l 0.594 a 0.855 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.341sec
# Epoch 12 tr: l 0.514 a 0.871 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 27.255sec(train) 44.849sec(infer)
# Epoch 12 tst: l 0.555 a 0.863 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  27.249sec
# Epoch 13 tr: l 0.485 a 0.877 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.690sec(train) 48.074sec(infer)
# Epoch 13 tst: l 0.528 a 0.868 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.180sec
# Epoch 14 tr: l 0.463 a 0.880 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.999sec(train) 45.074sec(infer)
# Epoch 14 tst: l 0.506 a 0.872 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.456sec
# Epoch 15 tr: l 0.443 a 0.883 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 32.052sec(train) 44.863sec(infer)
# Epoch 15 tst: l 0.483 a 0.877 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.638sec
# Epoch 16 tr: l 0.429 a 0.886 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 30.421sec(train) 43.126sec(infer)
# Epoch 16 tst: l 0.468 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  25.155sec
# Epoch 17 tr: l 0.412 a 0.890 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 30.915sec(train) 44.873sec(infer)
# Epoch 17 tst: l 0.453 a 0.883 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.465sec
# Epoch 18 tr: l 0.398 a 0.892 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.252sec(train) 41.918sec(infer)
# Epoch 18 tst: l 0.442 a 0.885 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.822sec
# Epoch 19 tr: l 0.390 a 0.893 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 31.453sec(train) 43.883sec(infer)
# Epoch 19 tst: l 0.431 a 0.887 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.978sec
# Epoch 20 tr: l 0.380 a 0.895 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.584sec(train) 44.040sec(infer)
# Epoch 20 tst: l 0.421 a 0.889 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  27.337sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.376 a 0.896 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.752sec(train) 40.956sec(infer)
# Epoch 21 tst: l 0.413 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  27.162sec
# Epoch 22 tr: l 0.365 a 0.898 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 31.163sec(train) 37.803sec(infer)
# Epoch 22 tst: l 0.406 a 0.891 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.201sec
# Epoch 23 tr: l 0.361 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.668sec(train) 42.817sec(infer)
# Epoch 23 tst: l 0.398 a 0.893 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.498sec
# Epoch 24 tr: l 0.354 a 0.900 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 30.998sec(train) 38.571sec(infer)
# Epoch 24 tst: l 0.391 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.506sec
# Epoch 25 tr: l 0.345 a 0.901 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.418sec(train) 40.308sec(infer)
# Epoch 25 tst: l 0.386 a 0.895 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.201sec
# Epoch 26 tr: l 0.341 a 0.902 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 30.268sec(train) 43.096sec(infer)
# Epoch 26 tst: l 0.382 a 0.896 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  23.859sec
# Epoch 27 tr: l 0.333 a 0.905 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.476sec(train) 38.508sec(infer)
# Epoch 27 tst: l 0.377 a 0.897 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  29.186sec
# Epoch 28 tr: l 0.327 a 0.906 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 32.217sec(train) 40.245sec(infer)
# Epoch 28 tst: l 0.373 a 0.898 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  24.924sec
# Epoch 29 tr: l 0.324 a 0.906 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 29.448sec(train) 41.681sec(infer)
# Epoch 29 tst: l 0.369 a 0.899 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  26.342sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.88 hour (3163.930 sec)

# %%
__.display_outputs()
# Out:
# ---------------------------------R:25, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  4.423sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  3.401sec
# Epoch 0 tr: l 2.103 a 0.350 clct[np.int64(688), np.int64(205), np.int64(195), np.int64(112)] cl_acc 0.358  lr 0.100000 21.864sec(train) 4.839sec(infer)
# Epoch 0 tst: l 2.188 a 0.295 clct[np.int64(122), np.int64(35), np.int64(26), np.int64(17)] cl_acc 0.390  2.979sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.924 a 0.501 clct[np.int64(479), np.int64(298), np.int64(235), np.int64(188)] cl_acc 0.432  lr 0.100000 18.840sec(train) 4.657sec(infer)
# Epoch 1 tst: l 2.044 a 0.433 clct[np.int64(82), np.int64(56), np.int64(37), np.int64(25)] cl_acc 0.400  3.491sec
# Epoch 2 tr: l 1.701 a 0.609 clct[np.int64(330), np.int64(382), np.int64(242), np.int64(246)] cl_acc 0.546  lr 0.100000 19.361sec(train) 4.375sec(infer)
# Epoch 2 tst: l 1.852 a 0.525 clct[np.int64(56), np.int64(61), np.int64(38), np.int64(45)] cl_acc 0.560  3.102sec
# Epoch 3 tr: l 1.492 a 0.666 clct[np.int64(224), np.int64(437), np.int64(258), np.int64(281)] cl_acc 0.674  lr 0.100000 19.073sec(train) 4.356sec(infer)
# Epoch 3 tst: l 1.628 a 0.598 clct[np.int64(33), np.int64(73), np.int64(42), np.int64(52)] cl_acc 0.745  3.036sec
# Epoch 4 tr: l 1.257 a 0.724 clct[np.int64(197), np.int64(422), np.int64(271), np.int64(310)] cl_acc 0.779  lr 0.100000 20.367sec(train) 4.501sec(infer)
# Epoch 4 tst: l 1.392 a 0.670 clct[np.int64(26), np.int64(77), np.int64(48), np.int64(49)] cl_acc 0.805  3.056sec
# Epoch 5 tr: l 1.075 a 0.768 clct[np.int64(256), np.int64(361), np.int64(281), np.int64(302)] cl_acc 0.892  lr 0.100000 20.161sec(train) 4.490sec(infer)
# Epoch 5 tst: l 1.183 a 0.726 clct[np.int64(41), np.int64(60), np.int64(49), np.int64(50)] cl_acc 0.920  2.985sec
# Epoch 6 tr: l 0.905 a 0.806 clct[np.int64(306), np.int64(305), np.int64(290), np.int64(299)] cl_acc 0.968  lr 0.100000 19.241sec(train) 4.424sec(infer)
# Epoch 6 tst: l 0.993 a 0.773 clct[np.int64(49), np.int64(51), np.int64(50), np.int64(50)] cl_acc 0.995  3.067sec
# Epoch 7 tr: l 0.767 a 0.834 clct[np.int64(304), np.int64(299), np.int64(297), np.int64(300)] cl_acc 0.991  lr 0.100000 20.429sec(train) 4.501sec(infer)
# Epoch 7 tst: l 0.851 a 0.802 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.033sec
# Epoch 8 tr: l 0.673 a 0.850 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.997  lr 0.100000 18.548sec(train) 5.273sec(infer)
# Epoch 8 tst: l 0.742 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.170sec
# Epoch 9 tr: l 0.601 a 0.860 clct[np.int64(302), np.int64(299), np.int64(300), np.int64(299)] cl_acc 0.998  lr 0.100000 18.579sec(train) 4.755sec(infer)
# Epoch 9 tst: l 0.668 a 0.839 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.543sec
# Epoch 10 tr: l 0.551 a 0.870 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 20.243sec(train) 4.385sec(infer)
# Epoch 10 tst: l 0.611 a 0.850 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.515sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.511 a 0.876 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 19.270sec(train) 4.527sec(infer)
# Epoch 11 tst: l 0.567 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.983sec
# Epoch 12 tr: l 0.478 a 0.883 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.767sec(train) 4.473sec(infer)
# Epoch 12 tst: l 0.534 a 0.864 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.025sec
# Epoch 13 tr: l 0.455 a 0.885 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.327sec(train) 4.572sec(infer)
# Epoch 13 tst: l 0.507 a 0.868 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.069sec
# Epoch 14 tr: l 0.435 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.659sec(train) 4.490sec(infer)
# Epoch 14 tst: l 0.484 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.187sec
# Epoch 15 tr: l 0.414 a 0.891 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.513sec(train) 4.572sec(infer)
# Epoch 15 tst: l 0.467 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.006sec
# Epoch 16 tr: l 0.400 a 0.895 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.544sec(train) 4.362sec(infer)
# Epoch 16 tst: l 0.450 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.027sec
# Epoch 17 tr: l 0.388 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.345sec(train) 4.626sec(infer)
# Epoch 17 tst: l 0.435 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.003sec
# Epoch 18 tr: l 0.372 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.191sec(train) 4.941sec(infer)
# Epoch 18 tst: l 0.424 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.002sec
# Epoch 19 tr: l 0.364 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.925sec(train) 5.161sec(infer)
# Epoch 19 tst: l 0.414 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.181sec
# Epoch 20 tr: l 0.352 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.644sec(train) 5.005sec(infer)
# Epoch 20 tst: l 0.403 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.383sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.343 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.060sec(train) 4.657sec(infer)
# Epoch 21 tst: l 0.398 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.606sec
# Epoch 22 tr: l 0.339 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.957sec(train) 4.586sec(infer)
# Epoch 22 tst: l 0.390 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.498sec
# Epoch 23 tr: l 0.334 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 18.667sec(train) 4.488sec(infer)
# Epoch 23 tst: l 0.382 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.976sec
# Epoch 24 tr: l 0.326 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.607sec(train) 4.583sec(infer)
# Epoch 24 tst: l 0.377 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.223sec
# Epoch 25 tr: l 0.321 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.380sec(train) 4.697sec(infer)
# Epoch 25 tst: l 0.370 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.997sec
# Epoch 26 tr: l 0.313 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 18.779sec(train) 4.640sec(infer)
# Epoch 26 tst: l 0.366 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.956sec
# Epoch 27 tr: l 0.309 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.149sec(train) 4.499sec(infer)
# Epoch 27 tst: l 0.361 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.030sec
# Epoch 28 tr: l 0.308 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.657sec(train) 4.571sec(infer)
# Epoch 28 tst: l 0.357 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.129sec
# Epoch 29 tr: l 0.300 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.440sec(train) 5.217sec(infer)
# Epoch 29 tst: l 0.353 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.095sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.23 hour (845.862 sec)
# ---------------------------------R:25, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  4.708sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  3.053sec
# Epoch 0 tr: l 2.096 a 0.432 clct[np.int64(358), np.int64(31), np.int64(444), np.int64(367)] cl_acc 0.641  lr 0.100000 20.317sec(train) 4.454sec(infer)
# Epoch 0 tst: l 2.181 a 0.343 clct[np.int64(61), np.int64(3), np.int64(82), np.int64(54)] cl_acc 0.675  3.104sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.881 a 0.572 clct[np.int64(356), np.int64(44), np.int64(443), np.int64(357)] cl_acc 0.694  lr 0.100000 18.533sec(train) 4.979sec(infer)
# Epoch 1 tst: l 2.004 a 0.487 clct[np.int64(61), np.int64(4), np.int64(83), np.int64(52)] cl_acc 0.700  2.943sec
# Epoch 2 tr: l 1.620 a 0.654 clct[np.int64(335), np.int64(57), np.int64(460), np.int64(348)] cl_acc 0.722  lr 0.100000 18.558sec(train) 5.198sec(infer)
# Epoch 2 tst: l 1.774 a 0.580 clct[np.int64(54), np.int64(8), np.int64(77), np.int64(61)] cl_acc 0.710  3.253sec
# Epoch 3 tr: l 1.386 a 0.697 clct[np.int64(315), np.int64(73), np.int64(488), np.int64(324)] cl_acc 0.733  lr 0.100000 20.174sec(train) 4.566sec(infer)
# Epoch 3 tst: l 1.549 a 0.632 clct[np.int64(52), np.int64(13), np.int64(84), np.int64(51)] cl_acc 0.760  3.117sec
# Epoch 4 tr: l 1.194 a 0.733 clct[np.int64(310), np.int64(92), np.int64(488), np.int64(310)] cl_acc 0.742  lr 0.100000 20.337sec(train) 4.572sec(infer)
# Epoch 4 tst: l 1.321 a 0.694 clct[np.int64(50), np.int64(15), np.int64(84), np.int64(51)] cl_acc 0.755  3.056sec
# Epoch 5 tr: l 1.046 a 0.762 clct[np.int64(306), np.int64(123), np.int64(467), np.int64(304)] cl_acc 0.742  lr 0.100000 20.241sec(train) 4.540sec(infer)
# Epoch 5 tst: l 1.154 a 0.728 clct[np.int64(50), np.int64(18), np.int64(81), np.int64(51)] cl_acc 0.770  3.164sec
# Epoch 6 tr: l 0.932 a 0.781 clct[np.int64(305), np.int64(161), np.int64(434), np.int64(300)] cl_acc 0.768  lr 0.100000 20.595sec(train) 4.578sec(infer)
# Epoch 6 tst: l 1.030 a 0.751 clct[np.int64(50), np.int64(29), np.int64(71), np.int64(50)] cl_acc 0.795  3.000sec
# Epoch 7 tr: l 0.845 a 0.800 clct[np.int64(302), np.int64(204), np.int64(395), np.int64(299)] cl_acc 0.811  lr 0.100000 18.614sec(train) 4.789sec(infer)
# Epoch 7 tst: l 0.938 a 0.768 clct[np.int64(50), np.int64(32), np.int64(68), np.int64(50)] cl_acc 0.840  2.950sec
# Epoch 8 tr: l 0.768 a 0.814 clct[np.int64(301), np.int64(239), np.int64(360), np.int64(300)] cl_acc 0.882  lr 0.100000 18.787sec(train) 5.243sec(infer)
# Epoch 8 tst: l 0.856 a 0.784 clct[np.int64(50), np.int64(34), np.int64(66), np.int64(50)] cl_acc 0.890  3.063sec
# Epoch 9 tr: l 0.680 a 0.837 clct[np.int64(301), np.int64(295), np.int64(304), np.int64(300)] cl_acc 0.973  lr 0.100000 18.565sec(train) 4.627sec(infer)
# Epoch 9 tst: l 0.767 a 0.808 clct[np.int64(50), np.int64(49), np.int64(51), np.int64(50)] cl_acc 0.995  3.534sec
# Epoch 10 tr: l 0.606 a 0.855 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.997  lr 0.100000 18.618sec(train) 4.439sec(infer)
# Epoch 10 tst: l 0.681 a 0.832 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.242sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.548 a 0.865 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 18.703sec(train) 4.489sec(infer)
# Epoch 11 tst: l 0.624 a 0.844 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.090sec
# Epoch 12 tr: l 0.507 a 0.874 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.835sec(train) 4.492sec(infer)
# Epoch 12 tst: l 0.574 a 0.856 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.047sec
# Epoch 13 tr: l 0.474 a 0.880 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 18.750sec(train) 4.557sec(infer)
# Epoch 13 tst: l 0.538 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.109sec
# Epoch 14 tr: l 0.447 a 0.885 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.214sec(train) 4.429sec(infer)
# Epoch 14 tst: l 0.511 a 0.868 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.093sec
# Epoch 15 tr: l 0.425 a 0.889 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.883sec(train) 4.787sec(infer)
# Epoch 15 tst: l 0.490 a 0.871 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.998sec
# Epoch 16 tr: l 0.408 a 0.892 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.585sec(train) 5.308sec(infer)
# Epoch 16 tst: l 0.470 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.068sec
# Epoch 17 tr: l 0.394 a 0.894 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.607sec(train) 4.928sec(infer)
# Epoch 17 tst: l 0.454 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.432sec
# Epoch 18 tr: l 0.376 a 0.897 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.029sec(train) 4.483sec(infer)
# Epoch 18 tst: l 0.441 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.299sec
# Epoch 19 tr: l 0.372 a 0.900 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 18.863sec(train) 4.567sec(infer)
# Epoch 19 tst: l 0.429 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.242sec
# Epoch 20 tr: l 0.362 a 0.900 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.645sec(train) 4.620sec(infer)
# Epoch 20 tst: l 0.420 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.953sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.352 a 0.902 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.328sec(train) 4.568sec(infer)
# Epoch 21 tst: l 0.409 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.030sec
# Epoch 22 tr: l 0.343 a 0.904 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 18.669sec(train) 4.511sec(infer)
# Epoch 22 tst: l 0.402 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.228sec
# Epoch 23 tr: l 0.340 a 0.904 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.279sec(train) 4.531sec(infer)
# Epoch 23 tst: l 0.394 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.186sec
# Epoch 24 tr: l 0.331 a 0.906 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 16.390sec(train) 4.403sec(infer)
# Epoch 24 tst: l 0.387 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.922sec
# Epoch 25 tr: l 0.326 a 0.907 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 19.642sec(train) 7.579sec(infer)
# Epoch 25 tst: l 0.380 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.819sec
# Epoch 26 tr: l 0.319 a 0.908 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.747sec(train) 10.812sec(infer)
# Epoch 26 tst: l 0.377 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.171sec
# Epoch 27 tr: l 0.314 a 0.909 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 21.051sec(train) 10.639sec(infer)
# Epoch 27 tst: l 0.372 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.130sec
# Epoch 28 tr: l 0.307 a 0.910 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 20.256sec(train) 11.764sec(infer)
# Epoch 28 tst: l 0.366 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  7.007sec
# Epoch 29 tr: l 0.302 a 0.912 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 21.297sec(train) 13.613sec(infer)
# Epoch 29 tst: l 0.363 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.818sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.24 hour (878.298 sec)
# ---------------------------------R:25, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  10.630sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  8.556sec
# Epoch 0 tr: l 2.089 a 0.432 clct[np.int64(334), np.int64(393), np.int64(363), np.int64(110)] cl_acc 0.666  lr 0.100000 19.479sec(train) 12.566sec(infer)
# Epoch 0 tst: l 2.181 a 0.349 clct[np.int64(62), np.int64(58), np.int64(60), np.int64(20)] cl_acc 0.695  31.242sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.867 a 0.595 clct[np.int64(325), np.int64(363), np.int64(336), np.int64(176)] cl_acc 0.777  lr 0.100000 26.094sec(train) 42.025sec(infer)
# Epoch 1 tst: l 1.990 a 0.519 clct[np.int64(54), np.int64(57), np.int64(55), np.int64(34)] cl_acc 0.855  31.717sec
# Epoch 2 tr: l 1.584 a 0.703 clct[np.int64(307), np.int64(312), np.int64(316), np.int64(265)] cl_acc 0.901  lr 0.100000 26.197sec(train) 46.888sec(infer)
# Epoch 2 tst: l 1.724 a 0.637 clct[np.int64(50), np.int64(58), np.int64(51), np.int64(41)] cl_acc 0.945  33.043sec
# Epoch 3 tr: l 1.286 a 0.769 clct[np.int64(301), np.int64(296), np.int64(304), np.int64(299)] cl_acc 0.969  lr 0.100000 25.587sec(train) 41.114sec(infer)
# Epoch 3 tst: l 1.421 a 0.723 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.183sec
# Epoch 4 tr: l 1.033 a 0.809 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.989  lr 0.100000 24.227sec(train) 42.802sec(infer)
# Epoch 4 tst: l 1.168 a 0.775 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.244sec
# Epoch 5 tr: l 0.857 a 0.832 clct[np.int64(298), np.int64(299), np.int64(301), np.int64(302)] cl_acc 0.994  lr 0.100000 26.068sec(train) 43.311sec(infer)
# Epoch 5 tst: l 0.969 a 0.805 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.919sec
# Epoch 6 tr: l 0.734 a 0.850 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.998  lr 0.100000 25.619sec(train) 41.473sec(infer)
# Epoch 6 tst: l 0.829 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.168sec
# Epoch 7 tr: l 0.645 a 0.861 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.998  lr 0.100000 29.610sec(train) 43.569sec(infer)
# Epoch 7 tst: l 0.741 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.581sec
# Epoch 8 tr: l 0.588 a 0.868 clct[np.int64(300), np.int64(299), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 28.241sec(train) 42.544sec(infer)
# Epoch 8 tst: l 0.671 a 0.847 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.827sec
# Epoch 9 tr: l 0.538 a 0.875 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.338sec(train) 44.509sec(infer)
# Epoch 9 tst: l 0.618 a 0.855 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.481sec
# Epoch 10 tr: l 0.498 a 0.880 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.721sec(train) 44.423sec(infer)
# Epoch 10 tst: l 0.579 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.834sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.472 a 0.884 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.549sec(train) 48.478sec(infer)
# Epoch 11 tst: l 0.548 a 0.866 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.708sec
# Epoch 12 tr: l 0.448 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.314sec(train) 43.931sec(infer)
# Epoch 12 tst: l 0.522 a 0.870 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.117sec
# Epoch 13 tr: l 0.429 a 0.890 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.128sec(train) 49.032sec(infer)
# Epoch 13 tst: l 0.499 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.434sec
# Epoch 14 tr: l 0.412 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.403sec(train) 45.409sec(infer)
# Epoch 14 tst: l 0.482 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.778sec
# Epoch 15 tr: l 0.397 a 0.895 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.541sec(train) 49.959sec(infer)
# Epoch 15 tst: l 0.469 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.829sec
# Epoch 16 tr: l 0.382 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.373sec(train) 45.560sec(infer)
# Epoch 16 tst: l 0.454 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.491sec
# Epoch 17 tr: l 0.372 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.203sec(train) 51.721sec(infer)
# Epoch 17 tst: l 0.443 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.798sec
# Epoch 18 tr: l 0.361 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.098sec(train) 46.055sec(infer)
# Epoch 18 tst: l 0.435 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.358sec
# Epoch 19 tr: l 0.352 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.800sec(train) 49.759sec(infer)
# Epoch 19 tst: l 0.427 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.959sec
# Epoch 20 tr: l 0.347 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.414sec(train) 47.558sec(infer)
# Epoch 20 tst: l 0.417 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.340sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.340 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.530sec(train) 49.035sec(infer)
# Epoch 21 tst: l 0.407 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.082sec
# Epoch 22 tr: l 0.331 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.638sec(train) 46.868sec(infer)
# Epoch 22 tst: l 0.403 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.981sec
# Epoch 23 tr: l 0.327 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.947sec(train) 51.475sec(infer)
# Epoch 23 tst: l 0.398 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.295sec
# Epoch 24 tr: l 0.323 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.138sec(train) 47.233sec(infer)
# Epoch 24 tst: l 0.393 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.296sec
# Epoch 25 tr: l 0.312 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.970sec(train) 49.385sec(infer)
# Epoch 25 tst: l 0.386 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.052sec
# Epoch 26 tr: l 0.313 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.804sec(train) 51.840sec(infer)
# Epoch 26 tst: l 0.384 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.801sec
# Epoch 27 tr: l 0.308 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.625sec(train) 50.433sec(infer)
# Epoch 27 tst: l 0.378 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.053sec
# Epoch 28 tr: l 0.302 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.098sec(train) 48.587sec(infer)
# Epoch 28 tst: l 0.376 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.286sec
# Epoch 29 tr: l 0.301 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.008sec(train) 51.976sec(infer)
# Epoch 29 tst: l 0.371 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.649sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.86 hour (3088.335 sec)
# ---------------------------------R:25, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  46.701sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  29.183sec
# Epoch 0 tr: l 2.102 a 0.367 clct[np.int64(51), np.int64(498), np.int64(341), np.int64(310)] cl_acc 0.434  lr 0.100000 26.115sec(train) 50.509sec(infer)
# Epoch 0 tst: l 2.190 a 0.294 clct[np.int64(6), np.int64(83), np.int64(55), np.int64(56)] cl_acc 0.460  30.376sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.918 a 0.526 clct[np.int64(85), np.int64(476), np.int64(320), np.int64(319)] cl_acc 0.471  lr 0.100000 26.263sec(train) 49.678sec(infer)
# Epoch 1 tst: l 2.038 a 0.436 clct[np.int64(14), np.int64(87), np.int64(40), np.int64(59)] cl_acc 0.520  29.825sec
# Epoch 2 tr: l 1.703 a 0.630 clct[np.int64(126), np.int64(511), np.int64(244), np.int64(319)] cl_acc 0.491  lr 0.100000 25.500sec(train) 50.633sec(infer)
# Epoch 2 tst: l 1.851 a 0.550 clct[np.int64(24), np.int64(83), np.int64(37), np.int64(56)] cl_acc 0.565  28.620sec
# Epoch 3 tr: l 1.486 a 0.692 clct[np.int64(183), np.int64(537), np.int64(172), np.int64(308)] cl_acc 0.571  lr 0.100000 27.883sec(train) 46.061sec(infer)
# Epoch 3 tst: l 1.631 a 0.629 clct[np.int64(34), np.int64(91), np.int64(23), np.int64(52)] cl_acc 0.650  29.240sec
# Epoch 4 tr: l 1.257 a 0.744 clct[np.int64(226), np.int64(548), np.int64(133), np.int64(293)] cl_acc 0.640  lr 0.100000 25.649sec(train) 51.741sec(infer)
# Epoch 4 tst: l 1.405 a 0.688 clct[np.int64(43), np.int64(97), np.int64(10), np.int64(50)] cl_acc 0.710  28.959sec
# Epoch 5 tr: l 1.091 a 0.770 clct[np.int64(245), np.int64(564), np.int64(99), np.int64(292)] cl_acc 0.688  lr 0.100000 27.713sec(train) 45.032sec(infer)
# Epoch 5 tst: l 1.212 a 0.729 clct[np.int64(42), np.int64(99), np.int64(8), np.int64(51)] cl_acc 0.710  32.162sec
# Epoch 6 tr: l 0.945 a 0.793 clct[np.int64(264), np.int64(579), np.int64(59), np.int64(298)] cl_acc 0.716  lr 0.100000 25.971sec(train) 44.878sec(infer)
# Epoch 6 tst: l 1.062 a 0.755 clct[np.int64(45), np.int64(99), np.int64(6), np.int64(50)] cl_acc 0.730  29.391sec
# Epoch 7 tr: l 0.844 a 0.806 clct[np.int64(270), np.int64(586), np.int64(47), np.int64(297)] cl_acc 0.724  lr 0.100000 26.335sec(train) 51.439sec(infer)
# Epoch 7 tst: l 0.949 a 0.772 clct[np.int64(48), np.int64(98), np.int64(3), np.int64(51)] cl_acc 0.740  30.987sec
# Epoch 8 tr: l 0.778 a 0.811 clct[np.int64(281), np.int64(589), np.int64(31), np.int64(299)] cl_acc 0.735  lr 0.100000 25.745sec(train) 47.247sec(infer)
# Epoch 8 tst: l 0.869 a 0.783 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  30.938sec
# Epoch 9 tr: l 0.717 a 0.822 clct[np.int64(281), np.int64(590), np.int64(30), np.int64(299)] cl_acc 0.737  lr 0.100000 26.886sec(train) 49.495sec(infer)
# Epoch 9 tst: l 0.809 a 0.791 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  30.214sec
# Epoch 10 tr: l 0.667 a 0.829 clct[np.int64(283), np.int64(591), np.int64(27), np.int64(299)] cl_acc 0.739  lr 0.100000 26.173sec(train) 50.253sec(infer)
# Epoch 10 tst: l 0.761 a 0.797 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  30.213sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.636 a 0.832 clct[np.int64(286), np.int64(591), np.int64(24), np.int64(299)] cl_acc 0.742  lr 0.100000 26.462sec(train) 47.688sec(infer)
# Epoch 11 tst: l 0.725 a 0.802 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  32.203sec
# Epoch 12 tr: l 0.611 a 0.834 clct[np.int64(288), np.int64(591), np.int64(22), np.int64(299)] cl_acc 0.743  lr 0.100000 26.239sec(train) 46.536sec(infer)
# Epoch 12 tst: l 0.696 a 0.807 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  28.899sec
# Epoch 13 tr: l 0.584 a 0.839 clct[np.int64(289), np.int64(591), np.int64(21), np.int64(299)] cl_acc 0.744  lr 0.100000 26.710sec(train) 50.653sec(infer)
# Epoch 13 tst: l 0.668 a 0.813 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  28.484sec
# Epoch 14 tr: l 0.566 a 0.843 clct[np.int64(291), np.int64(591), np.int64(19), np.int64(299)] cl_acc 0.746  lr 0.100000 26.480sec(train) 43.916sec(infer)
# Epoch 14 tst: l 0.650 a 0.814 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  30.180sec
# Epoch 15 tr: l 0.554 a 0.843 clct[np.int64(292), np.int64(591), np.int64(18), np.int64(299)] cl_acc 0.747  lr 0.100000 28.790sec(train) 47.182sec(infer)
# Epoch 15 tst: l 0.632 a 0.819 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  29.523sec
# Epoch 16 tr: l 0.536 a 0.847 clct[np.int64(293), np.int64(592), np.int64(16), np.int64(299)] cl_acc 0.747  lr 0.100000 26.513sec(train) 43.920sec(infer)
# Epoch 16 tst: l 0.615 a 0.822 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  31.301sec
# Epoch 17 tr: l 0.520 a 0.849 clct[np.int64(293), np.int64(592), np.int64(16), np.int64(299)] cl_acc 0.747  lr 0.100000 27.038sec(train) 45.988sec(infer)
# Epoch 17 tst: l 0.605 a 0.825 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  28.723sec
# Epoch 18 tr: l 0.509 a 0.853 clct[np.int64(295), np.int64(591), np.int64(15), np.int64(299)] cl_acc 0.749  lr 0.100000 28.882sec(train) 41.663sec(infer)
# Epoch 18 tst: l 0.590 a 0.827 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  29.319sec
# Epoch 19 tr: l 0.501 a 0.854 clct[np.int64(295), np.int64(590), np.int64(16), np.int64(299)] cl_acc 0.750  lr 0.100000 28.359sec(train) 45.131sec(infer)
# Epoch 19 tst: l 0.582 a 0.830 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  34.175sec
# Epoch 20 tr: l 0.492 a 0.855 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 26.824sec(train) 42.719sec(infer)
# Epoch 20 tst: l 0.570 a 0.832 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  29.361sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.483 a 0.858 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 27.620sec(train) 45.203sec(infer)
# Epoch 21 tst: l 0.559 a 0.835 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  31.981sec
# Epoch 22 tr: l 0.466 a 0.861 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 26.185sec(train) 44.637sec(infer)
# Epoch 22 tst: l 0.554 a 0.836 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  31.336sec
# Epoch 23 tr: l 0.464 a 0.861 clct[np.int64(297), np.int64(590), np.int64(14), np.int64(299)] cl_acc 0.752  lr 0.100000 26.557sec(train) 46.025sec(infer)
# Epoch 23 tst: l 0.544 a 0.839 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  31.083sec
# Epoch 24 tr: l 0.457 a 0.862 clct[np.int64(297), np.int64(589), np.int64(15), np.int64(299)] cl_acc 0.752  lr 0.100000 29.211sec(train) 43.948sec(infer)
# Epoch 24 tst: l 0.536 a 0.841 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  27.191sec
# Epoch 25 tr: l 0.456 a 0.863 clct[np.int64(297), np.int64(588), np.int64(16), np.int64(299)] cl_acc 0.753  lr 0.100000 26.858sec(train) 44.072sec(infer)
# Epoch 25 tst: l 0.532 a 0.842 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  28.351sec
# Epoch 26 tr: l 0.444 a 0.865 clct[np.int64(297), np.int64(587), np.int64(17), np.int64(299)] cl_acc 0.754  lr 0.100000 27.792sec(train) 44.140sec(infer)
# Epoch 26 tst: l 0.525 a 0.844 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  30.026sec
# Epoch 27 tr: l 0.442 a 0.866 clct[np.int64(297), np.int64(584), np.int64(20), np.int64(299)] cl_acc 0.757  lr 0.100000 26.774sec(train) 46.257sec(infer)
# Epoch 27 tst: l 0.517 a 0.846 clct[np.int64(50), np.int64(97), np.int64(3), np.int64(50)] cl_acc 0.765  31.039sec
# Epoch 28 tr: l 0.433 a 0.869 clct[np.int64(297), np.int64(584), np.int64(20), np.int64(299)] cl_acc 0.757  lr 0.100000 27.797sec(train) 43.815sec(infer)
# Epoch 28 tst: l 0.514 a 0.847 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  33.128sec
# Epoch 29 tr: l 0.425 a 0.870 clct[np.int64(297), np.int64(583), np.int64(21), np.int64(299)] cl_acc 0.757  lr 0.100000 25.845sec(train) 43.400sec(infer)
# Epoch 29 tst: l 0.509 a 0.848 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  31.174sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.89 hour (3187.994 sec)
# ---------------------------------R:25, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  52.052sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  28.657sec
# Epoch 0 tr: l 2.101 a 0.422 clct[np.int64(179), np.int64(211), np.int64(208), np.int64(602)] cl_acc 0.415  lr 0.100000 27.272sec(train) 42.947sec(infer)
# Epoch 0 tst: l 2.186 a 0.352 clct[np.int64(31), np.int64(39), np.int64(35), np.int64(95)] cl_acc 0.455  31.681sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.917 a 0.541 clct[np.int64(223), np.int64(275), np.int64(208), np.int64(494)] cl_acc 0.492  lr 0.100000 27.928sec(train) 49.308sec(infer)
# Epoch 1 tst: l 2.033 a 0.472 clct[np.int64(34), np.int64(40), np.int64(41), np.int64(85)] cl_acc 0.500  28.271sec
# Epoch 2 tr: l 1.685 a 0.627 clct[np.int64(265), np.int64(296), np.int64(220), np.int64(419)] cl_acc 0.593  lr 0.100000 26.726sec(train) 44.419sec(infer)
# Epoch 2 tst: l 1.842 a 0.557 clct[np.int64(43), np.int64(42), np.int64(40), np.int64(75)] cl_acc 0.615  30.339sec
# Epoch 3 tr: l 1.461 a 0.691 clct[np.int64(300), np.int64(293), np.int64(234), np.int64(373)] cl_acc 0.716  lr 0.100000 27.367sec(train) 44.388sec(infer)
# Epoch 3 tst: l 1.614 a 0.626 clct[np.int64(46), np.int64(47), np.int64(42), np.int64(65)] cl_acc 0.770  33.759sec
# Epoch 4 tr: l 1.237 a 0.744 clct[np.int64(322), np.int64(298), np.int64(254), np.int64(326)] cl_acc 0.851  lr 0.100000 26.356sec(train) 44.339sec(infer)
# Epoch 4 tst: l 1.379 a 0.688 clct[np.int64(52), np.int64(50), np.int64(45), np.int64(53)] cl_acc 0.905  29.246sec
# Epoch 5 tr: l 1.038 a 0.787 clct[np.int64(326), np.int64(303), np.int64(278), np.int64(293)] cl_acc 0.944  lr 0.100000 26.515sec(train) 48.189sec(infer)
# Epoch 5 tst: l 1.161 a 0.745 clct[np.int64(53), np.int64(49), np.int64(46), np.int64(52)] cl_acc 0.970  34.963sec
# Epoch 6 tr: l 0.872 a 0.818 clct[np.int64(313), np.int64(298), np.int64(291), np.int64(298)] cl_acc 0.976  lr 0.100000 26.399sec(train) 44.173sec(infer)
# Epoch 6 tst: l 0.973 a 0.788 clct[np.int64(50), np.int64(50), np.int64(49), np.int64(51)] cl_acc 0.990  31.407sec
# Epoch 7 tr: l 0.743 a 0.838 clct[np.int64(303), np.int64(300), np.int64(296), np.int64(301)] cl_acc 0.989  lr 0.100000 27.870sec(train) 43.320sec(infer)
# Epoch 7 tst: l 0.839 a 0.811 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.742sec
# Epoch 8 tr: l 0.665 a 0.850 clct[np.int64(302), np.int64(302), np.int64(295), np.int64(301)] cl_acc 0.995  lr 0.100000 26.234sec(train) 49.073sec(infer)
# Epoch 8 tst: l 0.741 a 0.831 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.301sec
# Epoch 9 tr: l 0.598 a 0.861 clct[np.int64(300), np.int64(302), np.int64(297), np.int64(301)] cl_acc 0.997  lr 0.100000 26.552sec(train) 45.782sec(infer)
# Epoch 9 tst: l 0.676 a 0.840 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  36.163sec
# Epoch 10 tr: l 0.547 a 0.870 clct[np.int64(299), np.int64(301), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 26.073sec(train) 44.664sec(infer)
# Epoch 10 tst: l 0.622 a 0.850 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.230sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.510 a 0.875 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.581sec(train) 49.350sec(infer)
# Epoch 11 tst: l 0.584 a 0.858 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  35.268sec
# Epoch 12 tr: l 0.475 a 0.882 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.146sec(train) 45.928sec(infer)
# Epoch 12 tst: l 0.554 a 0.863 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.909sec
# Epoch 13 tr: l 0.452 a 0.885 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.087sec(train) 46.265sec(infer)
# Epoch 13 tst: l 0.528 a 0.867 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  33.756sec
# Epoch 14 tr: l 0.436 a 0.888 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.655sec(train) 48.756sec(infer)
# Epoch 14 tst: l 0.501 a 0.873 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.253sec
# Epoch 15 tr: l 0.413 a 0.891 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.804sec(train) 46.441sec(infer)
# Epoch 15 tst: l 0.485 a 0.875 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  35.350sec
# Epoch 16 tr: l 0.395 a 0.895 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.398sec(train) 48.353sec(infer)
# Epoch 16 tst: l 0.470 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.302sec
# Epoch 17 tr: l 0.386 a 0.897 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.053sec(train) 47.656sec(infer)
# Epoch 17 tst: l 0.458 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  33.051sec
# Epoch 18 tr: l 0.372 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.415sec(train) 45.154sec(infer)
# Epoch 18 tst: l 0.445 a 0.883 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.880sec
# Epoch 19 tr: l 0.367 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.543sec(train) 43.868sec(infer)
# Epoch 19 tst: l 0.435 a 0.885 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.554sec
# Epoch 20 tr: l 0.355 a 0.902 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 27.763sec(train) 46.130sec(infer)
# Epoch 20 tst: l 0.425 a 0.887 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.662sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.347 a 0.903 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.752sec(train) 45.498sec(infer)
# Epoch 21 tst: l 0.417 a 0.888 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  34.365sec
# Epoch 22 tr: l 0.342 a 0.904 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 27.009sec(train) 45.423sec(infer)
# Epoch 22 tst: l 0.410 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.387sec
# Epoch 23 tr: l 0.332 a 0.907 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.924sec(train) 47.522sec(infer)
# Epoch 23 tst: l 0.401 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.217sec
# Epoch 24 tr: l 0.327 a 0.907 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.269sec(train) 44.834sec(infer)
# Epoch 24 tst: l 0.398 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.982sec
# Epoch 25 tr: l 0.323 a 0.908 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.240sec(train) 42.256sec(infer)
# Epoch 25 tst: l 0.389 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.101sec
# Epoch 26 tr: l 0.319 a 0.910 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.123sec(train) 45.584sec(infer)
# Epoch 26 tst: l 0.385 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.344sec
# Epoch 27 tr: l 0.313 a 0.910 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.115sec(train) 42.459sec(infer)
# Epoch 27 tst: l 0.382 a 0.895 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.603sec
# Epoch 28 tr: l 0.307 a 0.911 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.496sec(train) 45.693sec(infer)
# Epoch 28 tst: l 0.376 a 0.897 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  30.909sec
# Epoch 29 tr: l 0.299 a 0.913 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.817sec(train) 41.217sec(infer)
# Epoch 29 tst: l 0.372 a 0.898 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.966sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.89 hour (3206.512 sec)

# %%
___.display_outputs()
# Out:
# ---------------------------------R:10, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  4.518sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  3.408sec
# Epoch 0 tr: l 2.066 a 0.398 clct[np.int64(834), np.int64(148), np.int64(145), np.int64(73)] cl_acc 0.319  lr 0.100000 20.419sec(train) 5.293sec(infer)
# Epoch 0 tst: l 2.199 a 0.278 clct[np.int64(142), np.int64(24), np.int64(24), np.int64(10)] cl_acc 0.290  2.946sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.857 a 0.526 clct[np.int64(752), np.int64(188), np.int64(160), np.int64(100)] cl_acc 0.332  lr 0.100000 19.850sec(train) 4.663sec(infer)
# Epoch 1 tst: l 2.066 a 0.386 clct[np.int64(133), np.int64(31), np.int64(24), np.int64(12)] cl_acc 0.380  3.492sec
# Epoch 2 tr: l 1.634 a 0.609 clct[np.int64(666), np.int64(239), np.int64(178), np.int64(117)] cl_acc 0.345  lr 0.100000 17.104sec(train) 4.727sec(infer)
# Epoch 2 tst: l 1.898 a 0.474 clct[np.int64(108), np.int64(33), np.int64(39), np.int64(20)] cl_acc 0.375  2.962sec
# Epoch 3 tr: l 1.433 a 0.672 clct[np.int64(555), np.int64(301), np.int64(195), np.int64(149)] cl_acc 0.372  lr 0.100000 19.708sec(train) 4.611sec(infer)
# Epoch 3 tst: l 1.727 a 0.535 clct[np.int64(112), np.int64(40), np.int64(29), np.int64(19)] cl_acc 0.390  2.977sec
# Epoch 4 tr: l 1.241 a 0.722 clct[np.int64(485), np.int64(338), np.int64(204), np.int64(173)] cl_acc 0.409  lr 0.100000 17.423sec(train) 4.951sec(infer)
# Epoch 4 tst: l 1.582 a 0.577 clct[np.int64(97), np.int64(50), np.int64(37), np.int64(16)] cl_acc 0.430  3.003sec
# Epoch 5 tr: l 1.103 a 0.754 clct[np.int64(413), np.int64(360), np.int64(224), np.int64(203)] cl_acc 0.444  lr 0.100000 17.188sec(train) 4.461sec(infer)
# Epoch 5 tst: l 1.433 a 0.618 clct[np.int64(68), np.int64(55), np.int64(46), np.int64(31)] cl_acc 0.430  3.317sec
# Epoch 6 tr: l 0.980 a 0.783 clct[np.int64(378), np.int64(381), np.int64(221), np.int64(220)] cl_acc 0.484  lr 0.100000 19.266sec(train) 5.515sec(infer)
# Epoch 6 tst: l 1.313 a 0.650 clct[np.int64(64), np.int64(55), np.int64(47), np.int64(34)] cl_acc 0.515  3.055sec
# Epoch 7 tr: l 0.895 a 0.801 clct[np.int64(336), np.int64(384), np.int64(231), np.int64(249)] cl_acc 0.542  lr 0.100000 18.920sec(train) 5.303sec(infer)
# Epoch 7 tst: l 1.226 a 0.668 clct[np.int64(51), np.int64(59), np.int64(48), np.int64(42)] cl_acc 0.500  3.501sec
# Epoch 8 tr: l 0.812 a 0.817 clct[np.int64(300), np.int64(405), np.int64(226), np.int64(269)] cl_acc 0.583  lr 0.100000 17.119sec(train) 4.570sec(infer)
# Epoch 8 tst: l 1.133 a 0.688 clct[np.int64(58), np.int64(62), np.int64(37), np.int64(43)] cl_acc 0.575  3.533sec
# Epoch 9 tr: l 0.760 a 0.825 clct[np.int64(271), np.int64(428), np.int64(218), np.int64(283)] cl_acc 0.623  lr 0.100000 18.308sec(train) 4.577sec(infer)
# Epoch 9 tst: l 1.046 a 0.712 clct[np.int64(45), np.int64(74), np.int64(31), np.int64(50)] cl_acc 0.635  3.533sec
# Epoch 10 tr: l 0.708 a 0.835 clct[np.int64(244), np.int64(455), np.int64(225), np.int64(276)] cl_acc 0.672  lr 0.100000 19.043sec(train) 4.505sec(infer)
# Epoch 10 tst: l 0.973 a 0.730 clct[np.int64(43), np.int64(74), np.int64(34), np.int64(49)] cl_acc 0.725  3.354sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.659 a 0.842 clct[np.int64(231), np.int64(467), np.int64(221), np.int64(281)] cl_acc 0.688  lr 0.100000 19.555sec(train) 4.523sec(infer)
# Epoch 11 tst: l 0.906 a 0.748 clct[np.int64(36), np.int64(79), np.int64(36), np.int64(49)] cl_acc 0.710  3.412sec
# Epoch 12 tr: l 0.629 a 0.845 clct[np.int64(222), np.int64(470), np.int64(222), np.int64(286)] cl_acc 0.715  lr 0.100000 17.247sec(train) 4.385sec(infer)
# Epoch 12 tst: l 0.837 a 0.766 clct[np.int64(36), np.int64(77), np.int64(38), np.int64(49)] cl_acc 0.740  3.009sec
# Epoch 13 tr: l 0.586 a 0.855 clct[np.int64(230), np.int64(466), np.int64(216), np.int64(288)] cl_acc 0.737  lr 0.100000 17.453sec(train) 5.213sec(infer)
# Epoch 13 tst: l 0.793 a 0.780 clct[np.int64(33), np.int64(73), np.int64(44), np.int64(50)] cl_acc 0.775  2.983sec
# Epoch 14 tr: l 0.548 a 0.862 clct[np.int64(233), np.int64(450), np.int64(228), np.int64(289)] cl_acc 0.763  lr 0.100000 16.842sec(train) 4.397sec(infer)
# Epoch 14 tst: l 0.750 a 0.789 clct[np.int64(34), np.int64(72), np.int64(44), np.int64(50)] cl_acc 0.810  3.328sec
# Epoch 15 tr: l 0.520 a 0.866 clct[np.int64(251), np.int64(433), np.int64(225), np.int64(291)] cl_acc 0.786  lr 0.100000 18.223sec(train) 4.461sec(infer)
# Epoch 15 tst: l 0.713 a 0.795 clct[np.int64(38), np.int64(66), np.int64(46), np.int64(50)] cl_acc 0.900  3.000sec
# Epoch 16 tr: l 0.486 a 0.876 clct[np.int64(250), np.int64(417), np.int64(237), np.int64(296)] cl_acc 0.814  lr 0.100000 16.844sec(train) 4.515sec(infer)
# Epoch 16 tst: l 0.686 a 0.803 clct[np.int64(37), np.int64(66), np.int64(47), np.int64(50)] cl_acc 0.905  3.070sec
# Epoch 17 tr: l 0.462 a 0.881 clct[np.int64(260), np.int64(400), np.int64(243), np.int64(297)] cl_acc 0.838  lr 0.100000 16.933sec(train) 4.315sec(infer)
# Epoch 17 tst: l 0.653 a 0.813 clct[np.int64(37), np.int64(65), np.int64(48), np.int64(50)] cl_acc 0.915  3.059sec
# Epoch 18 tr: l 0.452 a 0.883 clct[np.int64(274), np.int64(384), np.int64(245), np.int64(297)] cl_acc 0.863  lr 0.100000 16.838sec(train) 5.308sec(infer)
# Epoch 18 tst: l 0.623 a 0.823 clct[np.int64(48), np.int64(54), np.int64(48), np.int64(50)] cl_acc 0.960  2.928sec
# Epoch 19 tr: l 0.429 a 0.888 clct[np.int64(286), np.int64(362), np.int64(252), np.int64(300)] cl_acc 0.895  lr 0.100000 18.658sec(train) 5.552sec(infer)
# Epoch 19 tst: l 0.594 a 0.830 clct[np.int64(47), np.int64(55), np.int64(48), np.int64(50)] cl_acc 0.965  3.155sec
# Epoch 20 tr: l 0.400 a 0.897 clct[np.int64(293), np.int64(343), np.int64(264), np.int64(300)] cl_acc 0.924  lr 0.100000 17.031sec(train) 4.586sec(infer)
# Epoch 20 tst: l 0.559 a 0.842 clct[np.int64(48), np.int64(51), np.int64(51), np.int64(50)] cl_acc 0.980  3.404sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.377 a 0.902 clct[np.int64(301), np.int64(329), np.int64(270), np.int64(300)] cl_acc 0.943  lr 0.100000 18.797sec(train) 4.503sec(infer)
# Epoch 21 tst: l 0.527 a 0.851 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.417sec
# Epoch 22 tr: l 0.357 a 0.906 clct[np.int64(299), np.int64(319), np.int64(282), np.int64(300)] cl_acc 0.963  lr 0.100000 18.754sec(train) 4.478sec(infer)
# Epoch 22 tst: l 0.501 a 0.857 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.042sec
# Epoch 23 tr: l 0.336 a 0.912 clct[np.int64(307), np.int64(307), np.int64(285), np.int64(301)] cl_acc 0.976  lr 0.100000 16.880sec(train) 4.465sec(infer)
# Epoch 23 tst: l 0.479 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.052sec
# Epoch 24 tr: l 0.321 a 0.916 clct[np.int64(308), np.int64(302), np.int64(290), np.int64(300)] cl_acc 0.987  lr 0.100000 16.900sec(train) 4.617sec(infer)
# Epoch 24 tst: l 0.461 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.033sec
# Epoch 25 tr: l 0.309 a 0.917 clct[np.int64(310), np.int64(301), np.int64(289), np.int64(300)] cl_acc 0.990  lr 0.100000 17.616sec(train) 5.321sec(infer)
# Epoch 25 tst: l 0.443 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.126sec
# Epoch 26 tr: l 0.298 a 0.920 clct[np.int64(306), np.int64(300), np.int64(294), np.int64(300)] cl_acc 0.995  lr 0.100000 16.871sec(train) 4.595sec(infer)
# Epoch 26 tst: l 0.429 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.540sec
# Epoch 27 tr: l 0.286 a 0.924 clct[np.int64(305), np.int64(300), np.int64(295), np.int64(300)] cl_acc 0.996  lr 0.100000 16.871sec(train) 4.512sec(infer)
# Epoch 27 tst: l 0.418 a 0.880 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.117sec
# Epoch 28 tr: l 0.276 a 0.926 clct[np.int64(302), np.int64(300), np.int64(298), np.int64(300)] cl_acc 0.998  lr 0.100000 18.049sec(train) 4.435sec(infer)
# Epoch 28 tst: l 0.410 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.062sec
# Epoch 29 tr: l 0.273 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 18.122sec(train) 4.375sec(infer)
# Epoch 29 tst: l 0.400 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.095sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.22 hour (790.500 sec)
# ---------------------------------R:10, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  4.613sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  2.998sec
# Epoch 0 tr: l 2.033 a 0.475 clct[np.int64(334), np.int64(26), np.int64(444), np.int64(396)] cl_acc 0.578  lr 0.100000 17.006sec(train) 4.548sec(infer)
# Epoch 0 tst: l 2.190 a 0.318 clct[np.int64(54), np.int64(3), np.int64(87), np.int64(56)] cl_acc 0.530  3.062sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.787 a 0.598 clct[np.int64(366), np.int64(29), np.int64(426), np.int64(379)] cl_acc 0.617  lr 0.100000 18.562sec(train) 4.022sec(infer)
# Epoch 1 tst: l 2.034 a 0.431 clct[np.int64(57), np.int64(2), np.int64(84), np.int64(57)] cl_acc 0.625  2.977sec
# Epoch 2 tr: l 1.547 a 0.667 clct[np.int64(371), np.int64(33), np.int64(431), np.int64(365)] cl_acc 0.652  lr 0.100000 16.760sec(train) 5.138sec(infer)
# Epoch 2 tst: l 1.831 a 0.525 clct[np.int64(56), np.int64(5), np.int64(86), np.int64(53)] cl_acc 0.700  3.657sec
# Epoch 3 tr: l 1.323 a 0.719 clct[np.int64(373), np.int64(38), np.int64(428), np.int64(361)] cl_acc 0.675  lr 0.100000 16.768sec(train) 4.502sec(infer)
# Epoch 3 tst: l 1.632 a 0.583 clct[np.int64(57), np.int64(8), np.int64(74), np.int64(61)] cl_acc 0.720  3.563sec
# Epoch 4 tr: l 1.132 a 0.753 clct[np.int64(367), np.int64(41), np.int64(440), np.int64(352)] cl_acc 0.694  lr 0.100000 19.163sec(train) 4.587sec(infer)
# Epoch 4 tst: l 1.434 a 0.636 clct[np.int64(59), np.int64(7), np.int64(67), np.int64(67)] cl_acc 0.735  3.491sec
# Epoch 5 tr: l 1.010 a 0.771 clct[np.int64(354), np.int64(45), np.int64(451), np.int64(350)] cl_acc 0.710  lr 0.100000 17.199sec(train) 4.244sec(infer)
# Epoch 5 tst: l 1.289 a 0.666 clct[np.int64(55), np.int64(9), np.int64(68), np.int64(68)] cl_acc 0.750  3.008sec
# Epoch 6 tr: l 0.902 a 0.792 clct[np.int64(339), np.int64(53), np.int64(462), np.int64(346)] cl_acc 0.720  lr 0.100000 17.033sec(train) 5.165sec(infer)
# Epoch 6 tst: l 1.173 a 0.689 clct[np.int64(51), np.int64(13), np.int64(71), np.int64(65)] cl_acc 0.755  2.959sec
# Epoch 7 tr: l 0.813 a 0.808 clct[np.int64(329), np.int64(53), np.int64(481), np.int64(337)] cl_acc 0.723  lr 0.100000 16.957sec(train) 4.488sec(infer)
# Epoch 7 tst: l 1.072 a 0.717 clct[np.int64(51), np.int64(14), np.int64(72), np.int64(63)] cl_acc 0.780  3.536sec
# Epoch 8 tr: l 0.738 a 0.823 clct[np.int64(322), np.int64(59), np.int64(486), np.int64(333)] cl_acc 0.723  lr 0.100000 17.052sec(train) 4.468sec(infer)
# Epoch 8 tst: l 0.998 a 0.729 clct[np.int64(49), np.int64(12), np.int64(78), np.int64(61)] cl_acc 0.760  3.002sec
# Epoch 9 tr: l 0.700 a 0.826 clct[np.int64(313), np.int64(64), np.int64(493), np.int64(330)] cl_acc 0.724  lr 0.100000 17.122sec(train) 4.479sec(infer)
# Epoch 9 tst: l 0.934 a 0.742 clct[np.int64(49), np.int64(10), np.int64(83), np.int64(58)] cl_acc 0.770  3.071sec
# Epoch 10 tr: l 0.653 a 0.834 clct[np.int64(310), np.int64(71), np.int64(492), np.int64(327)] cl_acc 0.722  lr 0.100000 17.051sec(train) 4.371sec(infer)
# Epoch 10 tst: l 0.880 a 0.758 clct[np.int64(52), np.int64(9), np.int64(81), np.int64(58)] cl_acc 0.765  3.035sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.606 a 0.845 clct[np.int64(311), np.int64(80), np.int64(493), np.int64(316)] cl_acc 0.737  lr 0.100000 18.435sec(train) 5.049sec(infer)
# Epoch 11 tst: l 0.833 a 0.766 clct[np.int64(50), np.int64(10), np.int64(89), np.int64(51)] cl_acc 0.775  2.993sec
# Epoch 12 tr: l 0.581 a 0.850 clct[np.int64(309), np.int64(98), np.int64(483), np.int64(310)] cl_acc 0.758  lr 0.100000 16.951sec(train) 4.676sec(infer)
# Epoch 12 tst: l 0.793 a 0.775 clct[np.int64(50), np.int64(13), np.int64(85), np.int64(52)] cl_acc 0.755  3.452sec
# Epoch 13 tr: l 0.562 a 0.855 clct[np.int64(303), np.int64(133), np.int64(458), np.int64(306)] cl_acc 0.796  lr 0.100000 17.053sec(train) 4.842sec(infer)
# Epoch 13 tst: l 0.755 a 0.786 clct[np.int64(50), np.int64(20), np.int64(79), np.int64(51)] cl_acc 0.805  2.972sec
# Epoch 14 tr: l 0.528 a 0.864 clct[np.int64(302), np.int64(175), np.int64(419), np.int64(304)] cl_acc 0.841  lr 0.100000 17.069sec(train) 4.965sec(infer)
# Epoch 14 tst: l 0.715 a 0.800 clct[np.int64(50), np.int64(26), np.int64(74), np.int64(50)] cl_acc 0.850  3.001sec
# Epoch 15 tr: l 0.487 a 0.876 clct[np.int64(301), np.int64(218), np.int64(378), np.int64(303)] cl_acc 0.888  lr 0.100000 17.056sec(train) 4.423sec(infer)
# Epoch 15 tst: l 0.675 a 0.810 clct[np.int64(50), np.int64(36), np.int64(64), np.int64(50)] cl_acc 0.910  3.471sec
# Epoch 16 tr: l 0.448 a 0.890 clct[np.int64(302), np.int64(263), np.int64(332), np.int64(303)] cl_acc 0.942  lr 0.100000 18.070sec(train) 4.782sec(infer)
# Epoch 16 tst: l 0.623 a 0.828 clct[np.int64(50), np.int64(47), np.int64(53), np.int64(50)] cl_acc 0.985  3.366sec
# Epoch 17 tr: l 0.411 a 0.898 clct[np.int64(302), np.int64(278), np.int64(316), np.int64(304)] cl_acc 0.968  lr 0.100000 17.820sec(train) 5.079sec(infer)
# Epoch 17 tst: l 0.582 a 0.839 clct[np.int64(50), np.int64(46), np.int64(54), np.int64(50)] cl_acc 0.980  3.747sec
# Epoch 18 tr: l 0.383 a 0.903 clct[np.int64(302), np.int64(290), np.int64(306), np.int64(302)] cl_acc 0.984  lr 0.100000 16.960sec(train) 4.419sec(infer)
# Epoch 18 tst: l 0.546 a 0.850 clct[np.int64(50), np.int64(48), np.int64(52), np.int64(50)] cl_acc 0.990  3.239sec
# Epoch 19 tr: l 0.356 a 0.910 clct[np.int64(301), np.int64(293), np.int64(304), np.int64(302)] cl_acc 0.990  lr 0.100000 17.336sec(train) 4.494sec(infer)
# Epoch 19 tst: l 0.515 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.002sec
# Epoch 20 tr: l 0.339 a 0.911 clct[np.int64(301), np.int64(295), np.int64(302), np.int64(302)] cl_acc 0.992  lr 0.100000 17.661sec(train) 4.563sec(infer)
# Epoch 20 tst: l 0.488 a 0.865 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.057sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.326 a 0.914 clct[np.int64(301), np.int64(296), np.int64(301), np.int64(302)] cl_acc 0.993  lr 0.100000 19.654sec(train) 4.510sec(infer)
# Epoch 21 tst: l 0.469 a 0.870 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.089sec
# Epoch 22 tr: l 0.315 a 0.917 clct[np.int64(301), np.int64(296), np.int64(302), np.int64(301)] cl_acc 0.993  lr 0.100000 16.990sec(train) 4.962sec(infer)
# Epoch 22 tst: l 0.454 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.998sec
# Epoch 23 tr: l 0.311 a 0.917 clct[np.int64(301), np.int64(298), np.int64(301), np.int64(300)] cl_acc 0.996  lr 0.100000 17.071sec(train) 4.955sec(infer)
# Epoch 23 tst: l 0.441 a 0.877 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.492sec
# Epoch 24 tr: l 0.297 a 0.919 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 17.152sec(train) 4.444sec(infer)
# Epoch 24 tst: l 0.429 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.993sec
# Epoch 25 tr: l 0.287 a 0.922 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 16.854sec(train) 4.429sec(infer)
# Epoch 25 tst: l 0.419 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.082sec
# Epoch 26 tr: l 0.278 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 16.850sec(train) 4.589sec(infer)
# Epoch 26 tst: l 0.411 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.173sec
# Epoch 27 tr: l 0.275 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 16.823sec(train) 4.847sec(infer)
# Epoch 27 tst: l 0.402 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.957sec
# Epoch 28 tr: l 0.268 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 14.601sec(train) 5.789sec(infer)
# Epoch 28 tst: l 0.396 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.987sec
# Epoch 29 tr: l 0.260 a 0.926 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 17.998sec(train) 9.648sec(infer)
# Epoch 29 tst: l 0.390 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.776sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.21 hour (771.740 sec)
# ---------------------------------R:10, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  7.641sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  6.555sec
# Epoch 0 tr: l 2.029 a 0.462 clct[np.int64(403), np.int64(376), np.int64(338), np.int64(83)] cl_acc 0.582  lr 0.100000 18.753sec(train) 9.658sec(infer)
# Epoch 0 tst: l 2.192 a 0.319 clct[np.int64(66), np.int64(63), np.int64(57), np.int64(14)] cl_acc 0.575  8.706sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.786 a 0.598 clct[np.int64(385), np.int64(368), np.int64(350), np.int64(97)] cl_acc 0.621  lr 0.100000 20.467sec(train) 9.473sec(infer)
# Epoch 1 tst: l 2.035 a 0.449 clct[np.int64(61), np.int64(66), np.int64(57), np.int64(16)] cl_acc 0.630  7.123sec
# Epoch 2 tr: l 1.539 a 0.682 clct[np.int64(353), np.int64(385), np.int64(351), np.int64(111)] cl_acc 0.662  lr 0.100000 18.845sec(train) 11.024sec(infer)
# Epoch 2 tst: l 1.833 a 0.538 clct[np.int64(55), np.int64(77), np.int64(55), np.int64(13)] cl_acc 0.755  7.082sec
# Epoch 3 tr: l 1.301 a 0.744 clct[np.int64(325), np.int64(385), np.int64(348), np.int64(142)] cl_acc 0.723  lr 0.100000 19.271sec(train) 11.894sec(infer)
# Epoch 3 tst: l 1.621 a 0.613 clct[np.int64(51), np.int64(74), np.int64(60), np.int64(15)] cl_acc 0.775  6.201sec
# Epoch 4 tr: l 1.103 a 0.784 clct[np.int64(320), np.int64(371), np.int64(333), np.int64(176)] cl_acc 0.774  lr 0.100000 18.333sec(train) 11.655sec(infer)
# Epoch 4 tst: l 1.403 a 0.677 clct[np.int64(50), np.int64(69), np.int64(52), np.int64(29)] cl_acc 0.865  7.974sec
# Epoch 5 tr: l 0.929 a 0.816 clct[np.int64(317), np.int64(346), np.int64(313), np.int64(224)] cl_acc 0.836  lr 0.100000 17.155sec(train) 48.996sec(infer)
# Epoch 5 tst: l 1.230 a 0.715 clct[np.int64(51), np.int64(66), np.int64(52), np.int64(31)] cl_acc 0.890  27.625sec
# Epoch 6 tr: l 0.801 a 0.840 clct[np.int64(309), np.int64(308), np.int64(312), np.int64(271)] cl_acc 0.900  lr 0.100000 24.077sec(train) 48.016sec(infer)
# Epoch 6 tst: l 1.066 a 0.754 clct[np.int64(51), np.int64(53), np.int64(51), np.int64(45)] cl_acc 0.960  30.304sec
# Epoch 7 tr: l 0.692 a 0.861 clct[np.int64(303), np.int64(286), np.int64(309), np.int64(302)] cl_acc 0.948  lr 0.100000 25.449sec(train) 51.887sec(infer)
# Epoch 7 tst: l 0.931 a 0.785 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  26.600sec
# Epoch 8 tr: l 0.604 a 0.874 clct[np.int64(302), np.int64(287), np.int64(306), np.int64(305)] cl_acc 0.971  lr 0.100000 24.043sec(train) 52.136sec(infer)
# Epoch 8 tst: l 0.824 a 0.805 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  26.533sec
# Epoch 9 tr: l 0.534 a 0.884 clct[np.int64(302), np.int64(290), np.int64(304), np.int64(304)] cl_acc 0.983  lr 0.100000 23.626sec(train) 52.201sec(infer)
# Epoch 9 tst: l 0.731 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.681sec
# Epoch 10 tr: l 0.488 a 0.891 clct[np.int64(302), np.int64(294), np.int64(303), np.int64(301)] cl_acc 0.989  lr 0.100000 24.373sec(train) 46.878sec(infer)
# Epoch 10 tst: l 0.667 a 0.839 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.868sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.450 a 0.896 clct[np.int64(302), np.int64(296), np.int64(300), np.int64(302)] cl_acc 0.993  lr 0.100000 24.352sec(train) 56.150sec(infer)
# Epoch 11 tst: l 0.622 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.872sec
# Epoch 12 tr: l 0.419 a 0.901 clct[np.int64(301), np.int64(296), np.int64(300), np.int64(303)] cl_acc 0.995  lr 0.100000 24.087sec(train) 51.461sec(infer)
# Epoch 12 tst: l 0.582 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.499sec
# Epoch 13 tr: l 0.391 a 0.905 clct[np.int64(301), np.int64(297), np.int64(300), np.int64(302)] cl_acc 0.996  lr 0.100000 24.170sec(train) 53.938sec(infer)
# Epoch 13 tst: l 0.556 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.194sec
# Epoch 14 tr: l 0.373 a 0.908 clct[np.int64(300), np.int64(299), np.int64(300), np.int64(301)] cl_acc 0.998  lr 0.100000 24.856sec(train) 50.736sec(infer)
# Epoch 14 tst: l 0.529 a 0.863 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.515sec
# Epoch 15 tr: l 0.357 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.342sec(train) 55.143sec(infer)
# Epoch 15 tst: l 0.509 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.931sec
# Epoch 16 tr: l 0.346 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.897sec(train) 48.290sec(infer)
# Epoch 16 tst: l 0.489 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.288sec
# Epoch 17 tr: l 0.329 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.874sec(train) 57.157sec(infer)
# Epoch 17 tst: l 0.476 a 0.873 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.660sec
# Epoch 18 tr: l 0.315 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.636sec(train) 50.130sec(infer)
# Epoch 18 tst: l 0.464 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.063sec
# Epoch 19 tr: l 0.307 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.659sec(train) 50.620sec(infer)
# Epoch 19 tst: l 0.452 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.905sec
# Epoch 20 tr: l 0.299 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.819sec(train) 51.004sec(infer)
# Epoch 20 tst: l 0.441 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.268sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.292 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.579sec(train) 52.690sec(infer)
# Epoch 21 tst: l 0.434 a 0.882 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.450sec
# Epoch 22 tr: l 0.282 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.925sec(train) 48.740sec(infer)
# Epoch 22 tst: l 0.426 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.344sec
# Epoch 23 tr: l 0.277 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.589sec(train) 54.906sec(infer)
# Epoch 23 tst: l 0.418 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.784sec
# Epoch 24 tr: l 0.272 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.486sec(train) 46.204sec(infer)
# Epoch 24 tst: l 0.413 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.843sec
# Epoch 25 tr: l 0.262 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.652sec(train) 49.487sec(infer)
# Epoch 25 tst: l 0.408 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.851sec
# Epoch 26 tr: l 0.260 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.189sec(train) 48.311sec(infer)
# Epoch 26 tst: l 0.402 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.281sec
# Epoch 27 tr: l 0.255 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.005sec(train) 48.064sec(infer)
# Epoch 27 tst: l 0.399 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  35.009sec
# Epoch 28 tr: l 0.253 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.528sec(train) 47.018sec(infer)
# Epoch 28 tst: l 0.393 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.608sec
# Epoch 29 tr: l 0.247 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.127sec(train) 49.901sec(infer)
# Epoch 29 tst: l 0.389 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.274sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.78 hour (2797.848 sec)
# ---------------------------------R:10, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  43.541sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  34.843sec
# Epoch 0 tr: l 2.041 a 0.425 clct[np.int64(41), np.int64(537), np.int64(364), np.int64(258)] cl_acc 0.414  lr 0.100000 25.946sec(train) 39.796sec(infer)
# Epoch 0 tst: l 2.197 a 0.286 clct[np.int64(7), np.int64(87), np.int64(66), np.int64(40)] cl_acc 0.410  37.069sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.817 a 0.567 clct[np.int64(52), np.int64(519), np.int64(357), np.int64(272)] cl_acc 0.429  lr 0.100000 25.340sec(train) 45.751sec(infer)
# Epoch 1 tst: l 2.058 a 0.403 clct[np.int64(15), np.int64(81), np.int64(57), np.int64(47)] cl_acc 0.480  33.315sec
# Epoch 2 tr: l 1.598 a 0.656 clct[np.int64(59), np.int64(501), np.int64(351), np.int64(289)] cl_acc 0.432  lr 0.100000 24.677sec(train) 42.680sec(infer)
# Epoch 2 tst: l 1.883 a 0.497 clct[np.int64(10), np.int64(80), np.int64(65), np.int64(45)] cl_acc 0.475  35.201sec
# Epoch 3 tr: l 1.379 a 0.715 clct[np.int64(62), np.int64(493), np.int64(348), np.int64(297)] cl_acc 0.443  lr 0.100000 25.735sec(train) 44.076sec(infer)
# Epoch 3 tst: l 1.695 a 0.560 clct[np.int64(9), np.int64(86), np.int64(64), np.int64(41)] cl_acc 0.490  30.470sec
# Epoch 4 tr: l 1.217 a 0.743 clct[np.int64(72), np.int64(487), np.int64(327), np.int64(314)] cl_acc 0.448  lr 0.100000 24.757sec(train) 45.942sec(infer)
# Epoch 4 tst: l 1.526 a 0.615 clct[np.int64(9), np.int64(88), np.int64(55), np.int64(48)] cl_acc 0.485  29.311sec
# Epoch 5 tr: l 1.074 a 0.772 clct[np.int64(82), np.int64(490), np.int64(316), np.int64(312)] cl_acc 0.457  lr 0.100000 26.465sec(train) 46.606sec(infer)
# Epoch 5 tst: l 1.386 a 0.646 clct[np.int64(13), np.int64(89), np.int64(43), np.int64(55)] cl_acc 0.470  29.772sec
# Epoch 6 tr: l 0.969 a 0.791 clct[np.int64(98), np.int64(493), np.int64(300), np.int64(309)] cl_acc 0.458  lr 0.100000 25.644sec(train) 42.787sec(infer)
# Epoch 6 tst: l 1.266 a 0.673 clct[np.int64(14), np.int64(91), np.int64(37), np.int64(58)] cl_acc 0.505  29.776sec
# Epoch 7 tr: l 0.888 a 0.800 clct[np.int64(115), np.int64(507), np.int64(268), np.int64(310)] cl_acc 0.477  lr 0.100000 25.851sec(train) 45.657sec(infer)
# Epoch 7 tst: l 1.164 a 0.694 clct[np.int64(17), np.int64(89), np.int64(44), np.int64(50)] cl_acc 0.490  31.575sec
# Epoch 8 tr: l 0.800 a 0.816 clct[np.int64(122), np.int64(525), np.int64(264), np.int64(289)] cl_acc 0.492  lr 0.100000 24.938sec(train) 44.184sec(infer)
# Epoch 8 tst: l 1.081 a 0.712 clct[np.int64(18), np.int64(97), np.int64(37), np.int64(48)] cl_acc 0.485  28.312sec
# Epoch 9 tr: l 0.730 a 0.828 clct[np.int64(144), np.int64(536), np.int64(235), np.int64(285)] cl_acc 0.516  lr 0.100000 24.748sec(train) 49.402sec(infer)
# Epoch 9 tst: l 1.006 a 0.726 clct[np.int64(27), np.int64(97), np.int64(30), np.int64(46)] cl_acc 0.545  30.757sec
# Epoch 10 tr: l 0.686 a 0.834 clct[np.int64(176), np.int64(545), np.int64(193), np.int64(286)] cl_acc 0.561  lr 0.100000 25.238sec(train) 44.415sec(infer)
# Epoch 10 tst: l 0.946 a 0.738 clct[np.int64(32), np.int64(99), np.int64(28), np.int64(41)] cl_acc 0.570  31.452sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.637 a 0.842 clct[np.int64(202), np.int64(557), np.int64(161), np.int64(280)] cl_acc 0.595  lr 0.100000 23.906sec(train) 44.086sec(infer)
# Epoch 11 tst: l 0.895 a 0.750 clct[np.int64(39), np.int64(98), np.int64(24), np.int64(39)] cl_acc 0.610  33.259sec
# Epoch 12 tr: l 0.602 a 0.849 clct[np.int64(235), np.int64(558), np.int64(150), np.int64(257)] cl_acc 0.629  lr 0.100000 24.830sec(train) 46.951sec(infer)
# Epoch 12 tst: l 0.841 a 0.765 clct[np.int64(41), np.int64(99), np.int64(19), np.int64(41)] cl_acc 0.640  28.447sec
# Epoch 13 tr: l 0.566 a 0.856 clct[np.int64(253), np.int64(566), np.int64(126), np.int64(255)] cl_acc 0.659  lr 0.100000 23.608sec(train) 44.978sec(infer)
# Epoch 13 tst: l 0.786 a 0.779 clct[np.int64(44), np.int64(100), np.int64(13), np.int64(43)] cl_acc 0.680  32.418sec
# Epoch 14 tr: l 0.525 a 0.863 clct[np.int64(261), np.int64(571), np.int64(114), np.int64(254)] cl_acc 0.671  lr 0.100000 25.520sec(train) 44.475sec(infer)
# Epoch 14 tst: l 0.752 a 0.784 clct[np.int64(47), np.int64(98), np.int64(9), np.int64(46)] cl_acc 0.705  29.854sec
# Epoch 15 tr: l 0.499 a 0.868 clct[np.int64(269), np.int64(576), np.int64(104), np.int64(251)] cl_acc 0.687  lr 0.100000 24.681sec(train) 48.867sec(infer)
# Epoch 15 tst: l 0.718 a 0.793 clct[np.int64(49), np.int64(98), np.int64(6), np.int64(47)] cl_acc 0.730  30.365sec
# Epoch 16 tr: l 0.483 a 0.868 clct[np.int64(284), np.int64(578), np.int64(86), np.int64(252)] cl_acc 0.703  lr 0.100000 25.374sec(train) 46.487sec(infer)
# Epoch 16 tst: l 0.683 a 0.803 clct[np.int64(50), np.int64(98), np.int64(3), np.int64(49)] cl_acc 0.755  31.264sec
# Epoch 17 tr: l 0.474 a 0.869 clct[np.int64(286), np.int64(577), np.int64(82), np.int64(255)] cl_acc 0.708  lr 0.100000 24.474sec(train) 42.347sec(infer)
# Epoch 17 tst: l 0.664 a 0.805 clct[np.int64(50), np.int64(98), np.int64(3), np.int64(49)] cl_acc 0.755  32.805sec
# Epoch 18 tr: l 0.455 a 0.874 clct[np.int64(287), np.int64(579), np.int64(79), np.int64(255)] cl_acc 0.710  lr 0.100000 24.920sec(train) 49.011sec(infer)
# Epoch 18 tst: l 0.645 a 0.810 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  30.624sec
# Epoch 19 tr: l 0.444 a 0.873 clct[np.int64(288), np.int64(580), np.int64(72), np.int64(260)] cl_acc 0.716  lr 0.100000 23.878sec(train) 44.871sec(infer)
# Epoch 19 tst: l 0.631 a 0.815 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  31.354sec
# Epoch 20 tr: l 0.427 a 0.877 clct[np.int64(288), np.int64(583), np.int64(67), np.int64(262)] cl_acc 0.719  lr 0.100000 26.888sec(train) 45.387sec(infer)
# Epoch 20 tst: l 0.622 a 0.816 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  29.416sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.423 a 0.878 clct[np.int64(290), np.int64(583), np.int64(61), np.int64(266)] cl_acc 0.724  lr 0.100000 24.595sec(train) 43.120sec(infer)
# Epoch 21 tst: l 0.605 a 0.820 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  31.588sec
# Epoch 22 tr: l 0.410 a 0.881 clct[np.int64(290), np.int64(584), np.int64(59), np.int64(267)] cl_acc 0.724  lr 0.100000 25.377sec(train) 46.594sec(infer)
# Epoch 22 tst: l 0.590 a 0.823 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  27.907sec
# Epoch 23 tr: l 0.402 a 0.883 clct[np.int64(292), np.int64(585), np.int64(53), np.int64(270)] cl_acc 0.728  lr 0.100000 26.512sec(train) 42.010sec(infer)
# Epoch 23 tst: l 0.584 a 0.824 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  29.614sec
# Epoch 24 tr: l 0.395 a 0.884 clct[np.int64(292), np.int64(584), np.int64(53), np.int64(271)] cl_acc 0.729  lr 0.100000 25.597sec(train) 46.822sec(infer)
# Epoch 24 tst: l 0.580 a 0.826 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  32.980sec
# Epoch 25 tr: l 0.388 a 0.885 clct[np.int64(293), np.int64(584), np.int64(52), np.int64(271)] cl_acc 0.730  lr 0.100000 24.861sec(train) 41.605sec(infer)
# Epoch 25 tst: l 0.567 a 0.828 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  29.339sec
# Epoch 26 tr: l 0.378 a 0.887 clct[np.int64(294), np.int64(584), np.int64(50), np.int64(272)] cl_acc 0.732  lr 0.100000 25.418sec(train) 45.158sec(infer)
# Epoch 26 tst: l 0.558 a 0.830 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  30.698sec
# Epoch 27 tr: l 0.370 a 0.888 clct[np.int64(294), np.int64(584), np.int64(50), np.int64(272)] cl_acc 0.732  lr 0.100000 24.644sec(train) 45.763sec(infer)
# Epoch 27 tst: l 0.554 a 0.831 clct[np.int64(50), np.int64(98), np.int64(4), np.int64(48)] cl_acc 0.750  28.278sec
# Epoch 28 tr: l 0.377 a 0.887 clct[np.int64(294), np.int64(582), np.int64(50), np.int64(274)] cl_acc 0.735  lr 0.100000 24.651sec(train) 47.408sec(infer)
# Epoch 28 tst: l 0.545 a 0.835 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  28.702sec
# Epoch 29 tr: l 0.361 a 0.891 clct[np.int64(294), np.int64(583), np.int64(47), np.int64(276)] cl_acc 0.736  lr 0.100000 27.124sec(train) 46.924sec(infer)
# Epoch 29 tst: l 0.544 a 0.834 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  28.201sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.87 hour (3115.754 sec)
# ---------------------------------R:10, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  44.998sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  32.367sec
# Epoch 0 tr: l 2.054 a 0.449 clct[np.int64(139), np.int64(206), np.int64(203), np.int64(652)] cl_acc 0.367  lr 0.100000 22.245sec(train) 51.583sec(infer)
# Epoch 0 tst: l 2.193 a 0.321 clct[np.int64(20), np.int64(39), np.int64(31), np.int64(110)] cl_acc 0.390  28.881sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.824 a 0.567 clct[np.int64(155), np.int64(241), np.int64(221), np.int64(583)] cl_acc 0.385  lr 0.100000 20.409sec(train) 49.467sec(infer)
# Epoch 1 tst: l 2.052 a 0.430 clct[np.int64(22), np.int64(34), np.int64(35), np.int64(109)] cl_acc 0.415  27.523sec
# Epoch 2 tr: l 1.578 a 0.648 clct[np.int64(171), np.int64(278), np.int64(226), np.int64(525)] cl_acc 0.408  lr 0.100000 23.374sec(train) 50.544sec(infer)
# Epoch 2 tst: l 1.874 a 0.504 clct[np.int64(30), np.int64(40), np.int64(39), np.int64(91)] cl_acc 0.435  29.748sec
# Epoch 3 tr: l 1.364 a 0.701 clct[np.int64(179), np.int64(290), np.int64(232), np.int64(499)] cl_acc 0.429  lr 0.100000 24.852sec(train) 45.502sec(infer)
# Epoch 3 tst: l 1.692 a 0.569 clct[np.int64(30), np.int64(52), np.int64(34), np.int64(84)] cl_acc 0.455  29.388sec
# Epoch 4 tr: l 1.202 a 0.740 clct[np.int64(186), np.int64(328), np.int64(234), np.int64(452)] cl_acc 0.460  lr 0.100000 24.835sec(train) 49.904sec(infer)
# Epoch 4 tst: l 1.531 a 0.610 clct[np.int64(29), np.int64(58), np.int64(30), np.int64(83)] cl_acc 0.510  30.272sec
# Epoch 5 tr: l 1.063 a 0.770 clct[np.int64(198), np.int64(344), np.int64(241), np.int64(417)] cl_acc 0.488  lr 0.100000 25.462sec(train) 43.597sec(infer)
# Epoch 5 tst: l 1.390 a 0.644 clct[np.int64(35), np.int64(47), np.int64(37), np.int64(81)] cl_acc 0.520  30.454sec
# Epoch 6 tr: l 0.965 a 0.789 clct[np.int64(202), np.int64(353), np.int64(226), np.int64(419)] cl_acc 0.498  lr 0.100000 25.040sec(train) 47.455sec(infer)
# Epoch 6 tst: l 1.261 a 0.676 clct[np.int64(37), np.int64(49), np.int64(43), np.int64(71)] cl_acc 0.540  32.767sec
# Epoch 7 tr: l 0.864 a 0.808 clct[np.int64(205), np.int64(360), np.int64(223), np.int64(412)] cl_acc 0.512  lr 0.100000 23.869sec(train) 48.241sec(infer)
# Epoch 7 tst: l 1.156 a 0.702 clct[np.int64(38), np.int64(45), np.int64(38), np.int64(79)] cl_acc 0.540  31.428sec
# Epoch 8 tr: l 0.801 a 0.815 clct[np.int64(210), np.int64(349), np.int64(221), np.int64(420)] cl_acc 0.524  lr 0.100000 24.147sec(train) 46.289sec(infer)
# Epoch 8 tst: l 1.084 a 0.714 clct[np.int64(39), np.int64(49), np.int64(38), np.int64(74)] cl_acc 0.555  34.689sec
# Epoch 9 tr: l 0.743 a 0.825 clct[np.int64(202), np.int64(364), np.int64(224), np.int64(410)] cl_acc 0.547  lr 0.100000 24.217sec(train) 48.101sec(infer)
# Epoch 9 tst: l 1.020 a 0.729 clct[np.int64(27), np.int64(54), np.int64(40), np.int64(79)] cl_acc 0.595  27.879sec
# Epoch 10 tr: l 0.686 a 0.837 clct[np.int64(196), np.int64(373), np.int64(220), np.int64(411)] cl_acc 0.563  lr 0.100000 24.827sec(train) 47.314sec(infer)
# Epoch 10 tst: l 0.964 a 0.736 clct[np.int64(29), np.int64(56), np.int64(42), np.int64(73)] cl_acc 0.615  32.827sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.650 a 0.842 clct[np.int64(185), np.int64(381), np.int64(230), np.int64(404)] cl_acc 0.578  lr 0.100000 26.756sec(train) 45.299sec(infer)
# Epoch 11 tst: l 0.911 a 0.748 clct[np.int64(29), np.int64(63), np.int64(41), np.int64(67)] cl_acc 0.650  28.850sec
# Epoch 12 tr: l 0.615 a 0.844 clct[np.int64(180), np.int64(390), np.int64(232), np.int64(398)] cl_acc 0.595  lr 0.100000 25.892sec(train) 48.980sec(infer)
# Epoch 12 tst: l 0.866 a 0.758 clct[np.int64(28), np.int64(60), np.int64(41), np.int64(71)] cl_acc 0.640  29.033sec
# Epoch 13 tr: l 0.590 a 0.849 clct[np.int64(189), np.int64(404), np.int64(227), np.int64(380)] cl_acc 0.626  lr 0.100000 25.768sec(train) 46.644sec(infer)
# Epoch 13 tst: l 0.834 a 0.764 clct[np.int64(24), np.int64(61), np.int64(46), np.int64(69)] cl_acc 0.680  32.403sec
# Epoch 14 tr: l 0.563 a 0.854 clct[np.int64(193), np.int64(414), np.int64(223), np.int64(370)] cl_acc 0.667  lr 0.100000 25.097sec(train) 48.911sec(infer)
# Epoch 14 tst: l 0.793 a 0.775 clct[np.int64(23), np.int64(63), np.int64(45), np.int64(69)] cl_acc 0.695  30.501sec
# Epoch 15 tr: l 0.530 a 0.861 clct[np.int64(188), np.int64(434), np.int64(226), np.int64(352)] cl_acc 0.693  lr 0.100000 26.301sec(train) 45.928sec(infer)
# Epoch 15 tst: l 0.755 a 0.784 clct[np.int64(18), np.int64(73), np.int64(50), np.int64(59)] cl_acc 0.770  31.696sec
# Epoch 16 tr: l 0.504 a 0.866 clct[np.int64(192), np.int64(446), np.int64(226), np.int64(336)] cl_acc 0.722  lr 0.100000 24.929sec(train) 46.466sec(infer)
# Epoch 16 tst: l 0.729 a 0.791 clct[np.int64(22), np.int64(73), np.int64(47), np.int64(58)] cl_acc 0.795  32.403sec
# Epoch 17 tr: l 0.485 a 0.870 clct[np.int64(221), np.int64(426), np.int64(232), np.int64(321)] cl_acc 0.768  lr 0.100000 27.028sec(train) 45.184sec(infer)
# Epoch 17 tst: l 0.692 a 0.803 clct[np.int64(35), np.int64(68), np.int64(43), np.int64(54)] cl_acc 0.825  30.900sec
# Epoch 18 tr: l 0.460 a 0.877 clct[np.int64(238), np.int64(405), np.int64(245), np.int64(312)] cl_acc 0.817  lr 0.100000 25.912sec(train) 43.254sec(infer)
# Epoch 18 tst: l 0.663 a 0.809 clct[np.int64(34), np.int64(65), np.int64(48), np.int64(53)] cl_acc 0.890  32.989sec
# Epoch 19 tr: l 0.435 a 0.885 clct[np.int64(263), np.int64(377), np.int64(251), np.int64(309)] cl_acc 0.861  lr 0.100000 25.631sec(train) 50.194sec(infer)
# Epoch 19 tst: l 0.627 a 0.820 clct[np.int64(39), np.int64(60), np.int64(49), np.int64(52)] cl_acc 0.930  31.775sec
# Epoch 20 tr: l 0.413 a 0.891 clct[np.int64(273), np.int64(360), np.int64(261), np.int64(306)] cl_acc 0.899  lr 0.100000 25.218sec(train) 42.535sec(infer)
# Epoch 20 tst: l 0.600 a 0.829 clct[np.int64(41), np.int64(58), np.int64(50), np.int64(51)] cl_acc 0.955  32.223sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.392 a 0.894 clct[np.int64(297), np.int64(324), np.int64(274), np.int64(305)] cl_acc 0.949  lr 0.100000 26.060sec(train) 46.913sec(infer)
# Epoch 21 tst: l 0.565 a 0.840 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.346sec
# Epoch 22 tr: l 0.366 a 0.903 clct[np.int64(298), np.int64(312), np.int64(285), np.int64(305)] cl_acc 0.968  lr 0.100000 26.689sec(train) 44.614sec(infer)
# Epoch 22 tst: l 0.533 a 0.850 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  29.352sec
# Epoch 23 tr: l 0.343 a 0.909 clct[np.int64(300), np.int64(304), np.int64(291), np.int64(305)] cl_acc 0.980  lr 0.100000 26.078sec(train) 48.932sec(infer)
# Epoch 23 tst: l 0.504 a 0.857 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  27.916sec
# Epoch 24 tr: l 0.326 a 0.914 clct[np.int64(298), np.int64(303), np.int64(296), np.int64(303)] cl_acc 0.990  lr 0.100000 27.209sec(train) 43.665sec(infer)
# Epoch 24 tst: l 0.484 a 0.864 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  28.377sec
# Epoch 25 tr: l 0.315 a 0.916 clct[np.int64(298), np.int64(302), np.int64(297), np.int64(303)] cl_acc 0.992  lr 0.100000 24.344sec(train) 48.094sec(infer)
# Epoch 25 tst: l 0.467 a 0.870 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  32.751sec
# Epoch 26 tr: l 0.304 a 0.918 clct[np.int64(297), np.int64(303), np.int64(298), np.int64(302)] cl_acc 0.993  lr 0.100000 23.920sec(train) 47.686sec(infer)
# Epoch 26 tst: l 0.455 a 0.872 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  27.839sec
# Epoch 27 tr: l 0.290 a 0.922 clct[np.int64(299), np.int64(302), np.int64(298), np.int64(301)] cl_acc 0.996  lr 0.100000 24.515sec(train) 50.278sec(infer)
# Epoch 27 tst: l 0.444 a 0.875 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  32.872sec
# Epoch 28 tr: l 0.282 a 0.922 clct[np.int64(298), np.int64(302), np.int64(299), np.int64(301)] cl_acc 0.997  lr 0.100000 25.083sec(train) 47.852sec(infer)
# Epoch 28 tst: l 0.435 a 0.877 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  28.760sec
# Epoch 29 tr: l 0.276 a 0.924 clct[np.int64(298), np.int64(302), np.int64(299), np.int64(301)] cl_acc 0.997  lr 0.100000 26.072sec(train) 46.265sec(infer)
# Epoch 29 tst: l 0.423 a 0.880 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  31.614sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.88 hour (3163.883 sec)

# %% [markdown]
# ## Plots

# %%
r_ten = {}
r_twentyfive = {}
r_fifty = {}

r_ten['cl_acc'] = []
r_ten['train_loss'] = []
r_ten['test_loss'] = []
r_ten['test_acc'] = []
for i in range(len(learning_rates)):
    r_ten['cl_acc'].append(ten[i][2])
    r_ten['train_loss'].append(ten[i][3])
    r_ten['test_loss'].append(ten[i][0])
    r_ten['test_acc'].append(ten[i][1])

r_twentyfive['cl_acc'] = []
r_twentyfive['train_loss'] = []
r_twentyfive['test_loss'] = []
r_twentyfive['test_acc'] = []
for i in range(len(learning_rates)):
    r_twentyfive['cl_acc'].append(twentyfive[i][2])
    r_twentyfive['train_loss'].append(twentyfive[i][3])
    r_twentyfive['test_loss'].append(twentyfive[i][0])
    r_twentyfive['test_acc'].append(twentyfive[i][1])

r_fifty['cl_acc'] = []
r_fifty['train_loss'] = []
r_fifty['test_loss'] = []
r_fifty['test_acc'] = []
for i in range(len(learning_rates)):
    r_fifty['cl_acc'].append(fifty[i][2])
    r_fifty['train_loss'].append(fifty[i][3])
    r_fifty['test_loss'].append(fifty[i][0])
    r_fifty['test_acc'].append(fifty[i][1])


os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,7))
    plt.plot(r_ten['test_loss'][l], label='R=10', color='xkcd:azure')
    plt.plot(r_twentyfive['test_loss'][l], label='R=25', color='red')
    plt.plot(r_fifty['test_loss'][l], label='R=50', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'train_loss.png'))

    plt.figure(figsize=(10,7))
    plt.plot(r_ten['test_acc'][l], label='R=10', color='xkcd:azure')
    plt.plot(r_twentyfive['test_acc'][l], label='R=25', color='red')
    plt.plot(r_fifty['test_acc'][l], label='R=50', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('test accuracy', fontsize=20)
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_acc.png'))

    plt.figure(figsize=(10,7))
    plt.ylim([0, 1.1])
    plt.plot(r_ten['cl_acc'][l], label='R=10', color='xkcd:azure', marker='o')
    plt.plot(r_twentyfive['cl_acc'][l], label='R=25', color='red', marker='o')
    plt.plot(r_fifty['cl_acc'][l], label='R=50', color='red', marker='o')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('cluster acc', fontsize=20)
    # plt.title(f'Cluster Accuracy per Epoch (Participation Rate={p_rates[l]})', fontsize=22, fontweight='bold')
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.savefig(os.path.join('graphs', f'cluster_acc_pn_{learning_rates[l]}.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 20
#      18 r_twentyfive['test_acc'] = []
#      19 for i in range(len(learning_rates)):
# ---> 20     r_twentyfive['cl_acc'].append(twentyfive[i][2])
#      21     r_twentyfive['train_loss'].append(twentyfive[i][3])
#      22     r_twentyfive['test_loss'].append(twentyfive[i][0])
#
# IndexError: list index out of range
