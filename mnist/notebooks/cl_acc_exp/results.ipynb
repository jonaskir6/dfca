# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_fixed.json

# %%
rc = ipp.Cluster(n=3).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]

# %%
learning_rates = [0.1]

ten = []
twentyfive = []
fifty = []

# %%
# %%px --targets all
#
# import sys
# import os
# import random
# sys.path.append(os.getcwd())
#
# random.seed(42)
# seeds = random.sample(range(10000), 5)
# learning_rates = [0.1]
#
# ten = []
# twentyfive = []
# fifty = []

# %% [markdown]
# Running with adaptive lambda

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 10
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ten.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running with fixed lambda

# %%
# %%px --target 1 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 25
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     twentyfive.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %%
# %%px --target 2 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config.json", "r") as read_file:
#     config = json.load(read_file)
#
# r = 50
# config['R'] = r
#
# for lr in learning_rates:
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------R:{r}, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     fifty.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# ### Outputs

# %%
rc.wait_interactive()
_.display_outputs()

ten = rc[0].pull('ten', block=True)
twentyfive = rc[1].pull('twentyfive', block=True)
fifty = rc[2].pull('fifty', block=True)
# Out:
# unknown:   0%|          | 0/3 [00:00<?, ?tasks/s]
# ---------------------------------R:50, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  49.738sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  27.993sec
# Epoch 0 tr: l 2.132 a 0.326 clct[np.int64(627), np.int64(234), np.int64(215), np.int64(124)] cl_acc 0.423  lr 0.100000 33.273sec(train) 43.858sec(infer)
# Epoch 0 tst: l 2.188 a 0.291 clct[np.int64(102), np.int64(44), np.int64(36), np.int64(18)] cl_acc 0.460  28.085sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.949 a 0.501 clct[np.int64(323), np.int64(376), np.int64(269), np.int64(232)] cl_acc 0.665  lr 0.100000 31.486sec(train) 44.483sec(infer)
# Epoch 1 tst: l 2.025 a 0.451 clct[np.int64(60), np.int64(59), np.int64(48), np.int64(33)] cl_acc 0.655  28.846sec
# Epoch 2 tr: l 1.688 a 0.644 clct[np.int64(254), np.int64(375), np.int64(279), np.int64(292)] cl_acc 0.862  lr 0.100000 31.586sec(train) 44.364sec(infer)
# Epoch 2 tst: l 1.770 a 0.603 clct[np.int64(36), np.int64(70), np.int64(47), np.int64(47)] cl_acc 0.860  29.317sec
# Epoch 3 tr: l 1.394 a 0.738 clct[np.int64(301), np.int64(308), np.int64(292), np.int64(299)] cl_acc 0.968  lr 0.100000 30.675sec(train) 46.428sec(infer)
# Epoch 3 tst: l 1.453 a 0.712 clct[np.int64(52), np.int64(51), np.int64(47), np.int64(50)] cl_acc 0.980  28.282sec
# Epoch 4 tr: l 1.114 a 0.788 clct[np.int64(301), np.int64(301), np.int64(296), np.int64(302)] cl_acc 0.994  lr 0.100000 31.116sec(train) 44.442sec(infer)
# Epoch 4 tst: l 1.170 a 0.772 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.595sec
# Epoch 5 tr: l 0.920 a 0.816 clct[np.int64(300), np.int64(301), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 29.346sec(train) 47.003sec(infer)
# Epoch 5 tst: l 0.964 a 0.803 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.028sec
# Epoch 6 tr: l 0.787 a 0.835 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.159sec(train) 46.439sec(infer)
# Epoch 6 tst: l 0.825 a 0.822 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.948sec
# Epoch 7 tr: l 0.699 a 0.847 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.958sec(train) 46.887sec(infer)
# Epoch 7 tst: l 0.726 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.347sec
# Epoch 8 tr: l 0.630 a 0.857 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.442sec(train) 45.622sec(infer)
# Epoch 8 tst: l 0.655 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.966sec
# Epoch 9 tr: l 0.576 a 0.865 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.627sec(train) 47.501sec(infer)
# Epoch 9 tst: l 0.603 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.590sec
# Epoch 10 tr: l 0.535 a 0.870 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.037sec(train) 44.966sec(infer)
# Epoch 10 tst: l 0.560 a 0.862 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.827sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.504 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.069sec(train) 45.664sec(infer)
# Epoch 11 tst: l 0.528 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.225sec
# Epoch 12 tr: l 0.478 a 0.879 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.720sec(train) 46.566sec(infer)
# Epoch 12 tst: l 0.500 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.739sec
# Epoch 13 tr: l 0.458 a 0.882 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.846sec(train) 44.545sec(infer)
# Epoch 13 tst: l 0.479 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.655sec
# Epoch 14 tr: l 0.439 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.017sec(train) 47.506sec(infer)
# Epoch 14 tst: l 0.460 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.759sec
# Epoch 15 tr: l 0.428 a 0.887 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.677sec(train) 44.516sec(infer)
# Epoch 15 tst: l 0.446 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.204sec
# Epoch 16 tr: l 0.411 a 0.890 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.658sec(train) 46.667sec(infer)
# Epoch 16 tst: l 0.431 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.371sec
# Epoch 17 tr: l 0.402 a 0.892 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.148sec(train) 47.392sec(infer)
# Epoch 17 tst: l 0.419 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.131sec
# Epoch 18 tr: l 0.389 a 0.894 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.873sec(train) 45.772sec(infer)
# Epoch 18 tst: l 0.408 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.020sec
# Epoch 19 tr: l 0.378 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.164sec(train) 48.483sec(infer)
# Epoch 19 tst: l 0.400 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.922sec
# Epoch 20 tr: l 0.369 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.276sec(train) 46.458sec(infer)
# Epoch 20 tst: l 0.392 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.362sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.365 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.301sec(train) 46.327sec(infer)
# Epoch 21 tst: l 0.386 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.764sec
# Epoch 22 tr: l 0.355 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.724sec(train) 48.219sec(infer)
# Epoch 22 tst: l 0.378 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.483sec
# Epoch 23 tr: l 0.352 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.813sec(train) 44.601sec(infer)
# Epoch 23 tst: l 0.372 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.488sec
# Epoch 24 tr: l 0.348 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.145sec(train) 47.722sec(infer)
# Epoch 24 tst: l 0.366 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.939sec
# Epoch 25 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.655sec(train) 46.164sec(infer)
# Epoch 25 tst: l 0.361 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.784sec
# Epoch 26 tr: l 0.339 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.180sec(train) 46.809sec(infer)
# Epoch 26 tst: l 0.356 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.359sec
# Epoch 27 tr: l 0.331 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.073sec(train) 45.428sec(infer)
# Epoch 27 tst: l 0.352 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.749sec
# Epoch 28 tr: l 0.327 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.777sec(train) 46.808sec(infer)
# Epoch 28 tst: l 0.349 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.563sec
# Epoch 29 tr: l 0.322 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.221sec(train) 44.792sec(infer)
# Epoch 29 tst: l 0.345 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.834sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.91 hour (3281.621 sec)
# ---------------------------------R:50, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  48.328sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  29.602sec
# Epoch 0 tr: l 2.125 a 0.416 clct[np.int64(343), np.int64(47), np.int64(452), np.int64(358)] cl_acc 0.688  lr 0.100000 30.025sec(train) 46.204sec(infer)
# Epoch 0 tst: l 2.179 a 0.366 clct[np.int64(57), np.int64(7), np.int64(84), np.int64(52)] cl_acc 0.680  29.258sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.904 a 0.586 clct[np.int64(317), np.int64(77), np.int64(482), np.int64(324)] cl_acc 0.728  lr 0.100000 28.840sec(train) 48.891sec(infer)
# Epoch 1 tst: l 1.981 a 0.539 clct[np.int64(52), np.int64(11), np.int64(87), np.int64(50)] cl_acc 0.730  27.892sec
# Epoch 2 tr: l 1.633 a 0.662 clct[np.int64(302), np.int64(117), np.int64(479), np.int64(302)] cl_acc 0.740  lr 0.100000 30.322sec(train) 44.961sec(infer)
# Epoch 2 tst: l 1.721 a 0.631 clct[np.int64(51), np.int64(20), np.int64(79), np.int64(50)] cl_acc 0.750  30.356sec
# Epoch 3 tr: l 1.395 a 0.702 clct[np.int64(301), np.int64(147), np.int64(453), np.int64(299)] cl_acc 0.759  lr 0.100000 30.579sec(train) 47.944sec(infer)
# Epoch 3 tst: l 1.464 a 0.681 clct[np.int64(50), np.int64(26), np.int64(74), np.int64(50)] cl_acc 0.780  28.697sec
# Epoch 4 tr: l 1.183 a 0.741 clct[np.int64(300), np.int64(195), np.int64(406), np.int64(299)] cl_acc 0.810  lr 0.100000 29.843sec(train) 45.892sec(infer)
# Epoch 4 tst: l 1.247 a 0.724 clct[np.int64(50), np.int64(30), np.int64(70), np.int64(50)] cl_acc 0.790  29.476sec
# Epoch 5 tr: l 1.037 a 0.768 clct[np.int64(301), np.int64(256), np.int64(344), np.int64(299)] cl_acc 0.921  lr 0.100000 30.568sec(train) 44.788sec(infer)
# Epoch 5 tst: l 1.093 a 0.750 clct[np.int64(50), np.int64(39), np.int64(61), np.int64(50)] cl_acc 0.895  29.744sec
# Epoch 6 tr: l 0.888 a 0.803 clct[np.int64(301), np.int64(289), np.int64(311), np.int64(299)] cl_acc 0.983  lr 0.100000 29.443sec(train) 44.078sec(infer)
# Epoch 6 tst: l 0.934 a 0.791 clct[np.int64(50), np.int64(49), np.int64(51), np.int64(50)] cl_acc 0.985  27.920sec
# Epoch 7 tr: l 0.767 a 0.828 clct[np.int64(301), np.int64(295), np.int64(304), np.int64(300)] cl_acc 0.993  lr 0.100000 29.175sec(train) 42.171sec(infer)
# Epoch 7 tst: l 0.806 a 0.817 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.087sec
# Epoch 8 tr: l 0.679 a 0.843 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.998  lr 0.100000 29.849sec(train) 44.238sec(infer)
# Epoch 8 tst: l 0.708 a 0.837 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.943sec
# Epoch 9 tr: l 0.618 a 0.854 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.567sec(train) 46.914sec(infer)
# Epoch 9 tst: l 0.643 a 0.848 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.715sec
# Epoch 10 tr: l 0.565 a 0.863 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 28.207sec(train) 44.925sec(infer)
# Epoch 10 tst: l 0.594 a 0.857 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.752sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.529 a 0.869 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.040sec(train) 46.413sec(infer)
# Epoch 11 tst: l 0.556 a 0.863 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.587sec
# Epoch 12 tr: l 0.497 a 0.873 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.154sec(train) 50.046sec(infer)
# Epoch 12 tst: l 0.524 a 0.869 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  24.922sec
# Epoch 13 tr: l 0.473 a 0.878 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.654sec(train) 50.207sec(infer)
# Epoch 13 tst: l 0.501 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.730sec
# Epoch 14 tr: l 0.455 a 0.882 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.444sec(train) 47.771sec(infer)
# Epoch 14 tst: l 0.478 a 0.877 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.238sec
# Epoch 15 tr: l 0.434 a 0.884 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.980sec(train) 46.112sec(infer)
# Epoch 15 tst: l 0.460 a 0.880 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.130sec
# Epoch 16 tr: l 0.418 a 0.887 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 27.445sec(train) 47.502sec(infer)
# Epoch 16 tst: l 0.445 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.656sec
# Epoch 17 tr: l 0.405 a 0.891 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.060sec(train) 44.222sec(infer)
# Epoch 17 tst: l 0.433 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.856sec
# Epoch 18 tr: l 0.392 a 0.893 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.144sec(train) 45.320sec(infer)
# Epoch 18 tst: l 0.422 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.705sec
# Epoch 19 tr: l 0.384 a 0.893 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.802sec(train) 44.208sec(infer)
# Epoch 19 tst: l 0.413 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.016sec
# Epoch 20 tr: l 0.375 a 0.896 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.414sec(train) 43.779sec(infer)
# Epoch 20 tst: l 0.404 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.068sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.369 a 0.897 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.856sec(train) 44.981sec(infer)
# Epoch 21 tst: l 0.396 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.263sec
# Epoch 22 tr: l 0.362 a 0.899 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 31.496sec(train) 42.416sec(infer)
# Epoch 22 tst: l 0.387 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.971sec
# Epoch 23 tr: l 0.355 a 0.899 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.962sec(train) 43.842sec(infer)
# Epoch 23 tst: l 0.381 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.203sec
# Epoch 24 tr: l 0.348 a 0.901 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 31.255sec(train) 39.979sec(infer)
# Epoch 24 tst: l 0.376 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.187sec
# Epoch 25 tr: l 0.343 a 0.901 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.977sec(train) 42.133sec(infer)
# Epoch 25 tst: l 0.372 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.719sec
# Epoch 26 tr: l 0.338 a 0.904 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.370sec(train) 41.253sec(infer)
# Epoch 26 tst: l 0.367 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.976sec
# Epoch 27 tr: l 0.332 a 0.904 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.677sec(train) 40.610sec(infer)
# Epoch 27 tst: l 0.362 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.165sec
# Epoch 28 tr: l 0.330 a 0.905 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 29.714sec(train) 43.702sec(infer)
# Epoch 28 tst: l 0.359 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.702sec
# Epoch 29 tr: l 0.327 a 0.905 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 30.380sec(train) 42.776sec(infer)
# Epoch 29 tst: l 0.353 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.507sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.88 hour (3172.294 sec)
# ---------------------------------R:50, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  42.584sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  26.229sec
# Epoch 0 tr: l 2.123 a 0.422 clct[np.int64(331), np.int64(386), np.int64(340), np.int64(143)] cl_acc 0.727  lr 0.100000 29.857sec(train) 40.576sec(infer)
# Epoch 0 tst: l 2.175 a 0.372 clct[np.int64(52), np.int64(61), np.int64(60), np.int64(27)] cl_acc 0.760  31.471sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.894 a 0.618 clct[np.int64(306), np.int64(310), np.int64(301), np.int64(283)] cl_acc 0.912  lr 0.100000 29.702sec(train) 41.368sec(infer)
# Epoch 1 tst: l 1.960 a 0.583 clct[np.int64(52), np.int64(54), np.int64(48), np.int64(46)] cl_acc 0.950  30.029sec
# Epoch 2 tr: l 1.574 a 0.728 clct[np.int64(304), np.int64(296), np.int64(301), np.int64(299)] cl_acc 0.978  lr 0.100000 29.942sec(train) 39.684sec(infer)
# Epoch 2 tst: l 1.659 a 0.693 clct[np.int64(51), np.int64(49), np.int64(48), np.int64(52)] cl_acc 0.985  32.356sec
# Epoch 3 tr: l 1.264 a 0.779 clct[np.int64(300), np.int64(298), np.int64(300), np.int64(302)] cl_acc 0.993  lr 0.100000 30.271sec(train) 41.030sec(infer)
# Epoch 3 tst: l 1.329 a 0.765 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.383sec
# Epoch 4 tr: l 1.014 a 0.814 clct[np.int64(300), np.int64(299), np.int64(301), np.int64(300)] cl_acc 0.997  lr 0.100000 29.584sec(train) 40.409sec(infer)
# Epoch 4 tst: l 1.091 a 0.796 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.652sec
# Epoch 5 tr: l 0.854 a 0.832 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 31.059sec(train) 40.217sec(infer)
# Epoch 5 tst: l 0.913 a 0.820 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.697sec
# Epoch 6 tr: l 0.737 a 0.846 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.763sec(train) 40.921sec(infer)
# Epoch 6 tst: l 0.793 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.220sec
# Epoch 7 tr: l 0.656 a 0.857 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.082sec(train) 40.995sec(infer)
# Epoch 7 tst: l 0.710 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.924sec
# Epoch 8 tr: l 0.604 a 0.862 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.026sec(train) 42.675sec(infer)
# Epoch 8 tst: l 0.646 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.100sec
# Epoch 9 tr: l 0.558 a 0.869 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.584sec(train) 41.891sec(infer)
# Epoch 9 tst: l 0.598 a 0.862 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.637sec
# Epoch 10 tr: l 0.519 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.765sec(train) 43.028sec(infer)
# Epoch 10 tst: l 0.562 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.195sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.492 a 0.878 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.664sec(train) 41.791sec(infer)
# Epoch 11 tst: l 0.532 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.507sec
# Epoch 12 tr: l 0.471 a 0.881 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.759sec(train) 42.113sec(infer)
# Epoch 12 tst: l 0.509 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.117sec
# Epoch 13 tr: l 0.443 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.929sec(train) 42.407sec(infer)
# Epoch 13 tst: l 0.489 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.735sec
# Epoch 14 tr: l 0.429 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.529sec(train) 42.270sec(infer)
# Epoch 14 tst: l 0.472 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.492sec
# Epoch 15 tr: l 0.419 a 0.889 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.647sec(train) 43.085sec(infer)
# Epoch 15 tst: l 0.457 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.178sec
# Epoch 16 tr: l 0.405 a 0.891 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.972sec(train) 41.725sec(infer)
# Epoch 16 tst: l 0.446 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.133sec
# Epoch 17 tr: l 0.397 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.112sec(train) 43.882sec(infer)
# Epoch 17 tst: l 0.434 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.596sec
# Epoch 18 tr: l 0.385 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.299sec(train) 44.639sec(infer)
# Epoch 18 tst: l 0.425 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.907sec
# Epoch 19 tr: l 0.376 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.524sec(train) 43.547sec(infer)
# Epoch 19 tst: l 0.416 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.433sec
# Epoch 20 tr: l 0.371 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.019sec(train) 44.946sec(infer)
# Epoch 20 tst: l 0.408 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.122sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.362 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.373sec(train) 43.986sec(infer)
# Epoch 21 tst: l 0.402 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.560sec
# Epoch 22 tr: l 0.354 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.902sec(train) 44.001sec(infer)
# Epoch 22 tst: l 0.396 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.302sec
# Epoch 23 tr: l 0.347 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.020sec(train) 44.003sec(infer)
# Epoch 23 tst: l 0.391 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.472sec
# Epoch 24 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.765sec(train) 42.469sec(infer)
# Epoch 24 tst: l 0.386 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.121sec
# Epoch 25 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.618sec(train) 43.567sec(infer)
# Epoch 25 tst: l 0.381 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.907sec
# Epoch 26 tr: l 0.331 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.419sec(train) 41.987sec(infer)
# Epoch 26 tst: l 0.375 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.068sec
# Epoch 27 tr: l 0.327 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.136sec(train) 42.244sec(infer)
# Epoch 27 tst: l 0.371 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.173sec
# Epoch 28 tr: l 0.324 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.911sec(train) 41.987sec(infer)
# Epoch 28 tst: l 0.368 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.126sec
# Epoch 29 tr: l 0.321 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.432sec(train) 43.266sec(infer)
# Epoch 29 tst: l 0.364 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.104sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.86 hour (3108.353 sec)
# ---------------------------------R:50, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  41.679sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  31.002sec
# Epoch 0 tr: l 2.141 a 0.318 clct[np.int64(69), np.int64(500), np.int64(292), np.int64(339)] cl_acc 0.450  lr 0.100000 28.091sec(train) 44.109sec(infer)
# Epoch 0 tst: l 2.192 a 0.290 clct[np.int64(16), np.int64(84), np.int64(52), np.int64(48)] cl_acc 0.460  29.448sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.971 a 0.504 clct[np.int64(98), np.int64(526), np.int64(228), np.int64(348)] cl_acc 0.483  lr 0.100000 29.166sec(train) 43.587sec(infer)
# Epoch 1 tst: l 2.043 a 0.453 clct[np.int64(18), np.int64(89), np.int64(32), np.int64(61)] cl_acc 0.505  30.354sec
# Epoch 2 tr: l 1.758 a 0.628 clct[np.int64(135), np.int64(547), np.int64(206), np.int64(312)] cl_acc 0.538  lr 0.100000 26.916sec(train) 38.476sec(infer)
# Epoch 2 tst: l 1.838 a 0.592 clct[np.int64(22), np.int64(95), np.int64(26), np.int64(57)] cl_acc 0.600  29.759sec
# Epoch 3 tr: l 1.512 a 0.699 clct[np.int64(211), np.int64(575), np.int64(117), np.int64(297)] cl_acc 0.646  lr 0.100000 28.535sec(train) 42.283sec(infer)
# Epoch 3 tst: l 1.594 a 0.668 clct[np.int64(42), np.int64(95), np.int64(14), np.int64(49)] cl_acc 0.680  32.863sec
# Epoch 4 tr: l 1.276 a 0.748 clct[np.int64(218), np.int64(592), np.int64(95), np.int64(295)] cl_acc 0.677  lr 0.100000 28.087sec(train) 42.456sec(infer)
# Epoch 4 tst: l 1.354 a 0.721 clct[np.int64(40), np.int64(99), np.int64(12), np.int64(49)] cl_acc 0.690  33.265sec
# Epoch 5 tr: l 1.084 a 0.773 clct[np.int64(247), np.int64(596), np.int64(58), np.int64(299)] cl_acc 0.707  lr 0.100000 28.126sec(train) 42.552sec(infer)
# Epoch 5 tst: l 1.163 a 0.747 clct[np.int64(44), np.int64(100), np.int64(6), np.int64(50)] cl_acc 0.720  32.544sec
# Epoch 6 tr: l 0.949 a 0.789 clct[np.int64(250), np.int64(597), np.int64(54), np.int64(299)] cl_acc 0.708  lr 0.100000 27.573sec(train) 41.311sec(infer)
# Epoch 6 tst: l 1.022 a 0.767 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  33.292sec
# Epoch 7 tr: l 0.855 a 0.800 clct[np.int64(261), np.int64(598), np.int64(42), np.int64(299)] cl_acc 0.718  lr 0.100000 28.216sec(train) 42.393sec(infer)
# Epoch 7 tst: l 0.922 a 0.779 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  31.966sec
# Epoch 8 tr: l 0.776 a 0.810 clct[np.int64(270), np.int64(598), np.int64(33), np.int64(299)] cl_acc 0.726  lr 0.100000 28.241sec(train) 46.837sec(infer)
# Epoch 8 tst: l 0.846 a 0.789 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  28.320sec
# Epoch 9 tr: l 0.736 a 0.812 clct[np.int64(273), np.int64(598), np.int64(29), np.int64(300)] cl_acc 0.729  lr 0.100000 29.523sec(train) 48.529sec(infer)
# Epoch 9 tst: l 0.792 a 0.796 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  26.863sec
# Epoch 10 tr: l 0.695 a 0.818 clct[np.int64(273), np.int64(598), np.int64(29), np.int64(300)] cl_acc 0.729  lr 0.100000 29.218sec(train) 46.939sec(infer)
# Epoch 10 tst: l 0.743 a 0.803 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  28.577sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.651 a 0.826 clct[np.int64(275), np.int64(598), np.int64(27), np.int64(300)] cl_acc 0.731  lr 0.100000 29.030sec(train) 47.710sec(infer)
# Epoch 11 tst: l 0.711 a 0.808 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  27.808sec
# Epoch 12 tr: l 0.630 a 0.827 clct[np.int64(277), np.int64(598), np.int64(25), np.int64(300)] cl_acc 0.733  lr 0.100000 29.184sec(train) 48.751sec(infer)
# Epoch 12 tst: l 0.682 a 0.814 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  24.902sec
# Epoch 13 tr: l 0.602 a 0.833 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 29.243sec(train) 47.155sec(infer)
# Epoch 13 tst: l 0.660 a 0.816 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  25.558sec
# Epoch 14 tr: l 0.594 a 0.833 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 30.105sec(train) 42.098sec(infer)
# Epoch 14 tst: l 0.639 a 0.820 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  19.977sec
# Epoch 15 tr: l 0.569 a 0.840 clct[np.int64(279), np.int64(598), np.int64(23), np.int64(300)] cl_acc 0.734  lr 0.100000 27.696sec(train) 32.502sec(infer)
# Epoch 15 tst: l 0.625 a 0.822 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  20.490sec
# Epoch 16 tr: l 0.557 a 0.841 clct[np.int64(279), np.int64(598), np.int64(23), np.int64(300)] cl_acc 0.734  lr 0.100000 30.067sec(train) 29.425sec(infer)
# Epoch 16 tst: l 0.605 a 0.826 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  21.820sec
# Epoch 17 tr: l 0.547 a 0.844 clct[np.int64(278), np.int64(598), np.int64(24), np.int64(300)] cl_acc 0.733  lr 0.100000 28.190sec(train) 31.355sec(infer)
# Epoch 17 tst: l 0.594 a 0.828 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  20.772sec
# Epoch 18 tr: l 0.537 a 0.845 clct[np.int64(279), np.int64(599), np.int64(22), np.int64(300)] cl_acc 0.733  lr 0.100000 28.567sec(train) 30.883sec(infer)
# Epoch 18 tst: l 0.580 a 0.832 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  22.060sec
# Epoch 19 tr: l 0.521 a 0.848 clct[np.int64(280), np.int64(599), np.int64(21), np.int64(300)] cl_acc 0.734  lr 0.100000 27.321sec(train) 30.464sec(infer)
# Epoch 19 tst: l 0.569 a 0.833 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  22.417sec
# Epoch 20 tr: l 0.510 a 0.850 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 27.857sec(train) 32.085sec(infer)
# Epoch 20 tst: l 0.560 a 0.836 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  22.636sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.501 a 0.853 clct[np.int64(282), np.int64(599), np.int64(19), np.int64(300)] cl_acc 0.736  lr 0.100000 26.493sec(train) 30.327sec(infer)
# Epoch 21 tst: l 0.553 a 0.838 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  25.013sec
# Epoch 22 tr: l 0.496 a 0.853 clct[np.int64(282), np.int64(599), np.int64(19), np.int64(300)] cl_acc 0.736  lr 0.100000 26.971sec(train) 31.386sec(infer)
# Epoch 22 tst: l 0.543 a 0.840 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  24.002sec
# Epoch 23 tr: l 0.489 a 0.856 clct[np.int64(280), np.int64(599), np.int64(21), np.int64(300)] cl_acc 0.734  lr 0.100000 26.766sec(train) 30.639sec(infer)
# Epoch 23 tst: l 0.538 a 0.842 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  25.517sec
# Epoch 24 tr: l 0.488 a 0.854 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 26.491sec(train) 33.536sec(infer)
# Epoch 24 tst: l 0.533 a 0.842 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  22.378sec
# Epoch 25 tr: l 0.481 a 0.857 clct[np.int64(281), np.int64(599), np.int64(20), np.int64(300)] cl_acc 0.735  lr 0.100000 26.887sec(train) 33.358sec(infer)
# Epoch 25 tst: l 0.524 a 0.844 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  20.344sec
# Epoch 26 tr: l 0.479 a 0.856 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 27.165sec(train) 36.481sec(infer)
# Epoch 26 tst: l 0.518 a 0.847 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  16.933sec
# Epoch 27 tr: l 0.475 a 0.857 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 27.697sec(train) 33.608sec(infer)
# Epoch 27 tst: l 0.512 a 0.848 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  18.951sec
# Epoch 28 tr: l 0.463 a 0.862 clct[np.int64(282), np.int64(600), np.int64(18), np.int64(300)] cl_acc 0.735  lr 0.100000 27.630sec(train) 32.207sec(infer)
# Epoch 28 tst: l 0.509 a 0.848 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  20.094sec
# Epoch 29 tr: l 0.451 a 0.863 clct[np.int64(281), np.int64(600), np.int64(19), np.int64(300)] cl_acc 0.734  lr 0.100000 27.017sec(train) 29.810sec(infer)
# Epoch 29 tst: l 0.503 a 0.850 clct[np.int64(48), np.int64(100), np.int64(2), np.int64(50)] cl_acc 0.740  22.682sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.78 hour (2822.199 sec)
# ---------------------------------R:50, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 50, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  31.031sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  21.334sec
# Epoch 0 tr: l 2.130 a 0.400 clct[np.int64(160), np.int64(234), np.int64(204), np.int64(602)] cl_acc 0.393  lr 0.100000 28.321sec(train) 30.122sec(infer)
# Epoch 0 tst: l 2.184 a 0.361 clct[np.int64(31), np.int64(39), np.int64(33), np.int64(97)] cl_acc 0.445  20.848sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.953 a 0.530 clct[np.int64(207), np.int64(249), np.int64(212), np.int64(532)] cl_acc 0.455  lr 0.100000 28.301sec(train) 29.695sec(infer)
# Epoch 1 tst: l 2.026 a 0.490 clct[np.int64(34), np.int64(47), np.int64(34), np.int64(85)] cl_acc 0.465  21.608sec
# Epoch 2 tr: l 1.749 a 0.613 clct[np.int64(180), np.int64(305), np.int64(239), np.int64(476)] cl_acc 0.560  lr 0.100000 28.253sec(train) 29.985sec(infer)
# Epoch 2 tst: l 1.825 a 0.580 clct[np.int64(30), np.int64(44), np.int64(44), np.int64(82)] cl_acc 0.580  21.279sec
# Epoch 3 tr: l 1.521 a 0.682 clct[np.int64(100), np.int64(382), np.int64(267), np.int64(451)] cl_acc 0.651  lr 0.100000 28.245sec(train) 29.392sec(infer)
# Epoch 3 tst: l 1.593 a 0.654 clct[np.int64(16), np.int64(58), np.int64(47), np.int64(79)] cl_acc 0.665  21.304sec
# Epoch 4 tr: l 1.309 a 0.723 clct[np.int64(81), np.int64(458), np.int64(273), np.int64(388)] cl_acc 0.685  lr 0.100000 26.965sec(train) 18.264sec(infer)
# Epoch 4 tst: l 1.379 a 0.702 clct[np.int64(12), np.int64(74), np.int64(50), np.int64(64)] cl_acc 0.720  14.909sec
# Epoch 5 tr: l 1.129 a 0.756 clct[np.int64(100), np.int64(484), np.int64(284), np.int64(332)] cl_acc 0.769  lr 0.100000 26.794sec(train) 18.579sec(infer)
# Epoch 5 tst: l 1.198 a 0.732 clct[np.int64(16), np.int64(81), np.int64(49), np.int64(54)] cl_acc 0.805  16.888sec
# Epoch 6 tr: l 0.978 a 0.782 clct[np.int64(200), np.int64(399), np.int64(291), np.int64(310)] cl_acc 0.888  lr 0.100000 26.873sec(train) 20.740sec(infer)
# Epoch 6 tst: l 1.042 a 0.760 clct[np.int64(34), np.int64(64), np.int64(50), np.int64(52)] cl_acc 0.915  14.521sec
# Epoch 7 tr: l 0.832 a 0.813 clct[np.int64(295), np.int64(306), np.int64(296), np.int64(303)] cl_acc 0.986  lr 0.100000 26.222sec(train) 20.278sec(infer)
# Epoch 7 tst: l 0.887 a 0.796 clct[np.int64(47), np.int64(52), np.int64(50), np.int64(51)] cl_acc 0.985  16.567sec
# Epoch 8 tr: l 0.721 a 0.834 clct[np.int64(299), np.int64(301), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 25.443sec(train) 23.561sec(infer)
# Epoch 8 tst: l 0.772 a 0.822 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  15.699sec
# Epoch 9 tr: l 0.650 a 0.847 clct[np.int64(298), np.int64(301), np.int64(300), np.int64(301)] cl_acc 0.998  lr 0.100000 24.771sec(train) 22.406sec(infer)
# Epoch 9 tst: l 0.692 a 0.837 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  15.867sec
# Epoch 10 tr: l 0.589 a 0.858 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.747sec(train) 23.245sec(infer)
# Epoch 10 tst: l 0.633 a 0.848 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  14.244sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.544 a 0.866 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.874sec(train) 22.303sec(infer)
# Epoch 11 tst: l 0.594 a 0.855 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  14.305sec
# Epoch 12 tr: l 0.514 a 0.871 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.989sec(train) 22.325sec(infer)
# Epoch 12 tst: l 0.555 a 0.863 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  14.406sec
# Epoch 13 tr: l 0.485 a 0.877 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.797sec(train) 20.716sec(infer)
# Epoch 13 tst: l 0.528 a 0.868 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.347sec
# Epoch 14 tr: l 0.463 a 0.880 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.847sec(train) 19.657sec(infer)
# Epoch 14 tst: l 0.506 a 0.872 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  14.999sec
# Epoch 15 tr: l 0.443 a 0.883 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.193sec(train) 18.323sec(infer)
# Epoch 15 tst: l 0.483 a 0.877 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  16.798sec
# Epoch 16 tr: l 0.429 a 0.886 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.983sec(train) 20.136sec(infer)
# Epoch 16 tst: l 0.468 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  17.077sec
# Epoch 17 tr: l 0.412 a 0.890 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.326sec(train) 18.321sec(infer)
# Epoch 17 tst: l 0.453 a 0.883 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.930sec
# Epoch 18 tr: l 0.398 a 0.892 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 26.148sec(train) 18.602sec(infer)
# Epoch 18 tst: l 0.442 a 0.885 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  18.378sec
# Epoch 19 tr: l 0.390 a 0.893 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.751sec(train) 21.277sec(infer)
# Epoch 19 tst: l 0.431 a 0.887 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  15.190sec
# Epoch 20 tr: l 0.380 a 0.895 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.707sec(train) 20.017sec(infer)
# Epoch 20 tst: l 0.421 a 0.889 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  17.419sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.376 a 0.896 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 25.415sec(train) 11.949sec(infer)
# Epoch 21 tst: l 0.413 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  6.171sec
# Epoch 22 tr: l 0.365 a 0.898 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 19.392sec(train) 8.024sec(infer)
# Epoch 22 tst: l 0.406 a 0.891 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  6.123sec
# Epoch 23 tr: l 0.361 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.601sec(train) 6.134sec(infer)
# Epoch 23 tst: l 0.398 a 0.893 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  3.693sec
# Epoch 24 tr: l 0.354 a 0.900 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.681sec(train) 8.006sec(infer)
# Epoch 24 tst: l 0.391 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  4.526sec
# Epoch 25 tr: l 0.345 a 0.901 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.563sec(train) 7.856sec(infer)
# Epoch 25 tst: l 0.386 a 0.895 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  4.505sec
# Epoch 26 tr: l 0.341 a 0.902 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.750sec(train) 5.466sec(infer)
# Epoch 26 tst: l 0.382 a 0.896 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  3.325sec
# Epoch 27 tr: l 0.333 a 0.905 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.381sec(train) 5.019sec(infer)
# Epoch 27 tst: l 0.377 a 0.897 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  3.706sec
# Epoch 28 tr: l 0.327 a 0.906 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.428sec(train) 5.278sec(infer)
# Epoch 28 tst: l 0.373 a 0.898 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  3.366sec
# Epoch 29 tr: l 0.324 a 0.906 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.313sec(train) 5.285sec(infer)
# Epoch 29 tst: l 0.369 a 0.899 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  3.652sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.48 hour (1727.050 sec)

# %%
__.display_outputs()
# Out:
# ---------------------------------R:25, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  49.588sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  28.196sec
# Epoch 0 tr: l 2.103 a 0.350 clct[np.int64(688), np.int64(205), np.int64(195), np.int64(112)] cl_acc 0.358  lr 0.100000 30.662sec(train) 45.086sec(infer)
# Epoch 0 tst: l 2.188 a 0.295 clct[np.int64(122), np.int64(35), np.int64(26), np.int64(17)] cl_acc 0.390  27.759sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.924 a 0.501 clct[np.int64(479), np.int64(298), np.int64(235), np.int64(188)] cl_acc 0.432  lr 0.100000 29.315sec(train) 45.390sec(infer)
# Epoch 1 tst: l 2.044 a 0.433 clct[np.int64(82), np.int64(56), np.int64(37), np.int64(25)] cl_acc 0.400  29.663sec
# Epoch 2 tr: l 1.701 a 0.609 clct[np.int64(330), np.int64(382), np.int64(242), np.int64(246)] cl_acc 0.546  lr 0.100000 28.519sec(train) 47.375sec(infer)
# Epoch 2 tst: l 1.852 a 0.525 clct[np.int64(56), np.int64(61), np.int64(38), np.int64(45)] cl_acc 0.560  28.085sec
# Epoch 3 tr: l 1.492 a 0.666 clct[np.int64(224), np.int64(437), np.int64(258), np.int64(281)] cl_acc 0.674  lr 0.100000 27.858sec(train) 47.715sec(infer)
# Epoch 3 tst: l 1.628 a 0.598 clct[np.int64(33), np.int64(73), np.int64(42), np.int64(52)] cl_acc 0.745  28.284sec
# Epoch 4 tr: l 1.257 a 0.724 clct[np.int64(197), np.int64(422), np.int64(271), np.int64(310)] cl_acc 0.779  lr 0.100000 27.880sec(train) 48.864sec(infer)
# Epoch 4 tst: l 1.392 a 0.670 clct[np.int64(26), np.int64(77), np.int64(48), np.int64(49)] cl_acc 0.805  27.689sec
# Epoch 5 tr: l 1.075 a 0.768 clct[np.int64(256), np.int64(361), np.int64(281), np.int64(302)] cl_acc 0.892  lr 0.100000 27.247sec(train) 47.197sec(infer)
# Epoch 5 tst: l 1.183 a 0.726 clct[np.int64(41), np.int64(60), np.int64(49), np.int64(50)] cl_acc 0.920  28.501sec
# Epoch 6 tr: l 0.905 a 0.806 clct[np.int64(306), np.int64(305), np.int64(290), np.int64(299)] cl_acc 0.968  lr 0.100000 27.243sec(train) 48.430sec(infer)
# Epoch 6 tst: l 0.993 a 0.773 clct[np.int64(49), np.int64(51), np.int64(50), np.int64(50)] cl_acc 0.995  27.551sec
# Epoch 7 tr: l 0.767 a 0.834 clct[np.int64(304), np.int64(299), np.int64(297), np.int64(300)] cl_acc 0.991  lr 0.100000 27.081sec(train) 49.330sec(infer)
# Epoch 7 tst: l 0.851 a 0.802 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.781sec
# Epoch 8 tr: l 0.673 a 0.850 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.997  lr 0.100000 27.428sec(train) 48.120sec(infer)
# Epoch 8 tst: l 0.742 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.309sec
# Epoch 9 tr: l 0.601 a 0.860 clct[np.int64(302), np.int64(299), np.int64(300), np.int64(299)] cl_acc 0.998  lr 0.100000 27.567sec(train) 50.864sec(infer)
# Epoch 9 tst: l 0.668 a 0.839 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.435sec
# Epoch 10 tr: l 0.551 a 0.870 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 27.707sec(train) 48.885sec(infer)
# Epoch 10 tst: l 0.611 a 0.850 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.166sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.511 a 0.876 clct[np.int64(302), np.int64(299), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 27.088sec(train) 50.073sec(infer)
# Epoch 11 tst: l 0.567 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.464sec
# Epoch 12 tr: l 0.478 a 0.883 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.248sec(train) 50.942sec(infer)
# Epoch 12 tst: l 0.534 a 0.864 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.848sec
# Epoch 13 tr: l 0.455 a 0.885 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.363sec(train) 48.604sec(infer)
# Epoch 13 tst: l 0.507 a 0.868 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.460sec
# Epoch 14 tr: l 0.435 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.806sec(train) 51.724sec(infer)
# Epoch 14 tst: l 0.484 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.707sec
# Epoch 15 tr: l 0.414 a 0.891 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.327sec(train) 48.960sec(infer)
# Epoch 15 tst: l 0.467 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.007sec
# Epoch 16 tr: l 0.400 a 0.895 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.730sec(train) 50.398sec(infer)
# Epoch 16 tst: l 0.450 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.506sec
# Epoch 17 tr: l 0.388 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.308sec(train) 49.995sec(infer)
# Epoch 17 tst: l 0.435 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.121sec
# Epoch 18 tr: l 0.372 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.800sec(train) 50.576sec(infer)
# Epoch 18 tst: l 0.424 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.220sec
# Epoch 19 tr: l 0.364 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.629sec(train) 49.583sec(infer)
# Epoch 19 tst: l 0.414 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.582sec
# Epoch 20 tr: l 0.352 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.762sec(train) 51.077sec(infer)
# Epoch 20 tst: l 0.403 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.800sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.343 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.762sec(train) 50.204sec(infer)
# Epoch 21 tst: l 0.398 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.036sec
# Epoch 22 tr: l 0.339 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.271sec(train) 49.026sec(infer)
# Epoch 22 tst: l 0.390 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.334sec
# Epoch 23 tr: l 0.334 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.391sec(train) 53.014sec(infer)
# Epoch 23 tst: l 0.382 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.199sec
# Epoch 24 tr: l 0.326 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.245sec(train) 49.486sec(infer)
# Epoch 24 tst: l 0.377 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.968sec
# Epoch 25 tr: l 0.321 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.097sec(train) 52.577sec(infer)
# Epoch 25 tst: l 0.370 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.782sec
# Epoch 26 tr: l 0.313 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.923sec(train) 52.674sec(infer)
# Epoch 26 tst: l 0.366 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.927sec
# Epoch 27 tr: l 0.309 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.820sec(train) 51.472sec(infer)
# Epoch 27 tst: l 0.361 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.624sec
# Epoch 28 tr: l 0.308 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.636sec(train) 53.511sec(infer)
# Epoch 28 tst: l 0.357 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.245sec
# Epoch 29 tr: l 0.300 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.160sec(train) 48.546sec(infer)
# Epoch 29 tst: l 0.353 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.007sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.91 hour (3258.657 sec)
# ---------------------------------R:25, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  45.751sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  31.077sec
# Epoch 0 tr: l 2.096 a 0.432 clct[np.int64(358), np.int64(31), np.int64(444), np.int64(367)] cl_acc 0.641  lr 0.100000 26.570sec(train) 47.858sec(infer)
# Epoch 0 tst: l 2.181 a 0.343 clct[np.int64(61), np.int64(3), np.int64(82), np.int64(54)] cl_acc 0.675  33.111sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.881 a 0.572 clct[np.int64(356), np.int64(44), np.int64(443), np.int64(357)] cl_acc 0.694  lr 0.100000 26.883sec(train) 48.799sec(infer)
# Epoch 1 tst: l 2.004 a 0.487 clct[np.int64(61), np.int64(4), np.int64(83), np.int64(52)] cl_acc 0.700  30.429sec
# Epoch 2 tr: l 1.620 a 0.654 clct[np.int64(335), np.int64(57), np.int64(460), np.int64(348)] cl_acc 0.722  lr 0.100000 27.068sec(train) 46.896sec(infer)
# Epoch 2 tst: l 1.774 a 0.580 clct[np.int64(54), np.int64(8), np.int64(77), np.int64(61)] cl_acc 0.710  33.404sec
# Epoch 3 tr: l 1.386 a 0.697 clct[np.int64(315), np.int64(73), np.int64(488), np.int64(324)] cl_acc 0.733  lr 0.100000 27.319sec(train) 46.990sec(infer)
# Epoch 3 tst: l 1.549 a 0.632 clct[np.int64(52), np.int64(13), np.int64(84), np.int64(51)] cl_acc 0.760  31.984sec
# Epoch 4 tr: l 1.194 a 0.733 clct[np.int64(310), np.int64(92), np.int64(488), np.int64(310)] cl_acc 0.742  lr 0.100000 27.217sec(train) 45.949sec(infer)
# Epoch 4 tst: l 1.321 a 0.694 clct[np.int64(50), np.int64(15), np.int64(84), np.int64(51)] cl_acc 0.755  32.444sec
# Epoch 5 tr: l 1.046 a 0.762 clct[np.int64(306), np.int64(123), np.int64(467), np.int64(304)] cl_acc 0.742  lr 0.100000 28.206sec(train) 46.030sec(infer)
# Epoch 5 tst: l 1.154 a 0.728 clct[np.int64(50), np.int64(18), np.int64(81), np.int64(51)] cl_acc 0.770  31.201sec
# Epoch 6 tr: l 0.932 a 0.781 clct[np.int64(305), np.int64(161), np.int64(434), np.int64(300)] cl_acc 0.768  lr 0.100000 27.297sec(train) 42.435sec(infer)
# Epoch 6 tst: l 1.030 a 0.751 clct[np.int64(50), np.int64(29), np.int64(71), np.int64(50)] cl_acc 0.795  30.972sec
# Epoch 7 tr: l 0.845 a 0.800 clct[np.int64(302), np.int64(204), np.int64(395), np.int64(299)] cl_acc 0.811  lr 0.100000 25.802sec(train) 43.404sec(infer)
# Epoch 7 tst: l 0.938 a 0.768 clct[np.int64(50), np.int64(32), np.int64(68), np.int64(50)] cl_acc 0.840  31.873sec
# Epoch 8 tr: l 0.768 a 0.814 clct[np.int64(301), np.int64(239), np.int64(360), np.int64(300)] cl_acc 0.882  lr 0.100000 26.396sec(train) 42.685sec(infer)
# Epoch 8 tst: l 0.856 a 0.784 clct[np.int64(50), np.int64(34), np.int64(66), np.int64(50)] cl_acc 0.890  30.736sec
# Epoch 9 tr: l 0.680 a 0.837 clct[np.int64(301), np.int64(295), np.int64(304), np.int64(300)] cl_acc 0.973  lr 0.100000 25.409sec(train) 43.526sec(infer)
# Epoch 9 tst: l 0.767 a 0.808 clct[np.int64(50), np.int64(49), np.int64(51), np.int64(50)] cl_acc 0.995  30.611sec
# Epoch 10 tr: l 0.606 a 0.855 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.997  lr 0.100000 27.008sec(train) 36.877sec(infer)
# Epoch 10 tst: l 0.681 a 0.832 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.573sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.548 a 0.865 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 26.071sec(train) 43.389sec(infer)
# Epoch 11 tst: l 0.624 a 0.844 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.762sec
# Epoch 12 tr: l 0.507 a 0.874 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.133sec(train) 41.149sec(infer)
# Epoch 12 tst: l 0.574 a 0.856 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.907sec
# Epoch 13 tr: l 0.474 a 0.880 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 26.975sec(train) 38.265sec(infer)
# Epoch 13 tst: l 0.538 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.172sec
# Epoch 14 tr: l 0.447 a 0.885 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.655sec(train) 40.120sec(infer)
# Epoch 14 tst: l 0.511 a 0.868 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.602sec
# Epoch 15 tr: l 0.425 a 0.889 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.940sec(train) 39.696sec(infer)
# Epoch 15 tst: l 0.490 a 0.871 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.088sec
# Epoch 16 tr: l 0.408 a 0.892 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.301sec(train) 40.335sec(infer)
# Epoch 16 tst: l 0.470 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.623sec
# Epoch 17 tr: l 0.394 a 0.894 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 28.522sec(train) 40.795sec(infer)
# Epoch 17 tst: l 0.454 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.352sec
# Epoch 18 tr: l 0.376 a 0.897 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 26.286sec(train) 39.344sec(infer)
# Epoch 18 tst: l 0.441 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.668sec
# Epoch 19 tr: l 0.372 a 0.900 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.979sec(train) 41.968sec(infer)
# Epoch 19 tst: l 0.429 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.867sec
# Epoch 20 tr: l 0.362 a 0.900 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.851sec(train) 43.073sec(infer)
# Epoch 20 tst: l 0.420 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.705sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.352 a 0.902 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.869sec(train) 43.569sec(infer)
# Epoch 21 tst: l 0.409 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.557sec
# Epoch 22 tr: l 0.343 a 0.904 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.314sec(train) 44.115sec(infer)
# Epoch 22 tst: l 0.402 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.312sec
# Epoch 23 tr: l 0.340 a 0.904 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 28.959sec(train) 41.591sec(infer)
# Epoch 23 tst: l 0.394 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.025sec
# Epoch 24 tr: l 0.331 a 0.906 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.305sec(train) 44.174sec(infer)
# Epoch 24 tst: l 0.387 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.590sec
# Epoch 25 tr: l 0.326 a 0.907 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 28.606sec(train) 41.543sec(infer)
# Epoch 25 tst: l 0.380 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.367sec
# Epoch 26 tr: l 0.319 a 0.908 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.375sec(train) 44.134sec(infer)
# Epoch 26 tst: l 0.377 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.755sec
# Epoch 27 tr: l 0.314 a 0.909 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 27.530sec(train) 41.770sec(infer)
# Epoch 27 tst: l 0.372 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.043sec
# Epoch 28 tr: l 0.307 a 0.910 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 26.301sec(train) 44.472sec(infer)
# Epoch 28 tst: l 0.366 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.472sec
# Epoch 29 tr: l 0.302 a 0.912 clct[np.int64(301), np.int64(299), np.int64(300), np.int64(300)] cl_acc 0.999  lr 0.100000 26.563sec(train) 43.232sec(infer)
# Epoch 29 tst: l 0.363 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.493sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.86 hour (3086.110 sec)
# ---------------------------------R:25, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  44.195sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  27.333sec
# Epoch 0 tr: l 2.089 a 0.432 clct[np.int64(334), np.int64(393), np.int64(363), np.int64(110)] cl_acc 0.666  lr 0.100000 27.751sec(train) 40.966sec(infer)
# Epoch 0 tst: l 2.181 a 0.349 clct[np.int64(62), np.int64(58), np.int64(60), np.int64(20)] cl_acc 0.695  29.699sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.867 a 0.595 clct[np.int64(325), np.int64(363), np.int64(336), np.int64(176)] cl_acc 0.777  lr 0.100000 27.410sec(train) 43.891sec(infer)
# Epoch 1 tst: l 1.990 a 0.519 clct[np.int64(54), np.int64(57), np.int64(55), np.int64(34)] cl_acc 0.855  28.271sec
# Epoch 2 tr: l 1.584 a 0.703 clct[np.int64(307), np.int64(312), np.int64(316), np.int64(265)] cl_acc 0.901  lr 0.100000 28.004sec(train) 41.518sec(infer)
# Epoch 2 tst: l 1.724 a 0.637 clct[np.int64(50), np.int64(58), np.int64(51), np.int64(41)] cl_acc 0.945  30.285sec
# Epoch 3 tr: l 1.286 a 0.769 clct[np.int64(301), np.int64(296), np.int64(304), np.int64(299)] cl_acc 0.969  lr 0.100000 26.332sec(train) 43.121sec(infer)
# Epoch 3 tst: l 1.421 a 0.723 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.925sec
# Epoch 4 tr: l 1.033 a 0.809 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.989  lr 0.100000 27.008sec(train) 42.132sec(infer)
# Epoch 4 tst: l 1.168 a 0.775 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.447sec
# Epoch 5 tr: l 0.857 a 0.832 clct[np.int64(298), np.int64(299), np.int64(301), np.int64(302)] cl_acc 0.994  lr 0.100000 26.006sec(train) 43.574sec(infer)
# Epoch 5 tst: l 0.969 a 0.805 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.204sec
# Epoch 6 tr: l 0.734 a 0.850 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.998  lr 0.100000 26.591sec(train) 43.031sec(infer)
# Epoch 6 tst: l 0.829 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.415sec
# Epoch 7 tr: l 0.645 a 0.861 clct[np.int64(300), np.int64(298), np.int64(301), np.int64(301)] cl_acc 0.998  lr 0.100000 25.785sec(train) 44.585sec(infer)
# Epoch 7 tst: l 0.741 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.907sec
# Epoch 8 tr: l 0.588 a 0.868 clct[np.int64(300), np.int64(299), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 26.669sec(train) 44.112sec(infer)
# Epoch 8 tst: l 0.671 a 0.847 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.285sec
# Epoch 9 tr: l 0.538 a 0.875 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.741sec(train) 45.563sec(infer)
# Epoch 9 tst: l 0.618 a 0.855 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.222sec
# Epoch 10 tr: l 0.498 a 0.880 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.676sec(train) 44.485sec(infer)
# Epoch 10 tst: l 0.579 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.352sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.472 a 0.884 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.126sec(train) 45.960sec(infer)
# Epoch 11 tst: l 0.548 a 0.866 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.149sec
# Epoch 12 tr: l 0.448 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.864sec(train) 44.687sec(infer)
# Epoch 12 tst: l 0.522 a 0.870 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.874sec
# Epoch 13 tr: l 0.429 a 0.890 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.439sec(train) 46.033sec(infer)
# Epoch 13 tst: l 0.499 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.013sec
# Epoch 14 tr: l 0.412 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.653sec(train) 45.365sec(infer)
# Epoch 14 tst: l 0.482 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.635sec
# Epoch 15 tr: l 0.397 a 0.895 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.722sec(train) 47.086sec(infer)
# Epoch 15 tst: l 0.469 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.854sec
# Epoch 16 tr: l 0.382 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.525sec(train) 44.524sec(infer)
# Epoch 16 tst: l 0.454 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.740sec
# Epoch 17 tr: l 0.372 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.124sec(train) 45.968sec(infer)
# Epoch 17 tst: l 0.443 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.283sec
# Epoch 18 tr: l 0.361 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.517sec(train) 43.544sec(infer)
# Epoch 18 tst: l 0.435 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.084sec
# Epoch 19 tr: l 0.352 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.686sec(train) 46.469sec(infer)
# Epoch 19 tst: l 0.427 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.557sec
# Epoch 20 tr: l 0.347 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.943sec(train) 46.420sec(infer)
# Epoch 20 tst: l 0.417 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.294sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.340 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.430sec(train) 44.553sec(infer)
# Epoch 21 tst: l 0.407 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.484sec
# Epoch 22 tr: l 0.331 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.677sec(train) 46.629sec(infer)
# Epoch 22 tst: l 0.403 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.685sec
# Epoch 23 tr: l 0.327 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.562sec(train) 45.949sec(infer)
# Epoch 23 tst: l 0.398 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.535sec
# Epoch 24 tr: l 0.323 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.113sec(train) 45.953sec(infer)
# Epoch 24 tst: l 0.393 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.626sec
# Epoch 25 tr: l 0.312 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.924sec(train) 48.520sec(infer)
# Epoch 25 tst: l 0.386 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.420sec
# Epoch 26 tr: l 0.313 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.610sec(train) 45.577sec(infer)
# Epoch 26 tst: l 0.384 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.394sec
# Epoch 27 tr: l 0.308 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.815sec(train) 48.134sec(infer)
# Epoch 27 tst: l 0.378 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.631sec
# Epoch 28 tr: l 0.302 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.520sec(train) 45.744sec(infer)
# Epoch 28 tst: l 0.376 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.303sec
# Epoch 29 tr: l 0.301 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.325sec(train) 46.298sec(infer)
# Epoch 29 tst: l 0.371 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.791sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.86 hour (3092.341 sec)
# ---------------------------------R:25, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  41.956sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  31.434sec
# Epoch 0 tr: l 2.102 a 0.367 clct[np.int64(51), np.int64(498), np.int64(341), np.int64(310)] cl_acc 0.434  lr 0.100000 27.000sec(train) 43.029sec(infer)
# Epoch 0 tst: l 2.190 a 0.294 clct[np.int64(6), np.int64(83), np.int64(55), np.int64(56)] cl_acc 0.460  28.718sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.918 a 0.526 clct[np.int64(85), np.int64(476), np.int64(320), np.int64(319)] cl_acc 0.471  lr 0.100000 27.626sec(train) 43.766sec(infer)
# Epoch 1 tst: l 2.038 a 0.436 clct[np.int64(14), np.int64(87), np.int64(40), np.int64(59)] cl_acc 0.520  29.304sec
# Epoch 2 tr: l 1.703 a 0.630 clct[np.int64(126), np.int64(511), np.int64(244), np.int64(319)] cl_acc 0.491  lr 0.100000 27.282sec(train) 44.559sec(infer)
# Epoch 2 tst: l 1.851 a 0.550 clct[np.int64(24), np.int64(83), np.int64(37), np.int64(56)] cl_acc 0.565  30.019sec
# Epoch 3 tr: l 1.486 a 0.692 clct[np.int64(183), np.int64(537), np.int64(172), np.int64(308)] cl_acc 0.571  lr 0.100000 27.390sec(train) 41.550sec(infer)
# Epoch 3 tst: l 1.631 a 0.629 clct[np.int64(34), np.int64(91), np.int64(23), np.int64(52)] cl_acc 0.650  27.223sec
# Epoch 4 tr: l 1.257 a 0.744 clct[np.int64(226), np.int64(548), np.int64(133), np.int64(293)] cl_acc 0.640  lr 0.100000 27.263sec(train) 43.440sec(infer)
# Epoch 4 tst: l 1.405 a 0.688 clct[np.int64(43), np.int64(97), np.int64(10), np.int64(50)] cl_acc 0.710  29.206sec
# Epoch 5 tr: l 1.091 a 0.770 clct[np.int64(245), np.int64(564), np.int64(99), np.int64(292)] cl_acc 0.688  lr 0.100000 28.114sec(train) 41.391sec(infer)
# Epoch 5 tst: l 1.212 a 0.729 clct[np.int64(42), np.int64(99), np.int64(8), np.int64(51)] cl_acc 0.710  29.920sec
# Epoch 6 tr: l 0.945 a 0.793 clct[np.int64(264), np.int64(579), np.int64(59), np.int64(298)] cl_acc 0.716  lr 0.100000 27.401sec(train) 43.847sec(infer)
# Epoch 6 tst: l 1.062 a 0.755 clct[np.int64(45), np.int64(99), np.int64(6), np.int64(50)] cl_acc 0.730  27.405sec
# Epoch 7 tr: l 0.844 a 0.806 clct[np.int64(270), np.int64(586), np.int64(47), np.int64(297)] cl_acc 0.724  lr 0.100000 28.073sec(train) 42.556sec(infer)
# Epoch 7 tst: l 0.949 a 0.772 clct[np.int64(48), np.int64(98), np.int64(3), np.int64(51)] cl_acc 0.740  28.217sec
# Epoch 8 tr: l 0.778 a 0.811 clct[np.int64(281), np.int64(589), np.int64(31), np.int64(299)] cl_acc 0.735  lr 0.100000 28.498sec(train) 44.610sec(infer)
# Epoch 8 tst: l 0.869 a 0.783 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  25.807sec
# Epoch 9 tr: l 0.717 a 0.822 clct[np.int64(281), np.int64(590), np.int64(30), np.int64(299)] cl_acc 0.737  lr 0.100000 28.286sec(train) 41.968sec(infer)
# Epoch 9 tst: l 0.809 a 0.791 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  27.640sec
# Epoch 10 tr: l 0.667 a 0.829 clct[np.int64(283), np.int64(591), np.int64(27), np.int64(299)] cl_acc 0.739  lr 0.100000 29.048sec(train) 40.505sec(infer)
# Epoch 10 tst: l 0.761 a 0.797 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  27.839sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.636 a 0.832 clct[np.int64(286), np.int64(591), np.int64(24), np.int64(299)] cl_acc 0.742  lr 0.100000 27.877sec(train) 42.892sec(infer)
# Epoch 11 tst: l 0.725 a 0.802 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  27.784sec
# Epoch 12 tr: l 0.611 a 0.834 clct[np.int64(288), np.int64(591), np.int64(22), np.int64(299)] cl_acc 0.743  lr 0.100000 27.758sec(train) 40.484sec(infer)
# Epoch 12 tst: l 0.696 a 0.807 clct[np.int64(49), np.int64(100), np.int64(1), np.int64(50)] cl_acc 0.745  30.457sec
# Epoch 13 tr: l 0.584 a 0.839 clct[np.int64(289), np.int64(591), np.int64(21), np.int64(299)] cl_acc 0.744  lr 0.100000 26.462sec(train) 43.605sec(infer)
# Epoch 13 tst: l 0.668 a 0.813 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  27.939sec
# Epoch 14 tr: l 0.566 a 0.843 clct[np.int64(291), np.int64(591), np.int64(19), np.int64(299)] cl_acc 0.746  lr 0.100000 26.847sec(train) 43.464sec(infer)
# Epoch 14 tst: l 0.650 a 0.814 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  28.541sec
# Epoch 15 tr: l 0.554 a 0.843 clct[np.int64(292), np.int64(591), np.int64(18), np.int64(299)] cl_acc 0.747  lr 0.100000 26.769sec(train) 43.195sec(infer)
# Epoch 15 tst: l 0.632 a 0.819 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  27.026sec
# Epoch 16 tr: l 0.536 a 0.847 clct[np.int64(293), np.int64(592), np.int64(16), np.int64(299)] cl_acc 0.747  lr 0.100000 28.048sec(train) 37.080sec(infer)
# Epoch 16 tst: l 0.615 a 0.822 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  18.638sec
# Epoch 17 tr: l 0.520 a 0.849 clct[np.int64(293), np.int64(592), np.int64(16), np.int64(299)] cl_acc 0.747  lr 0.100000 25.157sec(train) 30.110sec(infer)
# Epoch 17 tst: l 0.605 a 0.825 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  20.577sec
# Epoch 18 tr: l 0.509 a 0.853 clct[np.int64(295), np.int64(591), np.int64(15), np.int64(299)] cl_acc 0.749  lr 0.100000 25.492sec(train) 29.787sec(infer)
# Epoch 18 tst: l 0.590 a 0.827 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  21.644sec
# Epoch 19 tr: l 0.501 a 0.854 clct[np.int64(295), np.int64(590), np.int64(16), np.int64(299)] cl_acc 0.750  lr 0.100000 25.517sec(train) 32.233sec(infer)
# Epoch 19 tst: l 0.582 a 0.830 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  19.850sec
# Epoch 20 tr: l 0.492 a 0.855 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 25.571sec(train) 33.098sec(infer)
# Epoch 20 tst: l 0.570 a 0.832 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  19.105sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.483 a 0.858 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 25.640sec(train) 30.253sec(infer)
# Epoch 21 tst: l 0.559 a 0.835 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  22.093sec
# Epoch 22 tr: l 0.466 a 0.861 clct[np.int64(296), np.int64(590), np.int64(15), np.int64(299)] cl_acc 0.751  lr 0.100000 25.285sec(train) 30.704sec(infer)
# Epoch 22 tst: l 0.554 a 0.836 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  22.341sec
# Epoch 23 tr: l 0.464 a 0.861 clct[np.int64(297), np.int64(590), np.int64(14), np.int64(299)] cl_acc 0.752  lr 0.100000 24.709sec(train) 31.389sec(infer)
# Epoch 23 tst: l 0.544 a 0.839 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  21.840sec
# Epoch 24 tr: l 0.457 a 0.862 clct[np.int64(297), np.int64(589), np.int64(15), np.int64(299)] cl_acc 0.752  lr 0.100000 24.988sec(train) 30.867sec(infer)
# Epoch 24 tst: l 0.536 a 0.841 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.436sec
# Epoch 25 tr: l 0.456 a 0.863 clct[np.int64(297), np.int64(588), np.int64(16), np.int64(299)] cl_acc 0.753  lr 0.100000 25.492sec(train) 28.891sec(infer)
# Epoch 25 tst: l 0.532 a 0.842 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.871sec
# Epoch 26 tr: l 0.444 a 0.865 clct[np.int64(297), np.int64(587), np.int64(17), np.int64(299)] cl_acc 0.754  lr 0.100000 24.992sec(train) 29.385sec(infer)
# Epoch 26 tst: l 0.525 a 0.844 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.270sec
# Epoch 27 tr: l 0.442 a 0.866 clct[np.int64(297), np.int64(584), np.int64(20), np.int64(299)] cl_acc 0.757  lr 0.100000 25.725sec(train) 29.959sec(infer)
# Epoch 27 tst: l 0.517 a 0.846 clct[np.int64(50), np.int64(97), np.int64(3), np.int64(50)] cl_acc 0.765  19.672sec
# Epoch 28 tr: l 0.433 a 0.869 clct[np.int64(297), np.int64(584), np.int64(20), np.int64(299)] cl_acc 0.757  lr 0.100000 25.366sec(train) 28.303sec(infer)
# Epoch 28 tst: l 0.514 a 0.847 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.974sec
# Epoch 29 tr: l 0.425 a 0.870 clct[np.int64(297), np.int64(583), np.int64(21), np.int64(299)] cl_acc 0.757  lr 0.100000 25.363sec(train) 28.184sec(infer)
# Epoch 29 tst: l 0.509 a 0.848 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.599sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.76 hour (2742.156 sec)
# ---------------------------------R:25, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 25, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  32.363sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  20.382sec
# Epoch 0 tr: l 2.101 a 0.422 clct[np.int64(179), np.int64(211), np.int64(208), np.int64(602)] cl_acc 0.415  lr 0.100000 25.098sec(train) 33.643sec(infer)
# Epoch 0 tst: l 2.186 a 0.352 clct[np.int64(31), np.int64(39), np.int64(35), np.int64(95)] cl_acc 0.455  19.815sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.917 a 0.541 clct[np.int64(223), np.int64(275), np.int64(208), np.int64(494)] cl_acc 0.492  lr 0.100000 24.385sec(train) 34.343sec(infer)
# Epoch 1 tst: l 2.033 a 0.472 clct[np.int64(34), np.int64(40), np.int64(41), np.int64(85)] cl_acc 0.500  18.680sec
# Epoch 2 tr: l 1.685 a 0.627 clct[np.int64(265), np.int64(296), np.int64(220), np.int64(419)] cl_acc 0.593  lr 0.100000 24.937sec(train) 34.186sec(infer)
# Epoch 2 tst: l 1.842 a 0.557 clct[np.int64(43), np.int64(42), np.int64(40), np.int64(75)] cl_acc 0.615  21.028sec
# Epoch 3 tr: l 1.461 a 0.691 clct[np.int64(300), np.int64(293), np.int64(234), np.int64(373)] cl_acc 0.716  lr 0.100000 25.720sec(train) 35.744sec(infer)
# Epoch 3 tst: l 1.614 a 0.626 clct[np.int64(46), np.int64(47), np.int64(42), np.int64(65)] cl_acc 0.770  20.356sec
# Epoch 4 tr: l 1.237 a 0.744 clct[np.int64(322), np.int64(298), np.int64(254), np.int64(326)] cl_acc 0.851  lr 0.100000 24.374sec(train) 34.571sec(infer)
# Epoch 4 tst: l 1.379 a 0.688 clct[np.int64(52), np.int64(50), np.int64(45), np.int64(53)] cl_acc 0.905  22.045sec
# Epoch 5 tr: l 1.038 a 0.787 clct[np.int64(326), np.int64(303), np.int64(278), np.int64(293)] cl_acc 0.944  lr 0.100000 25.139sec(train) 36.439sec(infer)
# Epoch 5 tst: l 1.161 a 0.745 clct[np.int64(53), np.int64(49), np.int64(46), np.int64(52)] cl_acc 0.970  19.559sec
# Epoch 6 tr: l 0.872 a 0.818 clct[np.int64(313), np.int64(298), np.int64(291), np.int64(298)] cl_acc 0.976  lr 0.100000 24.681sec(train) 33.405sec(infer)
# Epoch 6 tst: l 0.973 a 0.788 clct[np.int64(50), np.int64(50), np.int64(49), np.int64(51)] cl_acc 0.990  13.431sec
# Epoch 7 tr: l 0.743 a 0.838 clct[np.int64(303), np.int64(300), np.int64(296), np.int64(301)] cl_acc 0.989  lr 0.100000 21.973sec(train) 25.751sec(infer)
# Epoch 7 tst: l 0.839 a 0.811 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.039sec
# Epoch 8 tr: l 0.665 a 0.850 clct[np.int64(302), np.int64(302), np.int64(295), np.int64(301)] cl_acc 0.995  lr 0.100000 22.260sec(train) 24.554sec(infer)
# Epoch 8 tst: l 0.741 a 0.831 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.771sec
# Epoch 9 tr: l 0.598 a 0.861 clct[np.int64(300), np.int64(302), np.int64(297), np.int64(301)] cl_acc 0.997  lr 0.100000 22.457sec(train) 23.832sec(infer)
# Epoch 9 tst: l 0.676 a 0.840 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  15.071sec
# Epoch 10 tr: l 0.547 a 0.870 clct[np.int64(299), np.int64(301), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 22.529sec(train) 24.374sec(infer)
# Epoch 10 tst: l 0.622 a 0.850 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.163sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.510 a 0.875 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.306sec(train) 24.195sec(infer)
# Epoch 11 tst: l 0.584 a 0.858 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  11.489sec
# Epoch 12 tr: l 0.475 a 0.882 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.474sec(train) 24.011sec(infer)
# Epoch 12 tst: l 0.554 a 0.863 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  11.310sec
# Epoch 13 tr: l 0.452 a 0.885 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.139sec(train) 23.482sec(infer)
# Epoch 13 tst: l 0.528 a 0.867 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  11.525sec
# Epoch 14 tr: l 0.436 a 0.888 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.606sec(train) 24.269sec(infer)
# Epoch 14 tst: l 0.501 a 0.873 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  11.085sec
# Epoch 15 tr: l 0.413 a 0.891 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.348sec(train) 22.761sec(infer)
# Epoch 15 tst: l 0.485 a 0.875 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.295sec
# Epoch 16 tr: l 0.395 a 0.895 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.428sec(train) 20.976sec(infer)
# Epoch 16 tst: l 0.470 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.938sec
# Epoch 17 tr: l 0.386 a 0.897 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.081sec(train) 20.534sec(infer)
# Epoch 17 tst: l 0.458 a 0.879 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  14.352sec
# Epoch 18 tr: l 0.372 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.607sec(train) 19.931sec(infer)
# Epoch 18 tst: l 0.445 a 0.883 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.822sec
# Epoch 19 tr: l 0.367 a 0.899 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.247sec(train) 20.343sec(infer)
# Epoch 19 tst: l 0.435 a 0.885 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.407sec
# Epoch 20 tr: l 0.355 a 0.902 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.290sec(train) 20.292sec(infer)
# Epoch 20 tst: l 0.425 a 0.887 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.168sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.347 a 0.903 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.648sec(train) 20.343sec(infer)
# Epoch 21 tst: l 0.417 a 0.888 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.002sec
# Epoch 22 tr: l 0.342 a 0.904 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.665sec(train) 22.862sec(infer)
# Epoch 22 tst: l 0.410 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.490sec
# Epoch 23 tr: l 0.332 a 0.907 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.713sec(train) 22.209sec(infer)
# Epoch 23 tst: l 0.401 a 0.890 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.781sec
# Epoch 24 tr: l 0.327 a 0.907 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.268sec(train) 22.587sec(infer)
# Epoch 24 tst: l 0.398 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  13.027sec
# Epoch 25 tr: l 0.323 a 0.908 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 20.871sec(train) 10.740sec(infer)
# Epoch 25 tst: l 0.389 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  5.285sec
# Epoch 26 tr: l 0.319 a 0.910 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 19.682sec(train) 8.700sec(infer)
# Epoch 26 tst: l 0.385 a 0.894 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  5.315sec
# Epoch 27 tr: l 0.313 a 0.910 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 19.230sec(train) 7.057sec(infer)
# Epoch 27 tst: l 0.382 a 0.895 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  5.053sec
# Epoch 28 tr: l 0.307 a 0.911 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 19.458sec(train) 6.772sec(infer)
# Epoch 28 tst: l 0.376 a 0.897 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  5.603sec
# Epoch 29 tr: l 0.299 a 0.913 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 19.395sec(train) 6.675sec(infer)
# Epoch 29 tst: l 0.372 a 0.898 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  4.908sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.51 hour (1827.555 sec)

# %%
___.display_outputs()
# Out:
# ---------------------------------R:10, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  49.739sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  27.935sec
# Epoch 0 tr: l 2.066 a 0.398 clct[np.int64(834), np.int64(148), np.int64(145), np.int64(73)] cl_acc 0.319  lr 0.100000 27.584sec(train) 46.779sec(infer)
# Epoch 0 tst: l 2.199 a 0.278 clct[np.int64(142), np.int64(24), np.int64(24), np.int64(10)] cl_acc 0.290  27.522sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.857 a 0.526 clct[np.int64(752), np.int64(188), np.int64(160), np.int64(100)] cl_acc 0.332  lr 0.100000 27.036sec(train) 46.934sec(infer)
# Epoch 1 tst: l 2.066 a 0.386 clct[np.int64(133), np.int64(31), np.int64(24), np.int64(12)] cl_acc 0.380  29.664sec
# Epoch 2 tr: l 1.634 a 0.609 clct[np.int64(666), np.int64(239), np.int64(178), np.int64(117)] cl_acc 0.345  lr 0.100000 25.348sec(train) 50.382sec(infer)
# Epoch 2 tst: l 1.898 a 0.474 clct[np.int64(108), np.int64(33), np.int64(39), np.int64(20)] cl_acc 0.375  27.236sec
# Epoch 3 tr: l 1.433 a 0.672 clct[np.int64(555), np.int64(301), np.int64(195), np.int64(149)] cl_acc 0.372  lr 0.100000 25.551sec(train) 50.008sec(infer)
# Epoch 3 tst: l 1.727 a 0.535 clct[np.int64(112), np.int64(40), np.int64(29), np.int64(19)] cl_acc 0.390  27.146sec
# Epoch 4 tr: l 1.241 a 0.722 clct[np.int64(485), np.int64(338), np.int64(204), np.int64(173)] cl_acc 0.409  lr 0.100000 26.133sec(train) 47.846sec(infer)
# Epoch 4 tst: l 1.582 a 0.577 clct[np.int64(97), np.int64(50), np.int64(37), np.int64(16)] cl_acc 0.430  28.539sec
# Epoch 5 tr: l 1.103 a 0.754 clct[np.int64(413), np.int64(360), np.int64(224), np.int64(203)] cl_acc 0.444  lr 0.100000 25.073sec(train) 51.125sec(infer)
# Epoch 5 tst: l 1.433 a 0.618 clct[np.int64(68), np.int64(55), np.int64(46), np.int64(31)] cl_acc 0.430  27.981sec
# Epoch 6 tr: l 0.980 a 0.783 clct[np.int64(378), np.int64(381), np.int64(221), np.int64(220)] cl_acc 0.484  lr 0.100000 25.290sec(train) 50.193sec(infer)
# Epoch 6 tst: l 1.313 a 0.650 clct[np.int64(64), np.int64(55), np.int64(47), np.int64(34)] cl_acc 0.515  28.399sec
# Epoch 7 tr: l 0.895 a 0.801 clct[np.int64(336), np.int64(384), np.int64(231), np.int64(249)] cl_acc 0.542  lr 0.100000 25.202sec(train) 51.879sec(infer)
# Epoch 7 tst: l 1.226 a 0.668 clct[np.int64(51), np.int64(59), np.int64(48), np.int64(42)] cl_acc 0.500  26.147sec
# Epoch 8 tr: l 0.812 a 0.817 clct[np.int64(300), np.int64(405), np.int64(226), np.int64(269)] cl_acc 0.583  lr 0.100000 25.618sec(train) 50.520sec(infer)
# Epoch 8 tst: l 1.133 a 0.688 clct[np.int64(58), np.int64(62), np.int64(37), np.int64(43)] cl_acc 0.575  28.721sec
# Epoch 9 tr: l 0.760 a 0.825 clct[np.int64(271), np.int64(428), np.int64(218), np.int64(283)] cl_acc 0.623  lr 0.100000 25.435sec(train) 51.015sec(infer)
# Epoch 9 tst: l 1.046 a 0.712 clct[np.int64(45), np.int64(74), np.int64(31), np.int64(50)] cl_acc 0.635  26.463sec
# Epoch 10 tr: l 0.708 a 0.835 clct[np.int64(244), np.int64(455), np.int64(225), np.int64(276)] cl_acc 0.672  lr 0.100000 24.445sec(train) 50.694sec(infer)
# Epoch 10 tst: l 0.973 a 0.730 clct[np.int64(43), np.int64(74), np.int64(34), np.int64(49)] cl_acc 0.725  28.294sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.659 a 0.842 clct[np.int64(231), np.int64(467), np.int64(221), np.int64(281)] cl_acc 0.688  lr 0.100000 25.345sec(train) 46.454sec(infer)
# Epoch 11 tst: l 0.906 a 0.748 clct[np.int64(36), np.int64(79), np.int64(36), np.int64(49)] cl_acc 0.710  33.343sec
# Epoch 12 tr: l 0.629 a 0.845 clct[np.int64(222), np.int64(470), np.int64(222), np.int64(286)] cl_acc 0.715  lr 0.100000 24.768sec(train) 50.543sec(infer)
# Epoch 12 tst: l 0.837 a 0.766 clct[np.int64(36), np.int64(77), np.int64(38), np.int64(49)] cl_acc 0.740  29.480sec
# Epoch 13 tr: l 0.586 a 0.855 clct[np.int64(230), np.int64(466), np.int64(216), np.int64(288)] cl_acc 0.737  lr 0.100000 23.944sec(train) 48.632sec(infer)
# Epoch 13 tst: l 0.793 a 0.780 clct[np.int64(33), np.int64(73), np.int64(44), np.int64(50)] cl_acc 0.775  32.506sec
# Epoch 14 tr: l 0.548 a 0.862 clct[np.int64(233), np.int64(450), np.int64(228), np.int64(289)] cl_acc 0.763  lr 0.100000 24.084sec(train) 49.541sec(infer)
# Epoch 14 tst: l 0.750 a 0.789 clct[np.int64(34), np.int64(72), np.int64(44), np.int64(50)] cl_acc 0.810  30.597sec
# Epoch 15 tr: l 0.520 a 0.866 clct[np.int64(251), np.int64(433), np.int64(225), np.int64(291)] cl_acc 0.786  lr 0.100000 24.200sec(train) 48.778sec(infer)
# Epoch 15 tst: l 0.713 a 0.795 clct[np.int64(38), np.int64(66), np.int64(46), np.int64(50)] cl_acc 0.900  31.051sec
# Epoch 16 tr: l 0.486 a 0.876 clct[np.int64(250), np.int64(417), np.int64(237), np.int64(296)] cl_acc 0.814  lr 0.100000 24.132sec(train) 47.346sec(infer)
# Epoch 16 tst: l 0.686 a 0.803 clct[np.int64(37), np.int64(66), np.int64(47), np.int64(50)] cl_acc 0.905  30.840sec
# Epoch 17 tr: l 0.462 a 0.881 clct[np.int64(260), np.int64(400), np.int64(243), np.int64(297)] cl_acc 0.838  lr 0.100000 24.469sec(train) 45.461sec(infer)
# Epoch 17 tst: l 0.653 a 0.813 clct[np.int64(37), np.int64(65), np.int64(48), np.int64(50)] cl_acc 0.915  34.918sec
# Epoch 18 tr: l 0.452 a 0.883 clct[np.int64(274), np.int64(384), np.int64(245), np.int64(297)] cl_acc 0.863  lr 0.100000 24.374sec(train) 45.198sec(infer)
# Epoch 18 tst: l 0.623 a 0.823 clct[np.int64(48), np.int64(54), np.int64(48), np.int64(50)] cl_acc 0.960  34.188sec
# Epoch 19 tr: l 0.429 a 0.888 clct[np.int64(286), np.int64(362), np.int64(252), np.int64(300)] cl_acc 0.895  lr 0.100000 24.340sec(train) 46.596sec(infer)
# Epoch 19 tst: l 0.594 a 0.830 clct[np.int64(47), np.int64(55), np.int64(48), np.int64(50)] cl_acc 0.965  34.823sec
# Epoch 20 tr: l 0.400 a 0.897 clct[np.int64(293), np.int64(343), np.int64(264), np.int64(300)] cl_acc 0.924  lr 0.100000 24.452sec(train) 43.947sec(infer)
# Epoch 20 tst: l 0.559 a 0.842 clct[np.int64(48), np.int64(51), np.int64(51), np.int64(50)] cl_acc 0.980  36.407sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.377 a 0.902 clct[np.int64(301), np.int64(329), np.int64(270), np.int64(300)] cl_acc 0.943  lr 0.100000 23.966sec(train) 47.406sec(infer)
# Epoch 21 tst: l 0.527 a 0.851 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.687sec
# Epoch 22 tr: l 0.357 a 0.906 clct[np.int64(299), np.int64(319), np.int64(282), np.int64(300)] cl_acc 0.963  lr 0.100000 24.399sec(train) 44.494sec(infer)
# Epoch 22 tst: l 0.501 a 0.857 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  34.375sec
# Epoch 23 tr: l 0.336 a 0.912 clct[np.int64(307), np.int64(307), np.int64(285), np.int64(301)] cl_acc 0.976  lr 0.100000 24.325sec(train) 44.824sec(infer)
# Epoch 23 tst: l 0.479 a 0.861 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.020sec
# Epoch 24 tr: l 0.321 a 0.916 clct[np.int64(308), np.int64(302), np.int64(290), np.int64(300)] cl_acc 0.987  lr 0.100000 25.603sec(train) 43.915sec(infer)
# Epoch 24 tst: l 0.461 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  33.414sec
# Epoch 25 tr: l 0.309 a 0.917 clct[np.int64(310), np.int64(301), np.int64(289), np.int64(300)] cl_acc 0.990  lr 0.100000 24.619sec(train) 43.657sec(infer)
# Epoch 25 tst: l 0.443 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.891sec
# Epoch 26 tr: l 0.298 a 0.920 clct[np.int64(306), np.int64(300), np.int64(294), np.int64(300)] cl_acc 0.995  lr 0.100000 26.281sec(train) 44.209sec(infer)
# Epoch 26 tst: l 0.429 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.932sec
# Epoch 27 tr: l 0.286 a 0.924 clct[np.int64(305), np.int64(300), np.int64(295), np.int64(300)] cl_acc 0.996  lr 0.100000 25.524sec(train) 42.119sec(infer)
# Epoch 27 tst: l 0.418 a 0.880 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.539sec
# Epoch 28 tr: l 0.276 a 0.926 clct[np.int64(302), np.int64(300), np.int64(298), np.int64(300)] cl_acc 0.998  lr 0.100000 26.816sec(train) 41.687sec(infer)
# Epoch 28 tst: l 0.410 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.735sec
# Epoch 29 tr: l 0.273 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.099sec(train) 44.653sec(infer)
# Epoch 29 tst: l 0.400 a 0.883 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.763sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.89 hour (3188.844 sec)
# ---------------------------------R:10, lr: 0.1, seed: 409---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 409, 'train_seed': 409, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.107 clct[np.int64(319), np.int64(22), np.int64(446), np.int64(413)] cl_acc 0.556  50.813sec
# Epoch -1 tst: l 2.296 a 0.123 clct[np.int64(46), np.int64(0), np.int64(77), np.int64(77)] cl_acc 0.565  27.260sec
# Epoch 0 tr: l 2.033 a 0.475 clct[np.int64(334), np.int64(26), np.int64(444), np.int64(396)] cl_acc 0.578  lr 0.100000 25.297sec(train) 45.449sec(infer)
# Epoch 0 tst: l 2.190 a 0.318 clct[np.int64(54), np.int64(3), np.int64(87), np.int64(56)] cl_acc 0.530  32.847sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.787 a 0.598 clct[np.int64(366), np.int64(29), np.int64(426), np.int64(379)] cl_acc 0.617  lr 0.100000 25.506sec(train) 49.920sec(infer)
# Epoch 1 tst: l 2.034 a 0.431 clct[np.int64(57), np.int64(2), np.int64(84), np.int64(57)] cl_acc 0.625  29.136sec
# Epoch 2 tr: l 1.547 a 0.667 clct[np.int64(371), np.int64(33), np.int64(431), np.int64(365)] cl_acc 0.652  lr 0.100000 23.961sec(train) 47.060sec(infer)
# Epoch 2 tst: l 1.831 a 0.525 clct[np.int64(56), np.int64(5), np.int64(86), np.int64(53)] cl_acc 0.700  30.321sec
# Epoch 3 tr: l 1.323 a 0.719 clct[np.int64(373), np.int64(38), np.int64(428), np.int64(361)] cl_acc 0.675  lr 0.100000 25.164sec(train) 44.985sec(infer)
# Epoch 3 tst: l 1.632 a 0.583 clct[np.int64(57), np.int64(8), np.int64(74), np.int64(61)] cl_acc 0.720  30.117sec
# Epoch 4 tr: l 1.132 a 0.753 clct[np.int64(367), np.int64(41), np.int64(440), np.int64(352)] cl_acc 0.694  lr 0.100000 25.803sec(train) 49.345sec(infer)
# Epoch 4 tst: l 1.434 a 0.636 clct[np.int64(59), np.int64(7), np.int64(67), np.int64(67)] cl_acc 0.735  28.110sec
# Epoch 5 tr: l 1.010 a 0.771 clct[np.int64(354), np.int64(45), np.int64(451), np.int64(350)] cl_acc 0.710  lr 0.100000 24.624sec(train) 47.672sec(infer)
# Epoch 5 tst: l 1.289 a 0.666 clct[np.int64(55), np.int64(9), np.int64(68), np.int64(68)] cl_acc 0.750  31.279sec
# Epoch 6 tr: l 0.902 a 0.792 clct[np.int64(339), np.int64(53), np.int64(462), np.int64(346)] cl_acc 0.720  lr 0.100000 25.454sec(train) 45.421sec(infer)
# Epoch 6 tst: l 1.173 a 0.689 clct[np.int64(51), np.int64(13), np.int64(71), np.int64(65)] cl_acc 0.755  29.005sec
# Epoch 7 tr: l 0.813 a 0.808 clct[np.int64(329), np.int64(53), np.int64(481), np.int64(337)] cl_acc 0.723  lr 0.100000 25.433sec(train) 43.616sec(infer)
# Epoch 7 tst: l 1.072 a 0.717 clct[np.int64(51), np.int64(14), np.int64(72), np.int64(63)] cl_acc 0.780  29.269sec
# Epoch 8 tr: l 0.738 a 0.823 clct[np.int64(322), np.int64(59), np.int64(486), np.int64(333)] cl_acc 0.723  lr 0.100000 25.581sec(train) 41.234sec(infer)
# Epoch 8 tst: l 0.998 a 0.729 clct[np.int64(49), np.int64(12), np.int64(78), np.int64(61)] cl_acc 0.760  31.896sec
# Epoch 9 tr: l 0.700 a 0.826 clct[np.int64(313), np.int64(64), np.int64(493), np.int64(330)] cl_acc 0.724  lr 0.100000 24.553sec(train) 42.599sec(infer)
# Epoch 9 tst: l 0.934 a 0.742 clct[np.int64(49), np.int64(10), np.int64(83), np.int64(58)] cl_acc 0.770  30.820sec
# Epoch 10 tr: l 0.653 a 0.834 clct[np.int64(310), np.int64(71), np.int64(492), np.int64(327)] cl_acc 0.722  lr 0.100000 24.011sec(train) 42.828sec(infer)
# Epoch 10 tst: l 0.880 a 0.758 clct[np.int64(52), np.int64(9), np.int64(81), np.int64(58)] cl_acc 0.765  31.495sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.606 a 0.845 clct[np.int64(311), np.int64(80), np.int64(493), np.int64(316)] cl_acc 0.737  lr 0.100000 24.664sec(train) 37.296sec(infer)
# Epoch 11 tst: l 0.833 a 0.766 clct[np.int64(50), np.int64(10), np.int64(89), np.int64(51)] cl_acc 0.775  31.262sec
# Epoch 12 tr: l 0.581 a 0.850 clct[np.int64(309), np.int64(98), np.int64(483), np.int64(310)] cl_acc 0.758  lr 0.100000 23.931sec(train) 41.247sec(infer)
# Epoch 12 tst: l 0.793 a 0.775 clct[np.int64(50), np.int64(13), np.int64(85), np.int64(52)] cl_acc 0.755  28.876sec
# Epoch 13 tr: l 0.562 a 0.855 clct[np.int64(303), np.int64(133), np.int64(458), np.int64(306)] cl_acc 0.796  lr 0.100000 25.126sec(train) 41.099sec(infer)
# Epoch 13 tst: l 0.755 a 0.786 clct[np.int64(50), np.int64(20), np.int64(79), np.int64(51)] cl_acc 0.805  28.787sec
# Epoch 14 tr: l 0.528 a 0.864 clct[np.int64(302), np.int64(175), np.int64(419), np.int64(304)] cl_acc 0.841  lr 0.100000 25.201sec(train) 42.187sec(infer)
# Epoch 14 tst: l 0.715 a 0.800 clct[np.int64(50), np.int64(26), np.int64(74), np.int64(50)] cl_acc 0.850  28.740sec
# Epoch 15 tr: l 0.487 a 0.876 clct[np.int64(301), np.int64(218), np.int64(378), np.int64(303)] cl_acc 0.888  lr 0.100000 25.746sec(train) 40.369sec(infer)
# Epoch 15 tst: l 0.675 a 0.810 clct[np.int64(50), np.int64(36), np.int64(64), np.int64(50)] cl_acc 0.910  29.945sec
# Epoch 16 tr: l 0.448 a 0.890 clct[np.int64(302), np.int64(263), np.int64(332), np.int64(303)] cl_acc 0.942  lr 0.100000 24.984sec(train) 41.900sec(infer)
# Epoch 16 tst: l 0.623 a 0.828 clct[np.int64(50), np.int64(47), np.int64(53), np.int64(50)] cl_acc 0.985  27.429sec
# Epoch 17 tr: l 0.411 a 0.898 clct[np.int64(302), np.int64(278), np.int64(316), np.int64(304)] cl_acc 0.968  lr 0.100000 25.799sec(train) 44.928sec(infer)
# Epoch 17 tst: l 0.582 a 0.839 clct[np.int64(50), np.int64(46), np.int64(54), np.int64(50)] cl_acc 0.980  26.730sec
# Epoch 18 tr: l 0.383 a 0.903 clct[np.int64(302), np.int64(290), np.int64(306), np.int64(302)] cl_acc 0.984  lr 0.100000 25.940sec(train) 44.627sec(infer)
# Epoch 18 tst: l 0.546 a 0.850 clct[np.int64(50), np.int64(48), np.int64(52), np.int64(50)] cl_acc 0.990  27.276sec
# Epoch 19 tr: l 0.356 a 0.910 clct[np.int64(301), np.int64(293), np.int64(304), np.int64(302)] cl_acc 0.990  lr 0.100000 26.043sec(train) 45.839sec(infer)
# Epoch 19 tst: l 0.515 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.644sec
# Epoch 20 tr: l 0.339 a 0.911 clct[np.int64(301), np.int64(295), np.int64(302), np.int64(302)] cl_acc 0.992  lr 0.100000 25.991sec(train) 45.198sec(infer)
# Epoch 20 tst: l 0.488 a 0.865 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.714sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.326 a 0.914 clct[np.int64(301), np.int64(296), np.int64(301), np.int64(302)] cl_acc 0.993  lr 0.100000 25.936sec(train) 45.205sec(infer)
# Epoch 21 tst: l 0.469 a 0.870 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.812sec
# Epoch 22 tr: l 0.315 a 0.917 clct[np.int64(301), np.int64(296), np.int64(302), np.int64(301)] cl_acc 0.993  lr 0.100000 24.708sec(train) 48.586sec(infer)
# Epoch 22 tst: l 0.454 a 0.874 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  25.947sec
# Epoch 23 tr: l 0.311 a 0.917 clct[np.int64(301), np.int64(298), np.int64(301), np.int64(300)] cl_acc 0.996  lr 0.100000 24.553sec(train) 47.145sec(infer)
# Epoch 23 tst: l 0.441 a 0.877 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.061sec
# Epoch 24 tr: l 0.297 a 0.919 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 24.657sec(train) 47.681sec(infer)
# Epoch 24 tst: l 0.429 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.478sec
# Epoch 25 tr: l 0.287 a 0.922 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 24.167sec(train) 46.115sec(infer)
# Epoch 25 tst: l 0.419 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  27.886sec
# Epoch 26 tr: l 0.278 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 24.961sec(train) 44.155sec(infer)
# Epoch 26 tst: l 0.411 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.271sec
# Epoch 27 tr: l 0.275 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 24.046sec(train) 46.758sec(infer)
# Epoch 27 tst: l 0.402 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.148sec
# Epoch 28 tr: l 0.268 a 0.924 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 24.251sec(train) 44.850sec(infer)
# Epoch 28 tst: l 0.396 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.451sec
# Epoch 29 tr: l 0.260 a 0.926 clct[np.int64(301), np.int64(299), np.int64(299), np.int64(301)] cl_acc 0.998  lr 0.100000 25.311sec(train) 48.322sec(infer)
# Epoch 29 tst: l 0.390 a 0.888 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  26.150sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.84 hour (3037.462 sec)
# ---------------------------------R:10, lr: 0.1, seed: 4506---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4506, 'train_seed': 4506, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.120 clct[np.int64(430), np.int64(377), np.int64(322), np.int64(71)] cl_acc 0.547  45.540sec
# Epoch -1 tst: l 2.294 a 0.135 clct[np.int64(84), np.int64(53), np.int64(49), np.int64(14)] cl_acc 0.545  29.456sec
# Epoch 0 tr: l 2.029 a 0.462 clct[np.int64(403), np.int64(376), np.int64(338), np.int64(83)] cl_acc 0.582  lr 0.100000 23.610sec(train) 42.131sec(infer)
# Epoch 0 tst: l 2.192 a 0.319 clct[np.int64(66), np.int64(63), np.int64(57), np.int64(14)] cl_acc 0.575  30.012sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.786 a 0.598 clct[np.int64(385), np.int64(368), np.int64(350), np.int64(97)] cl_acc 0.621  lr 0.100000 24.389sec(train) 43.822sec(infer)
# Epoch 1 tst: l 2.035 a 0.449 clct[np.int64(61), np.int64(66), np.int64(57), np.int64(16)] cl_acc 0.630  28.141sec
# Epoch 2 tr: l 1.539 a 0.682 clct[np.int64(353), np.int64(385), np.int64(351), np.int64(111)] cl_acc 0.662  lr 0.100000 23.670sec(train) 44.808sec(infer)
# Epoch 2 tst: l 1.833 a 0.538 clct[np.int64(55), np.int64(77), np.int64(55), np.int64(13)] cl_acc 0.755  28.829sec
# Epoch 3 tr: l 1.301 a 0.744 clct[np.int64(325), np.int64(385), np.int64(348), np.int64(142)] cl_acc 0.723  lr 0.100000 26.678sec(train) 46.909sec(infer)
# Epoch 3 tst: l 1.621 a 0.613 clct[np.int64(51), np.int64(74), np.int64(60), np.int64(15)] cl_acc 0.775  27.435sec
# Epoch 4 tr: l 1.103 a 0.784 clct[np.int64(320), np.int64(371), np.int64(333), np.int64(176)] cl_acc 0.774  lr 0.100000 25.352sec(train) 46.254sec(infer)
# Epoch 4 tst: l 1.403 a 0.677 clct[np.int64(50), np.int64(69), np.int64(52), np.int64(29)] cl_acc 0.865  27.764sec
# Epoch 5 tr: l 0.929 a 0.816 clct[np.int64(317), np.int64(346), np.int64(313), np.int64(224)] cl_acc 0.836  lr 0.100000 23.437sec(train) 49.109sec(infer)
# Epoch 5 tst: l 1.230 a 0.715 clct[np.int64(51), np.int64(66), np.int64(52), np.int64(31)] cl_acc 0.890  25.470sec
# Epoch 6 tr: l 0.801 a 0.840 clct[np.int64(309), np.int64(308), np.int64(312), np.int64(271)] cl_acc 0.900  lr 0.100000 24.025sec(train) 46.581sec(infer)
# Epoch 6 tst: l 1.066 a 0.754 clct[np.int64(51), np.int64(53), np.int64(51), np.int64(45)] cl_acc 0.960  26.450sec
# Epoch 7 tr: l 0.692 a 0.861 clct[np.int64(303), np.int64(286), np.int64(309), np.int64(302)] cl_acc 0.948  lr 0.100000 25.599sec(train) 46.133sec(infer)
# Epoch 7 tst: l 0.931 a 0.785 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  26.485sec
# Epoch 8 tr: l 0.604 a 0.874 clct[np.int64(302), np.int64(287), np.int64(306), np.int64(305)] cl_acc 0.971  lr 0.100000 24.792sec(train) 45.979sec(infer)
# Epoch 8 tst: l 0.824 a 0.805 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  28.984sec
# Epoch 9 tr: l 0.534 a 0.884 clct[np.int64(302), np.int64(290), np.int64(304), np.int64(304)] cl_acc 0.983  lr 0.100000 25.492sec(train) 45.944sec(infer)
# Epoch 9 tst: l 0.731 a 0.825 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.624sec
# Epoch 10 tr: l 0.488 a 0.891 clct[np.int64(302), np.int64(294), np.int64(303), np.int64(301)] cl_acc 0.989  lr 0.100000 24.967sec(train) 46.892sec(infer)
# Epoch 10 tst: l 0.667 a 0.839 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.187sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.450 a 0.896 clct[np.int64(302), np.int64(296), np.int64(300), np.int64(302)] cl_acc 0.993  lr 0.100000 24.710sec(train) 47.001sec(infer)
# Epoch 11 tst: l 0.622 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.451sec
# Epoch 12 tr: l 0.419 a 0.901 clct[np.int64(301), np.int64(296), np.int64(300), np.int64(303)] cl_acc 0.995  lr 0.100000 24.910sec(train) 45.909sec(infer)
# Epoch 12 tst: l 0.582 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.403sec
# Epoch 13 tr: l 0.391 a 0.905 clct[np.int64(301), np.int64(297), np.int64(300), np.int64(302)] cl_acc 0.996  lr 0.100000 24.753sec(train) 47.523sec(infer)
# Epoch 13 tst: l 0.556 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.007sec
# Epoch 14 tr: l 0.373 a 0.908 clct[np.int64(300), np.int64(299), np.int64(300), np.int64(301)] cl_acc 0.998  lr 0.100000 24.390sec(train) 44.963sec(infer)
# Epoch 14 tst: l 0.529 a 0.863 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.337sec
# Epoch 15 tr: l 0.357 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.722sec(train) 47.777sec(infer)
# Epoch 15 tst: l 0.509 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.564sec
# Epoch 16 tr: l 0.346 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.958sec(train) 44.501sec(infer)
# Epoch 16 tst: l 0.489 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.635sec
# Epoch 17 tr: l 0.329 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.728sec(train) 47.521sec(infer)
# Epoch 17 tst: l 0.476 a 0.873 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.800sec
# Epoch 18 tr: l 0.315 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.492sec(train) 44.850sec(infer)
# Epoch 18 tst: l 0.464 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.455sec
# Epoch 19 tr: l 0.307 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.541sec(train) 45.667sec(infer)
# Epoch 19 tst: l 0.452 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.759sec
# Epoch 20 tr: l 0.299 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.789sec(train) 41.945sec(infer)
# Epoch 20 tst: l 0.441 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.040sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.292 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.889sec(train) 44.356sec(infer)
# Epoch 21 tst: l 0.434 a 0.882 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.552sec
# Epoch 22 tr: l 0.282 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.785sec(train) 43.018sec(infer)
# Epoch 22 tst: l 0.426 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.642sec
# Epoch 23 tr: l 0.277 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.894sec(train) 43.824sec(infer)
# Epoch 23 tst: l 0.418 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.205sec
# Epoch 24 tr: l 0.272 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.304sec(train) 42.469sec(infer)
# Epoch 24 tst: l 0.413 a 0.886 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  31.168sec
# Epoch 25 tr: l 0.262 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.847sec(train) 39.167sec(infer)
# Epoch 25 tst: l 0.408 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  32.970sec
# Epoch 26 tr: l 0.260 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.409sec(train) 41.907sec(infer)
# Epoch 26 tst: l 0.402 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.442sec
# Epoch 27 tr: l 0.255 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.112sec(train) 42.430sec(infer)
# Epoch 27 tst: l 0.399 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  30.310sec
# Epoch 28 tr: l 0.253 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.882sec(train) 41.617sec(infer)
# Epoch 28 tst: l 0.393 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  29.619sec
# Epoch 29 tr: l 0.247 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.849sec(train) 42.427sec(infer)
# Epoch 29 tst: l 0.389 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  28.160sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.84 hour (3041.827 sec)
# ---------------------------------R:10, lr: 0.1, seed: 4012---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 4012, 'train_seed': 4012, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.108 clct[np.int64(39), np.int64(557), np.int64(362), np.int64(242)] cl_acc 0.400  46.054sec
# Epoch -1 tst: l 2.291 a 0.118 clct[np.int64(6), np.int64(84), np.int64(60), np.int64(50)] cl_acc 0.420  27.213sec
# Epoch 0 tr: l 2.041 a 0.425 clct[np.int64(41), np.int64(537), np.int64(364), np.int64(258)] cl_acc 0.414  lr 0.100000 25.365sec(train) 45.604sec(infer)
# Epoch 0 tst: l 2.197 a 0.286 clct[np.int64(7), np.int64(87), np.int64(66), np.int64(40)] cl_acc 0.410  28.069sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.817 a 0.567 clct[np.int64(52), np.int64(519), np.int64(357), np.int64(272)] cl_acc 0.429  lr 0.100000 24.811sec(train) 45.556sec(infer)
# Epoch 1 tst: l 2.058 a 0.403 clct[np.int64(15), np.int64(81), np.int64(57), np.int64(47)] cl_acc 0.480  29.800sec
# Epoch 2 tr: l 1.598 a 0.656 clct[np.int64(59), np.int64(501), np.int64(351), np.int64(289)] cl_acc 0.432  lr 0.100000 24.343sec(train) 43.380sec(infer)
# Epoch 2 tst: l 1.883 a 0.497 clct[np.int64(10), np.int64(80), np.int64(65), np.int64(45)] cl_acc 0.475  31.087sec
# Epoch 3 tr: l 1.379 a 0.715 clct[np.int64(62), np.int64(493), np.int64(348), np.int64(297)] cl_acc 0.443  lr 0.100000 24.500sec(train) 43.860sec(infer)
# Epoch 3 tst: l 1.695 a 0.560 clct[np.int64(9), np.int64(86), np.int64(64), np.int64(41)] cl_acc 0.490  29.714sec
# Epoch 4 tr: l 1.217 a 0.743 clct[np.int64(72), np.int64(487), np.int64(327), np.int64(314)] cl_acc 0.448  lr 0.100000 24.993sec(train) 41.375sec(infer)
# Epoch 4 tst: l 1.526 a 0.615 clct[np.int64(9), np.int64(88), np.int64(55), np.int64(48)] cl_acc 0.485  30.566sec
# Epoch 5 tr: l 1.074 a 0.772 clct[np.int64(82), np.int64(490), np.int64(316), np.int64(312)] cl_acc 0.457  lr 0.100000 22.053sec(train) 35.875sec(infer)
# Epoch 5 tst: l 1.386 a 0.646 clct[np.int64(13), np.int64(89), np.int64(43), np.int64(55)] cl_acc 0.470  33.148sec
# Epoch 6 tr: l 0.969 a 0.791 clct[np.int64(98), np.int64(493), np.int64(300), np.int64(309)] cl_acc 0.458  lr 0.100000 24.054sec(train) 42.366sec(infer)
# Epoch 6 tst: l 1.266 a 0.673 clct[np.int64(14), np.int64(91), np.int64(37), np.int64(58)] cl_acc 0.505  31.108sec
# Epoch 7 tr: l 0.888 a 0.800 clct[np.int64(115), np.int64(507), np.int64(268), np.int64(310)] cl_acc 0.477  lr 0.100000 24.597sec(train) 42.553sec(infer)
# Epoch 7 tst: l 1.164 a 0.694 clct[np.int64(17), np.int64(89), np.int64(44), np.int64(50)] cl_acc 0.490  30.818sec
# Epoch 8 tr: l 0.800 a 0.816 clct[np.int64(122), np.int64(525), np.int64(264), np.int64(289)] cl_acc 0.492  lr 0.100000 24.778sec(train) 41.215sec(infer)
# Epoch 8 tst: l 1.081 a 0.712 clct[np.int64(18), np.int64(97), np.int64(37), np.int64(48)] cl_acc 0.485  30.880sec
# Epoch 9 tr: l 0.730 a 0.828 clct[np.int64(144), np.int64(536), np.int64(235), np.int64(285)] cl_acc 0.516  lr 0.100000 25.285sec(train) 42.597sec(infer)
# Epoch 9 tst: l 1.006 a 0.726 clct[np.int64(27), np.int64(97), np.int64(30), np.int64(46)] cl_acc 0.545  28.154sec
# Epoch 10 tr: l 0.686 a 0.834 clct[np.int64(176), np.int64(545), np.int64(193), np.int64(286)] cl_acc 0.561  lr 0.100000 26.896sec(train) 40.487sec(infer)
# Epoch 10 tst: l 0.946 a 0.738 clct[np.int64(32), np.int64(99), np.int64(28), np.int64(41)] cl_acc 0.570  28.772sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.637 a 0.842 clct[np.int64(202), np.int64(557), np.int64(161), np.int64(280)] cl_acc 0.595  lr 0.100000 26.146sec(train) 41.146sec(infer)
# Epoch 11 tst: l 0.895 a 0.750 clct[np.int64(39), np.int64(98), np.int64(24), np.int64(39)] cl_acc 0.610  28.752sec
# Epoch 12 tr: l 0.602 a 0.849 clct[np.int64(235), np.int64(558), np.int64(150), np.int64(257)] cl_acc 0.629  lr 0.100000 26.808sec(train) 42.245sec(infer)
# Epoch 12 tst: l 0.841 a 0.765 clct[np.int64(41), np.int64(99), np.int64(19), np.int64(41)] cl_acc 0.640  27.139sec
# Epoch 13 tr: l 0.566 a 0.856 clct[np.int64(253), np.int64(566), np.int64(126), np.int64(255)] cl_acc 0.659  lr 0.100000 25.397sec(train) 42.249sec(infer)
# Epoch 13 tst: l 0.786 a 0.779 clct[np.int64(44), np.int64(100), np.int64(13), np.int64(43)] cl_acc 0.680  27.758sec
# Epoch 14 tr: l 0.525 a 0.863 clct[np.int64(261), np.int64(571), np.int64(114), np.int64(254)] cl_acc 0.671  lr 0.100000 25.257sec(train) 41.693sec(infer)
# Epoch 14 tst: l 0.752 a 0.784 clct[np.int64(47), np.int64(98), np.int64(9), np.int64(46)] cl_acc 0.705  30.352sec
# Epoch 15 tr: l 0.499 a 0.868 clct[np.int64(269), np.int64(576), np.int64(104), np.int64(251)] cl_acc 0.687  lr 0.100000 24.515sec(train) 43.936sec(infer)
# Epoch 15 tst: l 0.718 a 0.793 clct[np.int64(49), np.int64(98), np.int64(6), np.int64(47)] cl_acc 0.730  27.159sec
# Epoch 16 tr: l 0.483 a 0.868 clct[np.int64(284), np.int64(578), np.int64(86), np.int64(252)] cl_acc 0.703  lr 0.100000 24.620sec(train) 45.054sec(infer)
# Epoch 16 tst: l 0.683 a 0.803 clct[np.int64(50), np.int64(98), np.int64(3), np.int64(49)] cl_acc 0.755  26.060sec
# Epoch 17 tr: l 0.474 a 0.869 clct[np.int64(286), np.int64(577), np.int64(82), np.int64(255)] cl_acc 0.708  lr 0.100000 24.874sec(train) 44.783sec(infer)
# Epoch 17 tst: l 0.664 a 0.805 clct[np.int64(50), np.int64(98), np.int64(3), np.int64(49)] cl_acc 0.755  28.264sec
# Epoch 18 tr: l 0.455 a 0.874 clct[np.int64(287), np.int64(579), np.int64(79), np.int64(255)] cl_acc 0.710  lr 0.100000 25.358sec(train) 40.032sec(infer)
# Epoch 18 tst: l 0.645 a 0.810 clct[np.int64(50), np.int64(98), np.int64(2), np.int64(50)] cl_acc 0.760  19.601sec
# Epoch 19 tr: l 0.444 a 0.873 clct[np.int64(288), np.int64(580), np.int64(72), np.int64(260)] cl_acc 0.716  lr 0.100000 23.873sec(train) 31.861sec(infer)
# Epoch 19 tst: l 0.631 a 0.815 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  20.859sec
# Epoch 20 tr: l 0.427 a 0.877 clct[np.int64(288), np.int64(583), np.int64(67), np.int64(262)] cl_acc 0.719  lr 0.100000 23.289sec(train) 34.109sec(infer)
# Epoch 20 tst: l 0.622 a 0.816 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  20.249sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.423 a 0.878 clct[np.int64(290), np.int64(583), np.int64(61), np.int64(266)] cl_acc 0.724  lr 0.100000 23.633sec(train) 33.317sec(infer)
# Epoch 21 tst: l 0.605 a 0.820 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  20.484sec
# Epoch 22 tr: l 0.410 a 0.881 clct[np.int64(290), np.int64(584), np.int64(59), np.int64(267)] cl_acc 0.724  lr 0.100000 23.797sec(train) 30.304sec(infer)
# Epoch 22 tst: l 0.590 a 0.823 clct[np.int64(50), np.int64(100), np.int64(1), np.int64(49)] cl_acc 0.745  22.475sec
# Epoch 23 tr: l 0.402 a 0.883 clct[np.int64(292), np.int64(585), np.int64(53), np.int64(270)] cl_acc 0.728  lr 0.100000 23.398sec(train) 31.293sec(infer)
# Epoch 23 tst: l 0.584 a 0.824 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  21.275sec
# Epoch 24 tr: l 0.395 a 0.884 clct[np.int64(292), np.int64(584), np.int64(53), np.int64(271)] cl_acc 0.729  lr 0.100000 23.843sec(train) 30.813sec(infer)
# Epoch 24 tst: l 0.580 a 0.826 clct[np.int64(50), np.int64(100), np.int64(0), np.int64(50)] cl_acc 0.750  21.541sec
# Epoch 25 tr: l 0.388 a 0.885 clct[np.int64(293), np.int64(584), np.int64(52), np.int64(271)] cl_acc 0.730  lr 0.100000 23.853sec(train) 30.112sec(infer)
# Epoch 25 tst: l 0.567 a 0.828 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  22.229sec
# Epoch 26 tr: l 0.378 a 0.887 clct[np.int64(294), np.int64(584), np.int64(50), np.int64(272)] cl_acc 0.732  lr 0.100000 23.412sec(train) 32.173sec(infer)
# Epoch 26 tst: l 0.558 a 0.830 clct[np.int64(50), np.int64(99), np.int64(1), np.int64(50)] cl_acc 0.755  19.047sec
# Epoch 27 tr: l 0.370 a 0.888 clct[np.int64(294), np.int64(584), np.int64(50), np.int64(272)] cl_acc 0.732  lr 0.100000 24.140sec(train) 30.532sec(infer)
# Epoch 27 tst: l 0.554 a 0.831 clct[np.int64(50), np.int64(98), np.int64(4), np.int64(48)] cl_acc 0.750  21.570sec
# Epoch 28 tr: l 0.377 a 0.887 clct[np.int64(294), np.int64(582), np.int64(50), np.int64(274)] cl_acc 0.735  lr 0.100000 23.834sec(train) 31.531sec(infer)
# Epoch 28 tst: l 0.545 a 0.835 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  21.250sec
# Epoch 29 tr: l 0.361 a 0.891 clct[np.int64(294), np.int64(583), np.int64(47), np.int64(276)] cl_acc 0.736  lr 0.100000 23.445sec(train) 32.567sec(infer)
# Epoch 29 tst: l 0.544 a 0.834 clct[np.int64(50), np.int64(99), np.int64(2), np.int64(49)] cl_acc 0.750  20.468sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.76 hour (2744.633 sec)
# ---------------------------------R:10, lr: 0.1, seed: 3657---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'R': 10, 'h1': 200, 'num_epochs': 30, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 3657, 'train_seed': 3657, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.134 clct[np.int64(130), np.int64(172), np.int64(190), np.int64(708)] cl_acc 0.358  36.335sec
# Epoch -1 tst: l 2.291 a 0.145 clct[np.int64(18), np.int64(23), np.int64(41), np.int64(118)] cl_acc 0.375  18.301sec
# Epoch 0 tr: l 2.054 a 0.449 clct[np.int64(139), np.int64(206), np.int64(203), np.int64(652)] cl_acc 0.367  lr 0.100000 23.463sec(train) 37.152sec(infer)
# Epoch 0 tst: l 2.193 a 0.321 clct[np.int64(20), np.int64(39), np.int64(31), np.int64(110)] cl_acc 0.390  16.641sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.824 a 0.567 clct[np.int64(155), np.int64(241), np.int64(221), np.int64(583)] cl_acc 0.385  lr 0.100000 23.067sec(train) 32.877sec(infer)
# Epoch 1 tst: l 2.052 a 0.430 clct[np.int64(22), np.int64(34), np.int64(35), np.int64(109)] cl_acc 0.415  19.904sec
# Epoch 2 tr: l 1.578 a 0.648 clct[np.int64(171), np.int64(278), np.int64(226), np.int64(525)] cl_acc 0.408  lr 0.100000 22.908sec(train) 33.151sec(infer)
# Epoch 2 tst: l 1.874 a 0.504 clct[np.int64(30), np.int64(40), np.int64(39), np.int64(91)] cl_acc 0.435  21.720sec
# Epoch 3 tr: l 1.364 a 0.701 clct[np.int64(179), np.int64(290), np.int64(232), np.int64(499)] cl_acc 0.429  lr 0.100000 22.075sec(train) 34.194sec(infer)
# Epoch 3 tst: l 1.692 a 0.569 clct[np.int64(30), np.int64(52), np.int64(34), np.int64(84)] cl_acc 0.455  21.312sec
# Epoch 4 tr: l 1.202 a 0.740 clct[np.int64(186), np.int64(328), np.int64(234), np.int64(452)] cl_acc 0.460  lr 0.100000 23.111sec(train) 30.798sec(infer)
# Epoch 4 tst: l 1.531 a 0.610 clct[np.int64(29), np.int64(58), np.int64(30), np.int64(83)] cl_acc 0.510  22.949sec
# Epoch 5 tr: l 1.063 a 0.770 clct[np.int64(198), np.int64(344), np.int64(241), np.int64(417)] cl_acc 0.488  lr 0.100000 23.246sec(train) 28.341sec(infer)
# Epoch 5 tst: l 1.390 a 0.644 clct[np.int64(35), np.int64(47), np.int64(37), np.int64(81)] cl_acc 0.520  25.875sec
# Epoch 6 tr: l 0.965 a 0.789 clct[np.int64(202), np.int64(353), np.int64(226), np.int64(419)] cl_acc 0.498  lr 0.100000 22.592sec(train) 30.009sec(infer)
# Epoch 6 tst: l 1.261 a 0.676 clct[np.int64(37), np.int64(49), np.int64(43), np.int64(71)] cl_acc 0.540  23.247sec
# Epoch 7 tr: l 0.864 a 0.808 clct[np.int64(205), np.int64(360), np.int64(223), np.int64(412)] cl_acc 0.512  lr 0.100000 23.350sec(train) 28.886sec(infer)
# Epoch 7 tst: l 1.156 a 0.702 clct[np.int64(38), np.int64(45), np.int64(38), np.int64(79)] cl_acc 0.540  21.753sec
# Epoch 8 tr: l 0.801 a 0.815 clct[np.int64(210), np.int64(349), np.int64(221), np.int64(420)] cl_acc 0.524  lr 0.100000 23.797sec(train) 29.230sec(infer)
# Epoch 8 tst: l 1.084 a 0.714 clct[np.int64(39), np.int64(49), np.int64(38), np.int64(74)] cl_acc 0.555  21.424sec
# Epoch 9 tr: l 0.743 a 0.825 clct[np.int64(202), np.int64(364), np.int64(224), np.int64(410)] cl_acc 0.547  lr 0.100000 22.356sec(train) 20.288sec(infer)
# Epoch 9 tst: l 1.020 a 0.729 clct[np.int64(27), np.int64(54), np.int64(40), np.int64(79)] cl_acc 0.595  13.151sec
# Epoch 10 tr: l 0.686 a 0.837 clct[np.int64(196), np.int64(373), np.int64(220), np.int64(411)] cl_acc 0.563  lr 0.100000 22.443sec(train) 20.524sec(infer)
# Epoch 10 tst: l 0.964 a 0.736 clct[np.int64(29), np.int64(56), np.int64(42), np.int64(73)] cl_acc 0.615  14.571sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.650 a 0.842 clct[np.int64(185), np.int64(381), np.int64(230), np.int64(404)] cl_acc 0.578  lr 0.100000 22.111sec(train) 19.100sec(infer)
# Epoch 11 tst: l 0.911 a 0.748 clct[np.int64(29), np.int64(63), np.int64(41), np.int64(67)] cl_acc 0.650  14.405sec
# Epoch 12 tr: l 0.615 a 0.844 clct[np.int64(180), np.int64(390), np.int64(232), np.int64(398)] cl_acc 0.595  lr 0.100000 21.662sec(train) 20.926sec(infer)
# Epoch 12 tst: l 0.866 a 0.758 clct[np.int64(28), np.int64(60), np.int64(41), np.int64(71)] cl_acc 0.640  11.677sec
# Epoch 13 tr: l 0.590 a 0.849 clct[np.int64(189), np.int64(404), np.int64(227), np.int64(380)] cl_acc 0.626  lr 0.100000 21.273sec(train) 22.426sec(infer)
# Epoch 13 tst: l 0.834 a 0.764 clct[np.int64(24), np.int64(61), np.int64(46), np.int64(69)] cl_acc 0.680  13.439sec
# Epoch 14 tr: l 0.563 a 0.854 clct[np.int64(193), np.int64(414), np.int64(223), np.int64(370)] cl_acc 0.667  lr 0.100000 21.347sec(train) 22.014sec(infer)
# Epoch 14 tst: l 0.793 a 0.775 clct[np.int64(23), np.int64(63), np.int64(45), np.int64(69)] cl_acc 0.695  14.630sec
# Epoch 15 tr: l 0.530 a 0.861 clct[np.int64(188), np.int64(434), np.int64(226), np.int64(352)] cl_acc 0.693  lr 0.100000 21.383sec(train) 21.737sec(infer)
# Epoch 15 tst: l 0.755 a 0.784 clct[np.int64(18), np.int64(73), np.int64(50), np.int64(59)] cl_acc 0.770  14.262sec
# Epoch 16 tr: l 0.504 a 0.866 clct[np.int64(192), np.int64(446), np.int64(226), np.int64(336)] cl_acc 0.722  lr 0.100000 21.641sec(train) 20.737sec(infer)
# Epoch 16 tst: l 0.729 a 0.791 clct[np.int64(22), np.int64(73), np.int64(47), np.int64(58)] cl_acc 0.795  14.914sec
# Epoch 17 tr: l 0.485 a 0.870 clct[np.int64(221), np.int64(426), np.int64(232), np.int64(321)] cl_acc 0.768  lr 0.100000 21.843sec(train) 21.281sec(infer)
# Epoch 17 tst: l 0.692 a 0.803 clct[np.int64(35), np.int64(68), np.int64(43), np.int64(54)] cl_acc 0.825  13.467sec
# Epoch 18 tr: l 0.460 a 0.877 clct[np.int64(238), np.int64(405), np.int64(245), np.int64(312)] cl_acc 0.817  lr 0.100000 21.586sec(train) 22.261sec(infer)
# Epoch 18 tst: l 0.663 a 0.809 clct[np.int64(34), np.int64(65), np.int64(48), np.int64(53)] cl_acc 0.890  12.444sec
# Epoch 19 tr: l 0.435 a 0.885 clct[np.int64(263), np.int64(377), np.int64(251), np.int64(309)] cl_acc 0.861  lr 0.100000 21.672sec(train) 20.781sec(infer)
# Epoch 19 tst: l 0.627 a 0.820 clct[np.int64(39), np.int64(60), np.int64(49), np.int64(52)] cl_acc 0.930  13.732sec
# Epoch 20 tr: l 0.413 a 0.891 clct[np.int64(273), np.int64(360), np.int64(261), np.int64(306)] cl_acc 0.899  lr 0.100000 22.763sec(train) 20.575sec(infer)
# Epoch 20 tst: l 0.600 a 0.829 clct[np.int64(41), np.int64(58), np.int64(50), np.int64(51)] cl_acc 0.955  14.426sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.392 a 0.894 clct[np.int64(297), np.int64(324), np.int64(274), np.int64(305)] cl_acc 0.949  lr 0.100000 22.615sec(train) 20.530sec(infer)
# Epoch 21 tst: l 0.565 a 0.840 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.391sec
# Epoch 22 tr: l 0.366 a 0.903 clct[np.int64(298), np.int64(312), np.int64(285), np.int64(305)] cl_acc 0.968  lr 0.100000 22.235sec(train) 19.299sec(infer)
# Epoch 22 tst: l 0.533 a 0.850 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  15.220sec
# Epoch 23 tr: l 0.343 a 0.909 clct[np.int64(300), np.int64(304), np.int64(291), np.int64(305)] cl_acc 0.980  lr 0.100000 23.158sec(train) 19.611sec(infer)
# Epoch 23 tst: l 0.504 a 0.857 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  12.648sec
# Epoch 24 tr: l 0.326 a 0.914 clct[np.int64(298), np.int64(303), np.int64(296), np.int64(303)] cl_acc 0.990  lr 0.100000 22.212sec(train) 19.738sec(infer)
# Epoch 24 tst: l 0.484 a 0.864 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  11.561sec
# Epoch 25 tr: l 0.315 a 0.916 clct[np.int64(298), np.int64(302), np.int64(297), np.int64(303)] cl_acc 0.992  lr 0.100000 20.968sec(train) 24.176sec(infer)
# Epoch 25 tst: l 0.467 a 0.870 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  11.810sec
# Epoch 26 tr: l 0.304 a 0.918 clct[np.int64(297), np.int64(303), np.int64(298), np.int64(302)] cl_acc 0.993  lr 0.100000 20.681sec(train) 23.677sec(infer)
# Epoch 26 tst: l 0.455 a 0.872 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  13.881sec
# Epoch 27 tr: l 0.290 a 0.922 clct[np.int64(299), np.int64(302), np.int64(298), np.int64(301)] cl_acc 0.996  lr 0.100000 20.485sec(train) 23.606sec(infer)
# Epoch 27 tst: l 0.444 a 0.875 clct[np.int64(48), np.int64(51), np.int64(50), np.int64(51)] cl_acc 0.990  13.801sec
# Epoch 28 tr: l 0.282 a 0.922 clct[np.int64(298), np.int64(302), np.int64(299), np.int64(301)] cl_acc 0.997  lr 0.100000 19.331sec(train) 11.105sec(infer)
# Epoch 28 tst: l 0.435 a 0.877 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  6.433sec
# Epoch 29 tr: l 0.276 a 0.924 clct[np.int64(298), np.int64(302), np.int64(299), np.int64(301)] cl_acc 0.997  lr 0.100000 17.662sec(train) 9.674sec(infer)
# Epoch 29 tst: l 0.423 a 0.880 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  7.190sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 0.53 hour (1891.186 sec)

# %% [markdown]
# ## Plots

# %%
r_ten = {}
r_twentyfive = {}
r_fifty = {}

r_ten['cl_acc'] = []
r_ten['train_loss'] = []
r_ten['test_loss'] = []
r_ten['test_acc'] = []
for i in range(len(learning_rates)):
    r_ten['cl_acc'].append(ten[i][2])
    r_ten['train_loss'].append(ten[i][3])
    r_ten['test_loss'].append(ten[i][0])
    r_ten['test_acc'].append(ten[i][1])

r_twentyfive['cl_acc'] = []
r_twentyfive['train_loss'] = []
r_twentyfive['test_loss'] = []
r_twentyfive['test_acc'] = []
for i in range(len(learning_rates)):
    r_twentyfive['cl_acc'].append(twentyfive[i][2])
    r_twentyfive['train_loss'].append(twentyfive[i][3])
    r_twentyfive['test_loss'].append(twentyfive[i][0])
    r_twentyfive['test_acc'].append(twentyfive[i][1])

r_fifty['cl_acc'] = []
r_fifty['train_loss'] = []
r_fifty['test_loss'] = []
r_fifty['test_acc'] = []
for i in range(len(learning_rates)):
    r_fifty['cl_acc'].append(fifty[i][2])
    r_fifty['train_loss'].append(fifty[i][3])
    r_fifty['test_loss'].append(fifty[i][0])
    r_fifty['test_acc'].append(fifty[i][1])


os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,7))
    plt.plot(r_ten['test_loss'][l], label='R=10', color='xkcd:azure')
    plt.plot(r_twentyfive['test_loss'][l], label='R=25', color='red')
    plt.plot(r_fifty['test_loss'][l], label='R=50', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'train_loss.png'))

    plt.figure(figsize=(10,7))
    plt.plot(r_ten['test_acc'][l], label='R=10', color='xkcd:azure')
    plt.plot(r_twentyfive['test_acc'][l], label='R=25', color='red')
    plt.plot(r_fifty['test_acc'][l], label='R=50', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('test accuracy', fontsize=20)
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_acc.png'))

    plt.figure(figsize=(10,7))
    plt.ylim([0, 1.1])
    plt.plot(r_ten['cl_acc'][l], label='R=10', color='xkcd:azure', marker='o')
    plt.plot(r_twentyfive['cl_acc'][l], label='R=25', color='red', marker='o')
    plt.plot(r_fifty['cl_acc'][l], label='R=50', color='red', marker='o')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('cluster acc', fontsize=20)
    # plt.title(f'Cluster Accuracy per Epoch (Participation Rate={p_rates[l]})', fontsize=22, fontweight='bold')
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.savefig(os.path.join('graphs', f'cluster_acc_pn_{learning_rates[l]}.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 20
#      18 r_twentyfive['test_acc'] = []
#      19 for i in range(len(learning_rates)):
# ---> 20     r_twentyfive['cl_acc'].append(twentyfive[i][2])
#      21     r_twentyfive['train_loss'].append(twentyfive[i][3])
#      22     r_twentyfive['test_loss'].append(twentyfive[i][0])
#
# IndexError: list index out of range
