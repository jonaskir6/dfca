# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import ifca as IFCA

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
rc = ipp.Cluster(n=2).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
# 100%|██████████| 2/2 [00:06<00:00,  3.27s/engine]

# %%
seeds = [11,12,13,14,15]
learning_rates = [0.1]

dfca_gi = []
dfca_gi_std = []
ifca = []
ifca_std = []

# %%
# %%px --targets all
#
# import sys
# import os
# sys.path.append(os.getcwd())
#
# seeds = [11,12,13,14,15]
# learning_rates = [0.1]
#
# dfca_gi = []
# dfca_gi_std = []
# ifca = []
# ifca_std = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_gi.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-GI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     res_std = np.std(res_final, axis=0).tolist()
#     dfca_gi.append(res_mean)
#     dfca_gi_std.append(res_std)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the ifca experiment

# %%
# %%px --target 1 --noblock
# import ifca as IFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config_ifca.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------IFCA, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = IFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     res_std = np.std(res_final, axis=0).tolist()
#     ifca.append(res_mean)
#     ifca_std.append(res_std)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# DFCA-GI Experiment Outputs

# %%
rc.wait_interactive()
_.display_outputs()

dfca_gi = rc[0].pull('dfca_gi', block=True)
dfca_gi = rc[0].pull('dfca_gi_std', block=True)
ifca = rc[1].pull('ifca', block=True)
ifca_std = rc[1].pull('ifca_std', block=True)
# Out:
# unknown: 100%|██████████| 2/2 [02:01<00:00, 60.76s/tasks]
# ---------------------------------IFCA, lr: 0.1, seed: 11---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 11, 'train_seed': 11, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 2.293 a 0.112 clct[np.int64(440), np.int64(260), np.int64(363), np.int64(137)] cl_acc 0.480  3.482sec
# Epoch -1 tst: l 2.294 a 0.112 clct[np.int64(74), np.int64(38), np.int64(65), np.int64(23)] cl_acc 0.440  0.610sec
# Epoch 0 tr: l 2.179 a 0.328 clct[np.int64(301), np.int64(300), np.int64(284), np.int64(315)] cl_acc 0.953  lr 0.100000 6.648sec(train) 4.626sec(infer)
# Epoch 0 tst: l 2.179 a 0.330 clct[np.int64(50), np.int64(49), np.int64(51), np.int64(50)] cl_acc 0.930  0.994sec
# result written at output_ifca\results.pickle
# checkpoint written at output_ifca\checkpoint.pt
# ---train cluster Ended in 0.00 hour (17.654 sec)
# ---------------------------------IFCA, lr: 0.1, seed: 12---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 12, 'train_seed': 12, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.135 clct[np.int64(428), np.int64(424), np.int64(270), np.int64(78)] cl_acc 0.552  5.581sec
# Epoch -1 tst: l 2.292 a 0.135 clct[np.int64(62), np.int64(83), np.int64(44), np.int64(11)] cl_acc 0.535  0.599sec
# Epoch 0 tr: l 2.169 a 0.414 clct[np.int64(542), np.int64(330), np.int64(299), np.int64(29)] cl_acc 0.752  lr 0.100000 6.509sec(train) 3.546sec(infer)
# Epoch 0 tst: l 2.167 a 0.412 clct[np.int64(94), np.int64(53), np.int64(49), np.int64(4)] cl_acc 0.735  0.585sec
# result written at output_ifca\results.pickle
# checkpoint written at output_ifca\checkpoint.pt
# ---train cluster Ended in 0.00 hour (17.101 sec)
# ---------------------------------IFCA, lr: 0.1, seed: 13---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 13, 'train_seed': 13, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.123 clct[np.int64(69), np.int64(61), np.int64(84), np.int64(986)] cl_acc 0.307  3.780sec
# Epoch -1 tst: l 2.295 a 0.127 clct[np.int64(14), np.int64(13), np.int64(12), np.int64(161)] cl_acc 0.330  0.698sec
# Epoch 0 tr: l 2.202 a 0.263 clct[np.int64(291), np.int64(409), np.int64(193), np.int64(307)] cl_acc 0.817  lr 0.100000 7.840sec(train) 4.575sec(infer)
# Epoch 0 tst: l 2.198 a 0.265 clct[np.int64(49), np.int64(62), np.int64(31), np.int64(58)] cl_acc 0.835  0.576sec
# result written at output_ifca\results.pickle
# checkpoint written at output_ifca\checkpoint.pt
# ---train cluster Ended in 0.00 hour (17.701 sec)
# ---------------------------------IFCA, lr: 0.1, seed: 14---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 14, 'train_seed': 14, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.132 clct[np.int64(337), np.int64(365), np.int64(61), np.int64(437)] cl_acc 0.403  3.394sec
# Epoch -1 tst: l 2.294 a 0.132 clct[np.int64(59), np.int64(53), np.int64(13), np.int64(75)] cl_acc 0.420  0.417sec
# Epoch 0 tr: l 2.184 a 0.357 clct[np.int64(581), np.int64(425), np.int64(125), np.int64(69)] cl_acc 0.583  lr 0.100000 6.119sec(train) 3.955sec(infer)
# Epoch 0 tst: l 2.181 a 0.364 clct[np.int64(96), np.int64(72), np.int64(24), np.int64(8)] cl_acc 0.630  0.706sec
# result written at output_ifca\results.pickle
# checkpoint written at output_ifca\checkpoint.pt
# ---train cluster Ended in 0.00 hour (14.809 sec)
# ---------------------------------IFCA, lr: 0.1, seed: 15---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 15, 'train_seed': 15, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.119 clct[np.int64(147), np.int64(526), np.int64(174), np.int64(353)] cl_acc 0.438  5.023sec
# Epoch -1 tst: l 2.295 a 0.119 clct[np.int64(26), np.int64(96), np.int64(23), np.int64(55)] cl_acc 0.450  0.989sec
# Epoch 0 tr: l 2.196 a 0.302 clct[np.int64(118), np.int64(668), np.int64(58), np.int64(356)] cl_acc 0.522  lr 0.100000 6.841sec(train) 2.966sec(infer)
# Epoch 0 tst: l 2.194 a 0.307 clct[np.int64(23), np.int64(105), np.int64(12), np.int64(60)] cl_acc 0.535  0.502sec
# result written at output_ifca\results.pickle
# checkpoint written at output_ifca\checkpoint.pt
# ---train cluster Ended in 0.00 hour (16.554 sec)

# %% [markdown]
# IFCA Experiment Outputs

# %%
__.display_outputs()
# Out:
# ---------------------------------DFCA-GI, lr: 0.1, seed: 11---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 11, 'train_seed': 11, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.293 a 0.112 clct[np.int64(440), np.int64(260), np.int64(363), np.int64(137)] cl_acc 0.480  3.767sec
# Epoch -1 tst: l 2.293 a 0.135 clct[np.int64(74), np.int64(38), np.int64(65), np.int64(23)] cl_acc 0.440  2.972sec
# Epoch 0 tr: l 2.149 a 0.351 clct[np.int64(327), np.int64(294), np.int64(317), np.int64(262)] cl_acc 0.645  lr 0.100000 13.813sec(train) 3.903sec(infer)
# Epoch 0 tst: l 2.165 a 0.341 clct[np.int64(54), np.int64(42), np.int64(70), np.int64(34)] cl_acc 0.515  3.073sec
# result written at output_dfca_gi\results.pickle
# checkpoint written at output_dfca_gi\checkpoint.pt
# ---train cluster Ended in 0.01 hour (29.809 sec)
# ---------------------------------DFCA-GI, lr: 0.1, seed: 12---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 12, 'train_seed': 12, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.292 a 0.135 clct[np.int64(428), np.int64(424), np.int64(270), np.int64(78)] cl_acc 0.552  3.676sec
# Epoch -1 tst: l 2.292 a 0.157 clct[np.int64(62), np.int64(83), np.int64(44), np.int64(11)] cl_acc 0.535  2.538sec
# Epoch 0 tr: l 2.131 a 0.408 clct[np.int64(416), np.int64(348), np.int64(310), np.int64(126)] cl_acc 0.662  lr 0.100000 12.959sec(train) 3.532sec(infer)
# Epoch 0 tst: l 2.163 a 0.357 clct[np.int64(62), np.int64(64), np.int64(49), np.int64(25)] cl_acc 0.585  2.506sec
# result written at output_dfca_gi\results.pickle
# checkpoint written at output_dfca_gi\checkpoint.pt
# ---train cluster Ended in 0.01 hour (26.208 sec)
# ---------------------------------DFCA-GI, lr: 0.1, seed: 13---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 13, 'train_seed': 13, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.123 clct[np.int64(69), np.int64(61), np.int64(84), np.int64(986)] cl_acc 0.307  3.943sec
# Epoch -1 tst: l 2.294 a 0.155 clct[np.int64(14), np.int64(13), np.int64(12), np.int64(161)] cl_acc 0.330  2.711sec
# Epoch 0 tr: l 2.150 a 0.319 clct[np.int64(169), np.int64(234), np.int64(248), np.int64(549)] cl_acc 0.439  lr 0.100000 12.056sec(train) 4.124sec(infer)
# Epoch 0 tst: l 2.195 a 0.294 clct[np.int64(27), np.int64(33), np.int64(31), np.int64(109)] cl_acc 0.450  2.570sec
# result written at output_dfca_gi\results.pickle
# checkpoint written at output_dfca_gi\checkpoint.pt
# ---train cluster Ended in 0.01 hour (26.434 sec)
# ---------------------------------DFCA-GI, lr: 0.1, seed: 14---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 14, 'train_seed': 14, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.294 a 0.132 clct[np.int64(337), np.int64(365), np.int64(61), np.int64(437)] cl_acc 0.403  1.742sec
# Epoch -1 tst: l 2.294 a 0.151 clct[np.int64(59), np.int64(53), np.int64(13), np.int64(75)] cl_acc 0.420  1.165sec
# Epoch 0 tr: l 2.139 a 0.377 clct[np.int64(465), np.int64(315), np.int64(130), np.int64(290)] cl_acc 0.448  lr 0.100000 11.361sec(train) 1.540sec(infer)
# Epoch 0 tst: l 2.167 a 0.353 clct[np.int64(73), np.int64(64), np.int64(16), np.int64(47)] cl_acc 0.435  1.164sec
# result written at output_dfca_gi\results.pickle
# checkpoint written at output_dfca_gi\checkpoint.pt
# ---train cluster Ended in 0.01 hour (18.002 sec)
# ---------------------------------DFCA-GI, lr: 0.1, seed: 15---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 1, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 15, 'train_seed': 15, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda
# Epoch -1 tr: l 2.295 a 0.119 clct[np.int64(147), np.int64(526), np.int64(174), np.int64(353)] cl_acc 0.438  1.681sec
# Epoch -1 tst: l 2.295 a 0.129 clct[np.int64(26), np.int64(96), np.int64(23), np.int64(55)] cl_acc 0.450  1.203sec
# Epoch 0 tr: l 2.153 a 0.359 clct[np.int64(245), np.int64(447), np.int64(168), np.int64(340)] cl_acc 0.511  lr 0.100000 11.215sec(train) 1.524sec(infer)
# Epoch 0 tst: l 2.177 a 0.328 clct[np.int64(41), np.int64(66), np.int64(30), np.int64(63)] cl_acc 0.450  1.176sec
# result written at output_dfca_gi\results.pickle
# checkpoint written at output_dfca_gi\checkpoint.pt
# ---train cluster Ended in 0.00 hour (17.816 sec)

# %% [markdown]
# ## Plots

# %%
r_ifca = {}
r_dfca_gi = {}

r_ifca['test_loss'] = []
r_ifca['test_acc'] = []
r_ifca['cl_acc'] = []
r_ifca['train_loss'] = []
for i in range(len(learning_rates)):
    r_ifca['test_loss'].append(ifca[i][0])
    r_ifca['test_acc'].append(ifca[i][1])
    r_ifca['cl_acc'].append(ifca[i][2])
    r_ifca['train_loss'].append(ifca[i][3])

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
r_dfca_gi['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])
    r_dfca_gi['train_loss'].append(dfca_gi[i][3])



os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):
    epochs = np.arange(len(r_ifca['train_loss'][l]))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['train_loss'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['train_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Train Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_loss'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_test_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_acc'][l], label='ifca', color='blue')
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('test accuracy')
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_test_acc.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['cl_acc'][l][:31], label='ifca', color='blue')
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('cluster acc')
    plt.title(f'Cluster Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_cluster_acc.png'))

    plt.figure(figsize=(10,5))
    plt.errorbar(epochs[:31], r_dfca_gi['cl_acc'][l][:31], yerr=dfca_gi_std[2][:31], capsize=2)
    plt.xlabel('epoch')
    plt.ylabel('cluster acc')
    plt.title(f'DFCA Cluster Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_dfca_cluster_acc.png'))

    plt.figure(figsize=(10,5))
    plt.errorbar(epochs[:31], r_ifca['cl_acc'][l][:31], yerr=ifca_std[2][:31], capsize=2)
    plt.xlabel('epoch')
    plt.ylabel('cluster acc')
    plt.title(f'IFCA Cluster Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join('graphs', '1_ifca_cluster_acc.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 72
#      69 plt.savefig(os.path.join('graphs', '1_cluster_acc.png'))
#      71 plt.figure(figsize=(10,5))
# ---> 72 plt.errorbar(epochs[:31], r_dfca_gi['cl_acc'][l][:31], yerr=dfca_gi_std[l][2][:31], capsize=2)
#      73 plt.xlabel('epoch')
#      74 plt.ylabel('cluster acc')
#
# IndexError: list index out of range
